# %%
import re
import enum
import math
import random
import nltk
import csv
import numpy as np
import scipy as sp
from nltk.corpus import wordnet as wn
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import semcor
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from random import randrange
from collections import deque
from statistics import mean

# %% [markdown]
# FUNZIONI DI PREPROCESSING

# %%
#il pre-processing consiste nella tokenizzazione, lemmatizzazione,
#rimozione della punteggiatura e delle stopwords di una sentence
def pre_processing(sentence):
    return set(remove_stopwords(tokenize_sentence(remove_punctuation(sentence))))

#rimuove le stowords da una lista di parole
def remove_stopwords(words_list):
    stopwords_list = get_stopwords()
    return [value.lower() for value in words_list if value.lower() not in stopwords_list]


#Tokenizza la frase in input e ne affettua anche la lemmatizzazione della sue parole
def tokenize_sentence(sentence):
    words_list = []
    lmtzr = WordNetLemmatizer()
    for tag in nltk.pos_tag(word_tokenize(sentence)):
        if (tag[1][:2] == "NN"):
            words_list.append(lmtzr.lemmatize(tag[0], pos = wn.NOUN))
        elif (tag[1][:2] == "VB"):
             words_list.append(lmtzr.lemmatize(tag[0], pos = wn.VERB))
        elif (tag[1][:2] == "RB"):
             words_list.append(lmtzr.lemmatize(tag[0], pos = wn.ADV))
        elif (tag[1][:2] == "JJ"):
             words_list.append(lmtzr.lemmatize(tag[0], pos = wn.ADJ))
    return words_list

#Restituisce la l'insieme di stopwords dal file delle stopwords
def get_stopwords():
    stopwords = open("stop_words_FULL.txt", "r")
    stopwords_list = []
    for word in stopwords:
        stopwords_list.append(word.replace('\n', ''))
    stopwords.close()
    return stopwords_list

#Rimuove la punteggiatura da una sentence
#Restituisce la sentence senza punteggiature
def remove_punctuation(sentence):
    return re.sub(r'[^\w\s]','',sentence)

# %% [markdown]
# Word sense disambiguation (WSD) is an open problem of
# natural language processing, which comprises the process of
# identifying which sense of a word (i.e. meaning) is used in any
# given sentence, when the word has a number of distinct senses
# (polysemy).
#
# FUNZIONI PRINCIPALI

# %%
#Algoritmo di Lesk
def lesk_algorithm(word, sentence, word_type):
    best_sense = wn.synsets(word)[0]
    max_overlap = 0
    max_signature = []
    print("Frase: ", sentence)
    context = pre_processing(sentence)
    
    #se il tipo di parola è un nome allora cerco solo tra i nomi in wordnet
    #altrimenti prendo tutti i synset associati a quel termine
    if word_type == 'NOUN':
        synsets = wn.synsets(word, pos=wn.NOUN)
    elif word_type == 'ALL':
        synsets = wn.synsets(word)
        
    for sense in synsets:
        signature = get_signature(sense)
        overlap = len(list(signature & context)) #overlap
        if overlap > max_overlap:
            max_overlap = overlap
            best_sense = sense
            max_signature = signature
            
    print("Contesto della frase: ", context)
    print("max Signature: ", max_signature) #signature del senso con più overlap con il contesto della sentence
    return best_sense

#Signature di un senso di WordNet      
def get_signature(sense):
    signature = set()
    for word in pre_processing(sense.definition()): #tokenizzo la definizione del synset
        signature.add(word)
    for example in sense.examples(): #tokenizzo ogni esempio del synset
        for word in pre_processing(example):
            signature.add(word)
    return signature #la signature conterrà tutte le parole presenti nella definizione del senso e negli esempi

# %% [markdown]
# FUNZIONI UTILI PER L'ANALISI DEL TESTO

# %%
#Restituisce un sostantivo random presente nel dizionario associato ad una sentence
def get_random_noun(dictionary_tag):
    try:
        sentence_nouns = dictionary_tag['NN']
    except KeyError:
        return None #se non ci sono sostantivi
    noun =  random.choice(sentence_nouns)
    if len(wn.synsets(noun)) == 0:
        return None #se il sostantivo scelto non ha almeno un synset in wordnet
    return noun

#Restituisce una parola random presente nel dizionario associato ad una sentence
def get_random_word(dictionary_tag):
    keys = list(dictionary_tag.keys())
    if not keys:
        return None #se non ci sono parole "analizzabili" nel dizionario, aka se il dizionario è vuoto
    key = random.choice(keys)
    words_list = dictionary_tag[key]
    word = random.choice(words_list)
    if len(wn.synsets(word)) == 0:
        return None #se la parola scelta non ha almeno un synset in wordnet
    return word

#Verifica che una parola abbia un synset target associato
#Senza synset target associato è inutile confrontare l'output dell'algortimo di Lesk
def check_word_synset_target(word,sentence_sem):
    for w in sentence_sem:
        if (type(w) != list):
            if (w[0] == word):
                return True
    return False
    
#Crea un dizionario che ha come chiavi i tag presenti nella sentence
#e come valori liste di parole associate a quei tag
#e.g {NN: ['home','garden'], VB:['gone'], .....,}
#input: sentence_tag -> rappresenta le words della sentence con i relativi pos tag
#input: sentence_sem -> rappresenta le words della sentence con il relativo synset target associato
def get_dictionary_tag(sentence_tag,sentence_sem):
    dictionary_tag = dict()
    stopwords_list = get_stopwords()
    for word in sentence_tag:
         tag = word.label()
         word = " ".join(l for l in word)
         if check_word_synset_target(word, sentence_sem): #Non inserisco nel dizionario parole che non hanno un synset target
             w = word.lower()
             if w not in stopwords_list and tag: #Non inserisco nel dizionario stopwords o parole che non hanno un pos tag associato
                 if tag in dictionary_tag:
                     dictionary_tag[tag].append(word)
                 else:
                     dictionary_tag[tag] = [word]             
    return dictionary_tag


def get_random_index(index_evaluated, INDEXES_NUM):
    while True:
        index = randrange(INDEXES_NUM)
        if index not in index_evaluated:
            return index
    

#Restituisce il synset target per una parola in una sentence
def get_synset_target_for_word_in_sentence(noun,sentence):
     for word in sentence:
      if(type(word) != list):
          if (word[0] == noun):
              return str(word.label())

# %% [markdown]
# VARIE METRICHE DI SIMILARITA E ALGORITMI PER LA RICERCA

# %%
#Restituisce tutti i percorsi di iperonimi di un senso di wordnet
#effettua una ricerca in profondità ricorsiva
def all_hypernym_paths(sense):
    paths = []
    hypernyms = sense.hypernyms()
    if len(hypernyms) == 0:
        paths = [[sense]]
    for hypernym in hypernyms:
        for ancestor_list in all_hypernym_paths(hypernym):
            ancestor_list.append(sense)
            paths.append(ancestor_list)
    return paths

#massima profondità intesa come il massimo dei massimi percorsi di iperonimi di tutti i sensi presenti in wordnet
max_depth = max(max(len(hyp_path) for hyp_path in all_hypernym_paths(ss)) for ss in wn.all_synsets())

def similarity(word1, word2, similarity_function):
    max_sim = 0
    for s1 in wn.synsets(word1):
        for s2 in wn.synsets(word2):
           sim = similarity_function(s1,s2)
           if sim > max_sim:
               max_sim = sim
    return max_sim

#------------ MY SIMILARITY FUNCTIONS-------------#
def wu_palmer_similarity(sense1, sense2):
    numerator = 2 * depth(LC_subsumer(sense1,sense2))
    denominator = depth(sense1) + depth(sense2)
    return numerator/denominator

def leakcock_chodorow(sense1, sense2):
    numerator = (shortest_path(sense1, sense2) + 1)
    denominator = (2 * max_depth) + 1
    return -math.log(numerator/denominator)

def shortest_path_similarity(sense1, sense2):
    return ((2 * max_depth) - shortest_path(sense1, sense2))

#------------ WORDNET SIMILARITY FUNCTIONS---------#
def wn_wu_palmer_similarity(sense1, sense2):
    sim = sense1.wup_similarity(sense2)
    if sim: return sim
    else: return 0
    
def wn_leakcock_chodorow(sense1, sense2):
    try:
        sim = sense1.lch_similarity(sense2)
        if sim: return sim
        else: return 0
    except:
        return 0

#restituisce un dizionario di iperonimi del senso in input con la relativa profondità
#rispetto al senso in input
#le profondità di ogni senso sono sempre le più piccole distanze dal senso da cui si è partiti
#esempio per il senso 'apple.n.01':
"""{Synset('apple.n.01'): 0, Synset('edible_fruit.n.01'): 1, Synset('pome.n.01'): 1,
 Synset('fruit.n.01'): 2, Synset('produce.n.01'): 2, Synset('reproductive_structure.n.01'): 3,
 Synset('food.n.02'): 3, Synset('plant_organ.n.01'): 4, Synset('solid.n.01'): 4, 
 Synset('plant_part.n.01'): 5, Synset('matter.n.03'): 5,
 Synset('natural_object.n.01'): 6, Synset('physical_entity.n.01'): 6, 
 Synset('whole.n.02'): 7, Synset('entity.n.01'): 7, Synset('object.n.01'): 8}"""
def min_hypernyms_depth(sense):
    sense_depth_queue = deque([(sense, 0)]) #deque garantisce efficienza nell'inserire ed eliminare elementi sia a destra che a sinistra della coda
    sense_depth_dict = {}
    while sense_depth_queue:
        s, depth = sense_depth_queue.popleft()
        if s in sense_depth_dict:
            continue
        sense_depth_dict[s] = depth
        depth += 1
        sense_depth_queue.extend((hyperonym, depth) for hyperonym in s.hypernyms()) #li mette a destra della coda
    return sense_depth_dict

#restituisce il percorso più breve tra due sensi di wordnet
def shortest_path(sense1,sense2):
    if sense1 == sense2:
        return 0
    
    dict1 = min_hypernyms_depth(sense1) #dizionario iperonimi del sense1
    dict2 = min_hypernyms_depth(sense2) #dizionario iperonimi del sense2
    
    min_dist = (2 * max_depth) #distanza minima inizialmente uguale alla massima lunghezza che può avere
    #per ogni senso del dizionario degli iperonimi di sense1
    #cerca di trovare il match con un senso del secondo dizionario.
    #la distanza minima sarà la somma minima delle profondità dei sensi matchati
    #rispetto al senso di partenza (sense1, sense2)
    for ss, dist1 in dict1.items():
        dist2 = dict2.get(ss) 
        if not dist2:
            dist2 = (2 * max_depth)
        min_dist = min(min_dist, dist1 + dist2)
    return (2 * max_depth) if math.isinf(min_dist) else min_dist

#Restituisce il lowest common ancestor di due sensi, cioè l'iperonimo comune
#più vicino ai due sensi. se ne ho più di uno prendo quello può essere il più profondo rispetto alla radice,
def LC_subsumer(sense1, sense2):
    if sense1 == sense2: return sense1
    
    dict1 = min_hypernyms_depth(sense1) #dizionario iperonimi minimi del sense1
    dict2 = min_hypernyms_depth(sense2) #dizionario iperonimi minimi del sense2
    
    min_dist = (2 * max_depth)
    candidates = []
    for ss, dist1 in dict1.items():
        dist2 = dict2.get(ss) 
        if not dist2:
            dist2 = (2 * max_depth)
        else:
            if (dist1 + dist2) <= min_dist:
                min_dist = (dist1 + dist2)
                candidates.append(ss) 
    if candidates:
        deepest = candidates[0]
        for sense in candidates:
            if depth(sense) < depth(deepest):
                deepest = sense
        return deepest #restituisce il senso con profondità maggiore rispetto alla radice

#restituisce la profondità di un senso in wordnet
#la profondità è vista come il massimo percorso dal senso alla radice
#cioè il path più lungo di tutti i path degli iperonimi del senso          
def depth(sense):
    if not sense:
        return 0
    return max([len(path) for path in all_hypernym_paths(sense)])

#Classe enum con la quale specifichiamo il tipo di similarità utilizzata
class Similarity_Type(enum.Enum):
    wu_palmer_similarity = 1
    shortest_path = 2
    leakcock_chodorow = 3

# %%
def main():  
    similarity_type = Similarity_Type.wu_palmer_similarity
    
    #_____________________MAIN_________________________________________________
    with open('WordSim353.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        assignments = []
        targets = []
        line_count = 0
        for row in csv_reader:
            if line_count > 0:
                print("=============================")
                print("Word1: ",row[0])
                print("Word2: ",row[1])
                sim = 0
                wn_sim = 0
                if similarity_type.value == 1:
                    sim = similarity(row[0], row[1], wu_palmer_similarity)
                    wn_sim = similarity(row[0], row[1], wn_wu_palmer_similarity)
                elif similarity_type.value == 2:
                    sim = similarity(row[0], row[1], shortest_path_similarity)
                elif similarity_type.value == 3:
                    sim = similarity(row[0], row[1], leakcock_chodorow)
                    wn_sim = similarity(row[0], row[1], wn_leakcock_chodorow)
                print("System Similarity: ",sim)
                print("WordNet Similarity: ",wn_sim)
                print("Human Similarity: ",row[2])
                print("Similarity Type: ", similarity_type.name)
                assignments.append(sim)
                targets.append(float(row[2]))
                print("=============================")
            line_count = line_count + 1
    print()
    """
    PEARSON
        +1 - Complete positive correlation
        +0.8 - Strong positive correlation
        +0.6 - Moderate positive correlation
        0 - no correlation whatsoever
        -0.6 - Moderate negative correlation
        -0.8 - Strong negative correlation
        -1 - Complete negative correlation
        Restituisce una matrice M = nxn quadrata dove n = 2 (numero di inoput) dove M (i,j) è
        la correlazione tra la variabile casuale i e j. Poichè la correlazione
        tra una variabile e se stessa è 1, tutte le voci diagonali (i,i) sono uguali a 1
    """    
    print("Pearson Correlation: ",np.corrcoef(assignments, targets))
    
    """
    SPEARMAN
        Misura non parametrica della monotonicità della relazione
        tra due dataset. Varia da +1 a -1 con 0 che implica la non correlazione
        1 indica che se x cresce y cresce
        -1 indica che se x cresce y descresce
    """
    print()
    print("Spearman Correlation: ",sp.stats.spearmanr(assignments, targets))
    #_____________________MAIN_________________________________________________

#TESTING
main()
# Out:
# =============================
# Word1:  love
# Word2:  sex
# System Similarity:  0.7692307692307693
# WordNet Similarity:  0.9230769230769231
# Human Similarity:  6.77
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  tiger
# Word2:  cat
# System Similarity:  0.896551724137931
# WordNet Similarity:  0.9655172413793104
# Human Similarity:  7.35
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  tiger
# Word2:  tiger
# System Similarity:  1.0
# WordNet Similarity:  1.0
# Human Similarity:  10.00
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  book
# Word2:  paper
# System Similarity:  0.875
# WordNet Similarity:  0.875
# Human Similarity:  7.46
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  computer
# Word2:  keyboard
# System Similarity:  0.8235294117647058
# WordNet Similarity:  0.8235294117647058
# Human Similarity:  7.62
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  computer
# Word2:  internet
# System Similarity:  0.631578947368421
# WordNet Similarity:  0.631578947368421
# Human Similarity:  7.58
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  plane
# Word2:  car
# System Similarity:  0.7272727272727273
# WordNet Similarity:  0.7272727272727273
# Human Similarity:  5.77
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  train
# Word2:  car
# System Similarity:  0.7368421052631579
# WordNet Similarity:  0.7368421052631579
# Human Similarity:  6.31
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  telephone
# Word2:  communication
# System Similarity:  0.16666666666666666
# WordNet Similarity:  0.2
# Human Similarity:  7.50
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  television
# Word2:  radio
# System Similarity:  0.9090909090909091
# WordNet Similarity:  0.9090909090909091
# Human Similarity:  6.77
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  media
# Word2:  radio
# System Similarity:  0.8235294117647058
# WordNet Similarity:  0.8235294117647058
# Human Similarity:  7.42
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  drug
# Word2:  abuse
# System Similarity:  0.16666666666666666
# WordNet Similarity:  0.3333333333333333
# Human Similarity:  6.85
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  bread
# Word2:  butter
# System Similarity:  0.625
# WordNet Similarity:  0.75
# Human Similarity:  6.19
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  cucumber
# Word2:  potato
# System Similarity:  0.8235294117647058
# WordNet Similarity:  0.8235294117647058
# Human Similarity:  5.92
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  doctor
# Word2:  nurse
# System Similarity:  0.8695652173913043
# WordNet Similarity:  0.8695652173913043
# Human Similarity:  7.00
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  professor
# Word2:  doctor
# System Similarity:  0.75
# WordNet Similarity:  0.5454545454545454
# Human Similarity:  6.62
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  student
# Word2:  professor
# System Similarity:  0.6666666666666666
# WordNet Similarity:  0.5714285714285714
# Human Similarity:  6.81
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  smart
# Word2:  student
# System Similarity:  0.1111111111111111
# WordNet Similarity:  0.2
# Human Similarity:  4.62
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  smart
# Word2:  stupid
# System Similarity:  0.1111111111111111
# WordNet Similarity:  0.5
# Human Similarity:  5.81
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  company
# Word2:  stock
# System Similarity:  0.6153846153846154
# WordNet Similarity:  0.6153846153846154
# Human Similarity:  7.08
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  stock
# Word2:  market
# System Similarity:  0.5555555555555556
# WordNet Similarity:  0.5555555555555556
# Human Similarity:  8.08
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  stock
# Word2:  phone
# System Similarity:  0.7
# WordNet Similarity:  0.7
# Human Similarity:  1.62
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  stock
# Word2:  CD
# System Similarity:  0.7368421052631579
# WordNet Similarity:  0.7368421052631579
# Human Similarity:  1.31
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  stock
# Word2:  jaguar
# System Similarity:  0.8148148148148148
# WordNet Similarity:  0.8148148148148148
# Human Similarity:  0.92
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  stock
# Word2:  egg
# System Similarity:  0.625
# WordNet Similarity:  0.625
# Human Similarity:  1.81
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  fertility
# Word2:  egg
# System Similarity:  0.15384615384615385
# WordNet Similarity:  0.18181818181818182
# Human Similarity:  6.69
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  stock
# Word2:  live
# System Similarity:  0.2857142857142857
# WordNet Similarity:  0.5
# Human Similarity:  3.73
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  stock
# Word2:  life
# System Similarity:  0.6153846153846154
# WordNet Similarity:  0.6153846153846154
# Human Similarity:  0.92
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  book
# Word2:  library
# System Similarity:  0.8
# WordNet Similarity:  0.8
# Human Similarity:  7.46
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  bank
# Word2:  money
# System Similarity:  0.5714285714285714
# WordNet Similarity:  0.5714285714285714
# Human Similarity:  8.12
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  wood
# Word2:  forest
# System Similarity:  1.0
# WordNet Similarity:  1.0
# Human Similarity:  7.73
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  money
# Word2:  cash
# System Similarity:  0.875
# WordNet Similarity:  0.875
# Human Similarity:  9.15
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  professor
# Word2:  cucumber
# System Similarity:  0.5
# WordNet Similarity:  0.5
# Human Similarity:  0.31
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  king
# Word2:  cabbage
# System Similarity:  0.5714285714285714
# WordNet Similarity:  0.5714285714285714
# Human Similarity:  0.23
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  king
# Word2:  queen
# System Similarity:  1.0
# WordNet Similarity:  1.0
# Human Similarity:  8.58
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  king
# Word2:  rook
# System Similarity:  0.9090909090909091
# WordNet Similarity:  0.9090909090909091
# Human Similarity:  5.92
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  bishop
# Word2:  rabbi
# System Similarity:  0.8181818181818182
# WordNet Similarity:  0.5454545454545454
# Human Similarity:  6.69
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  Jerusalem
# Word2:  Israel
# System Similarity:  0
# WordNet Similarity:  0.7
# Human Similarity:  8.46
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  Jerusalem
# Word2:  Palestinian
# System Similarity:  0
# WordNet Similarity:  0.2857142857142857
# Human Similarity:  7.65
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  holy
# Word2:  sex
# System Similarity:  0.3076923076923077
# WordNet Similarity:  0.3076923076923077
# Human Similarity:  1.62
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  fuck
# Word2:  sex
# System Similarity:  0.7142857142857143
# WordNet Similarity:  0.8571428571428571
# Human Similarity:  9.44
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  Maradona
# Word2:  football
# System Similarity:  0
# WordNet Similarity:  0
# Human Similarity:  8.62
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  football
# Word2:  soccer
# System Similarity:  0.96
# WordNet Similarity:  0.96
# Human Similarity:  9.03
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  football
# Word2:  basketball
# System Similarity:  0.9
# WordNet Similarity:  0.9
# Human Similarity:  6.81
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  football
# Word2:  tennis
# System Similarity:  0.6956521739130435
# WordNet Similarity:  0.782608695652174
# Human Similarity:  6.63
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  tennis
# Word2:  racket
# System Similarity:  0.5714285714285714
# WordNet Similarity:  0.6
# Human Similarity:  7.56
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  Arafat
# Word2:  peace
# System Similarity:  0
# WordNet Similarity:  0.14285714285714285
# Human Similarity:  6.73
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  Arafat
# Word2:  terror
# System Similarity:  0
# WordNet Similarity:  0.631578947368421
# Human Similarity:  7.65
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  Arafat
# Word2:  Jackson
# System Similarity:  0
# WordNet Similarity:  0.5714285714285714
# Human Similarity:  2.50
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  law
# Word2:  lawyer
# System Similarity:  0.13333333333333333
# WordNet Similarity:  0.16666666666666666
# Human Similarity:  8.38
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  movie
# Word2:  star
# System Similarity:  0.5333333333333333
# WordNet Similarity:  0.5333333333333333
# Human Similarity:  7.38
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  movie
# Word2:  popcorn
# System Similarity:  0.36363636363636365
# WordNet Similarity:  0.36363636363636365
# Human Similarity:  6.19
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  movie
# Word2:  critic
# System Similarity:  0.4444444444444444
# WordNet Similarity:  0.4444444444444444
# Human Similarity:  6.73
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  movie
# Word2:  theater
# System Similarity:  0.625
# WordNet Similarity:  0.625
# Human Similarity:  7.92
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  physics
# Word2:  proton
# System Similarity:  0.2
# WordNet Similarity:  0.2222222222222222
# Human Similarity:  8.12
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  physics
# Word2:  chemistry
# System Similarity:  0.9
# WordNet Similarity:  0.9
# Human Similarity:  7.35
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  space
# Word2:  chemistry
# System Similarity:  0.4444444444444444
# WordNet Similarity:  0.4444444444444444
# Human Similarity:  4.88
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  alcohol
# Word2:  chemistry
# System Similarity:  0.7142857142857143
# WordNet Similarity:  0.5714285714285714
# Human Similarity:  5.54
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  vodka
# Word2:  gin
# System Similarity:  0.9090909090909091
# WordNet Similarity:  0.9090909090909091
# Human Similarity:  8.46
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  vodka
# Word2:  brandy
# System Similarity:  0.9090909090909091
# WordNet Similarity:  0.9090909090909091
# Human Similarity:  8.13
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  drink
# Word2:  car
# System Similarity:  0.26666666666666666
# WordNet Similarity:  0.2857142857142857
# Human Similarity:  3.04
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  drink
# Word2:  ear
# System Similarity:  0.46153846153846156
# WordNet Similarity:  0.46153846153846156
# Human Similarity:  1.31
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  drink
# Word2:  mouth
# System Similarity:  0.5
# WordNet Similarity:  0.5
# Human Similarity:  5.96
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  drink
# Word2:  eat
# System Similarity:  0.5
# WordNet Similarity:  0.3333333333333333
# Human Similarity:  6.87
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  baby
# Word2:  mother
# System Similarity:  0.8181818181818182
# WordNet Similarity:  0.631578947368421
# Human Similarity:  7.85
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  drink
# Word2:  mother
# System Similarity:  0.5333333333333333
# WordNet Similarity:  0.6153846153846154
# Human Similarity:  2.65
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  car
# Word2:  automobile
# System Similarity:  1.0
# WordNet Similarity:  1.0
# Human Similarity:  8.94
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  gem
# Word2:  jewel
# System Similarity:  1.0
# WordNet Similarity:  1.0
# Human Similarity:  8.96
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  journey
# Word2:  voyage
# System Similarity:  0.9523809523809523
# WordNet Similarity:  0.9523809523809523
# Human Similarity:  9.29
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  boy
# Word2:  lad
# System Similarity:  0.9473684210526315
# WordNet Similarity:  0.9473684210526315
# Human Similarity:  8.83
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  coast
# Word2:  shore
# System Similarity:  0.7272727272727273
# WordNet Similarity:  0.9090909090909091
# Human Similarity:  9.10
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  asylum
# Word2:  madhouse
# System Similarity:  0.9523809523809523
# WordNet Similarity:  0.9523809523809523
# Human Similarity:  8.87
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  magician
# Word2:  wizard
# System Similarity:  1.0
# WordNet Similarity:  1.0
# Human Similarity:  9.02
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  midday
# Word2:  noon
# System Similarity:  1.0
# WordNet Similarity:  1.0
# Human Similarity:  9.29
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  furnace
# Word2:  stove
# System Similarity:  0.5263157894736842
# WordNet Similarity:  0.5263157894736842
# Human Similarity:  8.79
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  food
# Word2:  fruit
# System Similarity:  0.4
# WordNet Similarity:  0.4
# Human Similarity:  7.52
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  bird
# Word2:  cock
# System Similarity:  0.9523809523809523
# WordNet Similarity:  0.9523809523809523
# Human Similarity:  7.10
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  bird
# Word2:  crane
# System Similarity:  0.8695652173913043
# WordNet Similarity:  0.8695652173913043
# Human Similarity:  7.38
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  tool
# Word2:  implement
# System Similarity:  0.8
# WordNet Similarity:  0.9333333333333333
# Human Similarity:  6.46
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  brother
# Word2:  monk
# System Similarity:  0.8571428571428571
# WordNet Similarity:  0.9523809523809523
# Human Similarity:  6.27
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  crane
# Word2:  implement
# System Similarity:  0.75
# WordNet Similarity:  0.75
# Human Similarity:  2.69
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  lad
# Word2:  brother
# System Similarity:  0.7777777777777778
# WordNet Similarity:  0.6666666666666666
# Human Similarity:  4.46
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  journey
# Word2:  car
# System Similarity:  0.1
# WordNet Similarity:  0.15384615384615385
# Human Similarity:  5.85
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  monk
# Word2:  oracle
# System Similarity:  0.6666666666666666
# WordNet Similarity:  0.5714285714285714
# Human Similarity:  5.00
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  cemetery
# Word2:  woodland
# System Similarity:  0.4
# WordNet Similarity:  0.42857142857142855
# Human Similarity:  2.08
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  food
# Word2:  rooster
# System Similarity:  0.21052631578947367
# WordNet Similarity:  0.21052631578947367
# Human Similarity:  4.42
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  coast
# Word2:  hill
# System Similarity:  0.6666666666666666
# WordNet Similarity:  0.6666666666666666
# Human Similarity:  4.38
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  forest
# Word2:  graveyard
# System Similarity:  0.4
# WordNet Similarity:  0.42857142857142855
# Human Similarity:  1.85
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  shore
# Word2:  woodland
# System Similarity:  0.5454545454545454
# WordNet Similarity:  0.6
# Human Similarity:  3.08
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  monk
# Word2:  slave
# System Similarity:  0.7777777777777778
# WordNet Similarity:  0.6666666666666666
# Human Similarity:  0.92
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  coast
# Word2:  forest
# System Similarity:  0.5
# WordNet Similarity:  0.5454545454545454
# Human Similarity:  3.15
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  lad
# Word2:  wizard
# System Similarity:  0.7777777777777778
# WordNet Similarity:  0.6666666666666666
# Human Similarity:  0.92
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  chord
# Word2:  smile
# System Similarity:  0.375
# WordNet Similarity:  0.375
# Human Similarity:  0.54
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  glass
# Word2:  magician
# System Similarity:  0.47058823529411764
# WordNet Similarity:  0.47058823529411764
# Human Similarity:  2.08
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  noon
# Word2:  string
# System Similarity:  0.26666666666666666
# WordNet Similarity:  0.26666666666666666
# Human Similarity:  0.54
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  rooster
# Word2:  voyage
# System Similarity:  0.08
# WordNet Similarity:  0.10526315789473684
# Human Similarity:  0.62
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  money
# Word2:  dollar
# System Similarity:  0.7777777777777778
# WordNet Similarity:  0.7777777777777778
# Human Similarity:  8.42
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  money
# Word2:  cash
# System Similarity:  0.875
# WordNet Similarity:  0.875
# Human Similarity:  9.08
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  money
# Word2:  currency
# System Similarity:  0.8571428571428571
# WordNet Similarity:  0.9333333333333333
# Human Similarity:  9.04
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  money
# Word2:  wealth
# System Similarity:  0.7692307692307693
# WordNet Similarity:  0.9230769230769231
# Human Similarity:  8.27
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  money
# Word2:  property
# System Similarity:  0.6666666666666666
# WordNet Similarity:  0.8333333333333334
# Human Similarity:  7.57
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  money
# Word2:  possession
# System Similarity:  0.5454545454545454
# WordNet Similarity:  0.7272727272727273
# Human Similarity:  7.29
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  money
# Word2:  bank
# System Similarity:  0.5714285714285714
# WordNet Similarity:  0.5714285714285714
# Human Similarity:  8.50
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  money
# Word2:  deposit
# System Similarity:  0.875
# WordNet Similarity:  0.875
# Human Similarity:  7.73
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  money
# Word2:  withdrawal
# System Similarity:  0.2857142857142857
# WordNet Similarity:  0.2857142857142857
# Human Similarity:  6.88
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  money
# Word2:  laundering
# System Similarity:  0.25
# WordNet Similarity:  0.25
# Human Similarity:  5.65
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  money
# Word2:  operation
# System Similarity:  0.3333333333333333
# WordNet Similarity:  0.3333333333333333
# Human Similarity:  3.31
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  tiger
# Word2:  jaguar
# System Similarity:  0.9333333333333333
# WordNet Similarity:  0.9333333333333333
# Human Similarity:  8.00
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  tiger
# Word2:  feline
# System Similarity:  0.8571428571428571
# WordNet Similarity:  0.9285714285714286
# Human Similarity:  8.00
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  tiger
# Word2:  carnivore
# System Similarity:  0.8148148148148148
# WordNet Similarity:  0.8888888888888888
# Human Similarity:  7.08
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  tiger
# Word2:  mammal
# System Similarity:  0.72
# WordNet Similarity:  0.8
# Human Similarity:  6.85
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  tiger
# Word2:  animal
# System Similarity:  0.8
# WordNet Similarity:  0.8
# Human Similarity:  7.00
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  tiger
# Word2:  organism
# System Similarity:  0.47619047619047616
# WordNet Similarity:  0.8571428571428571
# Human Similarity:  4.77
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  tiger
# Word2:  fauna
# System Similarity:  0.8
# WordNet Similarity:  0.8
# Human Similarity:  5.62
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  tiger
# Word2:  zoo
# System Similarity:  0.36363636363636365
# WordNet Similarity:  0.5333333333333333
# Human Similarity:  5.87
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  psychology
# Word2:  psychiatry
# System Similarity:  0.7272727272727273
# WordNet Similarity:  0.7272727272727273
# Human Similarity:  8.08
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  psychology
# Word2:  anxiety
# System Similarity:  0.25
# WordNet Similarity:  0.25
# Human Similarity:  7.00
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  psychology
# Word2:  fear
# System Similarity:  0.25
# WordNet Similarity:  0.25
# Human Similarity:  6.85
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  psychology
# Word2:  depression
# System Similarity:  0.35294117647058826
# WordNet Similarity:  0.35294117647058826
# Human Similarity:  7.42
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  psychology
# Word2:  clinic
# System Similarity:  0.23529411764705882
# WordNet Similarity:  0.23529411764705882
# Human Similarity:  6.58
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  psychology
# Word2:  doctor
# System Similarity:  0.3333333333333333
# WordNet Similarity:  0.3333333333333333
# Human Similarity:  6.42
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  psychology
# Word2:  Freud
# System Similarity:  0
# WordNet Similarity:  0.09523809523809523
# Human Similarity:  8.21
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  psychology
# Word2:  mind
# System Similarity:  0.5882352941176471
# WordNet Similarity:  0.5882352941176471
# Human Similarity:  7.69
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  psychology
# Word2:  health
# System Similarity:  0.26666666666666666
# WordNet Similarity:  0.26666666666666666
# Human Similarity:  7.23
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  psychology
# Word2:  science
# System Similarity:  0.8235294117647058
# WordNet Similarity:  0.9411764705882353
# Human Similarity:  6.71
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  psychology
# Word2:  discipline
# System Similarity:  0.75
# WordNet Similarity:  0.875
# Human Similarity:  5.58
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  psychology
# Word2:  cognition
# System Similarity:  0.46153846153846156
# WordNet Similarity:  0.6153846153846154
# Human Similarity:  7.48
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  planet
# Word2:  star
# System Similarity:  0.8571428571428571
# WordNet Similarity:  0.8571428571428571
# Human Similarity:  8.45
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  planet
# Word2:  constellation
# System Similarity:  0.7692307692307693
# WordNet Similarity:  0.7692307692307693
# Human Similarity:  8.06
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  planet
# Word2:  moon
# System Similarity:  0.8
# WordNet Similarity:  0.8
# Human Similarity:  8.08
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  planet
# Word2:  sun
# System Similarity:  0.8
# WordNet Similarity:  0.8
# Human Similarity:  8.02
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  planet
# Word2:  galaxy
# System Similarity:  0.631578947368421
# WordNet Similarity:  0.631578947368421
# Human Similarity:  8.11
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  planet
# Word2:  space
# System Similarity:  0.5333333333333333
# WordNet Similarity:  0.5333333333333333
# Human Similarity:  7.92
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  planet
# Word2:  astronomer
# System Similarity:  0.7368421052631579
# WordNet Similarity:  0.631578947368421
# Human Similarity:  7.94
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  precedent
# Word2:  example
# System Similarity:  0.7692307692307693
# WordNet Similarity:  0.9230769230769231
# Human Similarity:  5.85
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  precedent
# Word2:  information
# System Similarity:  0.7272727272727273
# WordNet Similarity:  0.8333333333333334
# Human Similarity:  3.85
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  precedent
# Word2:  cognition
# System Similarity:  0.5454545454545454
# WordNet Similarity:  0.7272727272727273
# Human Similarity:  2.81
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  precedent
# Word2:  law
# System Similarity:  0.7272727272727273
# WordNet Similarity:  0.9090909090909091
# Human Similarity:  6.65
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  precedent
# Word2:  collection
# System Similarity:  0.6666666666666666
# WordNet Similarity:  0.8
# Human Similarity:  2.50
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  precedent
# Word2:  group
# System Similarity:  0.4444444444444444
# WordNet Similarity:  0.6666666666666666
# Human Similarity:  1.77
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  precedent
# Word2:  antecedent
# System Similarity:  0.6153846153846154
# WordNet Similarity:  0.6153846153846154
# Human Similarity:  6.04
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  cup
# Word2:  coffee
# System Similarity:  0.7619047619047619
# WordNet Similarity:  0.7619047619047619
# Human Similarity:  6.58
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  cup
# Word2:  tableware
# System Similarity:  0.625
# WordNet Similarity:  0.8888888888888888
# Human Similarity:  6.85
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  cup
# Word2:  article
# System Similarity:  0.7142857142857143
# WordNet Similarity:  0.75
# Human Similarity:  2.40
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  cup
# Word2:  artifact
# System Similarity:  0.6153846153846154
# WordNet Similarity:  0.7692307692307693
# Human Similarity:  2.92
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  cup
# Word2:  object
# System Similarity:  0.36363636363636365
# WordNet Similarity:  0.5454545454545454
# Human Similarity:  3.69
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  cup
# Word2:  entity
# System Similarity:  0
# WordNet Similarity:  0.4
# Human Similarity:  2.15
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  cup
# Word2:  drink
# System Similarity:  0.6153846153846154
# WordNet Similarity:  0.8
# Human Similarity:  7.25
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  cup
# Word2:  food
# System Similarity:  0.47058823529411764
# WordNet Similarity:  0.6666666666666666
# Human Similarity:  5.00
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  cup
# Word2:  substance
# System Similarity:  0.5
# WordNet Similarity:  0.5714285714285714
# Human Similarity:  1.92
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  cup
# Word2:  liquid
# System Similarity:  0.631578947368421
# WordNet Similarity:  0.7368421052631579
# Human Similarity:  5.90
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  jaguar
# Word2:  cat
# System Similarity:  0.896551724137931
# WordNet Similarity:  0.9655172413793104
# Human Similarity:  7.42
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  jaguar
# Word2:  car
# System Similarity:  0.32
# WordNet Similarity:  0.3333333333333333
# Human Similarity:  7.27
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  energy
# Word2:  secretary
# System Similarity:  0.23529411764705882
# WordNet Similarity:  0.2857142857142857
# Human Similarity:  1.81
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  secretary
# Word2:  senate
# System Similarity:  0.1111111111111111
# WordNet Similarity:  0.13333333333333333
# Human Similarity:  5.06
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  energy
# Word2:  laboratory
# System Similarity:  0.3076923076923077
# WordNet Similarity:  0.3076923076923077
# Human Similarity:  5.09
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  computer
# Word2:  laboratory
# System Similarity:  0.4
# WordNet Similarity:  0.42857142857142855
# Human Similarity:  6.78
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  weapon
# Word2:  secret
# System Similarity:  0.2857142857142857
# WordNet Similarity:  0.2857142857142857
# Human Similarity:  6.06
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  FBI
# Word2:  fingerprint
# System Similarity:  0.23529411764705882
# WordNet Similarity:  0.25
# Human Similarity:  6.94
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  FBI
# Word2:  investigation
# System Similarity:  0.2222222222222222
# WordNet Similarity:  0.2222222222222222
# Human Similarity:  8.31
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  investigation
# Word2:  effort
# System Similarity:  0.8235294117647058
# WordNet Similarity:  0.8235294117647058
# Human Similarity:  4.59
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  Mars
# Word2:  water
# System Similarity:  0.3333333333333333
# WordNet Similarity:  0.5
# Human Similarity:  2.94
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  Mars
# Word2:  scientist
# System Similarity:  0.14285714285714285
# WordNet Similarity:  0.47058823529411764
# Human Similarity:  5.63
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  news
# Word2:  report
# System Similarity:  0.9230769230769231
# WordNet Similarity:  0.9230769230769231
# Human Similarity:  8.16
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  canyon
# Word2:  landscape
# System Similarity:  0.35294117647058826
# WordNet Similarity:  0.35294117647058826
# Human Similarity:  7.53
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  image
# Word2:  surface
# System Similarity:  0.7142857142857143
# WordNet Similarity:  0.7142857142857143
# Human Similarity:  4.56
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  discovery
# Word2:  space
# System Similarity:  0.4
# WordNet Similarity:  0.4
# Human Similarity:  6.34
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  water
# Word2:  seepage
# System Similarity:  0.15384615384615385
# WordNet Similarity:  0.25
# Human Similarity:  6.56
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  sign
# Word2:  recess
# System Similarity:  0.75
# WordNet Similarity:  0.75
# Human Similarity:  2.38
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  Wednesday
# Word2:  news
# System Similarity:  0.26666666666666666
# WordNet Similarity:  0.26666666666666666
# Human Similarity:  2.22
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  mile
# Word2:  kilometer
# System Similarity:  0.8
# WordNet Similarity:  0.8
# Human Similarity:  8.66
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  computer
# Word2:  news
# System Similarity:  0.13333333333333333
# WordNet Similarity:  0.16666666666666666
# Human Similarity:  4.47
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  territory
# Word2:  surface
# System Similarity:  0.6153846153846154
# WordNet Similarity:  0.6153846153846154
# Human Similarity:  5.34
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  atmosphere
# Word2:  landscape
# System Similarity:  0.5
# WordNet Similarity:  0.5
# Human Similarity:  3.69
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  president
# Word2:  medal
# System Similarity:  0.23529411764705882
# WordNet Similarity:  0.23529411764705882
# Human Similarity:  3.00
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  war
# Word2:  troops
# System Similarity:  0.3076923076923077
# WordNet Similarity:  0.3076923076923077
# Human Similarity:  8.13
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  record
# Word2:  number
# System Similarity:  0.7272727272727273
# WordNet Similarity:  0.9090909090909091
# Human Similarity:  6.31
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  skin
# Word2:  eye
# System Similarity:  0.6666666666666666
# WordNet Similarity:  0.6666666666666666
# Human Similarity:  6.22
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  Japanese
# Word2:  American
# System Similarity:  0.8421052631578947
# WordNet Similarity:  0.631578947368421
# Human Similarity:  6.50
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  theater
# Word2:  history
# System Similarity:  0.5
# WordNet Similarity:  0.5
# Human Similarity:  3.91
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  volunteer
# Word2:  motto
# System Similarity:  0.125
# WordNet Similarity:  0.2
# Human Similarity:  2.56
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  prejudice
# Word2:  recognition
# System Similarity:  0.6666666666666666
# WordNet Similarity:  0.6666666666666666
# Human Similarity:  3.00
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  decoration
# Word2:  valor
# System Similarity:  0.26666666666666666
# WordNet Similarity:  0.26666666666666666
# Human Similarity:  5.63
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  century
# Word2:  year
# System Similarity:  0.8333333333333334
# WordNet Similarity:  0.8333333333333334
# Human Similarity:  7.59
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  century
# Word2:  nation
# System Similarity:  0.36363636363636365
# WordNet Similarity:  0.36363636363636365
# Human Similarity:  3.16
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  delay
# Word2:  racism
# System Similarity:  0.625
# WordNet Similarity:  0.625
# Human Similarity:  1.19
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  delay
# Word2:  news
# System Similarity:  0.5333333333333333
# WordNet Similarity:  0.5333333333333333
# Human Similarity:  3.31
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  minister
# Word2:  party
# System Similarity:  0.7368421052631579
# WordNet Similarity:  0.631578947368421
# Human Similarity:  6.63
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  peace
# Word2:  plan
# System Similarity:  0.3076923076923077
# WordNet Similarity:  0.3076923076923077
# Human Similarity:  4.75
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  minority
# Word2:  peace
# System Similarity:  0.5714285714285714
# WordNet Similarity:  0.6153846153846154
# Human Similarity:  3.69
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  attempt
# Word2:  peace
# System Similarity:  0.3076923076923077
# WordNet Similarity:  0.3076923076923077
# Human Similarity:  4.25
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  government
# Word2:  crisis
# System Similarity:  0.5333333333333333
# WordNet Similarity:  0.5714285714285714
# Human Similarity:  6.56
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  deployment
# Word2:  departure
# System Similarity:  0.7142857142857143
# WordNet Similarity:  0.7142857142857143
# Human Similarity:  4.25
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  deployment
# Word2:  withdrawal
# System Similarity:  0.7777777777777778
# WordNet Similarity:  0.7777777777777778
# Human Similarity:  5.88
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  energy
# Word2:  crisis
# System Similarity:  0.625
# WordNet Similarity:  0.625
# Human Similarity:  5.94
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  announcement
# Word2:  news
# System Similarity:  0.6666666666666666
# WordNet Similarity:  0.6666666666666666
# Human Similarity:  7.56
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  announcement
# Word2:  effort
# System Similarity:  0.3076923076923077
# WordNet Similarity:  0.3076923076923077
# Human Similarity:  2.75
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  stroke
# Word2:  hospital
# System Similarity:  0.2857142857142857
# WordNet Similarity:  0.4
# Human Similarity:  7.03
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  disability
# Word2:  death
# System Similarity:  0.5333333333333333
# WordNet Similarity:  0.5333333333333333
# Human Similarity:  5.47
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  victim
# Word2:  emergency
# System Similarity:  0.2222222222222222
# WordNet Similarity:  0.4444444444444444
# Human Similarity:  6.47
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  treatment
# Word2:  recovery
# System Similarity:  0.7692307692307693
# WordNet Similarity:  0.7692307692307693
# Human Similarity:  7.91
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  journal
# Word2:  association
# System Similarity:  0.4
# WordNet Similarity:  0.4
# Human Similarity:  4.97
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  doctor
# Word2:  personnel
# System Similarity:  0.26666666666666666
# WordNet Similarity:  0.26666666666666666
# Human Similarity:  5.00
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  doctor
# Word2:  liability
# System Similarity:  0.26666666666666666
# WordNet Similarity:  0.26666666666666666
# Human Similarity:  5.19
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  liability
# Word2:  insurance
# System Similarity:  0.625
# WordNet Similarity:  0.625
# Human Similarity:  7.03
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  school
# Word2:  center
# System Similarity:  0.875
# WordNet Similarity:  0.875
# Human Similarity:  3.44
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  reason
# Word2:  hypertension
# System Similarity:  0.5555555555555556
# WordNet Similarity:  0.5555555555555556
# Human Similarity:  2.31
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  reason
# Word2:  criterion
# System Similarity:  0.5333333333333333
# WordNet Similarity:  0.5333333333333333
# Human Similarity:  5.91
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  hundred
# Word2:  percent
# System Similarity:  0.25
# WordNet Similarity:  0.25
# Human Similarity:  7.38
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  Harvard
# Word2:  Yale
# System Similarity:  0
# WordNet Similarity:  0.9166666666666666
# Human Similarity:  8.13
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  hospital
# Word2:  infrastructure
# System Similarity:  0.26666666666666666
# WordNet Similarity:  0.26666666666666666
# Human Similarity:  4.63
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  death
# Word2:  row
# System Similarity:  0.5
# WordNet Similarity:  0.5
# Human Similarity:  5.25
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  death
# Word2:  inmate
# System Similarity:  0.23529411764705882
# WordNet Similarity:  0.2857142857142857
# Human Similarity:  5.03
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  lawyer
# Word2:  evidence
# System Similarity:  0.13333333333333333
# WordNet Similarity:  0.16666666666666666
# Human Similarity:  6.69
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  life
# Word2:  death
# ...
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  seven
# Word2:  series
# System Similarity:  0.375
# WordNet Similarity:  0.375
# Human Similarity:  3.56
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  seafood
# Word2:  sea
# System Similarity:  0.36363636363636365
# WordNet Similarity:  0.36363636363636365
# Human Similarity:  7.47
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  seafood
# Word2:  food
# System Similarity:  0.7272727272727273
# WordNet Similarity:  0.9090909090909091
# Human Similarity:  8.34
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  seafood
# Word2:  lobster
# System Similarity:  0.8571428571428571
# WordNet Similarity:  0.8571428571428571
# Human Similarity:  8.70
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  lobster
# Word2:  food
# System Similarity:  0.6153846153846154
# WordNet Similarity:  0.7692307692307693
# Human Similarity:  7.81
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  lobster
# Word2:  wine
# System Similarity:  0.3333333333333333
# WordNet Similarity:  0.375
# Human Similarity:  5.70
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  food
# Word2:  preparation
# System Similarity:  0.5714285714285714
# WordNet Similarity:  0.5714285714285714
# Human Similarity:  6.22
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  video
# Word2:  archive
# System Similarity:  0.5555555555555556
# WordNet Similarity:  0.5555555555555556
# Human Similarity:  6.34
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  start
# Word2:  year
# System Similarity:  0.5454545454545454
# WordNet Similarity:  0.5454545454545454
# Human Similarity:  4.06
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  start
# Word2:  match
# System Similarity:  0.5714285714285714
# WordNet Similarity:  0.5714285714285714
# Human Similarity:  4.47
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  game
# Word2:  round
# System Similarity:  0.8888888888888888
# WordNet Similarity:  0.8888888888888888
# Human Similarity:  5.97
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  boxing
# Word2:  round
# System Similarity:  0.7272727272727273
# WordNet Similarity:  0.7272727272727273
# Human Similarity:  7.61
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  championship
# Word2:  tournament
# System Similarity:  0.8571428571428571
# WordNet Similarity:  0.8571428571428571
# Human Similarity:  8.36
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  fighting
# Word2:  defeating
# System Similarity:  0.2857142857142857
# WordNet Similarity:  0.5
# Human Similarity:  7.41
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  line
# Word2:  insurance
# System Similarity:  0.7142857142857143
# WordNet Similarity:  0.7142857142857143
# Human Similarity:  2.69
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  day
# Word2:  summer
# System Similarity:  0.7692307692307693
# WordNet Similarity:  0.7692307692307693
# Human Similarity:  3.94
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  summer
# Word2:  drought
# System Similarity:  0.7692307692307693
# WordNet Similarity:  0.7692307692307693
# Human Similarity:  7.16
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  summer
# Word2:  nature
# System Similarity:  0.3333333333333333
# WordNet Similarity:  0.3333333333333333
# Human Similarity:  5.63
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  day
# Word2:  dawn
# System Similarity:  0.8333333333333334
# WordNet Similarity:  0.8333333333333334
# Human Similarity:  7.53
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  nature
# Word2:  environment
# System Similarity:  0.5454545454545454
# WordNet Similarity:  0.5454545454545454
# Human Similarity:  8.31
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  environment
# Word2:  ecology
# System Similarity:  0.9230769230769231
# WordNet Similarity:  0.9230769230769231
# Human Similarity:  8.81
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  nature
# Word2:  man
# System Similarity:  0.5333333333333333
# WordNet Similarity:  0.6666666666666666
# Human Similarity:  6.25
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  man
# Word2:  woman
# System Similarity:  0.8888888888888888
# WordNet Similarity:  0.7058823529411765
# Human Similarity:  8.30
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  man
# Word2:  governor
# System Similarity:  0.7777777777777778
# WordNet Similarity:  0.6666666666666666
# Human Similarity:  5.25
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  murder
# Word2:  manslaughter
# System Similarity:  0.9166666666666666
# WordNet Similarity:  0.9166666666666666
# Human Similarity:  8.53
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  soap
# Word2:  opera
# System Similarity:  0.2222222222222222
# WordNet Similarity:  0.23529411764705882
# Human Similarity:  7.94
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  opera
# Word2:  performance
# System Similarity:  0.3076923076923077
# WordNet Similarity:  0.3076923076923077
# Human Similarity:  6.88
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  life
# Word2:  lesson
# System Similarity:  0.42857142857142855
# WordNet Similarity:  0.42857142857142855
# Human Similarity:  5.94
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  focus
# Word2:  life
# System Similarity:  0.5333333333333333
# WordNet Similarity:  0.5333333333333333
# Human Similarity:  4.06
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  production
# Word2:  crew
# System Similarity:  0.36363636363636365
# WordNet Similarity:  0.36363636363636365
# Human Similarity:  6.25
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  television
# Word2:  film
# System Similarity:  0.7777777777777778
# WordNet Similarity:  0.7777777777777778
# Human Similarity:  7.72
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  lover
# Word2:  quarrel
# System Similarity:  0.2
# WordNet Similarity:  0.4
# Human Similarity:  6.19
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  viewer
# Word2:  serial
# System Similarity:  0.5
# WordNet Similarity:  0.5
# Human Similarity:  2.97
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  possibility
# Word2:  girl
# System Similarity:  0.13333333333333333
# WordNet Similarity:  0.16666666666666666
# Human Similarity:  1.94
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  population
# Word2:  development
# System Similarity:  0.7272727272727273
# WordNet Similarity:  0.7272727272727273
# Human Similarity:  3.75
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  morality
# Word2:  importance
# System Similarity:  0.6666666666666666
# WordNet Similarity:  0.6666666666666666
# Human Similarity:  3.31
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  morality
# Word2:  marriage
# System Similarity:  0.5454545454545454
# WordNet Similarity:  0.5454545454545454
# Human Similarity:  3.69
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  Mexico
# Word2:  Brazil
# System Similarity:  0
# WordNet Similarity:  0.8
# Human Similarity:  7.44
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  gender
# Word2:  equality
# System Similarity:  0.46153846153846156
# WordNet Similarity:  0.46153846153846156
# Human Similarity:  6.41
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  change
# Word2:  attitude
# System Similarity:  0.5454545454545454
# WordNet Similarity:  0.5454545454545454
# Human Similarity:  5.44
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  family
# Word2:  planning
# System Similarity:  0.3076923076923077
# WordNet Similarity:  0.3076923076923077
# Human Similarity:  6.25
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  opera
# Word2:  industry
# System Similarity:  0.26666666666666666
# WordNet Similarity:  0.2857142857142857
# Human Similarity:  2.63
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  sugar
# Word2:  approach
# System Similarity:  0.26666666666666666
# WordNet Similarity:  0.2857142857142857
# Human Similarity:  0.88
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  practice
# Word2:  institution
# System Similarity:  0.8333333333333334
# WordNet Similarity:  0.8333333333333334
# Human Similarity:  3.19
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  ministry
# Word2:  culture
# System Similarity:  0.5333333333333333
# WordNet Similarity:  0.5333333333333333
# Human Similarity:  4.69
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  problem
# Word2:  challenge
# System Similarity:  0.6153846153846154
# WordNet Similarity:  0.6153846153846154
# Human Similarity:  6.75
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  size
# Word2:  prominence
# System Similarity:  0.6153846153846154
# WordNet Similarity:  0.6153846153846154
# Human Similarity:  5.31
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  country
# Word2:  citizen
# System Similarity:  0.26666666666666666
# WordNet Similarity:  0.42857142857142855
# Human Similarity:  7.31
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  planet
# Word2:  people
# System Similarity:  0.18181818181818182
# WordNet Similarity:  0.2
# Human Similarity:  5.75
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  development
# Word2:  issue
# System Similarity:  0.75
# WordNet Similarity:  0.75
# Human Similarity:  3.97
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  experience
# Word2:  music
# System Similarity:  0.6153846153846154
# WordNet Similarity:  0.6153846153846154
# Human Similarity:  3.47
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  music
# Word2:  project
# System Similarity:  0.8
# WordNet Similarity:  0.8
# Human Similarity:  3.63
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  glass
# Word2:  metal
# System Similarity:  0.5
# WordNet Similarity:  0.5454545454545454
# Human Similarity:  5.56
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  aluminum
# Word2:  metal
# System Similarity:  0.8
# WordNet Similarity:  0.9333333333333333
# Human Similarity:  7.83
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  chance
# Word2:  credibility
# System Similarity:  0.5
# WordNet Similarity:  0.5
# Human Similarity:  3.88
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  exhibit
# Word2:  memorabilia
# System Similarity:  0.42857142857142855
# WordNet Similarity:  0.42857142857142855
# Human Similarity:  5.31
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  concert
# Word2:  virtuoso
# System Similarity:  0.11764705882352941
# WordNet Similarity:  0.2857142857142857
# Human Similarity:  6.81
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  rock
# Word2:  jazz
# System Similarity:  0.875
# WordNet Similarity:  0.875
# Human Similarity:  7.59
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  museum
# Word2:  theater
# System Similarity:  0.625
# WordNet Similarity:  0.625
# Human Similarity:  7.19
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  observation
# Word2:  architecture
# System Similarity:  0.7058823529411765
# WordNet Similarity:  0.7058823529411765
# Human Similarity:  4.38
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  space
# Word2:  world
# System Similarity:  0.5714285714285714
# WordNet Similarity:  0.5714285714285714
# Human Similarity:  6.53
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  preservation
# Word2:  world
# System Similarity:  0.5882352941176471
# WordNet Similarity:  0.5882352941176471
# Human Similarity:  6.19
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  admission
# Word2:  ticket
# System Similarity:  0.5714285714285714
# WordNet Similarity:  0.5714285714285714
# Human Similarity:  7.69
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  shower
# Word2:  thunderstorm
# System Similarity:  0.7
# WordNet Similarity:  0.7
# Human Similarity:  6.31
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  shower
# Word2:  flood
# System Similarity:  0.6363636363636364
# WordNet Similarity:  0.6363636363636364
# Human Similarity:  6.03
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  weather
# Word2:  forecast
# System Similarity:  0.13333333333333333
# WordNet Similarity:  0.3333333333333333
# Human Similarity:  8.34
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  disaster
# Word2:  area
# System Similarity:  0.5
# WordNet Similarity:  0.5
# Human Similarity:  6.25
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  governor
# Word2:  office
# System Similarity:  0.5263157894736842
# WordNet Similarity:  0.5263157894736842
# Human Similarity:  6.34
# Similarity Type:  wu_palmer_similarity
# =============================
# =============================
# Word1:  architecture
# Word2:  century
# System Similarity:  0.3076923076923077
# WordNet Similarity:  0.3076923076923077
# Human Similarity:  3.78
# Similarity Type:  wu_palmer_similarity
# =============================
#
# Pearson Correlation:  [[1.         0.25475669]
#  [0.25475669 1.        ]]
#
# Spearman Correlation:  SpearmanrResult(correlation=0.30921768923908527, pvalue=2.9358160859019058e-09)

# %%
tokenizer = RegexpTokenizer(r'\w+')

INDEXES_NUM = 1000 #è il limite, partendo da 0, di sentence che possono essere testate relative al database SemCor
RANGE = 50 #è il numero di sentence che effettivamente verranno testate            

sentences_tag = semcor.tagged_sents() #lista di liste. Ogni lista rappresenta una sentence e ad ogni parola della sentence è associato un pos tag
sentences = semcor.sents() #lista di liste di parole. Ogni lista rappresenta una sentence
sentences_sem = semcor.tagged_sents(tag = "sem") #lista di liste. Ogni lista rappresenta una sentence e ad ogni parola della sentence è associato un synset gold


def main():
    checked = 0 #termini valutati correttamente
    evaluated = 0 #termini valutati
    index_evaluated = set() #insieme degli indici già valutati
    while(evaluated <= RANGE):
        while True: #fino a quando non trova una word che ha almeno un senso in wordnet   
            index = get_random_index(index_evaluated, INDEXES_NUM)
            word = get_random_noun(get_dictionary_tag(sentences_tag[index],sentences_sem[index]))
            if word:
                break
        print("====================")
        sentence = sentences[index]
        print("Parola da disambiguare: ",word)
        #all'algoritmo di lesk viene dato in input la word e l'insieme dei termini che formano la frase, uniti sottoforma di stringa
        best_sense = str(lesk_algorithm(word, ' '.join(word for word in sentence), word_type='NOUN'))
        print("Senso attribuito dall'algoritmo di Lesk: ",best_sense)
        target_lemma = get_synset_target_for_word_in_sentence(word,sentences_sem[index])
        print("Senso Target: ",target_lemma)
        best_sense_lemma = best_sense[8:len(best_sense)-2]
        if target_lemma:
            if best_sense_lemma in target_lemma:
             checked= checked + 1
        print("====================")
        evaluated += 1
        print("====================")
    
    print("Checked: ", checked)
    print("Evaluated: ",evaluated)
    print("Accuracy: ",checked/RANGE)
    
main()
# Out:
# ====================
# Parola da disambiguare:  years
# Frase:  Named by Mayor Wagner three years ago to head a committee that included James A. Farley , Bernard Gimbel and Clint Blume , Shea worked relentlessly .
# Contesto della frase:  {'james', 'wagner', 'include', 'bernard', 'blume', 'work', 'relentlessly', 'year', 'committee', 'ago', 'clint', 'head', 'farley', 'mayor', 'shea', 'named', 'gimbel'}
# max Signature:  {'white', 'eld', 'life', 'late', 'year', 'hasnt', 'brink', 'time', 'geezerhood', 'beard', 'age', 'sissy', 'slow'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('old_age.n.01')
# Senso Target:  Lemma('year.n.01.year')
# ====================
# ====================
# ====================
# Parola da disambiguare:  man
# Frase:  When a man is laid to rest , he is entitled to stay put .
# Contesto della frase:  {'entitle', 'man', 'lay', 'rest', 'stay'}
# max Signature:  {'man', 'human', 'word', 'refer', 'generic'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('man.n.03')
# Senso Target:  Lemma('homo.n.02.man')
# ====================
# ====================
# ====================
# Parola da disambiguare:  formation
# Frase:  When that failed , he enlisted Branch Rickey 's aid in the formation of a third major league , the Continental , with New York as the key franchise .
# Contesto della frase:  {'branch', 'aid', 'rickey', 'fail', 'third', 'enlist', 'continental', 'key', 'formation', 'franchise', 'league', 'major', 'york'}
# max Signature:  {'thing', 'defensive', 'arrangement', 'formation', 'plane', 'people', 'unit'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('formation.n.01')
# Senso Target:  Lemma('constitution.n.02.formation')
# ====================
# ====================
# ====================
# Parola da disambiguare:  sewing
# Frase:  writes : What makes my hands numb when sewing ?
# Contesto della frase:  {'write', 'hand', 'sew', 'numb'}
# max Signature:  {'sew', 'needle', 'work', 'thread', 'basket', 'needlework'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('sewing.n.02')
# Senso Target:  Lemma('sewing.n.01.sewing')
# ====================
# ====================
# ====================
# Parola da disambiguare:  speed
# Frase:  Toying with her field in the early stages , Garden Fresh was asked for top speed only in the stretch by Jockey Philip Grimm and won by a length and a half in 1.24 3 - 5 for the 7 furlongs .
# Contesto della frase:  {'toying', 'garden', 'top', 'stage', 'stretch', 'field', 'speed', 'win', 'furlong', 'half', 'jockey', 'early', 'length', 'fresh', 'philip', 'grimm'}
# max Signature:  {'speed', 'advance', 'gratify', 'project', 'rapid', 'rate'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('speed.n.02')
# Senso Target:  Lemma('speed.n.01.speed')
# ====================
# ====================
# ====================
# Parola da disambiguare:  golfing
# Frase:  The golfing fathers ruled in his favor .
# Contesto della frase:  {'golfing', 'rule', 'favor', 'father'}
# max Signature:  {'play', 'winter', 'golfing', 'golf', 'south'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('golfing.n.01')
# Senso Target:  Lemma('golfing.n.01.golfing')
# ====================
# ====================
# ====================
# Parola da disambiguare:  roster
# Frase:  Moritz is listed on the Longhorn roster as a right halfback , the position at which he lettered on the 1956 team .
# Contesto della frase:  {'roster', 'team', 'longhorn', 'halfback', 'letter', 'list', 'position', 'moritz'}
# max Signature:  {'strike', 'roll', 'list'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('roll.n.02')
# Senso Target:  Lemma('roll.n.02.roster')
# ====================
# ====================
# ====================
# Parola da disambiguare:  portion
# Frase:  Nevertheless , `` we feel that in the future Fulton County should receive some portion of these available funds '' , the jurors said .
# Contesto della frase:  {'future', 'fund', 'receive', 'fulton', 'juror', 'portion', 'county', 'feel'}
# max Signature:  {'determine', 'read', 'small', 'reach', 'include', 'animal', 'hard', 'plankton', 'manuscript', 'component', 'portion', 'relation', 'constituent', 'big', 'feel'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('part.n.01')
# Senso Target:  Lemma('parcel.n.02.portion')
# ====================
# ====================
# ====================
# Parola da disambiguare:  management
# Frase:  The last couple of years the Bears management got the business from the `` Living Room Athletic Club '' when games were cut off .
# Contesto della frase:  {'club', 'year', 'living', 'bears', 'athletic', 'couple', 'game', 'room', 'management', 'business', 'cut'}
# max Signature:  {'program', 'government', 'function', 'economy', 'manage', 'management', 'direction'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('management.n.01')
# Senso Target:  Lemma('management.n.02.management')
# ====================
# ====================
# ====================
# Parola da disambiguare:  tomorrow
# Frase:  Bobby Waters of Sylvania , Ga. , relief quarterback for the San Francisco 49ers of the National Football League , will undergo a knee operation tomorrow at Franklin Hospital here .
# Contesto della frase:  {'francisco', 'operation', 'ga', 'waters', 'san', 'sylvania', 'knee', 'hospital', 'undergo', 'football', 'tomorrow', 'league', 'national', 'relief', 'quarterback', 'franklin', 'bobby'}
# max Signature:  {'day', 'tomorrow', 'today', 'task'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('tomorrow.n.01')
# Senso Target:  Lemma('tomorrow.n.01.tomorrow')
# ====================
# ====================
# ====================
# Parola da disambiguare:  Brooklyn
# Frase:  Bobby Lowe of Boston was the first to hit four at home and Gil Hodges turned the trick in Brooklyn 's Ebbetts Field .
# Contesto della frase:  {'gil', 'trick', 'boston', 'turn', 'brooklyn', 'hodges', 'ebbetts', 'lowe', 'field', 'hit', 'bobby'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('brooklyn.n.01')
# Senso Target:  Lemma('brooklyn.n.01.Brooklyn')
# ====================
# ====================
# ====================
# Parola da disambiguare:  song
# Frase:  There was about that song something incandescent , for this Brahms was Milstein at white heat .
# Contesto della frase:  {'incandescent', 'song', 'milstein', 'heat', 'white', 'brahms'}
# max Signature:  {'musical', 'song', 'good', 'short', 'composition', 'word', 'successful'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('song.n.01')
# Senso Target:  Lemma('song.n.01.song')
# ====================
# ====================
# ====================
# Parola da disambiguare:  employment
# Frase:  The volume of ADC cases will decrease , Martin reported , when the community is able to deal effectively with two problems : Relatively limited skills and discrimination in employment because of color .
# Contesto della frase:  {'report', 'adc', 'case', 'deal', 'skill', 'problem', 'effectively', 'decrease', 'limited', 'color', 'community', 'martin', 'discrimination', 'employment', 'volume'}
# max Signature:  {'employ', 'job', 'city', 'employment'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('employment.n.01')
# Senso Target:  Lemma('employment.n.03.employment')
# ====================
# ====================
# ====================
# Parola da disambiguare:  team
# Frase:  The owners would like each club in the fourteen team league to play a home and home series with teams in its division , plus two games against teams in the other division .
# Contesto della frase:  {'owner', 'play', 'club', 'team', 'division', 'fourteen', 'game', 'league', 'series'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('team.n.01')
# Senso Target:  Lemma('team.n.01.team')
# ====================
# ====================
# ====================
# Parola da disambiguare:  ball
# Frase:  He was called upon 26 times - more than all of the other ball carriers combined - and delivered 145 yards .
# Contesto della frase:  {'ball', 'time', 'carrier', 'deliver', 'yard', 'combine', 'call'}
# max Signature:  {'ball', 'kick', 'roll', 'object', 'pocket', 'corner', 'mph', 'travel', 'round', 'serve', 'game', 'mayor', 'throw', 'hit'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('ball.n.01')
# Senso Target:  Lemma('ball.n.01.ball')
# ====================
# ====================
# ====================
# Parola da disambiguare:  rules
# Frase:  Nor were there any rules to save him .
# Contesto della frase:  {'rule', 'save'}
# max Signature:  {'breakfast', 'principle', 'customarily', 'short', 'govern', 'condition', 'regulation', 'rule', 'haircut', 'walk', 'behavior'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('rule.n.01')
# Senso Target:  Lemma('rule.n.01.rule')
# ====================
# ====================
# ====================
# Parola da disambiguare:  calls
# Frase:  Ordinary Williams said he , too , was subjected to anonymous calls soon after he scheduled the election .
# Contesto della frase:  {'subject', 'ordinary', 'williams', 'schedule', 'anonymous', 'call', 'election'}
# max Signature:  {'telephone', 'report', 'connection', 'london', 'call', 'ring', 'didnt', 'hear', 'place', 'anonymous', 'phone'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('call.n.01')
# Senso Target:  Lemma('call.n.01.call')
# ====================
# ====================
# ====================
# Parola da disambiguare:  left
# Frase:  Alusik then moved Cooke across with a line drive to left .
# Contesto della frase:  {'leave', 'alusik', 'drive', 'cooke', 'move'}
# max Signature:  {'outfield', 'piece', 'catcher', 'leave', 'batter', 'flied', 'ground'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('left_field.n.01')
# Senso Target:  Lemma('left_field.n.01.left')
# ====================
# ====================
# ====================
# Parola da disambiguare:  slugger
# Frase:  The Major decided that , rather than be led , the slugger could lead .
# Contesto della frase:  {'lead', 'major', 'slugger', 'decide'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('batter.n.01')
# Senso Target:  Lemma('batter.n.01.slugger')
# ====================
# ====================
# ====================
# Parola da disambiguare:  patients
# Frase:  Several dentists and patients with special dental problems have experimented with the device .
# Contesto della frase:  {'dentist', 'problem', 'experiment', 'dental', 'patient', 'special', 'device'}
# max Signature:  {'care', 'require', 'person', 'grow', 'rapidly', 'medical', 'patient', 'number', 'emergency'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('patient.n.01')
# Senso Target:  Lemma('patient.n.01.patient')
# ====================
# ====================
# ====================
# Parola da disambiguare:  lefthanders
# Frase:  But there surely can be no doubt about the slender southpaw belonging with the all time great lefthanders in the game 's history .
# Contesto della frase:  {'history', 'southpaw', 'surely', 'slender', 'time', 'lefthander', 'game', 'doubt', 'belong', 'great'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('left-handed_pitcher.n.01')
# Senso Target:  Lemma('left-handed_pitcher.n.01.left-hander')
# ====================
# ====================
# ====================
# Parola da disambiguare:  second
# Frase:  Jim Gentile bounced a hard shot off Kunkel 's glove and beat it out for a single , and when Lumpe grabbed the ball and threw it over first baseman Throneberry 's head Brandt took third and Gentile second on the error .
# Contesto della frase:  {'lumpe', 'glove', 'grab', 'gentile', 'beat', 'head', 'brandt', 'jim', 'third', 'baseman', 'throw', 'hard', 'second', 'error', 'bounce', 'single', 'kunkel', 'ball', 'shot', 'throneberry'}
# max Signature:  {'infield', 'player', 'base', 'fielding', 'team', 'second', 'baseball', 'station', 'position'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('second_base.n.02')
# Senso Target:  Lemma('second_base.n.02.second')
# ====================
# ====================
# ====================
# Parola da disambiguare:  discontinuity
# Frase:  What is needed , Philip Morrison writes in The Cornell Daily Sun ( October 26 ) is a discontinuity .
# Contesto della frase:  {'daily', 'discontinuity', 'write', 'morrison', 'cornell', 'philip', 'october', 'sun'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('discontinuity.n.01')
# Senso Target:  Lemma('discontinuity.n.01.discontinuity')
# ====================
# ====================
# ====================
# Parola da disambiguare:  toy
# Frase:  If he snatches a toy , she says , `` Caroline wants her own truck just as you do '' .
# Contesto della frase:  {'caroline', 'truck', 'toy', 'snatch'}
# max Signature:  {'replica', 'nonfunctional', 'toy', 'frequently', 'modifier', 'stove'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('toy.n.02')
# Senso Target:  Lemma('plaything.n.01.toy')
# ====================
# ====================
# ====================
# Parola da disambiguare:  reflexes
# Frase:  Suddenly my reflexes are gone .
# Contesto della frase:  {'suddenly', 'reflex'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('reflex.n.01')
# Senso Target:  Lemma('reflex.n.01.reflex')
# ====================
# ====================
# ====================
# Parola da disambiguare:  Dallas
# Frase:  The Texans made themselves a comforting break on the opening kickoff when Denver 's Al Carmichael was jarred loose from the ball when Dave Grayson , the speedy halfback , hit him and Guard Al Reynolds claimed it for Dallas .
# Contesto della frase:  {'dave', 'break', 'jar', 'hit', 'reynolds', 'claim', 'texans', 'comfort', 'carmichael', 'halfback', 'denver', 'loose', 'al', 'kickoff', 'opening', 'ball', 'speedy', 'guard', 'grayson', 'dallas'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('dallas.n.01')
# Senso Target:  Lemma('dallas.n.01.Dallas')
# ====================
# ====================
# ====================
# Parola da disambiguare:  corporation
# Frase:  Allied Arts corporation first listed the Chicago dates as Dec. 4 thru 10 .
# Contesto della frase:  {'arts', 'corporation', 'chicago', 'allied', 'dec', 'list'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('corporation.n.01')
# Senso Target:  Lemma('corporation.n.01.corporation')
# ====================
# ====================
# ====================
# Parola da disambiguare:  vein
# Frase:  In a brighter nautical vein is Ile de France blue .
# Contesto della frase:  {'vein', 'blue', 'ile', 'nautical', 'brighter', 'france'}
# max Signature:  {'carry', 'vein', 'heart', 'capillary', 'blood', 'pulmonary', 'vessel', 'unaerated'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('vein.n.01')
# Senso Target:  Lemma('vein.n.02.vein')
# ====================
# ====================
# ====================
# Parola da disambiguare:  hit
# Frase:  Unfortunately , Brooks ' teammates were not in such festive mood as the Orioles expired before the seven hit pitching of three Kansas City rookie hurlers .
# Contesto della frase:  {'expire', 'city', 'hurler', 'pitching', 'brooks', 'kansas', 'teammate', 'rookie', 'mood', 'orioles', 'festive', 'hit'}
# max Signature:  {'williams', 'athletic', 'baseball', 'stroke', 'successful', 'contest', 'hit'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('hit.n.01')
# Senso Target:  Lemma('hit.n.01.hit')
# ====================
# ====================
# ====================
# Parola da disambiguare:  kind
# Frase:  It got the kind of scrambled , coarsened performance that can happen to best of orchestras when the man with the baton lacks technique and style .
# Contesto della frase:  {'technique', 'happen', 'baton', 'scrambled', 'best', 'man', 'coarsened', 'performance', 'kind', 'orchestra', 'lack', 'style'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('kind.n.01')
# Senso Target:  Lemma('kind.n.01.kind')
# ====================
# ====================
# ====================
# Parola da disambiguare:  office
# Frase:  U Thant of course , will hold office until the spring of 1963 , when Mr. Hammarskjold 's term would have come to an end .
# Contesto della frase:  {'hammarskjold', 'hold', 'office', 'thant', 'course', 'term', 'spring'}
# max Signature:  {'candidate', 'advantage', 'hold', 'power', 'year', 'office', 'government', 'official', 'president', 'great'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('office.n.04')
# Senso Target:  Lemma('office.n.04.office')
# ====================
# ====================
# ====================
# Parola da disambiguare:  toss
# Frase:  Lumpe worked a walk as the first batter to face Hyde and romped around as Siebern blasted Hyde 's next toss 415 feet over the scoreboard in right center .
# Contesto della frase:  {'siebern', 'lumpe', 'blast', 'toss', 'hyde', 'work', 'center', 'batter', 'walk', 'romp', 'scoreboard', 'face', 'foot'}
# max Signature:  {'movement', 'toss', 'abrupt', 'head'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('toss.n.03')
# Senso Target:  Lemma('pass.n.15.toss')
# ====================
# ====================
# ====================
# Parola da disambiguare:  degree
# Frase:  He also received a Master of Science degree from Texas A+I College and a Bachelor of Science degree from Southwestern State College , Weatherford , Okla. .
# Contesto della frase:  {'college', 'bachelor', 'weatherford', 'master', 'ai', 'receive', 'southwestern', 'texas', 'okla', 'science', 'degree'}
# max Signature:  {'remarkable', 'frankness', 'stage', 'continuum', 'degree', 'social', 'identifiable', 'process', 'position', 'specific', 'science', 'series'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('degree.n.02')
# Senso Target:  Lemma('academic_degree.n.01.degree')
# ====================
# ====================
# ====================
# Parola da disambiguare:  chastisement
# Frase:  It is , in fact , a relatively mild chastisement of the dead .
# Contesto della frase:  {'fact', 'mild', 'dead', 'chastisement'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('castigation.n.02')
# Senso Target:  Lemma('castigation.n.02.chastisement')
# ====================
# ====================
# ====================
# Parola da disambiguare:  ball
# Frase:  Carey singled on a slow bouncing ball to short which Robinson cut across to field and threw wide to first .
# Contesto della frase:  {'bouncing', 'ball', 'robinson', 'short', 'field', 'carey', 'cut', 'wide', 'throw', 'single', 'slow'}
# max Signature:  {'ball', 'kick', 'roll', 'object', 'pocket', 'corner', 'mph', 'travel', 'round', 'serve', 'game', 'mayor', 'throw', 'hit'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('ball.n.01')
# Senso Target:  Lemma('ball.n.01.ball')
# ====================
# ====================
# ====================
# Parola da disambiguare:  season
# Frase:  An injury forced Skorich to quit after the 1948 season .
# Contesto della frase:  {'force', 'quit', 'injury', 'season', 'skorich'}
# max Signature:  {'period', 'mark', 'event', 'activity', 'field', 'year', 'ballet', 'forward', 'avocado', 'company', 'special', 'season', 'celebrate'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('season.n.01')
# Senso Target:  Lemma('season.n.01.season')
# ====================
# ====================
# ====================
# Parola da disambiguare:  performance
# Frase:  Mankowski , the ball-hawking defensive expert , was cited for his performance against Bradley in St. Louis U. 's nationally televised victory .
# Contesto della frase:  {'expert', 'mankowski', 'televise', 'defensive', 'ballhawking', 'nationally', 'victory', 'performance', 'louis', 'cite', 'bradley', 'st'}
# max Signature:  {'musical', 'play', 'testify', 'symphony', 'frequent', 'popularity', 'ten', 'performance', 'listen', 'entertainment', 'dramatic'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('performance.n.01')
# Senso Target:  Lemma('performance.n.03.performance')
# ====================
# ====================
# ====================
# Parola da disambiguare:  quarterback
# Frase:  `` Buster would solve that quarterback problem just as we head that way '' .
# Contesto della frase:  {'solve', 'buster', 'problem', 'head', 'quarterback'}
# max Signature:  {'football', 'person', 'play', 'quarterback'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('quarterback.n.01')
# Senso Target:  Lemma('quarterback.n.01.quarterback')
# ====================
# ====================
# ====================
# Parola da disambiguare:  year
# Frase:  A normal year 's work in college is 30 semester hours .
# Contesto della frase:  {'college', 'work', 'normal', 'year', 'semester', 'hour'}
# max Signature:  {'time', 'period', 'day', 'year'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('year.n.01')
# Senso Target:  year.n.2;1
# ====================
# ====================
# ====================
# Parola da disambiguare:  runs
# Frase:  The Birds got five hits and all three of their runs off Kunkel before Hartman took over in the top of the fourth .
# Contesto della frase:  {'kunkel', 'birds', 'top', 'fourth', 'hartman', 'hit'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('run.n.01')
# Senso Target:  Lemma('run.n.01.run')
# ====================
# ====================
# ====================
# Parola da disambiguare:  Saturday
# Frase:  A good feeling prevailed on the SMU coaching staff Monday , but attention quickly turned from Saturday 's victory to next week 's problem : Rice University .
# Contesto della frase:  {'saturday', 'attention', 'good', 'week', 'turn', 'prevail', 'problem', 'victory', 'coaching', 'monday', 'smu', 'feeling', 'university', 'rice', 'staff'}
# max Signature:  {'seventh', 'observe', 'day', 'christians', 'jews', 'week', 'sabbath'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('saturday.n.01')
# Senso Target:  Lemma('saturday.n.01.Saturday')
# ====================
# ====================
# ====================
# Parola da disambiguare:  hour
# Frase:  His proposal is opposed to that of Richard Nixon , Governor Rockefeller , past chairmen Strauss and McCone of the Atomic Energy Commission , Dr. Edward Teller and those others now enjoying their hour of triumph in the exacerbation of the cold war .
# Contesto della frase:  {'teller', 'proposal', 'enjoy', 'chairman', 'governor', 'atomic', 'hour', 'energy', 'edward', 'richard', 'rockefeller', 'commission', 'mccone', 'strauss', 'nixon', 'oppose', 'dr', 'war', 'triumph', 'cold', 'exacerbation'}
# max Signature:  {'job', 'period', 'day', 'time', 'hour', 'equal'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('hour.n.01')
# Senso Target:  Lemma('hour.n.02.hour')
# ====================
# ====================
# ====================
# Parola da disambiguare:  boys
# Frase:  The boys had a tremendous respect for each other 's ability .
# Contesto della frase:  {'tremendous', 'boy', 'respect', 'ability'}
# max Signature:  {'soldier', 'boy', 'person', 'male', 'night', 'youthful', 'uniform', 'brush', 'teeth', 'baby'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('male_child.n.01')
# Senso Target:  Lemma('male_child.n.01.boy')
# ====================
# ====================
# ====================
# Parola da disambiguare:  leadership
# Frase:  And what leadership a proud Mantle has given so far .
# Contesto della frase:  {'mantle', 'leadership'}
# max Signature:  {'inspire', 'activity', 'lead', 'team', 'leadership'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('leadership.n.01')
# Senso Target:  Lemma('leadership.n.01.leadership')
# ====================
# ====================
# ====================
# Parola da disambiguare:  brushing
# Frase:  It is conceivable that Broxodent could do a better job than ordinary brushing , especially in those who do not brush their teeth properly .
# Contesto della frase:  {'job', 'good', 'properly', 'ordinary', 'conceivable', 'brush', 'broxodent', 'teeth'}
# max Signature:  {'recommend', 'dentist', 'day', 'brush', 'teeth'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('brush.n.07')
# Senso Target:  Lemma('brush.n.07.brushing')
# ====================
# ====================
# ====================
# Parola da disambiguare:  creation
# Frase:  The third amended the enabling act for creation of the Lamar county Hospital District , for which a special constitutional amendment previously was adopted .
# Contesto della frase:  {'district', 'amendment', 'creation', 'third', 'lamar', 'amend', 'enabling', 'adopt', 'constitutional', 'special', 'hospital', 'county'}
# max Signature:  {'event', 'plan', 'creation', 'doom', 'failure', 'occur'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('creation.n.03')
# Senso Target:  Lemma('creation.n.01.creation')
# ====================
# ====================
# ====================
# Parola da disambiguare:  stage
# Frase:  `` How many is that , Jim '' ? asked Willie at one stage of his excavation project .
# Contesto della frase:  {'excavation', 'stage', 'jim', 'project', 'willie'}
# max Signature:  {'period', 'event', 'stage', 'distinct', 'reject', 'revise', 'time', 'idea', 'sequence', 'transitional'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('phase.n.01')
# Senso Target:  Lemma('phase.n.01.stage')
# ====================
# ====================
# ====================
# Parola da disambiguare:  race
# Frase:  Vandiver opened his race for governor in 1958 with a battle in the Legislature against the issuance of $ 50 million worth of additional rural roads bonds proposed by then Gov. Marvin Griffin .
# Contesto della frase:  {'open', 'vandiver', 'road', 'marvin', 'griffin', 'additional', 'race', 'governor', 'rural', 'bond', 'legislature', 'propose', 'battle', 'issuance', 'gov', 'worth'}
# max Signature:  {'competition', 'race', 'presidency'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('race.n.01')
# Senso Target:  Lemma('race.n.01.race')
# ====================
# ====================
# ====================
# Parola da disambiguare:  calendar
# Frase:  But if you keep a calendar of events , as we do , you noticed a conflict .
# Contesto della frase:  {'conflict', 'event', 'calendar', 'notice'}
# max Signature:  {'case', 'event', 'calendar', 'social', 'court', 'monday', 'list', 'register', 'appointment'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('calendar.n.02')
# Senso Target:  Lemma('calendar.n.02.calendar')
# ====================
# ====================
# ====================
# Parola da disambiguare:  team
# Frase:  We 'd be losing at halftime to a good team and Hartweger would say , ' Do n't worry , Coach - we 'll get 'em all right '' ' .
# Contesto della frase:  {'halftime', 'good', 'team', 'll', 'coach', 'hartweger', 'lose', 'nt', 'worry'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('team.n.01')
# Senso Target:  Lemma('team.n.01.team')
# ====================
# ====================
# ====================
# Parola da disambiguare:  scope
# Frase:  Perhaps the lesson we should take from these pages is that the welfare state in England still allows wild scope for all kinds of rugged eccentrics .
# Contesto della frase:  {'wild', 'eccentric', 'rugged', 'lesson', 'scope', 'england', 'welfare', 'kind', 'allow'}
# max Signature:  {'investigation', 'human', 'supersonic', 'area', 'compass', 'power', 'political', 'scope', 'operate', 'jet', 'range', 'municipal', 'great', 'reach', 'piano', 'article', 'ambit', 'voice', 'law', 'control', 'legislation', 'orbit'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('scope.n.01')
# Senso Target:  Lemma('scope.n.01.scope')
# ====================
# ====================
# Checked:  35
# Evaluated:  51
# Accuracy:  0.7

# %%
tokenizer = RegexpTokenizer(r'\w+')

EXECUTIONS = 10 #numero massimo di esecuzioni
INDEXES_NUM = 7000 #è il limite, partendo da 0, di sentence che possono essere testate relative al database SemCor
RANGE = 50 #è il numero di sentence che effettivamente verranno testate in ogni esecuzione        

sentences_tag = semcor.tagged_sents()
sentences = semcor.sents()
sentences_sem = semcor.tagged_sents(tag = "sem")


def main():
    accuracy_list = []
    for execution in range(1,EXECUTIONS + 1):
        checked = 0 #termini valutati correttamente
        evaluated = 0 #termini valutati
        index_evaluated = set() #insieme degli indici già valutati
        while(evaluated <= RANGE):
            while True: #fino a quando non trova una word che può essere presa in considerazione  
                index = get_random_index(index_evaluated, INDEXES_NUM)
                word = get_random_word(get_dictionary_tag(sentences_tag[index],sentences_sem[index]))
                if word:
                    break
            print("====================")
            sentence = sentences[index]
            print("Parola da disambiguare: ",word)
            #all'algoritmo di lesk viene dato in input la word e l'insieme dei termini che formano la frase, uniti sottoforma di stringa
            best_sense = str(lesk_algorithm(word, ' '.join(word for word in sentence), word_type='NOUN'))
            print("Senso attribuito dall'algoritmo di Lesk: ",best_sense)
            target_lemma = get_synset_target_for_word_in_sentence(word,sentences_sem[index])
            print("Senso Target: ",target_lemma)
            best_sense_lemma = best_sense[8:len(best_sense)-2]
            if target_lemma:
                if best_sense_lemma in target_lemma:
                 checked= checked + 1
            print("====================")
            evaluated += 1
            print("====================")
        
        print("Checked: ", checked)
        print("Evaluated: ",evaluated)
        accuracy = checked/RANGE
        print("Accuracy: ",accuracy)
        accuracy_list.append(accuracy)
    print()
    print("Esecuzioni: ",EXECUTIONS)
    print("Lista delle accuratezze: ", accuracy_list)
    print("Accuratezza media: ",mean(accuracy_list))
    
main()
# Out:
# ====================
# Parola da disambiguare:  flocculated
# Frase:  As shown in Figure 3 , the protoplasm of other fibers was pale , granular , or flocculated and invaded by phagocytes .
# Contesto della frase:  {'pale', 'invade', 'fiber', 'protoplasm', 'granular', 'flocculate', 'phagocyte', 'figure'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('flocculate.v.01')
# Senso Target:  Lemma('flocculate.v.01.flocculate')
# ====================
# ====================
# ====================
# Parola da disambiguare:  tested
# Frase:  All samples were tested by both the saline and albumin methods .
# Contesto della frase:  {'test', 'albumin', 'sample', 'saline', 'method'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('test.v.01')
# Senso Target:  Lemma('screen.v.01.test')
# ====================
# ====================
# ====================
# Parola da disambiguare:  13
# Frase:  The BOD of the effluent ranged from a minimum of 13 to a maximum of 47 mg / l .
# Contesto della frase:  {'bod', 'maximum', 'minimum', 'range', 'effluent'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('thirteen.n.01')
# Senso Target:  Lemma('thirteen.s.01.13')
# ====================
# ====================
# ====================
# Parola da disambiguare:  BW
# Frase:  this is why this approach to BW defense has not been given major attention .
# Contesto della frase:  {'attention', 'defense', 'approach', 'bw', 'major'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('biological_warfare.n.01')
# Senso Target:  Lemma('biological_warfare.n.01.BW')
# ====================
# ====================
# ====================
# Parola da disambiguare:  raw
# Frase:  The BOD of the raw sewage was typical of domestic sewage from a subdivision .
# Contesto della frase:  {'bod', 'sewage', 'raw', 'domestic', 'typical', 'subdivision'}
# max Signature:  {'raw', 'birthday', 'informal', 'altogether', 'nakedness', 'suit', 'term'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('raw.n.01')
# Senso Target:  Lemma('natural.s.07.raw')
# ====================
# ====================
# ====================
# Parola da disambiguare:  indoor
# Frase:  Also , perhaps , table-tennis and other indoor sports to keep them fit and contented .
# Contesto della frase:  {'content', 'indoor', 'fit', 'tabletennis', 'sport'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('indoor.a.01')
# Senso Target:  Lemma('indoor.a.01.indoor')
# ====================
# ====================
# ====================
# Parola da disambiguare:  aid
# Frase:  The professional organizations such as American Institute of Interior Designers , National Society of Interior Designers , Home Fashions League and various trade associations , can and do aid greatly in this work .
# Contesto della frase:  {'aid', 'professional', 'work', 'trade', 'designers', 'greatly', 'american', 'organization', 'association', 'interior', 'league', 'fashions', 'national', 'institute', 'society'}
# max Signature:  {'teach', 'visual', 'resource', 'aid'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('aid.n.01')
# Senso Target:  Lemma('help.v.01.aid')
# ====================
# ====================
# ====================
# Parola da disambiguare:  transports
# Frase:  The way in which it transports its pollen is not so perfect , either .
# Contesto della frase:  {'transport', 'pollen', 'perfect'}
# max Signature:  {'carry', 'music', 'emotion', 'perfect', 'charles', 'sweet', 'dickens', 'overwhelm', 'rapture', 'listen'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('ecstasy.n.01')
# Senso Target:  Lemma('transport.v.02.transport')
# ====================
# ====================
# ====================
# Parola da disambiguare:  independent
# Frase:  The Farm Credit Administration , an independent agency located within the Department of Agriculture , supervises and coordinates a cooperative credit system for agriculture .
# Contesto della frase:  {'credit', 'cooperative', 'farm', 'coordinate', 'agriculture', 'administration', 'system', 'department', 'independent', 'supervises', 'agency', 'locate'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('mugwump.n.02')
# Senso Target:  Lemma('independent.a.01.independent')
# ====================
# ====================
# ====================
# Parola da disambiguare:  coordinated
# Frase:  Capital flows must be coordinated with national needs and planning .
# Contesto della frase:  {'coordinate', 'capital', 'flow', 'national', 'planning'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('organize.v.04')
# Senso Target:  Lemma('align.v.04.coordinate')
# ====================
# ====================
# ====================
# Parola da disambiguare:  century
# Frase:  But there are also the commercial propagandists and the analysts - one dominated by money , the other by nineteenth century German scholarship .
# Contesto della frase:  {'propagandist', 'dominate', 'nineteenth', 'century', 'money', 'commercial', 'german', 'analyst', 'scholarship'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('century.n.01')
# Senso Target:  Lemma('century.n.01.century')
# ====================
# ====================
# ====================
# Parola da disambiguare:  changes
# Frase:  Weekly samples would make any changes more readily discernible than daily samples .
# Contesto della frase:  {'daily', 'sample', 'discernible', 'weekly', 'change'}
# max Signature:  {'event', 'pass', 'intend', 'phase', 'year', 'increase', 'sale', 'undergone', 'ago', 'storm', 'modification', 'worse', 'neighborhood', 'occur', 'visit', 'change'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('change.n.01')
# Senso Target:  Lemma('change.n.04.change')
# ====================
# ====================
# ====================
# Parola da disambiguare:  15
# Frase:  The sections were then washed with PBS for 15 - 30 minutes and mounted in buffered glycerine .
# Contesto della frase:  {'buffered', 'glycerine', 'wash', 'minute', 'pbs', 'mount'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('fifteen.n.01')
# Senso Target:  Lemma('fifteen.s.01.15')
# ====================
# ====================
# ====================
# Parola da disambiguare:  essentially
# Frase:  If the argument is accepted as essentially sound up to this point , it remains for us to consider whether the patient 's difficulties in orienting himself spatially and in locating objects in space with the sense of touch can be explained by his defective visual condition .
# Contesto della frase:  {'remain', 'essentially', 'visual', 'sense', 'orient', 'locate', 'consider', 'defective', 'object', 'patient', 'condition', 'space', 'touch', 'argument', 'sound', 'accept', 'point', 'difficulty', 'spatially', 'explain'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('basically.r.01')
# Senso Target:  Lemma('basically.r.01.essentially')
# ====================
# ====================
# ====================
# Parola da disambiguare:  releases
# Frase:  Howard Mitchell and the National Symphony perform in the first two releases , designed for grades one and two .
# Contesto della frase:  {'symphony', 'howard', 'mitchell', 'release', 'design', 'perform', 'national', 'grade'}
# max Signature:  {'london', 'merchandise', 'issue', 'symphony', 'film', 'showing', 'release', 'sale', 'record', 'public', 'orchestra'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('release.n.01')
# Senso Target:  Lemma('release.n.01.release')
# ====================
# ====================
# ====================
# Parola da disambiguare:  mm
# Frase:  Very recently , observations have been made at 8 - mm wave length with a reflector 22 meters in diameter with a resultant beam width of only about 2 ' ( Amenitskii , Noskova , and Salomonovich , 1960 ) .
# Contesto della frase:  {'mm', 'resultant', 'wave', 'amenitskii', 'length', 'diameter', 'beam', 'meter', 'observation', 'width', 'noskova', 'salomonovich', 'reflector'}
# max Signature:  {'length', 'meter', 'thousandth', 'metric', 'equal', 'unit'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('millimeter.n.01')
# Senso Target:  Lemma('millimeter.n.01.mm')
# ====================
# ====================
# ====================
# Parola da disambiguare:  sheer
# Frase:  He had a mean , unbroken sheer bastard in his outfit , and someone invented the name Trig for him .
# Contesto della frase:  {'outfit', 'bastard', 'invent', 'unbroken', 'sheer', 'trig'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('swerve.v.01')
# Senso Target:  Lemma('absolute.s.02.sheer')
# ====================
# ====================
# ====================
# Parola da disambiguare:  reaffirmed
# Frase:  Berry , Brailsford and Daly in 1931 and Nakamura in 1958 reaffirmed this .
# Contesto della frase:  {'nakamura', 'brailsford', 'reaffirm', 'berry', 'daly'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('reaffirm.v.01')
# Senso Target:  Lemma('reaffirm.v.01.reaffirm')
# ====================
# ====================
# ====================
# Parola da disambiguare:  antisera
# Frase:  Those antisera shown by immunoelectrophoresis to be of the `` broad spectrum '' type were selected for used in the present study .
# Contesto della frase:  {'study', 'antiserum', 'type', 'select', 'spectrum', 'immunoelectrophoresis', 'broad'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('antiserum.n.01')
# Senso Target:  Lemma('antiserum.n.01.antiserum')
# ====================
# ====================
# ====================
# Parola da disambiguare:  well-known
# Frase:  There is a well-known relationship between probability and entropy which states that * * f , where \q is the probability that state ( i.e. , volume for an ideal gas ) could be reached by chance alone .
# Contesto della frase:  {'gas', 'reach', 'probability', 'ideal', 'entropy', 'wellknown', 'volume', 'relationship', 'chance'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('well-known.s.01')
# Senso Target:  Lemma('well-known.s.01.well-known')
# ====================
# ====================
# ====================
# Parola da disambiguare:  day
# Frase:  The necessity of that day has long disappeared .
# Contesto della frase:  {'disappear', 'day', 'long', 'necessity'}
# max Signature:  {'axis', 'period', 'jupiter', 'planet', 'day', 'mars', 'time', 'rotation', 'long', 'complete'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('day.n.07')
# Senso Target:  Lemma('day.n.02.day')
# ====================
# ====================
# ====================
# Parola da disambiguare:  blend
# Frase:  One of the script 's big problems was how to blend pictures and music of the past with live performances by musicians of today .
# Contesto della frase:  {'blend', 'picture', 'music', 'musician', 'problem', 'live', 'performance', 'today', 'big', 'script'}
# max Signature:  {'portmanteau', 'blend', 'hotel', 'motel', 'fog', 'word', 'smoke', 'motor', 'smog', 'meaning', 'form', 'wellknown', 'brunch', 'combine', 'join'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('blend.n.02')
# Senso Target:  Lemma('blend.v.01.blend')
# ====================
# ====================
# ====================
# Parola da disambiguare:  three
# Frase:  The Flock added a pair of tallies in the third on three straight hits after two were out .
# Contesto della frase:  {'pair', 'third', 'hit', 'tally', 'flock', 'straight', 'add'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('three.n.01')
# Senso Target:  Lemma('three.s.01.three')
# ====================
# ====================
# ====================
# Parola da disambiguare:  vary
# Frase:  Second , for both sexes , the 21 transverse lines in the Onset Profile vary more in individual spread than those in the Completion Profile .
# Contesto della frase:  {'spread', 'onset', 'transverse', 'individual', 'completion', 'second', 'profile', 'sex', 'vary'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('change.v.03')
# Senso Target:  Lemma('deviate.v.02.vary')
# ====================
# ====================
# ====================
# Parola da disambiguare:  wondering
# Frase:  There is a pause in the merriment as your friends gaze at you , wondering why you are staring , open-mouthed in amazement .
# Contesto della frase:  {'merriment', 'wonder', 'pause', 'amazement', 'star', 'gaze', 'friend', 'openmouthed'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('wonder.v.01')
# Senso Target:  Lemma('wonder.v.01.wonder')
# ====================
# ====================
# ====================
# Parola da disambiguare:  spinning
# Frase:  He was sitting on top of a log which was spinning round and around in the water .
# Contesto della frase:  {'top', 'log', 'round', 'sit', 'spin', 'water'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('spinning.n.01')
# Senso Target:  Lemma('spin.v.02.spin')
# ====================
# ====================
# ====================
# Parola da disambiguare:  won
# Frase:  Toying with her field in the early stages , Garden Fresh was asked for top speed only in the stretch by Jockey Philip Grimm and won by a length and a half in 1.24 3 - 5 for the 7 furlongs .
# Contesto della frase:  {'toying', 'garden', 'top', 'stage', 'stretch', 'field', 'speed', 'win', 'furlong', 'half', 'jockey', 'early', 'length', 'fresh', 'philip', 'grimm'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('south_korean_won.n.01')
# Senso Target:  Lemma('win.v.01.win')
# ====================
# ====================
# ====================
# Parola da disambiguare:  pushes
# Frase:  He then pushes his seat into the air and the teacher guides it over .
# Contesto della frase:  {'push', 'guide', 'seat', 'teacher', 'air'}
# max Signature:  {'force', 'push', 'good', 'hard', 'order', 'apply', 'exercise', 'move', 'door'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('push.n.01')
# Senso Target:  Lemma('push.v.01.push')
# ====================
# ====================
# ====================
# Parola da disambiguare:  nigger
# Frase:  But a nigger .
# Contesto della frase:  {'nigger'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('nigger.n.01')
# Senso Target:  Lemma('nigger.n.01.nigger')
# ====================
# ====================
# ====================
# Parola da disambiguare:  Southern
# Frase:  Southern resentment has been over the method of its ending , the invasion , and Reconstruction ; their fears now are of miscegenation and Negro political control in many counties .
# Contesto della frase:  {'resentment', 'negro', 'miscegenation', 'political', 'control', 'reconstruction', 'fear', 'southern', 'invasion', 'method', 'county'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('southern.a.01')
# Senso Target:  Lemma('southern.a.01.southern')
# ====================
# ====================
# ====================
# Parola da disambiguare:  progressive
# Frase:  Consciousness is the factor that provides the progressive continuity to sensory impressions .
# Contesto della frase:  {'continuity', 'progressive', 'consciousness', 'sensory', 'impression', 'factor', 'provide'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('progressive.n.01')
# Senso Target:  Lemma('progressive.a.01.progressive')
# ====================
# ====================
# ====================
# Parola da disambiguare:  supported
# Frase:  This viewpoint is further supported by Verloop 's ( ' 48 ) demonstration of thickened bronchial artery and arteriolar muscular coats which are capable of acting as valves .
# Contesto della frase:  {'coat', 'viewpoint', 'artery', 'verloop', 'arteriolar', 'thickened', 'bronchial', 'valve', 'capable', 'muscular', 'demonstration', 'support'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('support.v.01')
# Senso Target:  Lemma('confirm.v.01.support')
# ====================
# ====================
# ====================
# Parola da disambiguare:  better
# Frase:  Our pitching is much better than it has shown '' .
# Contesto della frase:  {'pitching', 'good'}
# max Signature:  {'good', 'condition', 'superior', 'quality', 'change'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('better.n.01')
# Senso Target:  Lemma('better.a.01.better')
# ====================
# ====================
# ====================
# Parola da disambiguare:  resented
# Frase:  Mantle , it 's apparent , resented Casey Stengel 's attempts to push and prod him into the perfection the veteran manager saw as a thrilling possibility .
# Contesto della frase:  {'prod', 'push', 'possibility', 'attempt', 'stengel', 'veteran', 'casey', 'resent', 'perfection', 'manager', 'mantle', 'thrilling', 'apparent'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('resent.v.01')
# Senso Target:  Lemma('resent.v.01.resent')
# ====================
# ====================
# ====================
# Parola da disambiguare:  intimate
# Frase:  The furor was such that people who could not possibly have squirmed their way into the rehearsals were pretending that they were intimate with the whole affair and that it would be sensational .
# Contesto della frase:  {'rehearsal', 'pretend', 'intimate', 'sensational', 'furor', 'squirm', 'affair', 'people'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('confidant.n.01')
# Senso Target:  Lemma('intimate.s.01.intimate')
# ====================
# ====================
# ====================
# Parola da disambiguare:  contribution
# Frase:  About the Pro Arte 's contribution I am less happy .
# Contesto della frase:  {'pro', 'arte', 'contribution', 'happy'}
# max Signature:  {'play', 'work', 'person', 'advance', 'bring', 'share', 'project', 'contribution', 'result'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('contribution.n.01')
# Senso Target:  Lemma('contribution.n.01.contribution')
# ====================
# ====================
# ====================
# Parola da disambiguare:  stared
# Frase:  Wilson stared at her .
# Contesto della frase:  {'wilson', 'star'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('gaze.v.01')
# Senso Target:  Lemma('gaze.v.01.stare')
# ====================
# ====================
# ====================
# Parola da disambiguare:  lethal
# Frase:  The incubation period of infectious disease , plus a variable period of illness even before a lethal effect , render this weapon unsuitable for hand-to-hand encounter .
# Contesto della frase:  {'period', 'encounter', 'incubation', 'variable', 'render', 'weapon', 'infectious', 'handtohand', 'illness', 'unsuitable', 'disease', 'lethal'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('deadly.s.02')
# Senso Target:  Lemma('deadly.s.02.lethal')
# ====================
# ====================
# ====================
# Parola da disambiguare:  letterhead
# Frase:  Not only do these quacks assume impressive titles , but represent themselves as being associated with various scientific or impressive foundations - foundations which often have little more than a letterhead existence .
# Contesto della frase:  {'foundation', 'scientific', 'existence', 'represent', 'title', 'letterhead', 'assume', 'associate', 'impressive', 'quack'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('letterhead.n.01')
# Senso Target:  Lemma('letterhead.n.01.letterhead')
# ====================
# ====================
# ====================
# Parola da disambiguare:  special
# Frase:  A salad with greens and tomato is a popular and wonderfully healthful addition to a meal , but add an avocado and you have something really special .
# Contesto della frase:  {'healthful', 'popular', 'salad', 'special', 'wonderfully', 'meal', 'addition', 'avocado', 'green', 'tomato', 'add'}
# max Signature:  {'temporary', 'offering', 'advertising', 'pork', 'feature', 'chop', 'reduced', 'special', 'price'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('special.n.01')
# Senso Target:  Lemma('special.s.02.special')
# ====================
# ====================
# ====================
# Parola da disambiguare:  1
# Frase:  The pilot lagoon was located as shown in Figure 1 to serve the area just south of the existing housing area .
# Contesto della frase:  {'exist', 'pilot', 'south', 'serve', 'housing', 'figure', 'area', 'locate', 'lagoon'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('one.n.01')
# Senso Target:  Lemma('one.n.01.1')
# ====================
# ====================
# ====================
# Parola da disambiguare:  flux
# Frase:  It is sufficiently small compared with the surface temperature of the anode holder , to make the energy flux radiated from the environment toward the anode holder negligible within the accuracy of the present measurements .
# Contesto della frase:  {'negligible', 'temperature', 'small', 'surface', 'energy', 'anode', 'environment', 'holder', 'accuracy', 'measurement', 'compare', 'radiate', 'flux'}
# max Signature:  {'energy', 'surface', 'flow', 'particle', 'rate'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('flux.n.01')
# Senso Target:  Lemma('flux.n.02.flux')
# ====================
# ====================
# ====================
# Parola da disambiguare:  activity
# Frase:  As expected , most of the activity was found in Fraction * * f , with slight activity seen in Fraction 4 , - 1 .
# Contesto della frase:  {'find', 'activity', 'fraction', 'slight', 'expect'}
# max Signature:  {'activity', 'recreational', 'behavior', 'specific', 'avoid'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('activity.n.01')
# Senso Target:  Lemma('action.n.02.activity')
# ====================
# ====================
# ====================
# Parola da disambiguare:  won
# Frase:  Toying with her field in the early stages , Garden Fresh was asked for top speed only in the stretch by Jockey Philip Grimm and won by a length and a half in 1.24 3 - 5 for the 7 furlongs .
# Contesto della frase:  {'toying', 'garden', 'top', 'stage', 'stretch', 'field', 'speed', 'win', 'furlong', 'half', 'jockey', 'early', 'length', 'fresh', 'philip', 'grimm'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('south_korean_won.n.01')
# Senso Target:  Lemma('win.v.01.win')
# ====================
# ====================
# ====================
# Parola da disambiguare:  true
# Frase:  Rarer still is a Mr. America or Mr. Universe of true Herculean build .
# Contesto della frase:  {'rarer', 'universe', 'true', 'build', 'herculean', 'america'}
# max Signature:  {'alignment', 'true', 'property', 'proper', 'correct', 'possess'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('true.n.01')
# Senso Target:  true.s.00
# ====================
# ====================
# ====================
# Parola da disambiguare:  psychotherapy
# Frase:  It is believed that drug therapy and electroshock involve the former and psychotherapy the latter mechanism .
# Contesto della frase:  {'involve', 'electroshock', 'psychotherapy', 'mechanism', 'therapy', 'drug'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('psychotherapy.n.01')
# Senso Target:  Lemma('psychotherapy.n.01.psychotherapy')
# ====================
# ====================
# ====================
# Parola da disambiguare:  discovered
# Frase:  The reporters had not yet discovered that this was his hideaway .
# Contesto della frase:  {'discover', 'hideaway', 'reporter'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('detect.v.01')
# Senso Target:  Lemma('learn.v.02.discover')
# ====================
# ====================
# ====================
# Parola da disambiguare:  slovenly
# Frase:  `` But in such a slovenly condition '' .
# Contesto della frase:  {'slovenly', 'condition'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('frowsy.s.01')
# Senso Target:  Lemma('frowsy.s.01.slovenly')
# ====================
# ====================
# ====================
# Parola da disambiguare:  decidedly
# Frase:  The underlying assumption , of course , is that only sight and touch enable us , in any precise and fully dependable way , to locate objects in space beyond us , the other senses being decidedly inferior , if not totally inadequate , in this regard .
# Contesto della frase:  {'decidedly', 'fully', 'precise', 'object', 'totally', 'regard', 'enable', 'underlying', 'touch', 'inferior', 'dependable', 'inadequate', 'sens', 'space', 'course', 'locate', 'assumption', 'sight'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('decidedly.r.01')
# Senso Target:  Lemma('decidedly.r.01.decidedly')
# ====================
# ====================
# ====================
# Parola da disambiguare:  social
# Frase:  After all , social life in the group of the bees is by no means general , although it certainly is a striking feature .
# Contesto della frase:  {'striking', 'social', 'life', 'general', 'feature', 'bee', 'group'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('sociable.n.01')
# Senso Target:  Lemma('social.a.02.social')
# ====================
# ====================
# ====================
# Parola da disambiguare:  missing
# Frase:  A foot misplaced , a leg missing .
# Contesto della frase:  {'misplace', 'foot', 'leg'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('miss.v.01')
# Senso Target:  missing.s.00
# ====================
# ====================
# Checked:  22
# Evaluated:  51
# Accuracy:  0.44
# ====================
# Parola da disambiguare:  shared
# Frase:  The trio who shared the most-valuable honors were introduced by Bob Broeg , sports editor of the Post-Dispatch .
# Contesto della frase:  {'trio', 'postdispatch', 'share', 'introduce', 'broeg', 'editor', 'mostvaluable', 'bob', 'honor', 'sport'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('share.v.01')
# Senso Target:  Lemma('share.v.01.share')
# ====================
# ====================
# ====================
# Parola da disambiguare:  pupates
# Frase:  Each now makes a tough , papery cocoon and pupates .
# Contesto della frase:  {'tough', 'pupates', 'papery', 'cocoon'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('pupate.v.01')
# Senso Target:  Lemma('pupate.v.01.pupate')
# ====================
# ====================
# ====================
# Parola da disambiguare:  feeling
# Frase:  It casts a spell upon them so that they leave with a feeling of having been in the mysterious presence of an evil power .
# Contesto della frase:  {'mysterious', 'presence', 'power', 'leave', 'spell', 'feeling', 'cast', 'evil'}
# max Signature:  {'guilt', 'affective', 'dislike', 'terrible', 'emotional', 'feeling', 'mutual', 'euphoria', 'experiencing'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('feeling.n.01')
# Senso Target:  Lemma('impression.n.01.feeling')
# ====================
# ====================
# ====================
# Parola da disambiguare:  unquestionably
# Frase:  In doing so science has unquestionably cleared up widespread misconceptions , removed extraneous and illusory sources of fear , and dispelled many undesirable popular superstitions .
# Contesto della frase:  {'extraneous', 'popular', 'illusory', 'dispel', 'undesirable', 'clear', 'remove', 'misconception', 'source', 'widespread', 'fear', 'superstition', 'science', 'unquestionably'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('unquestionably.r.01')
# Senso Target:  Lemma('unquestionably.r.01.unquestionably')
# ====================
# ====================
# ====================
# Parola da disambiguare:  full
# Frase:  Later the Hurok office made it Dec. 8 thru 17 , a nice , long booking for the full repertory .
# Contesto della frase:  {'hurok', 'book', 'repertory', 'office', 'dec', 'nice', 'full', 'long'}
# max Signature:  {'fully', 'illuminate', 'time', 'full', 'moon'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('full_moon.n.01')
# Senso Target:  Lemma('entire.s.01.full')
# ====================
# ====================
# ====================
# Parola da disambiguare:  confused
# Frase:  For a moment the hall confused him .
# Contesto della frase:  {'confuse', 'hall', 'moment'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('confuse.v.01')
# Senso Target:  Lemma('confuse.v.02.confuse')
# ====================
# ====================
# ====================
# Parola da disambiguare:  time
# Frase:  0 time ?
# Contesto della frase:  {'time'}
# max Signature:  {'event', 'call', 'ten', 'clip', 'time', 'occasion', 'succeed', 'instance', 'single'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('time.n.01')
# Senso Target:  Lemma('time.n.01.time')
# ====================
# ====================
# ====================
# Parola da disambiguare:  meant
# Frase:  Every woman has had the experience of saying no when she meant yes , and saying yes when she meant no .
# Contesto della frase:  {'experience', 'woman'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('mean.v.01')
# Senso Target:  Lemma('mean.v.01.mean')
# ====================
# ====================
# ====================
# Parola da disambiguare:  watch
# Frase:  He could only watch with a sort of gentle dismay while his body did these quick , appalling , and efficient things .
# Contesto della frase:  {'body', 'gentle', 'thing', 'watch', 'quick', 'dismay', 'efficient', 'sort', 'appalling'}
# max Signature:  {'event', 'anticipated', 'watch', 'person', 'employ'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('lookout.n.01')
# Senso Target:  Lemma('watch.v.01.watch')
# ====================
# ====================
# ====================
# Parola da disambiguare:  inquisitive
# Frase:  `` Chicago and All That Jazz '' may have wound up satisfying neither the confirmed fan nor the inquisitive newcomer .
# Contesto della frase:  {'satisfy', 'inquisitive', 'jazz', 'wind', 'chicago', 'newcomer', 'confirmed', 'fan'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('inquisitive.s.01')
# Senso Target:  Lemma('inquisitive.s.01.inquisitive')
# ====================
# ====================
# ====================
# Parola da disambiguare:  averaged
# Frase:  The average volatile suspended solids in the effluent was 75 mg / l while MLSS averaged 170 mg / l volatile suspended solids .
# Contesto della frase:  {'average', 'solid', 'suspend', 'volatile', 'mlss', 'suspended', 'effluent'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('average.v.01')
# Senso Target:  Lemma('average.v.01.average')
# ====================
# ====================
# ====================
# Parola da disambiguare:  register
# Frase:  They visited the shipyards at Brest and Pierre had to sign the register , vouching for the integrity of the visiting foreigner .
# Contesto della frase:  {'foreigner', 'integrity', 'visiting', 'sign', 'vouch', 'shipyard', 'brest', 'pierre', 'register', 'visit'}
# max Signature:  {'cashbox', 'transaction', 'register', 'shop', 'bill', 'add', 'machine'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('cash_register.n.01')
# Senso Target:  Lemma('register.n.01.register')
# ====================
# ====================
# ====================
# Parola da disambiguare:  character
# Frase:  Pansies have character .
# Contesto della frase:  {'character', 'pansies'}
# max Signature:  {'imaginary', 'play', 'character', 'work', 'film', 'person', 'represent', 'fiction', 'novel', 'main', 'story'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('fictional_character.n.01')
# Senso Target:  Lemma('character.n.03.character')
# ====================
# ====================
# ====================
# Parola da disambiguare:  series
# Frase:  RCA Victor has an ambitious and useful project in a stereo series called `` Adventures in Music '' , which is an instructional record library for elementary schools .
# Contesto della frase:  {'elementary', 'rca', 'music', 'victor', 'adventures', 'stereo', 'record', 'school', 'ambitious', 'project', 'instructional', 'library', 'call', 'series'}
# max Signature:  {'happen', 'robbery', 'thing', 'bank', 'order', 'place', 'investigate', 'series'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('series.n.01')
# Senso Target:  Lemma('serial.n.01.series')
# ====================
# ====================
# ====================
# Parola da disambiguare:  inspection
# Frase:  An examination of some forty catalogs of schools offering courses in interior design , for the most part schools accredited by membership in the National Association of Schools of Art , and a further `` on the spot '' inspection of a number of schools , show their courses adhere pretty closely to the recommendations .
# Contesto della frase:  {'pretty', 'examination', 'accredit', 'forty', 'recommendation', 'catalog', 'design', 'number', 'closely', 'schools', 'membership', 'association', 'inspection', 'offer', 'art', 'school', 'spot', 'course', 'interior', 'adhere', 'national'}
# max Signature:  {'formal', 'examination', 'inspection', 'ready', 'review', 'elevator', 'wait', 'official', 'platoon', 'stand'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('inspection.n.01')
# Senso Target:  inspection.n.00
# ====================
# ====================
# ====================
# Parola da disambiguare:  certifies
# Frase:  A 5 - percent royalty is paid on any production during the period the contract is in effect ; if the Government certifies that production may be possible from the property , the royalty obligation continues for the 10 - year period usually specified in the contract or until the Government 's contribution is repaid with interest .
# Contesto della frase:  {'continue', 'period', 'interest', 'certifies', 'property', 'percent', 'repay', 'production', 'year', 'royalty', 'government', 'contract', 'contribution', 'pay', 'obligation'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('attest.v.01')
# Senso Target:  Lemma('license.v.01.certify')
# ====================
# ====================
# ====================
# Parola da disambiguare:  straight
# Frase:  It was Nischwitz ' third straight victory of the new season and ran the Grizzlies ' winning streak to four straight .
# Contesto della frase:  {'win', 'nischwitz', 'third', 'grizzlies', 'victory', 'season', 'straight', 'streak'}
# max Signature:  {'segment', 'straight', 'roadway', 'racecourse'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('straightaway.n.01')
# Senso Target:  Lemma('straight.s.01.straight')
# ====================
# ====================
# ====================
# Parola da disambiguare:  excess
# Frase:  This chlorine carbon tetrachloride solution was illuminated for a day following which the flask was resealed onto a vacuum system and the excess chlorine distilled off .
# Contesto della frase:  {'follow', 'reseal', 'illuminate', 'chlorine', 'solution', 'day', 'system', 'flask', 'distil', 'vacuum', 'carbon', 'excess'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('excess.n.01')
# Senso Target:  Lemma('excess.s.01.excess')
# ====================
# ====================
# ====================
# Parola da disambiguare:  slipping
# Frase:  Stevie was constantly slipping into the church .
# Contesto della frase:  {'constantly', 'stevie', 'church', 'slip'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('steal.v.02')
# Senso Target:  Lemma('steal.v.02.slip')
# ====================
# ====================
# ====================
# Parola da disambiguare:  loans
# Frase:  Commodity loans , operating capital loans , and facility loans .
# Contesto della frase:  {'loan', 'capital', 'facility', 'operate', 'commodity'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('loan.n.01')
# Senso Target:  Lemma('loan.n.01.loan')
# ====================
# ====================
# ====================
# Parola da disambiguare:  naive
# Frase:  The already faded pastel charms of the naive music itself vanish entirely in Fistoulari 's melodramatic contrasts between ultra vehement brute power and chilly , if suave , sentimentality .
# Contesto della frase:  {'ultra', 'contrast', 'music', 'vanish', 'brute', 'power', 'suave', 'vehement', 'faded', 'fistoulari', 'entirely', 'melodramatic', 'pastel', 'sentimentality', 'chilly', 'naive', 'charm'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('naive.a.01')
# Senso Target:  Lemma('naive.a.01.naive')
# ====================
# ====================
# ====================
# Parola da disambiguare:  knew
# Frase:  They made the world seem friendly somehow , though he knew it was not .
# Contesto della frase:  {'friendly'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('know.v.01')
# Senso Target:  Lemma('know.v.03.know')
# ====================
# ====================
# ====================
# Parola da disambiguare:  general
# Frase:  What can we do with the general T ?
# Contesto della frase:  {'general'}
# max Signature:  {'rank', 'general', 'high', 'officer'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('general.n.01')
# Senso Target:  Lemma('general.a.01.general')
# ====================
# ====================
# ====================
# Parola da disambiguare:  outclass
# Frase:  `` The Pirates showed they could outclass the field last year .
# Contesto della frase:  {'outclass', 'year', 'pirates', 'field'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('outclass.v.01')
# Senso Target:  Lemma('outclass.v.01.outclass')
# ====================
# ====================
# ====================
# Parola da disambiguare:  completely
# Frase:  When we say that a mythological mode of thought must be completely abandoned , we mean it must be abandoned as the sole or proper means for presenting the Christian understanding of existence .
# Contesto della frase:  {'existence', 'proper', 'completely', 'mythological', 'christian', 'thought', 'abandon', 'mode', 'understanding', 'sole'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('wholly.r.01')
# Senso Target:  Lemma('wholly.r.01.completely')
# ====================
# ====================
# ====================
# Parola da disambiguare:  function
# Frase:  In some neighborhood in the f-plane of any ordinary point of the graph , the function f is a single valued , continuous function .
# Contesto della frase:  {'ordinary', 'point', 'fplane', 'function', 'neighborhood', 'graph', 'single', 'continuous'}
# max Signature:  {'mathematical', 'element', 'domain', 'function', 'set', 'range', 'associate', 'relation', 'mathematics'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('function.n.01')
# Senso Target:  Lemma('function.n.01.function')
# ====================
# ====================
# ====================
# Parola da disambiguare:  avocado
# Frase:  Once you become an avocado fan , you will look forward to the season each year with eager anticipation .
# Contesto della frase:  {'anticipation', 'year', 'eager', 'forward', 'avocado', 'fan', 'season'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('avocado.n.01')
# Senso Target:  Lemma('avocado.n.01.avocado')
# ====================
# ====================
# ====================
# Parola da disambiguare:  bilateral
# Frase:  The body was that of a well developed , somewhat debilitated white man weighing 108 lb. There were bilateral pterygia and arcus senilis , and the mouth was edentulous .
# Contesto della frase:  {'body', 'develop', 'man', 'bilateral', 'pterygium', 'senilis', 'lb', 'mouth', 'arcus', 'well', 'edentulous', 'weigh', 'debilitated', 'white'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('bilateral.s.01')
# Senso Target:  Lemma('bilateral.s.01.bilateral')
# ====================
# ====================
# ====================
# Parola da disambiguare:  confirmed
# Frase:  The final step was a vote for a $ 230000 bond issue for the construction of a sewage system by the 1959 town meeting , later confirmed by a two-thirds vote at a special town meeting June 21 , 1960 .
# Contesto della frase:  {'sewage', 'issue', 'town', 'meeting', 'june', 'final', 'system', 'bond', 'step', 'twothirds', 'special', 'construction', 'vote', 'confirm'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('confirm.v.01')
# Senso Target:  Lemma('confirm.v.01.confirm')
# ====================
# ====================
# ====================
# Parola da disambiguare:  remove
# Frase:  She can remove all knick-knacks within reach .
# Contesto della frase:  {'reach', 'remove', 'knickknack'}
# max Signature:  {'separation', 'tragedy', 'imitate', 'figurative', 'distance', 'madness', 'remove', 'shakespearean', 'degree'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('remove.n.01')
# Senso Target:  Lemma('remove.v.01.remove')
# ====================
# ====================
# ====================
# Parola da disambiguare:  menarches
# Frase:  Accordingly , if epiphyseal diaphyseal fusion occurs in this phalanx near menarche , early and late menarches might have been forecast rather precisely at the time of Onset of ossification for the 18 girls with `` same schedule '' .
# Contesto della frase:  {'onset', 'girl', 'precisely', 'forecast', 'late', 'early', 'diaphyseal', 'time', 'schedule', 'menarche', 'epiphyseal', 'phalanx', 'ossification', 'fusion', 'occur'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('menarche.n.01')
# Senso Target:  Lemma('menarche.n.01.menarche')
# ====================
# ====================
# ====================
# Parola da disambiguare:  pistol
# Frase:  He ran for the sick room , found his pistol was broken , and threw it away .
# Contesto della frase:  {'find', 'pistol', 'break', 'room', 'throw', 'sick'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('pistol.n.01')
# Senso Target:  Lemma('pistol.n.01.pistol')
# ====================
# ====================
# ====================
# Parola da disambiguare:  holder
# Frase:  Rachel wore a smart hat and , because she had been warned recently about smoking , puffed at her cigarettes through a long ivory holder stained with lipstick .
# Contesto della frase:  {'rachel', 'wear', 'stain', 'puffed', 'holder', 'smart', 'cigarette', 'smoke', 'ivory', 'warn', 'long', 'hat', 'lipstick'}
# max Signature:  {'holder', 'hold', 'cigarette', 'umbrella', 'towel', 'device'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('holder.n.01')
# Senso Target:  Lemma('holder.n.01.holder')
# ====================
# ====================
# ====================
# Parola da disambiguare:  Outstanding
# Frase:  On the clock given him was the inscription , `` For Outstanding Contribution to Billiken Basketball , 1960 - 61 '' .
# Contesto della frase:  {'basketball', 'inscription', 'outstanding', 'billiken', 'clock', 'contribution'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('outstanding.s.01')
# Senso Target:  Lemma('outstanding.s.01.outstanding')
# ====================
# ====================
# ====================
# Parola da disambiguare:  led
# Frase:  The Major decided that , rather than be led , the slugger could lead .
# Contesto della frase:  {'lead', 'major', 'slugger', 'decide'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('light-emitting_diode.n.01')
# Senso Target:  Lemma('lead.v.01.lead')
# ====================
# ====================
# ====================
# Parola da disambiguare:  pliant
# Frase:  The teacher was a pliant fool .
# Contesto della frase:  {'teacher', 'fool', 'pliant'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('plastic.s.02')
# Senso Target:  Lemma('plastic.s.02.pliant')
# ====================
# ====================
# ====================
# Parola da disambiguare:  raising
# Frase:  Examination of the data in Table 1 , shows that a few samples contributed to raising the effluent BOD .
# Contesto della frase:  {'bod', 'examination', 'raise', 'sample', 'table', 'data', 'contribute', 'effluent'}
# max Signature:  {'raise', 'temperature', 'event', 'activity', 'volcanic', 'land', 'raising', 'upward', 'afternoon', 'elevation', 'result'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('elevation.n.01')
# Senso Target:  Lemma('raise.v.01.raise')
# ====================
# ====================
# ====================
# Parola da disambiguare:  hit
# Frase:  It was ruled a difficult chance and a hit .
# Contesto della frase:  {'difficult', 'rule', 'chance', 'hit'}
# max Signature:  {'williams', 'athletic', 'baseball', 'stroke', 'successful', 'contest', 'hit'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('hit.n.01')
# Senso Target:  Lemma('hit.n.01.hit')
# ====================
# ====================
# ====================
# Parola da disambiguare:  invariably
# Frase:  And his efforts to get a performance for his Gallant Muses invariably failed .
# Contesto della frase:  {'gallant', 'fail', 'performance', 'invariably', 'effort', 'muses'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('constantly.r.01')
# Senso Target:  Lemma('constantly.r.01.invariably')
# ====================
# ====================
# ====================
# Parola da disambiguare:  amounts
# Frase:  Our understanding of the solar system has taught us to replace our former elaborate rituals with the appropriate action which , in this case , amounts to doing nothing .
# Contesto della frase:  {'teach', 'action', 'case', 'elaborate', 'appropriate', 'system', 'replace', 'solar', 'amount', 'understanding', 'ritual'}
# max Signature:  {'borrow', 'sum', 'money', 'amount', 'quantity', 'large', 'cash', 'insufficient'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('sum.n.01')
# Senso Target:  Lemma('amount.v.01.amount')
# ====================
# ====================
# ====================
# Parola da disambiguare:  interesting
# Frase:  What is interesting is that his positive qualifications for the post were revealed only as a kind of tail to his candidacy .
# Contesto della frase:  {'positive', 'qualification', 'interest', 'tail', 'candidacy', 'kind', 'reveal', 'post'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('interest.v.01')
# Senso Target:  Lemma('interesting.a.01.interesting')
# ====================
# ====================
# ====================
# Parola da disambiguare:  man
# Frase:  For ' God had not rained ' , says the Scripture , before man was made , ' and there was no man to till the earth ' .
# Contesto della frase:  {'scripture', 'till', 'man', 'earth', 'rain', 'god'}
# max Signature:  {'man', 'human', 'word', 'refer', 'generic'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('man.n.03')
# Senso Target:  man.n.00
# ====================
# ====================
# ====================
# Parola da disambiguare:  inner
# Frase:  Although the inner functions of religion are not of direct significance in social organization , they have important indirect consequences .
# Contesto della frase:  {'inner', 'social', 'significance', 'organization', 'religion', 'direct', 'function', 'consequence', 'indirect'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('inner.s.01')
# Senso Target:  Lemma('inner.s.01.inner')
# ====================
# ====================
# ====================
# Parola da disambiguare:  toppled
# Frase:  Early equipment was very flimsy ; the smallest gusts of wind toppled poles , making communications impossible .
# Contesto della frase:  {'equipment', 'small', 'impossible', 'wind', 'pole', 'early', 'gust', 'toppled', 'communication', 'flimsy'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('tumble.v.01')
# Senso Target:  Lemma('tumble.v.01.topple')
# ====================
# ====================
# ====================
# Parola da disambiguare:  packed
# Frase:  Of course he did some exercising - he 's crazy about water skiing and swimming and this vigorous exercise in conjunction with the added food supplements packed pounds of solid muscle on his skinny frame .
# Contesto della frase:  {'vigorous', 'skinny', 'frame', 'conjunction', 'muscle', 'exercising', 'swimming', 'pack', 'solid', 'skiing', 'food', 'supplement', 'exercise', 'pound', 'course', 'water', 'add', 'crazy'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('pack.v.01')
# Senso Target:  Lemma('pack_on.v.01.pack_on')
# ====================
# ====================
# ====================
# Parola da disambiguare:  membership
# Frase:  That is in the continuance of the `` grandfather clauses '' in their membership requirements .
# Contesto della frase:  {'membership', 'requirement', 'grandfather', 'continuance', 'clause'}
# max Signature:  {'find', 'body', 'unemployed', 'rank', 'dissension', 'poll', 'membership', 'organization', 'member', 'group', 'join'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('membership.n.01')
# Senso Target:  Lemma('membership.n.02.membership')
# ====================
# ====================
# ====================
# Parola da disambiguare:  Andrena
# Frase:  Although Andrena is gregarious , so that we may find hundreds and hundreds of burrows together , we must still call it a solitary bee .
# ...
# Senso Target:  Lemma('separated.s.02.separated')
# ====================
# ====================
# ====================
# Parola da disambiguare:  background
# Frase:  As the background discussion indicated there were frequently expressed doubts that a government dominated by either party could fairly administer elections .
# Contesto della frase:  {'administer', 'discussion', 'dominate', 'background', 'indicate', 'fairly', 'frequently', 'express', 'party', 'government', 'doubt', 'election'}
# max Signature:  {'training', 'background', 'social', 'person', 'previous', 'lawyer', 'heritage', 'experience', 'sport'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('background.n.01')
# Senso Target:  Lemma('background.n.03.background')
# ====================
# ====================
# ====================
# Parola da disambiguare:  maintained
# Frase:  In type 3 , this general relationship is maintained peripherally but not centrally where the pulmonary vein follows a more independent path to the hilum as is the case throughout the lung in type 2 , .
# Contesto della frase:  {'follow', 'maintain', 'hilum', 'case', 'type', 'vein', 'lung', 'general', 'path', 'peripherally', 'independent', 'relationship', 'pulmonary', 'centrally'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('keep.v.01')
# Senso Target:  Lemma('keep.v.01.maintain')
# ====================
# ====================
# ====================
# Parola da disambiguare:  operative
# Frase:  The spirit of the Marine Corps was present and operative before any of the present members of it came into it .
# Contesto della frase:  {'spirit', 'corps', 'member', 'marine', 'operative'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('secret_agent.n.01')
# Senso Target:  Lemma('operative.a.01.operative')
# ====================
# ====================
# ====================
# Parola da disambiguare:  outdoors
# Frase:  He dressed , and sped outdoors .
# Contesto della frase:  {'speed', 'dress', 'outdoors'}
# max Signature:  {'open', 'hold', 'outdoors', 'concert', 'unconfined', 'air', 'camp'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('outdoors.n.01')
# Senso Target:  Lemma('outside.r.01.outdoors')
# ====================
# ====================
# ====================
# Parola da disambiguare:  Authorities
# Frase:  Authorities believe that many of the Doctor Frauds using these false health gadgets are still in business .
# Contesto della frase:  {'authorities', 'health', 'frauds', 'false', 'gadget', 'doctor', 'business'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('government.n.01')
# Senso Target:  Lemma('government.n.01.authorities')
# ====================
# ====================
# ====================
# Parola da disambiguare:  dissection
# Frase:  Instead they learn their dissection on the bulbs of plants .
# Contesto della frase:  {'bulb', 'learn', 'dissection', 'plant'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('dissection.n.01')
# Senso Target:  Lemma('dissection.n.01.dissection')
# ====================
# ====================
# ====================
# Parola da disambiguare:  running
# Frase:  With Skorich at the helm , the Eagles are expected to put more emphasis on running , rather than passing .
# Contesto della frase:  {'pass', 'emphasis', 'helm', 'eagles', 'skorich', 'expect'}
# max Signature:  {'ball', 'player', 'play', 'opposing', 'carry', 'defensive', 'team', 'attempt', 'emphasis', 'american', 'football', 'brace', 'coach', 'great'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('run.n.05')
# Senso Target:  Lemma('run.n.05.running')
# ====================
# ====================
# ====================
# Parola da disambiguare:  injury
# Frase:  ( 3 ) How can we be sure that his sense of touch was not profoundly disturbed by his head injury ?
# Contesto della frase:  {'injury', 'sense', 'touch', 'head', 'profoundly', 'disturb'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('injury.n.01')
# Senso Target:  Lemma('injury.n.01.injury')
# ====================
# ====================
# ====================
# Parola da disambiguare:  methodical
# Frase:  Payne was more methodical than that .
# Contesto della frase:  {'payne', 'methodical'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('methodical.s.01')
# Senso Target:  Lemma('methodical.s.01.methodical')
# ====================
# ====================
# ====================
# Parola da disambiguare:  massive
# Frase:  It speeds muscle growth and power development even for the advanced bodybuilder because each hip and leg is exercised separately , thus enabling a massive , concentrated effort to be focused on each .
# Contesto della frase:  {'focus', 'separately', 'muscle', 'hip', 'speed', 'power', 'growth', 'bodybuilder', 'enable', 'concentrated', 'leg', 'massive', 'exercise', 'effort', 'advanced', 'development'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('massive.s.01')
# Senso Target:  Lemma('massive.s.01.massive')
# ====================
# ====================
# ====================
# Parola da disambiguare:  negligible
# Frase:  ( C ) The kinetic effects are negligible .
# Contesto della frase:  {'negligible', 'kinetic'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('negligible.s.01')
# Senso Target:  Lemma('negligible.s.01.negligible')
# ====================
# ====================
# ====================
# Parola da disambiguare:  processes
# Frase:  These are few and seemingly disjointed data , but they illustrate the important fact that fundamental alterations in conditioned reactions occur in a variety of states in which the hypothalamic balance has been altered by physiological experimentation , pharmacological action , or clinical processes .
# Contesto della frase:  {'hypothalamic', 'experimentation', 'illustrate', 'process', 'disjoint', 'alteration', 'pharmacological', 'fundamental', 'physiological', 'data', 'occur', 'alter', 'variety', 'conditioned', 'fact', 'clinical', 'reaction', 'action', 'seemingly', 'balance'}
# max Signature:  {'action', 'intend', 'procedure', 'driver', 'error', 'achieve', 'process', 'result', 'license', 'course', 'trial'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('procedure.n.01')
# Senso Target:  process.n.00
# ====================
# ====================
# ====================
# Parola da disambiguare:  connected
# Frase:  The arc voltage was measured with a voltmeter whose terminals were connected to the anode and cathode holders .
# Contesto della frase:  {'terminal', 'cathode', 'voltage', 'anode', 'holder', 'connect', 'voltmeter', 'arc', 'measure'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('connect.v.01')
# Senso Target:  Lemma('connect.v.01.connect')
# ====================
# ====================
# ====================
# Parola da disambiguare:  adhesive
# Frase:  The sections were mounted on cold slides smeared with Haupts ' adhesive ( Johansen , 1940 ) in earlier experiments , and in later experiments with a different mixture of the same components reported by Schramm and Rottger ( 1959 ) .
# Contesto della frase:  {'slide', 'report', 'schramm', 'smear', 'adhesive', 'late', 'experiment', 'early', 'johansen', 'mixture', 'cold', 'component', 'haupts', 'mount', 'rottger'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('adhesive_material.n.01')
# Senso Target:  Lemma('adhesive_material.n.01.adhesive')
# ====================
# ====================
# ====================
# Parola da disambiguare:  live
# Frase:  With respect to those countries whose leaders prefer to live with their illusions , we can afford to wait , for in time their comparative lack of progress will become clear for all to see .
# Contesto della frase:  {'prefer', 'illusion', 'comparative', 'afford', 'leader', 'live', 'time', 'wait', 'clear', 'country', 'respect', 'lack', 'progress'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('populate.v.01')
# Senso Target:  Lemma('survive.v.01.live')
# ====================
# ====================
# ====================
# Parola da disambiguare:  kinder
# Frase:  Ours were kinder than theirs , some said .
# Contesto della frase:  {'kind'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('kind.a.01')
# Senso Target:  Lemma('kind.a.01.kind')
# ====================
# ====================
# ====================
# Parola da disambiguare:  colonial
# Frase:  The colonial period has generally left people believing that government can , if it wishes , provide all manner of services for them - and that with independence free men do not have to work to realize the benefits of modern life .
# Contesto della frase:  {'free', 'period', 'independence', 'modern', 'colonial', 'work', 'manner', 'service', 'life', 'leave', 'men', 'realize', 'generally', 'government', 'benefit', 'people'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('colonial.n.01')
# Senso Target:  Lemma('colonial.a.01.colonial')
# ====================
# ====================
# ====================
# Parola da disambiguare:  practically
# Frase:  Apart from the honeybee , practically all bees and bumblebees hibernate in a state of torpor .
# Contesto della frase:  {'practically', 'hibernate', 'torpor', 'bumblebee', 'honeybee', 'bee', 'apart'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('practically.r.01')
# Senso Target:  Lemma('practically.r.01.practically')
# ====================
# ====================
# ====================
# Parola da disambiguare:  merry
# Frase:  `` I have heard stories '' , he writes , `` of the most terrible , the most unnatural actions , of the most monstrous murders , told with the most spontaneous , childishly merry laughter '' .
# Contesto della frase:  {'unnatural', 'action', 'write', 'spontaneous', 'monstrous', 'terrible', 'hear', 'murder', 'merry', 'story', 'childishly', 'laughter'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('gay.s.02')
# Senso Target:  Lemma('gay.s.02.merry')
# ====================
# ====================
# ====================
# Parola da disambiguare:  whiteness
# Frase:  In this way , numerical values for the relative efficacy of various detergent formulations can be obtained by measuring the reflectance ( whiteness ) of the cloth swatches before and after washing .
# Contesto della frase:  {'formulation', 'relative', 'reflectance', 'efficacy', 'whiteness', 'numerical', 'detergent', 'swatch', 'wash', 'cloth', 'measure'}
# max Signature:  {'complexion', 'fairness', 'cheek', 'lightness', 'whiteness', 'suffer', 'indication', 'stress'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('whiteness.n.03')
# Senso Target:  Lemma('white.n.02.whiteness')
# ====================
# ====================
# ====================
# Parola da disambiguare:  Progress
# Frase:  Progress is impeded by psychological inhibitions to effective action among those in power and by a failure on their part to understand how local resources , human and material , can be mobilized to achieve the national goals of modernization already symbolically accepted .
# Contesto della frase:  {'impede', 'goal', 'psychological', 'human', 'power', 'effective', 'modernization', 'symbolically', 'failure', 'progress', 'material', 'resource', 'inhibition', 'action', 'understand', 'accept', 'local', 'achieve', 'national', 'mobilize'}
# max Signature:  {'progress', 'gradual', 'growth', 'improvement', 'art', 'knowledge', 'advancement', 'development', 'great'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('advancement.n.03')
# Senso Target:  Lemma('advancement.n.03.progress')
# ====================
# ====================
# ====================
# Parola da disambiguare:  denoted
# Frase:  It was denoted by **f .
# Contesto della frase:  {'denote'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('denote.v.01')
# Senso Target:  Lemma('denote.v.01.denote')
# ====================
# ====================
# ====================
# Parola da disambiguare:  well
# Frase:  This idea , which occurs in both Tatian and Cyprian , fits especially well into the scheme of Irenaeus ' theology ; for it prepares the way for the passage from life through death to life that is achieved in Christ .
# Contesto della frase:  {'cyprian', 'theology', 'irenaeus', 'life', 'tatian', 'christ', 'prepare', 'well', 'achieve', 'scheme', 'idea', 'fit', 'passage', 'death', 'occur'}
# max Signature:  {'abundant', 'well', 'source'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('well.n.03')
# Senso Target:  Lemma('well.r.01.well')
# ====================
# ====================
# ====================
# Parola da disambiguare:  performed
# Frase:  I saw `` Fiorello ! '' performed in New York by the original cast and I think this company is every bit as good , and perhaps better .
# Contesto della frase:  {'good', 'cast', 'well', 'fiorello', 'bit', 'perform', 'company', 'original', 'york'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('perform.v.01')
# Senso Target:  Lemma('perform.v.03.perform')
# ====================
# ====================
# ====================
# Parola da disambiguare:  early
# Frase:  * * h Then he was asking himself the usual early morning questions : What the Hell am I doin here ?
# Contesto della frase:  {'morning', 'early', 'doin', 'hell', 'usual', 'question'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('early.a.01')
# Senso Target:  Lemma('early.a.01.early')
# ====================
# ====================
# ====================
# Parola da disambiguare:  motivating
# Frase:  The insuperable reward systems that most religions embody have great motivating effects .
# Contesto della frase:  {'system', 'motivating', 'embody', 'religion', 'insuperable', 'reward', 'great'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('motivation.n.03')
# Senso Target:  Lemma('motivative.s.01.motivating')
# ====================
# ====================
# ====================
# Parola da disambiguare:  signed
# Frase:  A big-league municipal stadium at Flushing Meadow Park is in the works , and once the lease is signed the local club will be formally recognized by Commissioner Ford C. Frick .
# Contesto della frase:  {'meadow', 'recognize', 'park', 'work', 'club', 'flushing', 'lease', 'local', 'formally', 'sign', 'ford', 'stadium', 'municipal', 'bigleague', 'commissioner', 'frick'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('sign.v.01')
# Senso Target:  Lemma('sign.v.02.sign')
# ====================
# ====================
# ====================
# Parola da disambiguare:  composed
# Frase:  When this experiment is viewed as composed of five binomial trials , one for each member of the family , the outcomes of the trials are obviously not independent .
# Contesto della frase:  {'outcome', 'view', 'compose', 'experiment', 'member', 'independent', 'binomial', 'family', 'trial'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('compose.v.01')
# Senso Target:  Lemma('compose.v.01.compose')
# ====================
# ====================
# ====================
# Parola da disambiguare:  leading
# Frase:  Dolores Hart , is charming in a leading role , and quite believable .
# Contesto della frase:  {'believable', 'role', 'dolores', 'leading', 'hart', 'charm'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('lead.n.14')
# Senso Target:  Lemma('leading.s.01.leading')
# ====================
# ====================
# ====================
# Parola da disambiguare:  reported
# Frase:  The Postmaster General recently reported that mail order frauds - among which fake therapeutic devices figure prominently - are at the highest level in history .
# Contesto della frase:  {'history', 'report', 'prominently', 'general', 'fraud', 'order', 'mail', 'fake', 'level', 'figure', 'therapeutic', 'device', 'high', 'postmaster'}
# max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('report.v.01')
# Senso Target:  Lemma('report.v.02.report')
# ====================
# ====================
# Checked:  26
# Evaluated:  51
# Accuracy:  0.52
#
# Esecuzioni:  10
# Lista delle accuratezze:  [0.44, 0.56, 0.54, 0.56, 0.56, 0.58, 0.5, 0.6, 0.38, 0.52]
# Accuratezza media:  0.524
