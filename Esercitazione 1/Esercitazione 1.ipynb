# %%
import re
import enum
import math
import random
import nltk
import csv
import numpy as np
import scipy as sp
from nltk.corpus import wordnet as wn
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import semcor
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from random import randrange
from collections import deque
from statistics import mean

# %% [markdown]
# FUNZIONI DI PREPROCESSING

# %%
#il pre-processing consiste nella tokenizzazione, lemmatizzazione,
#rimozione della punteggiatura e delle stopwords di una sentence
def pre_processing(sentence):
    return set(remove_stopwords(tokenize_sentence(remove_punctuation(sentence))))

#rimuove le stowords da una lista di parole
def remove_stopwords(words_list):
    stopwords_list = get_stopwords()
    return [value.lower() for value in words_list if value.lower() not in stopwords_list]

#Tokenizza la frase in input e ne affettua anche la lemmatizzazione della sue parole
def tokenize_sentence(sentence):
    words_list = []
    lmtzr = WordNetLemmatizer()
    for tag in nltk.pos_tag(word_tokenize(sentence)):
        if (tag[1][:2] == "NN"):
            words_list.append(lmtzr.lemmatize(tag[0], pos = wn.NOUN))
        elif (tag[1][:2] == "VB"):
             words_list.append(lmtzr.lemmatize(tag[0], pos = wn.VERB))
        elif (tag[1][:2] == "RB"):
             words_list.append(lmtzr.lemmatize(tag[0], pos = wn.ADV))
        elif (tag[1][:2] == "JJ"):
             words_list.append(lmtzr.lemmatize(tag[0], pos = wn.ADJ))
    return words_list

#Restituisce la l'insieme di stopwords dal file delle stopwords
def get_stopwords():
    stopwords = open("stop_words_FULL.txt", "r")
    stopwords_list = []
    for word in stopwords:
        stopwords_list.append(word.replace('\n', ''))
    stopwords.close()
    return stopwords_list

#Rimuove la punteggiatura da una sentence
#Restituisce la sentence senza punteggiature
def remove_punctuation(sentence):
    return re.sub(r'[^\w\s]','',sentence)

# %% [markdown]
# FUNZIONI UTILI PER L'ANALISI DEL TESTO

# %%
#Restituisce un sostantivo random presente nel dizionario associato ad una sentence
def get_random_noun(dictionary_tag):
    try:
        sentence_nouns = dictionary_tag['NN']
    except KeyError:
        return None #se non ci sono sostantivi
    noun =  random.choice(sentence_nouns)
    if len(wn.synsets(noun)) == 0:
        return None #se il sostantivo scelto non ha almeno un synset in wordnet
    return noun

#Restituisce una parola random presente nel dizionario associato ad una sentence
def get_random_word(dictionary_tag):
    keys = list(dictionary_tag.keys())
    if not keys:
        return None #se non ci sono parole "analizzabili" nel dizionario, aka se il dizionario è vuoto
    key = random.choice(keys)
    words_list = dictionary_tag[key]
    word = random.choice(words_list)
    if len(wn.synsets(word)) == 0:
        return None #se la parola scelta non ha almeno un synset in wordnet
    return word

#Verifica che una parola abbia un synset target associato
#Senza synset target associato è inutile confrontare l'output dell'algortimo di Lesk
def check_word_synset_target(word,sentence_sem):
    for w in sentence_sem:
        if (type(w) != list):
            if (w[0] == word):
                return True
    return False
    
#Crea un dizionario che ha come chiavi i tag presenti nella sentence e come valori liste di parole associate a quei tag
#e.g {NN: ['home','garden'], VB:['gone'], .....,}
#input: sentence_tag -> rappresenta le words della sentence con i relativi pos tag
#input: sentence_sem -> rappresenta le words della sentence con il relativo synset target associato
def get_dictionary_tag(sentence_tag,sentence_sem):
    dictionary_tag = dict()
    stopwords_list = get_stopwords()
    for word in sentence_tag:
         tag = word.label()
         word = " ".join(l for l in word)
         if check_word_synset_target(word, sentence_sem): #Non inserisco nel dizionario parole che non hanno un synset target
             w = word.lower()
             if w not in stopwords_list and tag: #Non inserisco nel dizionario stopwords o parole che non hanno un pos tag associato
                 if tag in dictionary_tag:
                     dictionary_tag[tag].append(word)
                 else:
                     dictionary_tag[tag] = [word]             
    return dictionary_tag

#Restituisce un indice randomico utile per l'ultimo esercizio
def get_random_index(index_evaluated, INDEXES_NUM):
    while True:
        index = randrange(INDEXES_NUM)
        if index not in index_evaluated:
            return index
    
#Restituisce il synset target per una parola in una sentence
def get_synset_target_for_word_in_sentence(noun,sentence):
     for word in sentence:
      if(type(word) != list):
          if (word[0] == noun):
              return str(word.label())

# %% [markdown]
# METRICHE DI SIMILARITA E ALGORITMI PER LA RICERCA

# %%
#Custom similarity functions
def wu_palmer_similarity(sense1, sense2):
    numerator = 2 * depth(lowest_common_subsumer(sense1,sense2))
    denominator = depth(sense1) + depth(sense2)
    return numerator/denominator

def leakcock_chodorow(sense1, sense2):
    numerator = (shortest_path(sense1, sense2) + 1)
    denominator = (2 * max_depth) + 1
    return -math.log(numerator/denominator)

def shortest_path_similarity(sense1, sense2):
    return ((2 * max_depth) - shortest_path(sense1, sense2))

#Wordnet similarity functions
def wn_wu_palmer_similarity(sense1, sense2):
    sim = sense1.wup_similarity(sense2)
    if sim: return sim
    else: return 0
    
def wn_leakcock_chodorow(sense1, sense2):
    try:
        sim = sense1.lch_similarity(sense2)
        if sim: return sim
        else: return 0
    except:
        return 0

#Restituisce la similarità tra due parole date in input
def similarity(word1, word2, similarity_function):
    max_sim = 0
    for s1 in wn.synsets(word1):
        for s2 in wn.synsets(word2):
           sim = similarity_function(s1,s2)
           if sim > max_sim:
               max_sim = sim
    return max_sim

#Restituisce la profondità di un senso in wordnet, cioè il massimo percorso dal senso alla radice        
def depth(sense):
    if not sense:
        return 0
    return max([len(path) for path in all_hypernym_paths(sense)])

#Restituisce tutti i percorsi di iperonimi di un senso di wordnet, la ricerca dei percosi viene effettuata in modo ricorsivo
def all_hypernym_paths(sense):
    paths = []
    hypernyms = sense.hypernyms()
    if len(hypernyms) == 0:
        paths = [[sense]]
    for hypernym in hypernyms:
        for ancestor_list in all_hypernym_paths(hypernym):
            ancestor_list.append(sense)
            paths.append(ancestor_list)
    return paths

#Massima profondità intesa come il percorso più lungo degli iperonimi di tutti i sensi presenti in wordnet
max_depth = max(max(len(hyp_path) for hyp_path in all_hypernym_paths(ss)) for ss in wn.all_synsets())

#Restituisce un dizionario di iperonimi del senso in input con la relativa profondità
def min_hypernyms_depth(sense):
    sense_depth_queue = deque([(sense, 0)]) #deque garantisce efficienza nell'inserire ed eliminare elementi sia a destra che a sinistra della coda
    sense_depth_dict = {}
    while sense_depth_queue:
        s, depth = sense_depth_queue.popleft()
        if s in sense_depth_dict:
            continue
        sense_depth_dict[s] = depth
        depth += 1
        sense_depth_queue.extend((hyperonym, depth) for hyperonym in s.hypernyms()) #li mette a destra della coda
    return sense_depth_dict

#restituisce il percorso più breve tra due sensi di wordnet
def shortest_path(sense1,sense2):
    if sense1 == sense2:
        return 0
    dict1 = min_hypernyms_depth(sense1)
    dict2 = min_hypernyms_depth(sense2)
    min_dist = (2 * max_depth) # distanza minima iniziale

    #per ogni senso del dizionario degli iperonimi di sense1 cerca di trovare il match con un senso del secondo dizionario.
    for ss, dist1 in dict1.items():
        dist2 = dict2.get(ss)
        if not dist2:
            dist2 = (2 * max_depth)
        min_dist = min(min_dist, dist1 + dist2) #somma dei due sensi matchati
    return (2 * max_depth) if math.isinf(min_dist) else min_dist

#Restituisce l'antenato comune più vicino di due sensi, cioè l'iperonimo comune più vicino ai due sensi. 
#SCELTA PROGETTUALE: Se ne ho più di uno prendo quello può essere il più profondo rispetto alla radice.
def lowest_common_subsumer(sense1, sense2):
    if sense1 == sense2: return sense1
    
    dict1 = min_hypernyms_depth(sense1)
    dict2 = min_hypernyms_depth(sense2)
    
    min_dist = (2 * max_depth)
    candidates = []
    for ss, dist1 in dict1.items():
        dist2 = dict2.get(ss) 
        if not dist2:
            dist2 = (2 * max_depth)
        else:
            if (dist1 + dist2) <= min_dist:
                min_dist = (dist1 + dist2)
                candidates.append(ss) 
    if candidates:
        deepest = candidates[0]
        for sense in candidates:
            if depth(sense) < depth(deepest):
                deepest = sense
        return deepest #restituisce il senso con profondità maggiore rispetto alla radice

#Classe enum con la quale specifichiamo il tipo di similarità utilizzata
class Similarity_Type(enum.Enum):
    wu_palmer_similarity = 1
    shortest_path = 2
    leakcock_chodorow = 3

# %% [markdown]
# Word sense disambiguation è un problema aperto dell'elaborazione del linguaggio naturale, che comprende il processo di identificazione del senso di una parola (cioè il significato) utilizzato in una determinata frase, quando la parola ha un numero di sensi distinti (polisemia).

# %%
#Algoritmo di Lesk
def lesk_algorithm(word, sentence, word_type):
    best_sense = wn.synsets(word)[0]
    max_overlap = 0
    max_signature = []
    print("Frase in cui compare la parola: ", sentence)
    context = pre_processing(sentence)
    
    #se il tipo di parola è un nome allora cerco solo tra i nomi in wordnet
    #altrimenti prendo tutti i synset associati a quel termine
    if word_type == 'NOUN':
        synsets = wn.synsets(word, pos=wn.NOUN)
    elif word_type == 'ALL':
        synsets = wn.synsets(word)
        
    for sense in synsets:
        signature = get_signature(sense)
        overlap = len(list(signature & context)) #overlap
        if overlap > max_overlap:
            max_overlap = overlap
            best_sense = sense
            max_signature = signature
            
    print("Contesto della frase: ", context)
    print("Max Signature: ", max_signature) #signature del senso con più overlap con il contesto della sentence
    return best_sense

#Signature di un senso di WordNet
def get_signature(sense):
    signature = set()
    for word in pre_processing(sense.definition()): #tokenizzo la definizione del synset
        signature.add(word)
    for example in sense.examples(): #tokenizzo ogni esempio del synset
        for word in pre_processing(example):
            signature.add(word)
    return signature #la signature conterrà tutte le parole presenti nella definizione del senso e negli esempi

# %% [markdown]
# CONSEGNA 1:
#
# L'esercitazione consiste nell'implementare tre misure di similarità basate su WordNet.
#
# Per ciascuna di tali misure di similarità, calcolare gli indici di
# correlazione di Spearman and gli indici di correlazione di Pearson
# fra i risultati ottenuti e quelli ‘target’ presenti nel file annotato.

# %%
def main():

    #scelta della metrica da utilizzare per il calcolo della similarità
    similarity_type = Similarity_Type.leakcock_chodorow
    #similarity_type = Similarity_Type.wu_palmer_similarity
    #similarity_type = Similarity_Type.shortest_path
    
    with open('WordSim353.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        assignments = []
        targets = []
        line_count = 0
        for row in csv_reader:
            if line_count > 0:
                print("Word1: ",row[0])
                print("Word2: ",row[1])
                sim = 0
                wn_sim = 0
                if similarity_type.value == 1:
                    sim = similarity(row[0], row[1], wu_palmer_similarity)
                    wn_sim = similarity(row[0], row[1], wn_wu_palmer_similarity)
                elif similarity_type.value == 2:
                    sim = similarity(row[0], row[1], shortest_path_similarity)
                elif similarity_type.value == 3:
                    sim = similarity(row[0], row[1], leakcock_chodorow)
                    wn_sim = similarity(row[0], row[1], wn_leakcock_chodorow)
                print("Type of similarity chosen: ", similarity_type.name)
                print("MyCustom Similarity: ",sim)
                print("WordNet Similarity: ",wn_sim)
                print("Human Similarity: ",row[2])
                assignments.append(sim)
                targets.append(float(row[2]))
                print("------------------------------")
            line_count = line_count + 1
            
    print("Pearson Correlation: ", np.corrcoef(assignments, targets))
    print("Spearman Correlation: ", sp.stats.spearmanr(assignments, targets))
main()
# Out:
# Word1:  love
# Word2:  sex
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  6.77
# ------------------------------
# Word1:  tiger
# Word2:  cat
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  7.35
# ------------------------------
# Word1:  tiger
# Word2:  tiger
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# WordNet Similarity:  3.6375861597263857
# Human Similarity:  10.00
# ------------------------------
# Word1:  book
# Word2:  paper
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.46
# ------------------------------
# Word1:  computer
# Word2:  keyboard
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.62
# ------------------------------
# Word1:  computer
# Word2:  internet
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  7.58
# ------------------------------
# Word1:  plane
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  5.77
# ------------------------------
# Word1:  train
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.31
# ------------------------------
# Word1:  telephone
# Word2:  communication
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  7.50
# ------------------------------
# Word1:  television
# Word2:  radio
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  6.77
# ------------------------------
# Word1:  media
# Word2:  radio
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.42
# ------------------------------
# Word1:  drug
# Word2:  abuse
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.6486586255873816
# Human Similarity:  6.85
# ------------------------------
# Word1:  bread
# Word2:  butter
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  6.19
# ------------------------------
# Word1:  cucumber
# Word2:  potato
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  5.92
# ------------------------------
# Word1:  doctor
# Word2:  nurse
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.00
# ------------------------------
# Word1:  professor
# Word2:  doctor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  6.62
# ------------------------------
# Word1:  student
# Word2:  professor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  6.81
# ------------------------------
# Word1:  smart
# Word2:  student
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  0.9985288301111273
# Human Similarity:  4.62
# ------------------------------
# Word1:  smart
# Word2:  stupid
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  0.9985288301111273
# Human Similarity:  5.81
# ------------------------------
# Word1:  company
# Word2:  stock
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  7.08
# ------------------------------
# Word1:  stock
# Word2:  market
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  8.08
# ------------------------------
# Word1:  stock
# Word2:  phone
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  1.62
# ------------------------------
# Word1:  stock
# Word2:  CD
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  1.31
# ------------------------------
# Word1:  stock
# Word2:  jaguar
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  0.92
# ------------------------------
# Word1:  stock
# Word2:  egg
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  1.81
# ------------------------------
# Word1:  fertility
# Word2:  egg
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  6.69
# ------------------------------
# Word1:  stock
# Word2:  live
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.8718021769015913
# Human Similarity:  3.73
# ------------------------------
# Word1:  stock
# Word2:  life
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  0.92
# ------------------------------
# Word1:  book
# Word2:  library
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.46
# ------------------------------
# Word1:  bank
# Word2:  money
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  8.12
# ------------------------------
# Word1:  wood
# Word2:  forest
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# WordNet Similarity:  3.6375861597263857
# Human Similarity:  7.73
# ------------------------------
# Word1:  money
# Word2:  cash
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  9.15
# ------------------------------
# Word1:  professor
# Word2:  cucumber
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  0.31
# ------------------------------
# Word1:  king
# Word2:  cabbage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  0.23
# ------------------------------
# Word1:  king
# Word2:  queen
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# WordNet Similarity:  3.6375861597263857
# Human Similarity:  8.58
# ------------------------------
# Word1:  king
# Word2:  rook
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  5.92
# ------------------------------
# Word1:  bishop
# Word2:  rabbi
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  6.69
# ------------------------------
# Word1:  Jerusalem
# Word2:  Israel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  8.46
# ------------------------------
# Word1:  Jerusalem
# Word2:  Palestinian
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  0.8649974374866046
# Human Similarity:  7.65
# ------------------------------
# Word1:  holy
# Word2:  sex
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  1.62
# ------------------------------
# Word1:  fuck
# Word2:  sex
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.538973871058276
# Human Similarity:  9.44
# ------------------------------
# Word1:  Maradona
# Word2:  football
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  0
# Human Similarity:  8.62
# ------------------------------
# Word1:  football
# Word2:  soccer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  9.03
# ------------------------------
# Word1:  football
# Word2:  basketball
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  6.81
# ------------------------------
# Word1:  football
# Word2:  tennis
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.63
# ------------------------------
# Word1:  tennis
# Word2:  racket
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  7.56
# ------------------------------
# Word1:  Arafat
# Word2:  peace
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  1.072636802264849
# Human Similarity:  6.73
# ------------------------------
# Word1:  Arafat
# Word2:  terror
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  1.845826690498331
# Human Similarity:  7.65
# ------------------------------
# Word1:  Arafat
# Word2:  Jackson
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  2.50
# ------------------------------
# Word1:  law
# Word2:  lawyer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  8.38
# ------------------------------
# Word1:  movie
# Word2:  star
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  7.38
# ------------------------------
# Word1:  movie
# Word2:  popcorn
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  0.9985288301111273
# Human Similarity:  6.19
# ------------------------------
# Word1:  movie
# Word2:  critic
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  6.73
# ------------------------------
# Word1:  movie
# Word2:  theater
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.92
# ------------------------------
# Word1:  physics
# Word2:  proton
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.0055218656020977
# WordNet Similarity:  0.9295359586241757
# Human Similarity:  8.12
# ------------------------------
# Word1:  physics
# Word2:  chemistry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.35
# ------------------------------
# Word1:  space
# Word2:  chemistry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  4.88
# ------------------------------
# Word1:  alcohol
# Word2:  chemistry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  5.54
# ------------------------------
# Word1:  vodka
# Word2:  gin
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.46
# ------------------------------
# Word1:  vodka
# Word2:  brandy
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.13
# ------------------------------
# Word1:  drink
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  3.04
# ------------------------------
# Word1:  drink
# Word2:  ear
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  1.31
# ------------------------------
# Word1:  drink
# Word2:  mouth
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  5.96
# ------------------------------
# Word1:  drink
# Word2:  eat
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.159484249353372
# Human Similarity:  6.87
# ------------------------------
# Word1:  baby
# Word2:  mother
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  7.85
# ------------------------------
# Word1:  drink
# Word2:  mother
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  2.65
# ------------------------------
# Word1:  car
# Word2:  automobile
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# WordNet Similarity:  3.6375861597263857
# Human Similarity:  8.94
# ------------------------------
# Word1:  gem
# Word2:  jewel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# WordNet Similarity:  3.6375861597263857
# Human Similarity:  8.96
# ------------------------------
# Word1:  journey
# Word2:  voyage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  9.29
# ------------------------------
# Word1:  boy
# Word2:  lad
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  8.83
# ------------------------------
# Word1:  coast
# Word2:  shore
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  9.10
# ------------------------------
# Word1:  asylum
# Word2:  madhouse
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  8.87
# ------------------------------
# Word1:  magician
# Word2:  wizard
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# WordNet Similarity:  3.6375861597263857
# Human Similarity:  9.02
# ------------------------------
# Word1:  midday
# Word2:  noon
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# WordNet Similarity:  3.6375861597263857
# Human Similarity:  9.29
# ------------------------------
# Word1:  furnace
# Word2:  stove
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  8.79
# ------------------------------
# Word1:  food
# Word2:  fruit
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  7.52
# ------------------------------
# Word1:  bird
# Word2:  cock
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  7.10
# ------------------------------
# Word1:  bird
# Word2:  crane
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.38
# ------------------------------
# Word1:  tool
# Word2:  implement
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  6.46
# ------------------------------
# Word1:  brother
# Word2:  monk
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  6.27
# ------------------------------
# Word1:  crane
# Word2:  implement
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  2.69
# ------------------------------
# Word1:  lad
# Word2:  brother
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  4.46
# ------------------------------
# Word1:  journey
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0.8232003088081431
# WordNet Similarity:  0.7472144018302211
# Human Similarity:  5.85
# ------------------------------
# Word1:  monk
# Word2:  oracle
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  5.00
# ------------------------------
# Word1:  cemetery
# Word2:  woodland
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  2.08
# ------------------------------
# Word1:  food
# Word2:  rooster
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0.9409833444645266
# WordNet Similarity:  0.8649974374866046
# Human Similarity:  4.42
# ------------------------------
# Word1:  coast
# Word2:  hill
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  4.38
# ------------------------------
# Word1:  forest
# Word2:  graveyard
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  1.85
# ------------------------------
# Word1:  shore
# Word2:  woodland
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  3.08
# ------------------------------
# Word1:  monk
# Word2:  slave
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  0.92
# ------------------------------
# Word1:  coast
# Word2:  forest
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  3.15
# ------------------------------
# Word1:  lad
# Word2:  wizard
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  0.92
# ------------------------------
# Word1:  chord
# Word2:  smile
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  0.54
# ------------------------------
# Word1:  glass
# Word2:  magician
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  2.08
# ------------------------------
# Word1:  noon
# Word2:  string
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  0.54
# ------------------------------
# Word1:  rooster
# Word2:  voyage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0.5355182363563622
# WordNet Similarity:  0.4595323293784402
# Human Similarity:  0.62
# ------------------------------
# Word1:  money
# Word2:  dollar
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  8.42
# ------------------------------
# Word1:  money
# Word2:  cash
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  9.08
# ------------------------------
# Word1:  money
# Word2:  currency
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  9.04
# ------------------------------
# Word1:  money
# Word2:  wealth
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  8.27
# ------------------------------
# Word1:  money
# Word2:  property
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.57
# ------------------------------
# Word1:  money
# Word2:  possession
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.29
# ------------------------------
# Word1:  money
# Word2:  bank
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  8.50
# ------------------------------
# Word1:  money
# Word2:  deposit
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.73
# ------------------------------
# Word1:  money
# Word2:  withdrawal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  6.88
# ------------------------------
# Word1:  money
# Word2:  laundering
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  5.65
# ------------------------------
# Word1:  money
# Word2:  operation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  3.31
# ------------------------------
# Word1:  tiger
# Word2:  jaguar
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.00
# ------------------------------
# Word1:  tiger
# Word2:  feline
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.00
# ------------------------------
# Word1:  tiger
# Word2:  carnivore
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.08
# ------------------------------
# Word1:  tiger
# Word2:  mammal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.85
# ------------------------------
# Word1:  tiger
# Word2:  animal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.00
# ------------------------------
# Word1:  tiger
# Word2:  organism
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.538973871058276
# Human Similarity:  4.77
# ------------------------------
# Word1:  tiger
# Word2:  fauna
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  5.62
# ------------------------------
# Word1:  tiger
# Word2:  zoo
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  5.87
# ------------------------------
# Word1:  psychology
# Word2:  psychiatry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  8.08
# ------------------------------
# Word1:  psychology
# Word2:  anxiety
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  7.00
# ------------------------------
# Word1:  psychology
# Word2:  fear
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  6.85
# ------------------------------
# Word1:  psychology
# Word2:  depression
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  7.42
# ------------------------------
# Word1:  psychology
# Word2:  clinic
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  0.9985288301111273
# Human Similarity:  6.58
# ------------------------------
# Word1:  psychology
# Word2:  doctor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  6.42
# ------------------------------
# Word1:  psychology
# Word2:  Freud
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  0.6418538861723948
# Human Similarity:  8.21
# ------------------------------
# Word1:  psychology
# Word2:  mind
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.69
# ------------------------------
# Word1:  psychology
# Word2:  health
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  7.23
# ------------------------------
# Word1:  psychology
# Word2:  science
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  6.71
# ------------------------------
# Word1:  psychology
# Word2:  discipline
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.538973871058276
# Human Similarity:  5.58
# ------------------------------
# Word1:  psychology
# Word2:  cognition
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.845826690498331
# Human Similarity:  7.48
# ------------------------------
# Word1:  planet
# Word2:  star
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.45
# ------------------------------
# Word1:  planet
# Word2:  constellation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  8.06
# ------------------------------
# Word1:  planet
# Word2:  moon
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  8.08
# ------------------------------
# Word1:  planet
# Word2:  sun
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  8.02
# ------------------------------
# Word1:  planet
# Word2:  galaxy
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  8.11
# ------------------------------
# Word1:  planet
# Word2:  space
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.92
# ------------------------------
# Word1:  planet
# Word2:  astronomer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  7.94
# ------------------------------
# Word1:  precedent
# Word2:  example
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  5.85
# ------------------------------
# Word1:  precedent
# Word2:  information
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.538973871058276
# Human Similarity:  3.85
# ------------------------------
# Word1:  precedent
# Word2:  cognition
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  2.81
# ------------------------------
# Word1:  precedent
# Word2:  law
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  6.65
# ------------------------------
# Word1:  precedent
# Word2:  collection
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.538973871058276
# Human Similarity:  2.50
# ------------------------------
# Word1:  precedent
# Word2:  group
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  1.77
# ------------------------------
# Word1:  precedent
# Word2:  antecedent
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.04
# ------------------------------
# Word1:  cup
# Word2:  coffee
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.58
# ------------------------------
# Word1:  cup
# Word2:  tableware
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.538973871058276
# Human Similarity:  6.85
# ------------------------------
# Word1:  cup
# Word2:  article
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  2.40
# ------------------------------
# Word1:  cup
# Word2:  artifact
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  2.92
# ------------------------------
# Word1:  cup
# Word2:  object
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.845826690498331
# Human Similarity:  3.69
# ------------------------------
# Word1:  cup
# Word2:  entity
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  1.845826690498331
# Human Similarity:  2.15
# ------------------------------
# Word1:  cup
# Word2:  drink
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  7.25
# ------------------------------
# Word1:  cup
# Word2:  food
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.845826690498331
# Human Similarity:  5.00
# ------------------------------
# Word1:  cup
# Word2:  substance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  1.92
# ------------------------------
# Word1:  cup
# Word2:  liquid
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.845826690498331
# Human Similarity:  5.90
# ------------------------------
# Word1:  jaguar
# Word2:  cat
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  7.42
# ------------------------------
# Word1:  jaguar
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0.8803587226480918
# WordNet Similarity:  0.8043728156701697
# Human Similarity:  7.27
# ------------------------------
# Word1:  energy
# Word2:  secretary
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  1.81
# ------------------------------
# Word1:  secretary
# Word2:  senate
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  0.9985288301111273
# Human Similarity:  5.06
# ------------------------------
# Word1:  energy
# Word2:  laboratory
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  5.09
# ------------------------------
# Word1:  computer
# Word2:  laboratory
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  6.78
# ------------------------------
# Word1:  weapon
# Word2:  secret
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  6.06
# ------------------------------
# Word1:  FBI
# Word2:  fingerprint
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  6.94
# ------------------------------
# Word1:  FBI
# Word2:  investigation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.0055218656020977
# WordNet Similarity:  0.9295359586241757
# Human Similarity:  8.31
# ------------------------------
# Word1:  investigation
# Word2:  effort
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  4.59
# ------------------------------
# Word1:  Mars
# Word2:  water
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  1.6486586255873816
# Human Similarity:  2.94
# ------------------------------
# Word1:  Mars
# Word2:  scientist
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  5.63
# ------------------------------
# Word1:  news
# Word2:  report
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  8.16
# ------------------------------
# Word1:  canyon
# Word2:  landscape
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  7.53
# ------------------------------
# Word1:  image
# Word2:  surface
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  4.56
# ------------------------------
# Word1:  discovery
# Word2:  space
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  6.34
# ------------------------------
# Word1:  water
# Word2:  seepage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  6.56
# ------------------------------
# Word1:  sign
# Word2:  recess
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.159484249353372
# Human Similarity:  2.38
# ------------------------------
# Word1:  Wednesday
# Word2:  news
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  2.22
# ------------------------------
# Word1:  mile
# Word2:  kilometer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  8.66
# ------------------------------
# Word1:  computer
# Word2:  news
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  4.47
# ------------------------------
# Word1:  territory
# Word2:  surface
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  5.34
# ------------------------------
# Word1:  atmosphere
# Word2:  landscape
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  3.69
# ------------------------------
# Word1:  president
# Word2:  medal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  3.00
# ------------------------------
# Word1:  war
# Word2:  troops
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  8.13
# ------------------------------
# Word1:  record
# Word2:  number
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  6.31
# ------------------------------
# Word1:  skin
# Word2:  eye
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.22
# ------------------------------
# Word1:  Japanese
# Word2:  American
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  6.50
# ------------------------------
# Word1:  theater
# Word2:  history
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  3.91
# ------------------------------
# Word1:  volunteer
# Word2:  motto
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  2.56
# ------------------------------
# Word1:  prejudice
# Word2:  recognition
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  3.00
# ------------------------------
# Word1:  decoration
# Word2:  valor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  5.63
# ------------------------------
# Word1:  century
# Word2:  year
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.59
# ------------------------------
# Word1:  century
# Word2:  nation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  3.16
# ------------------------------
# Word1:  delay
# Word2:  racism
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  1.19
# ------------------------------
# Word1:  delay
# Word2:  news
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  3.31
# ------------------------------
# Word1:  minister
# Word2:  party
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.63
# ------------------------------
# Word1:  peace
# Word2:  plan
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  4.75
# ------------------------------
# Word1:  minority
# Word2:  peace
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  3.69
# ------------------------------
# Word1:  attempt
# Word2:  peace
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  4.25
# ------------------------------
# Word1:  government
# Word2:  crisis
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  6.56
# ------------------------------
# Word1:  deployment
# Word2:  departure
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  4.25
# ------------------------------
# Word1:  deployment
# Word2:  withdrawal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  5.88
# ------------------------------
# Word1:  energy
# Word2:  crisis
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  5.94
# ------------------------------
# Word1:  announcement
# Word2:  news
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  7.56
# ------------------------------
# Word1:  announcement
# Word2:  effort
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  2.75
# ------------------------------
# Word1:  stroke
# Word2:  hospital
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  7.03
# ------------------------------
# Word1:  disability
# Word2:  death
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  5.47
# ------------------------------
# Word1:  victim
# Word2:  emergency
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  6.47
# ------------------------------
# Word1:  treatment
# Word2:  recovery
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.91
# ------------------------------
# Word1:  journal
# Word2:  association
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  4.97
# ------------------------------
# Word1:  doctor
# Word2:  personnel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  5.00
# ------------------------------
# Word1:  doctor
# Word2:  liability
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  5.19
# ------------------------------
# Word1:  liability
# Word2:  insurance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.03
# ------------------------------
# Word1:  school
# Word2:  center
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  3.44
# ------------------------------
# Word1:  reason
# Word2:  hypertension
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  2.31
# ------------------------------
# Word1:  reason
# Word2:  criterion
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  5.91
# ------------------------------
# Word1:  hundred
# Word2:  percent
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  7.38
# ------------------------------
# Word1:  Harvard
# Word2:  Yale
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.13
# ------------------------------
# Word1:  hospital
# Word2:  infrastructure
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  4.63
# ------------------------------
# Word1:  death
# Word2:  row
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  5.25
# ------------------------------
# Word1:  death
# Word2:  inmate
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  5.03
# ------------------------------
# Word1:  lawyer
# Word2:  evidence
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  6.69
# ------------------------------
# Word1:  life
# Word2:  death
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.88
# ------------------------------
# Word1:  life
# Word2:  term
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  4.50
# ------------------------------
# Word1:  word
# Word2:  similarity
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  4.75
# ------------------------------
# Word1:  board
# Word2:  recommendation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  4.47
# ------------------------------
# Word1:  governor
# Word2:  interview
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  0.9985288301111273
# Human Similarity:  3.25
# ------------------------------
# Word1:  OPEC
# Word2:  country
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  5.63
# ------------------------------
# Word1:  peace
# Word2:  atmosphere
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  3.69
# ------------------------------
# Word1:  peace
# Word2:  insurance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  2.94
# ------------------------------
# Word1:  territory
# Word2:  kilometer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  5.28
# ------------------------------
# Word1:  travel
# Word2:  activity
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  5.00
# ------------------------------
# Word1:  competition
# Word2:  price
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  6.44
# ------------------------------
# Word1:  consumer
# Word2:  confidence
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  4.13
# ------------------------------
# Word1:  consumer
# Word2:  energy
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  4.75
# ------------------------------
# Word1:  problem
# Word2:  airport
# ...
# WordNet Similarity:  0.9295359586241757
# Human Similarity:  5.97
# ------------------------------
# Word1:  game
# Word2:  victory
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.03
# ------------------------------
# Word1:  game
# Word2:  team
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  7.69
# ------------------------------
# Word1:  marathon
# Word2:  sprint
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  7.47
# ------------------------------
# Word1:  game
# Word2:  series
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  6.19
# ------------------------------
# Word1:  game
# Word2:  defeat
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  6.97
# ------------------------------
# Word1:  seven
# Word2:  series
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  3.56
# ------------------------------
# Word1:  seafood
# Word2:  sea
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  7.47
# ------------------------------
# Word1:  seafood
# Word2:  food
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  8.34
# ------------------------------
# Word1:  seafood
# Word2:  lobster
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.70
# ------------------------------
# Word1:  lobster
# Word2:  food
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.81
# ------------------------------
# Word1:  lobster
# Word2:  wine
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  5.70
# ------------------------------
# Word1:  food
# Word2:  preparation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  6.22
# ------------------------------
# Word1:  video
# Word2:  archive
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  6.34
# ------------------------------
# Word1:  start
# Word2:  year
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  4.06
# ------------------------------
# Word1:  start
# Word2:  match
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  1.8718021769015913
# Human Similarity:  4.47
# ------------------------------
# Word1:  game
# Word2:  round
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  5.97
# ------------------------------
# Word1:  boxing
# Word2:  round
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.61
# ------------------------------
# Word1:  championship
# Word2:  tournament
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.36
# ------------------------------
# Word1:  fighting
# Word2:  defeating
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  2.159484249353372
# Human Similarity:  7.41
# ------------------------------
# Word1:  line
# Word2:  insurance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  2.69
# ------------------------------
# Word1:  day
# Word2:  summer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  3.94
# ------------------------------
# Word1:  summer
# Word2:  drought
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.16
# ------------------------------
# Word1:  summer
# Word2:  nature
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  5.63
# ------------------------------
# Word1:  day
# Word2:  dawn
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.53
# ------------------------------
# Word1:  nature
# Word2:  environment
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  8.31
# ------------------------------
# Word1:  environment
# Word2:  ecology
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  8.81
# ------------------------------
# Word1:  nature
# Word2:  man
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  6.25
# ------------------------------
# Word1:  man
# Word2:  woman
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.30
# ------------------------------
# Word1:  man
# Word2:  governor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  5.25
# ------------------------------
# Word1:  murder
# Word2:  manslaughter
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.53
# ------------------------------
# Word1:  soap
# Word2:  opera
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  0.9985288301111273
# Human Similarity:  7.94
# ------------------------------
# Word1:  opera
# Word2:  performance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  6.88
# ------------------------------
# Word1:  life
# Word2:  lesson
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  5.94
# ------------------------------
# Word1:  focus
# Word2:  life
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  4.06
# ------------------------------
# Word1:  production
# Word2:  crew
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  6.25
# ------------------------------
# Word1:  television
# Word2:  film
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  7.72
# ------------------------------
# Word1:  lover
# Word2:  quarrel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  6.19
# ------------------------------
# Word1:  viewer
# Word2:  serial
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  2.97
# ------------------------------
# Word1:  possibility
# Word2:  girl
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  1.94
# ------------------------------
# Word1:  population
# Word2:  development
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  3.75
# ------------------------------
# Word1:  morality
# Word2:  importance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  3.31
# ------------------------------
# Word1:  morality
# Word2:  marriage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  3.69
# ------------------------------
# Word1:  Mexico
# Word2:  Brazil
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  7.44
# ------------------------------
# Word1:  gender
# Word2:  equality
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  6.41
# ------------------------------
# Word1:  change
# Word2:  attitude
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  5.44
# ------------------------------
# Word1:  family
# Word2:  planning
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  6.25
# ------------------------------
# Word1:  opera
# Word2:  industry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  2.63
# ------------------------------
# Word1:  sugar
# Word2:  approach
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.3121863889661687
# Human Similarity:  0.88
# ------------------------------
# Word1:  practice
# Word2:  institution
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  3.19
# ------------------------------
# Word1:  ministry
# Word2:  culture
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  4.69
# ------------------------------
# Word1:  problem
# Word2:  challenge
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.75
# ------------------------------
# Word1:  size
# Word2:  prominence
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  5.31
# ------------------------------
# Word1:  country
# Word2:  citizen
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  7.31
# ------------------------------
# Word1:  planet
# Word2:  people
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  5.75
# ------------------------------
# Word1:  development
# Word2:  issue
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  3.97
# ------------------------------
# Word1:  experience
# Word2:  music
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  3.47
# ------------------------------
# Word1:  music
# Word2:  project
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  3.63
# ------------------------------
# Word1:  glass
# Word2:  metal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  5.56
# ------------------------------
# Word1:  aluminum
# Word2:  metal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  7.83
# ------------------------------
# Word1:  chance
# Word2:  credibility
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  3.88
# ------------------------------
# Word1:  exhibit
# Word2:  memorabilia
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  5.31
# ------------------------------
# Word1:  concert
# Word2:  virtuoso
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  6.81
# ------------------------------
# Word1:  rock
# Word2:  jazz
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.59
# ------------------------------
# Word1:  museum
# Word2:  theater
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.19
# ------------------------------
# Word1:  observation
# Word2:  architecture
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  4.38
# ------------------------------
# Word1:  space
# Word2:  world
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  6.53
# ------------------------------
# Word1:  preservation
# Word2:  world
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  6.19
# ------------------------------
# Word1:  admission
# Word2:  ticket
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.69
# ------------------------------
# Word1:  shower
# Word2:  thunderstorm
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  6.31
# ------------------------------
# Word1:  shower
# Word2:  flood
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  1.6486586255873816
# Human Similarity:  6.03
# ------------------------------
# Word1:  weather
# Word2:  forecast
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  1.3121863889661687
# Human Similarity:  8.34
# ------------------------------
# Word1:  disaster
# Word2:  area
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  6.25
# ------------------------------
# Word1:  governor
# Word2:  office
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  6.34
# ------------------------------
# Word1:  architecture
# Word2:  century
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  3.78
# ------------------------------
# Pearson Correlation:  [[1.         0.26142012]
#  [0.26142012 1.        ]]
# Spearman Correlation:  SpearmanrResult(correlation=0.2651845536640065, pvalue=4.292887522518468e-07)

# %% [markdown]
# CONSEGNA 2.1:
#
# Estrarre 50 frasi dal corpus SemCor (corpus annotato con i synset di
# WN) e disambiguare (almeno) un sostantivo per frase.
#
# Calcolare
# l’accuratezza del sistema implementato sulla base dei sensi annotati in
# SemCor.

# %%
tokenizer = RegexpTokenizer(r'\w+')

INDEXES_NUM = 1000 #è il limite, partendo da 0, di sentence che possono essere testate relative al database SemCor
RANGE = 50 #è il numero di sentence che effettivamente verranno testate

sentences_tag = semcor.tagged_sents() #lista di liste. Ogni lista rappresenta una sentence e ad ogni parola della sentence è associato un pos tag
sentences = semcor.sents() #lista di liste di parole. Ogni lista rappresenta una sentence
sentences_sem = semcor.tagged_sents(tag = "sem") #lista di liste. Ogni lista rappresenta una sentence e ad ogni parola della sentence è associato un synset gold

def main():
    evaluated = 0 #termini valutati
    checked = 0 #termini valutati correttamente
    index_evaluated = set() #insieme degli indici già valutati
    while(evaluated <= RANGE):
        while True: #fino a quando non trova una word che ha almeno un senso in wordnet   
            index = get_random_index(index_evaluated, INDEXES_NUM)
            word = get_random_noun(get_dictionary_tag(sentences_tag[index],sentences_sem[index]))
            if word:
                break
        sentence = sentences[index]
        print("Parola da disambiguare: ",word)
        #all'algoritmo di lesk viene dato in input la word e l'insieme dei termini che formano la frase, uniti sottoforma di stringa
        best_sense = str(lesk_algorithm(word, ' '.join(word for word in sentence), word_type='NOUN'))
        print("Senso attribuito dall'algoritmo di Lesk: ",best_sense)
        target_lemma = get_synset_target_for_word_in_sentence(word,sentences_sem[index])
        print("Senso Target: ",target_lemma)
        best_sense_lemma = best_sense[8:len(best_sense)-2]
        if target_lemma:
            if best_sense_lemma in target_lemma:
             checked= checked + 1
        evaluated += 1
        print("------------------------------")
    
    print("Termini valutati: ", evaluated)
    print("Termini valutati correttamente: ", checked)
    print("Accuratezza: ", checked/RANGE)
    
main()
# Out:
# Parola da disambiguare:  drive
# Frase in cui compare la parola:  Over the first five frames , Jack Fisher , the big righthander who figures to be in the middle of Oriole plans for a drive on the 1961 American League pennant , held the A 's scoreless while yielding three scattered hits .
# Contesto della frase:  {'middle', 'plan', 'league', 'oriole', 'figure', 'jack', 'frame', 'scoreless', 'yield', 'hit', 'drive', 'american', 'scatter', 'hold', 'righthander', 'fisher', 'pennant', 'big'}
# Max Signature:  {'campaign', 'principle', 'work', 'support', 'advance', 'peace', 'slavery', 'movement', 'war', 'effort', 'series', 'tend', 'contribute', 'action', 'pennant', 'ready', 'populist', 'team', 'drive'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('campaign.n.02')
# Senso Target:  Lemma('campaign.n.02.drive')
# ------------------------------
# Parola da disambiguare:  election
# Frase in cui compare la parola:  During the election campaign , both candidates , Davis and Bush , reportedly received anonymous telephone calls .
# Contesto della frase:  {'candidate', 'election', 'anonymous', 'telephone', 'campaign', 'reportedly', 'bush', 'receive', 'davis', 'call'}
# Max Signature:  {'office', 'vote', 'election', 'select', 'political', 'result', 'tonight', 'winner', 'position'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('election.n.01')
# Senso Target:  Lemma('election.n.01.election')
# ------------------------------
# Parola da disambiguare:  play
# Frase in cui compare la parola:  When Robinson tried to stretch his blow into a triple , he was cut down in a close play at third , Tuttle to Andy Carey .
# Contesto della frase:  {'play', 'robinson', 'andy', 'cut', 'tuttle', 'triple', 'blow', 'third', 'stretch', 'close', 'carey'}
# Max Signature:  {'work', 'play', 'produce', 'performance', 'broadway', 'stage', 'actor', 'intend', 'dramatic', 'write'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('play.n.01')
# Senso Target:  Lemma('play.n.03.play')
# ------------------------------
# Parola da disambiguare:  liner
# Frase in cui compare la parola:  Lemon was on with his fourth single of the game , a liner to center .
# Contesto della frase:  {'fourth', 'single', 'center', 'game', 'liner', 'lemon'}
# Max Signature:  {'fly', 'baseball', 'batter', 'straight', 'shortstop', 'hit', 'liner'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('liner.n.01')
# Senso Target:  Lemma('liner.n.01.liner')
# ------------------------------
# Parola da disambiguare:  newspapers
# Frase in cui compare la parola:  A couple of days later a balletomane told me he had telephoned Allied Arts for ticket information and was told `` the newspapers had made a mistake '' .
# Contesto della frase:  {'arts', 'ticket', 'couple', 'day', 'telephone', 'mistake', 'newspaper', 'balletomane', 'allied'}
# Max Signature:  {'print', 'paper', 'day', 'wood', 'newspaper', 'cheap', 'pulp', 'bale'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('newspaper.n.04')
# Senso Target:  Lemma('newspaper.n.01.newspaper')
# ------------------------------
# Parola da disambiguare:  ball
# Frase in cui compare la parola:  The Texans made themselves a comforting break on the opening kickoff when Denver 's Al Carmichael was jarred loose from the ball when Dave Grayson , the speedy halfback , hit him and Guard Al Reynolds claimed it for Dallas .
# Contesto della frase:  {'reynolds', 'loose', 'break', 'halfback', 'hit', 'dave', 'texans', 'claim', 'grayson', 'al', 'speedy', 'opening', 'denver', 'ball', 'carmichael', 'jar', 'comfort', 'guard', 'kickoff', 'dallas'}
# Max Signature:  {'pocket', 'ball', 'kick', 'roll', 'mph', 'corner', 'hit', 'serve', 'travel', 'round', 'object', 'mayor', 'game', 'throw'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('ball.n.01')
# Senso Target:  Lemma('ball.n.01.ball')
# ------------------------------
# Parola da disambiguare:  escalation
# Frase in cui compare la parola:  And now , of course , the hue and cry for counter escalation is being raised on our side .
# Contesto della frase:  {'cry', 'hue', 'side', 'raise', 'counter', 'course', 'escalation'}
# Max Signature:  {'increase', 'wage', 'gradual', 'discrepancy', 'hostility', 'high', 'perceived', 'counteract', 'price', 'escalation'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('escalation.n.01')
# Senso Target:  Lemma('escalation.n.01.escalation')
# ------------------------------
# Parola da disambiguare:  tallies
# Frase in cui compare la parola:  The Flock added a pair of tallies in the third on three straight hits after two were out .
# Contesto della frase:  {'flock', 'add', 'straight', 'pair', 'hit', 'third', 'tally'}
# Max Signature:  {'safely', 'base', 'runner', 'baseball', 'score', 'inning', 'tally', 'yankees', 'bottom', 'touch'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('run.n.01')
# Senso Target:  Lemma('run.n.01.tally')
# ------------------------------
# Parola da disambiguare:  residents
# Frase in cui compare la parola:  Nearly 18 per cent of West Berlin 's 2200000 residents are sixty-five or older , only 12.8 per cent are under fifteen .
# Contesto della frase:  {'berlin', 'fifteen', 'sixtyfive', 'west', 'cent', 'resident'}
# Max Signature:  {'care', 'live', 'clinical', 'medical', 'physician', 'intern', 'hospital', 'supervision', 'patient', 'special', 'staff', 'training', 'hospitalized', 'receive', 'resident'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('house_physician.n.01')
# Senso Target:  Lemma('resident.n.01.resident')
# ------------------------------
# Parola da disambiguare:  inch
# Frase in cui compare la parola:  The 6 - foot 3 inch Hansen checked in close to 200 pounds , 15 pounds lighter than his reporting weight last spring .
# Contesto della frase:  {'reporting', 'lighter', 'hansen', 'foot', 'pound', 'spring', 'check', 'close', 'inch', 'weight'}
# Max Signature:  {'equal', 'foot', 'length', 'twelfth', 'unit'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('inch.n.01')
# Senso Target:  Lemma('inch.n.01.inch')
# ------------------------------
# Parola da disambiguare:  pack
# Frase in cui compare la parola:  They now lead Louisville by a full game on top of the American Association pack .
# Contesto della frase:  {'association', 'top', 'full', 'pack', 'lead', 'louisville', 'american', 'game'}
# Max Signature:  {'gang', 'thief', 'association', 'break', 'pack', 'police', 'criminal'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('gang.n.01')
# Senso Target:  Lemma('pack.n.02.pack')
# ------------------------------
# Parola da disambiguare:  guys
# Frase in cui compare la parola:  It was a real stimulant to a lot of guys I know who have moved past the 2 - score year milestone .
# Contesto della frase:  {'move', 'real', 'guy', 'milestone', 'score', 'year', 'stimulant', 'lot'}
# Max Signature:  {'man', 'guy', 'doll', 'informal', 'term', 'nice', 'youth'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('guy.n.01')
# Senso Target:  Lemma('guy.n.01.guy')
# ------------------------------
# Parola da disambiguare:  16
# Frase in cui compare la parola:  He had a 16 .
# Contesto della frase:  set()
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('sixteen.n.01')
# Senso Target:  Lemma('sixteen.n.01.16')
# ------------------------------
# Parola da disambiguare:  Practice
# Frase in cui compare la parola:  Practice helps you to get your timing down .
# Contesto della frase:  {'help', 'time', 'practice'}
# Max Signature:  {'behavior', 'dietary', 'practice', 'raise', 'customary', 'change', 'annual', 'pattern', 'operation'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('practice.n.01')
# Senso Target:  Lemma('exercise.n.03.practice')
# ------------------------------
# Parola da disambiguare:  paragon
# Frase in cui compare la parola:  If such a paragon of perfection as Palmer could commit such a scoring sacrilege , there was hope left for all .
# Contesto della frase:  {'paragon', 'commit', 'left', 'score', 'perfection', 'hope', 'palmer', 'sacrilege'}
# Max Signature:  {'excellence', 'equal', 'kind', 'model', 'perfection'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('ideal.n.02')
# Senso Target:  Lemma('paragon.n.01.paragon')
# ------------------------------
# Parola da disambiguare:  dollars
# Frase in cui compare la parola:  Daniel termed `` extremely conservative '' his estimate that it would produce 17 million dollars to help erase an anticipated deficit of 63 million dollars at the end of the current fiscal year next Aug. 31 .
# Contesto della frase:  {'fiscal', 'produce', 'year', 'aug', 'help', 'daniel', 'extremely', 'erase', 'current', 'estimate', 'dollar', 'conservative', 'deficit', 'term', 'anticipated'}
# Max Signature:  {'piece', 'paper', 'money', 'dollar'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('dollar.n.02')
# Senso Target:  Lemma('dollar.n.01.dollar')
# ------------------------------
# Parola da disambiguare:  releases
# Frase in cui compare la parola:  The program was instituted in 1940 , and releases are available only from the Recording Laboratory of the Library of Congress , Washington 25 , D. C. A catalogue is available on request .
# Contesto della frase:  {'catalogue', 'program', 'request', 'laboratory', 'release', 'congress', 'recording', 'institute', 'library', 'washington'}
# Max Signature:  {'issue', 'london', 'public', 'symphony', 'orchestra', 'merchandise', 'release', 'film', 'showing', 'sale', 'record'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('release.n.01')
# Senso Target:  Lemma('release.n.01.release')
# ------------------------------
# Parola da disambiguare:  times
# Frase in cui compare la parola:  His statistical record that year , when Texas won only one game and lost nine , was far from impressive : he carried the ball three times for a net gain of 10 yards , punted once for 39 yards and caught one pass for 13 yards .
# Contesto della frase:  {'record', 'impressive', 'carry', 'ball', 'time', 'gain', 'catch', 'yard', 'game', 'pas', 'lose', 'net', 'texas', 'statistical', 'punt', 'year', 'win'}
# Max Signature:  {'year', 'specific', 'time', 'mark', 'plant', 'indefinite', 'activity', 'actor', 'period', 'attribute', 'wait', 'great', 'long'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('time.n.03')
# Senso Target:  Lemma('time.n.01.time')
# ------------------------------
# Parola da disambiguare:  hamlet
# Frase in cui compare la parola:  Rep. James Cotten of Weatherford insisted that a water development bill passed by the Texas House of Representatives was an effort by big cities like Dallas and Fort Worth to cover up places like Paradise , a Wise County hamlet of 250 people .
# Contesto della frase:  {'water', 'development', 'representatives', 'rep', 'fort', 'texas', 'city', 'cotten', 'weatherford', 'insist', 'james', 'cover', 'paradise', 'big', 'pass', 'house', 'effort', 'hamlet', 'worth', 'county', 'wise', 'bill', 'place', 'people', 'dallas'}
# Max Signature:  {'people', 'village', 'small', 'community'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('hamlet.n.01')
# Senso Target:  Lemma('hamlet.n.01.hamlet')
# ------------------------------
# Parola da disambiguare:  center
# Frase in cui compare la parola:  With a lefthander going for Pittsburgh , I may use Don Taussig in center '' .
# Contesto della frase:  {'lefthander', 'center', 'don', 'taussig', 'pittsburgh'}
# Max Signature:  {'forward', 'center', 'large', 'region', 'town', 'central', 'area', 'storm', 'eye', 'heart', 'struggle'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('center.n.01')
# Senso Target:  Lemma('center_field.n.01.center')
# ------------------------------
# Parola da disambiguare:  Texans
# Frase in cui compare la parola:  State representatives decided Thursday against taking a poll on what kind of taxes Texans would prefer to pay .
# Contesto della frase:  {'kind', 'prefer', 'pay', 'decide', 'representative', 'thursday', 'tax', 'poll', 'texans'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('texan.n.01')
# Senso Target:  Lemma('texan.n.01.Texan')
# ------------------------------
# Parola da disambiguare:  doctrine
# Frase in cui compare la parola:  The doctrine has never worked ; it is not working now .
# Contesto della frase:  {'work', 'doctrine'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('doctrine.n.01')
# Senso Target:  Lemma('doctrine.n.01.doctrine')
# ------------------------------
# Parola da disambiguare:  surprise
# Frase in cui compare la parola:  The rangy , Albany ( Cal. ) native , a surprise slugging sensation for the Flock last year as well as a defensive whiz , set `` improved fielding '' as his 1961 goal .
# Contesto della frase:  {'goal', 'cal', 'slug', 'defensive', 'flock', 'fielding', 'sensation', 'surprise', 'albany', 'improved', 'well', 'set', 'whiz', 'year', 'native', 'rangy'}
# Max Signature:  {'surprise'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('surprise.n.03')
# Senso Target:  Lemma('surprise.n.02.surprise')
# ------------------------------
# Parola da disambiguare:  awarding
# Frase in cui compare la parola:  The jury also commented on the Fulton ordinary 's court which has been under fire for its practices in the appointment of appraisers , guardians and administrators and the awarding of fees and compensation .
# Contesto della frase:  {'guardian', 'comment', 'practice', 'appointment', 'compensation', 'fee', 'fulton', 'administrator', 'court', 'ordinary', 'jury', 'appraiser', 'awarding', 'fire'}
# Max Signature:  {'compensation', 'criticize', 'court', 'law', 'grant', 'awarding'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('award.n.01')
# Senso Target:  Lemma('award.n.01.awarding')
# ------------------------------
# Parola da disambiguare:  game
# Frase in cui compare la parola:  He kicked several while playing at Stamford High School , including one that beat Anson , 3 - 0 , in a 1953 district game .
# Contesto della frase:  {'play', 'beat', 'kick', 'include', 'stamford', 'district', 'high', 'school', 'game', 'anson'}
# Max Signature:  {'play', 'contest', 'people', 'winner', 'game', 'rule', 'determine'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('game.n.01')
# Senso Target:  Lemma('game.n.02.game')
# ------------------------------
# Parola da disambiguare:  Senate
# Frase in cui compare la parola:  The House passed finally , and sent to the Senate , a bill extending the State Health Department 's authority to give planning assistance to cities .
# Contesto della frase:  {'send', 'senate', 'pass', 'house', 'bill', 'department', 'assistance', 'finally', 'planning', 'authority', 'health', 'city', 'extend'}
# Max Signature:  {'congress', 'united', 'upper', 'house'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('united_states_senate.n.01')
# Senso Target:  Lemma('senate.n.01.senate')
# ------------------------------
# Parola da disambiguare:  town
# Frase in cui compare la parola:  Despite the recession , Pittsburgh came into town with this imposing list of averages : Smoky Burgess .455 , Gino Cimoli .389 , Bill Virdon .340 , Bob Clemente and Dick Groat , each .323 , Dick Stuart .306 , Don Hoak .280 and Bob Skinner .267 .
# Contesto della frase:  {'burgess', 'pittsburgh', 'virdon', 'smoky', 'average', 'skinner', 'groat', 'town', 'gino', 'bob', 'dick', 'impose', 'recession', 'bill', 'clemente', 'stuart', 'don', 'hoak', 'list', 'cimoli'}
# Max Signature:  {'work', 'town', 'small', 'boundary', 'fixed', 'area', 'urban', 'drive', 'city'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('town.n.01')
# Senso Target:  Lemma('town.n.01.town')
# ------------------------------
# Parola da disambiguare:  foot
# Frase in cui compare la parola:  Breeding to Adair to Gentile , setting up Tuttle 's 390 - foot homer over the wall in left center .
# Contesto della frase:  {'tuttle', 'adair', 'homer', 'foot', 'left', 'center', 'gentile', 'wall', 'breeding', 'set'}
# Max Signature:  {'trouser', 'foot', 'armor', 'project', 'bare', 'joint', 'head', 'human', 'ankle', 'leg'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('foot.n.01')
# Senso Target:  Lemma('foot.n.02.foot')
# ------------------------------
# Parola da disambiguare:  Georgia
# Frase in cui compare la parola:  The jury said it did find that many of Georgia 's registration and election laws `` are outmoded or inadequate and often ambiguous '' .
# Contesto della frase:  {'inadequate', 'election', 'georgia', 'find', 'jury', 'outmode', 'law', 'registration', 'ambiguous'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('georgia.n.01')
# Senso Target:  Lemma('georgia.n.01.Georgia')
# ------------------------------
# Parola da disambiguare:  yard
# Frase in cui compare la parola:  He boomed a 280 - yard drive .
# Contesto della frase:  {'drive', 'boom', 'yard'}
# Max Signature:  {'house', 'land', 'small', 'yard', 'building', 'enclosed'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('yard.n.02')
# Senso Target:  Lemma('yard.n.01.yard')
# ------------------------------
# Parola da disambiguare:  Boston
# Frase in cui compare la parola:  Bobby Lowe of Boston was the first to hit four at home and Gil Hodges turned the trick in Brooklyn 's Ebbetts Field .
# Contesto della frase:  {'ebbetts', 'hodges', 'lowe', 'gil', 'boston', 'trick', 'brooklyn', 'hit', 'field', 'bobby', 'turn'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('boston.n.01')
# Senso Target:  Lemma('boston.n.01.Boston')
# ------------------------------
# Parola da disambiguare:  formula
# Frase in cui compare la parola:  A formula to supply players for the new Minneapolis Vikings and the problem of increasing the 1961 schedule to fourteen games will be discussed by National Football League owners at a meeting at the Hotel Warwick today .
# Contesto della frase:  {'meeting', 'increase', 'problem', 'discuss', 'league', 'football', 'hotel', 'schedule', 'supply', 'owner', 'warwick', 'national', 'vikings', 'formula', 'today', 'game', 'minneapolis', 'player', 'fourteen'}
# Max Signature:  {'bound', 'attack', 'descartes', 'polynomial', 'standard', 'general', 'problem', 'formula', 'mathematics', 'mathematical', 'solve', 'sign', 'class', 'procedure', 'rule', 'upper', 'determine'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('rule.n.11')
# Senso Target:  Lemma('recipe.n.01.formula')
# ------------------------------
# Parola da disambiguare:  Tuesday
# Frase in cui compare la parola:  Sam Caldwell , State Highway Department public relations director , resigned Tuesday to work for Lt. Gov. Garland Byrd 's campaign .
# Contesto della frase:  {'work', 'tuesday', 'highway', 'department', 'public', 'garland', 'gov', 'campaign', 'resign', 'director', 'byrd', 'sam', 'lt', 'relation', 'caldwell'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('tuesday.n.01')
# Senso Target:  Lemma('tuesday.n.01.Tuesday')
# ------------------------------
# Parola da disambiguare:  coach
# Frase in cui compare la parola:  Nick Skorich , the line coach for the football champion Philadelphia Eagles , was elevated today to head coach .
# Contesto della frase:  {'football', 'coach', 'eagles', 'elevate', 'skorich', 'champion', 'head', 'nick', 'today', 'philadelphia'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('coach.n.01')
# Senso Target:  Lemma('coach.n.01.coach')
# ------------------------------
# Parola da disambiguare:  doubles
# Frase in cui compare la parola:  Dick McAuliffe cracked the first of his two doubles against Lefty Don Rudolph to open the Bear 's attack .
# Contesto della frase:  {'dick', 'crack', 'mcauliffe', 'attack', 'don', 'lefty', 'rudolph', 'open', 'bear', 'double'}
# Max Signature:  {'safely', 'base', 'deep', 'batter', 'hit', 'second', 'double', 'centerfield'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('double.n.01')
# Senso Target:  Lemma('double.n.01.double')
# ------------------------------
# Parola da disambiguare:  brace
# Frase in cui compare la parola:  writes : Does a brace help in sciatica ?
# Contesto della frase:  {'brace', 'help', 'sciatica', 'writes'}
# Max Signature:  {'wear', 'strengthen', 'steady', 'knee', 'support', 'brace'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('brace.n.01')
# Senso Target:  Lemma('brace.n.01.brace')
# ------------------------------
# Parola da disambiguare:  performance
# Frase in cui compare la parola:  I remember his beardown performance in a meaningless exhibition game at Bears Stadium Oct. 14 , 1951 , before a new record crowd for the period of 18792 .
# Contesto della frase:  {'performance', 'remember', 'stadium', 'exhibition', 'bears', 'oct', 'crowd', 'period', 'meaningless', 'beardown', 'game', 'record'}
# Max Signature:  {'stress', 'performance', 'maris', 'admire', 'merit', 'awe', 'power', 'accomplishment', 'recognize', 'game', 'roger'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('performance.n.04')
# Senso Target:  Lemma('performance.n.03.performance')
# ------------------------------
# Parola da disambiguare:  countryman
# Frase in cui compare la parola:  Another is a wily countryman called Larkin , whose blandly boisterous progress has been chronicled , I believe , in earlier volumes of Mr. Bates ' comedie humaine .
# Contesto della frase:  {'countryman', 'blandly', 'bates', 'humaine', 'early', 'wily', 'boisterous', 'volume', 'larkin', 'comedie', 'chronicle', 'progress', 'call'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('countryman.n.01')
# Senso Target:  Lemma('countryman.n.01.countryman')
# ------------------------------
# Parola da disambiguare:  offices
# Frase in cui compare la parola:  However , the jury said it believes `` these two offices should be combined to achieve greater efficiency and reduce the cost of administration '' .
# Contesto della frase:  {'office', 'combine', 'reduce', 'efficiency', 'jury', 'great', 'achieve', 'cost', 'administration'}
# Max Signature:  {'candidate', 'office', 'year', 'president', 'advantage', 'great', 'power', 'government', 'hold', 'official'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('office.n.04')
# Senso Target:  Lemma('agency.n.01.office')
# ------------------------------
# Parola da disambiguare:  enemy
# Frase in cui compare la parola:  If this capacity had not failed them , they would see that their enemy has made a disastrous miscalculation .
# Contesto della frase:  {'fail', 'enemy', 'miscalculation', 'disastrous', 'capacity'}
# Max Signature:  {'military', 'oppose', 'attack', 'force', 'dawn', 'enemy'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('enemy.n.01')
# Senso Target:  Lemma('enemy.n.01.enemy')
# ------------------------------
# Parola da disambiguare:  victories
# Frase in cui compare la parola:  Then last season the Birds tumbled as low as 11 - 18 on May 19 before recovering to make a race of it and total 86 victories .
# Contesto della frase:  {'race', 'low', 'victory', 'tumble', 'season', 'recover', 'total', 'birds'}
# Max Signature:  {'convince', 'contest', 'triumph', 'successful', 'victory', 'clinch', 'narrow', 'common', 'sense', 'general', 'credit', 'army', 'struggle', 'agreement'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('victory.n.01')
# Senso Target:  Lemma('victory.n.01.victory')
# ------------------------------
# Parola da disambiguare:  war
# Frase in cui compare la parola:  The nuclear war is already being fought , except that the bombs are not being dropped on enemy targets - not yet .
# Contesto della frase:  {'bomb', 'drop', 'target', 'enemy', 'war', 'fight', 'nuclear'}
# Max Signature:  {'armed', 'waging', 'people', 'conflict', 'war', 'enemy', 'kill'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('war.n.01')
# Senso Target:  Lemma('war.n.02.war')
# ------------------------------
# Parola da disambiguare:  year
# Frase in cui compare la parola:  A year later they were 4 - 13 .
# Contesto della frase:  {'year'}
# Max Signature:  {'period', 'year', 'time', 'day'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('year.n.01')
# Senso Target:  Lemma('year.n.01.year')
# ------------------------------
# Parola da disambiguare:  waste
# Frase in cui compare la parola:  The Lenin tomb is obviously adequate for double occupancy , Moscow is a crowded city , and the creed of communism deplores waste .
# Contesto della frase:  {'double', 'communism', 'adequate', 'moscow', 'creed', 'deplores', 'crowded', 'lenin', 'occupancy', 'city', 'tomb', 'waste'}
# Max Signature:  {'sewer', 'unwanted', 'reject', 'collect', 'week', 'carry', 'waste', 'material', 'unused', 'worthless'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('waste.n.01')
# Senso Target:  Lemma('waste.n.02.waste')
# ------------------------------
# Parola da disambiguare:  games
# Frase in cui compare la parola:  Tailback James Saxton already has surpassed his rushing total for his brilliant sophomore season , when he netted 271 yards on 55 carries ; he now has 273 yards in 22 tries during three games .
# Contesto della frase:  {'carry', 'rush', 'brilliant', 'surpass', 'james', 'sophomore', 'saxton', 'yard', 'game', 'season', 'tailback', 'net', 'total'}
# Max Signature:  {'play', 'contest', 'people', 'winner', 'game', 'rule', 'determine'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('game.n.01')
# Senso Target:  Lemma('game.n.02.game')
# ------------------------------
# Parola da disambiguare:  hearing
# Frase in cui compare la parola:  The West Texan reported that he had finally gotten Chairman Bill Hollowell of the committee to set it for public hearing on Feb. 22 .
# Contesto della frase:  {'feb', 'report', 'bill', 'public', 'finally', 'chairman', 'committee', 'west', 'set', 'texan', 'hearing', 'hollowell'}
# Max Signature:  {'hearing', 'grand', 'witness', 'testimony', 'committee', 'jury', 'chicago', 'investigative', 'hold', 'session', 'call'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('hearing.n.05')
# Senso Target:  Lemma('hearing.n.01.hearing')
# ------------------------------
# Parola da disambiguare:  night
# Frase in cui compare la parola:  In the ninth , Robinson led off with his second double of the night , a blast off the fence 375 feet deep into left .
# Contesto della frase:  {'blast', 'robinson', 'left', 'foot', 'fence', 'ninth', 'deep', 'lead', 'second', 'double', 'night'}
# Max Signature:  {'period', 'spend', 'restless', 'sleep', 'night'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('night.n.03')
# Senso Target:  Lemma('night.n.01.night')
# ------------------------------
# Parola da disambiguare:  perforations
# Frase in cui compare la parola:  Many styles have perforations and an almost weightlessness achieved via unlined leathers .
# Contesto della frase:  {'perforation', 'unlined', 'style', 'leather', 'weightlessness', 'achieve'}
# Max Signature:  {'eardrum', 'perforation', 'hole'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('perforation.n.02')
# Senso Target:  Lemma('perforation.n.01.perforation')
# ------------------------------
# Parola da disambiguare:  ball
# Frase in cui compare la parola:  `` We always like to keep the ball as much as we can against Denver because they have such an explosive attack '' , explained Stram .
# Contesto della frase:  {'denver', 'ball', 'explosive', 'attack', 'explain', 'stram'}
# Max Signature:  {'pocket', 'ball', 'kick', 'roll', 'mph', 'corner', 'hit', 'serve', 'travel', 'round', 'object', 'mayor', 'game', 'throw'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('ball.n.01')
# Senso Target:  Lemma('ball.n.01.ball')
# ------------------------------
# Parola da disambiguare:  account
# Frase in cui compare la parola:  `` If the day should ever come that foreign invaders swarm ashore along the Gulf Coast '' , the account reads , `` they can count on heavy opposition from a group of commando trained telephone employees - all girls .
# Contesto della frase:  {'group', 'gulf', 'coast', 'day', 'train', 'opposition', 'telephone', 'ashore', 'employee', 'count', 'girl', 'heavy', 'account', 'read', 'foreign', 'swarm', 'invader', 'commando'}
# Max Signature:  {'story', 'plot', 'event', 'exposure', 'president', 'history', 'description', 'account', 'lead', 'france', 'inaccurate', 'narrative', 'kill', 'record'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('history.n.02')
# Senso Target:  Lemma('explanation.n.01.account')
# ------------------------------
# Parola da disambiguare:  inch
# Frase in cui compare la parola:  A 208 - pound , 6 - foot 1 - inch senior from Stamford , Moritz practices nothing but place-kicking .
# Contesto della frase:  {'practice', 'foot', 'stamford', 'pound', 'placekicking', 'senior', 'inch', 'moritz'}
# Max Signature:  {'equal', 'foot', 'length', 'twelfth', 'unit'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('inch.n.01')
# Senso Target:  Lemma('inch.n.01.inch')
# ------------------------------
# Termini valutati:  51
# Termini valutati correttamente:  27
# Accuratezza:  0.54

# %% [markdown]
# CONSEGNA 2.2:
#
# Randomizzare la selezione delle 50 frasi e la selezione del termine da
# disambiguare, e restituire l’accuratezza media su (per esempio) 10
# esecuzioni del programma.

# %%
tokenizer = RegexpTokenizer(r'\w+')

EXECUTIONS = 10 #numero massimo di esecuzioni
INDEXES_NUM = 7000 #è il limite, partendo da 0, di sentence che possono essere testate relative al database SemCor
RANGE = 50 #è il numero di sentence che effettivamente verranno testate in ogni esecuzione        

sentences_tag = semcor.tagged_sents()
sentences = semcor.sents()
sentences_sem = semcor.tagged_sents(tag = "sem")

def main():
    accuracy_list = []
    for execution in range(1,EXECUTIONS + 1):
        evaluated = 0 #termini valutati
        checked = 0 #termini valutati correttamente
        index_evaluated = set() #insieme degli indici già valutati
        while(evaluated <= RANGE):
            while True: #fino a quando non trova una word che può essere presa in considerazione  
                index = get_random_index(index_evaluated, INDEXES_NUM)
                word = get_random_word(get_dictionary_tag(sentences_tag[index],sentences_sem[index]))
                if word:
                    break
            sentence = sentences[index]
            print("Parola da disambiguare: ",word)
            #all'algoritmo di lesk viene dato in input la word e l'insieme dei termini che formano la frase, uniti sottoforma di stringa
            best_sense = str(lesk_algorithm(word, ' '.join(word for word in sentence), word_type='ALL'))
            print("Senso attribuito dall'algoritmo di Lesk: ",best_sense)
            target_lemma = get_synset_target_for_word_in_sentence(word,sentences_sem[index])
            print("Senso Target: ",target_lemma)
            best_sense_lemma = best_sense[8:len(best_sense)-2]
            if target_lemma:
                if best_sense_lemma in target_lemma:
                 checked= checked + 1
            evaluated += 1
            print("------------------------------")
        
        print("Termini valutati: ", evaluated)
        print("Termini valutati correttamente: ", checked)
        accuracy = checked/RANGE
        print("Accuratezza: ", accuracy)
        accuracy_list.append(accuracy)
        
    print()
    print("Esecuzioni: ",EXECUTIONS)
    print("Lista delle accuratezze: ", accuracy_list)
    print("Accuratezza media: ",mean(accuracy_list))
    
main()
# Out:
# Parola da disambiguare:  epiphysis
# Frase in cui compare la parola:  For example , arrow 17 in Figure 3 portrays the proximal radial epiphysis for boy 34 , whereas the same epiphysis for girl 2 is portrayed by arrow 18 in Figure 4 .
# Contesto della frase:  {'radial', 'portray', 'example', 'figure', 'epiphysis', 'proximal', 'arrow', 'girl', 'boy'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('epiphysis.n.01')
# Senso Target:  Lemma('epiphysis.n.01.epiphysis')
# ------------------------------
# Parola da disambiguare:  led
# Frase in cui compare la parola:  In 1931 Mrs. F. H. Briggs , agent and chief operator , who was to retire in 1946 with thirty years ' service , led agency offices in sales for the year with $ 2490 .
# Contesto della frase:  {'chief', 'office', 'service', 'agent', 'briggs', 'operator', 'thirty', 'agency', 'lead', 'year', 'sale', 'retire'}
# Max Signature:  {'main', 'chief', 'conduct', 'entrance', 'lead', 'palace'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('lead.v.01')
# Senso Target:  Lemma('lead.v.08.lead')
# ------------------------------
# Parola da disambiguare:  contour
# Frase in cui compare la parola:  These contour diagrams also suggest a rather rapid falloff in the radio brightness with latitude .
# Contesto della frase:  {'rapid', 'contour', 'diagram', 'latitude', 'brightness', 'radio', 'falloff'}
# Max Signature:  {'contour', 'complex', 'feature', 'structure', 'major', 'define', 'order', 'arrangement', 'melody', 'administration'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('contour.n.03')
# Senso Target:  Lemma('contour.n.01.contour')
# ------------------------------
# Parola da disambiguare:  March
# Frase in cui compare la parola:  Carl Kauffeld has written to me of sexual activity in February 1943 of young born in March 1940 .
# Contesto della frase:  {'sexual', 'february', 'kauffeld', 'young', 'activity', 'march', 'bear', 'carl', 'write'}
# Max Signature:  {'music', 'march', 'best', 'genre', 'write', 'sousa'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('marching_music.n.01')
# Senso Target:  Lemma('march.n.01.March')
# ------------------------------
# Parola da disambiguare:  sweet
# Frase in cui compare la parola:  Oh , sweet land of heaven , haint there just nothin like sweet nigger pussy !
# Contesto della frase:  {'sweet', 'land', 'pussy', 'haint', 'heaven', 'nigger'}
# Max Signature:  {'angel', 'nature', 'sweet', 'cherubic', 'cherub', 'smile', 'seraphic', 'angelic', 'face', 'befit', 'sleep', 'disposition'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('angelic.s.03')
# Senso Target:  Lemma('sweet.a.01.sweet')
# ------------------------------
# Parola da disambiguare:  7
# Frase in cui compare la parola:  It will be recalled from the discussion in Section 7 that the position of the `` right '' , as represented by Barth , rests on the following thesis : The only tenable alternative to Bultmann 's position is a theology that ( 1 ) rejects or at least qualifies his unconditioned demand for demythologization and existential interpretation ; ( 2 ) accepts instead a special biblical hermeneutics or method of interpretation ; and ( 3 ) in so doing , frees itself to give appropriate emphasis to the event Jesus Christ by means of statements that , from Bultmann 's point of view , are mythological .
# Contesto della frase:  {'biblical', 'reject', 'method', 'jesus', 'event', 'hermeneutics', 'discussion', 'bultmann', 'existential', 'appropriate', 'interpretation', 'recall', 'qualifies', 'rest', 'free', 'thesis', 'statement', 'christ', 'theology', 'emphasis', 'unconditioned', 'demand', 'alternative', 'tenable', 'demythologization', 'view', 'mythological', 'accepts', 'represent', 'barth', 'point', 'special', 'position'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('seven.n.01')
# Senso Target:  Lemma('seven.s.01.7')
# ------------------------------
# Parola da disambiguare:  learned
# Frase in cui compare la parola:  The chief , annoyed by these questions , knocks Voltaire down and shouts at him that he not only never went to any school , but never even learned how to read .
# Contesto della frase:  {'chief', 'learn', 'voltaire', 'knock', 'shout', 'question', 'annoy', 'read', 'school'}
# Max Signature:  {'sanskrit', 'learn', 'dance', 'acquire', 'language', 'gain', 'amazing', 'skill', 'rate', 'knowledge', 'sister', 'children'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('learn.v.01')
# Senso Target:  Lemma('learn.v.01.learn')
# ------------------------------
# Parola da disambiguare:  loathed
# Frase in cui compare la parola:  How he loathed him .
# Contesto della frase:  {'loathe'}
# Max Signature:  {'man', 'repugnant', 'loathe', 'find', 'cat', 'abhors'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('abhor.v.01')
# Senso Target:  Lemma('abhor.v.01.loathe')
# ------------------------------
# Parola da disambiguare:  real
# Frase in cui compare la parola:  Well , sir , they did real great !
# Contesto della frase:  {'sir', 'real', 'great', 'well'}
# Max Signature:  {'play', 'intensifier', 'real', 'gifted', 'rattle', 'informal', 'good', 'informally', 'evening', 'enjoyable', 'well', 'yarn'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('very.r.01')
# Senso Target:  Lemma('very.r.01.real')
# ------------------------------
# Parola da disambiguare:  constantly
# Frase in cui compare la parola:  Stevie was constantly slipping into the church .
# Contesto della frase:  {'stevie', 'slip', 'constantly', 'church'}
# Max Signature:  {'kind', 'case', 'time', 'arrive', 'gracious', 'constantly', 'change', 'variation'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('constantly.r.01')
# Senso Target:  constantly.r.00
# ------------------------------
# Parola da disambiguare:  form
# Frase in cui compare la parola:  The discovery that movies are a form of fiction was made in the early years of this century and it was made chiefly by two men , a French magician , Georges Melies , and an American employee of Edison , Edwin S. Porter .
# Contesto della frase:  {'fiction', 'chiefly', 'melies', 'magician', 'georges', 'early', 'french', 'employee', 'movie', 'porter', 'discovery', 'century', 'edison', 'american', 'year', 'form', 'edwin', 'men'}
# Max Signature:  {'word', 'attach', 'identify', 'phonological', 'orthographic', 'inflection', 'represent', 'inflected', 'stem', 'appearance', 'describe', 'list', 'sound', 'form'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('form.n.01')
# Senso Target:  Lemma('kind.n.01.form')
# ------------------------------
# Parola da disambiguare:  antibodies
# Frase in cui compare la parola:  The serum containing the mixed type of complete and incomplete antibodies showed activity in both regions ( Fig. 1 ) .
# Contesto della frase:  {'complete', 'incomplete', 'region', 'serum', 'activity', 'type', 'fig', 'antibody', 'mixed'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('antibody.n.01')
# Senso Target:  Lemma('antibody.n.01.antibody')
# ------------------------------
# Parola da disambiguare:  definitely
# Frase in cui compare la parola:  For the case of Jupiter , the radio emission spectrum is definitely not like the spectrum of a black-body radiator , and it seems very likely that the radiation reaching the earth is a combination of thermal radiation from the atmosphere and non thermal components .
# Contesto della frase:  {'reach', 'case', 'definitely', 'earth', 'blackbody', 'component', 'thermal', 'radiator', 'jupiter', 'atmosphere', 'spectrum', 'combination', 'radio', 'emission', 'radiation'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('decidedly.r.01')
# Senso Target:  Lemma('decidedly.r.01.definitely')
# ------------------------------
# Parola da disambiguare:  sleep
# Frase in cui compare la parola:  If we manage to keep track of a Bombus queen after she has left her feeding place , we may discover the snug little hideout which she has fixed up for herself when she woke up from her winter sleep .
# Contesto della frase:  {'track', 'bombus', 'leave', 'sleep', 'manage', 'place', 'hideout', 'wake', 'winter', 'feeding', 'queen', 'discover', 'snug'}
# Max Signature:  {'dreamless', 'suspend', 'slumber', 'didnt', 'natural', 'consciousness', 'calm', 'rest', 'periodic', 'child', 'sleep', 'night'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('sleep.n.01')
# Senso Target:  Lemma('sleep.n.01.sleep')
# ------------------------------
# Parola da disambiguare:  grams
# Frase in cui compare la parola:  Dr. Douglass was kind enough to lend us about 5 grams of his material .
# Contesto della frase:  {'lend', 'kind', 'douglass', 'material', 'gram', 'dr'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('gram.n.01')
# Senso Target:  Lemma('gram.n.01.gram')
# ------------------------------
# Parola da disambiguare:  receive
# Frase in cui compare la parola:  Only the independent art schools , that is , those not connected with any university or college , receive severe and separate investigation before accreditation by the various regional organizations .
# Contesto della frase:  {'university', 'separate', 'investigation', 'severe', 'connect', 'regional', 'organization', 'accreditation', 'college', 'school', 'receive', 'independent', 'art'}
# Max Signature:  {'letter', 'front', 'gift', 'payment', 'possession', 'receive'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('receive.v.01')
# Senso Target:  Lemma('experience.v.03.receive')
# ------------------------------
# Parola da disambiguare:  prompted
# Frase in cui compare la parola:  The lack of adequate data on the aerated lagoon system prompted the developer to construct an aerated lagoon pilot plant to determine its feasibility for treating domestic sewage .
# Contesto della frase:  {'developer', 'aerate', 'aerated', 'adequate', 'feasibility', 'pilot', 'domestic', 'plant', 'sewage', 'prompt', 'treat', 'system', 'data', 'lagoon', 'construct', 'lack', 'determine'}
# Max Signature:  {'inciting', 'prompt', 'serve', 'relative', 'call'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('prompt.v.02')
# Senso Target:  Lemma('motivate.v.01.prompt')
# ------------------------------
# Parola da disambiguare:  drew
# Frase in cui compare la parola:  Jay Porter drew a base on balls to fill the bases but Don Wert 's smash was knocked down by Rudolph for the putout .
# Contesto della frase:  {'jay', 'ball', 'base', 'knock', 'don', 'porter', 'rudolph', 'putout', 'draw', 'fill', 'wert', 'smash'}
# Max Signature:  {'earn', 'walk', 'pitcher', 'base', 'ball', 'draw', 'achieve'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('draw.v.15')
# Senso Target:  Lemma('draw.v.15.draw')
# ------------------------------
# Parola da disambiguare:  reality
# Frase in cui compare la parola:  ( This provides whatever real justification there is for the talk about `` reality '' . )
# Contesto della frase:  {'provide', 'real', 'reality', 'talk', 'justification'}
# Max Signature:  {'slowly', 'actual', 'real', 'reality', 'dawn', 'situation'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('reality.n.02')
# Senso Target:  Lemma('reality.n.02.reality')
# ------------------------------
# Parola da disambiguare:  find
# Frase in cui compare la parola:  But by the tracing procedure , he could , in a strange obviously kinesthetic manner , find the unseen form ; could piece , as it were , the jumbled mass together into an organized whole and then recognize it as a man or a triangle or whatever it turned out to be .
# Contesto della frase:  {'tracing', 'man', 'turn', 'triangle', 'form', 'piece', 'kinesthetic', 'find', 'organize', 'jumbled', 'mass', 'recognize', 'manner', 'procedure', 'unseen', 'strange'}
# Max Signature:  {'idea', 'bookstore', 'bakery', 'interesting', 'accident', 'day', 'book', 'chance', 'meet', 'happen', 'wonderful', 'find', 'plato'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('find.v.01')
# Senso Target:  Lemma('determine.v.01.find')
# ------------------------------
# Parola da disambiguare:  rapped
# Frase in cui compare la parola:  Then Throneberry rapped into a fast double play .
# Contesto della frase:  {'play', 'rap', 'throneberry', 'fast', 'double'}
# Max Signature:  {'strike', 'knuckle', 'rap', 'sharply'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('rap.v.01')
# Senso Target:  Lemma('rap.v.01.rap')
# ------------------------------
# Parola da disambiguare:  sitting
# Frase in cui compare la parola:  Since the hero , a sterling and upright fellow , is a rich Brown senior , while two Yalies are cast as virtual rapists , I suppose I should disqualify myself from sitting in judgment on `` Where the Boys are '' , but I shall do nothing of the sort .
# Contesto della frase:  {'sterling', 'rich', 'cast', 'rapist', 'suppose', 'judgment', 'sort', 'hero', 'yalies', 'virtual', 'boys', 'sit', 'upright', 'disqualify', 'senior', 'brown', 'fellow'}
# Max Signature:  {'mystery', 'seat', 'read', 'sit', 'assume', 'position', 'maintain'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('sitting.n.02')
# Senso Target:  Lemma('sit.v.04.sit')
# ------------------------------
# Parola da disambiguare:  blue
# Frase in cui compare la parola:  After the storm , the sky cleared blue and cool , and fragrant air swept the hills .
# Contesto della frase:  {'fragrant', 'hill', 'sky', 'sweep', 'clear', 'storm', 'air', 'cool', 'blue'}
# Max Signature:  {'daytime', 'color', 'pigment', 'sky', 'clear', 'bright', 'eye', 'blue', 'resemble'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('blue.n.01')
# Senso Target:  Lemma('blue.s.01.blue')
# ------------------------------
# Parola da disambiguare:  telling
# Frase in cui compare la parola:  All this is simple enough , but in telling the story Porter did two important things that had not been done before .
# Contesto della frase:  {'thing', 'story', 'porter', 'simple'}
# Max Signature:  {'story', 'father', 'happen', 'account', 'narrate', 'detailed', 'child'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('tell.v.03')
# Senso Target:  Lemma('tell.v.03.tell')
# ------------------------------
# Parola da disambiguare:  widespread
# Frase in cui compare la parola:  There may be a number of secondary effects resulting from diffusion through buildings such as widespread contamination of kitchens , restaurants , food stores , hospitals , etc. .
# Contesto della frase:  {'restaurant', 'hospital', 'number', 'food', 'result', 'store', 'secondary', 'diffusion', 'building', 'contamination', 'kitchen', 'widespread'}
# Max Signature:  {'diffuse', 'circulate', 'doctrine', 'fear', 'widespread', 'war', 'nuclear'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('widespread.s.01')
# Senso Target:  Lemma('widespread.s.01.widespread')
# ------------------------------
# Parola da disambiguare:  corrected
# Frase in cui compare la parola:  `` It is possible that I over corrected '' , he said ruefully .
# Contesto della frase:  {'ruefully', 'correct'}
# Max Signature:  {'rectify', 'calculation', 'correct', 'mistake'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('correct.v.01')
# Senso Target:  Lemma('correct.v.01.correct')
# ------------------------------
# Parola da disambiguare:  dumped
# Frase in cui compare la parola:  Why could n't they have dumped him off on someone else ?
# Contesto della frase:  {'dump', 'nt'}
# Max Signature:  {'tie', 'dump', 'year', 'sever', 'service', 'man', 'rich', 'unceremoniously', 'company', 'love', 'boyfriend', 'irresponsibly', 'fell'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('dump.v.02')
# Senso Target:  Lemma('dump.v.01.dump')
# ------------------------------
# Parola da disambiguare:  polynomials
# Frase in cui compare la parola:  Thus there are polynomials * * f such that * * f .
# Contesto della frase:  {'polynomial'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('polynomial.n.01')
# Senso Target:  Lemma('polynomial.n.01.polynomial')
# ------------------------------
# Parola da disambiguare:  operational
# Frase in cui compare la parola:  The periods of high effluent BOD occurred during cold periods when operational problems with the aerator resulted .
# Contesto della frase:  {'effluent', 'occur', 'cold', 'period', 'result', 'problem', 'bod', 'high', 'aerator', 'operational'}
# Max Signature:  {'difficulty', 'process', 'series', 'result', 'pertain', 'operational', 'assume', 'achieve', 'action', 'position'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('operational.a.01')
# Senso Target:  Lemma('operational.a.01.operational')
# ------------------------------
# Parola da disambiguare:  dancers
# Frase in cui compare la parola:  The Russians are all trained as dancers before they start to study gymnastics .
# Contesto della frase:  {'study', 'gymnastics', 'russians', 'train', 'dancer', 'start'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('dancer.n.01')
# Senso Target:  Lemma('dancer.n.01.dancer')
# ------------------------------
# Parola da disambiguare:  uncertain
# Frase in cui compare la parola:  Even Mr. Miller himself seems uncertain on this score .
# Contesto della frase:  {'uncertain', 'score', 'miller'}
# Max Signature:  {'unsure', 'lacking', 'conviction', 'move', 'ornament', 'indicate', 'finger', 'assurance', 'uncertain', 'smile', 'future', 'confidence', 'touch', 'lack', 'step'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('uncertain.a.01')
# Senso Target:  Lemma('uncertain.a.01.uncertain')
# ------------------------------
# Parola da disambiguare:  symmetry
# Frase in cui compare la parola:  Douglass found **f to be trigonal , Laue symmetry **f , with **f , **f .
# Contesto della frase:  {'symmetry', 'douglass', 'trigonal', 'find', 'laue'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('symmetry.n.01')
# Senso Target:  Lemma('symmetry.n.01.symmetry')
# ------------------------------
# Parola da disambiguare:  nightdress
# Frase in cui compare la parola:  There was a lady there , in a nightdress .
# Contesto della frase:  {'nightdress', 'lady'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('nightgown.n.01')
# Senso Target:  Lemma('nightgown.n.01.nightdress')
# ------------------------------
# Parola da disambiguare:  slovenly
# Frase in cui compare la parola:  `` What is slovenly about me '' ?
# Contesto della frase:  {'slovenly'}
# Max Signature:  {'neatness', 'fill', 'white', 'slovenly', 'door', 'dirty', 'hair', 'frowzy', 'unkempt', 'appearance', 'person', 'habitually', 'negligent', 'bulk', 'dress'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('frowsy.s.01')
# Senso Target:  Lemma('frowsy.s.01.slovenly')
# ------------------------------
# Parola da disambiguare:  Initially
# Frase in cui compare la parola:  Initially , the wastewater would be entirely from the shopping center with the domestic sewage from the houses increasing over an 18 - month period .
# Contesto della frase:  {'increase', 'initially', 'house', 'center', 'domestic', 'wastewater', 'sewage', 'period', 'shopping', 'month', 'entirely'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('initially.r.01')
# Senso Target:  Lemma('initially.r.01.initially')
# ------------------------------
# Parola da disambiguare:  ended
# Frase in cui compare la parola:  The '52 Cards were 6 - 7 on May 1 but ended with 88 triumphs , the club 's top since 1949 .
# Contesto della frase:  {'triumph', 'top', 'club', 'cards'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('end.v.01')
# Senso Target:  Lemma('end.v.03.end')
# ------------------------------
# Parola da disambiguare:  commute
# Frase in cui compare la parola:  Now we have * * f or * * f and all four of these operators commute with one another .
# Contesto della frase:  {'commute', 'operator'}
# Max Signature:  {'commute', 'operator', 'change', 'exchange', 'position'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('commute.v.01')
# Senso Target:  Lemma('commute.v.01.commute')
# ------------------------------
# Parola da disambiguare:  dialogue
# Frase in cui compare la parola:  Emerson , in his lecture , refers to the `` startling experience which almost every person confesses in daylight , that particular passages of conversation and action have occurred to him in the same order before , whether dreaming or waking , a suspicion that they have been with precisely these persons in precisely this room , and heard precisely this dialogue , at some former hour , they know not when '' .
# Contesto della frase:  {'dialogue', 'passage', 'emerson', 'refers', 'occur', 'hour', 'wake', 'person', 'conversation', 'startling', 'room', 'daylight', 'lecture', 'order', 'action', 'experience', 'dream', 'confess', 'heard', 'suspicion', 'precisely'}
# Max Signature:  {'conversation', 'person'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('dialogue.n.01')
# Senso Target:  Lemma('dialogue.n.01.dialogue')
# ------------------------------
# Parola da disambiguare:  praised
# Frase in cui compare la parola:  The jury praised the administration and operation of the Atlanta Police Department , the Fulton Tax Commissioner 's Office , the Bellwood and Alpharetta prison farms , Grady Hospital and the Fulton Health Department .
# Contesto della frase:  {'office', 'prison', 'commissioner', 'praise', 'atlanta', 'department', 'farm', 'hospital', 'fulton', 'bellwood', 'police', 'tax', 'jury', 'health', 'grady', 'operation', 'alpharetta', 'administration'}
# Max Signature:  {'approval', 'performance', 'parent', 'express', 'child', 'academic', 'praise'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('praise.v.01')
# Senso Target:  Lemma('praise.v.01.praise')
# ------------------------------
# Parola da disambiguare:  ventilation
# Frase in cui compare la parola:  If you do use a cold frame be sure that its ventilation is adequate .
# Contesto della frase:  {'adequate', 'ventilation', 'cold', 'frame'}
# Max Signature:  {'provide', 'fresh', 'continually', 'mechanical', 'air', 'building', 'ventilation', 'system', 'adjust'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('ventilation.n.02')
# Senso Target:  Lemma('ventilation.n.01.ventilation')
# ------------------------------
# Parola da disambiguare:  ordinary
# Frase in cui compare la parola:  Sheriff Felix Tabb said the ordinary apparently made good his promise .
# Contesto della frase:  {'good', 'tabb', 'ordinary', 'promise', 'sheriff', 'felix'}
# Max Signature:  {'condition', 'expect', 'ordinary', 'situation', 'commonplace'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('ordinary.n.02')
# Senso Target:  Lemma('ordinary.n.01.ordinary')
# ------------------------------
# Parola da disambiguare:  effluent
# Frase in cui compare la parola:  Examination of the data in Table 1 , shows that a few samples contributed to raising the effluent BOD .
# Contesto della frase:  {'effluent', 'table', 'raise', 'examination', 'contribute', 'bod', 'data', 'sample'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('effluent.n.01')
# Senso Target:  Lemma('effluent.n.01.effluent')
# ------------------------------
# Parola da disambiguare:  grounds
# Frase in cui compare la parola:  The Catholics had the largest cemetery , near the Neversink River where Main Street ran south ; Stevie whistled when he passed these alien grounds .
# Contesto della frase:  {'main', 'river', 'ground', 'whistle', 'pass', 'large', 'street', 'cemetery', 'alien', 'stevie', 'catholics', 'south', 'neversink'}
# Max Signature:  {'middle', 'ground', 'solid', 'custom', 'eastern', 'consisting', 'residue', 'dregs', 'coffee', 'future', 'read', 'particle', 'form'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('grounds.n.05')
# Senso Target:  grounds.n.3;2
# ------------------------------
# Parola da disambiguare:  whipped
# Frase in cui compare la parola:  On the narrow fairway of a 508 - yard hole , Arnold whipped into his second shot .
# Contesto della frase:  {'shot', 'arnold', 'whip', 'yard', 'hole', 'narrow', 'second', 'fairway'}
# Max Signature:  {'student', 'beat', 'teacher', 'flog', 'trounced', 'severely', 'rod', 'child', 'whip'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('flog.v.01')
# Senso Target:  Lemma('flog.v.01.whip')
# ------------------------------
# Parola da disambiguare:  stared
# Frase in cui compare la parola:  Wilson stared at her .
# Contesto della frase:  {'wilson', 'star'}
# Max Signature:  {'student', 'teacher', 'amazement', 'star', 'fixed', 'eye'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('gaze.v.01')
# Senso Target:  Lemma('gaze.v.01.stare')
# ------------------------------
# Parola da disambiguare:  sun
# Frase in cui compare la parola:  At greater distances from the sun , the situation is still less certain .
# Contesto della frase:  {'distance', 'sun', 'great', 'situation'}
# Max Signature:  {'sun', 'earth', 'star', 'revolve', 'heat', 'mass', 'planet', 'system', 'source', 'solar', 'light'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('sun.n.01')
# Senso Target:  Lemma('sun.n.01.sun')
# ------------------------------
# Parola da disambiguare:  hour
# Frase in cui compare la parola:  The reaction rates observed at 200 ` ranged from * * f of the chlorine exchanged per hour to 0.7 exchanged per hour .
# Contesto della frase:  {'observe', 'range', 'hour', 'chlorine', 'reaction', 'rate', 'exchange'}
# Max Signature:  {'equal', 'time', 'job', 'day', 'hour', 'period'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('hour.n.01')
# Senso Target:  Lemma('hour.n.01.hour')
# ------------------------------
# Parola da disambiguare:  delays
# Frase in cui compare la parola:  This cooling does not change the avocado in any way , it just delays the natural softening of the fruit until a grove like temperature ( room temperature ) is restored .
# Contesto della frase:  {'fruit', 'grove', 'cooling', 'room', 'natural', 'change', 'delay', 'temperature', 'avocado', 'softening', 'restore'}
# Max Signature:  {'await', 'replay', 'time', 'hold', 'instant', 'delay', 'order', 'long', 'action'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('delay.n.01')
# Senso Target:  Lemma('delay.v.01.delay')
# ------------------------------
# Parola da disambiguare:  integral
# Frase in cui compare la parola:  As in the theory of perception , established in psycho-physiology , the eye is recognized as an integral part of the brain .
# Contesto della frase:  {'establish', 'brain', 'psychophysiology', 'integral', 'eye', 'perception', 'recognize', 'theory'}
# Max Signature:  {'integration', 'result', 'integral', 'mathematical', 'dfdx', 'fx'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('integral.n.01')
# Senso Target:  Lemma('built-in.s.01.integral')
# ------------------------------
# Parola da disambiguare:  essentially
# Frase in cui compare la parola:  There are two types of such intersections , depending essentially on whether the curves cross at the point of intersection .
# Contesto della frase:  {'cross', 'depend', 'curve', 'type', 'intersection', 'essentially', 'point'}
# Max Signature:  {'nature', 'argument', 'shy', 'essence', 'bluster', 'basically', 'essentially', 'dishonest', 'bottom', 'person', 'technical'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('basically.r.01')
# Senso Target:  Lemma('basically.r.01.essentially')
# ------------------------------
# Parola da disambiguare:  Hope
# Frase in cui compare la parola:  Hope to see you again '' .
# Contesto della frase:  {'hope'}
# Max Signature:  {'instance', 'hopeful', 'specific', 'hope', 'feel', 'revive', 'win', 'pennant'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('hope.n.01')
# Senso Target:  Lemma('hope.v.02.hope')
# ------------------------------
# Termini valutati:  51
# Termini valutati correttamente:  31
# Accuratezza:  0.62
# Parola da disambiguare:  popped
# Frase in cui compare la parola:  Pete Ward was sent in for House and , after failing in a bunt attempt , popped to Howser on the grass back of short .
# Contesto della frase:  {'send', 'fail', 'short', 'pop', 'house', 'pete', 'bunt', 'grass', 'attempt', 'howser', 'ward'}
# Max Signature:  {'outward', 'bulge', 'pop', 'eye'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('start.v.14')
# Senso Target:  Lemma('pop.v.02.pop')
# ------------------------------
# Parola da disambiguare:  receiving
# Frase in cui compare la parola:  The gas flow through a plasma generator will modify these conditions ; however , the anode is still the part receiving the largest heat flux .
# Contesto della frase:  {'gas', 'flux', 'large', 'condition', 'flow', 'anode', 'modify', 'heat', 'generator', 'receive', 'plasma'}
# Max Signature:  {'letter', 'front', 'gift', 'payment', 'possession', 'receive'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('receive.v.01')
# Senso Target:  Lemma('receive.v.01.receive')
# ------------------------------
# Parola da disambiguare:  starter
# Frase in cui compare la parola:  A high frequency starter was used to start the arc .
# Contesto della frase:  {'starter', 'arc', 'frequency', 'high', 'start'}
# Max Signature:  {'culture', 'bacteria', 'starter', 'butter', 'cheese', 'process', 'fermentation', 'start', 'yeast', 'souring', 'dough', 'sourdough'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('starter.n.07')
# Senso Target:  Lemma('starter.n.01.starter')
# ------------------------------
# Parola da disambiguare:  current
# Frase in cui compare la parola:  The Office of Business Economics ( OBE ) of the U.S. Department of Commerce provides basic measures of the national economy and current analysis of short-run changes in the economic situation and business outlook .
# Contesto della frase:  {'business', 'provide', 'office', 'analysis', 'economics', 'national', 'department', 'economy', 'outlook', 'obe', 'basic', 'current', 'measure', 'change', 'situation', 'commerce', 'shortrun', 'economic'}
# Max Signature:  {'conductor', 'ampere', 'current', 'flow', 'measure', 'electricity'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('current.n.01')
# Senso Target:  Lemma('current.a.01.current')
# ------------------------------
# Parola da disambiguare:  destruction
# Frase in cui compare la parola:  In fact the accumulation of the hardware of destruction is day by day increasing our fear of each other .
# Contesto della frase:  {'increase', 'destruction', 'fact', 'day', 'hardware', 'accumulation', 'fear'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('destruction.n.01')
# Senso Target:  Lemma('destruction.n.02.destruction')
# ------------------------------
# Parola da disambiguare:  concentrating
# Frase in cui compare la parola:  These drugs have no effect on the iodide concentrating mechanism , but they inhibit organification .
# Contesto della frase:  {'concentrate', 'inhibit', 'mechanism', 'iodide', 'drug', 'organification'}
# Max Signature:  {'strong', 'concentrate', 'juice', 'denser', 'purer'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('concentrate.v.01')
# Senso Target:  Lemma('concentrate.v.01.concentrate')
# ------------------------------
# Parola da disambiguare:  generally
# Frase in cui compare la parola:  More generally , suppose that an experiment consists of a number of independent trials , that each trial results in either a `` success '' or a `` non success '' ( `` failure '' ) , and that the probability of success remains constant from trial to trial .
# Contesto della frase:  {'generally', 'suppose', 'trial', 'remain', 'experiment', 'number', 'result', 'constant', 'probability', 'consists', 'success', 'independent', 'failure'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('by_and_large.r.01')
# Senso Target:  Lemma('generally.r.02.generally')
# ------------------------------
# Parola da disambiguare:  size
# Frase in cui compare la parola:  Almost equal in size to a honeybee .
# Contesto della frase:  {'equal', 'size', 'honeybee'}
# Max Signature:  {'dog', 'large', 'wolf', 'magnitude', 'physical', 'size', 'big'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('size.n.01')
# Senso Target:  Lemma('size.n.01.size')
# ------------------------------
# Parola da disambiguare:  frustration
# Frase in cui compare la parola:  He has to cope with frustration and other emotional disturbance and anomie .
# Contesto della frase:  {'frustration', 'cope', 'anomie', 'emotional', 'disturbance'}
# Max Signature:  {'main', 'feeling', 'frustration', 'annoyance', 'criticize', 'constant', 'hinder', 'source', 'complaint'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('frustration.n.03')
# Senso Target:  Lemma('frustration.n.01.frustration')
# ------------------------------
# Parola da disambiguare:  landmark
# Frase in cui compare la parola:  But it was a landmark .
# Contesto della frase:  {'landmark'}
# Max Signature:  {'provide', 'landscape', 'steeple', 'church', 'landmark', 'wellknown', 'object', 'convenient', 'prominent', 'position'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('landmark.n.01')
# Senso Target:  Lemma('landmark.n.01.landmark')
# ------------------------------
# Parola da disambiguare:  visit
# Frase in cui compare la parola:  This may just be pride in my adopted State of Washington , but certainly I love to visit their mound cities near Yakima and Prosser in July or August , when the bees are in their most active period .
# Contesto della frase:  {'active', 'august', 'yakima', 'bee', 'period', 'july', 'love', 'mound', 'pride', 'visit', 'city', 'prosser', 'washington'}
# Max Signature:  {'thing', 'short', 'time', 'drop', 'place', 'visit', 'person'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('visit.n.01')
# Senso Target:  Lemma('travel_to.v.01.visit')
# ------------------------------
# Parola da disambiguare:  country
# Frase in cui compare la parola:  They cannot stop to grasp and embrace and sit in the back seat of cars along a dark country lane .
# Contesto della frase:  {'embrace', 'country', 'seat', 'car', 'dark', 'sit', 'lane', 'grasp'}
# Max Signature:  {'politically', 'student', 'elect', 'single', 'body', 'president', 'large', 'nation', 'land', 'capitol', 'people', 'organize', 'industrialized', 'government', 'african', 'country', 'manufacturer'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('state.n.04')
# Senso Target:  country.s.00
# ------------------------------
# Parola da disambiguare:  urgent
# Frase in cui compare la parola:  He said the matter was urgent .
# Contesto della frase:  {'urgent', 'matter'}
# Max Signature:  {'hurry', 'word', 'compel', 'permit', 'bridge', 'delay', 'press', 'urgent', 'repair', 'long', 'action'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('pressing.s.01')
# Senso Target:  Lemma('pressing.s.01.urgent')
# ------------------------------
# Parola da disambiguare:  finished
# Frase in cui compare la parola:  He finished the worship service as if there had been no brazen attempt to dishonor God and man .
# Contesto della frase:  {'man', 'service', 'worship', 'brazen', 'dishonor', 'attempt', 'god', 'finish'}
# Max Signature:  {'degree', 'race', 'runner', 'complete', 'bring', 'hour', 'masters', 'fast', 'requirement', 'dish', 'finish'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('complete.v.01')
# Senso Target:  Lemma('finish_up.v.02.finish')
# ------------------------------
# Parola da disambiguare:  snakes
# Frase in cui compare la parola:  Bernard Heuvelmans also treats of the largest snakes , but on the third level , and is chiefly concerned with the anaconda .
# Contesto della frase:  {'concern', 'chiefly', 'large', 'level', 'third', 'treat', 'anaconda', 'bernard', 'heuvelmans', 'snake'}
# Max Signature:  {'resemble', 'thin', 'long', 'flexible', 'snake'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('snake.n.05')
# Senso Target:  Lemma('snake.n.01.snake')
# ------------------------------
# Parola da disambiguare:  change
# Frase in cui compare la parola:  Chlorothiazide was omitted for a 2 - week period , but there was no change in the muscle weakness .
# Contesto della frase:  {'chlorothiazide', 'week', 'change', 'period', 'omit', 'muscle', 'weakness'}
# Max Signature:  {'increase', 'undergone', 'phase', 'event', 'pass', 'worse', 'modification', 'occur', 'ago', 'neighborhood', 'change', 'intend', 'storm', 'visit', 'year', 'sale'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('change.n.01')
# Senso Target:  Lemma('change.n.02.change')
# ------------------------------
# Parola da disambiguare:  national
# Frase in cui compare la parola:  Such identification comes for each group in each crisis by rewriting history into legend and developing appropriate national heroes .
# Contesto della frase:  {'group', 'appropriate', 'national', 'hero', 'history', 'rewrite', 'legend', 'develop', 'identification', 'crisis'}
# Max Signature:  {'anthem', 'national', 'nation', 'hero', 'belong', 'landmark', 'relate', 'country'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('national.a.01')
# Senso Target:  Lemma('national.a.01.national')
# ------------------------------
# Parola da disambiguare:  period
# Frase in cui compare la parola:  During this precarious period of development the mother should continue to influence the growth of the child 's conscience .
# Contesto della frase:  {'continue', 'conscience', 'child', 'development', 'growth', 'period', 'mother', 'precarious', 'influence'}
# Max Signature:  {'picassos', 'time', 'hasten', 'recovery', 'period', 'blue', 'year', 'amount'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('time_period.n.01')
# Senso Target:  Lemma('time_period.n.01.period')
# ------------------------------
# Parola da disambiguare:  concerned
# Frase in cui compare la parola:  When we arrive at the events concerned in the vanished majority , they , of course , cannot impress us as anything familiar .
# Contesto della frase:  {'majority', 'concern', 'event', 'familiar', 'arrive', 'course', 'vanished', 'impress'}
# Max Signature:  {'concern', 'concerned', 'youthful', 'offender', 'greatly', 'task', 'small', 'hand', 'accomplish', 'worry', 'solicitude', 'future', 'feel', 'parent', 'child', 'disappoint'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('concerned.a.01')
# Senso Target:  Lemma('refer.v.02.concern')
# ------------------------------
# Parola da disambiguare:  stage
# Frase in cui compare la parola:  On the stage , Harry Hawk began to weep .
# Contesto della frase:  {'weep', 'harry', 'stage', 'hawk'}
# Max Signature:  {'distinct', 'idea', 'reject', 'time', 'event', 'stage', 'period', 'revise', 'transitional', 'sequence'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('phase.n.01')
# Senso Target:  Lemma('stage.n.03.stage')
# ------------------------------
# Parola da disambiguare:  true
# Frase in cui compare la parola:  Finding it true that he was not inside , the deputies returned to the first house and tore holes through the side and the roof until they could see a body on the bed covered by a blanket .
# Contesto della frase:  {'true', 'finding', 'house', 'return', 'tore', 'side', 'body', 'bed', 'hole', 'cover', 'blanket', 'roof', 'deputy'}
# Max Signature:  {'true', 'alignment', 'correct', 'property', 'possess', 'proper'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('true.n.01')
# Senso Target:  Lemma('true.a.01.true')
# ------------------------------
# Parola da disambiguare:  figure
# Frase in cui compare la parola:  Arnold Palmer has been a blazing figure in golf over the past twelve months .
# Contesto della frase:  {'arnold', 'figure', 'twelve', 'blazing', 'golf', 'palmer', 'month'}
# Max Signature:  {'textual', 'diagram', 'figure', 'cover', 'picture', 'area', 'material', 'illustrate'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('figure.n.01')
# Senso Target:  Lemma('name.n.04.figure')
# ------------------------------
# Parola da disambiguare:  Normal
# Frase in cui compare la parola:  Normal , by God .
# Contesto della frase:  {'god', 'normal'}
# Max Signature:  {'constitute', 'event', 'wine', 'social', 'word', 'curiosity', 'hour', 'norm', 'working', 'serve', 'normal', 'conform', 'room', 'level', 'type', 'order', 'diplomatic', 'course', 'standard', 'temperature', 'abnormal', 'relation'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('normal.a.01')
# Senso Target:  Lemma('normal.a.01.normal')
# ------------------------------
# Parola da disambiguare:  dirt
# Frase in cui compare la parola:  The negatively charged dirt particles then leave the surface and go into the aqueous phase .
# Contesto della frase:  {'charge', 'leave', 'phase', 'aqueous', 'negatively', 'surface', 'particle', 'dirt'}
# Max Signature:  {'consist', 'disintegrate', 'rock', 'surface', 'earths', 'humus'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('soil.n.02')
# Senso Target:  Lemma('dirt.n.02.dirt')
# ------------------------------
# Parola da disambiguare:  raise
# Frase in cui compare la parola:  Maris is in line for a big raise .
# Contesto della frase:  {'big', 'raise', 'maris'}
# Max Signature:  {'increase', 'wage', 'raise', 'hike', 'salary', 'amount'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('raise.n.01')
# Senso Target:  Lemma('raise.n.01.raise')
# ------------------------------
# Parola da disambiguare:  regrets
# Frase in cui compare la parola:  Like Mrs. Dalloway , with her regrets about Peter Walsh , he had his moments of melancholy over a youth too well spent .
# Contesto della frase:  {'youth', 'spent', 'dalloway', 'melancholy', 'peter', 'well', 'walsh', 'moment', 'regret'}
# Max Signature:  {'disappointment', 'sorrow', 'drown', 'error', 'regret', 'rue', 'associate', 'note', 'game', 'cost', 'drink', 'express', 'sadness', 'write', 'wrong'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('sorrow.n.02')
# Senso Target:  Lemma('sorrow.n.02.regret')
# ------------------------------
# Parola da disambiguare:  applaud
# Frase in cui compare la parola:  At the end of the monologue the audience would applaud .
# Contesto della frase:  {'applaud', 'audience', 'monologue'}
# Max Signature:  {'effort', 'express', 'applaud', 'approval'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('applaud.v.02')
# Senso Target:  Lemma('applaud.v.01.applaud')
# ------------------------------
# Parola da disambiguare:  suggests
# Frase in cui compare la parola:  As the first sentence suggests , both roads belong to death in the end .
# Contesto della frase:  {'death', 'belong', 'sentence', 'road'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('propose.v.01')
# Senso Target:  Lemma('indicate.v.05.suggest')
# ------------------------------
# Parola da disambiguare:  occurred
# Frase in cui compare la parola:  At that moment Kipling was overwhelmed with awed amazement , suddenly recalling that these identical details of scene , action and word had occurred to him in a dream six weeks earlier .
# Contesto della frase:  {'earlier', 'word', 'amazement', 'week', 'suddenly', 'identical', 'recall', 'action', 'occur', 'dream', 'detail', 'scene', 'overwhelm', 'awed', 'kipling', 'moment'}
# Max Signature:  {'incidence', 'meeting', 'pass', 'occur', 'happen', 'place'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('happen.v.01')
# Senso Target:  Lemma('occur.v.02.occur')
# ------------------------------
# Parola da disambiguare:  mulch
# Frase in cui compare la parola:  Give them food , some shade , mulch , water and more food , and they 'll repay your solicitude with beauty .
# Contesto della frase:  {'shade', 'repay', 'll', 'water', 'food', 'beauty', 'mulch', 'solicitude'}
# Max Signature:  {'mulch', 'flowerbed', 'cover'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('mulch.v.01')
# Senso Target:  Lemma('mulch.n.01.mulch')
# ------------------------------
# Parola da disambiguare:  meteors
# Frase in cui compare la parola:  Zodiacal light and the gegenschein give some evidence for such a dust blanket , a phenomenon also to be expected if the dust before capture is in circular orbits about the sun , as indicated by the trend of the smaller visible meteors .
# Contesto della frase:  {'trend', 'sun', 'evidence', 'orbit', 'capture', 'phenomenon', 'indicate', 'expect', 'small', 'blanket', 'visible', 'meteor', 'dust', 'gegenschein', 'circular', 'zodiacal', 'light'}
# Max Signature:  {'solid', 'earth', 'body', 'small', 'hit', 'atmosphere', 'extraterrestrial', 'astronomy'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('meteoroid.n.01')
# Senso Target:  Lemma('meteoroid.n.01.meteor')
# ------------------------------
# Parola da disambiguare:  reactionary
# Frase in cui compare la parola:  Turn the bastards over to me - to me and my boys - no nigger ever got what would be comin to them - reactionary bastards .
# Contesto della frase:  {'bastard', 'comin', 'boys', 'turn', 'reactionary', 'nigger'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('reactionary.n.01')
# Senso Target:  Lemma('reactionary.s.01.reactionary')
# ------------------------------
# Parola da disambiguare:  presently
# Frase in cui compare la parola:  After being located for some years in the Village at the Equinox Pharmacy under the supervision of Mrs. Harry Mercier , it is presently located in the Hill and Dale Shop , Manchester Center .
# Contesto della frase:  {'mercier', 'hill', 'presently', 'locate', 'pharmacy', 'shop', 'harry', 'supervision', 'dale', 'center', 'village', 'equinox', 'manchester', 'year'}
# Max Signature:  {'shortly', 'doctor', 'presently', 'book', 'arrive', 'future', 'news', 'long', 'appear'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('soon.r.01')
# Senso Target:  Lemma('presently.r.02.presently')
# ------------------------------
# Parola da disambiguare:  leaving
# Frase in cui compare la parola:  They are leaving so fast that the president of the West German Employers' Federation issued an appeal this week to factory workers in the West to volunteer for six months ' front-line work in factories in West Berlin .
# Contesto della frase:  {'work', 'issue', 'worker', 'leave', 'week', 'federation', 'employers', 'month', 'frontline', 'president', 'berlin', 'volunteer', 'appeal', 'fast', 'west', 'factory', 'german'}
# Max Signature:  {'leave', 'inflation', 'remark', 'president', 'penniless', 'speechless'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('leave.v.03')
# Senso Target:  Lemma('leave.v.01.leave')
# ------------------------------
# Parola da disambiguare:  gun
# Frase in cui compare la parola:  Instead , he whirled and ran to his house for a gun forcing them to kill him , Cook reported .
# Contesto della frase:  {'house', 'gun', 'report', 'force', 'cook', 'whirl', 'kill'}
# Max Signature:  {'regard', 'gun', 'ability', 'shoot', 'person'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('gunman.n.02')
# Senso Target:  Lemma('gun.n.01.gun')
# ------------------------------
# Parola da disambiguare:  distinguishable
# Frase in cui compare la parola:  In all cases a disturbing amount of nonspecific staining was still present although it was still distinguishable from specific fluorescence .
# Contesto della frase:  {'disturbing', 'nonspecific', 'case', 'specific', 'fluorescence', 'staining', 'distinguishable', 'amount'}
# Max Signature:  {'distinct', 'gloom', 'metal', 'shine', 'stage', 'project', 'distinguishable', 'capable', 'perceive', 'twin', 'difference', 'progress'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('distinguishable.a.01')
# Senso Target:  Lemma('distinguishable.a.01.distinguishable')
# ------------------------------
# Parola da disambiguare:  deserve
# Frase in cui compare la parola:  Further we cannot go , for the Dark ages deserve their name .
# Contesto della frase:  {'deserve', 'dark', 'age'}
# Max Signature:  {'worthy', 'deserve', 'work', 'hard', 'promotion'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('deserve.v.01')
# Senso Target:  Lemma('deserve.v.01.deserve')
# ------------------------------
# Parola da disambiguare:  fraction
# Frase in cui compare la parola:  It was then distilled at least three times from a trap at - 78 ` to a liquid air trap with only a small middle fraction being retained in each distillation .
# Contesto della frase:  {'middle', 'time', 'trap', 'retain', 'small', 'fraction', 'air', 'liquid', 'distillation', 'distil'}
# Max Signature:  {'piece', 'item', 'small', 'form'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('fraction.n.02')
# Senso Target:  Lemma('fraction.n.01.fraction')
# ------------------------------
# Parola da disambiguare:  expect
# Frase in cui compare la parola:  In tularemia produced by aerosol exposure , one would not expect to find the classical ulcer of `` rabbit fever '' on a finger .
# Contesto della frase:  {'produce', 'classical', 'exposure', 'fever', 'finger', 'expect', 'aerosol', 'find', 'ulcer', 'rabbit', 'tularemia'}
# Max Signature:  {'regard', 'probable', 'expect', 'meteorologist', 'rain', 'tomorrow'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('expect.v.01')
# Senso Target:  Lemma('expect.v.01.expect')
# ------------------------------
# Parola da disambiguare:  indicating
# ...
# Senso Target:  Lemma('faithful.a.01.faithful')
# ------------------------------
# Parola da disambiguare:  massive
# Frase in cui compare la parola:  In a properly ordered society the massive force of public law performs the function which in natural law theory ineptly is left altogether to a small voice so often still .
# Contesto della frase:  {'ineptly', 'leave', 'altogether', 'massive', 'public', 'properly', 'force', 'natural', 'small', 'voice', 'society', 'law', 'order', 'perform', 'theory', 'function'}
# Max Signature:  {'proportion', 'impose', 'monumental', 'monolithic', 'massive', 'oak', 'solidity', 'door', 'scale', 'stalinist', 'sculpture', 'moores', 'architecture', 'size', 'bulk'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('massive.s.01')
# Senso Target:  Lemma('massive.s.01.massive')
# ------------------------------
# Parola da disambiguare:  women
# Frase in cui compare la parola:  By the time he was prosperous enough - his goals were high - he was bald and afraid of women .
# Contesto della frase:  {'bald', 'time', 'woman', 'high', 'goal', 'afraid', 'prosperous'}
# Max Signature:  {'man', 'hunt', 'house', 'woman', 'oppose', 'female', 'person', 'adult'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('woman.n.01')
# Senso Target:  Lemma('woman.n.01.woman')
# ------------------------------
# Parola da disambiguare:  elected
# Frase in cui compare la parola:  The state had elected Republican candidates in the past two years .
# Contesto della frase:  {'candidate', 'republican', 'year', 'elect'}
# Max Signature:  {'office', 'vote', 'elect', 'membership', 'select', 'chairman', 'board'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('elect.v.01')
# Senso Target:  Lemma('elect.v.01.elect')
# ------------------------------
# Parola da disambiguare:  feature
# Frase in cui compare la parola:  The second feature , `` The Price of Silence '' , is a British detective story that will talk your head off .
# Contesto della frase:  {'story', 'feature', 'silence', 'detective', 'talk', 'head', 'british', 'second', 'price'}
# Max Signature:  {'feature', 'characteristic', 'generosity', 'map', 'aspect', 'attribute', 'best', 'prominent', 'road'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('feature.n.01')
# Senso Target:  Lemma('feature.n.03.feature')
# ------------------------------
# Parola da disambiguare:  mind
# Frase in cui compare la parola:  Stephen Vincent Benet 's John Brown's Body comes immediately to mind in this connection , as does John Steinbeck 's The Grapes of Wrath and Carl Sandburg 's The People, Yes .
# Contesto della frase:  {'grapes', 'connection', 'body', 'benet', 'wrath', 'sandburg', 'mind', 'steinbeck', 'people', 'stephen', 'carl', 'john', 'vincent', 'browns'}
# Max Signature:  {'wander', 'word', 'feeling', 'reason', 'faculty', 'seat', 'mind', 'responsible', 'thought', 'head'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('mind.n.01')
# Senso Target:  Lemma('mind.n.02.mind')
# ------------------------------
# Parola da disambiguare:  time
# Frase in cui compare la parola:  0 time ?
# Contesto della frase:  {'time'}
# Max Signature:  {'instance', 'single', 'event', 'time', 'ten', 'occasion', 'clip', 'succeed', 'call'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('time.n.01')
# Senso Target:  Lemma('time.n.01.time')
# ------------------------------
# Parola da disambiguare:  game
# Frase in cui compare la parola:  Let us not try to key them out at this stage of the game , and let us just call them Bombus ; there must be several dozen species in the United States alone .
# Contesto della frase:  {'bombus', 'specie', 'stage', 'key', 'dozen', 'game', 'united', 'call'}
# Max Signature:  {'play', 'contest', 'people', 'winner', 'game', 'rule', 'determine'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('game.n.01')
# Senso Target:  Lemma('game.n.03.game')
# ------------------------------
# Parola da disambiguare:  visit
# Frase in cui compare la parola:  She wants to pay you a visit .
# Contesto della frase:  {'visit', 'pay'}
# Max Signature:  {'pay', 'citizen', 'mayor', 'visit', 'prominent', 'call'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('visit.v.03')
# Senso Target:  Lemma('visit.n.02.visit')
# ------------------------------
# Parola da disambiguare:  real
# Frase in cui compare la parola:  Is this for real ?
# Contesto della frase:  {'real'}
# Max Signature:  {'existence', 'life', 'fact', 'illusory', 'ghost', 'base', 'earnest', 'real', 'occur', 'actuality', 'humility', 'longfellow', 'object', 'people', 'film', 'illness', 'verify'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('real.a.01')
# Senso Target:  Lemma('real.a.01.real')
# ------------------------------
# Parola da disambiguare:  wrote
# Frase in cui compare la parola:  Time 's editor , Thomas Griffith , in his book , The Waist High Culture , wrote : `` most of what was different about it ( the Deep South ) I found myself unsympathetic to '' .
# Contesto della frase:  {'culture', 'time', 'griffith', 'unsympathetic', 'thomas', 'book', 'deep', 'waist', 'high', 'find', 'south', 'write', 'editor'}
# Max Signature:  {'work', 'issue', 'book', 'georges', 'career', 'publish', 'publication', 'simenon', 'long', 'write'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('publish.v.03')
# Senso Target:  Lemma('write.v.02.write')
# ------------------------------
# Parola da disambiguare:  reason
# Frase in cui compare la parola:  In fact , he intimated clearly that that was the reason that Wilson had been sent here - to make a larger contribution of dollar money .
# Contesto della frase:  {'send', 'fact', 'intimate', 'reason', 'clearly', 'wilson', 'large', 'contribution', 'money', 'dollar'}
# Max Signature:  {'fact', 'reason', 'conclusion', 'lie', 'justify', 'logically', 'premise'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('reason.n.06')
# Senso Target:  Lemma('reason.n.01.reason')
# ------------------------------
# Parola da disambiguare:  gay
# Frase in cui compare la parola:  He crossed the tracks to Delaware House , where ladies in gay dresses and men in straw boaters and waxed mustaches crowded the verandah .
# Contesto della frase:  {'track', 'verandah', 'lady', 'cross', 'waxed', 'men', 'house', 'mustache', 'crowd', 'straw', 'dress', 'delaware', 'boater', 'gay'}
# Max Signature:  {'highspirited', 'wordsworth', 'heart', 'poet', 'jolly', 'jocund', 'laughter', 'crowd', 'christmas', 'company', 'laugh', 'full', 'merriment', 'saint', 'jovial', 'gay', 'mirthful', 'reunion', 'gentleman', 'young', 'merry', 'peal', 'nick'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('gay.s.02')
# Senso Target:  Lemma('brave.s.03.gay')
# ------------------------------
# Parola da disambiguare:  steeple
# Frase in cui compare la parola:  It could never happen as long as God was alert and the Drew steeple stood guard with its peaked lance .
# Contesto della frase:  {'drew', 'steeple', 'happen', 'alert', 'god', 'peaked', 'stand', 'guard', 'long', 'lance'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('steeple.n.01')
# Senso Target:  Lemma('steeple.n.01.steeple')
# ------------------------------
# Parola da disambiguare:  collected
# Frase in cui compare la parola:  Statistically , the most significant data have been collected from the sensors on 1958 Alpha ( Explorer 1 , ) , 1958 Delta 2 ( Sputnik 3 , ) , and 1959 Eta ( Vanguard 3 , ) .
# Contesto della frase:  {'collect', 'alpha', 'delta', 'explorer', 'sensor', 'sputnik', 'eta', 'statistically', 'data', 'vanguard'}
# Max Signature:  {'man', 'amass', 'unfaithfulness', 'wife', 'roll', 'evidence', 'small', 'gather', 'accumulate', 'fortune', 'data', 'thesis', 'lot'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('roll_up.v.02')
# Senso Target:  Lemma('gather.v.01.collect')
# ------------------------------
# Parola da disambiguare:  projection
# Frase in cui compare la parola:  Two types of light source were used , a thousand watt projection lamp and an AH6 high pressure mercury arc .
# Contesto della frase:  {'lamp', 'pressure', 'ah6', 'type', 'arc', 'watt', 'mercury', 'high', 'projection', 'source', 'light'}
# Max Signature:  {'image', 'screen', 'projection', 'film'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('projection.n.02')
# Senso Target:  Lemma('projection.n.02.projection')
# ------------------------------
# Parola da disambiguare:  liberal
# Frase in cui compare la parola:  His assumption seems to be that any such friends , being tolerable humans , must be more liberal than most Southerners and therefore at least partly in sympathy with his views .
# Contesto della frase:  {'view', 'southerners', 'partly', 'sympathy', 'assumption', 'liberal', 'tolerable', 'friend', 'human'}
# Max Signature:  {'opinion', 'opponent', 'broad', 'sympathy', 'liberal', 'tolerant', 'broadmindedness', 'political', 'characterize', 'generous', 'newspaper', 'stance'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('broad.s.08')
# Senso Target:  Lemma('broad.s.08.liberal')
# ------------------------------
# Parola da disambiguare:  action
# Frase in cui compare la parola:  Much of the important individual and social action has been owing to religious incentives .
# Contesto della frase:  {'social', 'individual', 'religious', 'owe', 'action', 'incentive'}
# Max Signature:  {'story', 'unnatural', 'murder', 'oppose', 'action'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('action.n.01')
# Senso Target:  Lemma('action.n.01.action')
# ------------------------------
# Parola da disambiguare:  demand
# Frase in cui compare la parola:  It is only fair to demand that teachers of courses in English , history , psychology and so on be as well informed in matters of art , especially interior design , as are the art teachers educated in the academic subjects .
# Contesto della frase:  {'academic', 'teacher', 'english', 'matter', 'design', 'fair', 'educate', 'history', 'psychology', 'interior', 'demand', 'well', 'subject', 'course', 'art', 'inform'}
# Max Signature:  {'demand', 'explanation', 'inform'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('demand.v.06')
# Senso Target:  Lemma('demand.v.03.demand')
# ------------------------------
# Parola da disambiguare:  hole
# Frase in cui compare la parola:  On the narrow fairway of a 508 - yard hole , Arnold whipped into his second shot .
# Contesto della frase:  {'shot', 'arnold', 'whip', 'yard', 'hole', 'narrow', 'second', 'fairway'}
# Max Signature:  {'play', 'green', 'tee', 'hole', 'period', 'golf', 'course'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('hole.n.03')
# Senso Target:  Lemma('hole.n.03.hole')
# ------------------------------
# Parola da disambiguare:  fast
# Frase in cui compare la parola:  And they could n't have entrusted Henri to better hands because `` le professeur '' knows his muscles from the sterno-cleido mastoideus of the neck right down to the tibialis anticus of the leg - and better still , he knows just what exercises work best for them and what Weider principles to combine them with for fast , fast muscle growth .
# Contesto della frase:  {'henri', 'tibialis', 'work', 'exercise', 'sternocleido', 'nt', 'weider', 'better', 'best', 'muscle', 'le', 'neck', 'growth', 'anticus', 'hand', 'entrust', 'fast', 'professeur', 'leg', 'principles', 'combine', 'mastoideus', 'good'}
# Max Signature:  {'lent', 'reason', 'medical', 'food', 'religious', 'fast', 'catholics', 'abstain'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('fast.v.01')
# Senso Target:  Lemma('fast.a.01.fast')
# ------------------------------
# Parola da disambiguare:  inferred
# Frase in cui compare la parola:  Dice , for example , he inferred from black dots on a white surface .
# Contesto della frase:  {'dot', 'example', 'white', 'black', 'dice', 'surface', 'infer'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('deduce.v.01')
# Senso Target:  Lemma('deduce.v.01.infer')
# ------------------------------
# Parola da disambiguare:  office
# Frase in cui compare la parola:  U Thant of course , will hold office until the spring of 1963 , when Mr. Hammarskjold 's term would have come to an end .
# Contesto della frase:  {'office', 'hammarskjold', 'thant', 'hold', 'spring', 'course', 'term'}
# Max Signature:  {'candidate', 'office', 'year', 'president', 'advantage', 'great', 'power', 'government', 'hold', 'official'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('office.n.04')
# Senso Target:  Lemma('office.n.04.office')
# ------------------------------
# Parola da disambiguare:  speak
# Frase in cui compare la parola:  They did not speak much .
# Contesto della frase:  {'speak'}
# Max Signature:  {'language', 'speak', 'wont', 'baby', 'talk', 'dialect', 'prisoner', 'strange'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('speak.v.03')
# Senso Target:  Lemma('talk.v.01.speak')
# ------------------------------
# Parola da disambiguare:  ago
# Frase in cui compare la parola:  As a contemporary bonus , the set includes Carl Sandburg 's address at a joint session of Congress , delivered on Lincoln 's birthday two years ago .
# Contesto della frase:  {'year', 'include', 'bonus', 'ago', 'contemporary', 'lincoln', 'sandburg', 'session', 'birthday', 'set', 'congress', 'carl', 'deliver', 'address', 'joint'}
# Max Signature:  {'word', 'archaic', 'ago', 'agone', 'year'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('ago.s.01')
# Senso Target:  Lemma('ago.r.01.ago')
# ------------------------------
# Parola da disambiguare:  1
# Frase in cui compare la parola:  The most distal airways are similar to those found in type 1 , , being composed of numerous , apparently true terminal bronchioles and occasional , poorly developed respiratory bronchioles ( figs. 14 , 15 ) .
# Contesto della frase:  {'true', 'numerous', 'airway', 'respiratory', 'compose', 'developed', 'figs', 'type', 'terminal', 'find', 'distal', 'occasional', 'bronchiole'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('one.n.01')
# Senso Target:  Lemma('one.s.01.1')
# ------------------------------
# Parola da disambiguare:  cross
# Frase in cui compare la parola:  Less ambitious freeway plans may be more successful - especially when the roadways and interchanges are raised , allowing for cross access at many points and providing parking areas below the ramp .
# Contesto della frase:  {'plan', 'provide', 'ramp', 'cross', 'successful', 'interchange', 'raise', 'area', 'roadway', 'ambitious', 'point', 'allow', 'access', 'freeway', 'park'}
# Max Signature:  {'consist', 'cross', 'marking'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('crisscross.n.01')
# Senso Target:  Lemma('cross.s.01.cross')
# ------------------------------
# Parola da disambiguare:  true
# Frase in cui compare la parola:  This is true of all components which have such a bounded support .
# Contesto della frase:  {'true', 'bounded', 'support', 'component'}
# Max Signature:  {'true', 'alignment', 'correct', 'property', 'possess', 'proper'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('true.n.01')
# Senso Target:  Lemma('true.a.01.true')
# ------------------------------
# Parola da disambiguare:  completely
# Frase in cui compare la parola:  Space in any form is completely measured by the three dimensions .
# Contesto della frase:  {'completely', 'measure', 'space', 'dimension', 'form'}
# Max Signature:  {'apartment', 'complete', 'completely', 'furnished', 'fill', 'form'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('completely.r.02')
# Senso Target:  Lemma('completely.r.02.completely')
# ------------------------------
# Parola da disambiguare:  formula
# Frase in cui compare la parola:  Before deriving this formula , we explain what we mean by `` problems of this kind '' .
# Contesto della frase:  {'kind', 'derive', 'explain', 'problem', 'formula'}
# Max Signature:  {'bound', 'attack', 'descartes', 'polynomial', 'standard', 'general', 'problem', 'formula', 'mathematics', 'mathematical', 'solve', 'sign', 'class', 'procedure', 'rule', 'upper', 'determine'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('rule.n.11')
# Senso Target:  Lemma('formula.n.01.formula')
# ------------------------------
# Termini valutati:  51
# Termini valutati correttamente:  19
# Accuratezza:  0.38
#
# Esecuzioni:  10
# Lista delle accuratezze:  [0.62, 0.42, 0.46, 0.38, 0.5, 0.58, 0.6, 0.46, 0.38, 0.38]
# Accuratezza media:  0.478
