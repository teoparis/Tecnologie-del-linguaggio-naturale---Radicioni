# %%
import re
import enum
import math
import random
import nltk
import csv
import numpy as np
import scipy as sp
from nltk.corpus import wordnet as wn
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import semcor
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from random import randrange
from collections import deque
from statistics import mean

# %% [markdown]
# FUNZIONI DI PREPROCESSING

# %%
#il pre-processing consiste nella tokenizzazione, lemmatizzazione,
#rimozione della punteggiatura e delle stopwords di una sentence
def pre_processing(sentence):
    return set(remove_stopwords(tokenize_sentence(remove_punctuation(sentence))))

#rimuove le stowords da una lista di parole
def remove_stopwords(words_list):
    stopwords_list = get_stopwords()
    return [value.lower() for value in words_list if value.lower() not in stopwords_list]

#Rimuove la punteggiatura da una sentence
#Restituisce la sentence senza punteggiature
def remove_punctuation(sentence):
    return re.sub(r'[^\w\s]','',sentence)

#Tokenizza la frase in input e ne affettua anche la lemmatizzazione della sue parole
def tokenize_sentence(sentence):
    words_list = []
    lmtzr = WordNetLemmatizer()
    for tag in nltk.pos_tag(word_tokenize(sentence)):
        if (tag[1][:2] == "NN"):
            words_list.append(lmtzr.lemmatize(tag[0], pos = wn.NOUN))
        elif (tag[1][:2] == "VB"):
             words_list.append(lmtzr.lemmatize(tag[0], pos = wn.VERB))
        elif (tag[1][:2] == "RB"):
             words_list.append(lmtzr.lemmatize(tag[0], pos = wn.ADV))
        elif (tag[1][:2] == "JJ"):
             words_list.append(lmtzr.lemmatize(tag[0], pos = wn.ADJ))
    return words_list

#Restituisce la l'insieme di stopwords dal file delle stopwords
def get_stopwords():
    stopwords = open("stop_words_FULL.txt", "r")
    stopwords_list = []
    for word in stopwords:
        stopwords_list.append(word.replace('\n', ''))
    stopwords.close()
    return stopwords_list

# %% [markdown]
# FUNZIONI UTILI PER L'ANALISI DEL TESTO

# %%
#Restituisce un sostantivo random presente nel dizionario associato ad una sentence
def get_random_noun(dictionary_tag):
    try:
        sentence_nouns = dictionary_tag['NN']
    except KeyError:
        return None #se non ci sono sostantivi
    noun =  random.choice(sentence_nouns)
    if len(wn.synsets(noun)) == 0:
        return None #se il sostantivo scelto non ha almeno un synset in wordnet
    return noun

#Restituisce una parola random presente nel dizionario associato ad una sentence
def get_random_word(dictionary_tag):
    keys = list(dictionary_tag.keys())
    if not keys:
        return None #se non ci sono parole "analizzabili" nel dizionario, aka se il dizionario è vuoto
    key = random.choice(keys)
    words_list = dictionary_tag[key]
    word = random.choice(words_list)
    if len(wn.synsets(word)) == 0:
        return None #se la parola scelta non ha almeno un synset in wordnet
    return word

#Verifica che una parola abbia un synset target associato
#Senza synset target associato è inutile confrontare l'output dell'algortimo di Lesk
def check_word_synset_target(word,sentence_sem):
    for w in sentence_sem:
        if (type(w) != list):
            if (w[0] == word):
                return True
    return False
    
#Crea un dizionario che ha come chiavi i tag presenti nella sentence e come valori liste di parole associate a quei tag
#e.g {NN: ['home','garden'], VB:['gone'], .....,}
#input: sentence_tag -> rappresenta le words della sentence con i relativi pos tag
#input: sentence_sem -> rappresenta le words della sentence con il relativo synset target associato
def get_dictionary_tag(sentence_tag,sentence_sem):
    dictionary_tag = dict()
    stopwords_list = get_stopwords()
    for word in sentence_tag:
         tag = word.label()
         word = " ".join(l for l in word)
         if check_word_synset_target(word, sentence_sem): #Non inserisco nel dizionario parole che non hanno un synset target
             w = word.lower()
             if w not in stopwords_list and tag: #Non inserisco nel dizionario stopwords o parole che non hanno un pos tag associato
                 if tag in dictionary_tag:
                     dictionary_tag[tag].append(word)
                 else:
                     dictionary_tag[tag] = [word]             
    return dictionary_tag

#Restituisce un indice randomico utile per l'ultimo esercizio
def get_random_index(index_evaluated, INDEXES_NUM):
    while True:
        index = randrange(INDEXES_NUM)
        if index not in index_evaluated:
            return index
    
#Restituisce il synset target per una parola in una sentence
def get_synset_target_for_word_in_sentence(noun,sentence):
     for word in sentence:
      if(type(word) != list):
          if (word[0] == noun):
              return str(word.label())

# %% [markdown]
# METRICHE DI SIMILARITA E ALGORITMI PER LA RICERCA

# %%
#Custom similarity functions
def wu_palmer_similarity(sense1, sense2):
    numerator = 2 * depth(lowest_common_subsumer(sense1,sense2))
    denominator = depth(sense1) + depth(sense2)
    return numerator/denominator

def leakcock_chodorow(sense1, sense2):
    numerator = (shortest_path(sense1, sense2) + 1)
    denominator = (2 * max_depth) + 1
    return -math.log(numerator/denominator)

def shortest_path_similarity(sense1, sense2):
    return ((2 * max_depth) - shortest_path(sense1, sense2))

#Restituisce la similarità tra due parole date in input
def similarity(word1, word2, similarity_function):
    max_sim = 0
    for s1 in wn.synsets(word1):
        for s2 in wn.synsets(word2):
           sim = similarity_function(s1,s2)
           if sim > max_sim:
               max_sim = sim
    return max_sim

#Restituisce la profondità di un senso in wordnet, cioè il massimo percorso dal senso alla radice        
def depth(sense):
    if not sense:
        return 0
    return max([len(path) for path in all_hypernym_paths(sense)])

#Restituisce tutti i percorsi di iperonimi di un senso di wordnet, la ricerca dei percosi viene effettuata in modo ricorsivo
def all_hypernym_paths(sense):
    paths = []
    hypernyms = sense.hypernyms()
    if len(hypernyms) == 0:
        paths = [[sense]]
    for hypernym in hypernyms:
        for ancestor_list in all_hypernym_paths(hypernym):
            ancestor_list.append(sense)
            paths.append(ancestor_list)
    return paths

#Massima profondità intesa come il percorso più lungo degli iperonimi di tutti i sensi presenti in wordnet
max_depth = max(max(len(hyp_path) for hyp_path in all_hypernym_paths(ss)) for ss in wn.all_synsets())

#Restituisce un dizionario di iperonimi del senso in input con la relativa profondità
def min_hypernyms_depth(sense):
    sense_depth_queue = deque([(sense, 0)]) #deque garantisce efficienza nell'inserire ed eliminare elementi sia a destra che a sinistra della coda
    sense_depth_dict = {}
    while sense_depth_queue:
        s, depth = sense_depth_queue.popleft()
        if s in sense_depth_dict:
            continue
        sense_depth_dict[s] = depth
        depth += 1
        sense_depth_queue.extend((hyperonym, depth) for hyperonym in s.hypernyms()) #li mette a destra della coda
    return sense_depth_dict

#restituisce il percorso più breve tra due sensi di wordnet
def shortest_path(sense1,sense2):
    if sense1 == sense2:
        return 0
    dict1 = min_hypernyms_depth(sense1)
    dict2 = min_hypernyms_depth(sense2)
    min_dist = (2 * max_depth) # distanza minima iniziale

    #per ogni senso del dizionario degli iperonimi di sense1 cerca di trovare il match con un senso del secondo dizionario.
    for ss, dist1 in dict1.items():
        dist2 = dict2.get(ss)
        if not dist2:
            dist2 = (2 * max_depth)
        min_dist = min(min_dist, dist1 + dist2) #somma dei due sensi matchati
    return (2 * max_depth) if math.isinf(min_dist) else min_dist

#Restituisce l'antenato comune più vicino di due sensi, cioè l'iperonimo comune più vicino ai due sensi. 
#SCELTA PROGETTUALE: Se ne ho più di uno prendo quello può essere il più profondo rispetto alla radice.
def lowest_common_subsumer(sense1, sense2):
    if sense1 == sense2: return sense1
    
    dict1 = min_hypernyms_depth(sense1)
    dict2 = min_hypernyms_depth(sense2)
    
    min_dist = (2 * max_depth)
    candidates = []
    for ss, dist1 in dict1.items():
        dist2 = dict2.get(ss) 
        if not dist2:
            dist2 = (2 * max_depth)
        else:
            if (dist1 + dist2) <= min_dist:
                min_dist = (dist1 + dist2)
                candidates.append(ss) 
    if candidates:
        deepest = candidates[0]
        for sense in candidates:
            if depth(sense) < depth(deepest):
                deepest = sense
        return deepest #restituisce il senso con profondità maggiore rispetto alla radice

#Classe enum con la quale specifichiamo il tipo di similarità utilizzata
class Similarity_Type(enum.Enum):
    wu_palmer_similarity = 1
    shortest_path = 2
    leakcock_chodorow = 3

# %% [markdown]
# Word sense disambiguation è il processo con il quale si precisa il significato di una parola o di un insieme di parole (frase), che denota significati diversi a seconda dei contesti, per evitare che sia ambigua.

# %%
#Algoritmo di Lesk
def lesk_algorithm(word, sentence, word_type):
    best_sense = wn.synsets(word)[0]
    max_overlap = 0
    max_signature = []
    print("Frase in cui compare la parola: ", sentence)
    context = pre_processing(sentence)
    
    #se il tipo di parola è un nome allora cerco solo tra i nomi in wordnet
    #altrimenti prendo tutti i synset associati a quel termine
    if word_type == 'NOUN':
        synsets = wn.synsets(word, pos=wn.NOUN)
    elif word_type == 'ALL':
        synsets = wn.synsets(word)
        
    for sense in synsets:
        signature = get_signature(sense)
        overlap = len(list(signature & context)) #overlap
        if overlap > max_overlap:
            max_overlap = overlap
            best_sense = sense
            max_signature = signature
            
    print("Contesto della frase: ", context)
    print("Max Signature: ", max_signature) #signature del senso con più overlap con il contesto della sentence
    return best_sense

#Signature di un senso di WordNet
def get_signature(sense):
    signature = set()
    for word in pre_processing(sense.definition()): #tokenizzo la definizione del synset
        signature.add(word)
    for example in sense.examples(): #tokenizzo ogni esempio del synset
        for word in pre_processing(example):
            signature.add(word)
    return signature #la signature conterrà tutte le parole presenti nella definizione del senso e negli esempi

# %% [markdown]
# CONSEGNA 1:
#
# L'esercitazione consiste nell'implementare tre misure di similarità basate su WordNet.
#
# Per ciascuna di tali misure di similarità, calcolare gli indici di
# correlazione di Spearman and gli indici di correlazione di Pearson
# fra i risultati ottenuti e quelli ‘target’ presenti nel file annotato.

# %%
def main():

    #scelta della metrica da utilizzare per il calcolo della similarità
    
    similarity_type = Similarity_Type.leakcock_chodorow
    #similarity_type = Similarity_Type.wu_palmer_similarity
    #similarity_type = Similarity_Type.shortest_path
    
    with open('WordSim353.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        assignments = []
        targets = []
        line_count = 0
        for row in csv_reader:
            if line_count > 0:
                print("Word1: ",row[0])
                print("Word2: ",row[1])
                sim = 0
                if similarity_type.value == 1:
                    sim = similarity(row[0], row[1], wu_palmer_similarity)
                elif similarity_type.value == 2:
                    sim = similarity(row[0], row[1], shortest_path_similarity)
                elif similarity_type.value == 3:
                    sim = similarity(row[0], row[1], leakcock_chodorow)
                print("Type of similarity chosen: ", similarity_type.name)
                print("MyCustom Similarity: ",sim)
                print("Human Similarity: ",row[2])
                assignments.append(sim)
                targets.append(float(row[2]))
                print("------------------------------")
            line_count = line_count + 1
            
    print("Pearson Correlation: ", np.corrcoef(assignments, targets))
    print("Spearman Correlation: ", sp.stats.spearmanr(assignments, targets))
main()
# Out:
# Word1:  love
# Word2:  sex
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  6.77
# ------------------------------
# Word1:  tiger
# Word2:  cat
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.35
# ------------------------------
# Word1:  tiger
# Word2:  tiger
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# Human Similarity:  10.00
# ------------------------------
# Word1:  book
# Word2:  paper
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  7.46
# ------------------------------
# Word1:  computer
# Word2:  keyboard
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.62
# ------------------------------
# Word1:  computer
# Word2:  internet
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  7.58
# ------------------------------
# Word1:  plane
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  5.77
# ------------------------------
# Word1:  train
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.31
# ------------------------------
# Word1:  telephone
# Word2:  communication
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  7.50
# ------------------------------
# Word1:  television
# Word2:  radio
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  6.77
# ------------------------------
# Word1:  media
# Word2:  radio
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.42
# ------------------------------
# Word1:  drug
# Word2:  abuse
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  6.85
# ------------------------------
# Word1:  bread
# Word2:  butter
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  6.19
# ------------------------------
# Word1:  cucumber
# Word2:  potato
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  5.92
# ------------------------------
# Word1:  doctor
# Word2:  nurse
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  7.00
# ------------------------------
# Word1:  professor
# Word2:  doctor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  6.62
# ------------------------------
# Word1:  student
# Word2:  professor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  6.81
# ------------------------------
# Word1:  smart
# Word2:  student
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  4.62
# ------------------------------
# Word1:  smart
# Word2:  stupid
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  5.81
# ------------------------------
# Word1:  company
# Word2:  stock
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  7.08
# ------------------------------
# Word1:  stock
# Word2:  market
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  8.08
# ------------------------------
# Word1:  stock
# Word2:  phone
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  1.62
# ------------------------------
# Word1:  stock
# Word2:  CD
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  1.31
# ------------------------------
# Word1:  stock
# Word2:  jaguar
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  0.92
# ------------------------------
# Word1:  stock
# Word2:  egg
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  1.81
# ------------------------------
# Word1:  fertility
# Word2:  egg
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  6.69
# ------------------------------
# Word1:  stock
# Word2:  live
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  3.73
# ------------------------------
# Word1:  stock
# Word2:  life
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  0.92
# ------------------------------
# Word1:  book
# Word2:  library
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  7.46
# ------------------------------
# Word1:  bank
# Word2:  money
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  8.12
# ------------------------------
# Word1:  wood
# Word2:  forest
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# Human Similarity:  7.73
# ------------------------------
# Word1:  money
# Word2:  cash
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  9.15
# ------------------------------
# Word1:  professor
# Word2:  cucumber
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  0.31
# ------------------------------
# Word1:  king
# Word2:  cabbage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  0.23
# ------------------------------
# Word1:  king
# Word2:  queen
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# Human Similarity:  8.58
# ------------------------------
# Word1:  king
# Word2:  rook
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  5.92
# ------------------------------
# Word1:  bishop
# Word2:  rabbi
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  6.69
# ------------------------------
# Word1:  Jerusalem
# Word2:  Israel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  8.46
# ------------------------------
# Word1:  Jerusalem
# Word2:  Palestinian
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  7.65
# ------------------------------
# Word1:  holy
# Word2:  sex
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  1.62
# ------------------------------
# Word1:  fuck
# Word2:  sex
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  9.44
# ------------------------------
# Word1:  Maradona
# Word2:  football
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  8.62
# ------------------------------
# Word1:  football
# Word2:  soccer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# Human Similarity:  9.03
# ------------------------------
# Word1:  football
# Word2:  basketball
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  6.81
# ------------------------------
# Word1:  football
# Word2:  tennis
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.63
# ------------------------------
# Word1:  tennis
# Word2:  racket
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  7.56
# ------------------------------
# Word1:  Arafat
# Word2:  peace
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  6.73
# ------------------------------
# Word1:  Arafat
# Word2:  terror
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  7.65
# ------------------------------
# Word1:  Arafat
# Word2:  Jackson
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  2.50
# ------------------------------
# Word1:  law
# Word2:  lawyer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  8.38
# ------------------------------
# Word1:  movie
# Word2:  star
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  7.38
# ------------------------------
# Word1:  movie
# Word2:  popcorn
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  6.19
# ------------------------------
# Word1:  movie
# Word2:  critic
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  6.73
# ------------------------------
# Word1:  movie
# Word2:  theater
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  7.92
# ------------------------------
# Word1:  physics
# Word2:  proton
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.0055218656020977
# Human Similarity:  8.12
# ------------------------------
# Word1:  physics
# Word2:  chemistry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  7.35
# ------------------------------
# Word1:  space
# Word2:  chemistry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  4.88
# ------------------------------
# Word1:  alcohol
# Word2:  chemistry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  5.54
# ------------------------------
# Word1:  vodka
# Word2:  gin
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  8.46
# ------------------------------
# Word1:  vodka
# Word2:  brandy
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  8.13
# ------------------------------
# Word1:  drink
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  3.04
# ------------------------------
# Word1:  drink
# Word2:  ear
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  1.31
# ------------------------------
# Word1:  drink
# Word2:  mouth
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  5.96
# ------------------------------
# Word1:  drink
# Word2:  eat
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  6.87
# ------------------------------
# Word1:  baby
# Word2:  mother
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  7.85
# ------------------------------
# Word1:  drink
# Word2:  mother
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  2.65
# ------------------------------
# Word1:  car
# Word2:  automobile
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# Human Similarity:  8.94
# ------------------------------
# Word1:  gem
# Word2:  jewel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# Human Similarity:  8.96
# ------------------------------
# Word1:  journey
# Word2:  voyage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# Human Similarity:  9.29
# ------------------------------
# Word1:  boy
# Word2:  lad
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# Human Similarity:  8.83
# ------------------------------
# Word1:  coast
# Word2:  shore
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  9.10
# ------------------------------
# Word1:  asylum
# Word2:  madhouse
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# Human Similarity:  8.87
# ------------------------------
# Word1:  magician
# Word2:  wizard
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# Human Similarity:  9.02
# ------------------------------
# Word1:  midday
# Word2:  noon
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# Human Similarity:  9.29
# ------------------------------
# Word1:  furnace
# Word2:  stove
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  8.79
# ------------------------------
# Word1:  food
# Word2:  fruit
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  7.52
# ------------------------------
# Word1:  bird
# Word2:  cock
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# Human Similarity:  7.10
# ------------------------------
# Word1:  bird
# Word2:  crane
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.38
# ------------------------------
# Word1:  tool
# Word2:  implement
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  6.46
# ------------------------------
# Word1:  brother
# Word2:  monk
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  6.27
# ------------------------------
# Word1:  crane
# Word2:  implement
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  2.69
# ------------------------------
# Word1:  lad
# Word2:  brother
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  4.46
# ------------------------------
# Word1:  journey
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0.8232003088081431
# Human Similarity:  5.85
# ------------------------------
# Word1:  monk
# Word2:  oracle
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  5.00
# ------------------------------
# Word1:  cemetery
# Word2:  woodland
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  2.08
# ------------------------------
# Word1:  food
# Word2:  rooster
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0.9409833444645266
# Human Similarity:  4.42
# ------------------------------
# Word1:  coast
# Word2:  hill
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  4.38
# ------------------------------
# Word1:  forest
# Word2:  graveyard
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  1.85
# ------------------------------
# Word1:  shore
# Word2:  woodland
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  3.08
# ------------------------------
# Word1:  monk
# Word2:  slave
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  0.92
# ------------------------------
# Word1:  coast
# Word2:  forest
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  3.15
# ------------------------------
# Word1:  lad
# Word2:  wizard
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  0.92
# ------------------------------
# Word1:  chord
# Word2:  smile
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  0.54
# ------------------------------
# Word1:  glass
# Word2:  magician
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  2.08
# ------------------------------
# Word1:  noon
# Word2:  string
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  0.54
# ------------------------------
# Word1:  rooster
# Word2:  voyage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0.5355182363563622
# Human Similarity:  0.62
# ------------------------------
# Word1:  money
# Word2:  dollar
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  8.42
# ------------------------------
# Word1:  money
# Word2:  cash
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  9.08
# ------------------------------
# Word1:  money
# Word2:  currency
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  9.04
# ------------------------------
# Word1:  money
# Word2:  wealth
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  8.27
# ------------------------------
# Word1:  money
# Word2:  property
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  7.57
# ------------------------------
# Word1:  money
# Word2:  possession
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  7.29
# ------------------------------
# Word1:  money
# Word2:  bank
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  8.50
# ------------------------------
# Word1:  money
# Word2:  deposit
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  7.73
# ------------------------------
# Word1:  money
# Word2:  withdrawal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  6.88
# ------------------------------
# Word1:  money
# Word2:  laundering
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  5.65
# ------------------------------
# Word1:  money
# Word2:  operation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  3.31
# ------------------------------
# Word1:  tiger
# Word2:  jaguar
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  8.00
# ------------------------------
# Word1:  tiger
# Word2:  feline
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  8.00
# ------------------------------
# Word1:  tiger
# Word2:  carnivore
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  7.08
# ------------------------------
# Word1:  tiger
# Word2:  mammal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  6.85
# ------------------------------
# Word1:  tiger
# Word2:  animal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.00
# ------------------------------
# Word1:  tiger
# Word2:  organism
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  4.77
# ------------------------------
# Word1:  tiger
# Word2:  fauna
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  5.62
# ------------------------------
# Word1:  tiger
# Word2:  zoo
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  5.87
# ------------------------------
# Word1:  psychology
# Word2:  psychiatry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  8.08
# ------------------------------
# Word1:  psychology
# Word2:  anxiety
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  7.00
# ------------------------------
# Word1:  psychology
# Word2:  fear
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  6.85
# ------------------------------
# Word1:  psychology
# Word2:  depression
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  7.42
# ------------------------------
# Word1:  psychology
# Word2:  clinic
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  6.58
# ------------------------------
# Word1:  psychology
# Word2:  doctor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  6.42
# ------------------------------
# Word1:  psychology
# Word2:  Freud
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  8.21
# ------------------------------
# Word1:  psychology
# Word2:  mind
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  7.69
# ------------------------------
# Word1:  psychology
# Word2:  health
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  7.23
# ------------------------------
# Word1:  psychology
# Word2:  science
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  6.71
# ------------------------------
# Word1:  psychology
# Word2:  discipline
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  5.58
# ------------------------------
# Word1:  psychology
# Word2:  cognition
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  7.48
# ------------------------------
# Word1:  planet
# Word2:  star
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  8.45
# ------------------------------
# Word1:  planet
# Word2:  constellation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  8.06
# ------------------------------
# Word1:  planet
# Word2:  moon
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  8.08
# ------------------------------
# Word1:  planet
# Word2:  sun
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  8.02
# ------------------------------
# Word1:  planet
# Word2:  galaxy
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  8.11
# ------------------------------
# Word1:  planet
# Word2:  space
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  7.92
# ------------------------------
# Word1:  planet
# Word2:  astronomer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  7.94
# ------------------------------
# Word1:  precedent
# Word2:  example
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  5.85
# ------------------------------
# Word1:  precedent
# Word2:  information
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  3.85
# ------------------------------
# Word1:  precedent
# Word2:  cognition
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  2.81
# ------------------------------
# Word1:  precedent
# Word2:  law
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  6.65
# ------------------------------
# Word1:  precedent
# Word2:  collection
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  2.50
# ------------------------------
# Word1:  precedent
# Word2:  group
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  1.77
# ------------------------------
# Word1:  precedent
# Word2:  antecedent
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.04
# ------------------------------
# Word1:  cup
# Word2:  coffee
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.58
# ------------------------------
# Word1:  cup
# Word2:  tableware
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  6.85
# ------------------------------
# Word1:  cup
# Word2:  article
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  2.40
# ------------------------------
# Word1:  cup
# Word2:  artifact
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  2.92
# ------------------------------
# Word1:  cup
# Word2:  object
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  3.69
# ------------------------------
# Word1:  cup
# Word2:  entity
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  2.15
# ------------------------------
# Word1:  cup
# Word2:  drink
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  7.25
# ------------------------------
# Word1:  cup
# Word2:  food
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  5.00
# ------------------------------
# Word1:  cup
# Word2:  substance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  1.92
# ------------------------------
# Word1:  cup
# Word2:  liquid
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  5.90
# ------------------------------
# Word1:  jaguar
# Word2:  cat
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.42
# ------------------------------
# Word1:  jaguar
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0.8803587226480918
# Human Similarity:  7.27
# ------------------------------
# Word1:  energy
# Word2:  secretary
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  1.81
# ------------------------------
# Word1:  secretary
# Word2:  senate
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  5.06
# ------------------------------
# Word1:  energy
# Word2:  laboratory
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  5.09
# ------------------------------
# Word1:  computer
# Word2:  laboratory
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  6.78
# ------------------------------
# Word1:  weapon
# Word2:  secret
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  6.06
# ------------------------------
# Word1:  FBI
# Word2:  fingerprint
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  6.94
# ------------------------------
# Word1:  FBI
# Word2:  investigation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.0055218656020977
# Human Similarity:  8.31
# ------------------------------
# Word1:  investigation
# Word2:  effort
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  4.59
# ------------------------------
# Word1:  Mars
# Word2:  water
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  2.94
# ------------------------------
# Word1:  Mars
# Word2:  scientist
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  5.63
# ------------------------------
# Word1:  news
# Word2:  report
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# Human Similarity:  8.16
# ------------------------------
# Word1:  canyon
# Word2:  landscape
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  7.53
# ------------------------------
# Word1:  image
# Word2:  surface
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  4.56
# ------------------------------
# Word1:  discovery
# Word2:  space
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  6.34
# ------------------------------
# Word1:  water
# Word2:  seepage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  6.56
# ------------------------------
# Word1:  sign
# Word2:  recess
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  2.38
# ------------------------------
# Word1:  Wednesday
# Word2:  news
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  2.22
# ------------------------------
# Word1:  mile
# Word2:  kilometer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  8.66
# ------------------------------
# Word1:  computer
# Word2:  news
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  4.47
# ------------------------------
# Word1:  territory
# Word2:  surface
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  5.34
# ------------------------------
# Word1:  atmosphere
# Word2:  landscape
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  3.69
# ------------------------------
# Word1:  president
# Word2:  medal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  3.00
# ------------------------------
# Word1:  war
# Word2:  troops
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  8.13
# ------------------------------
# Word1:  record
# Word2:  number
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  6.31
# ------------------------------
# Word1:  skin
# Word2:  eye
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.22
# ------------------------------
# Word1:  Japanese
# Word2:  American
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  6.50
# ------------------------------
# Word1:  theater
# Word2:  history
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  3.91
# ------------------------------
# Word1:  volunteer
# Word2:  motto
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  2.56
# ------------------------------
# Word1:  prejudice
# Word2:  recognition
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  3.00
# ------------------------------
# Word1:  decoration
# Word2:  valor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  5.63
# ------------------------------
# Word1:  century
# Word2:  year
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  7.59
# ------------------------------
# Word1:  century
# Word2:  nation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  3.16
# ------------------------------
# Word1:  delay
# Word2:  racism
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  1.19
# ------------------------------
# Word1:  delay
# Word2:  news
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  3.31
# ------------------------------
# Word1:  minister
# Word2:  party
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.63
# ------------------------------
# Word1:  peace
# Word2:  plan
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  4.75
# ------------------------------
# Word1:  minority
# Word2:  peace
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  3.69
# ------------------------------
# Word1:  attempt
# Word2:  peace
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  4.25
# ------------------------------
# Word1:  government
# Word2:  crisis
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  6.56
# ------------------------------
# Word1:  deployment
# Word2:  departure
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  4.25
# ------------------------------
# Word1:  deployment
# Word2:  withdrawal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  5.88
# ------------------------------
# Word1:  energy
# Word2:  crisis
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  5.94
# ------------------------------
# Word1:  announcement
# Word2:  news
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  7.56
# ------------------------------
# Word1:  announcement
# Word2:  effort
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  2.75
# ------------------------------
# Word1:  stroke
# Word2:  hospital
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  7.03
# ------------------------------
# Word1:  disability
# Word2:  death
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  5.47
# ------------------------------
# Word1:  victim
# Word2:  emergency
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  6.47
# ------------------------------
# Word1:  treatment
# Word2:  recovery
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.91
# ------------------------------
# Word1:  journal
# Word2:  association
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  4.97
# ------------------------------
# Word1:  doctor
# Word2:  personnel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  5.00
# ------------------------------
# Word1:  doctor
# Word2:  liability
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  5.19
# ------------------------------
# Word1:  liability
# Word2:  insurance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  7.03
# ------------------------------
# Word1:  school
# Word2:  center
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  3.44
# ------------------------------
# Word1:  reason
# Word2:  hypertension
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  2.31
# ------------------------------
# Word1:  reason
# Word2:  criterion
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  5.91
# ------------------------------
# Word1:  hundred
# Word2:  percent
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  7.38
# ------------------------------
# Word1:  Harvard
# Word2:  Yale
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  8.13
# ------------------------------
# Word1:  hospital
# Word2:  infrastructure
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  4.63
# ------------------------------
# Word1:  death
# Word2:  row
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  5.25
# ------------------------------
# Word1:  death
# Word2:  inmate
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  5.03
# ------------------------------
# Word1:  lawyer
# Word2:  evidence
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  6.69
# ------------------------------
# Word1:  life
# Word2:  death
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  7.88
# ------------------------------
# Word1:  life
# Word2:  term
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  4.50
# ------------------------------
# Word1:  word
# Word2:  similarity
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  4.75
# ------------------------------
# Word1:  board
# Word2:  recommendation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  4.47
# ------------------------------
# Word1:  governor
# Word2:  interview
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  3.25
# ------------------------------
# Word1:  OPEC
# Word2:  country
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  5.63
# ------------------------------
# Word1:  peace
# Word2:  atmosphere
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  3.69
# ------------------------------
# Word1:  peace
# Word2:  insurance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  2.94
# ------------------------------
# Word1:  territory
# Word2:  kilometer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  5.28
# ------------------------------
# Word1:  travel
# Word2:  activity
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  5.00
# ------------------------------
# Word1:  competition
# Word2:  price
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  6.44
# ------------------------------
# Word1:  consumer
# Word2:  confidence
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  4.13
# ------------------------------
# Word1:  consumer
# Word2:  energy
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  4.75
# ------------------------------
# Word1:  problem
# Word2:  airport
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  2.38
# ------------------------------
# Word1:  car
# Word2:  flight
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  4.94
# ------------------------------
# Word1:  credit
# Word2:  card
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  8.06
# ------------------------------
# Word1:  credit
# Word2:  information
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  5.31
# ------------------------------
# Word1:  hotel
# Word2:  reservation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  8.03
# ------------------------------
# Word1:  grocery
# Word2:  money
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  5.94
# ------------------------------
# Word1:  registration
# Word2:  arrangement
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  6.00
# ------------------------------
# Word1:  arrangement
# Word2:  accommodation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  5.41
# ------------------------------
# Word1:  month
# Word2:  hotel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  1.81
# ------------------------------
# Word1:  type
# Word2:  kind
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  8.97
# ------------------------------
# Word1:  arrival
# Word2:  hotel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  6.00
# ------------------------------
# Word1:  bed
# Word2:  closet
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  6.72
# ------------------------------
# Word1:  closet
# Word2:  clothes
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  8.00
# ------------------------------
# Word1:  situation
# Word2:  conclusion
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  4.81
# ------------------------------
# Word1:  situation
# Word2:  isolation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  3.88
# ------------------------------
# Word1:  impartiality
# Word2:  interest
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  5.16
# ------------------------------
# Word1:  direction
# Word2:  combination
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  2.25
# ------------------------------
# Word1:  street
# Word2:  place
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.44
# ------------------------------
# Word1:  street
# Word2:  avenue
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# Human Similarity:  8.88
# ------------------------------
# Word1:  street
# Word2:  block
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.88
# ------------------------------
# Word1:  street
# Word2:  children
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  4.94
# ------------------------------
# Word1:  listing
# Word2:  proximity
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  2.56
# ------------------------------
# Word1:  listing
# Word2:  category
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  6.38
# ------------------------------
# Word1:  cell
# Word2:  phone
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  7.81
# ------------------------------
# Word1:  production
# Word2:  hike
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  1.75
# ------------------------------
# Word1:  benchmark
# Word2:  index
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  4.25
# ------------------------------
# Word1:  media
# Word2:  trading
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  3.88
# ------------------------------
# Word1:  media
# Word2:  gain
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  2.88
# ------------------------------
# Word1:  dividend
# Word2:  payment
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  7.63
# ------------------------------
# Word1:  dividend
# Word2:  calculation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  6.48
# ------------------------------
# Word1:  calculation
# Word2:  computation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# Human Similarity:  8.44
# ------------------------------
# Word1:  currency
# Word2:  market
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  7.50
# ------------------------------
# Word1:  OPEC
# Word2:  oil
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  8.59
# ------------------------------
# Word1:  oil
# Word2:  stock
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  6.34
# ------------------------------
# Word1:  announcement
# Word2:  production
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  3.38
# ------------------------------
# Word1:  announcement
# Word2:  warning
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.00
# ------------------------------
# Word1:  profit
# Word2:  warning
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  3.88
# ------------------------------
# Word1:  profit
# Word2:  loss
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  7.63
# ------------------------------
# Word1:  dollar
# Word2:  yen
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.78
# ------------------------------
# Word1:  dollar
# Word2:  buck
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# Human Similarity:  9.22
# ------------------------------
# Word1:  dollar
# Word2:  profit
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  7.38
# ------------------------------
# Word1:  dollar
# Word2:  loss
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  6.09
# ------------------------------
# Word1:  computer
# Word2:  software
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  8.50
# ------------------------------
# Word1:  network
# Word2:  hardware
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  8.31
# ------------------------------
# Word1:  phone
# Word2:  equipment
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  7.13
# ------------------------------
# Word1:  equipment
# Word2:  maker
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  5.91
# ------------------------------
# Word1:  luxury
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.0055218656020977
# Human Similarity:  6.47
# ------------------------------
# Word1:  five
# Word2:  month
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  3.38
# ------------------------------
# Word1:  report
# Word2:  gain
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  3.63
# ------------------------------
# Word1:  investor
# Word2:  earning
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  7.13
# ------------------------------
# Word1:  liquid
# Word2:  water
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# Human Similarity:  7.89
# ------------------------------
# Word1:  baseball
# Word2:  season
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.0055218656020977
# Human Similarity:  5.97
# ------------------------------
# Word1:  game
# Word2:  victory
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  7.03
# ------------------------------
# Word1:  game
# Word2:  team
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  7.69
# ------------------------------
# Word1:  marathon
# Word2:  sprint
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  7.47
# ------------------------------
# Word1:  game
# Word2:  series
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  6.19
# ------------------------------
# Word1:  game
# Word2:  defeat
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  6.97
# ------------------------------
# Word1:  seven
# Word2:  series
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  3.56
# ------------------------------
# Word1:  seafood
# Word2:  sea
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  7.47
# ------------------------------
# Word1:  seafood
# Word2:  food
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  8.34
# ------------------------------
# Word1:  seafood
# Word2:  lobster
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  8.70
# ------------------------------
# Word1:  lobster
# Word2:  food
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  7.81
# ------------------------------
# Word1:  lobster
# Word2:  wine
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  5.70
# ------------------------------
# Word1:  food
# Word2:  preparation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  6.22
# ------------------------------
# Word1:  video
# Word2:  archive
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  6.34
# ------------------------------
# Word1:  start
# Word2:  year
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  4.06
# ------------------------------
# Word1:  start
# Word2:  match
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  4.47
# ------------------------------
# Word1:  game
# Word2:  round
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  5.97
# ------------------------------
# Word1:  boxing
# Word2:  round
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  7.61
# ------------------------------
# Word1:  championship
# Word2:  tournament
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  8.36
# ------------------------------
# Word1:  fighting
# Word2:  defeating
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  7.41
# ------------------------------
# Word1:  line
# Word2:  insurance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  2.69
# ------------------------------
# Word1:  day
# Word2:  summer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  3.94
# ------------------------------
# Word1:  summer
# Word2:  drought
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.16
# ------------------------------
# Word1:  summer
# Word2:  nature
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  5.63
# ------------------------------
# Word1:  day
# Word2:  dawn
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  7.53
# ------------------------------
# Word1:  nature
# Word2:  environment
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  8.31
# ------------------------------
# Word1:  environment
# Word2:  ecology
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# Human Similarity:  8.81
# ------------------------------
# Word1:  nature
# Word2:  man
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  6.25
# ------------------------------
# Word1:  man
# Word2:  woman
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  8.30
# ------------------------------
# Word1:  man
# Word2:  governor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  5.25
# ------------------------------
# Word1:  murder
# Word2:  manslaughter
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  8.53
# ------------------------------
# Word1:  soap
# Word2:  opera
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  7.94
# ------------------------------
# Word1:  opera
# Word2:  performance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  6.88
# ------------------------------
# Word1:  life
# Word2:  lesson
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  5.94
# ------------------------------
# Word1:  focus
# Word2:  life
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  4.06
# ------------------------------
# Word1:  production
# Word2:  crew
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  6.25
# ------------------------------
# Word1:  television
# Word2:  film
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  7.72
# ------------------------------
# Word1:  lover
# Word2:  quarrel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  6.19
# ------------------------------
# Word1:  viewer
# Word2:  serial
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  2.97
# ------------------------------
# Word1:  possibility
# Word2:  girl
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  1.94
# ------------------------------
# Word1:  population
# Word2:  development
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  3.75
# ------------------------------
# Word1:  morality
# Word2:  importance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  3.31
# ------------------------------
# Word1:  morality
# Word2:  marriage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  3.69
# ------------------------------
# Word1:  Mexico
# Word2:  Brazil
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  7.44
# ------------------------------
# Word1:  gender
# Word2:  equality
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  6.41
# ------------------------------
# Word1:  change
# Word2:  attitude
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  5.44
# ------------------------------
# Word1:  family
# Word2:  planning
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  6.25
# ------------------------------
# Word1:  opera
# Word2:  industry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  2.63
# ------------------------------
# Word1:  sugar
# Word2:  approach
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  0.88
# ------------------------------
# Word1:  practice
# Word2:  institution
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  3.19
# ------------------------------
# Word1:  ministry
# Word2:  culture
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  4.69
# ------------------------------
# Word1:  problem
# Word2:  challenge
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.75
# ------------------------------
# Word1:  size
# Word2:  prominence
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  5.31
# ------------------------------
# Word1:  country
# Word2:  citizen
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  7.31
# ------------------------------
# Word1:  planet
# Word2:  people
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  5.75
# ------------------------------
# Word1:  development
# Word2:  issue
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  3.97
# ------------------------------
# Word1:  experience
# Word2:  music
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  3.47
# ------------------------------
# Word1:  music
# Word2:  project
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  3.63
# ------------------------------
# Word1:  glass
# Word2:  metal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  5.56
# ------------------------------
# Word1:  aluminum
# Word2:  metal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.83
# ------------------------------
# Word1:  chance
# Word2:  credibility
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  3.88
# ------------------------------
# Word1:  exhibit
# Word2:  memorabilia
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  5.31
# ------------------------------
# Word1:  concert
# Word2:  virtuoso
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  6.81
# ------------------------------
# Word1:  rock
# Word2:  jazz
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  7.59
# ------------------------------
# Word1:  museum
# Word2:  theater
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  7.19
# ------------------------------
# Word1:  observation
# Word2:  architecture
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  4.38
# ------------------------------
# Word1:  space
# Word2:  world
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  6.53
# ------------------------------
# Word1:  preservation
# Word2:  world
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  6.19
# ------------------------------
# Word1:  admission
# Word2:  ticket
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  7.69
# ------------------------------
# Word1:  shower
# Word2:  thunderstorm
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  6.31
# ------------------------------
# Word1:  shower
# Word2:  flood
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  6.03
# ------------------------------
# Word1:  weather
# Word2:  forecast
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  8.34
# ------------------------------
# Word1:  disaster
# Word2:  area
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  6.25
# ------------------------------
# Word1:  governor
# Word2:  office
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  6.34
# ------------------------------
# Word1:  architecture
# Word2:  century
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  3.78
# ------------------------------
# Pearson Correlation:  [[1.         0.26142012]
#  [0.26142012 1.        ]]
# Spearman Correlation:  SpearmanrResult(correlation=0.2651845536640065, pvalue=4.292887522518468e-07)

# %% [markdown]
# CONSEGNA 2.1:
#
# L'esercitazione consiste nell'estrarre 50 frasi dal corpus SemCor (corpus annotato con i synset di WN) e disambiguare (almeno) un sostantivo per frase.
#
# Calcolare l’accuratezza del sistema implementato sulla base dei sensi annotati in SemCor.

# %%
tokenizer = RegexpTokenizer(r'\w+')

INDEXES_NUM = 1000 #è il limite, partendo da 0, di sentence che possono essere testate relative al database SemCor
RANGE = 50 #è il numero di sentence che effettivamente verranno testate

sentences_tag = semcor.tagged_sents() #lista di liste. Ogni lista rappresenta una sentence e ad ogni parola della sentence è associato un pos tag
sentences = semcor.sents() #lista di liste di parole. Ogni lista rappresenta una sentence
sentences_sem = semcor.tagged_sents(tag = "sem") #lista di liste. Ogni lista rappresenta una sentence e ad ogni parola della sentence è associato un synset gold

def main():
    evaluated = 0 #termini valutati
    checked = 0 #termini valutati correttamente
    index_evaluated = set() #insieme degli indici già valutati
    while(evaluated <= RANGE):
        while True: #fino a quando non trova una word che ha almeno un senso in wordnet   
            index = get_random_index(index_evaluated, INDEXES_NUM)
            word = get_random_noun(get_dictionary_tag(sentences_tag[index],sentences_sem[index]))
            if word:
                break
        sentence = sentences[index]
        print("Parola da disambiguare: ",word)
        #all'algoritmo di lesk viene dato in input la word e l'insieme dei termini che formano la frase, uniti sottoforma di stringa
        best_sense = str(lesk_algorithm(word, ' '.join(word for word in sentence), word_type='NOUN'))
        print("Senso attribuito dall'algoritmo di Lesk: ",best_sense)
        target_lemma = get_synset_target_for_word_in_sentence(word,sentences_sem[index])
        print("Senso Target: ",target_lemma)
        best_sense_lemma = best_sense[8:len(best_sense)-2]
        if target_lemma:
            if best_sense_lemma in target_lemma: checked= checked + 1
        evaluated += 1
        print("------------------------------")
    
    print("Termini valutati: ", evaluated)
    print("Termini valutati correttamente: ", checked)
    print("Accuratezza: ", checked/RANGE)
    
main()
# Out:
# Parola da disambiguare:  bill
# Frase in cui compare la parola:  Cox argued that the bill is `` probably unconstitutional '' since , he said , it would impair contracts .
# Contesto della frase:  {'bill', 'contract', 'argue', 'unconstitutional', 'cox', 'impair'}
# Max Signature:  {'bill', 'draft', 'public', 'hearing', 'law', 'statute', 'hold'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('bill.n.01')
# Senso Target:  Lemma('bill.n.01.bill')
# ------------------------------
# Parola da disambiguare:  basketball
# Frase in cui compare la parola:  Benington recalled that he once told Hartweger that he doubted Gordon would ever play much for him because he seemed to be lacking in all of the accepted basketball skills .
# Contesto della frase:  {'benington', 'basketball', 'doubt', 'play', 'lack', 'gordon', 'accepted', 'hartweger', 'recall', 'skill'}
# Max Signature:  {'play', 'basketball', 'inflated', 'ball'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('basketball.n.02')
# Senso Target:  Lemma('basketball.n.01.basketball')
# ------------------------------
# Parola da disambiguare:  frenzy
# Frase in cui compare la parola:  This may be opera bouffe now , but it will become more serious should the cold war mount in frenzy .
# Contesto della frase:  {'serious', 'war', 'bouffe', 'opera', 'frenzy', 'cold', 'mount'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('craze.n.02')
# Senso Target:  Lemma('craze.n.02.frenzy')
# ------------------------------
# Parola da disambiguare:  ball
# Frase in cui compare la parola:  He was called upon 26 times - more than all of the other ball carriers combined - and delivered 145 yards .
# Contesto della frase:  {'combine', 'deliver', 'call', 'yard', 'ball', 'time', 'carrier'}
# Max Signature:  {'hit', 'throw', 'mph', 'round', 'mayor', 'pocket', 'corner', 'roll', 'game', 'ball', 'object', 'serve', 'travel', 'kick'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('ball.n.01')
# Senso Target:  Lemma('ball.n.01.ball')
# ------------------------------
# Parola da disambiguare:  booking
# Frase in cui compare la parola:  Allied Arts then notified us that the Kirov would cut short its Los Angeles booking , fly here to open Nov. 28 , and close Dec. 2 .
# Contesto della frase:  {'cut', 'book', 'nov', 'arts', 'short', 'fly', 'open', 'dec', 'angeles', 'los', 'allied', 'kirov', 'notify', 'close'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('engagement.n.05')
# Senso Target:  Lemma('engagement.n.05.booking')
# ------------------------------
# Parola da disambiguare:  Georgia
# Frase in cui compare la parola:  Implementation of Georgia 's automobile title law was also recommended by the outgoing jury .
# Contesto della frase:  {'jury', 'title', 'recommend', 'outgoing', 'automobile', 'georgia', 'implementation', 'law'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('georgia.n.01')
# Senso Target:  Lemma('georgia.n.01.Georgia')
# ------------------------------
# Parola da disambiguare:  changes
# Frase in cui compare la parola:  Since the apparatus is new , it requires experimentation and changes in technique .
# Contesto della frase:  {'require', 'change', 'experimentation', 'technique', 'apparatus'}
# Max Signature:  {'phase', 'modification', 'pass', 'visit', 'ago', 'change', 'worse', 'occur', 'event', 'neighborhood', 'year', 'increase', 'storm', 'sale', 'undergone', 'intend'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('change.n.01')
# Senso Target:  Lemma('change.n.03.change')
# ------------------------------
# Parola da disambiguare:  result
# Frase in cui compare la parola:  The City Purchasing Department , the jury said , `` is lacking in experienced clerical personnel as a result of city personnel policies '' .
# Contesto della frase:  {'jury', 'purchasing', 'experienced', 'personnel', 'lack', 'result', 'city', 'clerical', 'department', 'policy'}
# Max Signature:  {'peaceful', 'answer', 'book', 'decimal', 'compute', 'explain', 'result', 'find', 'solve', 'statement', 'solution', 'problem', 'place'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('solution.n.02')
# Senso Target:  Lemma('consequence.n.01.result')
# ------------------------------
# Parola da disambiguare:  day
# Frase in cui compare la parola:  That means Stan Musial probably will ride the bench on the seventh anniversary of his record five home run day against the Giants .
# Contesto della frase:  {'musial', 'giants', 'seventh', 'ride', 'bench', 'day', 'record', 'anniversary', 'stan'}
# Max Signature:  {'rotation', 'complete', 'earth', 'leave', 'axis', 'passenger', 'day', 'performance', 'time'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('day.n.01')
# Senso Target:  Lemma('day.n.03.day')
# ------------------------------
# Parola da disambiguare:  statue
# Frase in cui compare la parola:  In 1899 , Parliament erected a statue to Cromwell in Westminster , facing Whitehall and there , presumably , he still stands .
# Contesto della frase:  {'statue', 'westminster', 'cromwell', 'face', 'presumably', 'erect', 'whitehall', 'stand', 'parliament'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('statue.n.01')
# Senso Target:  Lemma('statue.n.01.statue')
# ------------------------------
# Parola da disambiguare:  baseball
# Frase in cui compare la parola:  Boston Red Sox Outfielder Jackie Jensen said Monday night he was through playing baseball .
# Contesto della frase:  {'sox', 'jackie', 'night', 'play', 'monday', 'boston', 'red', 'baseball', 'jensen', 'outfielder'}
# Max Signature:  {'turn', 'desire', 'area', 'national', 'play', 'score', 'lot', 'league', 'baseball', 'player', 'game', 'bat', 'school', 'ball', 'empty', 'high', 'team'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('baseball.n.01')
# Senso Target:  Lemma('baseball.n.01.baseball')
# ------------------------------
# Parola da disambiguare:  count
# Frase in cui compare la parola:  Willie 's partner was Long Jim Barnes , who tried to keep count .
# Contesto della frase:  {'count', 'barnes', 'partner', 'willie', 'long', 'jim'}
# Max Signature:  {'total', 'count', 'number', 'blood'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('count.n.01')
# Senso Target:  Lemma('count.n.02.count')
# ------------------------------
# Parola da disambiguare:  train
# Frase in cui compare la parola:  He took a midnight train out of Cleveland Saturday , without an official word to anybody , and has stayed away from newsmen on his train trip across the nation to Reno , Nev. , where his wife , former Olympic Diving Champion Zoe Ann Olsen , awaited .
# Contesto della frase:  {'saturday', 'diving', 'nation', 'await', 'trip', 'ann', 'champion', 'word', 'olympic', 'train', 'olsen', 'midnight', 'zoe', 'official', 'cleveland', 'reno', 'wife', 'stay', 'nev', 'newsman'}
# Max Signature:  {'car', 'express', 'locomotive', 'railway', 'transport', 'couple', 'junction', 'public', 'provide', 'draw', 'train', 'princeton', 'dont'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('train.n.01')
# Senso Target:  Lemma('train.n.01.train')
# ------------------------------
# Parola da disambiguare:  Thursday
# Frase in cui compare la parola:  A Houston teacher , now serving in the Legislature , proposed Thursday a law reducing the time spent learning `` educational methods '' .
# Contesto della frase:  {'teacher', 'legislature', 'houston', 'reduce', 'spend', 'method', 'thursday', 'educational', 'serve', 'law', 'time', 'propose', 'learn'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('thursday.n.01')
# Senso Target:  Lemma('thursday.n.01.Thursday')
# ------------------------------
# Parola da disambiguare:  career
# Frase in cui compare la parola:  During his college career , Dr. Clark was captain of his basketball team and was a football letterman .
# Contesto della frase:  {'football', 'basketball', 'dr', 'college', 'captain', 'letterman', 'career', 'clark', 'team'}
# Max Signature:  {'professional', 'life', 'progression', 'general', 'distinguish', 'work', 'long', 'law', 'career'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('career.n.02')
# Senso Target:  Lemma('career.n.01.career')
# ------------------------------
# Parola da disambiguare:  person
# Frase in cui compare la parola:  writes : Does numbness in the left hand at night , which awakens the person , indicate brain tumor ?
# Contesto della frase:  {'left', 'person', 'night', 'numbness', 'writes', 'tumor', 'brain', 'awaken', 'hand', 'indicate'}
# Max Signature:  {'determiner', 'grammatical', 'category', 'classification', 'form', 'addressee', 'pronoun', 'accord', 'speaker', 'possessive', 'party', 'third', 'person', 'verb', 'indicate', 'talk'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('person.n.03')
# Senso Target:  Lemma('person.n.01.person')
# ------------------------------
# Parola da disambiguare:  wife
# Frase in cui compare la parola:  Mayor William B. Hartsfield filed suit for divorce from his wife , Pearl Williams Hartsfield , in Fulton Superior Court Friday .
# Contesto della frase:  {'william', 'suit', 'pearl', 'fulton', 'friday', 'superior', 'file', 'wife', 'williams', 'mayor', 'divorce', 'hartsfield', 'court'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('wife.n.01')
# Senso Target:  Lemma('wife.n.01.wife')
# ------------------------------
# Parola da disambiguare:  calendar
# Frase in cui compare la parola:  The Senate quickly whipped through its meager fare of House bills approved by committees , passing the three on the calendar .
# Contesto della frase:  {'committee', 'house', 'senate', 'bill', 'whip', 'meager', 'pass', 'fare', 'calendar', 'approve'}
# Max Signature:  {'case', 'monday', 'list', 'appointment', 'event', 'calendar', 'social', 'register', 'court'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('calendar.n.02')
# Senso Target:  Lemma('calendar.n.01.calendar')
# ------------------------------
# Parola da disambiguare:  place
# Frase in cui compare la parola:  Who will take Stalin 's place beside Lenin ?
# Contesto della frase:  {'lenin', 'place', 'stalin'}
# Max Signature:  {'planet', 'locate', 'spot', 'surface', 'place', 'point', 'nice', 'bright', 'feature', 'picnic', 'respect', 'region'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('topographic_point.n.01')
# Senso Target:  Lemma('place.n.06.place')
# ------------------------------
# Parola da disambiguare:  weight
# Frase in cui compare la parola:  When he was inducted into the Army at Fort Knox , Ky. , Hansen 's weight had dropped to 180 - `` too light for me to be at my best '' he said .
# Contesto della frase:  {'light', 'knox', 'induct', 'hansen', 'weight', 'drop', 'ky', 'army', 'best', 'fort'}
# Max Signature:  {'relative', 'progression', 'weightiness', 'list', 'grant', 'carry', 'opinion', 'great', 'weight', 'increase', 'item', 'imply'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('weight.n.03')
# Senso Target:  Lemma('weight.n.01.weight')
# ------------------------------
# Parola da disambiguare:  bombs
# Frase in cui compare la parola:  Some time ago , however , Mr. Khrushchev decided that when bigger bombs were made , the Soviet Union would make them .
# Contesto della frase:  {'bomb', 'union', 'decide', 'big', 'time', 'soviet', 'khrushchev'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('bomb.n.01')
# Senso Target:  Lemma('bomb.n.01.bomb')
# ------------------------------
# Parola da disambiguare:  fillip
# Frase in cui compare la parola:  Hugh Downs is heard interviewing Wright , for an added prestige fillip .
# Contesto della frase:  {'prestige', 'interview', 'downs', 'fillip', 'hugh', 'wright', 'hear'}
# Max Signature:  {'fillip', 'tend', 'arouse', 'approval'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('bonus.n.01')
# Senso Target:  Lemma('bonus.n.01.fillip')
# ------------------------------
# Parola da disambiguare:  hands
# Frase in cui compare la parola:  writes : What makes my hands numb when sewing ?
# Contesto della frase:  {'write', 'hand', 'sew', 'numb'}
# Max Signature:  {'illegible', 'write', 'recognize', 'hand', 'handwriting'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('handwriting.n.01')
# Senso Target:  Lemma('hand.n.01.hand')
# ------------------------------
# Parola da disambiguare:  knee
# Frase in cui compare la parola:  Rice has not played since injuring a knee in the opener with Maryland .
# Contesto della frase:  {'maryland', 'play', 'injure', 'rice', 'opener', 'knee'}
# Max Signature:  {'tibia', 'human', 'joint', 'quadruped', 'femur', 'corresponds', 'knee'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('stifle.n.01')
# Senso Target:  Lemma('knee.n.01.knee')
# ------------------------------
# Parola da disambiguare:  knee
# Frase in cui compare la parola:  Wingback Jack Collins injured a knee in the Washington State game but insists he 'll be ready for Oklahoma .
# Contesto della frase:  {'insist', 'ready', 'jack', 'collins', 'game', 'injure', 'washington', 'wingback', 'oklahoma', 'll', 'knee'}
# Max Signature:  {'tibia', 'human', 'joint', 'quadruped', 'femur', 'corresponds', 'knee'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('stifle.n.01')
# Senso Target:  Lemma('knee.n.01.knee')
# ------------------------------
# Parola da disambiguare:  conversions
# Frase in cui compare la parola:  He ran his string of successful conversions this season to 13 straight before one went astray last Saturday night in the 41 - 8 slaughter of Washington State .
# Contesto della frase:  {'straight', 'string', 'saturday', 'night', 'successful', 'season', 'washington', 'conversion', 'slaughter'}
# Max Signature:  {'form', 'change', 'expression', 'centigrade', 'unit', 'conversion', 'fahrenheit'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('conversion.n.02')
# Senso Target:  Lemma('conversion.n.03.conversion')
# ------------------------------
# Parola da disambiguare:  bench
# Frase in cui compare la parola:  Within a week after the injury , suffered in St. Louis 's victory in the final game of the Kentucky tournament , Nordmann was sitting on the Bill 's bench doing what he could to help Benington .
# Contesto della frase:  {'injury', 'benington', 'week', 'st', 'bill', 'help', 'sit', 'bench', 'game', 'victory', 'louis', 'nordmann', 'final', 'kentucky', 'tournament', 'suffer'}
# Max Signature:  {'magistrate', 'judicial', 'collectively', 'compose', 'sit', 'court', 'judge', 'capacity'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('bench.n.05')
# Senso Target:  bench.n.00
# ------------------------------
# Parola da disambiguare:  family
# Frase in cui compare la parola:  Just before game time , Robinson 's pretty wife , Connie informed him that an addition to the family can be expected late next summer .
# Contesto della frase:  {'wife', 'expect', 'game', 'connie', 'addition', 'robinson', 'inform', 'summer', 'late', 'time', 'pretty', 'family'}
# Max Signature:  {'teacher', 'house', 'people', 'unit', 'live', 'christian', 'move', 'good', 'social', 'virginia', 'asleep', 'household', 'wait', 'family'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('family.n.01')
# Senso Target:  Lemma('family.n.02.family')
# ------------------------------
# Parola da disambiguare:  bill
# Frase in cui compare la parola:  The other bill , by Sen. A. M. Aikin Jr. of Paris , would relieve real estate brokers , who pay their own annual licensing fee , from the $ 12 annual occupation license on brokers in such as stocks and bonds .
# Contesto della frase:  {'relieve', 'estate', 'bill', 'fee', 'stock', 'broker', 'pay', 'real', 'annual', 'jr', 'paris', 'license', 'aikin', 'licensing', 'occupation', 'bond', 'sen'}
# Max Signature:  {'render', 'owe', 'bill', 'account', 'service', 'pay', 'leave', 'ship', 'money', 'good', 'itemized', 'statement', 'send'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('bill.n.02')
# Senso Target:  Lemma('bill.n.01.bill')
# ------------------------------
# Parola da disambiguare:  encouragement
# Frase in cui compare la parola:  Georgia Republicans are getting strong encouragement to enter a candidate in the 1962 governor 's race , a top official said Wednesday .
# Contesto della frase:  {'enter', 'governor', 'strong', 'official', 'georgia', 'top', 'republicans', 'wednesday', 'candidate', 'encouragement', 'race'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('encouragement.n.01')
# Senso Target:  Lemma('boost.n.01.encouragement')
# ------------------------------
# Parola da disambiguare:  horror
# Frase in cui compare la parola:  It 's a horror .
# Contesto della frase:  {'horror'}
# Max Signature:  {'beautiful', 'painting', 'horror', 'horrible', 'find', 'inspire'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('horror.n.02')
# Senso Target:  Lemma('horror.n.02.horror')
# ------------------------------
# Parola da disambiguare:  deaf
# Frase in cui compare la parola:  It would authorize the Texas Education Agency to establish county-wide day schools for the deaf in counties of 300000 or more population , require deaf children between 6 and 13 years of age to attend the day schools , permitting older ones to attend the residential Texas School for the Deaf here .
# Contesto della frase:  {'county', 'require', 'child', 'countywide', 'attend', 'texas', 'age', 'residential', 'school', 'establish', 'permit', 'deaf', 'education', 'day', 'authorize', 'year', 'population', 'agency'}
# Max Signature:  {'severe', 'impairment', 'people', 'hearing', 'sign', 'language', 'deaf'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('deaf.n.01')
# Senso Target:  Lemma('deaf.n.01.deaf')
# ------------------------------
# Parola da disambiguare:  behavior
# Frase in cui compare la parola:  It motivates his behavior .
# Contesto della frase:  {'behavior', 'motivate'}
# Max Signature:  {'machine', 'substance', 'reaction', 'study', 'behavior', 'action', 'experiment', 'circumstance', 'particle', 'small'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('behavior.n.02')
# Senso Target:  Lemma('behavior.n.01.behavior')
# ------------------------------
# Parola da disambiguare:  night
# Frase in cui compare la parola:  He was heralded as `` Sportsman of the Year '' by Sports Illustrated , and last night was acclaimed in Rochester as the `` Professional Athlete of the Year '' , a distinction that earned for him the $ 10000 diamond - studded Hickok Belt .
# Contesto della frase:  {'professional', 'night', 'distinction', 'sportsman', 'diamond', 'rochester', 'athlete', 'earn', 'stud', 'sports', 'year', 'hickok', 'belt', 'illustrated', 'herald', 'acclaim'}
# Max Signature:  {'night', 'period', 'spend', 'restless', 'sleep'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('night.n.03')
# Senso Target:  Lemma('night.n.01.night')
# ------------------------------
# Parola da disambiguare:  misbehavior
# Frase in cui compare la parola:  But even mother 's loving attitude will not always prevent misbehavior .
# Contesto della frase:  {'love', 'misbehavior', 'mother', 'prevent', 'attitude'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('misbehavior.n.01')
# Senso Target:  Lemma('misbehavior.n.01.misbehavior')
# ------------------------------
# Parola da disambiguare:  recording
# Frase in cui compare la parola:  The gap between the bookshelf and the record cabinet grows smaller with each new recording catalogue .
# Contesto della frase:  {'catalogue', 'bookshelf', 'gap', 'cabinet', 'record', 'grow', 'small'}
# Max Signature:  {'sound', 'encode', 'signal', 'picture', 'record'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('recording.n.01')
# Senso Target:  Lemma('recording.n.01.recording')
# ------------------------------
# Parola da disambiguare:  athletics
# Frase in cui compare la parola:  He merely became victimized by a form of athletics that respects no one and aggravates all .
# Contesto della frase:  {'form', 'athletics', 'victimize', 'respect', 'aggravate'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('sport.n.01')
# Senso Target:  Lemma('sport.n.01.athletics')
# ------------------------------
# Parola da disambiguare:  practice
# Frase in cui compare la parola:  `` Lindy McDaniel threw batting practice about 25 minutes , and he looked good '' , Hemus said .
# Contesto della frase:  {'lindy', 'hemus', 'throw', 'minute', 'mcdaniel', 'bat', 'good', 'practice'}
# Max Signature:  {'raise', 'dietary', 'change', 'behavior', 'operation', 'annual', 'pattern', 'practice', 'customary'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('practice.n.01')
# Senso Target:  Lemma('exercise.n.03.practice')
# ------------------------------
# Parola da disambiguare:  halfback
# Frase in cui compare la parola:  `` He timed it just right and broke through there before the boy ( halfback Terry Isaacson ) had time to turn around .
# Contesto della frase:  {'turn', 'break', 'boy', 'terry', 'time', 'halfback', 'isaacson'}
# Max Signature:  {'football', 'offensive', 'play', 'position', 'halfback'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('halfback.n.01')
# Senso Target:  Lemma('halfback.n.01.halfback')
# ------------------------------
# Parola da disambiguare:  chairman
# Frase in cui compare la parola:  Marshall Formby of Plainview , former chairman of the Texas Highway Commission , suggested a plan to fill by appointment future vacancies in the Legislature and Congress , eliminating the need for costly special elections .
# Contesto della frase:  {'costly', 'vacancy', 'formby', 'highway', 'fill', 'texas', 'plan', 'legislature', 'appointment', 'future', 'marshall', 'commission', 'chairman', 'eliminate', 'plainview', 'special', 'election', 'congress'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('president.n.04')
# Senso Target:  Lemma('president.n.04.chairman')
# ------------------------------
# Parola da disambiguare:  year
# Frase in cui compare la parola:  The conscience is non-existent in the 2 - year old .
# Contesto della frase:  {'conscience', 'nonexistent', 'year'}
# Max Signature:  {'period', 'time', 'day', 'year'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('year.n.01')
# Senso Target:  Lemma('year.n.01.year')
# ------------------------------
# Parola da disambiguare:  action
# Frase in cui compare la parola:  Friend is off to a great start with a 4 - 0 record but is n't likely to see action here this week .
# Contesto della frase:  {'start', 'nt', 'week', 'action', 'great', 'friend', 'record'}
# Max Signature:  {'action', 'oppose', 'story', 'murder', 'unnatural'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('action.n.01')
# Senso Target:  Lemma('military_action.n.01.action')
# ------------------------------
# Parola da disambiguare:  population
# Frase in cui compare la parola:  It would authorize the Texas Education Agency to establish county-wide day schools for the deaf in counties of 300000 or more population , require deaf children between 6 and 13 years of age to attend the day schools , permitting older ones to attend the residential Texas School for the Deaf here .
# Contesto della frase:  {'county', 'require', 'child', 'countywide', 'attend', 'texas', 'age', 'residential', 'school', 'establish', 'permit', 'deaf', 'education', 'day', 'authorize', 'year', 'population', 'agency'}
# Max Signature:  {'feed', 'people', 'well', 'clothe', 'inhabit', 'population', 'territory'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('population.n.01')
# Senso Target:  Lemma('population.n.03.population')
# ------------------------------
# Parola da disambiguare:  abstractions
# Frase in cui compare la parola:  Abstractions and semi abstractions by Everett McNear are being exhibited by the University gallery of Notre Dame until Nov. 5 .
# Contesto della frase:  {'abstraction', 'exhibit', 'nov', 'everett', 'university', 'abstractions', 'notre', 'semi', 'dame', 'gallery', 'mcnear'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('abstraction.n.01')
# Senso Target:  Lemma('abstraction.n.04.abstraction')
# ------------------------------
# Parola da disambiguare:  compromise
# Frase in cui compare la parola:  The materials for compromise are at hand : The Nation , Walter Lippmann and other sober commentators ( see Alan Clark on p. 367 ) have spelled them out again and again .
# Contesto della frase:  {'nation', 'hand', 'alan', 'walter', 'material', 'sober', 'commentator', 'spell', 'lippmann', 'compromise', 'clark'}
# Max Signature:  {'congressman', 'side', 'compromise', 'elect', 'business', 'reject', 'consider', 'newly', 'accommodation', 'concession', 'usual'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('compromise.n.02')
# Senso Target:  Lemma('compromise.n.01.compromise')
# ------------------------------
# Parola da disambiguare:  howl
# Frase in cui compare la parola:  Before you let loose a howl saying we announced its coming , not once but several times , indeed we did .
# Contesto della frase:  {'loose', 'time', 'howl'}
# Max Signature:  {'howling', 'emotional', 'utterance', 'laughter', 'loud', 'long', 'pain', 'howl'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('howl.n.01')
# Senso Target:  Lemma('howl.n.01.howl')
# ------------------------------
# Parola da disambiguare:  textures
# Frase in cui compare la parola:  Softness is found in crushed textures .
# Contesto della frase:  {'crushed', 'texture', 'softness', 'find'}
# Max Signature:  {'smooth', 'feel', 'surface', 'wall', 'texture', 'fabric'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('texture.n.01')
# Senso Target:  Lemma('texture.n.01.texture')
# ------------------------------
# Parola da disambiguare:  blast
# Frase in cui compare la parola:  Al Smith 's 340 - blast over left in the fourth - his fourth homer of the campaign - tied the score and Carreon 's first major league home run in the fifth put the Sox back in front .
# Contesto della frase:  {'carreon', 'sox', 'al', 'campaign', 'score', 'league', 'leave', 'front', 'blast', 'fourth', 'major', 'tie', 'homer', 'smith'}
# Max Signature:  {'celebrating', 'exciting', 'time', 'game', 'pleasurable', 'party', 'good', 'blast', 'highly', 'experience'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('good_time.n.01')
# Senso Target:  Lemma('blast.n.01.blast')
# ------------------------------
# Parola da disambiguare:  taxes
# Frase in cui compare la parola:  State representatives decided Thursday against taking a poll on what kind of taxes Texans would prefer to pay .
# Contesto della frase:  {'tax', 'poll', 'prefer', 'pay', 'decide', 'thursday', 'kind', 'representative', 'texans'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('tax.n.01')
# Senso Target:  Lemma('tax.n.01.tax')
# ------------------------------
# Parola da disambiguare:  April
# Frase in cui compare la parola:  The proposal would have to receive final legislative approval , by two-thirds majorities , before March 1 to be printed on the April 4 ballot , Roberts said .
# Contesto della frase:  {'legislative', 'receive', 'twothirds', 'ballot', 'majority', 'print', 'april', 'roberts', 'approval', 'final', 'proposal', 'march'}
# Max Signature:  {'preceding', 'month', 'follow', 'march'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('april.n.01')
# Senso Target:  Lemma('april.n.01.April')
# ------------------------------
# Parola da disambiguare:  mayor
# Frase in cui compare la parola:  The mayor 's present term of office expires Jan. 1 .
# Contesto della frase:  {'jan', 'mayor', 'office', 'term', 'expire'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('mayor.n.01')
# Senso Target:  Lemma('mayor.n.01.mayor')
# ------------------------------
# Termini valutati:  51
# Termini valutati correttamente:  26
# Accuratezza:  0.52

# %% [markdown]
# CONSEGNA 2.2:
#
# Sulla base della consegna precendente, randomizzare la selezione delle 50 frasi e la selezione del termine da disambiguare, e restituire l’accuratezza media su (per esempio) 10 esecuzioni del programma.

# %%
tokenizer = RegexpTokenizer(r'\w+')

EXECUTIONS = 10 #numero massimo di esecuzioni
INDEXES_NUM = 7000 #è il limite, partendo da 0, di sentence che possono essere testate relative al database SemCor
RANGE = 50 #è il numero di sentence che effettivamente verranno testate in ogni esecuzione        

sentences_tag = semcor.tagged_sents()
sentences = semcor.sents()
sentences_sem = semcor.tagged_sents(tag = "sem")

def main():
    accuracy_list = []
    for execution in range(1,EXECUTIONS + 1):
        evaluated = 0 #termini valutati
        checked = 0 #termini valutati correttamente
        index_evaluated = set() #insieme degli indici già valutati
        while(evaluated <= RANGE):
            while True: #fino a quando non trova una word che può essere presa in considerazione  
                index = get_random_index(index_evaluated, INDEXES_NUM)
                word = get_random_word(get_dictionary_tag(sentences_tag[index],sentences_sem[index]))
                if word:
                    break
            sentence = sentences[index]
            print("Parola da disambiguare: ",word)
            #all'algoritmo di lesk viene dato in input la word e l'insieme dei termini che formano la frase, uniti sottoforma di stringa
            best_sense = str(lesk_algorithm(word, ' '.join(word for word in sentence), word_type='ALL'))
            print("Senso attribuito dall'algoritmo di Lesk: ",best_sense)
            target_lemma = get_synset_target_for_word_in_sentence(word,sentences_sem[index])
            print("Senso Target: ",target_lemma)
            best_sense_lemma = best_sense[8:len(best_sense)-2]
            if target_lemma:
                if best_sense_lemma in target_lemma: checked= checked + 1
            evaluated += 1
            print("------------------------------")
        
        print("Termini valutati: ", evaluated)
        print("Termini valutati correttamente: ", checked)
        accuracy = checked/RANGE
        print("Accuratezza: ", accuracy)
        accuracy_list.append(accuracy)
        
    print()
    print("Esecuzioni: ",EXECUTIONS)
    print("Lista delle accuratezze: ", accuracy_list)
    print("Accuratezza media: ",mean(accuracy_list))
    
main()
# Out:
# Parola da disambiguare:  positivist
# Frase in cui compare la parola:  The positivist tells us that when we say this we are only expressing our present emotion .
# Contesto della frase:  {'emotion', 'express', 'positivist'}
# Max Signature:  {'relate', 'doctrine', 'positive', 'positivist', 'thinker', 'positivism', 'philosophy'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('positivist.a.01')
# Senso Target:  Lemma('positivist.n.01.positivist')
# ------------------------------
# Parola da disambiguare:  artists
# Frase in cui compare la parola:  By trying to be both a serious survey of a bygone era and a showcase for today 's artists , the program turned out to be a not quite perfect example of either .
# Contesto della frase:  {'turn', 'era', 'perfect', 'serious', 'survey', 'today', 'showcase', 'example', 'bygone', 'artists', 'program'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('artist.n.01')
# Senso Target:  Lemma('artist.n.01.artist')
# ------------------------------
# Parola da disambiguare:  directed
# Frase in cui compare la parola:  The Newport Playhouse presents `` Epitaph For George Dillon '' by John Osborne and Anthony Creighton , directed by Wallace Gray .
# Contesto della frase:  {'newport', 'george', 'wallace', 'osborne', 'gray', 'dillon', 'anthony', 'epitaph', 'john', 'playhouse', 'creighton', 'direct'}
# Max Signature:  {'child', 'authority', 'command', 'direct', 'homework'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('direct.v.01')
# Senso Target:  Lemma('direct.v.03.direct')
# ------------------------------
# Parola da disambiguare:  serious
# Frase in cui compare la parola:  In fact it has caused us to give serious thought to moving our residence south , because it is not easy for the most objective Southerner to sit calmly by when his host is telling a roomful of people that the only way to deal with Southerners who oppose integration is to send in troops and shoot the bastards down .
# Contesto della frase:  {'host', 'thought', 'troop', 'deal', 'oppose', 'southerners', 'easy', 'fact', 'integration', 'send', 'residence', 'serious', 'people', 'bastard', 'sit', 'move', 'south', 'calmly', 'southerner', 'objective', 'roomful', 'shoot'}
# Max Signature:  {'answer', 'require', 'serious', 'raise', 'objection', 'effort', 'plan', 'flaw', 'concentration', 'easy', 'solve', 'proposal', 'complex'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('serious.s.06')
# Senso Target:  Lemma('serious.a.01.serious')
# ------------------------------
# Parola da disambiguare:  sessions
# Frase in cui compare la parola:  It came up again and again in the discussion sessions .
# Contesto della frase:  {'discussion', 'session'}
# Max Signature:  {'meeting', 'group', 'function', 'legislature', 'execution', 'opening', 'session'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('session.n.01')
# Senso Target:  Lemma('session.n.01.session')
# ------------------------------
# Parola da disambiguare:  three
# Frase in cui compare la parola:  For exactly three unpaired electrons the coefficient would be 3.10 .
# Contesto della frase:  {'coefficient', 'electron', 'unpaired', 'exactly'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('three.n.01')
# Senso Target:  Lemma('three.s.01.three')
# ------------------------------
# Parola da disambiguare:  hitting
# Frase in cui compare la parola:  Until the Bucs ' bats quieted down a bit in Cincinnati over the weekend , the champions had eight men hitting over .300 .
# Contesto della frase:  {'men', 'hit', 'weekend', 'champion', 'bat', 'bucs', 'quiet', 'cincinnati', 'bit'}
# Max Signature:  {'noon', 'machine', 'start', 'barely', 'hit', 'mac', 'weekend', 'real', 'doorstep', 'water', 'reach', 'detroit', 'abstract', 'finish', 'destination'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('reach.v.01')
# Senso Target:  Lemma('score.v.01.hit')
# ------------------------------
# Parola da disambiguare:  obvious
# Frase in cui compare la parola:  It then follows that * * f is large enough , but this is not obvious from the above expression . )
# Contesto della frase:  {'large', 'follow', 'expression', 'obvious'}
# Max Signature:  {'easily', 'mind', 'obvious', 'perceive', 'error', 'sens', 'grasp'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('obvious.a.01')
# Senso Target:  Lemma('obvious.a.01.obvious')
# ------------------------------
# Parola da disambiguare:  broke
# Frase in cui compare la parola:  Hanging over the bar was an oil painting of a nude Al had accepted from a student at the Corcoran Gallery who needed to eat and drink and was broke .
# Contesto della frase:  {'al', 'corcoran', 'painting', 'hanging', 'bar', 'student', 'accept', 'eat', 'drink', 'oil', 'nude', 'broke', 'gallery'}
# Max Signature:  {'morning', 'release', 'broke', 'death', 'news'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('break.v.46')
# Senso Target:  Lemma('broke.s.01.broke')
# ------------------------------
# Parola da disambiguare:  pallid
# Frase in cui compare la parola:  Above , the glowing ivory baton of their searchlight pointed at the clouds , diluting the valley 's dark to a pallid light .
# Contesto della frase:  {'ivory', 'light', 'cloud', 'dark', 'valley', 'pallid', 'dilute', 'searchlight', 'point', 'glow', 'baton'}
# Max Signature:  {'dawn', 'light', 'feeble', 'el', 'fell', 'brightness', 'sun', 'late', 'street', 'star', 'lack', 'track', 'afternoon', 'oblong', 'moon', 'half', 'pale', 'sky', 'intensity', 'pallid', 'wan', 'dim'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('pale.s.02')
# Senso Target:  Lemma('pale.s.02.pallid')
# ------------------------------
# Parola da disambiguare:  general
# Frase in cui compare la parola:  What can we do with the general T ?
# Contesto della frase:  {'general'}
# Max Signature:  {'general', 'officer', 'high', 'rank'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('general.n.01')
# Senso Target:  Lemma('general.a.01.general')
# ------------------------------
# Parola da disambiguare:  springs
# Frase in cui compare la parola:  The area may provide good springs or opportunities for a well or be near to municipal water lines .
# Contesto della frase:  {'spring', 'opportunity', 'area', 'municipal', 'provide', 'water', 'good', 'well'}
# Max Signature:  {'hold', 'spring', 'season', 'office', 'sign', 'year', 'emerge', 'bud', 'growth'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('spring.n.01')
# Senso Target:  Lemma('spring.n.03.spring')
# ------------------------------
# Parola da disambiguare:  simultaneously
# Frase in cui compare la parola:  The dramatic construction of his stories characteristically turns on a situation in which someone is simultaneously compelled and forbidden to love .
# Contesto della frase:  {'construction', 'turn', 'characteristically', 'forbid', 'love', 'story', 'situation', 'simultaneously', 'dramatic', 'compel'}
# Max Signature:  {'speak', 'simultaneously', 'instant'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('simultaneously.r.01')
# Senso Target:  Lemma('simultaneously.r.01.simultaneously')
# ------------------------------
# Parola da disambiguare:  stepwise
# Frase in cui compare la parola:  A study of their activity on thyroglobulin has shown that thyroxine is not preferentially released and that the degradation proceeds stepwise with the formation of macromolecular intermediates ( Alpers , Petermann and Rall , 1956 ) .
# Contesto della frase:  {'preferentially', 'thyroxine', 'alpers', 'release', 'proceeds', 'study', 'macromolecular', 'petermann', 'formation', 'thyroglobulin', 'intermediate', 'rall', 'stepwise', 'activity', 'degradation'}
# Max Signature:  {'voltage', 'increase', 'step', 'stepwise', 'proceed'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('stepwise.r.01')
# Senso Target:  Lemma('bit-by-bit.s.01.stepwise')
# ------------------------------
# Parola da disambiguare:  consult
# Frase in cui compare la parola:  While working out in Sylvania a swelling developed in the knee and he came here to consult the team physician .
# Contesto della frase:  {'work', 'swell', 'team', 'physician', 'develop', 'consult', 'sylvania', 'knee'}
# Max Signature:  {'decision', 'broker', 'arrive', 'local', 'advice', 'consult'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('consult.v.01')
# Senso Target:  Lemma('consult.v.01.consult')
# ------------------------------
# Parola da disambiguare:  fellow
# Frase in cui compare la parola:  Spahn not only is a superior pitcher but a gentlemanly fine fellow , a ball player 's ball player , as they say in the trade .
# Contesto della frase:  {'fine', 'superior', 'gentlemanly', 'spahn', 'fellow', 'player', 'ball', 'trade', 'pitcher'}
# Max Signature:  {'host', 'cuss', 'boy', 'fellow', 'good', 'door', 'bloke', 'man', 'likable', 'chap'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('chap.n.01')
# Senso Target:  Lemma('chap.n.01.fellow')
# ------------------------------
# Parola da disambiguare:  lose
# Frase in cui compare la parola:  `` That 's a lot of hard earned money to lose '' , he says today .
# Contesto della frase:  {'today', 'lot', 'money', 'hard', 'lose', 'earn'}
# Max Signature:  {'turn', 'profit', 'business', 'company', 'fail', 'money', 'investment', 'bad', 'year', 'loss', 'lose', 'dollar'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('lose.v.07')
# Senso Target:  Lemma('lose.v.01.lose')
# ------------------------------
# Parola da disambiguare:  variables
# Frase in cui compare la parola:  No correlation between these variables and the irreproducibility of the results was found .
# Contesto della frase:  {'correlation', 'irreproducibility', 'find', 'result', 'variable'}
# Max Signature:  {'subject', 'weather', 'consider', 'variation', 'vary', 'variable'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('variable.n.01')
# Senso Target:  Lemma('variable.n.02.variable')
# ------------------------------
# Parola da disambiguare:  smoke
# Frase in cui compare la parola:  We were less than a quarter of a mile from the road , and we could trace its shape from the ribbon of powder smoke and dust that hung over it .
# Contesto della frase:  {'road', 'mile', 'shape', 'quarter', 'dust', 'ribbon', 'smoke', 'powder', 'hung', 'trace'}
# Max Signature:  {'fine', 'mile', 'tower', 'combustion', 'vapor', 'hot', 'smoke', 'carbon', 'black', 'fire', 'particle', 'produce'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('smoke.n.02')
# Senso Target:  Lemma('smoke.n.01.smoke')
# ------------------------------
# Parola da disambiguare:  products
# Frase in cui compare la parola:  To be eligible to borrow from a Bank for Cooperatives , a cooperative must be an association in which farmers act together in processing and marketing farm products , purchasing farm supplies , or furnishing farm business services , and must meet the requirements set forth in the Farm Credit Act of 1933 , as amended .
# Contesto della frase:  {'cooperatives', 'borrow', 'eligible', 'farmer', 'furnish', 'amend', 'marketing', 'farm', 'bank', 'cooperative', 'purchase', 'meet', 'product', 'supply', 'service', 'credit', 'set', 'business', 'association', 'requirement', 'processing'}
# Max Signature:  {'business', 'offer', 'commodity', 'depend', 'good', 'merchandise', 'store', 'sale', 'product', 'variety'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('merchandise.n.01')
# Senso Target:  Lemma('product.n.02.product')
# ------------------------------
# Parola da disambiguare:  stage
# Frase in cui compare la parola:  At what stage are social sciences then ?
# Contesto della frase:  {'social', 'stage', 'science'}
# Max Signature:  {'degree', 'stage', 'science', 'position', 'specific', 'continuum', 'process', 'frankness', 'social', 'remarkable', 'series', 'identifiable'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('degree.n.02')
# Senso Target:  Lemma('degree.n.02.stage')
# ------------------------------
# Parola da disambiguare:  mentioned
# Frase in cui compare la parola:  A few obvious target areas of great importance might be mentioned .
# Contesto della frase:  {'area', 'target', 'obvious', 'great', 'mention'}
# Max Signature:  {'mention', 'reference', 'connection'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('mention.v.01')
# Senso Target:  Lemma('note.v.01.mention')
# ------------------------------
# Parola da disambiguare:  existed
# Frase in cui compare la parola:  Although Utopian communism is both new in 1516 and also modern , it is not modern communism or even modern socialism , as they exist or have ever existed in theory or in practice .
# Contesto della frase:  {'communism', 'theory', 'socialism', 'exist', 'utopian', 'practice', 'modern'}
# Max Signature:  {'wage', 'people', 'york', 'month', 'live', 'exist', 'subsist', 'city', 'day', 'low', 'support', 'barely'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('exist.v.02')
# Senso Target:  Lemma('exist.v.01.exist')
# ------------------------------
# Parola da disambiguare:  passed
# Frase in cui compare la parola:  The reason and the day of `` grandfather clauses '' has long since passed .
# Contesto della frase:  {'reason', 'pass', 'grandfather', 'clause', 'day', 'long'}
# Max Signature:  {'car', 'pass', 'terrible', 'mind', 'point', 'thought', 'police', 'park'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('pass.v.01')
# Senso Target:  Lemma('elapse.v.01.pass')
# ------------------------------
# Parola da disambiguare:  temperature
# Frase in cui compare la parola:  A shielded thermocouple was used to measure the upstream temperature of the transpiring gas .
# Contesto della frase:  {'gas', 'shielded', 'upstream', 'measure', 'transpiring', 'temperature', 'thermocouple'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('temperature.n.01')
# Senso Target:  Lemma('temperature.n.01.temperature')
# ------------------------------
# Parola da disambiguare:  casual
# Frase in cui compare la parola:  In the casual field straws feature wedge heels of cork or carved wood in a variety of styles .
# Contesto della frase:  {'variety', 'straws', 'casual', 'heel', 'cork', 'field', 'style', 'wedge', 'feature', 'wood', 'carve'}
# Max Signature:  {'natural', 'unstudied', 'christian', 'freeandeasy', 'style', 'casual', 'lecture'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('free-and-easy.s.01')
# Senso Target:  Lemma('casual.s.03.casual')
# ------------------------------
# Parola da disambiguare:  called
# Frase in cui compare la parola:  It was called Kent House .
# Contesto della frase:  {'kent', 'house', 'call'}
# Max Signature:  {'noun', 'common', 'child', 'bastard', 'ungrateful', 'quality', 'call', 'ascribe', 'lazy', 'reflect'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('call.v.02')
# Senso Target:  called.s.00
# ------------------------------
# Parola da disambiguare:  clue
# Frase in cui compare la parola:  Some clue to the character of London 's approach in these discs may be gained immediately from the fact that ten of the 12 titles include the word `` percussion '' or `` percussive '' .
# Contesto della frase:  {'london', 'gain', 'approach', 'disc', 'include', 'percussion', 'title', 'character', 'clue', 'ten', 'word', 'fact', 'percussive'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('hint.n.02')
# Senso Target:  Lemma('hint.n.02.clue')
# ------------------------------
# Parola da disambiguare:  reserved
# Frase in cui compare la parola:  Those would be reserved for the orchestra 's great nights when the soloist can surpass himself .
# Contesto della frase:  {'night', 'reserve', 'soloist', 'orchestra', 'great', 'surpass'}
# Max Signature:  {'advance', 'maxims', 'reserve', 'table', 'arrange', 'manage'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('reserve.v.03')
# Senso Target:  Lemma('reserve.v.01.reserve')
# ------------------------------
# Parola da disambiguare:  ball
# Frase in cui compare la parola:  Gaines hammered the ball over the left fence for the third Indianapolis run in the ninth .
# Contesto della frase:  {'left', 'fence', 'third', 'hammer', 'ball', 'gaines', 'indianapolis', 'ninth'}
# Max Signature:  {'hit', 'throw', 'mph', 'round', 'mayor', 'pocket', 'corner', 'roll', 'game', 'ball', 'object', 'serve', 'travel', 'kick'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('ball.n.01')
# Senso Target:  Lemma('ball.n.01.ball')
# ------------------------------
# Parola da disambiguare:  opportunity
# Frase in cui compare la parola:  Nothing came of it , perhaps due to lack of opportunity for water storage .
# Contesto della frase:  {'water', 'lack', 'opportunity', 'storage'}
# Max Signature:  {'favorable', 'visit', 'opportunity', 'possibility', 'holiday', 'washington', 'chance', 'circumstance', 'combination'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('opportunity.n.01')
# Senso Target:  Lemma('opportunity.n.01.opportunity')
# ------------------------------
# Parola da disambiguare:  conducted
# Frase in cui compare la parola:  Five of the tests were conducted with a polyethylene cover to simulate an ice cover .
# Contesto della frase:  {'conduct', 'polyethylene', 'test', 'ice', 'simulate', 'cover'}
# Max Signature:  {'conduct', 'business', 'course', 'control', 'manage', 'direct'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('conduct.v.01')
# Senso Target:  Lemma('conduct.v.01.conduct')
# ------------------------------
# Parola da disambiguare:  aspect
# Frase in cui compare la parola:  The second major aspect of the election is the actual procedure of registration , nomination and voting .
# Contesto della frase:  {'actual', 'aspect', 'registration', 'procedure', 'voting', 'second', 'major', 'nomination', 'election'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('aspect.n.01')
# Senso Target:  Lemma('aspect.n.01.aspect')
# ------------------------------
# Parola da disambiguare:  solar
# Frase in cui compare la parola:  The solar electromagnetic - and corpuscular-radiation pressure and the associated Poynting-Robertson effect increase in effectiveness as the particle size decreases and modify the distribution and limit sizes to larger than a few microns .
# Contesto della frase:  {'large', 'associated', 'distribution', 'decrease', 'effectiveness', 'size', 'poyntingrobertson', 'pressure', 'electromagnetic', 'corpuscularradiation', 'micron', 'increase', 'solar', 'modify', 'limit', 'particle'}
# Max Signature:  {'utilize', 'sun', 'relate', 'eclipse', 'derive', 'solar', 'energy'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('solar.a.01')
# Senso Target:  Lemma('solar.a.01.solar')
# ------------------------------
# Parola da disambiguare:  ecclesiastical
# Frase in cui compare la parola:  Moreover , for those few there was almost no ecclesiastical representation in the city to care for their religious needs .
# Contesto della frase:  {'care', 'representation', 'city', 'religious', 'ecclesiastical'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('ecclesiastical.a.01')
# Senso Target:  Lemma('ecclesiastical.a.01.ecclesiastical')
# ------------------------------
# Parola da disambiguare:  single
# Frase in cui compare la parola:  Last year , when he worked out at halfback all season , he did n't get into a single game .
# Contesto della frase:  {'nt', 'season', 'game', 'work', 'year', 'halfback', 'single'}
# Max Signature:  {'left', 'hit', 'field', 'batter', 'single'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('single.v.01')
# Senso Target:  Lemma('individual.a.01.single')
# ------------------------------
# Parola da disambiguare:  pictures
# Frase in cui compare la parola:  One of the script 's big problems was how to blend pictures and music of the past with live performances by musicians of today .
# Contesto della frase:  {'script', 'music', 'blend', 'musician', 'today', 'live', 'big', 'picture', 'performance', 'problem'}
# Max Signature:  {'series', 'abstraction', 'wedding', 'integrate', 'visual', 'representation', 'scene', 'surface', 'movie', 'rapidly', 'project', 'object', 'picture', 'person', 'image', 'eye', 'produce'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('picture.n.01')
# Senso Target:  Lemma('picture.n.05.picture')
# ------------------------------
# Parola da disambiguare:  fall
# Frase in cui compare la parola:  A meteor could fall on San Francisco .
# Contesto della frase:  {'fall', 'san', 'francisco', 'meteor'}
# Max Signature:  {'fall', 'leaf', 'season', 'tree'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('fall.n.01')
# Senso Target:  Lemma('fall.v.01.fall')
# ------------------------------
# Parola da disambiguare:  embossed
# Frase in cui compare la parola:  Both , of course , were remarkable feats and further embossed the fact that baseball rightfully is the national pastime .
# Contesto della frase:  {'pastime', 'national', 'baseball', 'course', 'feat', 'remarkable', 'fact', 'rightfully', 'emboss'}
# Max Signature:  {'relief', 'emboss', 'raise', 'stationery'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('emboss.v.01')
# Senso Target:  Lemma('emboss.v.01.emboss')
# ------------------------------
# Parola da disambiguare:  repaid
# Frase in cui compare la parola:  Funds contributed by the Government are repaid by a royalty on production from the property .
# Contesto della frase:  {'production', 'contribute', 'royalty', 'government', 'property', 'repay', 'funds'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('refund.v.01')
# Senso Target:  Lemma('refund.v.01.repay')
# ------------------------------
# Parola da disambiguare:  suffering
# Frase in cui compare la parola:  a suffering form , an existence wholly comprised in the awareness of death .
# Contesto della frase:  {'awareness', 'form', 'existence', 'suffering', 'comprise', 'wholly', 'death'}
# Max Signature:  {'wife', 'suffering', 'psychological', 'great', 'distress', 'death'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('distress.n.01')
# Senso Target:  Lemma('miserable.s.01.suffering')
# ------------------------------
# Parola da disambiguare:  nation
# Frase in cui compare la parola:  America is rapidly becoming a nation that uses processed , precooked and even predigested foods .
# Contesto della frase:  {'food', 'nation', 'precooked', 'america', 'rapidly', 'predigest', 'process'}
# Max Signature:  {'body', 'large', 'organize', 'nation', 'people', 'government', 'president', 'elect', 'student', 'land', 'country', 'politically', 'capitol', 'manufacturer', 'african', 'industrialized', 'single'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('state.n.04')
# Senso Target:  Lemma('nation.n.02.nation')
# ------------------------------
# Parola da disambiguare:  unfitting
# Frase in cui compare la parola:  In such a case , any attitude would be as fitting or unfitting as any other , which means that the notion of fitness has lost all point .
# Contesto della frase:  {'case', 'unfitting', 'point', 'lose', 'notion', 'fitness', 'fitting', 'attitude'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('disqualify.v.01')
# Senso Target:  Lemma('inappropriate.s.02.unfitting')
# ------------------------------
# Parola da disambiguare:  atmosphere
# Frase in cui compare la parola:  In business circles , usually conservative , this sort of atmosphere would hardly be found .
# Contesto della frase:  {'business', 'sort', 'circle', 'find', 'atmosphere', 'conservative'}
# Max Signature:  {'environment', 'surround', 'influence', 'excitement', 'atmosphere'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('atmosphere.n.01')
# Senso Target:  Lemma('atmosphere.n.01.atmosphere')
# ------------------------------
# Parola da disambiguare:  compromise
# Frase in cui compare la parola:  `` There can be no compromise when souls are in jeopardy '' .
# Contesto della frase:  {'jeopardy', 'soul', 'compromise'}
# Max Signature:  {'congressman', 'side', 'compromise', 'elect', 'business', 'reject', 'consider', 'newly', 'accommodation', 'concession', 'usual'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('compromise.n.02')
# Senso Target:  Lemma('compromise.n.02.compromise')
# ------------------------------
# Parola da disambiguare:  dance
# Frase in cui compare la parola:  Our athletes are only just beginning to learn that they must study dance .
# Contesto della frase:  {'dance', 'athlete', 'study', 'learn'}
# Max Signature:  {'dance', 'party', 'assemble', 'people'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('dance.n.02')
# Senso Target:  Lemma('dance.n.01.dance')
# ------------------------------
# Parola da disambiguare:  texture
# Frase in cui compare la parola:  At the left is a pair of dressy straw pumps in a light , but crisp texture .
# Contesto della frase:  {'left', 'pump', 'light', 'pair', 'texture', 'straw', 'dressy', 'crisp'}
# Max Signature:  {'smooth', 'feel', 'surface', 'wall', 'texture', 'fabric'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('texture.n.01')
# Senso Target:  Lemma('texture.n.01.texture')
# ------------------------------
# Parola da disambiguare:  Utopians
# Frase in cui compare la parola:  Utopian communism applies to all Utopians .
# Contesto della frase:  {'utopians', 'utopian', 'applies', 'communism'}
# Max Signature:  {'impractical', 'perfectibility', 'reformer', 'idealistic', 'ultimate', 'utopian', 'social', 'man'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('utopian.n.01')
# Senso Target:  Lemma('utopian.n.01.Utopian')
# ------------------------------
# Parola da disambiguare:  Shape
# Frase in cui compare la parola:  Shape of the area is also related to the use attractions and needs of the development .
# Contesto della frase:  {'shape', 'area', 'development', 'relate', 'attraction'}
# Max Signature:  {'shape', 'attribute', 'outline', 'spatial', 'define', 'barely'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('shape.n.01')
# Senso Target:  Lemma('shape.n.01.shape')
# ------------------------------
# Parola da disambiguare:  moved
# Frase in cui compare la parola:  His arm moved swiftly , violently , once , twice .
# Contesto della frase:  {'violently', 'move', 'swiftly', 'arm'}
# Max Signature:  {'fast', 'night', 'attempt', 'rome', 'suspect', 'fell', 'travel', 'news', 'change', 'naples', 'door', 'city', 'location', 'soldier', 'move', 'proceed', 'car', 'bus', 'policeman', 'metaphorically'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('travel.v.01')
# Senso Target:  Lemma('move.v.02.move')
# ------------------------------
# Parola da disambiguare:  cited
# Frase in cui compare la parola:  Mankowski , the ball-hawking defensive expert , was cited for his performance against Bradley in St. Louis U. 's nationally televised victory .
# Contesto della frase:  {'expert', 'cite', 'st', 'nationally', 'mankowski', 'televise', 'bradley', 'louis', 'defensive', 'victory', 'performance', 'ballhawking'}
# Max Signature:  {'cite', 'achievement', 'outstanding', 'commend'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('mention.v.03')
# Senso Target:  Lemma('mention.v.03.cite')
# ------------------------------
# Termini valutati:  51
# Termini valutati correttamente:  24
# Accuratezza:  0.48
# Parola da disambiguare:  early
# Frase in cui compare la parola:  Color was delayed until 1935 , the wide screen until the early fifties .
# Contesto della frase:  {'wide', 'fifty', 'early', 'color', 'screen', 'delay'}
# Max Signature:  {'retirement', 'tomato', 'morning', 'spring', 'period', 'mature', 'warning', 'event', 'course', 'standard', 'pea', 'diagnosis', 'early', 'usual', 'time', 'death', 'variety', 'expect'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('early.a.01')
# Senso Target:  Lemma('early.a.01.early')
# ------------------------------
# Parola da disambiguare:  vector
# Frase in cui compare la parola:  If we are discussing differentiable complex valued functions , then * * f and V are complex vector spaces , and * * f may be any complex numbers .
# Contesto della frase:  {'discuss', 'function', 'differentiable', 'number', 'space', 'vector', 'complex'}
# Max Signature:  {'straight', 'magnitude', 'segment', 'direction', 'orientation', 'length', 'space'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('vector.n.02')
# Senso Target:  Lemma('vector.n.01.vector')
# ------------------------------
# Parola da disambiguare:  fine
# Frase in cui compare la parola:  Her debut over , perhaps the earlier scenes will emerge equally fine .
# Contesto della frase:  {'fine', 'equally', 'scene', 'debut', 'early', 'emerge'}
# Max Signature:  {'fine', 'car', 'fin', 'issue', 'street', 'side', 'penalty', 'wrong', 'ticket', 'move', 'park'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('ticket.v.01')
# Senso Target:  fine.s.00
# ------------------------------
# Parola da disambiguare:  precisely
# Frase in cui compare la parola:  Though the spread of this type of decoration in the Aegean has not yet been precisely determined , it seems to appear first in the Cyclades , which were among the leading exporters of pottery throughout the century .
# Contesto della frase:  {'type', 'century', 'spread', 'appear', 'decoration', 'exporter', 'precisely', 'lead', 'pottery', 'determine', 'aegean', 'cyclades'}
# Max Signature:  {'preciseness', 'saidthe', 'jewel', 'exactly', 'precisely', 'salt', 'exactness', 'indicate'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('precisely.r.01')
# Senso Target:  Lemma('precisely.r.01.precisely')
# ------------------------------
# Parola da disambiguare:  winner
# Frase in cui compare la parola:  Palmer , golf 's leading money winner in 1960 , and Snead will be saluted as the winning team in the Canada Cup matches last June in Dublin .
# Contesto della frase:  {'golf', 'june', 'canada', 'match', 'snead', 'palmer', 'money', 'win', 'lead', 'cup', 'dublin', 'winner', 'salute', 'team'}
# Max Signature:  {'contestant', 'win', 'contest'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('winner.n.01')
# Senso Target:  Lemma('winner.n.01.winner')
# ------------------------------
# Parola da disambiguare:  ahead
# Frase in cui compare la parola:  First the Larkins are ahead , then the Jerebohms .
# Contesto della frase:  {'ahead', 'jerebohms', 'larkins'}
# Max Signature:  {'contest', 'race', 'score', 'position', 'lead', 'pawn', 'ahead', 'pennant', 'high', 'team'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('ahead.s.01')
# Senso Target:  Lemma('ahead.r.01.ahead')
# ------------------------------
# Parola da disambiguare:  making
# Frase in cui compare la parola:  In the second place , a large number of writers , making a more direct claim than Frost to being `` folk writers '' of one sort or another , clearly make no distinctions between genuine and bogus material .
# Contesto della frase:  {'large', 'distinction', 'folk', 'writer', 'material', 'sort', 'genuine', 'second', 'number', 'clearly', 'bogus', 'frost', 'claim', 'place', 'direct'}
# Max Signature:  {'pig', 'house', 'warmer', 'combine', 'material', 'construct', 'brassiere', 'straw', 'eccentric', 'electric'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('construct.v.01')
# Senso Target:  Lemma('make.v.01.make')
# ------------------------------
# Parola da disambiguare:  membrane
# Frase in cui compare la parola:  Removal of the suspended solids by a membrane filter yielded an average effluent containing only 20 mg / l BOD .
# Contesto della frase:  {'membrane', 'removal', 'suspended', 'bod', 'filter', 'average', 'yield', 'effluent', 'solid'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('membrane.n.01')
# Senso Target:  Lemma('membrane.n.01.membrane')
# ------------------------------
# Parola da disambiguare:  fail
# Frase in cui compare la parola:  They often fail , however , to develop real abdominal , back , chest , shoulder and arm strength .
# Contesto della frase:  {'strength', 'abdominal', 'shoulder', 'real', 'chest', 'fail', 'arm', 'develop'}
# Max Signature:  {'strength', 'smell', 'finally', 'undependable', 'sense', 'child', 'disappoint', 'fail', 'forsake', 'abandon', 'time', 'crisis', 'prove'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('fail.v.03')
# Senso Target:  Lemma('fail.v.01.fail')
# ------------------------------
# Parola da disambiguare:  require
# Frase in cui compare la parola:  Grover also would require junior senior high teachers to have at least 24 semester hours credit in the subject they are teaching .
# Contesto della frase:  {'teacher', 'require', 'senior', 'subject', 'junior', 'hour', 'grover', 'semester', 'credit', 'teach', 'high'}
# Max Signature:  {'require', 'patience', 'sacrifice', 'position', 'spectacular', 'job', 'call', 'hard', 'intervention', 'consent', 'dessert', 'lot', 'personal', 'work', 'dinner', 'postulate', 'proper', 'demand', 'nerve', 'success', 'patient', 'skill'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('necessitate.v.01')
# Senso Target:  Lemma('command.v.02.require')
# ------------------------------
# Parola da disambiguare:  monologist
# Frase in cui compare la parola:  Berman , whose fame has rested in recent years on his skills as a night club monologist , proved himself very much at home in musical comedy .
# Contesto della frase:  {'night', 'comedy', 'musical', 'rest', 'fame', 'year', 'club', 'berman', 'monologist', 'skill', 'prove'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('monologist.n.01')
# Senso Target:  Lemma('monologist.n.01.monologist')
# ------------------------------
# Parola da disambiguare:  achieve
# Frase in cui compare la parola:  To achieve this goal of balanced development , communications between the central government and the local communities must be such that the needs and aspirations of the people themselves are effectively taken into account .
# Contesto della frase:  {'goal', 'central', 'people', 'government', 'effectively', 'account', 'development', 'aspiration', 'balanced', 'communication', 'local', 'achieve', 'community'}
# Max Signature:  {'goal', 'gain', 'effort', 'achieve', 'setback'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('achieve.v.01')
# Senso Target:  Lemma('achieve.v.01.achieve')
# ------------------------------
# Parola da disambiguare:  child
# Frase in cui compare la parola:  Moreover , her husband and child contracted T.B. from her .
# Contesto della frase:  {'husband', 'tb', 'contract', 'child'}
# Max Signature:  {'young', 'child', 'book', 'write', 'tiddler', 'sex', 'term', 'youngster', 'british', 'person', 'kid'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('child.n.01')
# Senso Target:  Lemma('child.n.02.child')
# ------------------------------
# Parola da disambiguare:  veteran
# Frase in cui compare la parola:  Another veteran telephone operator was Edith Fleming Blackmer , who had been in the office forty years at the time of her death in 1960 .
# Contesto della frase:  {'blackmer', 'time', 'office', 'operator', 'edith', 'forty', 'year', 'telephone', 'veteran', 'death', 'fleming'}
# Max Signature:  {'active', 'service', 'recruit', 'considerable', 'serviceman', 'veteran', 'laugh'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('veteran.n.01')
# Senso Target:  Lemma('seasoned.s.02.veteran')
# ------------------------------
# Parola da disambiguare:  reputable
# Frase in cui compare la parola:  Go to a reputable grower , preferably a pansy specialist .
# Contesto della frase:  {'pansy', 'reputable', 'grower', 'preferably', 'specialist'}
# Max Signature:  {'reputation', 'scientist', 'reputable', 'business', 'wine', 'good'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('reputable.a.01')
# Senso Target:  Lemma('reputable.a.01.reputable')
# ------------------------------
# Parola da disambiguare:  10
# Frase in cui compare la parola:  Moritz , however , kicks only about 10 or 12 extra points during each practice session .
# Contesto della frase:  {'moritz', 'session', 'point', 'extra', 'practice', 'kick'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('ten.n.01')
# Senso Target:  Lemma('ten.s.01.10')
# ------------------------------
# Parola da disambiguare:  trace
# Frase in cui compare la parola:  Calcium , phosphorus and iron are present in worthwhile amounts , and eleven other minerals also have been found in varying trace amounts .
# Contesto della frase:  {'mineral', 'phosphorus', 'iron', 'worthwhile', 'find', 'vary', 'eleven', 'calcium', 'amount', 'trace'}
# Max Signature:  {'french', 'speak', 'detectable', 'accent', 'amount', 'trace'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('trace.n.01')
# Senso Target:  Lemma('trace.n.01.trace')
# ------------------------------
# Parola da disambiguare:  settled
# Frase in cui compare la parola:  The increase in oxygen uptake rates from 1.2 to 2.6 mg / l / hr which followed an increase in rotor speed was believed to be related to resuspension of solids which had settled at the lower rotor speeds .
# Contesto della frase:  {'rotor', 'oxygen', 'low', 'uptake', 'relate', 'settle', 'resuspension', 'increase', 'hr', 'speed', 'follow', 'solid', 'rate'}
# Max Signature:  {'price', 'lack', 'complete', 'settle', 'satisfaction', 'low'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('settle.v.12')
# Senso Target:  Lemma('sink.v.04.settle')
# ------------------------------
# Parola da disambiguare:  visit
# Frase in cui compare la parola:  She wants to pay you a visit .
# Contesto della frase:  {'visit', 'pay'}
# Max Signature:  {'visit', 'mayor', 'pay', 'prominent', 'call', 'citizen'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('visit.v.03')
# Senso Target:  Lemma('visit.n.02.visit')
# ------------------------------
# Parola da disambiguare:  Monday
# Frase in cui compare la parola:  Boston Red Sox Outfielder Jackie Jensen said Monday night he was through playing baseball .
# Contesto della frase:  {'sox', 'jackie', 'night', 'play', 'monday', 'boston', 'red', 'baseball', 'jensen', 'outfielder'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('monday.n.01')
# Senso Target:  Lemma('monday.n.01.Monday')
# ------------------------------
# Parola da disambiguare:  nature
# Frase in cui compare la parola:  The many and frequent performances of the Trout serve to emphasize the dual nature of its writing .
# Contesto della frase:  {'dual', 'frequent', 'trout', 'writing', 'nature', 'serve', 'performance', 'emphasize'}
# Max Signature:  {'characteristic', 'true', 'quality', 'burn', 'jealousy', 'recognize', 'nature', 'essential', 'fire'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('nature.n.01')
# Senso Target:  Lemma('nature.n.04.nature')
# ------------------------------
# Parola da disambiguare:  refused
# Frase in cui compare la parola:  `` I refused '' , Duclos said .
# Contesto della frase:  {'refuse', 'duclos'}
# Max Signature:  {'accept', 'refuse', 'hospitality', 'offer'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('refuse.v.02')
# Senso Target:  Lemma('refuse.v.02.refuse')
# ------------------------------
# Parola da disambiguare:  idea
# Frase in cui compare la parola:  The idea of community and the idea of spirit are two distinct and separable ideas .
# Contesto della frase:  {'distinct', 'separable', 'spirit', 'community', 'idea'}
# Max Signature:  {'enter', 'thing', 'mind', 'good', 'thought', 'main', 'cognition', 'content', 'idea'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('idea.n.01')
# Senso Target:  Lemma('idea.n.01.idea')
# ------------------------------
# Parola da disambiguare:  septic
# Frase in cui compare la parola:  Shortly after this study ended septic conditions resulted which required the addition of sodium nitrate .
# Contesto della frase:  {'shortly', 'require', 'septic', 'study', 'nitrate', 'addition', 'condition', 'sodium', 'result'}
# Max Signature:  {'environment', 'septic', 'sewage', 'throat', 'organism', 'result', 'diseasecausing', 'sore'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('septic.a.01')
# Senso Target:  Lemma('septic.a.01.septic')
# ------------------------------
# Parola da disambiguare:  knowledge
# Frase in cui compare la parola:  To find a place for them in their theory of knowledge would require them to revise the theory radically , and yet that theory was what they regarded as their most important discovery .
# Contesto della frase:  {'require', 'revise', 'discovery', 'theory', 'knowledge', 'find', 'radically', 'regard', 'place'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('cognition.n.01')
# Senso Target:  Lemma('cognition.n.01.knowledge')
# ------------------------------
# Parola da disambiguare:  bend
# Frase in cui compare la parola:  Scotty murmured , `` No , thanks '' , so softly his father had to bend his gaunt height across the table and turn a round brown ear to him .
# Contesto della frase:  {'turn', 'brown', 'height', 'murmur', 'ear', 'round', 'softly', 'bend', 'table', 'gaunt', 'scotty', 'father'}
# Max Signature:  {'colon', 'shape', 'elbow', 'blouse', 'angular', 'round', 'flexure', 'bend', 'crease', 'napkin', 'trouser', 'plication', 'fold'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('fold.n.01')
# Senso Target:  Lemma('bend.v.02.bend')
# ------------------------------
# Parola da disambiguare:  feeling
# Frase in cui compare la parola:  The degree of circumstance , the ratio of memory to forgetfulness , determines whether a dream will be a recognized , fulfilled prevision , or the vaguely , effective source of the weird deja vu feeling .
# Contesto della frase:  {'memory', 'dream', 'ratio', 'vaguely', 'weird', 'feeling', 'prevision', 'vu', 'forgetfulness', 'recognize', 'fulfilled', 'degree', 'source', 'determines', 'circumstance', 'effective', 'deja'}
# Max Signature:  {'emotional', 'terrible', 'experiencing', 'feeling', 'mutual', 'guilt', 'euphoria', 'dislike', 'affective'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('feeling.n.01')
# Senso Target:  Lemma('impression.n.01.feeling')
# ------------------------------
# Parola da disambiguare:  religion
# Frase in cui compare la parola:  The unifying effect of religion is also brought out in the fact that historically peoples have clung together as more or less cohesive cultural units , with religion as the dominant bond , even though spatially dispersed and not politically organized .
# Contesto della frase:  {'cling', 'bring', 'cohesive', 'religion', 'organize', 'people', 'unit', 'historically', 'spatially', 'cultural', 'politically', 'fact', 'unifying', 'bond', 'disperse', 'dominant'}
# Max Signature:  {'express', 'religion', 'contradict', 'raise', 'baptist', 'member', 'power', 'belief', 'institution', 'divine', 'faith'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('religion.n.02')
# Senso Target:  Lemma('religion.n.01.religion')
# ------------------------------
# Parola da disambiguare:  basic
# Frase in cui compare la parola:  There are also more basic problems .
# Contesto della frase:  {'basic', 'problem'}
# Max Signature:  {'pertain', 'basis', 'change', 'base', 'public', 'occur', 'ingredient', 'priority', 'opinion', 'fact', 'basic', 'constitute'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('basic.a.01')
# Senso Target:  Lemma('basic.a.01.basic')
# ------------------------------
# Parola da disambiguare:  refused
# Frase in cui compare la parola:  Again he refused .
# Contesto della frase:  {'refuse'}
# Max Signature:  {'accept', 'refuse', 'hospitality', 'offer'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('refuse.v.02')
# Senso Target:  Lemma('refuse.v.01.refuse')
# ------------------------------
# Parola da disambiguare:  suburban
# Frase in cui compare la parola:  They are all suburban plants , relying on the roads to keep them supplied with workers .
# Contesto della frase:  {'road', 'supply', 'suburban', 'worker', 'plant', 'rely'}
# Max Signature:  {'suburban', 'characteristic', 'suburb', 'relate', 'population', 'situate'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('suburban.a.01')
# Senso Target:  Lemma('suburban.a.01.suburban')
# ------------------------------
# Parola da disambiguare:  needed
# Frase in cui compare la parola:  Muscle weakness did not improve , and the patient needed first a cane , then crutches .
# Contesto della frase:  {'improve', 'cane', 'crutch', 'muscle', 'weakness', 'patient'}
# Max Signature:  {'require', 'patience', 'sacrifice', 'position', 'spectacular', 'job', 'call', 'hard', 'intervention', 'consent', 'dessert', 'lot', 'personal', 'work', 'dinner', 'postulate', 'proper', 'demand', 'nerve', 'success', 'patient', 'skill'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('necessitate.v.01')
# Senso Target:  Lemma('want.v.02.need')
# ------------------------------
# Parola da disambiguare:  Houston
# Frase in cui compare la parola:  SMU will play the Owls at Rice Stadium in Houston in a night game Saturday , Oct. 21 .
# Contesto della frase:  {'saturday', 'night', 'play', 'houston', 'smu', 'game', 'oct', 'rice', 'stadium', 'owls'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('houston.n.01')
# Senso Target:  Lemma('houston.n.01.Houston')
# ------------------------------
# Parola da disambiguare:  exactly
# Frase in cui compare la parola:  Today , according to land economist Homer Hoyt , shopping centers and their associated parking lots cover some 46000 acres of land , which is almost exactly the total land area in all the nation 's Central Business Districts put together .
# Contesto della frase:  {'central', 'nation', 'area', 'today', 'districts', 'accord', 'cover', 'economist', 'hoyt', 'center', 'acre', 'lot', 'exactly', 'total', 'park', 'business', 'associate', 'land', 'shopping', 'homer'}
# Max Signature:  {'preciseness', 'saidthe', 'jewel', 'exactly', 'precisely', 'salt', 'exactness', 'indicate'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('precisely.r.01')
# Senso Target:  Lemma('precisely.r.01.exactly')
# ------------------------------
# Parola da disambiguare:  exhibit
# Frase in cui compare la parola:  A good formulation will keep the clothes clean and white after many washings ; whereas , with a poor formulation , the clothes exhibit a build-up of `` tattle-tale grey '' and dirty spots - sometimes with bad results even after the first wash .
# Contesto della frase:  {'tattletale', 'grey', 'dirty', 'exhibit', 'poor', 'spot', 'washing', 'buildup', 'clean', 'clothes', 'good', 'bad', 'wash', 'result', 'formulation', 'white'}
# Max Signature:  {'exhibit', 'public', 'oriental', 'art', 'museum'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('display.n.02')
# Senso Target:  Lemma('exhibit.v.01.exhibit')
# ------------------------------
# Parola da disambiguare:  ambitious
# Frase in cui compare la parola:  Poverty imposes a kind of chastity on the ambitious .
# Contesto della frase:  {'chastity', 'ambitious', 'poverty', 'impose', 'kind'}
# Max Signature:  {'require', 'ability', 'resource', 'ambitious', 'schedule', 'challenging', 'task', 'mistake', 'perform', 'full'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('ambitious.s.02')
# Senso Target:  Lemma('ambitious.a.01.ambitious')
# ------------------------------
# Parola da disambiguare:  second
# Frase in cui compare la parola:  The African rock python , a close second , is followed in turn by the reticulate python .
# Contesto della frase:  {'turn', 'rock', 'python', 'second', 'reticulate', 'african', 'follow', 'close'}
# Max Signature:  {'ordering', 'second', 'series', 'follow', 'close'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('second.n.05')
# Senso Target:  Lemma('second.s.01.second')
# ------------------------------
# Parola da disambiguare:  central
# Frase in cui compare la parola:  At the central level the scrutin uninominal voting system was selected over some form of the scrutin de liste system , even though the latter had been recommended by Duverger and favored by all political parties .
# Contesto della frase:  {'central', 'system', 'form', 'favor', 'select', 'voting', 'scrutin', 'level', 'liste', 'recommend', 'political', 'duverger', 'party', 'uninominal'}
# Max Signature:  {'central', 'fundamental', 'argument', 'structure', 'cardinal', 'computer', 'example', 'rule', 'serve', 'essential', 'industrial', 'problem', 'component', 'modern'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('cardinal.s.01')
# Senso Target:  Lemma('cardinal.s.01.central')
# ------------------------------
# Parola da disambiguare:  Winchester
# Frase in cui compare la parola:  When it became obvious that he could stay inside no longer , taking a thousand to one chance Gonzales rushed outside , square against the muzzle of a Winchester .
# Contesto della frase:  {'muzzle', 'longer', 'winchester', 'gonzales', 'obvious', 'stay', 'square', 'chance', 'rush'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('winchester.n.01')
# Senso Target:  NE
# ------------------------------
# Parola da disambiguare:  compare
# Frase in cui compare la parola:  And it is certainly no slight to either of them to compare both their achievements and their impact .
# Contesto della frase:  {'compare', 'impact', 'achievement', 'slight'}
# ...
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('anode.n.01')
# Senso Target:  Lemma('anode.n.01.anode')
# ------------------------------
# Parola da disambiguare:  existence
# Frase in cui compare la parola:  By 1883 the `` Battenkill Telegraph Company '' was in existence and Alvin Pettibone was its president .
# Contesto della frase:  {'alvin', 'telegraph', 'existence', 'president', 'company', 'battenkill', 'pettibone'}
# Max Signature:  {'existence', 'view', 'century', 'exist', 'point', 'fact', 'law', 'gradually'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('being.n.01')
# Senso Target:  Lemma('being.n.01.existence')
# ------------------------------
# Parola da disambiguare:  thigh
# Frase in cui compare la parola:  By Nov. 8 , 1958 , weakness , specifically involving the pelvic and thigh musculature , was pronounced , and a common complaint was `` difficulty in stepping up on to curbs '' .
# Contesto della frase:  {'common', 'thigh', 'pelvic', 'pronounce', 'difficulty', 'complaint', 'step', 'nov', 'musculature', 'weakness', 'curb', 'involve'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('thigh.n.01')
# Senso Target:  Lemma('thigh.n.01.thigh')
# ------------------------------
# Parola da disambiguare:  visiting
# Frase in cui compare la parola:  Consider couples visiting an art museum .
# Contesto della frase:  {'visit', 'couple', 'consider', 'art', 'museum'}
# Max Signature:  {'visit', 'service', 'promote', 'purpose', 'club', 'activity'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('visiting.n.01')
# Senso Target:  Lemma('visit.v.01.visit')
# ------------------------------
# Parola da disambiguare:  blanket
# Frase in cui compare la parola:  Of course , if there is a dust blanket around the Earth , the fluxes in interplanetary space should be less than the figures given here .
# Contesto della frase:  {'blanket', 'figure', 'earth', 'dust', 'course', 'interplanetary', 'space', 'flux'}
# Max Signature:  {'blanket', 'cover', 'snow'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('blanket.n.02')
# Senso Target:  Lemma('blanket.n.02.blanket')
# ------------------------------
# Parola da disambiguare:  men
# Frase in cui compare la parola:  Two men pulled him off .
# Contesto della frase:  {'men', 'pull'}
# Max Signature:  {'bus', 'men', 'oppose', 'adult', 'woman', 'male', 'person'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('man.n.01')
# Senso Target:  Lemma('man.n.01.man')
# ------------------------------
# Parola da disambiguare:  nigger
# Frase in cui compare la parola:  Then the nigger boy turned back and he was alone .
# Contesto della frase:  {'nigger', 'turn', 'boy'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('nigger.n.01')
# Senso Target:  Lemma('nigger.n.01.nigger')
# ------------------------------
# Parola da disambiguare:  stated
# Frase in cui compare la parola:  Any alteration of one of these factors is distortion , although we generally use that word only for effects so pronounced that they can be stated quantitatively on the basis of standard tests .
# Contesto della frase:  {'basis', 'test', 'pronounce', 'generally', 'standard', 'factor', 'word', 'alteration', 'quantitatively', 'distortion'}
# Max Signature:  {'bother', 'express', 'opinion', 'marry', 'word'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('state.v.01')
# Senso Target:  Lemma('submit.v.02.state')
# ------------------------------
# Parola da disambiguare:  experienced
# Frase in cui compare la parola:  Here , too , the reality of actual furniture must be experienced .
# Contesto della frase:  {'reality', 'furniture', 'actual', 'experience'}
# Max Signature:  {'nauseous', 'injury', 'receive', 'vertigo', 'mental', 'feeling', 'physical', 'experience', 'idea'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('experience.v.03')
# Senso Target:  Lemma('know.v.05.experience')
# ------------------------------
# Parola da disambiguare:  clinical
# Frase in cui compare la parola:  Physiological experiments and clinical observations have shown that these procedures influence the hypothalamically controlled hypophyseal secretions and increase sympathetic discharges .
# Contesto della frase:  {'hypothalamically', 'physiological', 'procedure', 'clinical', 'influence', 'experiment', 'hypophyseal', 'discharge', 'sympathetic', 'observation', 'increase', 'secretion', 'control'}
# Max Signature:  {'conduct', 'case', 'clinical', 'study', 'relate', 'depend', 'observation', 'clinic', 'patient', 'direct'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('clinical.a.01')
# Senso Target:  Lemma('clinical.a.01.clinical')
# ------------------------------
# Parola da disambiguare:  corresponds
# Frase in cui compare la parola:  Such a density corresponds to a paramagnetic ion density of about **f .
# Contesto della frase:  {'paramagnetic', 'correspond', 'ion', 'density'}
# Max Signature:  {'message', 'pen', 'correspond', 'exchange', 'year', 'russian', 'pal'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('correspond.v.03')
# Senso Target:  Lemma('equate.v.02.correspond')
# ------------------------------
# Parola da disambiguare:  slowly
# Frase in cui compare la parola:  Let the body down slowly , taking at least five seconds for the letting down .
# Contesto della frase:  {'body', 'second', 'slowly'}
# Max Signature:  {'road', 'speak', 'informally', 'slow', 'glacier', 'tardily', 'sight', 'move', 'herethe', 'easy', 'slippery', 'speed', 'slowly'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('slowly.r.01')
# Senso Target:  Lemma('slowly.r.01.slowly')
# ------------------------------
# Parola da disambiguare:  situation
# Frase in cui compare la parola:  But this situation of Kent House was more subtle .
# Contesto della frase:  {'kent', 'subtle', 'situation', 'house'}
# Max Signature:  {'fresh', 'wonder', 'true', 'eternal', 'thing', 'general', 'time', 'affair', 'truth', 'franklin', 'situation', 'international', 'social', 'dangerous', 'droosevelt', 'circumstance', 'meaning', 'combination'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('situation.n.01')
# Senso Target:  Lemma('situation.n.01.situation')
# ------------------------------
# Parola da disambiguare:  solid
# Frase in cui compare la parola:  A very fine , gray solid ( about 15 g ) is formed , water-washed by centrifugation , and dried at 110 ` C .
# Contesto della frase:  {'fine', 'dry', 'waterwashed', 'form', 'gray', 'centrifugation', 'solid'}
# Max Signature:  {'room', 'matter', 'temperature', 'pressure', 'solid'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('solid.n.01')
# Senso Target:  Lemma('solid.n.01.solid')
# ------------------------------
# Parola da disambiguare:  discussed
# Frase in cui compare la parola:  The chemical nature of the iodocompounds is discussed below ( pp. 76 et seq. ) .
# Contesto della frase:  {'seq', 'discuss', 'iodocompound', 'nature', 'chemical'}
# Max Signature:  {'speech', 'examine', 'aspect', 'discuss', 'class', 'author', 'inferno', 'dantes', 'writing', 'consider', 'talk', 'question'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('discourse.v.01')
# Senso Target:  Lemma('discourse.v.01.discuss')
# ------------------------------
# Parola da disambiguare:  hell
# Frase in cui compare la parola:  What the hell was he up to now ?
# Contesto della frase:  {'hell'}
# Max Signature:  {'battle', 'turmoil', 'engine', 'room', 'pit', 'christmas', 'inferno', 'pain', 'hell', 'place'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('hell.n.01')
# Senso Target:  Lemma('hell.n.01.hell')
# ------------------------------
# Parola da disambiguare:  Microscopic
# Frase in cui compare la parola:  Microscopic studies of the gastrocnemius , pectoralis major , transversus abdominis , biceps brachii , and diaphragm showed atrophy as well as varying degrees of injury ranging from swelling and vacuolization to focal necrosis of the muscle fibers .
# Contesto della frase:  {'pectoralis', 'abdominis', 'major', 'degree', 'diaphragm', 'focal', 'transversus', 'swell', 'vacuolization', 'vary', 'study', 'range', 'gastrocnemius', 'atrophy', 'microscopic', 'fiber', 'well', 'brachii', 'injury', 'necrosis', 'muscle', 'biceps'}
# Max Signature:  {'analysis', 'examination', 'microscopy', 'relate', 'microscopic', 'microscopical'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('microscopic.a.01')
# Senso Target:  Lemma('microscopic.a.01.microscopic')
# ------------------------------
# Parola da disambiguare:  rejoining
# Frase in cui compare la parola:  He was there one season before rejoining the Steelers as an assistant coach .
# Contesto della frase:  {'coach', 'assistant', 'rejoin', 'season', 'steelers'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('rejoin.v.01')
# Senso Target:  Lemma('rejoin.v.01.rejoin')
# ------------------------------
# Parola da disambiguare:  subspace
# Frase in cui compare la parola:  On the other hand , the null space of * * f and the null space of * * f together span V , the former being the subspace spanned by * * f and the latter the subspace spanned by * * f and * * f .
# Contesto della frase:  {'subspace', 'null', 'hand', 'space', 'span'}
# Max Signature:  {'space'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('subspace.n.01')
# Senso Target:  Lemma('subspace.n.01.subspace')
# ------------------------------
# Parola da disambiguare:  glories
# Frase in cui compare la parola:  He suggests that Gore Court embodies all the glories of Tudor splendor .
# Contesto della frase:  {'embody', 'tudor', 'glory', 'splendor', 'court', 'gore'}
# Max Signature:  {'life', 'high', 'honor', 'glory'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('glory.n.01')
# Senso Target:  Lemma('glory.n.02.glory')
# ------------------------------
# Parola da disambiguare:  3
# Frase in cui compare la parola:  Blood samples were allowed to clot at room temperature for 3 hr , centrifuged and the serum was removed .
# Contesto della frase:  {'blood', 'serum', 'remove', 'room', 'sample', 'allow', 'temperature', 'hr', 'centrifuge', 'clot'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('three.n.01')
# Senso Target:  Lemma('three.s.01.3')
# ------------------------------
# Parola da disambiguare:  government
# Frase in cui compare la parola:  These are becoming more and more available through the work of counties and other government agencies .
# Contesto della frase:  {'work', 'county', 'agency', 'government'}
# Max Signature:  {'tax', 'government', 'organization', 'unit', 'political', 'matter', 'govern', 'authority', 'refer', 'reduce', 'high'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('government.n.01')
# Senso Target:  Lemma('government.n.01.government')
# ------------------------------
# Parola da disambiguare:  circular
# Frase in cui compare la parola:  Zodiacal light and the gegenschein give some evidence for such a dust blanket , a phenomenon also to be expected if the dust before capture is in circular orbits about the sun , as indicated by the trend of the smaller visible meteors .
# Contesto della frase:  {'light', 'gegenschein', 'capture', 'blanket', 'zodiacal', 'circular', 'orbit', 'sun', 'phenomenon', 'trend', 'small', 'dust', 'meteor', 'evidence', 'visible', 'indicate', 'expect'}
# Max Signature:  {'leaflet', 'distribution', 'wide', 'circular', 'subscriber', 'advertisement', 'print', 'mail', 'intend'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('circular.n.01')
# Senso Target:  Lemma('round.a.01.circular')
# ------------------------------
# Parola da disambiguare:  lag
# Frase in cui compare la parola:  At any rate , Manchester did not lag far behind the first commercial system which was set up in 1844 between Baltimore and Washington .
# Contesto della frase:  {'baltimore', 'rate', 'system', 'set', 'lag', 'manchester', 'washington', 'commercial'}
# Max Signature:  {'lag', 'heat', 'pipe', 'loss', 'prevent', 'cover'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('lag.v.04')
# Senso Target:  Lemma('lag.v.01.lag')
# ------------------------------
# Parola da disambiguare:  simply
# Frase in cui compare la parola:  One year I simply set the plants in the remains of a compost pile , to which a little sand had been added , and I had the most beautiful pansies in my , or any of my neighbors ' experience .
# Contesto della frase:  {'sand', 'set', 'pansy', 'beautiful', 'neighbor', 'plant', 'remains', 'simply', 'experience', 'year', 'compost', 'pile', 'add'}
# Max Signature:  {'romeo', 'beautiful', 'absolutely', 'simply', 'grand', 'cant'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('just.r.04')
# Senso Target:  Lemma('merely.r.01.simply')
# ------------------------------
# Parola da disambiguare:  start
# Frase in cui compare la parola:  The Russians are all trained as dancers before they start to study gymnastics .
# Contesto della frase:  {'russians', 'start', 'study', 'train', 'gymnastics', 'dancer'}
# Max Signature:  {'good', 'start'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('start.n.01')
# Senso Target:  Lemma('get_down.v.07.start')
# ------------------------------
# Parola da disambiguare:  basic
# Frase in cui compare la parola:  Most park planners look to water frontage for basic park areas .
# Contesto della frase:  {'planner', 'area', 'water', 'basic', 'frontage', 'park'}
# Max Signature:  {'pertain', 'basis', 'change', 'base', 'public', 'occur', 'ingredient', 'priority', 'opinion', 'fact', 'basic', 'constitute'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('basic.a.01')
# Senso Target:  basic.s.00
# ------------------------------
# Parola da disambiguare:  demanded
# Frase in cui compare la parola:  Clara Harris , one of the guests in the box , stood up and demanded water .
# Contesto della frase:  {'guest', 'box', 'demand', 'water', 'stand', 'clara', 'harris'}
# Max Signature:  {'urgently', 'compensation', 'request', 'demand', 'bos', 'manager', 'fire', 'forcefully', 'victim', 'family'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('demand.v.01')
# Senso Target:  Lemma('demand.v.01.demand')
# ------------------------------
# Parola da disambiguare:  place
# Frase in cui compare la parola:  Who will take Stalin 's place beside Lenin ?
# Contesto della frase:  {'lenin', 'place', 'stalin'}
# Max Signature:  {'planet', 'locate', 'spot', 'surface', 'place', 'point', 'nice', 'bright', 'feature', 'picnic', 'respect', 'region'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('topographic_point.n.01')
# Senso Target:  Lemma('place.n.06.place')
# ------------------------------
# Parola da disambiguare:  mate
# Frase in cui compare la parola:  The young queens and drones leave the nest and mate , and after a short period of freedom , the fertilized young queens will begin to dig in for the winter .
# Contesto della frase:  {'young', 'mate', 'dig', 'winter', 'period', 'nest', 'short', 'freedom', 'leave', 'queen', 'drone', 'fertilized'}
# Max Signature:  {'love', 'mate', 'partner', 'sexual', 'camel', 'leave', 'animal', 'hate', 'mare'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('mate.n.03')
# Senso Target:  Lemma('copulate.v.01.mate')
# ------------------------------
# Parola da disambiguare:  function
# Frase in cui compare la parola:  We consider now the graph of the function f ( t ) on **f .
# Contesto della frase:  {'function', 'graph', 'consider'}
# Max Signature:  {'set', 'element', 'function', 'mathematics', 'relation', 'associate', 'range', 'domain', 'mathematical'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('function.n.01')
# Senso Target:  Lemma('function.n.01.function')
# ------------------------------
# Parola da disambiguare:  reserved
# Frase in cui compare la parola:  Those would be reserved for the orchestra 's great nights when the soloist can surpass himself .
# Contesto della frase:  {'night', 'reserve', 'soloist', 'orchestra', 'great', 'surpass'}
# Max Signature:  {'advance', 'maxims', 'reserve', 'table', 'arrange', 'manage'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('reserve.v.03')
# Senso Target:  Lemma('reserve.v.01.reserve')
# ------------------------------
# Termini valutati:  51
# Termini valutati correttamente:  25
# Accuratezza:  0.5
#
# Esecuzioni:  10
# Lista delle accuratezze:  [0.48, 0.46, 0.54, 0.56, 0.52, 0.42, 0.62, 0.4, 0.58, 0.5]
# Accuratezza media:  0.508
