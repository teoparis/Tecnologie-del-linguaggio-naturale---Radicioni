# %%
import re
import enum
import math
import random
import nltk
import csv
import numpy as np
import scipy as sp
from nltk.corpus import wordnet as wn
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import semcor
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from random import randrange
from collections import deque
from statistics import mean

# %% [markdown]
# FUNZIONI DI PREPROCESSING

# %%
#il pre-processing consiste nella tokenizzazione, lemmatizzazione,
#rimozione della punteggiatura e delle stopwords di una sentence
def pre_processing(sentence):
    return set(remove_stopwords(tokenize_sentence(remove_punctuation(sentence))))

#rimuove le stowords da una lista di parole
def remove_stopwords(words_list):
    stopwords_list = get_stopwords()
    return [value.lower() for value in words_list if value.lower() not in stopwords_list]

#Rimuove la punteggiatura da una sentence
#Restituisce la sentence senza punteggiature
def remove_punctuation(sentence):
    return re.sub(r'[^\w\s]','',sentence)

#Tokenizza la frase in input e ne affettua anche la lemmatizzazione della sue parole
def tokenize_sentence(sentence):
    words_list = []
    lmtzr = WordNetLemmatizer()
    for tag in nltk.pos_tag(word_tokenize(sentence)):
        if (tag[1][:2] == "NN"):
            words_list.append(lmtzr.lemmatize(tag[0], pos = wn.NOUN))
        elif (tag[1][:2] == "VB"):
             words_list.append(lmtzr.lemmatize(tag[0], pos = wn.VERB))
        elif (tag[1][:2] == "RB"):
             words_list.append(lmtzr.lemmatize(tag[0], pos = wn.ADV))
        elif (tag[1][:2] == "JJ"):
             words_list.append(lmtzr.lemmatize(tag[0], pos = wn.ADJ))
    return words_list

#Restituisce la l'insieme di stopwords dal file delle stopwords
def get_stopwords():
    stopwords = open("stop_words_FULL.txt", "r")
    stopwords_list = []
    for word in stopwords:
        stopwords_list.append(word.replace('\n', ''))
    stopwords.close()
    return stopwords_list

# %% [markdown]
# FUNZIONI UTILI PER L'ANALISI DEL TESTO

# %%
#Restituisce un sostantivo random presente nel dizionario associato ad una sentence
def get_random_noun(dictionary_tag):
    try:
        sentence_nouns = dictionary_tag['NN']
    except KeyError:
        return None #se non ci sono sostantivi
    noun =  random.choice(sentence_nouns)
    if len(wn.synsets(noun)) == 0:
        return None #se il sostantivo scelto non ha almeno un synset in wordnet
    return noun

#Restituisce una parola random presente nel dizionario associato ad una sentence
def get_random_word(dictionary_tag):
    keys = list(dictionary_tag.keys())
    if not keys:
        return None #se non ci sono parole "analizzabili" nel dizionario, aka se il dizionario è vuoto
    key = random.choice(keys)
    words_list = dictionary_tag[key]
    word = random.choice(words_list)
    if len(wn.synsets(word)) == 0:
        return None #se la parola scelta non ha almeno un synset in wordnet
    return word

#Verifica che una parola abbia un synset target associato
#Senza synset target associato è inutile confrontare l'output dell'algortimo di Lesk
def check_word_synset_target(word,sentence_sem):
    for w in sentence_sem:
        if (type(w) != list):
            if (w[0] == word):
                return True
    return False
    
#Crea un dizionario che ha come chiavi i tag presenti nella sentence e come valori liste di parole associate a quei tag
#e.g {NN: ['home','garden'], VB:['gone'], .....,}
#input: sentence_tag -> rappresenta le words della sentence con i relativi pos tag
#input: sentence_sem -> rappresenta le words della sentence con il relativo synset target associato
def get_dictionary_tag(sentence_tag,sentence_sem):
    dictionary_tag = dict()
    stopwords_list = get_stopwords()
    for word in sentence_tag:
         tag = word.label()
         word = " ".join(l for l in word)
         if check_word_synset_target(word, sentence_sem): #Non inserisco nel dizionario parole che non hanno un synset target
             w = word.lower()
             if w not in stopwords_list and tag: #Non inserisco nel dizionario stopwords o parole che non hanno un pos tag associato
                 if tag in dictionary_tag:
                     dictionary_tag[tag].append(word)
                 else:
                     dictionary_tag[tag] = [word]             
    return dictionary_tag

#Restituisce un indice randomico utile per l'ultimo esercizio
def get_random_index(index_evaluated, INDEXES_NUM):
    while True:
        index = randrange(INDEXES_NUM)
        if index not in index_evaluated:
            return index
    
#Restituisce il synset target per una parola in una sentence
def get_synset_target_for_word_in_sentence(noun,sentence):
     for word in sentence:
      if(type(word) != list):
          if (word[0] == noun):
              return str(word.label())

# %% [markdown]
# METRICHE DI SIMILARITA E ALGORITMI PER LA RICERCA

# %%
#Custom similarity functions
def wu_palmer_similarity(sense1, sense2):
    numerator = 2 * depth(lowest_common_subsumer(sense1,sense2))
    denominator = depth(sense1) + depth(sense2)
    return numerator/denominator

def leakcock_chodorow(sense1, sense2):
    numerator = (shortest_path(sense1, sense2) + 1)
    denominator = (2 * max_depth) + 1
    return -math.log(numerator/denominator)

def shortest_path_similarity(sense1, sense2):
    return ((2 * max_depth) - shortest_path(sense1, sense2))

#Restituisce la similarità tra due parole date in input
def similarity(word1, word2, similarity_function):
    max_sim = 0
    for s1 in wn.synsets(word1):
        for s2 in wn.synsets(word2):
           sim = similarity_function(s1,s2)
           if sim > max_sim:
               max_sim = sim
    return max_sim

#Restituisce la profondità di un senso in wordnet, cioè il massimo percorso dal senso alla radice        
def depth(sense):
    if not sense:
        return 0
    return max([len(path) for path in all_hypernym_paths(sense)])

#Restituisce tutti i percorsi di iperonimi di un senso di wordnet, la ricerca dei percosi viene effettuata in modo ricorsivo
def all_hypernym_paths(sense):
    paths = []
    hypernyms = sense.hypernyms()
    if len(hypernyms) == 0:
        paths = [[sense]]
    for hypernym in hypernyms:
        for ancestor_list in all_hypernym_paths(hypernym):
            ancestor_list.append(sense)
            paths.append(ancestor_list)
    return paths

#Massima profondità intesa come il percorso più lungo degli iperonimi di tutti i sensi presenti in wordnet
max_depth = max(max(len(hyp_path) for hyp_path in all_hypernym_paths(ss)) for ss in wn.all_synsets())

#Restituisce un dizionario di iperonimi del senso in input con la relativa profondità
def min_hypernyms_depth(sense):
    sense_depth_queue = deque([(sense, 0)]) #deque garantisce efficienza nell'inserire ed eliminare elementi sia a destra che a sinistra della coda
    sense_depth_dict = {}
    while sense_depth_queue:
        s, depth = sense_depth_queue.popleft()
        if s in sense_depth_dict:
            continue
        sense_depth_dict[s] = depth
        depth += 1
        sense_depth_queue.extend((hyperonym, depth) for hyperonym in s.hypernyms()) #li mette a destra della coda
    return sense_depth_dict

#restituisce il percorso più breve tra due sensi di wordnet
def shortest_path(sense1,sense2):
    if sense1 == sense2:
        return 0
    dict1 = min_hypernyms_depth(sense1)
    dict2 = min_hypernyms_depth(sense2)
    min_dist = (2 * max_depth) # distanza minima iniziale

    #per ogni senso del dizionario degli iperonimi di sense1 cerca di trovare il match con un senso del secondo dizionario.
    for ss, dist1 in dict1.items():
        dist2 = dict2.get(ss)
        if not dist2:
            dist2 = (2 * max_depth)
        min_dist = min(min_dist, dist1 + dist2) #somma dei due sensi matchati
    return (2 * max_depth) if math.isinf(min_dist) else min_dist

#Restituisce l'antenato comune più vicino di due sensi, cioè l'iperonimo comune più vicino ai due sensi. 
#SCELTA PROGETTUALE: Se ne ho più di uno prendo quello può essere il più profondo rispetto alla radice.
def lowest_common_subsumer(sense1, sense2):
    if sense1 == sense2: return sense1
    
    dict1 = min_hypernyms_depth(sense1)
    dict2 = min_hypernyms_depth(sense2)
    
    min_dist = (2 * max_depth)
    candidates = []
    for ss, dist1 in dict1.items():
        dist2 = dict2.get(ss) 
        if not dist2:
            dist2 = (2 * max_depth)
        else:
            if (dist1 + dist2) <= min_dist:
                min_dist = (dist1 + dist2)
                candidates.append(ss) 
    if candidates:
        deepest = candidates[0]
        for sense in candidates:
            if depth(sense) < depth(deepest):
                deepest = sense
        return deepest #restituisce il senso con profondità maggiore rispetto alla radice

#Classe enum con la quale specifichiamo il tipo di similarità utilizzata
class Similarity_Type(enum.Enum):
    wu_palmer_similarity = 1
    shortest_path = 2
    leakcock_chodorow = 3

# %% [markdown]
# Word sense disambiguation è il processo con il quale si precisa il significato di una parola o di un insieme di parole (frase), che denota significati diversi a seconda dei contesti, per evitare che sia ambigua.

# %%
#Algoritmo di Lesk
def lesk_algorithm(word, sentence, word_type):
    best_sense = wn.synsets(word)[0]
    max_overlap = 0
    max_signature = []
    print("Frase in cui compare la parola: ", sentence)
    context = pre_processing(sentence)
    
    #se il tipo di parola è un nome allora cerco solo tra i nomi in wordnet
    #altrimenti prendo tutti i synset associati a quel termine
    if word_type == 'NOUN':
        synsets = wn.synsets(word, pos=wn.NOUN)
    elif word_type == 'ALL':
        synsets = wn.synsets(word)
        
    for sense in synsets:
        signature = get_signature(sense)
        overlap = len(list(signature & context)) #overlap
        if overlap > max_overlap:
            max_overlap = overlap
            best_sense = sense
            max_signature = signature
            
    print("Contesto della frase: ", context)
    print("Max Signature: ", max_signature) #signature del senso con più overlap con il contesto della sentence
    return best_sense

#Signature di un senso di WordNet
def get_signature(sense):
    signature = set()
    for word in pre_processing(sense.definition()): #tokenizzo la definizione del synset
        signature.add(word)
    for example in sense.examples(): #tokenizzo ogni esempio del synset
        for word in pre_processing(example):
            signature.add(word)
    return signature #la signature conterrà tutte le parole presenti nella definizione del senso e negli esempi

# %% [markdown]
# CONSEGNA 1:
#
# L'esercitazione consiste nell'implementare tre misure di similarità basate su WordNet.
#
# Per ciascuna di tali misure di similarità, calcolare gli indici di
# correlazione di Spearman and gli indici di correlazione di Pearson
# fra i risultati ottenuti e quelli ‘target’ presenti nel file annotato.

# %%
def main():

    #scelta della metrica da utilizzare per il calcolo della similarità
    
    similarity_type = Similarity_Type.leakcock_chodorow
    #similarity_type = Similarity_Type.wu_palmer_similarity
    #similarity_type = Similarity_Type.shortest_path
    
    with open('WordSim353.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        assignments = []
        targets = []
        line_count = 0
        for row in csv_reader:
            if line_count > 0:
                print("Word1: ",row[0])
                print("Word2: ",row[1])
                sim = 0
                if similarity_type.value == 1:
                    sim = similarity(row[0], row[1], wu_palmer_similarity)
                elif similarity_type.value == 2:
                    sim = similarity(row[0], row[1], shortest_path_similarity)
                elif similarity_type.value == 3:
                    sim = similarity(row[0], row[1], leakcock_chodorow)
                print("Type of similarity chosen: ", similarity_type.name)
                print("MyCustom Similarity: ",sim)
                print("Human Similarity: ",row[2])
                assignments.append(sim)
                targets.append(float(row[2]))
                print("------------------------------")
            line_count = line_count + 1
            
    print("Pearson Correlation: ", np.corrcoef(assignments, targets))
    print("Spearman Correlation: ", sp.stats.spearmanr(assignments, targets))
main()
# Out:
# Word1:  love
# Word2:  sex
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  6.77
# ------------------------------
# Word1:  tiger
# Word2:  cat
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.35
# ------------------------------
# Word1:  tiger
# Word2:  tiger
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# Human Similarity:  10.00
# ------------------------------
# Word1:  book
# Word2:  paper
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  7.46
# ------------------------------
# Word1:  computer
# Word2:  keyboard
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.62
# ------------------------------
# Word1:  computer
# Word2:  internet
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  7.58
# ------------------------------
# Word1:  plane
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  5.77
# ------------------------------
# Word1:  train
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.31
# ------------------------------
# Word1:  telephone
# Word2:  communication
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  7.50
# ------------------------------
# Word1:  television
# Word2:  radio
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  6.77
# ------------------------------
# Word1:  media
# Word2:  radio
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.42
# ------------------------------
# Word1:  drug
# Word2:  abuse
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  6.85
# ------------------------------
# Word1:  bread
# Word2:  butter
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  6.19
# ------------------------------
# Word1:  cucumber
# Word2:  potato
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  5.92
# ------------------------------
# Word1:  doctor
# Word2:  nurse
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  7.00
# ------------------------------
# Word1:  professor
# Word2:  doctor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  6.62
# ------------------------------
# Word1:  student
# Word2:  professor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  6.81
# ------------------------------
# Word1:  smart
# Word2:  student
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  4.62
# ------------------------------
# Word1:  smart
# Word2:  stupid
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  5.81
# ------------------------------
# Word1:  company
# Word2:  stock
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  7.08
# ------------------------------
# Word1:  stock
# Word2:  market
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  8.08
# ------------------------------
# Word1:  stock
# Word2:  phone
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  1.62
# ------------------------------
# Word1:  stock
# Word2:  CD
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  1.31
# ------------------------------
# Word1:  stock
# Word2:  jaguar
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  0.92
# ------------------------------
# Word1:  stock
# Word2:  egg
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  1.81
# ------------------------------
# Word1:  fertility
# Word2:  egg
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  6.69
# ------------------------------
# Word1:  stock
# Word2:  live
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  3.73
# ------------------------------
# Word1:  stock
# Word2:  life
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  0.92
# ------------------------------
# Word1:  book
# Word2:  library
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  7.46
# ------------------------------
# Word1:  bank
# Word2:  money
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  8.12
# ------------------------------
# Word1:  wood
# Word2:  forest
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# Human Similarity:  7.73
# ------------------------------
# Word1:  money
# Word2:  cash
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  9.15
# ------------------------------
# Word1:  professor
# Word2:  cucumber
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  0.31
# ------------------------------
# Word1:  king
# Word2:  cabbage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  0.23
# ------------------------------
# Word1:  king
# Word2:  queen
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# Human Similarity:  8.58
# ------------------------------
# Word1:  king
# Word2:  rook
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  5.92
# ------------------------------
# Word1:  bishop
# Word2:  rabbi
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  6.69
# ------------------------------
# Word1:  Jerusalem
# Word2:  Israel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  8.46
# ------------------------------
# Word1:  Jerusalem
# Word2:  Palestinian
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  7.65
# ------------------------------
# Word1:  holy
# Word2:  sex
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  1.62
# ------------------------------
# Word1:  fuck
# Word2:  sex
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  9.44
# ------------------------------
# Word1:  Maradona
# Word2:  football
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  8.62
# ------------------------------
# Word1:  football
# Word2:  soccer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# Human Similarity:  9.03
# ------------------------------
# Word1:  football
# Word2:  basketball
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  6.81
# ------------------------------
# Word1:  football
# Word2:  tennis
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.63
# ------------------------------
# Word1:  tennis
# Word2:  racket
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  7.56
# ------------------------------
# Word1:  Arafat
# Word2:  peace
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  6.73
# ------------------------------
# Word1:  Arafat
# Word2:  terror
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  7.65
# ------------------------------
# Word1:  Arafat
# Word2:  Jackson
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  2.50
# ------------------------------
# Word1:  law
# Word2:  lawyer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  8.38
# ------------------------------
# Word1:  movie
# Word2:  star
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  7.38
# ------------------------------
# Word1:  movie
# Word2:  popcorn
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  6.19
# ------------------------------
# Word1:  movie
# Word2:  critic
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  6.73
# ------------------------------
# Word1:  movie
# Word2:  theater
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  7.92
# ------------------------------
# Word1:  physics
# Word2:  proton
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.0055218656020977
# Human Similarity:  8.12
# ------------------------------
# Word1:  physics
# Word2:  chemistry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  7.35
# ------------------------------
# Word1:  space
# Word2:  chemistry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  4.88
# ------------------------------
# Word1:  alcohol
# Word2:  chemistry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  5.54
# ------------------------------
# Word1:  vodka
# Word2:  gin
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  8.46
# ------------------------------
# Word1:  vodka
# Word2:  brandy
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  8.13
# ------------------------------
# Word1:  drink
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  3.04
# ------------------------------
# Word1:  drink
# Word2:  ear
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  1.31
# ------------------------------
# Word1:  drink
# Word2:  mouth
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  5.96
# ------------------------------
# Word1:  drink
# Word2:  eat
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  6.87
# ------------------------------
# Word1:  baby
# Word2:  mother
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  7.85
# ------------------------------
# Word1:  drink
# Word2:  mother
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  2.65
# ------------------------------
# Word1:  car
# Word2:  automobile
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# Human Similarity:  8.94
# ------------------------------
# Word1:  gem
# Word2:  jewel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# Human Similarity:  8.96
# ------------------------------
# Word1:  journey
# Word2:  voyage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# Human Similarity:  9.29
# ------------------------------
# Word1:  boy
# Word2:  lad
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# Human Similarity:  8.83
# ------------------------------
# Word1:  coast
# Word2:  shore
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  9.10
# ------------------------------
# Word1:  asylum
# Word2:  madhouse
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# Human Similarity:  8.87
# ------------------------------
# Word1:  magician
# Word2:  wizard
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# Human Similarity:  9.02
# ------------------------------
# Word1:  midday
# Word2:  noon
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# Human Similarity:  9.29
# ------------------------------
# Word1:  furnace
# Word2:  stove
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  8.79
# ------------------------------
# Word1:  food
# Word2:  fruit
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  7.52
# ------------------------------
# Word1:  bird
# Word2:  cock
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# Human Similarity:  7.10
# ------------------------------
# Word1:  bird
# Word2:  crane
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.38
# ------------------------------
# Word1:  tool
# Word2:  implement
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  6.46
# ------------------------------
# Word1:  brother
# Word2:  monk
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  6.27
# ------------------------------
# Word1:  crane
# Word2:  implement
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  2.69
# ------------------------------
# Word1:  lad
# Word2:  brother
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  4.46
# ------------------------------
# Word1:  journey
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0.8232003088081431
# Human Similarity:  5.85
# ------------------------------
# Word1:  monk
# Word2:  oracle
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  5.00
# ------------------------------
# Word1:  cemetery
# Word2:  woodland
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  2.08
# ------------------------------
# Word1:  food
# Word2:  rooster
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0.9409833444645266
# Human Similarity:  4.42
# ------------------------------
# Word1:  coast
# Word2:  hill
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  4.38
# ------------------------------
# Word1:  forest
# Word2:  graveyard
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  1.85
# ------------------------------
# Word1:  shore
# Word2:  woodland
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  3.08
# ------------------------------
# Word1:  monk
# Word2:  slave
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  0.92
# ------------------------------
# Word1:  coast
# Word2:  forest
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  3.15
# ------------------------------
# Word1:  lad
# Word2:  wizard
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  0.92
# ------------------------------
# Word1:  chord
# Word2:  smile
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  0.54
# ------------------------------
# Word1:  glass
# Word2:  magician
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  2.08
# ------------------------------
# Word1:  noon
# Word2:  string
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  0.54
# ------------------------------
# Word1:  rooster
# Word2:  voyage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0.5355182363563622
# Human Similarity:  0.62
# ------------------------------
# Word1:  money
# Word2:  dollar
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  8.42
# ------------------------------
# Word1:  money
# Word2:  cash
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  9.08
# ------------------------------
# Word1:  money
# Word2:  currency
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  9.04
# ------------------------------
# Word1:  money
# Word2:  wealth
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  8.27
# ------------------------------
# Word1:  money
# Word2:  property
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  7.57
# ------------------------------
# Word1:  money
# Word2:  possession
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  7.29
# ------------------------------
# Word1:  money
# Word2:  bank
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  8.50
# ------------------------------
# Word1:  money
# Word2:  deposit
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  7.73
# ------------------------------
# Word1:  money
# Word2:  withdrawal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  6.88
# ------------------------------
# Word1:  money
# Word2:  laundering
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  5.65
# ------------------------------
# Word1:  money
# Word2:  operation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  3.31
# ------------------------------
# Word1:  tiger
# Word2:  jaguar
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  8.00
# ------------------------------
# Word1:  tiger
# Word2:  feline
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  8.00
# ------------------------------
# Word1:  tiger
# Word2:  carnivore
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  7.08
# ------------------------------
# Word1:  tiger
# Word2:  mammal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  6.85
# ------------------------------
# Word1:  tiger
# Word2:  animal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.00
# ------------------------------
# Word1:  tiger
# Word2:  organism
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  4.77
# ------------------------------
# Word1:  tiger
# Word2:  fauna
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  5.62
# ------------------------------
# Word1:  tiger
# Word2:  zoo
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  5.87
# ------------------------------
# Word1:  psychology
# Word2:  psychiatry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  8.08
# ------------------------------
# Word1:  psychology
# Word2:  anxiety
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  7.00
# ------------------------------
# Word1:  psychology
# Word2:  fear
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  6.85
# ------------------------------
# Word1:  psychology
# Word2:  depression
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  7.42
# ------------------------------
# Word1:  psychology
# Word2:  clinic
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  6.58
# ------------------------------
# Word1:  psychology
# Word2:  doctor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  6.42
# ------------------------------
# Word1:  psychology
# Word2:  Freud
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  8.21
# ------------------------------
# Word1:  psychology
# Word2:  mind
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  7.69
# ------------------------------
# Word1:  psychology
# Word2:  health
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  7.23
# ------------------------------
# Word1:  psychology
# Word2:  science
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  6.71
# ------------------------------
# Word1:  psychology
# Word2:  discipline
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  5.58
# ------------------------------
# Word1:  psychology
# Word2:  cognition
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  7.48
# ------------------------------
# Word1:  planet
# Word2:  star
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  8.45
# ------------------------------
# Word1:  planet
# Word2:  constellation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  8.06
# ------------------------------
# Word1:  planet
# Word2:  moon
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  8.08
# ------------------------------
# Word1:  planet
# Word2:  sun
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  8.02
# ------------------------------
# Word1:  planet
# Word2:  galaxy
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  8.11
# ------------------------------
# Word1:  planet
# Word2:  space
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  7.92
# ------------------------------
# Word1:  planet
# Word2:  astronomer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  7.94
# ------------------------------
# Word1:  precedent
# Word2:  example
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  5.85
# ------------------------------
# Word1:  precedent
# Word2:  information
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  3.85
# ------------------------------
# Word1:  precedent
# Word2:  cognition
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  2.81
# ------------------------------
# Word1:  precedent
# Word2:  law
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  6.65
# ------------------------------
# Word1:  precedent
# Word2:  collection
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  2.50
# ------------------------------
# Word1:  precedent
# Word2:  group
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  1.77
# ------------------------------
# Word1:  precedent
# Word2:  antecedent
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.04
# ------------------------------
# Word1:  cup
# Word2:  coffee
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.58
# ------------------------------
# Word1:  cup
# Word2:  tableware
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  6.85
# ------------------------------
# Word1:  cup
# Word2:  article
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  2.40
# ------------------------------
# Word1:  cup
# Word2:  artifact
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  2.92
# ------------------------------
# Word1:  cup
# Word2:  object
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  3.69
# ------------------------------
# Word1:  cup
# Word2:  entity
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  2.15
# ------------------------------
# Word1:  cup
# Word2:  drink
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  7.25
# ------------------------------
# Word1:  cup
# Word2:  food
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  5.00
# ------------------------------
# Word1:  cup
# Word2:  substance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  1.92
# ------------------------------
# Word1:  cup
# Word2:  liquid
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  5.90
# ------------------------------
# Word1:  jaguar
# Word2:  cat
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.42
# ------------------------------
# Word1:  jaguar
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0.8803587226480918
# Human Similarity:  7.27
# ------------------------------
# Word1:  energy
# Word2:  secretary
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  1.81
# ------------------------------
# Word1:  secretary
# Word2:  senate
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  5.06
# ------------------------------
# Word1:  energy
# Word2:  laboratory
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  5.09
# ------------------------------
# Word1:  computer
# Word2:  laboratory
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  6.78
# ------------------------------
# Word1:  weapon
# Word2:  secret
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  6.06
# ------------------------------
# Word1:  FBI
# Word2:  fingerprint
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  6.94
# ------------------------------
# Word1:  FBI
# Word2:  investigation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.0055218656020977
# Human Similarity:  8.31
# ------------------------------
# Word1:  investigation
# Word2:  effort
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  4.59
# ------------------------------
# Word1:  Mars
# Word2:  water
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  2.94
# ------------------------------
# Word1:  Mars
# Word2:  scientist
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  5.63
# ------------------------------
# Word1:  news
# Word2:  report
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# Human Similarity:  8.16
# ------------------------------
# Word1:  canyon
# Word2:  landscape
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  7.53
# ------------------------------
# Word1:  image
# Word2:  surface
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  4.56
# ------------------------------
# Word1:  discovery
# Word2:  space
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  6.34
# ------------------------------
# Word1:  water
# Word2:  seepage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  6.56
# ------------------------------
# Word1:  sign
# Word2:  recess
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  2.38
# ------------------------------
# Word1:  Wednesday
# Word2:  news
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  2.22
# ------------------------------
# Word1:  mile
# Word2:  kilometer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  8.66
# ------------------------------
# Word1:  computer
# Word2:  news
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  4.47
# ------------------------------
# Word1:  territory
# Word2:  surface
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  5.34
# ------------------------------
# Word1:  atmosphere
# Word2:  landscape
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  3.69
# ------------------------------
# Word1:  president
# Word2:  medal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  3.00
# ------------------------------
# Word1:  war
# Word2:  troops
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  8.13
# ------------------------------
# Word1:  record
# Word2:  number
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  6.31
# ------------------------------
# Word1:  skin
# Word2:  eye
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.22
# ------------------------------
# Word1:  Japanese
# Word2:  American
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  6.50
# ------------------------------
# Word1:  theater
# Word2:  history
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  3.91
# ------------------------------
# Word1:  volunteer
# Word2:  motto
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  2.56
# ------------------------------
# Word1:  prejudice
# Word2:  recognition
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  3.00
# ------------------------------
# Word1:  decoration
# Word2:  valor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  5.63
# ------------------------------
# Word1:  century
# Word2:  year
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  7.59
# ------------------------------
# Word1:  century
# Word2:  nation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  3.16
# ------------------------------
# Word1:  delay
# Word2:  racism
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  1.19
# ------------------------------
# Word1:  delay
# Word2:  news
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  3.31
# ------------------------------
# Word1:  minister
# Word2:  party
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.63
# ------------------------------
# Word1:  peace
# Word2:  plan
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  4.75
# ------------------------------
# Word1:  minority
# Word2:  peace
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  3.69
# ------------------------------
# Word1:  attempt
# Word2:  peace
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  4.25
# ------------------------------
# Word1:  government
# Word2:  crisis
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  6.56
# ------------------------------
# Word1:  deployment
# Word2:  departure
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  4.25
# ------------------------------
# Word1:  deployment
# Word2:  withdrawal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  5.88
# ------------------------------
# Word1:  energy
# Word2:  crisis
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  5.94
# ------------------------------
# Word1:  announcement
# Word2:  news
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  7.56
# ------------------------------
# Word1:  announcement
# Word2:  effort
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  2.75
# ------------------------------
# Word1:  stroke
# Word2:  hospital
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  7.03
# ------------------------------
# Word1:  disability
# Word2:  death
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  5.47
# ------------------------------
# Word1:  victim
# Word2:  emergency
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  6.47
# ------------------------------
# Word1:  treatment
# Word2:  recovery
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.91
# ------------------------------
# Word1:  journal
# Word2:  association
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  4.97
# ------------------------------
# Word1:  doctor
# Word2:  personnel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  5.00
# ------------------------------
# Word1:  doctor
# Word2:  liability
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  5.19
# ------------------------------
# Word1:  liability
# Word2:  insurance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  7.03
# ------------------------------
# Word1:  school
# Word2:  center
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  3.44
# ------------------------------
# Word1:  reason
# Word2:  hypertension
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  2.31
# ------------------------------
# Word1:  reason
# Word2:  criterion
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  5.91
# ------------------------------
# Word1:  hundred
# Word2:  percent
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  7.38
# ------------------------------
# Word1:  Harvard
# Word2:  Yale
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  8.13
# ------------------------------
# Word1:  hospital
# Word2:  infrastructure
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  4.63
# ------------------------------
# Word1:  death
# Word2:  row
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  5.25
# ------------------------------
# Word1:  death
# Word2:  inmate
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  5.03
# ------------------------------
# Word1:  lawyer
# Word2:  evidence
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  6.69
# ------------------------------
# Word1:  life
# Word2:  death
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  7.88
# ------------------------------
# Word1:  life
# Word2:  term
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  4.50
# ------------------------------
# Word1:  word
# Word2:  similarity
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  4.75
# ------------------------------
# Word1:  board
# Word2:  recommendation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  4.47
# ------------------------------
# Word1:  governor
# Word2:  interview
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  3.25
# ------------------------------
# Word1:  OPEC
# Word2:  country
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  5.63
# ------------------------------
# Word1:  peace
# Word2:  atmosphere
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  3.69
# ------------------------------
# Word1:  peace
# Word2:  insurance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  2.94
# ------------------------------
# Word1:  territory
# Word2:  kilometer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  5.28
# ------------------------------
# Word1:  travel
# Word2:  activity
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  5.00
# ------------------------------
# Word1:  competition
# Word2:  price
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  6.44
# ------------------------------
# Word1:  consumer
# Word2:  confidence
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  4.13
# ------------------------------
# Word1:  consumer
# Word2:  energy
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  4.75
# ------------------------------
# Word1:  problem
# Word2:  airport
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  2.38
# ------------------------------
# Word1:  car
# Word2:  flight
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  4.94
# ------------------------------
# Word1:  credit
# Word2:  card
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  8.06
# ------------------------------
# Word1:  credit
# Word2:  information
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  5.31
# ------------------------------
# Word1:  hotel
# Word2:  reservation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  8.03
# ------------------------------
# Word1:  grocery
# Word2:  money
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  5.94
# ------------------------------
# Word1:  registration
# Word2:  arrangement
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  6.00
# ------------------------------
# Word1:  arrangement
# Word2:  accommodation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  5.41
# ------------------------------
# Word1:  month
# Word2:  hotel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  1.81
# ------------------------------
# Word1:  type
# Word2:  kind
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  8.97
# ------------------------------
# Word1:  arrival
# Word2:  hotel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  6.00
# ------------------------------
# Word1:  bed
# Word2:  closet
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  6.72
# ------------------------------
# Word1:  closet
# Word2:  clothes
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  8.00
# ------------------------------
# Word1:  situation
# Word2:  conclusion
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  4.81
# ------------------------------
# Word1:  situation
# Word2:  isolation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  3.88
# ------------------------------
# Word1:  impartiality
# Word2:  interest
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  5.16
# ------------------------------
# Word1:  direction
# Word2:  combination
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  2.25
# ------------------------------
# Word1:  street
# Word2:  place
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.44
# ------------------------------
# Word1:  street
# Word2:  avenue
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# Human Similarity:  8.88
# ------------------------------
# Word1:  street
# Word2:  block
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.88
# ------------------------------
# Word1:  street
# Word2:  children
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  4.94
# ------------------------------
# Word1:  listing
# Word2:  proximity
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  2.56
# ------------------------------
# Word1:  listing
# Word2:  category
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  6.38
# ------------------------------
# Word1:  cell
# Word2:  phone
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  7.81
# ------------------------------
# Word1:  production
# Word2:  hike
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  1.75
# ------------------------------
# Word1:  benchmark
# Word2:  index
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  4.25
# ------------------------------
# Word1:  media
# Word2:  trading
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  3.88
# ------------------------------
# Word1:  media
# Word2:  gain
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  2.88
# ------------------------------
# Word1:  dividend
# Word2:  payment
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  7.63
# ------------------------------
# Word1:  dividend
# Word2:  calculation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  6.48
# ------------------------------
# Word1:  calculation
# Word2:  computation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# Human Similarity:  8.44
# ------------------------------
# Word1:  currency
# Word2:  market
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  7.50
# ------------------------------
# Word1:  OPEC
# Word2:  oil
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  8.59
# ------------------------------
# Word1:  oil
# Word2:  stock
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  6.34
# ------------------------------
# Word1:  announcement
# Word2:  production
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  3.38
# ------------------------------
# Word1:  announcement
# Word2:  warning
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.00
# ------------------------------
# Word1:  profit
# Word2:  warning
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  3.88
# ------------------------------
# Word1:  profit
# Word2:  loss
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  7.63
# ------------------------------
# Word1:  dollar
# Word2:  yen
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.78
# ------------------------------
# Word1:  dollar
# Word2:  buck
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# Human Similarity:  9.22
# ------------------------------
# Word1:  dollar
# Word2:  profit
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  7.38
# ------------------------------
# Word1:  dollar
# Word2:  loss
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  6.09
# ------------------------------
# Word1:  computer
# Word2:  software
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  8.50
# ------------------------------
# Word1:  network
# Word2:  hardware
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  8.31
# ------------------------------
# Word1:  phone
# Word2:  equipment
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  7.13
# ------------------------------
# Word1:  equipment
# Word2:  maker
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  5.91
# ------------------------------
# Word1:  luxury
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.0055218656020977
# Human Similarity:  6.47
# ------------------------------
# Word1:  five
# Word2:  month
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  3.38
# ------------------------------
# Word1:  report
# Word2:  gain
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  3.63
# ------------------------------
# Word1:  investor
# Word2:  earning
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  7.13
# ------------------------------
# Word1:  liquid
# Word2:  water
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# Human Similarity:  7.89
# ------------------------------
# Word1:  baseball
# Word2:  season
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.0055218656020977
# Human Similarity:  5.97
# ------------------------------
# Word1:  game
# Word2:  victory
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  7.03
# ------------------------------
# Word1:  game
# Word2:  team
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  7.69
# ------------------------------
# Word1:  marathon
# Word2:  sprint
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  7.47
# ------------------------------
# Word1:  game
# Word2:  series
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  6.19
# ------------------------------
# Word1:  game
# Word2:  defeat
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  6.97
# ------------------------------
# Word1:  seven
# Word2:  series
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  3.56
# ------------------------------
# Word1:  seafood
# Word2:  sea
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  7.47
# ------------------------------
# Word1:  seafood
# Word2:  food
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  8.34
# ------------------------------
# Word1:  seafood
# Word2:  lobster
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  8.70
# ------------------------------
# Word1:  lobster
# Word2:  food
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  7.81
# ------------------------------
# Word1:  lobster
# Word2:  wine
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  5.70
# ------------------------------
# Word1:  food
# Word2:  preparation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  6.22
# ------------------------------
# Word1:  video
# Word2:  archive
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  6.34
# ------------------------------
# Word1:  start
# Word2:  year
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  4.06
# ------------------------------
# Word1:  start
# Word2:  match
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  4.47
# ------------------------------
# Word1:  game
# Word2:  round
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  5.97
# ------------------------------
# Word1:  boxing
# Word2:  round
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  7.61
# ------------------------------
# Word1:  championship
# Word2:  tournament
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  8.36
# ------------------------------
# Word1:  fighting
# Word2:  defeating
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  7.41
# ------------------------------
# Word1:  line
# Word2:  insurance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  2.69
# ------------------------------
# Word1:  day
# Word2:  summer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  3.94
# ------------------------------
# Word1:  summer
# Word2:  drought
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.16
# ------------------------------
# Word1:  summer
# Word2:  nature
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  5.63
# ------------------------------
# Word1:  day
# Word2:  dawn
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  7.53
# ------------------------------
# Word1:  nature
# Word2:  environment
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  8.31
# ------------------------------
# Word1:  environment
# Word2:  ecology
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# Human Similarity:  8.81
# ------------------------------
# Word1:  nature
# Word2:  man
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  6.25
# ------------------------------
# Word1:  man
# Word2:  woman
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  8.30
# ------------------------------
# Word1:  man
# Word2:  governor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  5.25
# ------------------------------
# Word1:  murder
# Word2:  manslaughter
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  8.53
# ------------------------------
# Word1:  soap
# Word2:  opera
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  7.94
# ------------------------------
# Word1:  opera
# Word2:  performance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  6.88
# ------------------------------
# Word1:  life
# Word2:  lesson
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  5.94
# ------------------------------
# Word1:  focus
# Word2:  life
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  4.06
# ------------------------------
# Word1:  production
# Word2:  crew
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  6.25
# ------------------------------
# Word1:  television
# Word2:  film
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  7.72
# ------------------------------
# Word1:  lover
# Word2:  quarrel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  6.19
# ------------------------------
# Word1:  viewer
# Word2:  serial
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  2.97
# ------------------------------
# Word1:  possibility
# Word2:  girl
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  1.94
# ------------------------------
# Word1:  population
# Word2:  development
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  3.75
# ------------------------------
# Word1:  morality
# Word2:  importance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  3.31
# ------------------------------
# Word1:  morality
# Word2:  marriage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  3.69
# ------------------------------
# Word1:  Mexico
# Word2:  Brazil
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  7.44
# ------------------------------
# Word1:  gender
# Word2:  equality
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  6.41
# ------------------------------
# Word1:  change
# Word2:  attitude
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  5.44
# ------------------------------
# Word1:  family
# Word2:  planning
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  6.25
# ------------------------------
# Word1:  opera
# Word2:  industry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  2.63
# ------------------------------
# Word1:  sugar
# Word2:  approach
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  0.88
# ------------------------------
# Word1:  practice
# Word2:  institution
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  3.19
# ------------------------------
# Word1:  ministry
# Word2:  culture
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  4.69
# ------------------------------
# Word1:  problem
# Word2:  challenge
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.75
# ------------------------------
# Word1:  size
# Word2:  prominence
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  5.31
# ------------------------------
# Word1:  country
# Word2:  citizen
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  7.31
# ------------------------------
# Word1:  planet
# Word2:  people
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  5.75
# ------------------------------
# Word1:  development
# Word2:  issue
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  3.97
# ------------------------------
# Word1:  experience
# Word2:  music
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  3.47
# ------------------------------
# Word1:  music
# Word2:  project
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  3.63
# ------------------------------
# Word1:  glass
# Word2:  metal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  5.56
# ------------------------------
# Word1:  aluminum
# Word2:  metal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.83
# ------------------------------
# Word1:  chance
# Word2:  credibility
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  3.88
# ------------------------------
# Word1:  exhibit
# Word2:  memorabilia
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  5.31
# ------------------------------
# Word1:  concert
# Word2:  virtuoso
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  6.81
# ------------------------------
# Word1:  rock
# Word2:  jazz
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  7.59
# ------------------------------
# Word1:  museum
# Word2:  theater
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  7.19
# ------------------------------
# Word1:  observation
# Word2:  architecture
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  4.38
# ------------------------------
# Word1:  space
# Word2:  world
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  6.53
# ------------------------------
# Word1:  preservation
# Word2:  world
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  6.19
# ------------------------------
# Word1:  admission
# Word2:  ticket
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  7.69
# ------------------------------
# Word1:  shower
# Word2:  thunderstorm
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  6.31
# ------------------------------
# Word1:  shower
# Word2:  flood
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  6.03
# ------------------------------
# Word1:  weather
# Word2:  forecast
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  8.34
# ------------------------------
# Word1:  disaster
# Word2:  area
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  6.25
# ------------------------------
# Word1:  governor
# Word2:  office
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  6.34
# ------------------------------
# Word1:  architecture
# Word2:  century
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  3.78
# ------------------------------
# Pearson Correlation:  [[1.         0.26142012]
#  [0.26142012 1.        ]]
# Spearman Correlation:  SpearmanrResult(correlation=0.2651845536640065, pvalue=4.292887522518468e-07)

# %% [markdown]
# CONSEGNA 2.1:
#
# L'esercitazione consiste nell'estrarre 50 frasi dal corpus SemCor (corpus annotato con i synset di WN) e disambiguare (almeno) un sostantivo per frase.
#
# Calcolare l’accuratezza del sistema implementato sulla base dei sensi annotati in SemCor.

# %%
tokenizer = RegexpTokenizer(r'\w+')

INDEXES_NUM = 1000 #è il limite, partendo da 0, di sentence che possono essere testate relative al database SemCor
RANGE = 50 #è il numero di sentence che effettivamente verranno testate

sentences_tag = semcor.tagged_sents() #lista di liste. Ogni lista rappresenta una sentence e ad ogni parola della sentence è associato un pos tag
sentences = semcor.sents() #lista di liste di parole. Ogni lista rappresenta una sentence
sentences_sem = semcor.tagged_sents(tag = "sem") #lista di liste. Ogni lista rappresenta una sentence e ad ogni parola della sentence è associato un synset gold

def main():
    evaluated = 0 #termini valutati
    checked = 0 #termini valutati correttamente
    index_evaluated = set() #insieme degli indici già valutati
    while(evaluated <= RANGE):
        while True: #fino a quando non trova una word che ha almeno un senso in wordnet   
            index = get_random_index(index_evaluated, INDEXES_NUM)
            word = get_random_noun(get_dictionary_tag(sentences_tag[index],sentences_sem[index]))
            if word:
                break
        sentence = sentences[index]
        print("Parola da disambiguare: ",word)
        #all'algoritmo di lesk viene dato in input la word e l'insieme dei termini che formano la frase, uniti sottoforma di stringa
        best_sense = str(lesk_algorithm(word, ' '.join(word for word in sentence), word_type='NOUN'))
        print("Senso attribuito dall'algoritmo di Lesk: ",best_sense)
        target_lemma = get_synset_target_for_word_in_sentence(word,sentences_sem[index])
        print("Senso Target: ",target_lemma)
        best_sense_lemma = best_sense[8:len(best_sense)-2]
        if target_lemma:
            if best_sense_lemma in target_lemma: checked= checked + 1
        evaluated += 1
        print("------------------------------")
    
    print("Termini valutati: ", evaluated)
    print("Termini valutati correttamente: ", checked)
    print("Accuratezza: ", checked/RANGE)
    
main()
# Out:
# Parola da disambiguare:  rushing
# Frase in cui compare la parola:  Last week , when Royal was informed that three Longhorns were among the conference 's top four in rushing , he said : `` That won't last long '' .
# Contesto della frase:  {'week', 'top', 'conference', 'longhorns', 'wont', 'rush', 'royal', 'inform', 'long'}
# Max Signature:  {'advance', 'ready', 'attempt', 'ball', 'linebacker', 'rush', 'american', 'football'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('rush.n.07')
# Senso Target:  Lemma('rush.n.07.rushing')
# ------------------------------
# Parola da disambiguare:  appointment
# Frase in cui compare la parola:  Whether the compromises - on both sides - that made possible the interim appointment can then be repeated remains to be seen .
# Contesto della frase:  {'appointment', 'side', 'compromise', 'repeat', 'remain', 'interim'}
# Max Signature:  {'appointment', 'person', 'nonelective', 'committee', 'approve', 'position'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('appointment.n.01')
# Senso Target:  Lemma('appointment.n.01.appointment')
# ------------------------------
# Parola da disambiguare:  number
# Frase in cui compare la parola:  She can decrease the number of temptations .
# Contesto della frase:  {'number', 'decrease', 'temptation'}
# Max Signature:  {'unit', 'sum', 'individual', 'figure', 'indefinite', 'property', 'number', 'parameter', 'small', 'quantity', 'chore', 'total', 'possess'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('number.n.01')
# Senso Target:  Lemma('number.n.02.number')
# ------------------------------
# Parola da disambiguare:  discrimination
# Frase in cui compare la parola:  State and federal legislation against racial discrimination in employment was called for yesterday in a report of a `` blue ribbon '' citizens committee on the aid to dependent children program .
# Contesto della frase:  {'employment', 'yesterday', 'aid', 'discrimination', 'dependent', 'committee', 'legislation', 'citizen', 'racial', 'child', 'ribbon', 'program', 'blue', 'report', 'federal', 'call'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('discrimination.n.01')
# Senso Target:  Lemma('discrimination.n.01.discrimination')
# ------------------------------
# Parola da disambiguare:  yard
# Frase in cui compare la parola:  He nailed it for a yard loss '' .
# Contesto della frase:  {'loss', 'nail', 'yard'}
# Max Signature:  {'land', 'enclosed', 'small', 'house', 'yard', 'building'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('yard.n.02')
# Senso Target:  Lemma('yard.n.01.yard')
# ------------------------------
# Parola da disambiguare:  ends
# Frase in cui compare la parola:  Gauer works with the ends .
# Contesto della frase:  {'gauer', 'work'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('end.n.01')
# Senso Target:  Lemma('end.n.08.end')
# ------------------------------
# Parola da disambiguare:  drive
# Frase in cui compare la parola:  He boomed a 280 - yard drive .
# Contesto della frase:  {'drive', 'boom', 'yard'}
# Max Signature:  {'drive', 'cut', 'force', 'reach', 'apply', 'velocity', 'desire', 'propel'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('drive.n.01')
# Senso Target:  Lemma('drive.n.06.drive')
# ------------------------------
# Parola da disambiguare:  practices
# Frase in cui compare la parola:  The grand jury commented on a number of other topics , among them the Atlanta and Fulton County purchasing departments which it said `` are well operated and follow generally accepted practices which inure to the best interest of both governments '' .
# Contesto della frase:  {'best', 'follow', 'county', 'accept', 'number', 'fulton', 'government', 'interest', 'inure', 'atlanta', 'jury', 'grand', 'practice', 'purchasing', 'generally', 'well', 'operate', 'topic', 'department', 'comment'}
# Max Signature:  {'dietary', 'practice', 'annual', 'change', 'raise', 'customary', 'operation', 'pattern', 'behavior'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('practice.n.01')
# Senso Target:  Lemma('practice.n.01.practice')
# ------------------------------
# Parola da disambiguare:  court
# Frase in cui compare la parola:  The jury said it found the court `` has incorporated into its operating procedures the recommendations '' of two previous grand juries , the Atlanta Bar Association and an interim citizens committee .
# Contesto della frase:  {'grand', 'procedures', 'find', 'atlanta', 'recommendation', 'previous', 'citizen', 'committee', 'interim', 'jury', 'court', 'operating', 'bar', 'association', 'incorporate'}
# Max Signature:  {'marked', 'player', 'horizontal', 'advance', 'reserve', 'area', 'specially', 'court', 'game', 'play'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('court.n.04')
# Senso Target:  Lemma('court.n.01.court')
# ------------------------------
# Parola da disambiguare:  disappointments
# Frase in cui compare la parola:  Despite countless barriers and disappointments , Shea moved forward .
# Contesto della frase:  {'shea', 'move', 'disappointment', 'barrier', 'forward', 'countless'}
# Max Signature:  {'high', 'hope', 'expectation', 'doom', 'feeling', 'dissatisfaction', 'result', 'realize', 'disappointment'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('disappointment.n.01')
# Senso Target:  Lemma('disappointment.n.02.disappointment')
# ------------------------------
# Parola da disambiguare:  doubles
# Frase in cui compare la parola:  Scherer also had a big night at bat with four hits in five trips including a double , Len Boehmer also was 4 - for - 5 with two doubles and Dave Ritchie had a home run and a triple .
# Contesto della frase:  {'trip', 'scherer', 'include', 'double', 'dave', 'bat', 'big', 'len', 'triple', 'boehmer', 'hit', 'ritchie', 'night'}
# Max Signature:  {'safely', 'double', 'base', 'second', 'centerfield', 'batter', 'deep', 'hit'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('double.n.01')
# Senso Target:  Lemma('double.n.01.double')
# ------------------------------
# Parola da disambiguare:  title
# Frase in cui compare la parola:  Implementation of Georgia 's automobile title law was also recommended by the outgoing jury .
# Contesto della frase:  {'recommend', 'law', 'automobile', 'georgia', 'title', 'outgoing', 'implementation', 'jury'}
# Max Signature:  {'federal', 'help', 'school', 'heading', 'title', 'summary', 'statute', 'provide', 'bill', 'legislative', 'deal', 'matter'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('title.n.01')
# Senso Target:  Lemma('deed.n.01.title')
# ------------------------------
# Parola da disambiguare:  letters
# Frase in cui compare la parola:  `` We 're getting more ' pro ' letters than ' con ' on horse race betting '' , said Ratcliff .
# Contesto della frase:  {'race', 'letter', 'ratcliff', 'horse', 'betting', 'pro', 'con'}
# Max Signature:  {'book', 'letter', 'best', 'culture', 'literary', 'american'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('letters.n.01')
# Senso Target:  Lemma('letter.n.01.letter')
# ------------------------------
# Parola da disambiguare:  starts
# Frase in cui compare la parola:  The desire to give Broglio as many starts as possible ; 3 .
# Contesto della frase:  {'start', 'broglio', 'desire'}
# Max Signature:  {'start', 'good'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('start.n.01')
# Senso Target:  Lemma('start.n.03.start')
# ------------------------------
# Parola da disambiguare:  game
# Frase in cui compare la parola:  This rule providing for a blackout of televised baseball 30 minutes before the start of a major or minor league game in any area comes from the game 's top rulers .
# Contesto della frase:  {'televised', 'top', 'minute', 'major', 'blackout', 'area', 'provide', 'baseball', 'start', 'minor', 'league', 'game', 'ruler', 'rule'}
# Max Signature:  {'winner', 'contest', 'people', 'determine', 'game', 'rule', 'play'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('game.n.01')
# Senso Target:  Lemma('game.n.01.game')
# ------------------------------
# Parola da disambiguare:  result
# Frase in cui compare la parola:  Garden Fresh , the result of a mating of Better Self and Rosy Fingered , seems to improve with each start and appeared to win the St. Patrick's Day Purse with some speed in reserve .
# Contesto della frase:  {'appear', 'rosy', 'better', 'patricks', 'st', 'mating', 'fingered', 'speed', 'reserve', 'garden', 'fresh', 'result', 'improve', 'start', 'win', 'day', 'purse'}
# Max Signature:  {'explain', 'place', 'statement', 'find', 'solve', 'peaceful', 'book', 'solution', 'result', 'problem', 'decimal', 'compute', 'answer'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('solution.n.02')
# Senso Target:  Lemma('consequence.n.01.result')
# ------------------------------
# Parola da disambiguare:  franchise
# Frase in cui compare la parola:  When that failed , he enlisted Branch Rickey 's aid in the formation of a third major league , the Continental , with New York as the key franchise .
# Contesto della frase:  {'fail', 'rickey', 'continental', 'key', 'franchise', 'formation', 'major', 'enlist', 'third', 'league', 'aid', 'york', 'branch'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('franchise.n.01')
# Senso Target:  Lemma('franchise.n.01.franchise')
# ------------------------------
# Parola da disambiguare:  desires
# Frase in cui compare la parola:  His desires are so strong that he needs constant reassurance of his mother 's love for him and what she expects of him , in order to overcome them .
# Contesto della frase:  {'mother', 'love', 'strong', 'constant', 'order', 'overcome', 'expect', 'desire', 'reassurance'}
# Max Signature:  {'man', 'thing', 'desire', 'inclination'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('desire.n.02')
# Senso Target:  Lemma('desire.n.01.desire')
# ------------------------------
# Parola da disambiguare:  members
# Frase in cui compare la parola:  The appointment was announced at a news conference at which Skorich said he would retain two members of Shaw 's staff - Jerry Williams and Charlie Gauer .
# Contesto della frase:  {'retain', 'member', 'appointment', 'news', 'charlie', 'jerry', 'conference', 'williams', 'staff', 'gauer', 'skorich', 'shaw'}
# Max Signature:  {'introduce', 'individual', 'member', 'group', 'family', 'person', 'social', 'organization', 'compose', 'admit', 'faculty', 'join', 'participate'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('member.n.01')
# Senso Target:  Lemma('member.n.01.member')
# ------------------------------
# Parola da disambiguare:  Tuesday
# Frase in cui compare la parola:  `` We 'll work hard Tuesday , Wednesday and Thursday '' , Meek said , `` and probably will have a good scrimmage Friday .
# Contesto della frase:  {'wednesday', 'hard', 'll', 'meek', 'good', 'scrimmage', 'thursday', 'work', 'tuesday', 'friday'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('tuesday.n.01')
# Senso Target:  Lemma('tuesday.n.01.Tuesday')
# ------------------------------
# Parola da disambiguare:  minutes
# Frase in cui compare la parola:  The Union Pacific Railroad streamliner , City of San Francisco , stopped in Ogden , Utah , for a few minutes .
# Contesto della frase:  {'pacific', 'city', 'railroad', 'francisco', 'utah', 'minute', 'san', 'streamliner', 'ogden', 'union'}
# Max Signature:  {'unit', 'time', 'second', 'minute', 'equal', 'mile', 'hour'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('minute.n.01')
# Senso Target:  Lemma('minute.n.01.minute')
# ------------------------------
# Parola da disambiguare:  Monday
# Frase in cui compare la parola:  Billy Gardner 's line double , which just eluded the diving Minnie Minoso in left field , drove in Jim Lemon with the winning run with two out in the last of the ninth to give the Minnesota Twins a 6 - 5 victory over the Chicago White Sox Monday .
# Contesto della frase:  {'minnesota', 'billy', 'minnie', 'white', 'field', 'victory', 'win', 'monday', 'drive', 'double', 'twins', 'ninth', 'elude', 'minoso', 'chicago', 'gardner', 'sox', 'lemon', 'left', 'jim', 'diving'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('monday.n.01')
# Senso Target:  Lemma('monday.n.01.Monday')
# ------------------------------
# Parola da disambiguare:  season
# Frase in cui compare la parola:  He succeeds Buck Shaw , who retired at the end of last season .
# Contesto della frase:  {'buck', 'retire', 'season', 'succeed', 'shaw'}
# Max Signature:  {'celebrate', 'mark', 'activity', 'avocado', 'ballet', 'season', 'period', 'special', 'event', 'field', 'forward', 'company', 'year'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('season.n.01')
# Senso Target:  Lemma('season.n.01.season')
# ------------------------------
# Parola da disambiguare:  fullback
# Frase in cui compare la parola:  He broke that boy ( Air Force fullback Nick Arshinkoff ) in two and knocked him loose from the football '' .
# Contesto della frase:  {'arshinkoff', 'boy', 'knock', 'force', 'break', 'air', 'football', 'loose', 'fullback', 'nick'}
# Max Signature:  {'offensive', 'fullback', 'team', 'position', 'play', 'football'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('fullback.n.01')
# Senso Target:  Lemma('fullback.n.01.fullback')
# ------------------------------
# Parola da disambiguare:  albums
# Frase in cui compare la parola:  The respective vocabularies `` essential for travel '' are available in separate albums .
# Contesto della frase:  {'album', 'vocabulary', 'travel', 'respective', 'separate', 'essential'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('album.n.01')
# Senso Target:  Lemma('album.n.01.album')
# ------------------------------
# Parola da disambiguare:  season
# Frase in cui compare la parola:  In the line of operatic trades to cushion the budget , the Dallas Civic Opera will use San Francisco 's new Leni Bauer-Ecsy production of `` Lucia di Lammermoor '' this season , returning the favor next season when San Francisco uses the Dallas `` Don Giovanni '' , designed by Franco Zeffirelli .
# Contesto della frase:  {'lammermoor', 'zeffirelli', 'return', 'cushion', 'bauerecsy', 'opera', 'trade', 'design', 'lucia', 'operatic', 'don', 'favor', 'francisco', 'budget', 'franco', 'civic', 'dallas', 'leni', 'production', 'season', 'giovanni', 'san'}
# Max Signature:  {'celebrate', 'mark', 'activity', 'avocado', 'ballet', 'season', 'period', 'special', 'event', 'field', 'forward', 'company', 'year'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('season.n.01')
# Senso Target:  Lemma('season.n.01.season')
# ------------------------------
# Parola da disambiguare:  explosion
# Frase in cui compare la parola:  Hector Lopez , subbing for Berra , smashed a 3 - run homer off Bill Henry during another 5 - run explosion in the fourth .
# Contesto della frase:  {'hector', 'lopez', 'smash', 'explosion', 'berra', 'henry', 'homer', 'bill', 'fourth'}
# Max Signature:  {'atom', 'bomb', 'enormous', 'explode', 'radiation', 'create', 'child', 'explosion', 'awake', 'aloft', 'burst', 'firecracker'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('explosion.n.02')
# Senso Target:  Lemma('explosion.n.02.explosion')
# ------------------------------
# Parola da disambiguare:  night
# Frase in cui compare la parola:  They honored the battling Billikens last night .
# Contesto della frase:  {'battling', 'honor', 'billikens', 'night'}
# Max Signature:  {'spend', 'sleep', 'period', 'restless', 'night'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('night.n.03')
# Senso Target:  Lemma('night.n.01.night')
# ------------------------------
# Parola da disambiguare:  law
# Frase in cui compare la parola:  He told the committee the measure would merely provide means of enforcing the escheat law which has been on the books `` since Texas was a republic '' .
# Contesto della frase:  {'enforce', 'escheat', 'texas', 'law', 'republic', 'book', 'committee', 'provide', 'measure'}
# Max Signature:  {'respect', 'enforce', 'jurisprudence', 'law', 'impose', 'allow', 'great', 'order', 'authority', 'freedom', 'problem', 'presupposes', 'rule', 'civilization', 'collection'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('law.n.01')
# Senso Target:  Lemma('law.n.02.law')
# ------------------------------
# Parola da disambiguare:  team
# Frase in cui compare la parola:  Whitey Herzog , performing in right as the Orioles fielded possibly their strongest team of the spring , worked Keegan for a base on balls .
# Contesto della frase:  {'herzog', 'whitey', 'base', 'perform', 'orioles', 'strong', 'team', 'ball', 'field', 'work', 'spring', 'keegan'}
# Max Signature:  {'draft', 'pull', 'animal', 'work'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('team.n.02')
# Senso Target:  Lemma('team.n.01.team')
# ------------------------------
# Parola da disambiguare:  reassurance
# Frase in cui compare la parola:  His desires are so strong that he needs constant reassurance of his mother 's love for him and what she expects of him , in order to overcome them .
# Contesto della frase:  {'mother', 'love', 'strong', 'constant', 'order', 'overcome', 'expect', 'desire', 'reassurance'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('reassurance.n.01')
# Senso Target:  Lemma('reassurance.n.01.reassurance')
# ------------------------------
# Parola da disambiguare:  changes
# Frase in cui compare la parola:  Since the apparatus is new , it requires experimentation and changes in technique .
# Contesto della frase:  {'require', 'change', 'technique', 'experimentation', 'apparatus'}
# Max Signature:  {'phase', 'increase', 'worse', 'visit', 'undergone', 'ago', 'occur', 'change', 'modification', 'intend', 'pass', 'sale', 'storm', 'event', 'neighborhood', 'year'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('change.n.01')
# Senso Target:  Lemma('change.n.03.change')
# ------------------------------
# Parola da disambiguare:  nights
# Frase in cui compare la parola:  Those would be reserved for the orchestra 's great nights when the soloist can surpass himself .
# Contesto della frase:  {'orchestra', 'soloist', 'great', 'reserve', 'surpass', 'night'}
# Max Signature:  {'spend', 'sleep', 'period', 'restless', 'night'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('night.n.03')
# Senso Target:  Lemma('night.n.01.night')
# ------------------------------
# Parola da disambiguare:  letters
# Frase in cui compare la parola:  `` We 're getting more ' pro ' letters than ' con ' on horse race betting '' , said Ratcliff .
# Contesto della frase:  {'race', 'letter', 'ratcliff', 'horse', 'betting', 'pro', 'con'}
# Max Signature:  {'book', 'letter', 'best', 'culture', 'literary', 'american'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('letters.n.01')
# Senso Target:  Lemma('letter.n.01.letter')
# ------------------------------
# Parola da disambiguare:  names
# Frase in cui compare la parola:  Yes , we know , they 're professionals , men paid to play , and they should n't care how they 're handled , just as long as their names are spelled correctly on the first and fifteenth of each month .
# Contesto della frase:  {'spell', 'correctly', 'nt', 'fifteenth', 'care', 'month', 'men', 'professional', 'handle', 'play', 'pay', 'long'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('name_calling.n.01')
# Senso Target:  Lemma('name.n.01.name')
# ------------------------------
# Parola da disambiguare:  season
# Frase in cui compare la parola:  The two top talents of the time , Mickey Mantle and Willie Mays , have hit the ball harder and more successfully so far this early season than at any period in careers which , to be frank about it , never have quite reached expectations .
# Contesto della frase:  {'mantle', 'career', 'top', 'time', 'early', 'mays', 'willie', 'harder', 'reach', 'expectation', 'season', 'period', 'frank', 'ball', 'mickey', 'hit', 'talent'}
# Max Signature:  {'celebrate', 'mark', 'activity', 'avocado', 'ballet', 'season', 'period', 'special', 'event', 'field', 'forward', 'company', 'year'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('season.n.01')
# Senso Target:  Lemma('season.n.01.season')
# ------------------------------
# Parola da disambiguare:  Houston
# Frase in cui compare la parola:  SMU will play the Owls at Rice Stadium in Houston in a night game Saturday , Oct. 21 .
# Contesto della frase:  {'owls', 'smu', 'rice', 'stadium', 'oct', 'saturday', 'game', 'play', 'houston', 'night'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('houston.n.01')
# Senso Target:  Lemma('houston.n.01.Houston')
# ------------------------------
# Parola da disambiguare:  averages
# Frase in cui compare la parola:  Despite the recession , Pittsburgh came into town with this imposing list of averages : Smoky Burgess .455 , Gino Cimoli .389 , Bill Virdon .340 , Bob Clemente and Dick Groat , each .323 , Dick Stuart .306 , Don Hoak .280 and Bob Skinner .267 .
# Contesto della frase:  {'town', 'bob', 'recession', 'smoky', 'pittsburgh', 'list', 'don', 'hoak', 'cimoli', 'groat', 'skinner', 'bill', 'gino', 'average', 'dick', 'stuart', 'impose', 'clemente', 'burgess', 'virdon'}
# Max Signature:  {'average', 'normal', 'height', 'snowfall', 'usual', 'intermediate', 'month', 'regard', 'scale'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('average.n.03')
# Senso Target:  Lemma('average.n.01.average')
# ------------------------------
# Parola da disambiguare:  hurler
# Frase in cui compare la parola:  Then Dick Hyde , submarine ball hurler , entered the contest and only five batters needed to face him before there existed a 3 - to 3 deadlock .
# Contesto della frase:  {'submarine', 'dick', 'contest', 'enter', 'batter', 'hurler', 'hyde', 'exist', 'face', 'ball', 'deadlock'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('pitcher.n.01')
# Senso Target:  Lemma('pitcher.n.01.hurler')
# ------------------------------
# Parola da disambiguare:  idol
# Frase in cui compare la parola:  The idol of the hackers , of course , is Ray Ainsley , who achieved a 19 in the United States Open .
# Contesto della frase:  {'open', 'idol', 'course', 'united', 'ray', 'achieve', 'hacker', 'ainsley'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('idol.n.01')
# Senso Target:  Lemma('idol.n.02.idol')
# ------------------------------
# Parola da disambiguare:  pair
# Frase in cui compare la parola:  The White Sox had taken a 5 - 4 lead in the top of the sixth on a pair of pop fly hits - a triple by Roy Sievers and single by Camilo Carreon - a walk and a sacrifice fly .
# Contesto della frase:  {'fly', 'top', 'camilo', 'hit', 'walk', 'sacrifice', 'sixth', 'single', 'roy', 'white', 'triple', 'sievers', 'carreon', 'pop', 'sox', 'lead', 'pair'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('pair.n.01')
# Senso Target:  Lemma('pair.n.01.pair')
# ------------------------------
# Parola da disambiguare:  millions
# Frase in cui compare la parola:  `` You take out of circulation many millions of dollars '' .
# Contesto della frase:  {'dollar', 'circulation'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('million.n.01')
# Senso Target:  Lemma('million.n.01.million')
# ------------------------------
# Parola da disambiguare:  time
# Frase in cui compare la parola:  `` I kicked about 110 extra points in 135 tries during three years in high school '' , he said , `` and made 26 in a row at one time .
# Contesto della frase:  {'high', 'time', 'extra', 'school', 'row', 'kick', 'point', 'year'}
# Max Signature:  {'time', 'wait', 'indefinite', 'activity', 'mark', 'great', 'period', 'attribute', 'year', 'actor', 'specific', 'plant', 'long'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('time.n.03')
# Senso Target:  Lemma('time.n.01.time')
# ------------------------------
# Parola da disambiguare:  West
# Frase in cui compare la parola:  Or the city can be a graveyard monument to Western intransigence , if that is what the West wants .
# Contesto della frase:  {'city', 'western', 'intransigence', 'west', 'graveyard', 'monument'}
# Max Signature:  {'city', 'region', 'western', 'country', 'location'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('west.n.08')
# Senso Target:  Lemma('west.n.01.West')
# ------------------------------
# Parola da disambiguare:  team
# Frase in cui compare la parola:  `` This team set a precedent that could be valuable in the future '' , Benington pointed out .
# Contesto della frase:  {'benington', 'precedent', 'future', 'team', 'point', 'valuable', 'set'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('team.n.01')
# Senso Target:  Lemma('team.n.01.team')
# ------------------------------
# Parola da disambiguare:  team
# Frase in cui compare la parola:  The '49 team was off to a so-so 5 - 5 beginning , then fell as low as 12 - 17 on May 23 before finishing with 96 victories .
# Contesto della frase:  {'fell', 'team', 'finish', 'victory', 'soso', 'low'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('team.n.01')
# Senso Target:  Lemma('team.n.01.team')
# ------------------------------
# Parola da disambiguare:  primary
# Frase in cui compare la parola:  Five per cent of the voters in each county must sign petitions requesting that the Republicans be allowed to place names of candidates on the general election ballot , or The Republicans must hold a primary under the county unit system - a system which the party opposes in its platform .
# Contesto della frase:  {'request', 'allow', 'cent', 'county', 'party', 'voter', 'place', 'sign', 'platform', 'general', 'election', 'unit', 'republicans', 'system', 'hold', 'petition', 'primary', 'candidate', 'oppose', 'ballot'}
# Max Signature:  {'election', 'choose', 'preliminary', 'delegate', 'nominee'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('primary.n.01')
# Senso Target:  Lemma('primary.n.01.primary')
# ------------------------------
# Parola da disambiguare:  echoes
# Frase in cui compare la parola:  `` Nae , man '' , said Willie , `` ye must be countin ' the echoes '' .
# Contesto della frase:  {'nae', 'man', 'willie', 'countin', 'echo', 'ye'}
# Max Signature:  {'idea', 'emperor', 'iii', 'man', 'feeling', 'parallel', 'style', 'echo', 'napoleon', 'rousseau', 'mighty', 'infinitely', 'close', 'well', 'contention'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('echo.n.05')
# Senso Target:  Lemma('echo.n.01.echo')
# ------------------------------
# Parola da disambiguare:  soldier
# Frase in cui compare la parola:  As the civic temper rises , the more naive citizens begin to play soldier - but the guns are real .
# Contesto della frase:  {'rise', 'real', 'citizen', 'temper', 'gun', 'civic', 'soldier', 'play', 'naive'}
# Max Signature:  {'army', 'man', 'serve', 'woman', 'stand', 'attention', 'enlisted', 'soldier'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('soldier.n.01')
# Senso Target:  Lemma('soldier.n.01.soldier')
# ------------------------------
# Parola da disambiguare:  implementation
# Frase in cui compare la parola:  It urged that the next Legislature `` provide enabling funds and re-set the effective date so that an orderly implementation of the law may be effected '' .
# Contesto della frase:  {'effective', 'law', 'enable', 'urge', 'provide', 'implementation', 'orderly', 'reset', 'legislature', 'fund'}
# Max Signature:  {'execute', 'accomplish', 'create', 'aim', 'order', 'policy', 'implementation', 'agency'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('execution.n.06')
# Senso Target:  Lemma('execution.n.06.implementation')
# ------------------------------
# Parola da disambiguare:  yard
# Frase in cui compare la parola:  Saxton has made only one second-half appearance this season and that was in the Washington State game , for four plays : he returned the kickoff 30 yards , gained five yards through the line and then uncorked a 56 - yard touchdown run before retiring to the bench .
# Contesto della frase:  {'bench', 'uncork', 'kickoff', 'secondhalf', 'retire', 'gain', 'season', 'appearance', 'touchdown', 'washington', 'return', 'yard', 'saxton', 'game', 'play'}
# Max Signature:  {'land', 'enclosed', 'small', 'house', 'yard', 'building'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('yard.n.02')
# Senso Target:  Lemma('yard.n.01.yard')
# ------------------------------
# Termini valutati:  51
# Termini valutati correttamente:  27
# Accuratezza:  0.54

# %% [markdown]
# CONSEGNA 2.2:
#
# Sulla base della consegna precendente, randomizzare la selezione delle 50 frasi e la selezione del termine da disambiguare, e restituire l’accuratezza media su (per esempio) 10 esecuzioni del programma.

# %%
tokenizer = RegexpTokenizer(r'\w+')

EXECUTIONS = 10 #numero massimo di esecuzioni
INDEXES_NUM = 7000 #è il limite, partendo da 0, di sentence che possono essere testate relative al database SemCor
RANGE = 50 #è il numero di sentence che effettivamente verranno testate in ogni esecuzione        

sentences_tag = semcor.tagged_sents()
sentences = semcor.sents()
sentences_sem = semcor.tagged_sents(tag = "sem")

def main():
    accuracy_list = []
    for execution in range(1,EXECUTIONS + 1):
        evaluated = 0 #termini valutati
        checked = 0 #termini valutati correttamente
        index_evaluated = set() #insieme degli indici già valutati
        while(evaluated <= RANGE):
            while True: #fino a quando non trova una word che può essere presa in considerazione  
                index = get_random_index(index_evaluated, INDEXES_NUM)
                word = get_random_word(get_dictionary_tag(sentences_tag[index],sentences_sem[index]))
                if word:
                    break
            sentence = sentences[index]
            print("Parola da disambiguare: ",word)
            #all'algoritmo di lesk viene dato in input la word e l'insieme dei termini che formano la frase, uniti sottoforma di stringa
            best_sense = str(lesk_algorithm(word, ' '.join(word for word in sentence), word_type='ALL'))
            print("Senso attribuito dall'algoritmo di Lesk: ",best_sense)
            target_lemma = get_synset_target_for_word_in_sentence(word,sentences_sem[index])
            print("Senso Target: ",target_lemma)
            best_sense_lemma = best_sense[8:len(best_sense)-2]
            if target_lemma:
                if best_sense_lemma in target_lemma: checked= checked + 1
            evaluated += 1
            print("------------------------------")
        
        print("Termini valutati: ", evaluated)
        print("Termini valutati correttamente: ", checked)
        accuracy = checked/RANGE
        print("Accuratezza: ", accuracy)
        accuracy_list.append(accuracy)
        
    print()
    print("Esecuzioni: ",EXECUTIONS)
    print("Lista delle accuratezze: ", accuracy_list)
    print("Accuratezza media: ",mean(accuracy_list))
    
main()
# Out:
# Parola da disambiguare:  stiffened
# Frase in cui compare la parola:  John stiffened in anger .
# Contesto della frase:  {'stiffen', 'john', 'anger'}
# Max Signature:  {'bos', 'enter', 'stiff', 'room', 'stiffer', 'stiffen'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('stiffen.v.01')
# Senso Target:  Lemma('stiffen.v.01.stiffen')
# ------------------------------
# Parola da disambiguare:  load
# Frase in cui compare la parola:  Keegan , a 6 - foot - 3 - inch 158 - pounder , gave up the Orioles ' last two safeties over the final three frames , escaping a load of trouble in the ninth when the Birds threatened but failed to tally .
# Contesto della frase:  {'inch', 'ninth', 'birds', 'frame', 'fail', 'tally', 'threaten', 'orioles', 'foot', 'safety', 'escape', 'load', 'trouble', 'final', 'pounder', 'keegan'}
# Max Signature:  {'time', 'transport', 'system', 'excessive', 'break', 'process', 'load', 'quantity'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('load.n.02')
# Senso Target:  Lemma('load.n.01.load')
# ------------------------------
# Parola da disambiguare:  experimented
# Frase in cui compare la parola:  Several dentists and patients with special dental problems have experimented with the device .
# Contesto della frase:  {'patient', 'device', 'dentist', 'special', 'problem', 'experiment', 'dental'}
# Max Signature:  {'conduct', 'disease', 'order', 'fight', 'test', 'drug', 'experiment', 'investigation'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('experiment.v.01')
# Senso Target:  Lemma('experiment.v.01.experiment')
# ------------------------------
# Parola da disambiguare:  time
# Frase in cui compare la parola:  Katie reared a third time , then , trembling , descended .
# Contesto della frase:  {'time', 'katie', 'descend', 'third', 'tremble', 'rear'}
# Max Signature:  {'clip', 'time', 'ten', 'instance', 'occasion', 'single', 'event', 'succeed', 'call'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('time.n.01')
# Senso Target:  Lemma('time.n.01.time')
# ------------------------------
# Parola da disambiguare:  eighth
# Frase in cui compare la parola:  With one down in the eighth , Marv Throneberry drew a walk and stole second as Hyde fanned Tuttle .
# Contesto della frase:  {'eighth', 'tuttle', 'second', 'walk', 'draw', 'hyde', 'fan', 'throneberry', 'marv', 'stole'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('eighth.n.01')
# Senso Target:  Lemma('eighth.s.01.eighth')
# ------------------------------
# Parola da disambiguare:  local
# Frase in cui compare la parola:  Statements by other legislators that Dallas is paying for all its water program by local bonds , and that less populous places would benefit most by the pending bill , did not sway Cotten 's attack .
# Contesto della frase:  {'statements', 'legislator', 'pending', 'place', 'water', 'cotten', 'populous', 'benefit', 'dallas', 'bond', 'attack', 'local', 'program', 'bill', 'sway', 'pay'}
# Max Signature:  {'transport', 'bus', 'forever', 'public', 'local', 'train', 'consist', 'station', 'york'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('local.n.01')
# Senso Target:  local.s.00
# ------------------------------
# Parola da disambiguare:  man
# Frase in cui compare la parola:  The man was D.W. Griffith .
# Contesto della frase:  {'man', 'griffith', 'dw'}
# Max Signature:  {'generic', 'man', 'refer', 'word', 'human'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('man.n.03')
# Senso Target:  Lemma('man.n.01.man')
# ------------------------------
# Parola da disambiguare:  plainly
# Frase in cui compare la parola:  If we were asked why we thought so , we should say that these things involve great evil and are wrong , and that to take delight in what is evil or wrong is plainly unfitting .
# Contesto della frase:  {'delight', 'unfitting', 'great', 'involve', 'plainly', 'thing', 'evil', 'wrong'}
# Max Signature:  {'time', 'property', 'plainly', 'unmistakably', 'wrong', 'stubborn', 'evidently', 'manifestly', 'patently', 'bed', 'live', 'list', 'informally', 'great', 'plain', 'guest', 'pain', 'leave', 'nonsense', 'answer'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('obviously.r.01')
# Senso Target:  Lemma('obviously.r.01.plainly')
# ------------------------------
# Parola da disambiguare:  conscience
# Frase in cui compare la parola:  During this precarious period of development the mother should continue to influence the growth of the child 's conscience .
# Contesto della frase:  {'mother', 'conscience', 'influence', 'precarious', 'child', 'continue', 'period', 'development', 'growth'}
# Max Signature:  {'conscience', 'person', 'conduct', 'conformity', 'unflagging', 'sense'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('conscience.n.02')
# Senso Target:  Lemma('conscience.n.01.conscience')
# ------------------------------
# Parola da disambiguare:  societal
# Frase in cui compare la parola:  Religion is vitally necessary in both societal maintenance and regulation .
# Contesto della frase:  {'regulation', 'societal', 'religion', 'maintenance', 'vitally'}
# Max Signature:  {'evolution', 'member', 'society', 'social', 'force', 'societal', 'legislation', 'institution', 'relate', 'human'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('social.a.01')
# Senso Target:  Lemma('social.a.01.societal')
# ------------------------------
# Parola da disambiguare:  married
# Frase in cui compare la parola:  The couple was married Aug. 2 , 1913 .
# Contesto della frase:  {'aug', 'marry', 'couple'}
# Max Signature:  {'week', 'hawaii', 'minister', 'ceremony', 'perform', 'follow', 'marriage', 'marry', 'saturday', 'couple', 'splice'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('marry.v.02')
# Senso Target:  Lemma('marry.v.01.marry')
# ------------------------------
# Parola da disambiguare:  True
# Frase in cui compare la parola:  True , the pattern and flow of the drama have strong literary qualities that are a bit wearisome in the first half , before Don Quixote goes to the duke 's court .
# Contesto della frase:  {'flow', 'court', 'wearisome', 'half', 'strong', 'duke', 'literary', 'quixote', 'bit', 'drama', 'quality', 'true', 'pattern', 'don'}
# Max Signature:  {'alignment', 'possess', 'property', 'proper', 'true', 'correct'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('true.n.01')
# Senso Target:  Lemma('true.r.01.true')
# ------------------------------
# Parola da disambiguare:  recommended
# Frase in cui compare la parola:  Implementation of Georgia 's automobile title law was also recommended by the outgoing jury .
# Contesto della frase:  {'recommend', 'law', 'automobile', 'georgia', 'title', 'outgoing', 'implementation', 'jury'}
# Max Signature:  {'recommend', 'agent', 'travel', 'day', 'thanksgiving', 'push'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('recommend.v.01')
# Senso Target:  Lemma('recommend.v.01.recommend')
# ------------------------------
# Parola da disambiguare:  man
# Frase in cui compare la parola:  `` Be sure the man nearest you is awake .
# Contesto della frase:  {'man', 'awake'}
# Max Signature:  {'generic', 'man', 'refer', 'word', 'human'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('man.n.03')
# Senso Target:  Lemma('man.n.01.man')
# ------------------------------
# Parola da disambiguare:  thrill
# Frase in cui compare la parola:  It was a thrill he felt no part in .
# Contesto della frase:  {'felt', 'thrill'}
# Max Signature:  {'space', 'experience', 'feeling', 'travel', 'sensation', 'intense', 'thrill', 'sudden'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('thrill.n.03')
# Senso Target:  Lemma('bang.n.04.thrill')
# ------------------------------
# Parola da disambiguare:  needed
# Frase in cui compare la parola:  Muscle weakness did not improve , and the patient needed first a cane , then crutches .
# Contesto della frase:  {'patient', 'crutch', 'muscle', 'weakness', 'improve', 'cane'}
# Max Signature:  {'sacrifice', 'success', 'skill', 'lot', 'position', 'spectacular', 'patient', 'require', 'job', 'proper', 'personal', 'work', 'patience', 'call', 'postulate', 'hard', 'consent', 'intervention', 'dessert', 'nerve', 'dinner', 'demand'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('necessitate.v.01')
# Senso Target:  Lemma('want.v.02.need')
# ------------------------------
# Parola da disambiguare:  future
# Frase in cui compare la parola:  Pelham pointed out that Georgia voters last November rejected a constitutional amendment to allow legislators to vote on pay raises for future Legislature sessions .
# Contesto della frase:  {'legislator', 'november', 'vote', 'allow', 'georgia', 'future', 'pelham', 'reject', 'constitutional', 'point', 'raise', 'voter', 'session', 'amendment', 'legislature', 'pay'}
# Max Signature:  {'verb', 'tense', 'future', 'action', 'express'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('future.n.02')
# Senso Target:  Lemma('future.a.01.future')
# ------------------------------
# Parola da disambiguare:  divides
# Frase in cui compare la parola:  It is easily seen that * * f divides g .
# Contesto della frase:  {'easily', 'divide'}
# Max Signature:  {'perform', 'divide', 'division'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('divide.v.02')
# Senso Target:  Lemma('divide.v.02.divide')
# ------------------------------
# Parola da disambiguare:  material
# Frase in cui compare la parola:  The insoluble material which precipitated during dialysis against starting buffer always showed intense agglutinin activity , regardless of the blood group of the donor .
# Contesto della frase:  {'agglutinin', 'dialysis', 'precipitate', 'material', 'group', 'activity', 'blood', 'insoluble', 'buffer', 'donor', 'intense', 'start'}
# Max Signature:  {'substance', 'material', 'hard', 'makeup', 'physical', 'bread', 'tangible', 'stuff', 'wheat', 'coal', 'black', 'object'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('material.n.01')
# Senso Target:  Lemma('material.n.01.material')
# ------------------------------
# Parola da disambiguare:  handed
# Frase in cui compare la parola:  Warren handed him the metal box and Prevot quietly disappeared down the line .
# Contesto della frase:  {'quietly', 'prevot', 'metal', 'box', 'disappear', 'warren', 'hand'}
# Max Signature:  {'place', 'spoon', 'file', 'lawyer', 'turn', 'custody', 'prisoner', 'hand'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('pass.v.05')
# Senso Target:  Lemma('pass.v.05.hand')
# ------------------------------
# Parola da disambiguare:  motions
# Frase in cui compare la parola:  This would mean , it can readily be seen , that , again , for each new visual experience the tracing motions would have to be repeated because of the absence of visual imagery .
# Contesto della frase:  {'absence', 'motion', 'experience', 'repeat', 'tracing', 'imagery', 'visual'}
# Max Signature:  {'life', 'motility', 'reveal', 'motion', 'move', 'change', 'reflex', 'entail', 'surprise', 'sign', 'eyebrow', 'gastrointestinal', 'impatient', 'movement', 'position', 'hand', 'location'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('motion.n.03')
# Senso Target:  Lemma('gesture.n.02.motion')
# ------------------------------
# Parola da disambiguare:  direct
# Frase in cui compare la parola:  Although the inner functions of religion are not of direct significance in social organization , they have important indirect consequences .
# Contesto della frase:  {'significance', 'social', 'organization', 'direct', 'function', 'religion', 'indirect', 'consequence', 'inner'}
# Max Signature:  {'consequence', 'direct', 'accident', 'result'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('direct.s.08')
# Senso Target:  Lemma('direct.a.01.direct')
# ------------------------------
# Parola da disambiguare:  hand
# Frase in cui compare la parola:  Young Frederick Seward held out his hand .
# Contesto della frase:  {'young', 'frederick', 'seward', 'hold', 'hand'}
# Max Signature:  {'game', 'evening', 'time', 'card', 'didnt', 'hold', 'good', 'player', 'hand'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('hand.n.06')
# Senso Target:  Lemma('hand.n.01.hand')
# ------------------------------
# Parola da disambiguare:  seekers
# Frase in cui compare la parola:  `` They are also honest seekers after truth .
# Contesto della frase:  {'seeker', 'truth', 'honest'}
# Max Signature:  {'search', 'truth', 'seeker', 'inquiry'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('seeker.n.01')
# Senso Target:  Lemma('seeker.n.01.seeker')
# ------------------------------
# Parola da disambiguare:  carefully
# Frase in cui compare la parola:  Klauber investigated the rattlesnakes carefully himself and also summarized what others have found .
# Contesto della frase:  {'carefully', 'find', 'summarize', 'rattlesnake', 'klauber', 'investigate'}
# Max Signature:  {'carefully', 'watch', 'care', 'attention', 'pay'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('carefully.r.01')
# Senso Target:  Lemma('carefully.r.01.carefully')
# ------------------------------
# Parola da disambiguare:  1
# Frase in cui compare la parola:  The saline and albumin tests were performed as described for the ABO samples except that the mixture was incubated for 1 hr at 37 ` C before centrifugation .
# Contesto della frase:  {'abo', 'mixture', 'perform', 'hr', 'albumin', 'described', 'sample', 'test', 'saline', 'centrifugation', 'incubate'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('one.n.01')
# Senso Target:  Lemma('one.s.01.1')
# ------------------------------
# Parola da disambiguare:  care
# Frase in cui compare la parola:  He did not care .
# Contesto della frase:  {'care'}
# Max Signature:  {'require', 'car', 'care', 'constant', 'provide', 'attend', 'medical', 'work', 'attention', 'treatment'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('care.n.01')
# Senso Target:  Lemma('care.v.01.care')
# ------------------------------
# Parola da disambiguare:  forced
# Frase in cui compare la parola:  Indeed we are forced to go much farther .
# Contesto della frase:  {'force'}
# Max Signature:  {'moral', 'city', 'force', 'physical', 'job', 'pressure', 'squeeze', 'necessity', 'intellectual'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('coerce.v.01')
# Senso Target:  Lemma('coerce.v.01.force')
# ------------------------------
# Parola da disambiguare:  diluted
# Frase in cui compare la parola:  Spectra were also obtained from a third sample of **f which had been diluted to three times its original volume with powdered , anhydrous alundum ( **f ) .
# Contesto della frase:  {'anhydrous', 'time', 'powdered', 'volume', 'sample', 'third', 'spectra', 'alundum', 'original', 'dilute'}
# Max Signature:  {'strength', 'dilute', 'acid', 'acetic', 'alcohol', 'reduce', 'solution', 'quality', 'purity', 'concentration'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('diluted.a.01')
# Senso Target:  Lemma('dilute.v.01.dilute')
# ------------------------------
# Parola da disambiguare:  man
# Frase in cui compare la parola:  The man shrank before the hot fury , searching frantically for the answer * * h Finnegan woke up .
# Contesto della frase:  {'search', 'fury', 'man', 'shrank', 'frantically', 'hot', 'finnegan', 'wake', 'answer'}
# Max Signature:  {'generic', 'man', 'refer', 'word', 'human'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('man.n.03')
# Senso Target:  Lemma('man.n.01.man')
# ------------------------------
# Parola da disambiguare:  including
# Frase in cui compare la parola:  There are many possibilities , including poor circulation , a variety of neurological conditions , and functional disorders .
# Contesto della frase:  {'circulation', 'condition', 'poor', 'neurological', 'variety', 'disorder', 'functional', 'possibility', 'include'}
# Max Signature:  {'writer', 'list', 'famous', 'include'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('include.v.01')
# Senso Target:  Lemma('include.v.01.include')
# ------------------------------
# Parola da disambiguare:  treasurer
# Frase in cui compare la parola:  B. J. Connell is the present treasurer and manager .
# Contesto della frase:  {'connell', 'treasurer', 'manager'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('treasurer.n.01')
# Senso Target:  Lemma('treasurer.n.01.treasurer')
# ------------------------------
# Parola da disambiguare:  professional
# Frase in cui compare la parola:  The professional organizations such as American Institute of Interior Designers , National Society of Interior Designers , Home Fashions League and various trade associations , can and do aid greatly in this work .
# Contesto della frase:  {'society', 'work', 'greatly', 'organization', 'institute', 'trade', 'association', 'fashions', 'national', 'professional', 'designers', 'league', 'interior', 'aid', 'american'}
# Max Signature:  {'law', 'suitable', 'organization', 'professional', 'relate', 'field', 'profession'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('professional.a.02')
# Senso Target:  Lemma('professional.a.02.professional')
# ------------------------------
# Parola da disambiguare:  peripherally
# Frase in cui compare la parola:  Further , the gland is able to re-use a larger fraction of the thyroid hormone de-iodinated peripherally .
# Contesto della frase:  {'gland', 'hormone', 'deiodinated', 'peripherally', 'thyroid', 'reuse', 'fraction', 'large'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('peripherally.r.01')
# Senso Target:  Lemma('peripherally.r.01.peripherally')
# ------------------------------
# Parola da disambiguare:  provincial
# Frase in cui compare la parola:  Periodic bulletins of the accomplishment in each province made the registration process into a kind of competition among provincial officials .
# Contesto della frase:  {'registration', 'accomplishment', 'province', 'process', 'official', 'bulletin', 'provincial', 'periodic', 'kind', 'competition'}
# Max Signature:  {'general', 'catholic', 'church', 'superior', 'ecclesiastical', 'province', 'jesuits', 'official', 'order', 'religious', 'monthly', 'provincial', 'receive', 'report', 'roman', 'charge'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('provincial.n.01')
# Senso Target:  Lemma('provincial.a.01.provincial')
# ------------------------------
# Parola da disambiguare:  late
# Frase in cui compare la parola:  Samples zoomed into closeup range in regular succession , like telephone poles passing on the highway , while representative music reinforced the mood of the late teens and 1920 's .
# Contesto della frase:  {'telephone', 'zoom', 'range', 'late', 'samples', 'pole', 'representative', 'regular', 'highway', 'succession', 'music', 'pass', 'reinforce', 'teen', 'mood', 'closeup'}
# Max Signature:  {'evening', 'time', 'late', 'advanced', '18th', 'century', 'occur', 'usual', 'breakfast', 'period', 'expect', 'movie', 'flight'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('late.a.01')
# Senso Target:  Lemma('late.a.01.late')
# ------------------------------
# Parola da disambiguare:  explosive
# Frase in cui compare la parola:  `` We always like to keep the ball as much as we can against Denver because they have such an explosive attack '' , explained Stram .
# Contesto della frase:  {'explain', 'denver', 'explosive', 'attack', 'stram', 'ball'}
# Max Signature:  {'explosive', 'device', 'serve', 'force', 'gas', 'explode', 'outburst', 'temper', 'explosion', 'violence', 'characterize', 'sudden'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('explosive.a.01')
# Senso Target:  Lemma('explosive.s.02.explosive')
# ------------------------------
# Parola da disambiguare:  concur
# Frase in cui compare la parola:  Christianity declares that in the life and death of Jesus Christ the unique and the universal concur .
# Contesto della frase:  {'life', 'christianity', 'christ', 'unique', 'universal', 'declare', 'concur', 'jesus', 'death'}
# Max Signature:  {'life', 'concord', 'term', 'settlement', 'agree', 'agreement', 'sacred', 'cant', 'point', 'hold', 'philosopher', 'accord'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('agree.v.01')
# Senso Target:  Lemma('concur.v.02.concur')
# ------------------------------
# Parola da disambiguare:  accepted
# Frase in cui compare la parola:  If the argument is accepted as essentially sound up to this point , it remains for us to consider whether the patient 's difficulties in orienting himself spatially and in locating objects in space with the sense of touch can be explained by his defective visual condition .
# Contesto della frase:  {'locate', 'essentially', 'visual', 'defective', 'argument', 'object', 'patient', 'orient', 'difficulty', 'accept', 'sense', 'space', 'touch', 'point', 'consider', 'explain', 'remain', 'sound', 'spatially', 'condition'}
# Max Signature:  {'church', 'dogma', 'accept', 'hold', 'consider', 'true', 'argument'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('accept.v.01')
# Senso Target:  Lemma('accept.v.03.accept')
# ------------------------------
# Parola da disambiguare:  mulch
# Frase in cui compare la parola:  They need mulch .
# Contesto della frase:  {'mulch'}
# Max Signature:  {'mulch', 'cover', 'flowerbed'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('mulch.v.01')
# Senso Target:  Lemma('mulch.n.01.mulch')
# ------------------------------
# Parola da disambiguare:  commenced
# Frase in cui compare la parola:  Davis commenced his remarks by an allusion to the general feeling of opposition which the meeting had encountered from many of the citizens and all the newspapers of the city .
# Contesto della frase:  {'general', 'city', 'commence', 'encounter', 'citizen', 'allusion', 'davis', 'remark', 'feeling', 'opposition', 'meeting', 'newspaper'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('get_down.v.07')
# Senso Target:  Lemma('begin.v.03.commence')
# ------------------------------
# Parola da disambiguare:  growth
# Frase in cui compare la parola:  Definite information on the growth of senile individuals is lacking .
# Contesto della frase:  {'individual', 'senile', 'lack', 'definite', 'growth'}
# Max Signature:  {'osseous', 'involve', 'process', 'biological', 'development', 'complex', 'grow', 'simple', 'level', 'event', 'indicator', 'organically', 'individual', 'propose', 'change', 'child', 'biology', 'unfolding', 'organism', 'gradually', 'purely'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('growth.n.01')
# Senso Target:  Lemma('growth.n.01.growth')
# ------------------------------
# Parola da disambiguare:  hitless
# Frase in cui compare la parola:  Of the two cherished achievements the elderly Spahn 's hitless pitching probably reached the most hearts .
# Contesto della frase:  {'pitching', 'reach', 'achievement', 'hitless', 'heart', 'spahn', 'elderly', 'cherish'}
# Max Signature:  {'hit', 'batter', 'inning', 'hitless'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('hitless.s.01')
# Senso Target:  Lemma('hitless.s.01.hitless')
# ------------------------------
# Parola da disambiguare:  pattern
# Frase in cui compare la parola:  One or two of the schools have a five year curriculum , but the usual pattern of American education has limited most of them to the four year plan which seems to be the minimum in acceptable institutions .
# Contesto della frase:  {'minimum', 'curriculum', 'school', 'education', 'plan', 'limit', 'usual', 'institution', 'acceptable', 'pattern', 'american', 'year'}
# Max Signature:  {'republic', 'provide', 'constitution', 'worthy', 'consider', 'model', 'pattern', 'american', 'imitation'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('pattern.n.05')
# Senso Target:  Lemma('practice.n.01.pattern')
# ------------------------------
# Parola da disambiguare:  point
# Frase in cui compare la parola:  My point is this :
# Contesto della frase:  {'point'}
# Max Signature:  {'define', 'element', 'extension', 'point', 'position', 'geometric', 'coordinate'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('point.n.01')
# Senso Target:  Lemma('point.n.03.point')
# ------------------------------
# Parola da disambiguare:  high
# Frase in cui compare la parola:  That was one of the high spots of the play .
# Contesto della frase:  {'high', 'play', 'spot'}
# Max Signature:  {'high', 'lofty', 'alltime', 'summer', 'reach', 'temperature', 'level', 'degree', 'position'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('high.n.01')
# Senso Target:  Lemma('high.a.01.high')
# ------------------------------
# Parola da disambiguare:  representation
# Frase in cui compare la parola:  If , on the other hand , they opted for representation , it had to be representation per se - representation as image pure and simple , without connotations ( at least , without more than schematic ones ) of the three-dimensional space in which the objects represented originally existed .
# Contesto della frase:  {'opt', 'originally', 'threedimensional', 'space', 'representation', 'object', 'schematic', 'represent', 'exist', 'simple', 'connotation', 'image', 'pure', 'hand'}
# Max Signature:  {'mind', 'idea', 'presentation', 'image', 'form'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('representation.n.01')
# Senso Target:  Lemma('representation.n.02.representation')
# ------------------------------
# Parola da disambiguare:  giants
# Frase in cui compare la parola:  Detailed information on record lengths of the giants is given in the section that follows .
# Contesto della frase:  {'follow', 'record', 'length', 'detailed', 'giant'}
# Max Signature:  {'walton', 'build', 'unusually', 'retail', 'giant', 'enterprise', 'large'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('giant.n.03')
# Senso Target:  Lemma('giant.n.01.giant')
# ------------------------------
# Parola da disambiguare:  claim
# Frase in cui compare la parola:  Seen in perspective , many of these releases have a genuine claim to be milestones .
# Contesto della frase:  {'milestone', 'perspective', 'claim', 'release', 'genuine'}
# Max Signature:  {'property', 'claim', 'damage', 'assertion', 'money'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('claim.n.01')
# Senso Target:  Lemma('claim.n.04.claim')
# ------------------------------
# Parola da disambiguare:  teeth
# Frase in cui compare la parola:  The brush moves up and down and is small enough to clean every dental surface , including the back of the teeth .
# Contesto della frase:  {'include', 'clean', 'move', 'small', 'surface', 'teeth', 'brush', 'dental'}
# Max Signature:  {'arrangement', 'animal', 'person', 'number', 'collectively', 'teeth', 'kind'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('dentition.n.02')
# Senso Target:  Lemma('tooth.n.01.tooth')
# ------------------------------
# Parola da disambiguare:  designed
# Frase in cui compare la parola:  For added comfort some of the Italian designed sandals have foam padded cushioning .
# Contesto della frase:  {'foam', 'comfort', 'cushioning', 'design', 'sandal', 'pad', 'italian', 'add'}
# Max Signature:  {'murder', 'bos', 'devise', 'plan', 'contrive', 'design', 'attack', 'sale', 'work', 'strategy'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('plan.v.03')
# Senso Target:  designed.s.00
# ------------------------------
# Termini valutati:  51
# Termini valutati correttamente:  19
# Accuratezza:  0.38
# Parola da disambiguare:  terrible
# Frase in cui compare la parola:  a voice called , and what made it even more terrible and unreal was that the redcoat ranks never paused for an instant , only some of them glancing toward the stone wall , from behind which the voice came .
# Contesto della frase:  {'instant', 'wall', 'glance', 'stone', 'pause', 'unreal', 'redcoat', 'voice', 'rank', 'terrible', 'call'}
# Max Signature:  {'abominable', 'odor', 'sweep', 'atrocious', 'painful', 'awful', 'manner', 'unspeakable', 'voice', 'terrible', 'dreadful', 'workmanship', 'room', 'bad', 'exceptionally', 'displease', 'handwriting', 'performance', 'taste'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('atrocious.s.02')
# Senso Target:  Lemma('awful.s.02.terrible')
# ------------------------------
# Parola da disambiguare:  age
# Frase in cui compare la parola:  The age of the moon was about 2 days .
# Contesto della frase:  {'day', 'moon', 'age'}
# Max Signature:  {'exist', 'replace', 'age', 'long'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('age.n.01')
# Senso Target:  Lemma('age.n.01.age')
# ------------------------------
# Parola da disambiguare:  reputable
# Frase in cui compare la parola:  Go to a reputable grower , preferably a pansy specialist .
# Contesto della frase:  {'reputable', 'preferably', 'grower', 'pansy', 'specialist'}
# Max Signature:  {'wine', 'reputable', 'reputation', 'business', 'scientist', 'good'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('reputable.a.01')
# Senso Target:  Lemma('reputable.a.01.reputable')
# ------------------------------
# Parola da disambiguare:  designed
# Frase in cui compare la parola:  The layout of the sewer lines was designed by Henry W. Taylor , who was the engineer for the Manchester Village disposal plant .
# Contesto della frase:  {'design', 'taylor', 'engineer', 'sewer', 'henry', 'disposal', 'village', 'plant', 'layout', 'manchester'}
# Max Signature:  {'murder', 'bos', 'devise', 'plan', 'contrive', 'design', 'attack', 'sale', 'work', 'strategy'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('plan.v.03')
# Senso Target:  Lemma('design.v.04.design')
# ------------------------------
# Parola da disambiguare:  deficiency
# Frase in cui compare la parola:  First , T may not have a single characteristic value ; this is really a deficiency in the scalar field , namely , that it is not algebraically closed .
# Contesto della frase:  {'characteristic', 'algebraically', 'deficiency', 'single', 'field', 'scalar', 'close'}
# Max Signature:  {'nail', 'region', 'water', 'lack', 'insight', 'unavailable', 'desert', 'deficiency', 'serious', 'lose', 'problem', 'absent', 'critical', 'shoe'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('lack.n.01')
# Senso Target:  Lemma('lack.n.01.deficiency')
# ------------------------------
# Parola da disambiguare:  directly
# Frase in cui compare la parola:  Says Wallace F. Jannsen , director of the FDA 's Division of Public Information : `` Quacks are apt to direct their appeal directly to older people , or to sufferers from chronic ailments such as arthritis , rheumatism , diabetes , and cancer .
# Contesto della frase:  {'people', 'rheumatism', 'older', 'apt', 'appeal', 'public', 'diabetes', 'division', 'direct', 'cancer', 'jannsen', 'sufferer', 'directly', 'arthritis', 'quacks', 'wallace', 'chronic', 'fda', 'ailment', 'director'}
# Max Signature:  {'direct', 'office', 'lake', 'directly', 'deviation', 'lead', 'path'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('directly.r.01')
# Senso Target:  Lemma('directly.r.01.directly')
# ------------------------------
# Parola da disambiguare:  cancer
# Frase in cui compare la parola:  `` You did n't tell me I had cancer '' .
# Contesto della frase:  {'nt', 'cancer'}
# Max Signature:  {'sun', 'person', 'bear', 'cancer', 'astrology'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('cancer.n.02')
# Senso Target:  Lemma('cancer.n.01.cancer')
# ------------------------------
# Parola da disambiguare:  example
# Frase in cui compare la parola:  Perhaps the most illuminating example of the reduction of fear through understanding is derived from our increased knowledge of the nature of disease .
# Contesto della frase:  {'derive', 'example', 'disease', 'increased', 'illuminating', 'nature', 'reduction', 'knowledge', 'understanding', 'fear'}
# Max Signature:  {'develop', 'work', 'chapter', 'perform', 'solve', 'order', 'skill', 'task', 'problem', 'textbook', 'understanding', 'example'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('exercise.n.04')
# Senso Target:  Lemma('model.n.07.example')
# ------------------------------
# Parola da disambiguare:  Wherefore
# Frase in cui compare la parola:  `` Wherefore also He [ God ] drove him [ man ] out of Paradise , and removed him far from the tree of life , not because He envied him the tree of life , as some venture to assert , but because He pitied him , [ and did not desire ] that he should continue a sinner for ever , nor that the sin which surrounded him should be immortal , and evil interminable and irremediable .
# Contesto della frase:  {'life', 'paradise', 'sin', 'evil', 'drive', 'surround', 'wherefore', 'man', 'remove', 'assert', 'irremediable', 'pity', 'envy', 'interminable', 'tree', 'venture', 'sinner', 'god', 'immortal', 'continue', 'desire'}
# Max Signature:  {'wherefore', 'phrase', 'underlie', 'situation', 'action', 'intention'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('why.n.01')
# Senso Target:  wherefore.r.00
# ------------------------------
# Parola da disambiguare:  carefree
# Frase in cui compare la parola:  The season , between spring and summer , belongs to life in its carefree aspect .
# Contesto della frase:  {'life', 'summer', 'aspect', 'belongs', 'season', 'carefree', 'spring'}
# Max Signature:  {'childhood', 'financially', 'joy', 'untroubled', 'free', 'care', 'carefree', 'trouble', 'worry', 'millionaire'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('carefree.s.01')
# Senso Target:  Lemma('carefree.s.01.carefree')
# ------------------------------
# Parola da disambiguare:  person
# Frase in cui compare la parola:  It seems clear , when one takes into consideration the exceedingly defective eyesight of the patient ( we shall describe it in detail in connection with our second question , the one concerning the psychical blindness of the patient ) , that he had to rely on his sense of touch much more than the usual portfolio maker and that consequently that faculty was most probably more sensitive to shape and size than that of a person with normal vision .
# Contesto della frase:  {'psychical', 'exceedingly', 'eyesight', 'blindness', 'defective', 'clear', 'question', 'patient', 'rely', 'connection', 'usual', 'maker', 'portfolio', 'shape', 'sense', 'normal', 'size', 'consequently', 'touch', 'sensitive', 'vision', 'person', 'second', 'consideration', 'concern', 'describe', 'faculty', 'detail'}
# Max Signature:  {'human', 'person'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('person.n.01')
# Senso Target:  Lemma('person.n.01.person')
# ------------------------------
# Parola da disambiguare:  edge
# Frase in cui compare la parola:  At State College , he had no time to walk among the violets on the water 's edge .
# Contesto della frase:  {'violet', 'time', 'water', 'walk', 'college', 'edge'}
# Max Signature:  {'place', 'water', 'sit', 'center', 'farthest', 'wavy', 'limit', 'area', 'leaf', 'surface', 'bed', 'object', 'edge'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('edge.n.06')
# Senso Target:  Lemma('edge.n.01.edge')
# ------------------------------
# Parola da disambiguare:  supernatural
# Frase in cui compare la parola:  Religion has its own supernatural prescriptions that are at the same time codes of behavior for the here and now .
# Contesto della frase:  {'time', 'supernatural', 'religion', 'prescription', 'code', 'behavior'}
# Max Signature:  {'force', 'supernatural', 'collectively', 'event', 'doesnt'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('supernatural.n.01')
# Senso Target:  Lemma('supernatural.a.01.supernatural')
# ------------------------------
# Parola da disambiguare:  funds
# Frase in cui compare la parola:  Rep. Mac Barber of Commerce is asking the House in a privilege resolution to `` endorse increased federal support for public education , provided that such funds be received and expended '' as state funds .
# Contesto della frase:  {'commerce', 'privilege', 'resolution', 'education', 'increased', 'expend', 'house', 'rep', 'barber', 'public', 'mac', 'endorse', 'provide', 'receive', 'support', 'federal', 'fund'}
# Max Signature:  {'interest', 'provide', 'redemption', 'principal', 'payment', 'fund'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('fund.v.03')
# Senso Target:  Lemma('fund.n.01.fund')
# ------------------------------
# Parola da disambiguare:  weaknesses
# Frase in cui compare la parola:  What are your weaknesses ?
# Contesto della frase:  {'weakness'}
# Max Signature:  {'reveal', 'group', 'powerlessness', 'remain', 'weakness', 'inability', 'spite', 'active'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('helplessness.n.01')
# Senso Target:  Lemma('failing.n.01.weakness')
# ------------------------------
# Parola da disambiguare:  Bishop
# Frase in cui compare la parola:  The Bishop looked at him coldly and said `` Take it or leave it '' !
# Contesto della frase:  {'coldly', 'leave', 'bishop'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('bishop.n.01')
# Senso Target:  Lemma('bishop.n.01.bishop')
# ------------------------------
# Parola da disambiguare:  number
# Frase in cui compare la parola:  Here the number of trials is a random variable , not a fixed number .
# Contesto della frase:  {'number', 'fixed', 'trial', 'random', 'variable'}
# Max Signature:  {'unit', 'sum', 'individual', 'figure', 'indefinite', 'property', 'number', 'parameter', 'small', 'quantity', 'chore', 'total', 'possess'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('number.n.01')
# Senso Target:  Lemma('number.n.01.number')
# ------------------------------
# Parola da disambiguare:  urged
# Frase in cui compare la parola:  It urged that the city `` take steps to remedy '' this problem .
# Contesto della frase:  {'city', 'remedy', 'urge', 'step', 'problem'}
# Max Signature:  {'direction', 'force', 'study', 'urge', 'indicated', 'finish', 'impel'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('urge.v.01')
# Senso Target:  Lemma('urge.v.01.urge')
# ------------------------------
# Parola da disambiguare:  side
# Frase in cui compare la parola:  Suspecting an ambush , the two deputies decided to ride up a side canyon taking a short cut into Catskill .
# Contesto della frase:  {'cut', 'decide', 'side', 'ambush', 'short', 'suspecting', 'catskill', 'ride', 'canyon', 'deputy'}
# Max Signature:  {'place', 'region', 'church', 'side', 'center', 'relative', 'sit', 'identify', 'reference', 'leave', 'location'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('side.n.01')
# Senso Target:  side.s.00
# ------------------------------
# Parola da disambiguare:  indicated
# Frase in cui compare la parola:  A single 24 - hr composite sample indicated that the sewage flow pattern and characteristics were typical .
# Contesto della frase:  {'indicate', 'characteristic', 'flow', 'hr', 'composite', 'sample', 'single', 'sewage', 'pattern', 'typical'}
# Max Signature:  {'indicate', 'severe', 'signal', 'indicator', 'illness', 'economic', 'undervalue', 'serious', 'point', 'euro', 'neurosis', 'behavior', 'symptom'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('bespeak.v.01')
# Senso Target:  Lemma('indicate.v.02.indicate')
# ------------------------------
# Parola da disambiguare:  yawning
# Frase in cui compare la parola:  Somewhere , beyond , where shadows lurked , must be the yawning pit of which Papa preached and the dreadful Lake of Fire .
# Contesto della frase:  {'dreadful', 'shadows', 'fire', 'preach', 'lake', 'papa', 'yawn', 'lurk', 'pit'}
# Max Signature:  {'open', 'suppress', 'time', 'intake', 'wide', 'mouth', 'audience', 'yawning', 'apologize', 'fatigue', 'oscitancy', 'involuntary', 'yawn', 'boredom', 'breath', 'trigger'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('yawn.n.01')
# Senso Target:  Lemma('yawning.s.01.yawning')
# ------------------------------
# Parola da disambiguare:  universal
# Frase in cui compare la parola:  This and other fears of the solar system have disappeared gradually , first , with the Ptolemaic system and its built-in concept of periodicity and then , more firmly , with the Newtonian innovation of an universal force that could account quantitatively for both terrestrial and celestial motions .
# Contesto della frase:  {'motion', 'newtonian', 'concept', 'disappear', 'terrestrial', 'quantitatively', 'fear', 'account', 'universal', 'celestial', 'solar', 'firmly', 'ptolemaic', 'force', 'system', 'builtin', 'gradually', 'periodicity', 'innovation'}
# Max Signature:  {'member', 'characteristic', 'universal', 'religion', 'culture', 'convention', 'behavioral', 'pattern', 'form', 'human'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('universal.n.03')
# Senso Target:  Lemma('cosmopolitan.s.03.universal')
# ------------------------------
# Parola da disambiguare:  unearth
# Frase in cui compare la parola:  Both parties and the Ministry of the Interior were busily at work after the elections trying to unearth the political affiliations of the successful candidates and , thereby , give the elections a confidential but known degree of national political significance .
# Contesto della frase:  {'election', 'political', 'significance', 'affiliation', 'successful', 'candidate', 'party', 'national', 'confidential', 'work', 'busily', 'interior', 'degree', 'ministry', 'unearth'}
# Max Signature:  {'cia', 'plot', 'bring', 'president', 'light', 'kill', 'unearth'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('unearth.v.01')
# Senso Target:  Lemma('unearth.v.01.unearth')
# ------------------------------
# Parola da disambiguare:  fourth
# Frase in cui compare la parola:  The Birds got five hits and all three of their runs off Kunkel before Hartman took over in the top of the fourth .
# Contesto della frase:  {'top', 'kunkel', 'birds', 'hit', 'fourth', 'hartman'}
# Max Signature:  {'place', 'fourthly', 'month', 'fourth', 'rent', 'pay'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('fourthly.r.01')
# Senso Target:  Lemma('fourth.s.01.fourth')
# ------------------------------
# Parola da disambiguare:  public
# Frase in cui compare la parola:  The West Texan reported that he had finally gotten Chairman Bill Hollowell of the committee to set it for public hearing on Feb. 22 .
# Contesto della frase:  {'feb', 'finally', 'committee', 'hearing', 'texan', 'public', 'chairman', 'hollowell', 'bill', 'report', 'set', 'west'}
# Max Signature:  {'general', 'people', 'eye', 'hero', 'public', 'consider'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('populace.n.01')
# Senso Target:  Lemma('public.a.01.public')
# ------------------------------
# Parola da disambiguare:  urged
# Frase in cui compare la parola:  He urged her to buy one of his machines - for $ 300 .
# Contesto della frase:  {'urge', 'buy', 'machine'}
# Max Signature:  {'direction', 'force', 'study', 'urge', 'indicated', 'finish', 'impel'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('urge.v.01')
# Senso Target:  Lemma('urge.v.01.urge')
# ------------------------------
# Parola da disambiguare:  deny
# Frase in cui compare la parola:  There is much truth in both these charges , and not many Bourbons deny them .
# Contesto della frase:  {'truth', 'deny', 'bourbons', 'charge'}
# Max Signature:  {'contradict', 'deny', 'allegation', 'declare', 'untrue', 'money'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('deny.v.01')
# Senso Target:  Lemma('deny.v.01.deny')
# ------------------------------
# Parola da disambiguare:  restricted
# Frase in cui compare la parola:  Other than this very significant result , most of the information now available about the radio emission of the planets is restricted to the intensity of the radiation .
# Contesto della frase:  {'emission', 'radiation', 'restrict', 'radio', 'result', 'intensity', 'planet'}
# Max Signature:  {'place', 'access', 'time', 'friend', 'extent', 'limit', 'restrict', 'lot', 'parking', 'spend'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('restrict.v.03')
# Senso Target:  Lemma('restrict.v.01.restrict')
# ------------------------------
# Parola da disambiguare:  years
# Frase in cui compare la parola:  If the change , at first sight , seems minor , we may recall that it took the Italian painters about two hundred years to make an analogous change , and the Italian painters , by universal consent , were the most brilliant group of geniuses any art has seen .
# Contesto della frase:  {'universal', 'group', 'consent', 'painter', 'art', 'change', 'genius', 'sight', 'analogous', 'brilliant', 'minor', 'italian', 'recall', 'year'}
# Max Signature:  {'life', 'time', 'late', 'sissy', 'eld', 'age', 'geezerhood', 'hasnt', 'slow', 'beard', 'white', 'brink', 'year'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('old_age.n.01')
# Senso Target:  Lemma('year.n.01.year')
# ------------------------------
# Parola da disambiguare:  likewise
# Frase in cui compare la parola:  The shock therapies act likewise on the hypothalamic balance .
# Contesto della frase:  {'shock', 'balance', 'therapy', 'hypothalamic', 'likewise'}
# Max Signature:  {'people', 'strength', 'resist', 'manner', 'samuel', 'good', 'power', 'johnson', 'evil', 'likewise'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('similarly.r.01')
# Senso Target:  Lemma('besides.r.02.likewise')
# ------------------------------
# Parola da disambiguare:  church
# Frase in cui compare la parola:  It has been my experience to find as many men as women in church , and to hear almost everyone in church congregations reciting the Latin prayers and responses at Mass .
# Contesto della frase:  {'church', 'congregation', 'experience', 'find', 'mass', 'woman', 'prayer', 'hear', 'latin', 'men', 'recite', 'response'}
# Max Signature:  {'church', 'perform', 'childbirth', 'woman', 'service', 'special', 'rite'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('church.v.01')
# Senso Target:  Lemma('church.n.02.church')
# ------------------------------
# Parola da disambiguare:  exactly
# Frase in cui compare la parola:  The engineering provides exactly the support needed for such a result .
# Contesto della frase:  {'exactly', 'engineering', 'provide', 'result', 'support'}
# Max Signature:  {'indicate', 'exactly', 'saidthe', 'jewel', 'salt', 'exactness', 'precisely', 'preciseness'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('precisely.r.01')
# Senso Target:  Lemma('precisely.r.01.exactly')
# ------------------------------
# Parola da disambiguare:  appeared
# Frase in cui compare la parola:  It appeared that the theory could be saved in one way only .
# Contesto della frase:  {'appear', 'save', 'theory'}
# Max Signature:  {'appear', 'people', 'impression', 'time', 'difficult', 'aspect', 'sleep', 'fishy', 'outward', 'eat', 'problem', 'project', 'long'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('look.v.02')
# Senso Target:  Lemma('appear.v.04.appear')
# ------------------------------
# Parola da disambiguare:  mother
# Frase in cui compare la parola:  His mother was nudging him , but he was still falling .
# Contesto della frase:  {'fall', 'mother', 'nudge'}
# Max Signature:  {'term', 'mother', 'woman', 'child', 'address', 'birth'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('mother.n.01')
# Senso Target:  Lemma('mother.n.01.mother')
# ------------------------------
# Parola da disambiguare:  help
# Frase in cui compare la parola:  This would help the little peanut districts '' .
# Contesto della frase:  {'district', 'peanut', 'help'}
# Max Signature:  {'unload', 'housework', 'offer', 'aid', 'effort', 'help', 'fulfillment', 'activity', 'contribute', 'walk', 'assistance', 'party', 'assist', 'rescue', 'furtherance', 'purpose'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('aid.n.02')
# Senso Target:  Lemma('help.v.02.help')
# ------------------------------
# Parola da disambiguare:  algebraically
# Frase in cui compare la parola:  First , T may not have a single characteristic value ; this is really a deficiency in the scalar field , namely , that it is not algebraically closed .
# Contesto della frase:  {'characteristic', 'algebraically', 'deficiency', 'single', 'field', 'scalar', 'close'}
# Max Signature:  {'determine', 'algebraically', 'algebraic', 'manner'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('algebraically.r.01')
# Senso Target:  Lemma('algebraically.r.01.algebraically')
# ------------------------------
# Parola da disambiguare:  sat
# Frase in cui compare la parola:  There the objective sat , brooding over all .
# Contesto della frase:  {'objective', 'brooding', 'sat'}
# Max Signature:  {'sat', 'sit', 'chat', 'purpose', 'hour', 'specific', 'idly', 'object', 'corner'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('sit.v.02')
# Senso Target:  Lemma('sit.v.02.sit')
# ------------------------------
# Parola da disambiguare:  therapeutic
# Frase in cui compare la parola:  But it is our health - more precious than all the money in the world - that these modern witch doctors with their fake therapeutic gadgets are gambling away .
# Contesto della frase:  {'modern', 'health', 'therapeutic', 'fake', 'gadget', 'doctor', 'gamble', 'precious', 'witch', 'money'}
# ...
# Senso Target:  Lemma('dead.a.01.dead')
# ------------------------------
# Parola da disambiguare:  arm
# Frase in cui compare la parola:  With a bold arm , he dared once more to obstruct them .
# Contesto della frase:  {'dare', 'arm', 'obstruct', 'bold'}
# Max Signature:  {'arm', 'projection', 'resemble', 'record', 'sewer', 'sea', 'player', 'human', 'branch'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('arm.n.02')
# Senso Target:  Lemma('arm.n.01.arm')
# ------------------------------
# Parola da disambiguare:  Oriental
# Frase in cui compare la parola:  He observed the Florentine vase in the hall , the Renoir painting in the library , as well as the long shelves of well-bound volumes ; the pattern of the Oriental rug , the delicate cut-glass chandelier .
# Contesto della frase:  {'rug', 'shelf', 'oriental', 'wellbound', 'observe', 'chandelier', 'painting', 'volumes', 'delicate', 'florentine', 'cutglass', 'hall', 'renoir', 'library', 'pattern', 'vase', 'well', 'long'}
# Max Signature:  {'asian', 'oriental', 'offensive', 'member', 'term', 'race', 'americans', 'asians', 'regard'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('oriental.n.01')
# Senso Target:  Lemma('oriental.s.01.oriental')
# ------------------------------
# Parola da disambiguare:  depicted
# Frase in cui compare la parola:  These areas by virtue of their abrupt density of pattern , stated the literal surface with such new and superior force that the resulting contrast drove the simulated printing into a depth from which it could be rescued - and set to shuttling again - only by conventional perspective ; that is , by being placed in such relation to the forms depicted within the illusion that these forms left no room for the typography except near the surface .
# Contesto della frase:  {'typography', 'abrupt', 'relation', 'depth', 'contrast', 'pattern', 'illusion', 'form', 'drive', 'place', 'shuttle', 'virtue', 'simulated', 'rescue', 'set', 'perspective', 'literal', 'force', 'printing', 'area', 'room', 'result', 'depict', 'superior', 'conventional', 'surface', 'leave', 'density'}
# Max Signature:  {'render', 'life', 'picture', 'painting', 'country', 'tenderness', 'child', 'face', 'scene', 'depict'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('picture.v.02')
# Senso Target:  Lemma('picture.v.02.depict')
# ------------------------------
# Parola da disambiguare:  Severe
# Frase in cui compare la parola:  Severe back pain in June , 1959 , prompted a third hospital admission .
# Contesto della frase:  {'severe', 'june', 'third', 'admission', 'prompt', 'hospital', 'pain'}
# Max Signature:  {'unpleasant', 'severe', 'pain', 'cough', 'fire', 'wicked', 'gun', 'enemy', 'intensely', 'flu', 'quality', 'degree', 'case', 'extremely', 'terrible', 'bad'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('severe.s.01')
# Senso Target:  Lemma('severe.s.01.severe')
# ------------------------------
# Parola da disambiguare:  number
# Frase in cui compare la parola:  As the temperature decreased , the number of free swimming ciliated protozoa decreased .
# Contesto della frase:  {'swimming', 'protozoa', 'number', 'free', 'temperature', 'decrease', 'ciliated'}
# Max Signature:  {'unit', 'sum', 'individual', 'figure', 'indefinite', 'property', 'number', 'parameter', 'small', 'quantity', 'chore', 'total', 'possess'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('number.n.01')
# Senso Target:  Lemma('number.n.02.number')
# ------------------------------
# Parola da disambiguare:  thing
# Frase in cui compare la parola:  In the end , however , the thing about this performance that is most striking is the way it sings .
# Contesto della frase:  {'thing', 'striking', 'performance', 'sing'}
# Max Signature:  {'thing', 'special', 'remarkable', 'situation'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('thing.n.01')
# Senso Target:  Lemma('thing.n.09.thing')
# ------------------------------
# Parola da disambiguare:  forgotten
# Frase in cui compare la parola:  By the time he was under the covers he had forgotten about seeing Kate .
# Contesto della frase:  {'time', 'cover', 'forget', 'kate'}
# Max Signature:  {'forget', 'chairman', 'dont', 'board', 'meeting', 'call'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('forget.v.03')
# Senso Target:  Lemma('forget.v.03.forget')
# ------------------------------
# Parola da disambiguare:  wide
# Frase in cui compare la parola:  Catcher Frank House 's throw in an effort to nab Throneberry was wide and in the dirt .
# Contesto della frase:  {'nab', 'wide', 'effort', 'catcher', 'throw', 'house', 'frank', 'throneberry', 'dirt'}
# Max Signature:  {'broad', 'road', 'wide', 'side', 'extent', 'great', 'necktie', 'mile', 'foot', 'margin', 'river', 'shoulder'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('wide.a.01')
# Senso Target:  Lemma('wide.a.01.wide')
# ------------------------------
# Parola da disambiguare:  hands
# Frase in cui compare la parola:  Try to push back to the stand position from the stretched position without any intermediate pushes from the hands .
# Contesto della frase:  {'stand', 'intermediate', 'position', 'hand', 'push', 'stretched'}
# Max Signature:  {'side', 'object', 'voice', 'position', 'objection', 'hand', 'location'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('hand.n.05')
# Senso Target:  Lemma('hand.n.01.hand')
# ------------------------------
# Parola da disambiguare:  stage
# Frase in cui compare la parola:  At what stage are social sciences then ?
# Contesto della frase:  {'social', 'science', 'stage'}
# Max Signature:  {'science', 'stage', 'social', 'series', 'identifiable', 'process', 'frankness', 'remarkable', 'position', 'specific', 'degree', 'continuum'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('degree.n.02')
# Senso Target:  Lemma('degree.n.02.stage')
# ------------------------------
# Parola da disambiguare:  conditions
# Frase in cui compare la parola:  Where does one find such conditions ?
# Contesto della frase:  {'find', 'condition'}
# Max Signature:  {'condition', 'variation', 'wide', 'influence', 'context', 'outcome', 'process', 'performance', 'observation', 'prevailing'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('conditions.n.01')
# Senso Target:  Lemma('condition.n.01.condition')
# ------------------------------
# Parola da disambiguare:  difficult
# Frase in cui compare la parola:  Hence it is difficult to conceive of a packing of the atoms in this material in which the oxygen atoms are far from geometrical equivalence .
# Contesto della frase:  {'geometrical', 'atom', 'equivalence', 'material', 'difficult', 'conceive', 'packing', 'oxygen'}
# Max Signature:  {'access', 'place', 'time', 'effort', 'hard', 'require', 'endure', 'difficult', 'great', 'physical', 'accomplish', 'comprehend', 'nest', 'secret', 'easy', 'task', 'cliff', 'mental'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('difficult.a.01')
# Senso Target:  Lemma('difficult.a.01.difficult')
# ------------------------------
# Parola da disambiguare:  data
# Frase in cui compare la parola:  Its value was * * f from the above data .
# Contesto della frase:  {'data'}
# Max Signature:  {'data', 'draw', 'statistical', 'conclusion', 'fact', 'collection'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('data.n.01')
# Senso Target:  Lemma('data.n.01.data')
# ------------------------------
# Parola da disambiguare:  vigorous
# Frase in cui compare la parola:  And the evidence that he does , indeed , stand there derives quite simply from the vigorous interest with which rather casual readers have responded to that book for the past century or so .
# Contesto della frase:  {'derive', 'reader', 'century', 'respond', 'book', 'stand', 'interest', 'evidence', 'casual', 'vigorous', 'simply'}
# Max Signature:  {'energetic', 'hiker', 'war', 'shake', 'activity', 'foreign', 'forceful', 'campaign', 'policy', 'opposition', 'skirt', 'vigorous', 'characterize', 'action'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('vigorous.s.01')
# Senso Target:  Lemma('vigorous.s.01.vigorous')
# ------------------------------
# Parola da disambiguare:  began
# Frase in cui compare la parola:  He had never heard the word reactionary before his life as a POW began .
# Contesto della frase:  {'life', 'pow', 'hear', 'reactionary', 'word'}
# Max Signature:  {'war', 'hostility', 'life', 'motion', 'chapter', 'east', 'start', 'middle', 'set', 'iraqis'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('begin.v.03')
# Senso Target:  Lemma('get_down.v.07.begin')
# ------------------------------
# Parola da disambiguare:  well-kept
# Frase in cui compare la parola:  On the other side of the church was a quiet , well-kept house with shutters and recently painted .
# Contesto della frase:  {'shutter', 'church', 'side', 'paint', 'wellkept', 'house', 'quiet'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('kept_up.s.01')
# Senso Target:  Lemma('kept_up.s.01.well-kept')
# ------------------------------
# Parola da disambiguare:  year
# Frase in cui compare la parola:  It was Gardner 's second run batted in of the game and his only ones of the year .
# Contesto della frase:  {'second', 'bat', 'game', 'gardner', 'year'}
# Max Signature:  {'period', 'time', 'day', 'year'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('year.n.01')
# Senso Target:  Lemma('year.n.01.year')
# ------------------------------
# Parola da disambiguare:  feel
# Frase in cui compare la parola:  I'm sure all girls feel this way about men until they live with them .
# Contesto della frase:  {'live', 'feel', 'girl', 'men'}
# Max Signature:  {'stimulation', 'feel', 'pleasure', 'sexual', 'area', 'sneak', 'girl', 'manual', 'genital', 'hat'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('feel.n.04')
# Senso Target:  Lemma('find.v.05.feel')
# ------------------------------
# Parola da disambiguare:  small
# Frase in cui compare la parola:  Some liver cord cells contained vacuolated cytoplasm , while others had small amounts of brown hemosiderin pigment .
# Contesto della frase:  {'hemosiderin', 'brown', 'cytoplasm', 'cord', 'small', 'cell', 'amount', 'pigment', 'liver', 'vacuolated'}
# Max Signature:  {'inflation', 'size', 'help', 'salary', 'small', 'sufficient', 'amount', 'modest', 'large'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('modest.s.02')
# Senso Target:  Lemma('minor.s.10.small')
# ------------------------------
# Parola da disambiguare:  stage
# Frase in cui compare la parola:  At what stage are social sciences then ?
# Contesto della frase:  {'social', 'science', 'stage'}
# Max Signature:  {'science', 'stage', 'social', 'series', 'identifiable', 'process', 'frankness', 'remarkable', 'position', 'specific', 'degree', 'continuum'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('degree.n.02')
# Senso Target:  Lemma('degree.n.02.stage')
# ------------------------------
# Parola da disambiguare:  Dallas
# Frase in cui compare la parola:  The Dallas Texans were back home Monday with their third victory in four American Football League starts - a 19 - 12 triumph over the Denver Broncos - but their visit will be a short one .
# Contesto della frase:  {'visit', 'denver', 'broncos', 'triumph', 'short', 'dallas', 'third', 'football', 'league', 'start', 'victory', 'texans', 'american', 'monday'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('dallas.n.01')
# Senso Target:  Lemma('dallas.n.01.Dallas')
# ------------------------------
# Parola da disambiguare:  man
# Frase in cui compare la parola:  Demons , fairies , angels , and a host of other spiritual beings were as much a part of the experiential world of western man as were rocks and trees and stars .
# Contesto della frase:  {'experiential', 'fairy', 'western', 'man', 'rock', 'host', 'star', 'angel', 'spiritual', 'tree', 'demons'}
# Max Signature:  {'generic', 'man', 'refer', 'word', 'human'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('man.n.03')
# Senso Target:  man.n.00
# ------------------------------
# Parola da disambiguare:  carry
# Frase in cui compare la parola:  This he did by using utterly literal means to carry the forward push of the collage ( and of Cubism in general ) literally into the literal space in front of the picture plane .
# Contesto della frase:  {'utterly', 'general', 'picture', 'space', 'literal', 'collage', 'cubism', 'carry', 'plane', 'forward', 'front', 'push', 'literally'}
# Max Signature:  {'carry'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('carry.n.01')
# Senso Target:  Lemma('carry.v.04.carry')
# ------------------------------
# Parola da disambiguare:  move
# Frase in cui compare la parola:  When the patient was not allowed to move his body in any way at all , the following striking results occurred .
# Contesto della frase:  {'patient', 'striking', 'move', 'allow', 'follow', 'occur', 'result', 'body'}
# Max Signature:  {'decide', 'help', 'lawyer', 'move', 'didnt', 'hire'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('move.n.01')
# Senso Target:  Lemma('move.v.03.move')
# ------------------------------
# Parola da disambiguare:  game
# Frase in cui compare la parola:  `` I think the big thing about the game was that our kids for the third straight week stayed in there pitching and kept the pressure on .
# Contesto della frase:  {'week', 'kid', 'straight', 'big', 'third', 'pressure', 'game', 'thing', 'stay', 'pitch'}
# Max Signature:  {'winner', 'contest', 'people', 'determine', 'game', 'rule', 'play'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('game.n.01')
# Senso Target:  Lemma('game.n.02.game')
# ------------------------------
# Parola da disambiguare:  howls
# Frase in cui compare la parola:  Piepsam calls the cyclist `` cur '' and `` puppy '' among other things , and at the crisis of his fit a little fox-terrier stands before him and howls into his face .
# Contesto della frase:  {'fit', 'howl', 'piepsam', 'cur', 'cyclist', 'stand', 'face', 'crisis', 'foxterrier', 'thing', 'puppy', 'call'}
# Max Signature:  {'pain', 'howling', 'laughter', 'emotional', 'loud', 'howl', 'utterance', 'long'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('howl.n.01')
# Senso Target:  Lemma('howl.n.01.howl')
# ------------------------------
# Parola da disambiguare:  word
# Frase in cui compare la parola:  He had no chance to say another word .
# Contesto della frase:  {'word', 'chance'}
# Max Signature:  {'unit', 'sentence', 'morning', 'ten', 'block', 'identify', 'native', 'language', 'word', 'speaker'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('word.n.01')
# Senso Target:  Lemma('word.n.01.word')
# ------------------------------
# Parola da disambiguare:  arterial
# Frase in cui compare la parola:  The volume and , perhaps , even the characteristics of bronchial arterial blood flow might be different in the dog than in the horse .
# Contesto della frase:  {'characteristic', 'arterial', 'flow', 'volume', 'blood', 'horse', 'bronchial', 'dog'}
# Max Signature:  {'arterial', 'artery', 'disease', 'system', 'blood', 'involve'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('arterial.a.01')
# Senso Target:  Lemma('arterial.a.01.arterial')
# ------------------------------
# Parola da disambiguare:  alike
# Frase in cui compare la parola:  Everyone in Salem , saint and sinner alike , is swept up by it .
# Contesto della frase:  {'sinner', 'salem', 'saint', 'alike', 'sweep'}
# Max Signature:  {'characteristic', 'friend', 'alike', 'background', 'generally', 'utterly', 'politician', 'taste'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('alike.a.01')
# Senso Target:  Lemma('alike.r.01.alike')
# ------------------------------
# Parola da disambiguare:  demands
# Frase in cui compare la parola:  The piano performance on this Trout is one that really demands a search for superlatives .
# Contesto della frase:  {'search', 'superlative', 'trout', 'performance', 'piano', 'demand'}
# Max Signature:  {'unceasing', 'request', 'urgent', 'attention', 'demand', 'peremptory'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('demand.n.01')
# Senso Target:  Lemma('necessitate.v.01.demand')
# ------------------------------
# Termini valutati:  51
# Termini valutati correttamente:  27
# Accuratezza:  0.54
#
# Esecuzioni:  10
# Lista delle accuratezze:  [0.38, 0.42, 0.48, 0.42, 0.56, 0.44, 0.54, 0.56, 0.54, 0.54]
# Accuratezza media:  0.488
