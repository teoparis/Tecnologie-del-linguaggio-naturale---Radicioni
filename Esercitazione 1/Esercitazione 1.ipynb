# %%
import re
import enum
import math
import random
import nltk
import csv
import numpy as np
import scipy as sp
from nltk.corpus import wordnet as wn
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import semcor
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from random import randrange
from collections import deque
from statistics import mean

# %% [markdown]
# FUNZIONI DI PREPROCESSING

# %%
#il pre-processing consiste nella tokenizzazione, lemmatizzazione,
#rimozione della punteggiatura e delle stopwords di una sentence
def pre_processing(sentence):
    return set(remove_stopwords(tokenize_sentence(remove_punctuation(sentence))))

#rimuove le stowords da una lista di parole
def remove_stopwords(words_list):
    stopwords_list = get_stopwords()
    return [value.lower() for value in words_list if value.lower() not in stopwords_list]

#Rimuove la punteggiatura da una sentence
#Restituisce la sentence senza punteggiature
def remove_punctuation(sentence):
    return re.sub(r'[^\w\s]','',sentence)

#Tokenizza la frase in input e ne affettua anche la lemmatizzazione della sue parole
def tokenize_sentence(sentence):
    words_list = []
    lmtzr = WordNetLemmatizer()
    for tag in nltk.pos_tag(word_tokenize(sentence)):
        if (tag[1][:2] == "NN"):
            words_list.append(lmtzr.lemmatize(tag[0], pos = wn.NOUN))
        elif (tag[1][:2] == "VB"):
             words_list.append(lmtzr.lemmatize(tag[0], pos = wn.VERB))
        elif (tag[1][:2] == "RB"):
             words_list.append(lmtzr.lemmatize(tag[0], pos = wn.ADV))
        elif (tag[1][:2] == "JJ"):
             words_list.append(lmtzr.lemmatize(tag[0], pos = wn.ADJ))
    return words_list

#Restituisce la l'insieme di stopwords dal file delle stopwords
def get_stopwords():
    stopwords = open("stop_words_FULL.txt", "r")
    stopwords_list = []
    for word in stopwords:
        stopwords_list.append(word.replace('\n', ''))
    stopwords.close()
    return stopwords_list

# %% [markdown]
# FUNZIONI UTILI PER L'ANALISI DEL TESTO

# %%
#Restituisce un sostantivo random presente nel dizionario associato ad una sentence
def get_random_noun(dictionary_tag):
    try:
        sentence_nouns = dictionary_tag['NN']
    except KeyError:
        return None #se non ci sono sostantivi
    noun =  random.choice(sentence_nouns)
    if len(wn.synsets(noun)) == 0:
        return None #se il sostantivo scelto non ha almeno un synset in wordnet
    return noun

#Restituisce una parola random presente nel dizionario associato ad una sentence
def get_random_word(dictionary_tag):
    keys = list(dictionary_tag.keys())
    if not keys:
        return None #se non ci sono parole "analizzabili" nel dizionario, aka se il dizionario è vuoto
    key = random.choice(keys)
    words_list = dictionary_tag[key]
    word = random.choice(words_list)
    if len(wn.synsets(word)) == 0:
        return None #se la parola scelta non ha almeno un synset in wordnet
    return word

#Verifica che una parola abbia un synset target associato
#Senza synset target associato è inutile confrontare l'output dell'algortimo di Lesk
def check_word_synset_target(word,sentence_sem):
    for w in sentence_sem:
        if (type(w) != list):
            if (w[0] == word):
                return True
    return False
    
#Crea un dizionario che ha come chiavi i tag presenti nella sentence e come valori liste di parole associate a quei tag
#e.g {NN: ['home','garden'], VB:['gone'], .....,}
#input: sentence_tag -> rappresenta le words della sentence con i relativi pos tag
#input: sentence_sem -> rappresenta le words della sentence con il relativo synset target associato
def get_dictionary_tag(sentence_tag,sentence_sem):
    dictionary_tag = dict()
    stopwords_list = get_stopwords()
    for word in sentence_tag:
         tag = word.label()
         word = " ".join(l for l in word)
         if check_word_synset_target(word, sentence_sem): #Non inserisco nel dizionario parole che non hanno un synset target
             w = word.lower()
             if w not in stopwords_list and tag: #Non inserisco nel dizionario stopwords o parole che non hanno un pos tag associato
                 if tag in dictionary_tag:
                     dictionary_tag[tag].append(word)
                 else:
                     dictionary_tag[tag] = [word]             
    return dictionary_tag

#Restituisce un indice randomico utile per l'ultimo esercizio
def get_random_index(index_evaluated, INDEXES_NUM):
    while True:
        index = randrange(INDEXES_NUM)
        if index not in index_evaluated:
            return index
    
#Restituisce il synset target per una parola in una sentence
def get_synset_target_for_word_in_sentence(noun,sentence):
     for word in sentence:
      if(type(word) != list):
          if (word[0] == noun):
              return str(word.label())

# %% [markdown]
# METRICHE DI SIMILARITA E ALGORITMI PER LA RICERCA

# %%
#Custom similarity functions
def wu_palmer_similarity(sense1, sense2):
    numerator = 2 * depth(lowest_common_subsumer(sense1,sense2))
    denominator = depth(sense1) + depth(sense2)
    return numerator/denominator

def leakcock_chodorow(sense1, sense2):
    numerator = (shortest_path(sense1, sense2) + 1)
    denominator = (2 * max_depth) + 1
    return -math.log(numerator/denominator)

def shortest_path_similarity(sense1, sense2):
    return ((2 * max_depth) - shortest_path(sense1, sense2))

#Restituisce la similarità tra due parole date in input
def similarity(word1, word2, similarity_function):
    max_sim = 0
    for s1 in wn.synsets(word1):
        for s2 in wn.synsets(word2):
           sim = similarity_function(s1,s2)
           if sim > max_sim:
               max_sim = sim
    return max_sim

#Restituisce la profondità di un senso in wordnet, cioè il massimo percorso dal senso alla radice        
def depth(sense):
    if not sense:
        return 0
    return max([len(path) for path in all_hypernym_paths(sense)])

#Restituisce tutti i percorsi di iperonimi di un senso di wordnet, la ricerca dei percosi viene effettuata in modo ricorsivo
def all_hypernym_paths(sense):
    paths = []
    hypernyms = sense.hypernyms()
    if len(hypernyms) == 0:
        paths = [[sense]]
    for hypernym in hypernyms:
        for ancestor_list in all_hypernym_paths(hypernym):
            ancestor_list.append(sense)
            paths.append(ancestor_list)
    return paths

#Massima profondità intesa come il percorso più lungo degli iperonimi di tutti i sensi presenti in wordnet
max_depth = max(max(len(hyp_path) for hyp_path in all_hypernym_paths(ss)) for ss in wn.all_synsets())

#Restituisce un dizionario di iperonimi del senso in input con la relativa profondità
def min_hypernyms_depth(sense):
    sense_depth_queue = deque([(sense, 0)]) #deque garantisce efficienza nell'inserire ed eliminare elementi sia a destra che a sinistra della coda
    sense_depth_dict = {}
    while sense_depth_queue:
        s, depth = sense_depth_queue.popleft()
        if s in sense_depth_dict:
            continue
        sense_depth_dict[s] = depth
        depth += 1
        sense_depth_queue.extend((hyperonym, depth) for hyperonym in s.hypernyms()) #li mette a destra della coda
    return sense_depth_dict

#restituisce il percorso più breve tra due sensi di wordnet
def shortest_path(sense1,sense2):
    if sense1 == sense2:
        return 0
    dict1 = min_hypernyms_depth(sense1)
    dict2 = min_hypernyms_depth(sense2)
    min_dist = (2 * max_depth) # distanza minima iniziale

    #per ogni senso del dizionario degli iperonimi di sense1 cerca di trovare il match con un senso del secondo dizionario.
    for ss, dist1 in dict1.items():
        dist2 = dict2.get(ss)
        if not dist2:
            dist2 = (2 * max_depth)
        min_dist = min(min_dist, dist1 + dist2) #somma dei due sensi matchati
    return (2 * max_depth) if math.isinf(min_dist) else min_dist

#Restituisce l'antenato comune più vicino di due sensi, cioè l'iperonimo comune più vicino ai due sensi. 
#SCELTA PROGETTUALE: Se ne ho più di uno prendo quello può essere il più profondo rispetto alla radice.
def lowest_common_subsumer(sense1, sense2):
    if sense1 == sense2: return sense1
    
    dict1 = min_hypernyms_depth(sense1)
    dict2 = min_hypernyms_depth(sense2)
    
    min_dist = (2 * max_depth)
    candidates = []
    for ss, dist1 in dict1.items():
        dist2 = dict2.get(ss) 
        if not dist2:
            dist2 = (2 * max_depth)
        else:
            if (dist1 + dist2) <= min_dist:
                min_dist = (dist1 + dist2)
                candidates.append(ss) 
    if candidates:
        deepest = candidates[0]
        for sense in candidates:
            if depth(sense) < depth(deepest):
                deepest = sense
        return deepest #restituisce il senso con profondità maggiore rispetto alla radice

#Classe enum con la quale specifichiamo il tipo di similarità utilizzata
class Similarity_Type(enum.Enum):
    wu_palmer_similarity = 1
    shortest_path = 2
    leakcock_chodorow = 3

# %% [markdown]
# Word sense disambiguation è il processo con il quale si precisa il significato di una parola o di un insieme di parole (frase), che denota significati diversi a seconda dei contesti, per evitare che sia ambigua.

# %%
#Algoritmo di Lesk
def lesk_algorithm(word, sentence, word_type):
    best_sense = wn.synsets(word)[0]
    max_overlap = 0
    max_signature = []
    print("Frase in cui compare la parola: ", sentence)
    context = pre_processing(sentence)
    
    #se il tipo di parola è un nome allora cerco solo tra i nomi in wordnet
    #altrimenti prendo tutti i synset associati a quel termine
    if word_type == 'NOUN':
        synsets = wn.synsets(word, pos=wn.NOUN)
    elif word_type == 'ALL':
        synsets = wn.synsets(word)
        
    for sense in synsets:
        signature = get_signature(sense)
        overlap = len(list(signature & context)) #overlap
        if overlap > max_overlap:
            max_overlap = overlap
            best_sense = sense
            max_signature = signature
            
    print("Contesto della frase: ", context)
    print("Max Signature: ", max_signature) #signature del senso con più overlap con il contesto della sentence
    return best_sense

#Signature di un senso di WordNet
def get_signature(sense):
    signature = set()
    for word in pre_processing(sense.definition()): #tokenizzo la definizione del synset
        signature.add(word)
    for example in sense.examples(): #tokenizzo ogni esempio del synset
        for word in pre_processing(example):
            signature.add(word)
    return signature #la signature conterrà tutte le parole presenti nella definizione del senso e negli esempi

# %% [markdown]
# CONSEGNA 1:
#
# L'esercitazione consiste nell'implementare tre misure di similarità basate su WordNet.
#
# Per ciascuna di tali misure di similarità, calcolare gli indici di
# correlazione di Spearman and gli indici di correlazione di Pearson
# fra i risultati ottenuti e quelli ‘target’ presenti nel file annotato.

# %%
def main():

    #scelta della metrica da utilizzare per il calcolo della similarità
    
    similarity_type = Similarity_Type.leakcock_chodorow
    #similarity_type = Similarity_Type.wu_palmer_similarity
    #similarity_type = Similarity_Type.shortest_path
    
    with open('WordSim353.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        assignments = []
        targets = []
        line_count = 0
        for row in csv_reader:
            if line_count > 0:
                print("Word1: ",row[0])
                print("Word2: ",row[1])
                sim = 0
                if similarity_type.value == 1:
                    sim = similarity(row[0], row[1], wu_palmer_similarity)
                elif similarity_type.value == 2:
                    sim = similarity(row[0], row[1], shortest_path_similarity)
                elif similarity_type.value == 3:
                    sim = similarity(row[0], row[1], leakcock_chodorow)
                print("Type of similarity chosen: ", similarity_type.name)
                print("MyCustom Similarity: ",sim)
                print("Human Similarity: ",row[2])
                assignments.append(sim)
                targets.append(float(row[2]))
                print("------------------------------")
            line_count = line_count + 1
            
    print("Pearson Correlation: ", np.corrcoef(assignments, targets))
    print("Spearman Correlation: ", sp.stats.spearmanr(assignments, targets))
main()
# Out:
# Word1:  love
# Word2:  sex
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  6.77
# ------------------------------
# Word1:  tiger
# Word2:  cat
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.35
# ------------------------------
# Word1:  tiger
# Word2:  tiger
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# Human Similarity:  10.00
# ------------------------------
# Word1:  book
# Word2:  paper
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  7.46
# ------------------------------
# Word1:  computer
# Word2:  keyboard
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.62
# ------------------------------
# Word1:  computer
# Word2:  internet
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  7.58
# ------------------------------
# Word1:  plane
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  5.77
# ------------------------------
# Word1:  train
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.31
# ------------------------------
# Word1:  telephone
# Word2:  communication
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  7.50
# ------------------------------
# Word1:  television
# Word2:  radio
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  6.77
# ------------------------------
# Word1:  media
# Word2:  radio
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.42
# ------------------------------
# Word1:  drug
# Word2:  abuse
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  6.85
# ------------------------------
# Word1:  bread
# Word2:  butter
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  6.19
# ------------------------------
# Word1:  cucumber
# Word2:  potato
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  5.92
# ------------------------------
# Word1:  doctor
# Word2:  nurse
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  7.00
# ------------------------------
# Word1:  professor
# Word2:  doctor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  6.62
# ------------------------------
# Word1:  student
# Word2:  professor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  6.81
# ------------------------------
# Word1:  smart
# Word2:  student
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  4.62
# ------------------------------
# Word1:  smart
# Word2:  stupid
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  5.81
# ------------------------------
# Word1:  company
# Word2:  stock
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  7.08
# ------------------------------
# Word1:  stock
# Word2:  market
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  8.08
# ------------------------------
# Word1:  stock
# Word2:  phone
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  1.62
# ------------------------------
# Word1:  stock
# Word2:  CD
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  1.31
# ------------------------------
# Word1:  stock
# Word2:  jaguar
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  0.92
# ------------------------------
# Word1:  stock
# Word2:  egg
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  1.81
# ------------------------------
# Word1:  fertility
# Word2:  egg
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  6.69
# ------------------------------
# Word1:  stock
# Word2:  live
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  3.73
# ------------------------------
# Word1:  stock
# Word2:  life
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  0.92
# ------------------------------
# Word1:  book
# Word2:  library
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  7.46
# ------------------------------
# Word1:  bank
# Word2:  money
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  8.12
# ------------------------------
# Word1:  wood
# Word2:  forest
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# Human Similarity:  7.73
# ------------------------------
# Word1:  money
# Word2:  cash
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  9.15
# ------------------------------
# Word1:  professor
# Word2:  cucumber
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  0.31
# ------------------------------
# Word1:  king
# Word2:  cabbage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  0.23
# ------------------------------
# Word1:  king
# Word2:  queen
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# Human Similarity:  8.58
# ------------------------------
# Word1:  king
# Word2:  rook
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  5.92
# ------------------------------
# Word1:  bishop
# Word2:  rabbi
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  6.69
# ------------------------------
# Word1:  Jerusalem
# Word2:  Israel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  8.46
# ------------------------------
# Word1:  Jerusalem
# Word2:  Palestinian
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  7.65
# ------------------------------
# Word1:  holy
# Word2:  sex
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  1.62
# ------------------------------
# Word1:  fuck
# Word2:  sex
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  9.44
# ------------------------------
# Word1:  Maradona
# Word2:  football
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  8.62
# ------------------------------
# Word1:  football
# Word2:  soccer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# Human Similarity:  9.03
# ------------------------------
# Word1:  football
# Word2:  basketball
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  6.81
# ------------------------------
# Word1:  football
# Word2:  tennis
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.63
# ------------------------------
# Word1:  tennis
# Word2:  racket
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  7.56
# ------------------------------
# Word1:  Arafat
# Word2:  peace
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  6.73
# ------------------------------
# Word1:  Arafat
# Word2:  terror
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  7.65
# ------------------------------
# Word1:  Arafat
# Word2:  Jackson
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  2.50
# ------------------------------
# Word1:  law
# Word2:  lawyer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  8.38
# ------------------------------
# Word1:  movie
# Word2:  star
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  7.38
# ------------------------------
# Word1:  movie
# Word2:  popcorn
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  6.19
# ------------------------------
# Word1:  movie
# Word2:  critic
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  6.73
# ------------------------------
# Word1:  movie
# Word2:  theater
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  7.92
# ------------------------------
# Word1:  physics
# Word2:  proton
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.0055218656020977
# Human Similarity:  8.12
# ------------------------------
# Word1:  physics
# Word2:  chemistry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  7.35
# ------------------------------
# Word1:  space
# Word2:  chemistry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  4.88
# ------------------------------
# Word1:  alcohol
# Word2:  chemistry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  5.54
# ------------------------------
# Word1:  vodka
# Word2:  gin
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  8.46
# ------------------------------
# Word1:  vodka
# Word2:  brandy
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  8.13
# ------------------------------
# Word1:  drink
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  3.04
# ------------------------------
# Word1:  drink
# Word2:  ear
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  1.31
# ------------------------------
# Word1:  drink
# Word2:  mouth
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  5.96
# ------------------------------
# Word1:  drink
# Word2:  eat
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  6.87
# ------------------------------
# Word1:  baby
# Word2:  mother
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  7.85
# ------------------------------
# Word1:  drink
# Word2:  mother
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  2.65
# ------------------------------
# Word1:  car
# Word2:  automobile
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# Human Similarity:  8.94
# ------------------------------
# Word1:  gem
# Word2:  jewel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# Human Similarity:  8.96
# ------------------------------
# Word1:  journey
# Word2:  voyage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# Human Similarity:  9.29
# ------------------------------
# Word1:  boy
# Word2:  lad
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# Human Similarity:  8.83
# ------------------------------
# Word1:  coast
# Word2:  shore
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  9.10
# ------------------------------
# Word1:  asylum
# Word2:  madhouse
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# Human Similarity:  8.87
# ------------------------------
# Word1:  magician
# Word2:  wizard
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# Human Similarity:  9.02
# ------------------------------
# Word1:  midday
# Word2:  noon
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# Human Similarity:  9.29
# ------------------------------
# Word1:  furnace
# Word2:  stove
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  8.79
# ------------------------------
# Word1:  food
# Word2:  fruit
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  7.52
# ------------------------------
# Word1:  bird
# Word2:  cock
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# Human Similarity:  7.10
# ------------------------------
# Word1:  bird
# Word2:  crane
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.38
# ------------------------------
# Word1:  tool
# Word2:  implement
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  6.46
# ------------------------------
# Word1:  brother
# Word2:  monk
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  6.27
# ------------------------------
# Word1:  crane
# Word2:  implement
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  2.69
# ------------------------------
# Word1:  lad
# Word2:  brother
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  4.46
# ------------------------------
# Word1:  journey
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0.8232003088081431
# Human Similarity:  5.85
# ------------------------------
# Word1:  monk
# Word2:  oracle
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  5.00
# ------------------------------
# Word1:  cemetery
# Word2:  woodland
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  2.08
# ------------------------------
# Word1:  food
# Word2:  rooster
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0.9409833444645266
# Human Similarity:  4.42
# ------------------------------
# Word1:  coast
# Word2:  hill
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  4.38
# ------------------------------
# Word1:  forest
# Word2:  graveyard
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  1.85
# ------------------------------
# Word1:  shore
# Word2:  woodland
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  3.08
# ------------------------------
# Word1:  monk
# Word2:  slave
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  0.92
# ------------------------------
# Word1:  coast
# Word2:  forest
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  3.15
# ------------------------------
# Word1:  lad
# Word2:  wizard
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  0.92
# ------------------------------
# Word1:  chord
# Word2:  smile
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  0.54
# ------------------------------
# Word1:  glass
# Word2:  magician
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  2.08
# ------------------------------
# Word1:  noon
# Word2:  string
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  0.54
# ------------------------------
# Word1:  rooster
# Word2:  voyage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0.5355182363563622
# Human Similarity:  0.62
# ------------------------------
# Word1:  money
# Word2:  dollar
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  8.42
# ------------------------------
# Word1:  money
# Word2:  cash
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  9.08
# ------------------------------
# Word1:  money
# Word2:  currency
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  9.04
# ------------------------------
# Word1:  money
# Word2:  wealth
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  8.27
# ------------------------------
# Word1:  money
# Word2:  property
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  7.57
# ------------------------------
# Word1:  money
# Word2:  possession
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  7.29
# ------------------------------
# Word1:  money
# Word2:  bank
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  8.50
# ------------------------------
# Word1:  money
# Word2:  deposit
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  7.73
# ------------------------------
# Word1:  money
# Word2:  withdrawal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  6.88
# ------------------------------
# Word1:  money
# Word2:  laundering
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  5.65
# ------------------------------
# Word1:  money
# Word2:  operation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  3.31
# ------------------------------
# Word1:  tiger
# Word2:  jaguar
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  8.00
# ------------------------------
# Word1:  tiger
# Word2:  feline
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  8.00
# ------------------------------
# Word1:  tiger
# Word2:  carnivore
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  7.08
# ------------------------------
# Word1:  tiger
# Word2:  mammal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  6.85
# ------------------------------
# Word1:  tiger
# Word2:  animal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.00
# ------------------------------
# Word1:  tiger
# Word2:  organism
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  4.77
# ------------------------------
# Word1:  tiger
# Word2:  fauna
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  5.62
# ------------------------------
# Word1:  tiger
# Word2:  zoo
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  5.87
# ------------------------------
# Word1:  psychology
# Word2:  psychiatry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  8.08
# ------------------------------
# Word1:  psychology
# Word2:  anxiety
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  7.00
# ------------------------------
# Word1:  psychology
# Word2:  fear
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  6.85
# ------------------------------
# Word1:  psychology
# Word2:  depression
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  7.42
# ------------------------------
# Word1:  psychology
# Word2:  clinic
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  6.58
# ------------------------------
# Word1:  psychology
# Word2:  doctor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  6.42
# ------------------------------
# Word1:  psychology
# Word2:  Freud
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  8.21
# ------------------------------
# Word1:  psychology
# Word2:  mind
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  7.69
# ------------------------------
# Word1:  psychology
# Word2:  health
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  7.23
# ------------------------------
# Word1:  psychology
# Word2:  science
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  6.71
# ------------------------------
# Word1:  psychology
# Word2:  discipline
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  5.58
# ------------------------------
# Word1:  psychology
# Word2:  cognition
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  7.48
# ------------------------------
# Word1:  planet
# Word2:  star
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  8.45
# ------------------------------
# Word1:  planet
# Word2:  constellation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  8.06
# ------------------------------
# Word1:  planet
# Word2:  moon
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  8.08
# ------------------------------
# Word1:  planet
# Word2:  sun
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  8.02
# ------------------------------
# Word1:  planet
# Word2:  galaxy
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  8.11
# ------------------------------
# Word1:  planet
# Word2:  space
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  7.92
# ------------------------------
# Word1:  planet
# Word2:  astronomer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  7.94
# ------------------------------
# Word1:  precedent
# Word2:  example
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  5.85
# ------------------------------
# Word1:  precedent
# Word2:  information
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  3.85
# ------------------------------
# Word1:  precedent
# Word2:  cognition
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  2.81
# ------------------------------
# Word1:  precedent
# Word2:  law
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  6.65
# ------------------------------
# Word1:  precedent
# Word2:  collection
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  2.50
# ------------------------------
# Word1:  precedent
# Word2:  group
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  1.77
# ------------------------------
# Word1:  precedent
# Word2:  antecedent
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.04
# ------------------------------
# Word1:  cup
# Word2:  coffee
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.58
# ------------------------------
# Word1:  cup
# Word2:  tableware
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  6.85
# ------------------------------
# Word1:  cup
# Word2:  article
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  2.40
# ------------------------------
# Word1:  cup
# Word2:  artifact
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  2.92
# ------------------------------
# Word1:  cup
# Word2:  object
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  3.69
# ------------------------------
# Word1:  cup
# Word2:  entity
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  2.15
# ------------------------------
# Word1:  cup
# Word2:  drink
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  7.25
# ------------------------------
# Word1:  cup
# Word2:  food
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  5.00
# ------------------------------
# Word1:  cup
# Word2:  substance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  1.92
# ------------------------------
# Word1:  cup
# Word2:  liquid
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  5.90
# ------------------------------
# Word1:  jaguar
# Word2:  cat
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.42
# ------------------------------
# Word1:  jaguar
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0.8803587226480918
# Human Similarity:  7.27
# ------------------------------
# Word1:  energy
# Word2:  secretary
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  1.81
# ------------------------------
# Word1:  secretary
# Word2:  senate
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  5.06
# ------------------------------
# Word1:  energy
# Word2:  laboratory
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  5.09
# ------------------------------
# Word1:  computer
# Word2:  laboratory
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  6.78
# ------------------------------
# Word1:  weapon
# Word2:  secret
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  6.06
# ------------------------------
# Word1:  FBI
# Word2:  fingerprint
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  6.94
# ------------------------------
# Word1:  FBI
# Word2:  investigation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.0055218656020977
# Human Similarity:  8.31
# ------------------------------
# Word1:  investigation
# Word2:  effort
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  4.59
# ------------------------------
# Word1:  Mars
# Word2:  water
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  2.94
# ------------------------------
# Word1:  Mars
# Word2:  scientist
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  5.63
# ------------------------------
# Word1:  news
# Word2:  report
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# Human Similarity:  8.16
# ------------------------------
# Word1:  canyon
# Word2:  landscape
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  7.53
# ------------------------------
# Word1:  image
# Word2:  surface
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  4.56
# ------------------------------
# Word1:  discovery
# Word2:  space
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  6.34
# ------------------------------
# Word1:  water
# Word2:  seepage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  6.56
# ------------------------------
# Word1:  sign
# Word2:  recess
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  2.38
# ------------------------------
# Word1:  Wednesday
# Word2:  news
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  2.22
# ------------------------------
# Word1:  mile
# Word2:  kilometer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  8.66
# ------------------------------
# Word1:  computer
# Word2:  news
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  4.47
# ------------------------------
# Word1:  territory
# Word2:  surface
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  5.34
# ------------------------------
# Word1:  atmosphere
# Word2:  landscape
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  3.69
# ------------------------------
# Word1:  president
# Word2:  medal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  3.00
# ------------------------------
# Word1:  war
# Word2:  troops
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  8.13
# ------------------------------
# Word1:  record
# Word2:  number
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  6.31
# ------------------------------
# Word1:  skin
# Word2:  eye
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.22
# ------------------------------
# Word1:  Japanese
# Word2:  American
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  6.50
# ------------------------------
# Word1:  theater
# Word2:  history
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  3.91
# ------------------------------
# Word1:  volunteer
# Word2:  motto
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  2.56
# ------------------------------
# Word1:  prejudice
# Word2:  recognition
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  3.00
# ------------------------------
# Word1:  decoration
# Word2:  valor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  5.63
# ------------------------------
# Word1:  century
# Word2:  year
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  7.59
# ------------------------------
# Word1:  century
# Word2:  nation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  3.16
# ------------------------------
# Word1:  delay
# Word2:  racism
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  1.19
# ------------------------------
# Word1:  delay
# Word2:  news
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  3.31
# ------------------------------
# Word1:  minister
# Word2:  party
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.63
# ------------------------------
# Word1:  peace
# Word2:  plan
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  4.75
# ------------------------------
# Word1:  minority
# Word2:  peace
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  3.69
# ------------------------------
# Word1:  attempt
# Word2:  peace
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  4.25
# ------------------------------
# Word1:  government
# Word2:  crisis
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  6.56
# ------------------------------
# Word1:  deployment
# Word2:  departure
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  4.25
# ------------------------------
# Word1:  deployment
# Word2:  withdrawal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  5.88
# ------------------------------
# Word1:  energy
# Word2:  crisis
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  5.94
# ------------------------------
# Word1:  announcement
# Word2:  news
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  7.56
# ------------------------------
# Word1:  announcement
# Word2:  effort
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  2.75
# ------------------------------
# Word1:  stroke
# Word2:  hospital
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  7.03
# ------------------------------
# Word1:  disability
# Word2:  death
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  5.47
# ------------------------------
# Word1:  victim
# Word2:  emergency
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  6.47
# ------------------------------
# Word1:  treatment
# Word2:  recovery
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.91
# ------------------------------
# Word1:  journal
# Word2:  association
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  4.97
# ------------------------------
# Word1:  doctor
# Word2:  personnel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  5.00
# ------------------------------
# Word1:  doctor
# Word2:  liability
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  5.19
# ------------------------------
# Word1:  liability
# Word2:  insurance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  7.03
# ------------------------------
# Word1:  school
# Word2:  center
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  3.44
# ------------------------------
# Word1:  reason
# Word2:  hypertension
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  2.31
# ------------------------------
# Word1:  reason
# Word2:  criterion
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  5.91
# ------------------------------
# Word1:  hundred
# Word2:  percent
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  7.38
# ------------------------------
# Word1:  Harvard
# Word2:  Yale
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  8.13
# ------------------------------
# Word1:  hospital
# Word2:  infrastructure
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  4.63
# ------------------------------
# Word1:  death
# Word2:  row
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  5.25
# ------------------------------
# Word1:  death
# Word2:  inmate
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  5.03
# ------------------------------
# Word1:  lawyer
# Word2:  evidence
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  6.69
# ------------------------------
# Word1:  life
# Word2:  death
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  7.88
# ------------------------------
# Word1:  life
# Word2:  term
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  4.50
# ------------------------------
# Word1:  word
# Word2:  similarity
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  4.75
# ------------------------------
# Word1:  board
# Word2:  recommendation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  4.47
# ------------------------------
# Word1:  governor
# Word2:  interview
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  3.25
# ------------------------------
# Word1:  OPEC
# Word2:  country
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  5.63
# ------------------------------
# Word1:  peace
# Word2:  atmosphere
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  3.69
# ------------------------------
# Word1:  peace
# Word2:  insurance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  2.94
# ------------------------------
# Word1:  territory
# Word2:  kilometer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  5.28
# ------------------------------
# Word1:  travel
# Word2:  activity
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  5.00
# ------------------------------
# Word1:  competition
# Word2:  price
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  6.44
# ------------------------------
# Word1:  consumer
# Word2:  confidence
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  4.13
# ------------------------------
# Word1:  consumer
# Word2:  energy
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  4.75
# ------------------------------
# Word1:  problem
# Word2:  airport
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  2.38
# ------------------------------
# Word1:  car
# Word2:  flight
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  4.94
# ------------------------------
# Word1:  credit
# Word2:  card
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  8.06
# ------------------------------
# Word1:  credit
# Word2:  information
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  5.31
# ------------------------------
# Word1:  hotel
# Word2:  reservation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  8.03
# ------------------------------
# Word1:  grocery
# Word2:  money
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  5.94
# ------------------------------
# Word1:  registration
# Word2:  arrangement
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  6.00
# ------------------------------
# Word1:  arrangement
# Word2:  accommodation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  5.41
# ------------------------------
# Word1:  month
# Word2:  hotel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# Human Similarity:  1.81
# ------------------------------
# Word1:  type
# Word2:  kind
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  8.97
# ------------------------------
# Word1:  arrival
# Word2:  hotel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  6.00
# ------------------------------
# Word1:  bed
# Word2:  closet
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  6.72
# ------------------------------
# Word1:  closet
# Word2:  clothes
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  8.00
# ------------------------------
# Word1:  situation
# Word2:  conclusion
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  4.81
# ------------------------------
# Word1:  situation
# Word2:  isolation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  3.88
# ------------------------------
# Word1:  impartiality
# Word2:  interest
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  5.16
# ------------------------------
# Word1:  direction
# Word2:  combination
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  2.25
# ------------------------------
# Word1:  street
# Word2:  place
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.44
# ------------------------------
# Word1:  street
# Word2:  avenue
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# Human Similarity:  8.88
# ------------------------------
# Word1:  street
# Word2:  block
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.88
# ------------------------------
# Word1:  street
# Word2:  children
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  4.94
# ------------------------------
# Word1:  listing
# Word2:  proximity
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  2.56
# ------------------------------
# Word1:  listing
# Word2:  category
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  6.38
# ------------------------------
# Word1:  cell
# Word2:  phone
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  7.81
# ------------------------------
# Word1:  production
# Word2:  hike
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  1.75
# ------------------------------
# Word1:  benchmark
# Word2:  index
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  4.25
# ------------------------------
# Word1:  media
# Word2:  trading
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  3.88
# ------------------------------
# Word1:  media
# Word2:  gain
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  2.88
# ------------------------------
# Word1:  dividend
# Word2:  payment
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  7.63
# ------------------------------
# Word1:  dividend
# Word2:  calculation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  6.48
# ------------------------------
# Word1:  calculation
# Word2:  computation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# Human Similarity:  8.44
# ------------------------------
# Word1:  currency
# Word2:  market
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  7.50
# ------------------------------
# Word1:  OPEC
# Word2:  oil
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  8.59
# ------------------------------
# Word1:  oil
# Word2:  stock
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  6.34
# ------------------------------
# Word1:  announcement
# Word2:  production
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  3.38
# ------------------------------
# Word1:  announcement
# Word2:  warning
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.00
# ------------------------------
# Word1:  profit
# Word2:  warning
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  3.88
# ------------------------------
# Word1:  profit
# Word2:  loss
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  7.63
# ------------------------------
# Word1:  dollar
# Word2:  yen
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.78
# ------------------------------
# Word1:  dollar
# Word2:  buck
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# Human Similarity:  9.22
# ------------------------------
# Word1:  dollar
# Word2:  profit
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  7.38
# ------------------------------
# Word1:  dollar
# Word2:  loss
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  6.09
# ------------------------------
# Word1:  computer
# Word2:  software
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  8.50
# ------------------------------
# Word1:  network
# Word2:  hardware
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  8.31
# ------------------------------
# Word1:  phone
# Word2:  equipment
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  7.13
# ------------------------------
# Word1:  equipment
# Word2:  maker
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  5.91
# ------------------------------
# Word1:  luxury
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.0055218656020977
# Human Similarity:  6.47
# ------------------------------
# Word1:  five
# Word2:  month
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  3.38
# ------------------------------
# Word1:  report
# Word2:  gain
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  3.63
# ------------------------------
# Word1:  investor
# Word2:  earning
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  7.13
# ------------------------------
# Word1:  liquid
# Word2:  water
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# Human Similarity:  7.89
# ------------------------------
# Word1:  baseball
# Word2:  season
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.0055218656020977
# Human Similarity:  5.97
# ------------------------------
# Word1:  game
# Word2:  victory
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  7.03
# ------------------------------
# Word1:  game
# Word2:  team
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  7.69
# ------------------------------
# Word1:  marathon
# Word2:  sprint
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  7.47
# ------------------------------
# Word1:  game
# Word2:  series
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  6.19
# ------------------------------
# Word1:  game
# Word2:  defeat
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  6.97
# ------------------------------
# Word1:  seven
# Word2:  series
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  3.56
# ------------------------------
# Word1:  seafood
# Word2:  sea
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  7.47
# ------------------------------
# Word1:  seafood
# Word2:  food
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  8.34
# ------------------------------
# Word1:  seafood
# Word2:  lobster
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  8.70
# ------------------------------
# Word1:  lobster
# Word2:  food
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  7.81
# ------------------------------
# Word1:  lobster
# Word2:  wine
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  5.70
# ------------------------------
# Word1:  food
# Word2:  preparation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  6.22
# ------------------------------
# Word1:  video
# Word2:  archive
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  6.34
# ------------------------------
# Word1:  start
# Word2:  year
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  4.06
# ------------------------------
# Word1:  start
# Word2:  match
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  4.47
# ------------------------------
# Word1:  game
# Word2:  round
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  5.97
# ------------------------------
# Word1:  boxing
# Word2:  round
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  7.61
# ------------------------------
# Word1:  championship
# Word2:  tournament
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  8.36
# ------------------------------
# Word1:  fighting
# Word2:  defeating
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  7.41
# ------------------------------
# Word1:  line
# Word2:  insurance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  2.69
# ------------------------------
# Word1:  day
# Word2:  summer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  3.94
# ------------------------------
# Word1:  summer
# Word2:  drought
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.16
# ------------------------------
# Word1:  summer
# Word2:  nature
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  5.63
# ------------------------------
# Word1:  day
# Word2:  dawn
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  7.53
# ------------------------------
# Word1:  nature
# Word2:  environment
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  8.31
# ------------------------------
# Word1:  environment
# Word2:  ecology
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# Human Similarity:  8.81
# ------------------------------
# Word1:  nature
# Word2:  man
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  6.25
# ------------------------------
# Word1:  man
# Word2:  woman
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  8.30
# ------------------------------
# Word1:  man
# Word2:  governor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  5.25
# ------------------------------
# Word1:  murder
# Word2:  manslaughter
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  8.53
# ------------------------------
# Word1:  soap
# Word2:  opera
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  7.94
# ------------------------------
# Word1:  opera
# Word2:  performance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  6.88
# ------------------------------
# Word1:  life
# Word2:  lesson
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  5.94
# ------------------------------
# Word1:  focus
# Word2:  life
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  4.06
# ------------------------------
# Word1:  production
# Word2:  crew
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  6.25
# ------------------------------
# Word1:  television
# Word2:  film
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  7.72
# ------------------------------
# Word1:  lover
# Word2:  quarrel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  6.19
# ------------------------------
# Word1:  viewer
# Word2:  serial
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  2.97
# ------------------------------
# Word1:  possibility
# Word2:  girl
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  1.94
# ------------------------------
# Word1:  population
# Word2:  development
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  3.75
# ------------------------------
# Word1:  morality
# Word2:  importance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  3.31
# ------------------------------
# Word1:  morality
# Word2:  marriage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  3.69
# ------------------------------
# Word1:  Mexico
# Word2:  Brazil
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# Human Similarity:  7.44
# ------------------------------
# Word1:  gender
# Word2:  equality
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  6.41
# ------------------------------
# Word1:  change
# Word2:  attitude
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  5.44
# ------------------------------
# Word1:  family
# Word2:  planning
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  6.25
# ------------------------------
# Word1:  opera
# Word2:  industry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  2.63
# ------------------------------
# Word1:  sugar
# Word2:  approach
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# Human Similarity:  0.88
# ------------------------------
# Word1:  practice
# Word2:  institution
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  3.19
# ------------------------------
# Word1:  ministry
# Word2:  culture
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# Human Similarity:  4.69
# ------------------------------
# Word1:  problem
# Word2:  challenge
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  6.75
# ------------------------------
# Word1:  size
# Word2:  prominence
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  5.31
# ------------------------------
# Word1:  country
# Word2:  citizen
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  7.31
# ------------------------------
# Word1:  planet
# Word2:  people
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  5.75
# ------------------------------
# Word1:  development
# Word2:  issue
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  3.97
# ------------------------------
# Word1:  experience
# Word2:  music
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  3.47
# ------------------------------
# Word1:  music
# Word2:  project
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  3.63
# ------------------------------
# Word1:  glass
# Word2:  metal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  5.56
# ------------------------------
# Word1:  aluminum
# Word2:  metal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# Human Similarity:  7.83
# ------------------------------
# Word1:  chance
# Word2:  credibility
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  3.88
# ------------------------------
# Word1:  exhibit
# Word2:  memorabilia
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  5.31
# ------------------------------
# Word1:  concert
# Word2:  virtuoso
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# Human Similarity:  6.81
# ------------------------------
# Word1:  rock
# Word2:  jazz
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# Human Similarity:  7.59
# ------------------------------
# Word1:  museum
# Word2:  theater
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  7.19
# ------------------------------
# Word1:  observation
# Word2:  architecture
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# Human Similarity:  4.38
# ------------------------------
# Word1:  space
# Word2:  world
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  6.53
# ------------------------------
# Word1:  preservation
# Word2:  world
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  6.19
# ------------------------------
# Word1:  admission
# Word2:  ticket
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  7.69
# ------------------------------
# Word1:  shower
# Word2:  thunderstorm
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# Human Similarity:  6.31
# ------------------------------
# Word1:  shower
# Word2:  flood
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# Human Similarity:  6.03
# ------------------------------
# Word1:  weather
# Word2:  forecast
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# Human Similarity:  8.34
# ------------------------------
# Word1:  disaster
# Word2:  area
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# Human Similarity:  6.25
# ------------------------------
# Word1:  governor
# Word2:  office
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  6.34
# ------------------------------
# Word1:  architecture
# Word2:  century
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# Human Similarity:  3.78
# ------------------------------
# Pearson Correlation:  [[1.         0.26142012]
#  [0.26142012 1.        ]]
# Spearman Correlation:  SpearmanrResult(correlation=0.2651845536640065, pvalue=4.292887522518468e-07)

# %% [markdown]
# CONSEGNA 2.1:
#
# L'esercitazione consiste nell'estrarre 50 frasi dal corpus SemCor (corpus annotato con i synset di WN) e disambiguare (almeno) un sostantivo per frase.
#
# Calcolare l’accuratezza del sistema implementato sulla base dei sensi annotati in SemCor.

# %%
tokenizer = RegexpTokenizer(r'\w+')

INDEXES_NUM = 1000 #è il limite, partendo da 0, di sentence che possono essere testate relative al database SemCor
RANGE = 50 #è il numero di sentence che effettivamente verranno testate

sentences_tag = semcor.tagged_sents() #lista di liste. Ogni lista rappresenta una sentence e ad ogni parola della sentence è associato un pos tag
sentences = semcor.sents() #lista di liste di parole. Ogni lista rappresenta una sentence
sentences_sem = semcor.tagged_sents(tag = "sem") #lista di liste. Ogni lista rappresenta una sentence e ad ogni parola della sentence è associato un synset gold

def main():
    evaluated = 0 #termini valutati
    checked = 0 #termini valutati correttamente
    index_evaluated = set() #insieme degli indici già valutati
    while(evaluated <= RANGE):
        while True: #fino a quando non trova una word che ha almeno un senso in wordnet   
            index = get_random_index(index_evaluated, INDEXES_NUM)
            word = get_random_noun(get_dictionary_tag(sentences_tag[index],sentences_sem[index]))
            if word:
                break
        sentence = sentences[index]
        print("Parola da disambiguare: ",word)
        #all'algoritmo di lesk viene dato in input la word e l'insieme dei termini che formano la frase, uniti sottoforma di stringa
        best_sense = str(lesk_algorithm(word, ' '.join(word for word in sentence), word_type='NOUN'))
        print("Senso attribuito dall'algoritmo di Lesk: ",best_sense)
        target_lemma = get_synset_target_for_word_in_sentence(word,sentences_sem[index])
        print("Senso Target: ",target_lemma)
        best_sense_lemma = best_sense[8:len(best_sense)-2]
        if target_lemma:
            if best_sense_lemma in target_lemma: checked= checked + 1
        evaluated += 1
        print("------------------------------")
    
    print("Termini valutati: ", evaluated)
    print("Termini valutati correttamente: ", checked)
    print("Accuratezza: ", checked/RANGE)
    
main()
# Out:
# Parola da disambiguare:  drive
# Frase in cui compare la parola:  Momentarily the Reds were back in the ball game , trailing only 6 - 3 , but the drive fizzled when John Edwards fouled out with men on second and third and two out .
# Contesto della frase:  {'edwards', 'men', 'trail', 'foul', 'momentarily', 'second', 'reds', 'game', 'third', 'ball', 'john', 'drive', 'fizzle'}
# Max Signature:  {'hit', 'tee', 'golf', 'driver', 'slice', 'ball', 'drive', 'bound'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('drive.n.06')
# Senso Target:  Lemma('campaign.n.02.drive')
# ------------------------------
# Parola da disambiguare:  charity
# Frase in cui compare la parola:  The writers ' Gold Tee Award will go to John McAuliffe of Plainfield , N. J. , and Palm Beach , Fla. , for his sponsorship of charity tournaments .
# Contesto della frase:  {'writer', 'mcauliffe', 'tee', 'gold', 'award', 'plainfield', 'charity', 'palm', 'fla', 'john', 'beach', 'sponsorship', 'tournament'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('charity.n.01')
# Senso Target:  Lemma('charity.n.01.charity')
# ------------------------------
# Parola da disambiguare:  top
# Frase in cui compare la parola:  They now lead Louisville by a full game on top of the American Association pack .
# Contesto della frase:  {'pack', 'association', 'game', 'lead', 'top', 'full', 'louisville', 'american'}
# Max Signature:  {'cut', 'write', 'mower', 'title', 'upper', 'top', 'grass'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('top.n.01')
# Senso Target:  Lemma('acme.n.01.top')
# ------------------------------
# Parola da disambiguare:  reflexes
# Frase in cui compare la parola:  Suddenly my reflexes are gone .
# Contesto della frase:  {'reflex', 'suddenly'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('reflex.n.01')
# Senso Target:  Lemma('reflex.n.01.reflex')
# ------------------------------
# Parola da disambiguare:  club
# Frase in cui compare la parola:  When he was unable to bring about immediate expansion , he sought to convince another National League club to move here .
# Contesto della frase:  {'expansion', 'bring', 'national', 'convince', 'league', 'move', 'unable', 'club', 'seek'}
# Max Signature:  {'professional', 'division', 'play', 'baseball', 'player', 'game', 'club', 'travel', 'team'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('baseball_club.n.01')
# Senso Target:  Lemma('baseball_club.n.01.club')
# ------------------------------
# Parola da disambiguare:  idol
# Frase in cui compare la parola:  The idol of the hackers , of course , is Ray Ainsley , who achieved a 19 in the United States Open .
# Contesto della frase:  {'ray', 'idol', 'hacker', 'open', 'course', 'achieve', 'united', 'ainsley'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('idol.n.01')
# Senso Target:  Lemma('idol.n.02.idol')
# ------------------------------
# Parola da disambiguare:  weeks
# Frase in cui compare la parola:  However , this would require a lengthening of the season from thirteen to fourteen weeks .
# Contesto della frase:  {'require', 'fourteen', 'week', 'season', 'lengthening', 'thirteen'}
# Max Signature:  {'consecutive', 'week', 'rain', 'period', 'day'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('week.n.01')
# Senso Target:  Lemma('week.n.01.week')
# ------------------------------
# Parola da disambiguare:  magazines
# Frase in cui compare la parola:  If he can't play with Mommy 's magazines , he should have some old numbers of his own .
# Contesto della frase:  {'play', 'magazine', 'number', 'mommy', 'cant'}
# Max Signature:  {'publication', 'article', 'start', 'break', 'subscribe', 'magazine', 'periodic', 'money', 'story', 'purchase', 'year', 'picture', 'interest'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('magazine.n.01')
# Senso Target:  Lemma('magazine.n.01.magazine')
# ------------------------------
# Parola da disambiguare:  Missouri
# Frase in cui compare la parola:  The principal speaker will be Senator Stuart Symington , Democrat of Missouri .
# Contesto della frase:  {'stuart', 'missouri', 'speaker', 'principal', 'senator', 'symington', 'democrat'}
# Max Signature:  {'central', 'confederacy', 'border', 'midwestern', 'missouri', 'union', 'war', 'secede', 'united', 'civil', 'admit', 'american'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('missouri.n.01')
# Senso Target:  Lemma('missouri.n.01.Missouri')
# ------------------------------
# Parola da disambiguare:  disappointments
# Frase in cui compare la parola:  Despite countless barriers and disappointments , Shea moved forward .
# Contesto della frase:  {'shea', 'forward', 'disappointment', 'move', 'countless', 'barrier'}
# Max Signature:  {'doom', 'expectation', 'feeling', 'disappointment', 'result', 'high', 'realize', 'dissatisfaction', 'hope'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('disappointment.n.01')
# Senso Target:  Lemma('disappointment.n.02.disappointment')
# ------------------------------
# Parola da disambiguare:  campaign
# Frase in cui compare la parola:  Sam Caldwell , State Highway Department public relations director , resigned Tuesday to work for Lt. Gov. Garland Byrd 's campaign .
# Contesto della frase:  {'tuesday', 'campaign', 'caldwell', 'highway', 'relation', 'public', 'lt', 'resign', 'work', 'department', 'garland', 'byrd', 'gov', 'sam', 'director'}
# Max Signature:  {'ready', 'action', 'drive', 'series', 'pennant', 'populist', 'contribute', 'advance', 'campaign', 'slavery', 'tend', 'support', 'principle', 'work', 'peace', 'team', 'effort', 'war', 'movement'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('campaign.n.02')
# Senso Target:  Lemma('political_campaign.n.01.campaign')
# ------------------------------
# Parola da disambiguare:  chores
# Frase in cui compare la parola:  Bill Kunkel , Bob Hartman and Ed Keegan did the mound chores for the club down from West Palm Beach to play the game before 767 paying customers in Miami Stadium .
# Contesto della frase:  {'kunkel', 'west', 'bill', 'customer', 'play', 'keegan', 'bob', 'chores', 'pay', 'game', 'palm', 'miami', 'club', 'beach', 'hartman', 'stadium', 'mound'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('job.n.02')
# Senso Target:  Lemma('job.n.02.chore')
# ------------------------------
# Parola da disambiguare:  leadership
# Frase in cui compare la parola:  And what leadership a proud Mantle has given so far .
# Contesto della frase:  {'mantle', 'leadership'}
# Max Signature:  {'leadership', 'lead', 'inspire', 'activity', 'team'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('leadership.n.01')
# Senso Target:  Lemma('leadership.n.01.leadership')
# ------------------------------
# Parola da disambiguare:  set
# Frase in cui compare la parola:  Thanks to Spoken Arts Records , history buffs may hear Lincoln 's `` most memorable speeches and letters '' in a two disc set , interpreted by Lincoln authority and lecturer Roy P. Basler .
# Contesto della frase:  {'memorable', 'speech', 'set', 'records', 'disc', 'arts', 'spoken', 'buff', 'letter', 'lecturer', 'roy', 'interpret', 'basler', 'history', 'authority', 'lincoln', 'hear'}
# Max Signature:  {'set', 'group', 'book', 'golf', 'teeth', 'thing', 'belong', 'club', 'kind'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('set.n.01')
# Senso Target:  Lemma('set.n.01.set')
# ------------------------------
# Parola da disambiguare:  corporations
# Frase in cui compare la parola:  The bill , which Daniel said he drafted personally , would force banks , insurance firms , pipeline companies and other corporations to report such property to the state treasurer .
# Contesto della frase:  {'bill', 'personally', 'draft', 'firm', 'report', 'property', 'company', 'bank', 'daniel', 'pipeline', 'corporation', 'force', 'insurance', 'treasurer'}
# Max Signature:  {'article', 'incorporation', 'firm', 'business', 'approve'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('corporation.n.01')
# Senso Target:  Lemma('corporation.n.01.corporation')
# ------------------------------
# Parola da disambiguare:  inning
# Frase in cui compare la parola:  The Bears took the lead in the first inning , as they did in Sunday 's opener , and never lagged .
# Contesto della frase:  {'sunday', 'bears', 'lag', 'lead', 'inning', 'opener'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('inning.n.01')
# Senso Target:  Lemma('inning.n.01.inning')
# ------------------------------
# Parola da disambiguare:  club
# Frase in cui compare la parola:  The '52 Cards were 6 - 7 on May 1 but ended with 88 triumphs , the club 's top since 1949 .
# Contesto della frase:  {'triumph', 'cards', 'club', 'top'}
# Max Signature:  {'professional', 'division', 'play', 'baseball', 'player', 'game', 'club', 'travel', 'team'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('baseball_club.n.01')
# Senso Target:  Lemma('baseball_club.n.01.club')
# ------------------------------
# Parola da disambiguare:  bill
# Frase in cui compare la parola:  The bill would increase from $ 5000000 to $ 15000000 the maximum loan the state could make to a local water project .
# Contesto della frase:  {'bill', 'maximum', 'water', 'local', 'project', 'increase', 'loan'}
# Max Signature:  {'brim', 'bill', 'front', 'project', 'shade', 'trudge', 'pull', 'ahead', 'cap', 'eye'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('bill.n.09')
# Senso Target:  Lemma('bill.n.01.bill')
# ------------------------------
# Parola da disambiguare:  Ordinary
# Frase in cui compare la parola:  Ordinary Williams said he , too , was subjected to anonymous calls soon after he scheduled the election .
# Contesto della frase:  {'subject', 'anonymous', 'schedule', 'williams', 'call', 'ordinary', 'election'}
# Max Signature:  {'commonplace', 'condition', 'situation', 'ordinary', 'expect'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('ordinary.n.02')
# Senso Target:  Lemma('ordinary.n.01.ordinary')
# ------------------------------
# Parola da disambiguare:  game
# Frase in cui compare la parola:  `` Kelsey is very doubtful for the Rice game '' , Meek said .
# Contesto della frase:  {'meek', 'kelsey', 'game', 'doubtful', 'rice'}
# Max Signature:  {'contest', 'people', 'play', 'game', 'rule', 'determine', 'winner'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('game.n.01')
# Senso Target:  Lemma('game.n.02.game')
# ------------------------------
# Parola da disambiguare:  luxury
# Frase in cui compare la parola:  But for many of us , it will prove an enjoyable luxury .
# Contesto della frase:  {'enjoyable', 'luxury', 'prove'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('luxury.n.01')
# Senso Target:  Lemma('luxury.n.01.luxury')
# ------------------------------
# Parola da disambiguare:  coach
# Frase in cui compare la parola:  Williams is a defensive coach .
# Contesto della frase:  {'coach', 'williams', 'defensive'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('coach.n.01')
# Senso Target:  Lemma('coach.n.01.coach')
# ------------------------------
# Parola da disambiguare:  Abstractions
# Frase in cui compare la parola:  Abstractions and semi abstractions by Everett McNear are being exhibited by the University gallery of Notre Dame until Nov. 5 .
# Contesto della frase:  {'abstraction', 'exhibit', 'nov', 'everett', 'university', 'abstractions', 'notre', 'semi', 'dame', 'gallery', 'mcnear'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('abstraction.n.01')
# Senso Target:  Lemma('abstraction.n.04.abstraction')
# ------------------------------
# Parola da disambiguare:  side
# Frase in cui compare la parola:  He hooked the next two out of bounds on the opposite side .
# Contesto della frase:  {'bound', 'hook', 'opposite', 'side'}
# Max Signature:  {'relative', 'center', 'side', 'identify', 'sit', 'church', 'leave', 'reference', 'region', 'location', 'place'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('side.n.01')
# Senso Target:  Lemma('side.n.01.side')
# ------------------------------
# Parola da disambiguare:  dirt
# Frase in cui compare la parola:  The Orioles got a run in the first inning when Breeding , along with Robinson , the two Birds who got a pair of hits , doubled to right center , moved to third on Russ Snyder 's single to right and crossed on Kunkel 's wild pitch into the dirt in front of the plate .
# Contesto della frase:  {'dirt', 'wild', 'breeding', 'pitch', 'third', 'hit', 'snyder', 'inning', 'single', 'double', 'kunkel', 'center', 'russ', 'move', 'robinson', 'plate', 'cross', 'pair', 'orioles', 'front', 'birds'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('soil.n.02')
# Senso Target:  Lemma('soil.n.02.dirt')
# ------------------------------
# Parola da disambiguare:  kid
# Frase in cui compare la parola:  Stengel probably preached too much in the early days when the kid wanted to pop his bubble gum and sow his oats .
# Contesto della frase:  {'sow', 'preach', 'pop', 'early', 'day', 'gum', 'oat', 'stengel', 'bubble', 'kid'}
# Max Signature:  {'young', 'child', 'book', 'write', 'tiddler', 'sex', 'term', 'youngster', 'british', 'person', 'kid'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('child.n.01')
# Senso Target:  Lemma('child.n.01.kid')
# ------------------------------
# Parola da disambiguare:  man
# Frase in cui compare la parola:  When a man is laid to rest , he is entitled to stay put .
# Contesto della frase:  {'lay', 'rest', 'stay', 'man', 'entitle'}
# Max Signature:  {'human', 'word', 'man', 'generic', 'refer'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('man.n.03')
# Senso Target:  Lemma('homo.n.02.man')
# ------------------------------
# Parola da disambiguare:  wintertime
# Frase in cui compare la parola:  Pitcher Steve Barber joined the club one week ago after completing his hitch under the Army 's accelerated wintertime military course , also at Fort Knox , Ky. .
# Contesto della frase:  {'wintertime', 'military', 'join', 'week', 'ago', 'knox', 'army', 'steve', 'complete', 'barber', 'hitch', 'course', 'accelerate', 'club', 'ky', 'pitcher', 'fort'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('winter.n.01')
# Senso Target:  Lemma('winter.n.01.wintertime')
# ------------------------------
# Parola da disambiguare:  year
# Frase in cui compare la parola:  There is no use trying to `` Explain '' to a 2 - year old .
# Contesto della frase:  {'explain', 'year'}
# Max Signature:  {'period', 'time', 'day', 'year'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('year.n.01')
# Senso Target:  Lemma('year.n.01.year')
# ------------------------------
# Parola da disambiguare:  champions
# Frase in cui compare la parola:  Until the Bucs ' bats quieted down a bit in Cincinnati over the weekend , the champions had eight men hitting over .300 .
# Contesto della frase:  {'men', 'hit', 'weekend', 'champion', 'bat', 'bucs', 'quiet', 'cincinnati', 'bit'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('champion.n.01')
# Senso Target:  Lemma('champion.n.01.champion')
# ------------------------------
# Parola da disambiguare:  men
# Frase in cui compare la parola:  The truth is , though , that men react differently to different treatment .
# Contesto della frase:  {'men', 'react', 'treatment', 'differently', 'truth'}
# Max Signature:  {'bus', 'men', 'oppose', 'adult', 'woman', 'male', 'person'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('man.n.01')
# Senso Target:  Lemma('man.n.01.man')
# ------------------------------
# Parola da disambiguare:  hearing
# Frase in cui compare la parola:  He also complained that not enough notice was given on the hearing , since the bill was introduced only last Monday .
# Contesto della frase:  {'notice', 'bill', 'monday', 'hearing', 'complain', 'introduce'}
# Max Signature:  {'case', 'audience', 'condemn', 'opportunity', 'hearing', 'lose', 'hear'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('hearing.n.02')
# Senso Target:  Lemma('hearing.n.01.hearing')
# ------------------------------
# Parola da disambiguare:  athletics
# Frase in cui compare la parola:  He merely became victimized by a form of athletics that respects no one and aggravates all .
# Contesto della frase:  {'form', 'athletics', 'victimize', 'respect', 'aggravate'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('sport.n.01')
# Senso Target:  Lemma('sport.n.01.athletics')
# ------------------------------
# Parola da disambiguare:  November
# Frase in cui compare la parola:  Pelham pointed out that Georgia voters last November rejected a constitutional amendment to allow legislators to vote on pay raises for future Legislature sessions .
# Contesto della frase:  {'raise', 'legislature', 'reject', 'pay', 'vote', 'constitutional', 'point', 'georgia', 'pelham', 'amendment', 'voter', 'allow', 'legislator', 'future', 'november', 'session'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('november.n.01')
# Senso Target:  Lemma('november.n.01.November')
# ------------------------------
# Parola da disambiguare:  plunkers
# Frase in cui compare la parola:  No plunkers for him '' .
# Contesto della frase:  {'plunker'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('plunk.n.02')
# Senso Target:  Lemma('plunk.n.02.plunker')
# ------------------------------
# Parola da disambiguare:  miscalculation
# Frase in cui compare la parola:  If this capacity had not failed them , they would see that their enemy has made a disastrous miscalculation .
# Contesto della frase:  {'fail', 'disastrous', 'miscalculation', 'capacity', 'enemy'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('miscalculation.n.01')
# Senso Target:  Lemma('miscalculation.n.01.miscalculation')
# ------------------------------
# Parola da disambiguare:  flood
# Frase in cui compare la parola:  The flood is not as great - only 700 a week according to one apparently conservative account - but it is symptomatic .
# Contesto della frase:  {'week', 'account', 'symptomatic', 'accord', 'great', 'flood', 'conservative'}
# Max Signature:  {'torrent', 'overwhelming', 'abuse', 'request', 'number', 'amount', 'flood'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('flood.n.02')
# Senso Target:  Lemma('flood.n.04.flood')
# ------------------------------
# Parola da disambiguare:  point
# Frase in cui compare la parola:  But Mr. Hendl does not go straight to any point .
# Contesto della frase:  {'hendl', 'point', 'straight'}
# Max Signature:  {'element', 'geometric', 'extension', 'position', 'point', 'define', 'coordinate'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('point.n.01')
# Senso Target:  Lemma('degree.n.02.point')
# ------------------------------
# Parola da disambiguare:  luxury
# Frase in cui compare la parola:  But for many of us , it will prove an enjoyable luxury .
# Contesto della frase:  {'enjoyable', 'luxury', 'prove'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('luxury.n.01')
# Senso Target:  Lemma('luxury.n.01.luxury')
# ------------------------------
# Parola da disambiguare:  Weltanschauung
# Frase in cui compare la parola:  He is a Buddhist , which means that to him peace and the sanctity of human life are not only religious dogma , but a profound and unshakable Weltanschauung .
# Contesto della frase:  {'dogma', 'unshakable', 'life', 'sanctity', 'buddhist', 'human', 'profound', 'peace', 'weltanschauung', 'religious'}
# Max Signature:  {'human', 'comprehensive', 'life', 'view'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('weltanschauung.n.01')
# Senso Target:  Lemma('weltanschauung.n.01.Weltanschauung')
# ------------------------------
# Parola da disambiguare:  loss
# Frase in cui compare la parola:  He nailed it for a yard loss '' .
# Contesto della frase:  {'nail', 'yard', 'loss'}
# Max Signature:  {'car', 'leave', 'bankrupt', 'loss', 'rancher', 'total', 'lose', 'livestock'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('loss.n.01')
# Senso Target:  Lemma('loss.n.01.loss')
# ------------------------------
# Parola da disambiguare:  church
# Frase in cui compare la parola:  `` Being at the polls was just like being at church .
# Contesto della frase:  {'church', 'poll'}
# Max Signature:  {'church', 'public', 'worship', 'christian', 'empty', 'place'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('church.n.02')
# Senso Target:  Lemma('church_service.n.01.church')
# ------------------------------
# Parola da disambiguare:  double-crosser
# Frase in cui compare la parola:  I told him what Liston had said and he said Liston was a double-crosser and said anything he ( Liston ) got was through a keyhole .
# Contesto della frase:  {'doublecrosser', 'liston', 'keyhole'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('double-crosser.n.01')
# Senso Target:  Lemma('double-crosser.n.01.double-crosser')
# ------------------------------
# Parola da disambiguare:  season
# Frase in cui compare la parola:  However , this would require a lengthening of the season from thirteen to fourteen weeks .
# Contesto della frase:  {'require', 'fourteen', 'week', 'season', 'lengthening', 'thirteen'}
# Max Signature:  {'ballet', 'avocado', 'forward', 'period', 'celebrate', 'company', 'season', 'event', 'field', 'year', 'activity', 'mark', 'special'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('season.n.01')
# Senso Target:  Lemma('season.n.01.season')
# ------------------------------
# Parola da disambiguare:  music
# Frase in cui compare la parola:  That is , when Mr. Milstein thrust straight to the core of the music , sparks flying , bow shredding , violin singing , glittering and sometimes spitting , Mr. Hendl could go along .
# Contesto della frase:  {'straight', 'hendl', 'music', 'core', 'fly', 'spit', 'thrust', 'shred', 'violin', 'spark', 'glittering', 'milstein', 'sing'}
# Max Signature:  {'sound', 'harmonious', 'music', 'agreeable', 'chime', 'asleep', 'wind', 'fell', 'pleasing'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('music.n.02')
# Senso Target:  Lemma('music.n.02.music')
# ------------------------------
# Parola da disambiguare:  performance
# Frase in cui compare la parola:  Mankowski , the ball-hawking defensive expert , was cited for his performance against Bradley in St. Louis U. 's nationally televised victory .
# Contesto della frase:  {'expert', 'cite', 'st', 'nationally', 'mankowski', 'televise', 'bradley', 'louis', 'defensive', 'victory', 'performance', 'ballhawking'}
# Max Signature:  {'entertainment', 'frequent', 'musical', 'play', 'listen', 'testify', 'popularity', 'symphony', 'ten', 'performance', 'dramatic'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('performance.n.01')
# Senso Target:  Lemma('performance.n.03.performance')
# ------------------------------
# Parola da disambiguare:  freshman
# Frase in cui compare la parola:  Moritz came to Texas in 1954 but his freshman football efforts were hampered by a knee injury .
# Contesto della frase:  {'football', 'injury', 'effort', 'texas', 'moritz', 'freshman', 'hamper', 'knee'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('freshman.n.01')
# Senso Target:  Lemma('freshman.n.01.freshman')
# ------------------------------
# Parola da disambiguare:  entry
# Frase in cui compare la parola:  Skorich was considered the logical choice after the club gave Norm Van Brocklin permission to seek the head coaching job with the Minnesota Vikings , the newest National Football League entry .
# Contesto della frase:  {'football', 'coach', 'norm', 'national', 'seek', 'permission', 'logical', 'head', 'vikings', 'brocklin', 'job', 'consider', 'choice', 'van', 'club', 'minnesota', 'entry', 'league', 'skorich'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('entry.n.01')
# Senso Target:  Lemma('submission.n.01.entry')
# ------------------------------
# Parola da disambiguare:  mark
# Frase in cui compare la parola:  Both were under the meet mark of 1.10.8 set in 1950 by Mal Whitfield .
# Contesto della frase:  {'whitfield', 'set', 'meet', 'mark', 'mal'}
# Max Signature:  {'set', 'lord', 'disgrace', 'symbol', 'infamy', 'genesis', 'mark', 'cain'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('mark.n.06')
# Senso Target:  Lemma('mark.n.01.mark')
# ------------------------------
# Parola da disambiguare:  housewife
# Frase in cui compare la parola:  Mrs. Grace Butcher , of nearby Chardon , a 27 - year old housewife who has two children , finished in 2.21.6 .
# Contesto della frase:  {'housewife', 'child', 'grace', 'chardon', 'year', 'finish', 'nearby', 'butcher'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('housewife.n.01')
# Senso Target:  Lemma('housewife.n.01.housewife')
# ------------------------------
# Parola da disambiguare:  mood
# Frase in cui compare la parola:  It was the first of two doubles by Robinson , who was in a mood to celebrate .
# Contesto della frase:  {'celebrate', 'double', 'robinson', 'mood'}
# Max Signature:  {'national', 'change', 'mood', 'psychological', 'opinion', 'radically', 'prevailing', 'climate', 'election'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('climate.n.02')
# Senso Target:  Lemma('temper.n.02.mood')
# ------------------------------
# Termini valutati:  51
# Termini valutati correttamente:  33
# Accuratezza:  0.66

# %% [markdown]
# CONSEGNA 2.2:
#
# Sulla base della consegna precendente, randomizzare la selezione delle 50 frasi e la selezione del termine da disambiguare, e restituire l’accuratezza media su (per esempio) 10 esecuzioni del programma.

# %%
tokenizer = RegexpTokenizer(r'\w+')

EXECUTIONS = 10 #numero massimo di esecuzioni
INDEXES_NUM = 7000 #è il limite, partendo da 0, di sentence che possono essere testate relative al database SemCor
RANGE = 50 #è il numero di sentence che effettivamente verranno testate in ogni esecuzione        

sentences_tag = semcor.tagged_sents()
sentences = semcor.sents()
sentences_sem = semcor.tagged_sents(tag = "sem")

def main():
    accuracy_list = []
    for execution in range(1,EXECUTIONS + 1):
        evaluated = 0 #termini valutati
        checked = 0 #termini valutati correttamente
        index_evaluated = set() #insieme degli indici già valutati
        while(evaluated <= RANGE):
            while True: #fino a quando non trova una word che può essere presa in considerazione  
                index = get_random_index(index_evaluated, INDEXES_NUM)
                word = get_random_word(get_dictionary_tag(sentences_tag[index],sentences_sem[index]))
                if word:
                    break
            sentence = sentences[index]
            print("Parola da disambiguare: ",word)
            #all'algoritmo di lesk viene dato in input la word e l'insieme dei termini che formano la frase, uniti sottoforma di stringa
            best_sense = str(lesk_algorithm(word, ' '.join(word for word in sentence), word_type='ALL'))
            print("Senso attribuito dall'algoritmo di Lesk: ",best_sense)
            target_lemma = get_synset_target_for_word_in_sentence(word,sentences_sem[index])
            print("Senso Target: ",target_lemma)
            best_sense_lemma = best_sense[8:len(best_sense)-2]
            if target_lemma:
                if best_sense_lemma in target_lemma: checked= checked + 1
            evaluated += 1
            print("------------------------------")
        
        print("Termini valutati: ", evaluated)
        print("Termini valutati correttamente: ", checked)
        accuracy = checked/RANGE
        print("Accuratezza: ", accuracy)
        accuracy_list.append(accuracy)
        
    print()
    print("Esecuzioni: ",EXECUTIONS)
    print("Lista delle accuratezze: ", accuracy_list)
    print("Accuratezza media: ",mean(accuracy_list))
    
main()
# Out:
# Parola da disambiguare:  monaural
# Frase in cui compare la parola:  This is a characteristic of good stereo recording and one of its tremendous advantages over monaural sound .
# Contesto della frase:  {'sound', 'characteristic', 'advantage', 'tremendous', 'stereo', 'good', 'recording', 'monaural'}
# Max Signature:  {'deafness', 'ear', 'relate', 'monaural', 'hear'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('monaural.a.01')
# Senso Target:  Lemma('monaural.a.01.monaural')
# ------------------------------
# Parola da disambiguare:  indicated
# Frase in cui compare la parola:  This is , of course , a similar type of behavior to that indicated by birefringence studies .
# Contesto della frase:  {'type', 'study', 'behavior', 'birefringence', 'course', 'indicate'}
# Max Signature:  {'severe', 'serious', 'indicator', 'behavior', 'neurosis', 'point', 'signal', 'illness', 'euro', 'undervalue', 'economic', 'indicate', 'symptom'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('bespeak.v.01')
# Senso Target:  Lemma('indicate.v.02.indicate')
# ------------------------------
# Parola da disambiguare:  wound
# Frase in cui compare la parola:  By early summer , he wrote from Laramie that he was suffering from the wound inflicted in the ambush and was in a bad way financially , so Pels sent him a draft for $ 100 , warning that it was still not wise for him to return .
# Contesto della frase:  {'laramie', 'financially', 'draft', 'write', 'pels', 'wise', 'wound', 'warning', 'bad', 'early', 'return', 'summer', 'inflict', 'ambush', 'send', 'suffer'}
# Max Signature:  {'inflict', 'wound'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('wound.n.04')
# Senso Target:  Lemma('wound.n.01.wound')
# ------------------------------
# Parola da disambiguare:  refrigerated
# Frase in cui compare la parola:  Today , refrigerated carriers have made the shipping of avocados possible to any place in the world .
# Contesto della frase:  {'refrigerate', 'avocados', 'shipping', 'today', 'place', 'carrier'}
# Max Signature:  {'food', 'refrigerate', 'spoil', 'preserve', 'chill'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('refrigerate.v.01')
# Senso Target:  Lemma('refrigerated.s.01.refrigerated')
# ------------------------------
# Parola da disambiguare:  entirely
# Frase in cui compare la parola:  For example , the marked susceptibility of the monkey to respiratory infection might be related to its delicate , long alveolar ducts and short , large bronchioles situated within a parenchyma entirely lacking in protective supportive tissue barriers such as those found in types 1 , and 3 , .
# Contesto della frase:  {'alveolar', 'delicate', 'example', 'parenchyma', 'entirely', 'respiratory', 'situate', 'monkey', 'infection', 'large', 'type', 'short', 'lack', 'bronchiole', 'supportive', 'tissue', 'barrier', 'marked', 'protective', 'relate', 'susceptibility', 'duct', 'find', 'long'}
# Max Signature:  {'altogether', 'convinced', 'direction', 'degree', 'completely', 'totally', 'wholly', 'situation', 'entirely', 'expect', 'idea', 'approach', 'informally', 'meal', 'entire', 'fault', 'full', 'complete', 'wrong', 'satisfy', 'extent'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('wholly.r.01')
# Senso Target:  Lemma('wholly.r.01.entirely')
# ------------------------------
# Parola da disambiguare:  increase
# Frase in cui compare la parola:  The quiescent level of centimeter wave-length solar radiation would increase the average disk brightness temperature by less than 1 ` K .
# Contesto della frase:  {'wavelength', 'brightness', 'quiescent', 'level', 'centimeter', 'radiation', 'average', 'temperature', 'increase', 'solar', 'disk'}
# Max Signature:  {'schedule', 'change', 'month', 'increase', 'result'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('increase.n.02')
# Senso Target:  Lemma('increase.v.01.increase')
# ------------------------------
# Parola da disambiguare:  transfer
# Frase in cui compare la parola:  The heat transfer to the anode is due to the following effects : 1 .
# Contesto della frase:  {'transfer', 'anode', 'heat'}
# Max Signature:  {'transfer', 'lsu', 'position', 'student', 'best'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('transfer.n.02')
# Senso Target:  Lemma('transportation.n.02.transfer')
# ------------------------------
# Parola da disambiguare:  sake
# Frase in cui compare la parola:  ( Several times recently I have wondered whether shows were being staged for the sake of the script or just to entertain the audience with the spectacle of scenery being shifted right in front of their eyes .
# Contesto della frase:  {'script', 'wonder', 'audience', 'shift', 'sake', 'front', 'scenery', 'stag', 'spectacle', 'entertain', 'time', 'eye'}
# Max Signature:  {'reason', 'common', 'sake', 'safety', 'country', 'interest', 'die'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('sake.n.01')
# Senso Target:  Lemma('sake.n.01.sake')
# ------------------------------
# Parola da disambiguare:  hear
# Frase in cui compare la parola:  Dallas may get to hear a debate on horse race parimutuels soon between Reps. V. E. Red Berry and Joe Ratcliff .
# Contesto della frase:  {'reps', 'ratcliff', 'parimutuel', 'debate', 'red', 'horse', 'dallas', 'berry', 'joe', 'race', 'hear'}
# Max Signature:  {'case', 'jury', 'examine', 'judicial', 'california', 'evidence', 'process', 'hear'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('hear.v.03')
# Senso Target:  Lemma('hear.v.01.hear')
# ------------------------------
# Parola da disambiguare:  employed
# Frase in cui compare la parola:  George Woodcock was manager and troubleshooter ; Elizabeth Way was the first operator ; and a night operator was also employed .
# Contesto della frase:  {'employ', 'george', 'night', 'manager', 'woodcock', 'operator', 'elizabeth', 'troubleshooter'}
# Max Signature:  {'natural', 'apply', 'utilize', 'bag', 'plastic', 'good', 'thinking', 'cant', 'head', 'doesnt', 'project', 'employ', 'service', 'inherent', 'spanish', 'computer', 'work', 'field', 'magnetic', 'store', 'food', 'tool', 'rule', 'purpose', 'result'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('use.v.01')
# Senso Target:  Lemma('hire.v.01.employ')
# ------------------------------
# Parola da disambiguare:  girls
# Frase in cui compare la parola:  There the middle one of the three curves denotes `` mean Skeletal Age '' for the Maturity Series boys and girls .
# Contesto della frase:  {'series', 'girl', 'boy', 'age', 'middle', 'maturity', 'skeletal', 'curve', 'denote'}
# Max Signature:  {'girl', 'ride', 'youthful', 'tricycle', 'baby', 'person', 'female', 'learn'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('female_child.n.01')
# Senso Target:  Lemma('female_child.n.01.girl')
# ------------------------------
# Parola da disambiguare:  evaporate
# Frase in cui compare la parola:  Miscellaneous soils , which primarily include sticky substances and colorless liquids which evaporate to leave a residue .
# Contesto della frase:  {'substance', 'include', 'colorless', 'miscellaneous', 'evaporate', 'sticky', 'liquid', 'residue', 'leave', 'soil'}
# Max Signature:  {'residue', 'evaporate', 'liquid', 'milk', 'leave', 'vaporization', 'lose', 'concentrated'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('evaporate.v.01')
# Senso Target:  Lemma('evaporate.v.01.evaporate')
# ------------------------------
# Parola da disambiguare:  wailed
# Frase in cui compare la parola:  Then the pixies and the zombies took over while the banshees wailed in the distance .
# Contesto della frase:  {'wail', 'distance', 'banshee', 'zombie', 'pixy'}
# Max Signature:  {'selfpity', 'wail', 'howl', 'loud', 'long', 'sorrow', 'emit', 'cry'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('howl.v.01')
# Senso Target:  Lemma('howl.v.01.wail')
# ------------------------------
# Parola da disambiguare:  weapons
# Frase in cui compare la parola:  Warren and White each carried , in addition to their own weapons and ammo , a box of ammo for the ROK 's machine gun .
# Contesto della frase:  {'rok', 'machine', 'box', 'warren', 'ammo', 'addition', 'weapon', 'carry', 'white', 'gun'}
# Max Signature:  {'instrument', 'hunt', 'weapon', 'carry', 'license', 'fight', 'instrumentality'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('weapon.n.01')
# Senso Target:  Lemma('weapon.n.01.weapon')
# ------------------------------
# Parola da disambiguare:  disappeared
# Frase in cui compare la parola:  But it had largely disappeared on account of protest by the whites and through growing resentment on the part of the Negroes as they became more educated and got better wages .
# Contesto della frase:  {'wage', 'account', 'protest', 'resentment', 'white', 'good', 'disappear', 'grow', 'educated', 'negroes'}
# Max Signature:  {'warn', 'explanation', 'lose', 'disappear', 'trace'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('disappear.v.01')
# Senso Target:  Lemma('disappear.v.01.disappear')
# ------------------------------
# Parola da disambiguare:  church
# Frase in cui compare la parola:  The church certainly would not be removed .
# Contesto della frase:  {'church', 'remove'}
# Max Signature:  {'church', 'public', 'worship', 'christian', 'empty', 'place'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('church.n.02')
# Senso Target:  Lemma('church.n.02.church')
# ------------------------------
# Parola da disambiguare:  argument
# Frase in cui compare la parola:  The functions f and b have exactly the same multiplicity at every argument t .
# Contesto della frase:  {'function', 'argument', 'multiplicity', 'exactly'}
# Max Signature:  {'assertion', 'argument', 'true', 'strong', 'offer', 'evidence', 'fact', 'hypothesis'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('argument.n.01')
# Senso Target:  Lemma('argument.n.01.argument')
# ------------------------------
# Parola da disambiguare:  possessive
# Frase in cui compare la parola:  The old man was almost too possessive .
# Contesto della frase:  {'possessive', 'man'}
# Max Signature:  {'express', 'possession', 'genitive', 'pronoun', 'possessive', 'serve', 'indicate'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('possessive.a.01')
# Senso Target:  Lemma('possessive.s.02.possessive')
# ------------------------------
# Parola da disambiguare:  hard
# Frase in cui compare la parola:  `` We 'll work hard Tuesday , Wednesday and Thursday '' , Meek said , `` and probably will have a good scrimmage Friday .
# Contesto della frase:  {'tuesday', 'friday', 'meek', 'work', 'good', 'thursday', 'wednesday', 'hard', 'scrimmage', 'll'}
# Max Signature:  {'pace', 'heavy', 'grueling', 'laborious', 'campaign', 'arduous', 'physical', 'project', 'hard', 'punishing', 'exhaustion', 'characterize', 'spend', 'work', 'set', 'effort', 'valley', 'mining', 'hour', 'point', 'labor'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('arduous.s.01')
# Senso Target:  Lemma('hard.r.01.hard')
# ------------------------------
# Parola da disambiguare:  low
# Frase in cui compare la parola:  West Berlin morale is low and , in age distribution , the situation is unfavorable .
# Contesto della frase:  {'west', 'distribution', 'morale', 'berlin', 'age', 'situation', 'low', 'unfavorable'}
# Max Signature:  {'bring', 'air', 'night', 'sleet', 'snow', 'move', 'precipitation', 'pressure', 'low', 'mass'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('low.n.01')
# Senso Target:  Lemma('low.a.01.low')
# ------------------------------
# Parola da disambiguare:  timed
# Frase in cui compare la parola:  Mills was timed in 1.10.4 .
# Contesto della frase:  {'time', 'mills'}
# Max Signature:  {'clock', 'runner', 'period', 'time', 'action', 'measure', 'duration', 'event', 'perform', 'person'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('clock.v.01')
# Senso Target:  Lemma('clock.v.01.time')
# ------------------------------
# Parola da disambiguare:  naturally
# Frase in cui compare la parola:  There is some evidence that naturally occurring goitrogens may play a role in the development of goitre , particularly in Tasmania and Australia ( Clements and Wishart , 1956 ) .
# Contesto della frase:  {'naturally', 'australia', 'clements', 'play', 'development', 'occur', 'wishart', 'role', 'goitrogen', 'evidence', 'goitre', 'tasmania'}
# Max Signature:  {'naturally', 'huge', 'lawyer', 'bill', 'send', 'expect'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('naturally.r.01')
# Senso Target:  Lemma('naturally.r.02.naturally')
# ------------------------------
# Parola da disambiguare:  position
# Frase in cui compare la parola:  But ask coach Darrell Royal what position he plays and you 'll get the quick response , `` place kicker '' .
# Contesto della frase:  {'coach', 'darrell', 'response', 'play', 'position', 'kicker', 'royal', 'quick', 'll', 'place'}
# Max Signature:  {'stage', 'piece', 'clock', 'property', 'relation', 'position', 'furniture', 'spatial', 'hand', 'situate', 'place'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('position.n.07')
# Senso Target:  Lemma('position.n.09.position')
# ------------------------------
# Parola da disambiguare:  sixty
# Frase in cui compare la parola:  Yet one has to go back only some sixty years .
# Contesto della frase:  {'year'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('sixty.n.01')
# Senso Target:  Lemma('sixty.s.01.sixty')
# ------------------------------
# Parola da disambiguare:  third
# Frase in cui compare la parola:  At the end of the run , the strips in the third and sixth positions in each chamber were dried , stained for 1 hr , washed and dried , while the other strips were maintained in a horizontal position at 1 ` C .
# Contesto della frase:  {'dry', 'stain', 'horizontal', 'sixth', 'position', 'strip', 'maintain', 'wash', 'third', 'hr', 'chamber'}
# Max Signature:  {'count', 'infield', 'counterclockwise', 'fielding', 'play', 'base', 'position', 'baseball', 'player', 'third', 'station', 'plate', 'team'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('third_base.n.02')
# Senso Target:  Lemma('third.s.01.third')
# ------------------------------
# Parola da disambiguare:  logical
# Frase in cui compare la parola:  At the least , however , one may conclude that Geometric potters sensed a logical order ; their principles of composition stand very close to those which appear in the Homeric epics and the hexameter line .
# Contesto della frase:  {'logical', 'composition', 'epic', 'hexameter', 'sense', 'geometric', 'appear', 'homeric', 'principle', 'stand', 'order', 'potter', 'conclude', 'close'}
# Max Signature:  {'logical', 'capable', 'mind', 'capability', 'correct', 'valid', 'reasoning', 'reflect'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('logical.a.01')
# Senso Target:  Lemma('logical.a.01.logical')
# ------------------------------
# Parola da disambiguare:  cliches
# Frase in cui compare la parola:  They not only think and feel cliches but live cliches as well .
# Contesto della frase:  {'feel', 'well', 'cliche', 'live'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('platitude.n.01')
# Senso Target:  Lemma('platitude.n.01.cliche')
# ------------------------------
# Parola da disambiguare:  parties
# Frase in cui compare la parola:  That settled it , and we broke into parties of two and three .
# Contesto della frase:  {'party', 'settle', 'break'}
# Max Signature:  {'gain', 'organize', 'national', 'organization', 'power', 'political', 'perot', 'level', 'party', 'third'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('party.n.01')
# Senso Target:  Lemma('party.n.03.party')
# ------------------------------
# Parola da disambiguare:  curves
# Frase in cui compare la parola:  Near Q , both curves can be represented by analytic functions of u .
# Contesto della frase:  {'function', 'represent', 'analytic', 'curve'}
# Max Signature:  {'data', 'graph', 'represent'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('curve.n.02')
# Senso Target:  Lemma('curve.n.01.curve')
# ------------------------------
# Parola da disambiguare:  driven
# Frase in cui compare la parola:  How could the rich , for whom life was made so simple , ever understand the subterfuges , the lies , the frauds , the errors , sins and even crimes to which the poor were driven in their efforts to overcome the great advantages the rich had in the race of life ?
# Contesto della frase:  {'understand', 'advantage', 'race', 'life', 'fraud', 'sin', 'simple', 'poor', 'effort', 'drive', 'overcome', 'great', 'rich', 'error', 'crime', 'lie', 'subterfuge'}
# Max Signature:  {'goal', 'doctoral', 'effort', 'tug', 'push', 'reach', 'living', 'deadline', 'year', 'decent', 'drive', 'thesis', 'strive'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('tug.v.02')
# Senso Target:  Lemma('drive.v.07.drive')
# ------------------------------
# Parola da disambiguare:  celestial
# Frase in cui compare la parola:  This and other fears of the solar system have disappeared gradually , first , with the Ptolemaic system and its built-in concept of periodicity and then , more firmly , with the Newtonian innovation of an universal force that could account quantitatively for both terrestrial and celestial motions .
# Contesto della frase:  {'firmly', 'celestial', 'ptolemaic', 'concept', 'builtin', 'motion', 'newtonian', 'fear', 'quantitatively', 'force', 'system', 'periodicity', 'universal', 'solar', 'disappear', 'gradually', 'terrestrial', 'account', 'innovation'}
# Max Signature:  {'body', 'sky', 'map', 'relate', 'celestial', 'heavenly'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('celestial.a.01')
# Senso Target:  Lemma('celestial.a.01.celestial')
# ------------------------------
# Parola da disambiguare:  machines
# Frase in cui compare la parola:  Mrs. Shaefer never got around to joining the thousand or so people who paid Lee some $ 30000 for his ozone machines .
# Contesto della frase:  {'machine', 'join', 'people', 'ozone', 'pay', 'shaefer', 'lee'}
# Max Signature:  {'machine', 'efficient', 'boxer', 'fighting', 'person', 'magnificent'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('machine.n.02')
# Senso Target:  Lemma('machine.n.01.machine')
# ------------------------------
# Parola da disambiguare:  fellow
# Frase in cui compare la parola:  `` He recommended both of them for the DSM and the Detroit fellow for the Purple Heart , too , for a combat inflicted wound .
# Contesto della frase:  {'combat', 'fellow', 'recommend', 'wound', 'dsm', 'detroit', 'heart', 'inflict', 'purple'}
# Max Signature:  {'host', 'cuss', 'boy', 'fellow', 'good', 'door', 'bloke', 'man', 'likable', 'chap'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('chap.n.01')
# Senso Target:  Lemma('chap.n.01.fellow')
# ------------------------------
# Parola da disambiguare:  basking
# Frase in cui compare la parola:  Port Jervis , basking in the foothills , was the city of God .
# Contesto della frase:  {'god', 'basking', 'foothill', 'jervis', 'city', 'port'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('enjoy.v.01')
# Senso Target:  Lemma('bask.v.02.bask')
# ------------------------------
# Parola da disambiguare:  bed
# Frase in cui compare la parola:  Rachel said , `` I 'd better get him to bed '' .
# Contesto della frase:  {'bed', 'rachel', 'well'}
# Max Signature:  {'bed', 'chair', 'piece', 'room', 'sit', 'provide', 'sleep', 'furniture', 'edge', 'place'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('bed.n.01')
# Senso Target:  Lemma('bed.n.01.bed')
# ------------------------------
# Parola da disambiguare:  stealing
# Frase in cui compare la parola:  They caught Trig stealing liquor from the officers ' mess , and he got a couple of girls in trouble .
# Contesto della frase:  {'girl', 'officer', 'catch', 'steal', 'trig', 'couple', 'mess', 'trouble', 'liquor'}
# Max Signature:  {'paragraph', 'steal', 'owner', 'entire', 'train', 'author', 'stole', 'wallet', 'consent', 'dissertation'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('steal.v.01')
# Senso Target:  Lemma('steal.v.01.steal')
# ------------------------------
# Parola da disambiguare:  deny
# Frase in cui compare la parola:  But they deny the values of the city - the crowded , competitive , tolerant city , the `` melting pot '' which gave off so many of the most admirable American qualities .
# Contesto della frase:  {'competitive', 'crowded', 'tolerant', 'melting', 'quality', 'pot', 'city', 'deny', 'admirable', 'american'}
# Max Signature:  {'declare', 'contradict', 'untrue', 'money', 'deny', 'allegation'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('deny.v.01')
# Senso Target:  Lemma('deny.v.02.deny')
# ------------------------------
# Parola da disambiguare:  lived
# Frase in cui compare la parola:  He remembered exactly when he had lived through it before , and he had something to prove he had .
# Contesto della frase:  {'remember', 'prove', 'live', 'exactly'}
# Max Signature:  {'people', 'ago', 'dwells', 'live', 'inhabit', 'inhabitant', 'desert', 'wood', 'africa', 'year', 'island', 'fish', 'ocean', 'populate', 'kind', 'deer', 'bottom'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('populate.v.01')
# Senso Target:  Lemma('live.v.02.live')
# ------------------------------
# Parola da disambiguare:  1
# Frase in cui compare la parola:  1 time ?
# Contesto della frase:  {'time'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('one.n.01')
# Senso Target:  Lemma('one.s.01.1')
# ------------------------------
# Parola da disambiguare:  pause
# Frase in cui compare la parola:  The sets are remarkably elaborate for a road-show that does n't pause long in any one place , and they are devised so that they shift with a minimum of interruption or obtrusiveness .
# Contesto della frase:  {'set', 'nt', 'remarkably', 'roadshow', 'obtrusiveness', 'shift', 'elaborate', 'devise', 'interruption', 'minimum', 'long', 'place', 'pause'}
# Max Signature:  {'speaker', 'interrupt', 'continue', 'temporarily', 'activity', 'pause'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('hesitate.v.02')
# Senso Target:  Lemma('pause.v.02.pause')
# ------------------------------
# Parola da disambiguare:  pulmonary
# Frase in cui compare la parola:  A reason for such wide variation in the pulmonary morphology is entirely lacking at present .
# Contesto della frase:  {'reason', 'wide', 'lack', 'morphology', 'variation', 'entirely', 'pulmonary'}
# Max Signature:  {'affect', 'relate', 'disease', 'pulmonary', 'lung'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('pneumonic.a.02')
# Senso Target:  Lemma('pneumonic.a.02.pulmonary')
# ------------------------------
# Parola da disambiguare:  revision
# Frase in cui compare la parola:  Two tax revision bills were passed .
# Contesto della frase:  {'pass', 'tax', 'bill', 'revision'}
# Max Signature:  {'alter', 'modification', 'require', 'revise', 'opinion', 'revision', 'drastic', 'involve', 'reconsideration'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('revision.n.01')
# Senso Target:  Lemma('rewrite.n.01.revision')
# ------------------------------
# Parola da disambiguare:  methods
# Frase in cui compare la parola:  On the one side we have the university professors and their students , trained in Teutonic methods of research , who have sought out , collected and studied the true products of the oral traditions of the ethnic , regional and occupational groups that make up this nation .
# Contesto della frase:  {'nation', 'group', 'teutonic', 'collect', 'regional', 'seek', 'oral', 'occupational', 'side', 'train', 'student', 'ethnic', 'tradition', 'method', 'product', 'true', 'study', 'professor', 'university'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('method.n.01')
# Senso Target:  Lemma('method.n.01.method')
# ------------------------------
# Parola da disambiguare:  commute
# Frase in cui compare la parola:  Since D and D ' are both diagonalizable and they commute , they are simultaneously diagonalizable , and * * f is diagonalizable .
# Contesto della frase:  {'commute', 'diagonalizable', 'simultaneously'}
# Max Signature:  {'distance', 'regular', 'room', 'work', 'stand', 'commute', 'highspeed', 'journey', 'place'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('commute.n.01')
# Senso Target:  Lemma('commute.v.01.commute')
# ------------------------------
# Parola da disambiguare:  result
# Frase in cui compare la parola:  Working in a vacuum of minimal information can result only in show pieces that look good in exhibitions and catalogs and may please the public relations department but have little to do with the essence of interior design .
# Contesto della frase:  {'essence', 'minimal', 'piece', 'exhibition', 'catalog', 'design', 'relation', 'interior', 'working', 'public', 'good', 'vacuum', 'department', 'result'}
# Max Signature:  {'peaceful', 'answer', 'book', 'decimal', 'compute', 'explain', 'result', 'find', 'solve', 'statement', 'solution', 'problem', 'place'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('solution.n.02')
# Senso Target:  Lemma('leave.v.07.result')
# ------------------------------
# Parola da disambiguare:  generally
# Frase in cui compare la parola:  Opponents generally argued that the ballot could n't give enough information about tax proposals for the voters to make an intelligent choice .
# Contesto della frase:  {'tax', 'ballot', 'opponents', 'nt', 'intelligent', 'argue', 'voter', 'choice', 'generally', 'proposal'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('by_and_large.r.01')
# Senso Target:  Lemma('by_and_large.r.01.generally')
# ------------------------------
# Parola da disambiguare:  bees
# Frase in cui compare la parola:  The only exception to this is certain bees that have become parasites .
# Contesto della frase:  {'bee', 'parasite', 'exception'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('bee.n.01')
# Senso Target:  Lemma('bee.n.01.bee')
# ------------------------------
# Parola da disambiguare:  proved
# Frase in cui compare la parola:  Besides being most convenient , the line `` soon proved a good investment for the owners '' .
# Contesto della frase:  {'owner', 'good', 'investment', 'convenient', 'prove'}
# Max Signature:  {'turn', 'life', 'save', 'positive', 'find', 'medicine', 'hiv', 'prove'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('prove.v.01')
# Senso Target:  Lemma('prove.v.01.prove')
# ------------------------------
# Parola da disambiguare:  Naturally
# Frase in cui compare la parola:  Naturally , a park site with scenic views , a good lake , trees , and sand dunes , will attract more people than a nearby area with only trees and dunes .
# Contesto della frase:  {'naturally', 'site', 'sand', 'attract', 'dune', 'view', 'tree', 'people', 'area', 'lake', 'scenic', 'good', 'nearby', 'park'}
# Max Signature:  {'naturally', 'huge', 'lawyer', 'bill', 'send', 'expect'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('naturally.r.01')
# Senso Target:  Lemma('naturally.r.01.naturally')
# ------------------------------
# Parola da disambiguare:  man
# Frase in cui compare la parola:  `` Be sure the man nearest you is awake .
# Contesto della frase:  {'awake', 'man'}
# Max Signature:  {'human', 'word', 'man', 'generic', 'refer'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('man.n.03')
# Senso Target:  Lemma('man.n.01.man')
# ------------------------------
# Parola da disambiguare:  rifle
# Frase in cui compare la parola:  From above me and somewhere behind me , a rifle cracked .
# Contesto della frase:  {'crack', 'rifle'}
# Max Signature:  {'firearm', 'lift', 'shoulder', 'barrel', 'rifle', 'bore', 'long', 'fire'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('rifle.n.01')
# Senso Target:  Lemma('rifle.n.01.rifle')
# ------------------------------
# Termini valutati:  51
# Termini valutati correttamente:  24
# Accuratezza:  0.48
# Parola da disambiguare:  ahead
# Frase in cui compare la parola:  Cousin Joshua and some others felt that we should march toward Lexington and take up new positions ahead of the slow-moving British column , but another group maintained that we should stick to this spot and this section of road .
# Contesto della frase:  {'joshua', 'lexington', 'road', 'group', 'spot', 'position', 'cousin', 'stick', 'column', 'slowmoving', 'maintain', 'felt', 'british', 'ahead', 'march'}
# Max Signature:  {'straight', 'road', 'light', 'people', 'town', 'foggy', 'star', 'head', 'front', 'jesus', 'ahead', 'cross', 'march'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('ahead.r.01')
# Senso Target:  Lemma('ahead.r.01.ahead')
# ------------------------------
# Parola da disambiguare:  sat
# Frase in cui compare la parola:  Jane sat receptive and interested .
# Contesto della frase:  {'interested', 'sit', 'receptive', 'jane'}
# Max Signature:  {'idly', 'corner', 'sit', 'hour', 'chat', 'specific', 'purpose', 'object', 'sat'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('sit.v.02')
# Senso Target:  Lemma('sit.v.01.sit')
# ------------------------------
# Parola da disambiguare:  avocado
# Frase in cui compare la parola:  Once you become an avocado fan , you will look forward to the season each year with eager anticipation .
# Contesto della frase:  {'avocado', 'forward', 'fan', 'season', 'year', 'eager', 'anticipation'}
# Max Signature:  {'avocado', 'dull', 'meat', 'green', 'yellowish'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('avocado.s.01')
# Senso Target:  Lemma('avocado.n.01.avocado')
# ------------------------------
# Parola da disambiguare:  human
# Frase in cui compare la parola:  I am certainly not adequately trained to describe or enlarge on human fears , but there are certain features of the fears dispelled by scientific explanations that stand out quite clearly .
# Contesto della frase:  {'dispel', 'scientific', 'describe', 'human', 'explanation', 'train', 'adequately', 'clearly', 'stand', 'fear', 'enlarge', 'feature'}
# Max Signature:  {'human', 'characteristic', 'nature', 'humanity'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('human.a.01')
# Senso Target:  Lemma('human.a.01.human')
# ------------------------------
# Parola da disambiguare:  ball
# Frase in cui compare la parola:  Joe naturally ruled that a ball be dropped from alongside the spot where it had originally entered the stream .
# Contesto della frase:  {'naturally', 'enter', 'stream', 'spot', 'rule', 'ball', 'drop', 'originally', 'joe'}
# Max Signature:  {'hit', 'throw', 'mph', 'round', 'mayor', 'pocket', 'corner', 'roll', 'game', 'ball', 'object', 'serve', 'travel', 'kick'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('ball.n.01')
# Senso Target:  Lemma('ball.n.01.ball')
# ------------------------------
# Parola da disambiguare:  stronger
# Frase in cui compare la parola:  At first the patient felt stronger , and the hemoglobin rose to 13.8 gm. , but on Oct. 20 , 1958 , he complained of `` caving in '' in his knees .
# Contesto della frase:  {'strong', 'oct', 'complain', 'cave', 'felt', 'rise', 'hemoglobin', 'patient', 'gm', 'knee'}
# Max Signature:  {'strength', 'radio', 'strong', 'power', 'average', 'signal', 'great', 'man', 'medicine', 'expect'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('strong.a.01')
# Senso Target:  Lemma('strong.a.01.strong')
# ------------------------------
# Parola da disambiguare:  sale
# Frase in cui compare la parola:  The suburban branch is thereby credited with a sale which would have been made even if its glass doors had never opened .
# Contesto della frase:  {'suburban', 'sale', 'open', 'branch', 'door', 'credit', 'glass'}
# Max Signature:  {'sell', 'instance', 'complete', 'bank', 'sale', 'close'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('sale.n.01')
# Senso Target:  Lemma('sale.n.01.sale')
# ------------------------------
# Parola da disambiguare:  beard
# Frase in cui compare la parola:  A hundred years ago I would have worn a beard with pride .
# Contesto della frase:  {'pride', 'beard', 'year', 'wear'}
# Max Signature:  {'rim', 'chin', 'height', 'houses', 'top', 'beard'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('beard.v.01')
# Senso Target:  Lemma('beard.n.01.beard')
# ------------------------------
# Parola da disambiguare:  major
# Frase in cui compare la parola:  The only area in which one might find major disagreement in this matter is in regard to the alveolar distribution of the bronchial arteries .
# Contesto della frase:  {'alveolar', 'distribution', 'area', 'artery', 'matter', 'disagreement', 'find', 'major', 'bronchial', 'regard'}
# Max Signature:  {'linguistics', 'subject', 'study', 'student', 'university', 'field', 'principal', 'major'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('major.n.03')
# Senso Target:  Lemma('major.a.03.major')
# ------------------------------
# Parola da disambiguare:  reduce
# Frase in cui compare la parola:  The slippage of the drive belts caused the aerator to slow down and reduce oxygen transfer as well as the mixing of the raw sewage .
# Contesto della frase:  {'sewage', 'slow', 'reduce', 'transfer', 'raw', 'belt', 'mixing', 'drive', 'aerator', 'slippage', 'oxygen', 'well'}
# Max Signature:  {'cut', 'benefit', 'reduce', 'health', 'reduction', 'intake', 'daily', 'employer', 'fat'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('reduce.v.01')
# Senso Target:  Lemma('reduce.v.01.reduce')
# ------------------------------
# Parola da disambiguare:  deserving
# Frase in cui compare la parola:  No sympathy or admiration for Brown could be found in the Providence Daily Post , for the editor claimed that there were a score of men in the state prison who were a thousand times more deserving of sympathy .
# Contesto della frase:  {'sympathy', 'brown', 'men', 'prison', 'post', 'deserving', 'score', 'time', 'providence', 'find', 'editor', 'claim', 'daily', 'admiration'}
# Max Signature:  {'worth', 'poor', 'deserving', 'worthy', 'treat', 'consider', 'ironically', 'idea'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('deserving.s.01')
# Senso Target:  Lemma('deserving.s.01.deserving')
# ------------------------------
# Parola da disambiguare:  broad
# Frase in cui compare la parola:  Those antisera shown by immunoelectrophoresis to be of the `` broad spectrum '' type were selected for used in the present study .
# Contesto della frase:  {'type', 'select', 'broad', 'study', 'spectrum', 'antiserum', 'immunoelectrophoresis'}
# Max Signature:  {'scope', 'pay', 'grant', 'tgwinner', 'increase', 'humanrights', 'definition', 'broad', 'blanket', 'allembracing', 'study', 'violator', 'content', 'panoptic', 'wide', 'sanction', 'power', 'nationality', 'application', 'soviet', 'acrosstheboard'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('across-the-board.s.01')
# Senso Target:  Lemma('across-the-board.s.01.broad')
# ------------------------------
# Parola da disambiguare:  interest
# Frase in cui compare la parola:  It is of interest that her menarche was somewhat later than the average for the girls in this group .
# Contesto della frase:  {'girl', 'menarche', 'group', 'average', 'late', 'interest'}
# Max Signature:  {'production', 'common', 'group', 'member', 'control', 'iron', 'social', 'field', 'step', 'plural', 'activity', 'aim', 'interest'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('interest.n.06')
# Senso Target:  Lemma('interest.n.01.interest')
# ------------------------------
# Parola da disambiguare:  locate
# Frase in cui compare la parola:  The underlying assumption , of course , is that only sight and touch enable us , in any precise and fully dependable way , to locate objects in space beyond us , the other senses being decidedly inferior , if not totally inadequate , in this regard .
# Contesto della frase:  {'fully', 'precise', 'touch', 'locate', 'space', 'dependable', 'sight', 'assumption', 'totally', 'underlying', 'course', 'object', 'inferior', 'sens', 'inadequate', 'decidedly', 'enable', 'regard'}
# Max Signature:  {'site', 'locate', 'instrument', 'survey', 'sense', 'boundary', 'property', 'sight', 'enables', 'object', 'determine', 'space', 'limit', 'indicate', 'place'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('situate.v.01')
# Senso Target:  Lemma('situate.v.01.locate')
# ------------------------------
# Parola da disambiguare:  finished
# Frase in cui compare la parola:  Other lettermen from the team that compiled a 21 - 9 record and finished as runner-up in the National Invitation Tournament were : Art Hambric , Donnell Reid , Bill Nordmann , Dave Harris , Dave Luechtefeld and George Latinovich .
# Contesto della frase:  {'george', 'national', 'dave', 'harris', 'record', 'latinovich', 'runnerup', 'donnell', 'hambric', 'luechtefeld', 'letterman', 'art', 'compile', 'tournament', 'team', 'bill', 'reid', 'invitation', 'nordmann', 'finish'}
# Max Signature:  {'fast', 'bring', 'race', 'runner', 'dish', 'complete', 'hour', 'degree', 'masters', 'requirement', 'finish'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('complete.v.01')
# Senso Target:  Lemma('finish_up.v.02.finish')
# ------------------------------
# Parola da disambiguare:  places
# Frase in cui compare la parola:  It places certain values at least beyond questioning and tampering .
# Contesto della frase:  {'tamper', 'question', 'place'}
# Max Signature:  {'planet', 'locate', 'spot', 'surface', 'place', 'point', 'nice', 'bright', 'feature', 'picnic', 'respect', 'region'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('topographic_point.n.01')
# Senso Target:  Lemma('put.v.01.place')
# ------------------------------
# Parola da disambiguare:  hear
# Frase in cui compare la parola:  His eyes now fixed on White 's solid figure , Warren could hear behind him the tread of another .
# Contesto della frase:  {'warren', 'figure', 'tread', 'hear', 'white', 'solid', 'eye'}
# Max Signature:  {'case', 'jury', 'examine', 'judicial', 'california', 'evidence', 'process', 'hear'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('hear.v.03')
# Senso Target:  Lemma('hear.v.01.hear')
# ------------------------------
# Parola da disambiguare:  practice
# Frase in cui compare la parola:  You could n't on the one hand decry the arts and at the same time practice them , could you ?
# Contesto della frase:  {'nt', 'hand', 'time', 'practice', 'art', 'decry'}
# Max Signature:  {'raise', 'dietary', 'change', 'behavior', 'operation', 'annual', 'pattern', 'practice', 'customary'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('practice.n.01')
# Senso Target:  Lemma('practice.n.04.practice')
# ------------------------------
# Parola da disambiguare:  young
# Frase in cui compare la parola:  The movie was The Great Train Robbery and its effects on the young industry and art were all but incalculable .
# Contesto della frase:  {'young', 'art', 'incalculable', 'train', 'movie', 'great', 'industry', 'robbery'}
# Max Signature:  {'young', 'stage', 'early', 'day', 'industry'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('young.s.04')
# Senso Target:  Lemma('young.a.01.young')
# ------------------------------
# Parola da disambiguare:  lightly
# Frase in cui compare la parola:  This time Rachel kissed him lightly on the forehead .
# Contesto della frase:  {'forehead', 'kiss', 'lightly', 'time', 'rachel'}
# Max Signature:  {'forehead', 'kiss', 'weight', 'lightly', 'force'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('lightly.r.03')
# Senso Target:  Lemma('lightly.r.05.lightly')
# ------------------------------
# Parola da disambiguare:  16
# Frase in cui compare la parola:  He had a 16 .
# Contesto della frase:  set()
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('sixteen.n.01')
# Senso Target:  Lemma('sixteen.n.01.16')
# ------------------------------
# Parola da disambiguare:  agree
# Frase in cui compare la parola:  The values agree with the data from 1958 Alpha and 1959 Eta .
# Contesto della frase:  {'data', 'alpha', 'eta', 'agree'}
# Max Signature:  {'hold', 'settlement', 'life', 'agreement', 'accord', 'sacred', 'term', 'point', 'philosopher', 'agree', 'concord', 'cant'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('agree.v.01')
# Senso Target:  Lemma('harmonize.v.01.agree')
# ------------------------------
# Parola da disambiguare:  braced
# Frase in cui compare la parola:  He braced himself .
# Contesto della frase:  {'brace'}
# Max Signature:  {'steady', 'elbow', 'work', 'brace', 'steadfast', 'potter', 'support', 'wheel', 'hold'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('brace.v.02')
# Senso Target:  Lemma('brace.v.01.brace')
# ------------------------------
# Parola da disambiguare:  powderpuff
# Frase in cui compare la parola:  The Orioles once again performed at the plate in powderpuff fashion , gathering only seven blows off the offerings of three Kansas City pitchers .
# Contesto della frase:  {'powderpuff', 'kansas', 'gather', 'blow', 'orioles', 'plate', 'fashion', 'city', 'offering', 'perform', 'pitcher'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('powderpuff.n.01')
# Senso Target:  Lemma('powder-puff.s.01.powder-puff')
# ------------------------------
# Parola da disambiguare:  school
# Frase in cui compare la parola:  The TEA estimated there would be 182 scholastics to attend the day school in Dallas County , saving them from coming to Austin to live in the state deaf school .
# Contesto della frase:  {'estimate', 'county', 'attend', 'save', 'tea', 'dallas', 'scholastic', 'school', 'live', 'austin', 'deaf', 'day'}
# Max Signature:  {'walk', 'period', 'didnt', 'stay', 'school', 'day', 'instruction', 'time', 'single', 'session'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('school.n.05')
# Senso Target:  Lemma('school.n.01.school')
# ------------------------------
# Parola da disambiguare:  substance
# Frase in cui compare la parola:  Obviously , a substance which is permanently or temporarily sorbed on the surface in place of the soil will tend to accelerate this process and effectively push off the greasy soil .
# Contesto della frase:  {'permanently', 'substance', 'effectively', 'sorb', 'surface', 'push', 'soil', 'accelerate', 'process', 'temporarily', 'tend', 'greasy', 'place'}
# Max Signature:  {'dna', 'substance', 'gene', 'consists', 'thing', 'real', 'physical', 'matter', 'person'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('substance.n.01')
# Senso Target:  Lemma('substance.n.01.substance')
# ------------------------------
# Parola da disambiguare:  exclaimed
# Frase in cui compare la parola:  `` C'est formidable '' , they exclaimed .
# Contesto della frase:  {'cest', 'exclaim', 'formidable'}
# Max Signature:  {'exclaim', 'joy', 'help', 'child', 'horror', 'surprise', 'shout', 'aloud', 'win', 'mother', 'lose', 'utter', 'cry'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('exclaim.v.01')
# Senso Target:  Lemma('exclaim.v.01.exclaim')
# ------------------------------
# Parola da disambiguare:  evokes
# Frase in cui compare la parola:  The horrifying humor , the specifically sexual embarrassment of the joke gone wrong , the monstrous image of the fat man dressed up as a whore dressing up as a baby ; the epiphany of that quivering flesh ; the bringing together around it of the secret liaison between indolent , mindless sensuality and sharp , shrewd talent , cleverness with an occasional touch of genius ( which , however , does not know `` how to attack the problem of suffering '' ) ; the miraculous way in which music , revelation and death are associated in a single instant - all this seems a triumph of art , a rather desperate art , in itself ; beyond itself , also , it evokes numerous and distant resonances from the entire body of Mann 's work .
# Contesto della frase:  {'shrewd', 'attack', 'liaison', 'monstrous', 'flesh', 'resonance', 'dress', 'man', 'baby', 'sharp', 'epiphany', 'genius', 'problem', 'embarrassment', 'occasional', 'music', 'touch', 'triumph', 'evoke', 'quiver', 'sexual', 'revelation', 'secret', 'single', 'entire', 'whore', 'miraculous', 'work', 'horrifying', 'sensuality', 'distant', 'mann', 'art', 'image', 'joke', 'fat', 'talent', 'cleverness', 'body', 'humor', 'numerous', 'desperate', 'bringing', 'indolent', 'mindless', 'associate', 'wrong', 'instant', 'death', 'suffer'}
# Max Signature:  {'sympathy', 'response', 'raise', 'evoke', 'pity', 'feeling', 'emotion', 'call', 'smile', 'arouse'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('arouse.v.01')
# Senso Target:  Lemma('provoke.v.02.evoke')
# ------------------------------
# Parola da disambiguare:  continues
# Frase in cui compare la parola:  The opinion continues here that with a 162 - game schedule , pitching spread thin through a 10 - team league and a most inviting target in Los Angeles ' Wrigley Field Jr. , Mantle just might break the most glamorous record on the books , Babe Ruth 's 60 homers of 1927 .
# Contesto della frase:  {'spread', 'ruth', 'pitch', 'game', 'jr', 'record', 'babe', 'mantle', 'book', 'glamorous', 'wrigley', 'target', 'opinion', 'los', 'field', 'angeles', 'inviting', 'team', 'schedule', 'break', 'league', 'continue', 'homer'}
# Max Signature:  {'break', 'demonstration', 'interruption', 'continue', 'lunch'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('continue.v.07')
# Senso Target:  Lemma('continue.v.01.continue')
# ------------------------------
# Parola da disambiguare:  negligible
# Frase in cui compare la parola:  The anode ablation could be reduced to a negligible amount .
# Contesto della frase:  {'negligible', 'ablation', 'amount', 'anode', 'reduce'}
# Max Signature:  {'insignificant', 'small', 'negligible', 'meaningless'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('negligible.s.01')
# Senso Target:  Lemma('negligible.s.01.negligible')
# ------------------------------
# Parola da disambiguare:  unique
# Frase in cui compare la parola:  These operators D and N are unique and each is a polynomial in T .
# Contesto della frase:  {'unique', 'polynomial', 'operator'}
# Max Signature:  {'unequaled', 'handling', 'altogether', 'unparalleled', 'law', 'problem', 'bach', 'radically', 'breakdown', 'penetration', 'theory', 'field', 'counterpoint', 'unique', 'equal', 'microbiology', 'ability', 'athletic', 'distinctive', 'history', 'craftsman', 'skill'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('alone.s.04')
# Senso Target:  unique.s.00
# ------------------------------
# Parola da disambiguare:  glad
# Frase in cui compare la parola:  I'm glad to say there 's none of that distraction in this `` Fiorello ! ''
# Contesto della frase:  {'distraction', 'glad', 'fiorello'}
# Max Signature:  {'occasion', 'joy', 'pleasure', 'shout', 'happy', 'glad', 'smile', 'succeed', 'heard', 'news'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('glad.a.01')
# Senso Target:  Lemma('glad.a.01.glad')
# ------------------------------
# Parola da disambiguare:  observe
# Frase in cui compare la parola:  Thus , if we are to observe American folklore in the twentieth century , we will do well to establish the relationships between folklore , nationalism and imperialism at the outset .
# Contesto della frase:  {'nationalism', 'century', 'twentieth', 'establish', 'relationship', 'folklore', 'outset', 'imperialism', 'observe', 'american', 'well'}
# Max Signature:  {'note', 'fine', 'sailing', 'day', 'time', 'mention', 'observe', 'presentation'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('note.v.01')
# Senso Target:  Lemma('note.v.03.observe')
# ------------------------------
# Parola da disambiguare:  regions
# Frase in cui compare la parola:  The cores of deep sea sediments and content of collectors in remote regions are valuable in this category .
# Contesto della frase:  {'category', 'sea', 'core', 'remote', 'valuable', 'sediment', 'deep', 'content', 'collector', 'region'}
# Max Signature:  {'space', 'religion', 'outer', 'france', 'farming', 'spatial', 'extended', 'location', 'region'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('region.n.01')
# Senso Target:  Lemma('region.n.03.region')
# ------------------------------
# Parola da disambiguare:  surely
# Frase in cui compare la parola:  This recording surely belongs in everyone 's collection .
# Contesto della frase:  {'belong', 'recording', 'surely', 'collection'}
# Max Signature:  {'encouraging', 'smell', 'informally', 'worker', 'kill', 'result', 'good', 'win', 'day', 'positively', 'definitely', 'hard', 'hell', 'surely', 'shoot'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('surely.r.01')
# Senso Target:  Lemma('surely.r.01.surely')
# ------------------------------
# Parola da disambiguare:  Hard
# Frase in cui compare la parola:  Hard surface cleaning in household application is represented by two classes of alkaline products : ( 1 ) the formulations made expressly for machine dishwashers , and ( 2 ) the general-purpose cleaners used for walls and woodwork .
# Contesto della frase:  {'represent', 'machine', 'formulation', 'expressly', 'class', 'cleaning', 'generalpurpose', 'surface', 'dishwasher', 'cleaner', 'wall', 'alkaline', 'hard', 'household', 'woodwork', 'application', 'product'}
# ...
# ------------------------------
# Parola da disambiguare:  errand
# Frase in cui compare la parola:  No one would question such an errand .
# Contesto della frase:  {'errand', 'question'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('errand.n.01')
# Senso Target:  Lemma('errand.n.01.errand')
# ------------------------------
# Parola da disambiguare:  considerably
# Frase in cui compare la parola:  Now , not only are there considerably more laity as students and professors at Oxford , but there are also numerous houses of religious orders existing in respectable and friendly relations with the non Catholic members of the University .
# Contesto della frase:  {'respectable', 'oxford', 'house', 'numerous', 'friendly', 'laity', 'relation', 'member', 'professor', 'student', 'university', 'exist', 'catholic', 'considerably', 'order', 'religious'}
# Max Signature:  {'large', 'house', 'budget', 'room', 'fall', 'white', 'film', 'price', 'afraid', 'great', 'paint', 'degree', 'considerably', 'extent', 'well'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('well.r.07')
# Senso Target:  Lemma('well.r.07.considerably')
# ------------------------------
# Parola da disambiguare:  installed
# Frase in cui compare la parola:  The direct evidence on the micrometeorite environment near the Earth is obtained from piezoelectric sensors ( essentially microphones ) and from wire gages ; these instruments are installed on rockets , satellites , and space probes .
# Contesto della frase:  {'space', 'micrometeorite', 'instrument', 'rocket', 'probe', 'earth', 'wire', 'instal', 'evidence', 'microphone', 'gage', 'essentially', 'sensor', 'environment', 'piezoelectric', 'direct', 'satellite'}
# Max Signature:  {'president', 'position', 'office', 'instal', 'election'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('install.v.02')
# Senso Target:  Lemma('install.v.01.install')
# ------------------------------
# Parola da disambiguare:  situation
# Frase in cui compare la parola:  It is hard to see how the situation could be otherwise .
# Contesto della frase:  {'situation', 'hard'}
# Max Signature:  {'fresh', 'wonder', 'true', 'eternal', 'thing', 'general', 'time', 'affair', 'truth', 'franklin', 'situation', 'international', 'social', 'dangerous', 'droosevelt', 'circumstance', 'meaning', 'combination'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('situation.n.01')
# Senso Target:  Lemma('situation.n.01.situation')
# ------------------------------
# Parola da disambiguare:  floor
# Frase in cui compare la parola:  `` She did n't really say '' - She glanced away at the floor , then swooped gracefully and picked up one of Scotty 's slippers .
# Contesto della frase:  {'pick', 'swoop', 'floor', 'nt', 'glance', 'slipper', 'scotty', 'gracefully'}
# Max Signature:  {'tent', 'cover', 'horizontal', 'structure', 'floor', 'dry', 'bare', 'rug', 'room', 'spread', 'bag', 'surface', 'sleeping', 'inside', 'low', 'hallway'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('floor.n.01')
# Senso Target:  Lemma('floor.n.01.floor')
# ------------------------------
# Parola da disambiguare:  posse
# Frase in cui compare la parola:  We leap from event to event - including the formation of the posse - even though the events , in `` reality '' are taking place not in sequence but simultaneously , and not near each other but at a considerable distance .
# Contesto della frase:  {'leap', 'distance', 'include', 'reality', 'formation', 'sequence', 'event', 'considerable', 'simultaneously', 'posse', 'place'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('posse.n.01')
# Senso Target:  Lemma('posse.n.01.posse')
# ------------------------------
# Parola da disambiguare:  pure
# Frase in cui compare la parola:  Contrary to these expectations we have found it impossible to obtain the degree of reproducibility one would wish , even with extensive efforts to prepare especially pure reagents .
# Contesto della frase:  {'reproducibility', 'expectation', 'effort', 'extensive', 'pure', 'impossible', 'find', 'contrary', 'reagent', 'degree', 'prepare'}
# Max Signature:  {'primary', 'element', 'air', 'tone', 'gold', 'lovely', 'pure', 'water', 'violin', 'color', 'extraneous', 'free', 'kind', 'oxygen', 'song'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('pure.a.01')
# Senso Target:  Lemma('pure.a.01.pure')
# ------------------------------
# Parola da disambiguare:  subconscious
# Frase in cui compare la parola:  We may conclude that all six points of information , ostensibly given by the dream priest , could have been furnished by Dr. Hilprecht 's subconscious reasoning .
# Contesto della frase:  {'hilprecht', 'ostensibly', 'dream', 'dr', 'priest', 'subconscious', 'point', 'reasoning', 'furnish', 'conclude'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('subconscious_mind.n.01')
# Senso Target:  Lemma('subconscious.s.01.subconscious')
# ------------------------------
# Parola da disambiguare:  decorator
# Frase in cui compare la parola:  He merely said , `` Any good decorator these days can make you a tasteful home '' .
# Contesto della frase:  {'decorator', 'good', 'tasteful', 'day'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('interior_designer.n.01')
# Senso Target:  Lemma('decorator.n.02.decorator')
# ------------------------------
# Parola da disambiguare:  sections
# Frase in cui compare la parola:  The sections were mounted on cold slides smeared with Haupts ' adhesive ( Johansen , 1940 ) in earlier experiments , and in later experiments with a different mixture of the same components reported by Schramm and Rottger ( 1959 ) .
# Contesto della frase:  {'mixture', 'smear', 'report', 'schramm', 'adhesive', 'experiment', 'late', 'johansen', 'component', 'rottger', 'early', 'cold', 'haupts', 'mount', 'slide'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('section.n.01')
# Senso Target:  Lemma('section.n.02.section')
# ------------------------------
# Parola da disambiguare:  posterior
# Frase in cui compare la parola:  Microscopically , sections from the posterior base of the left ventricle of the heart showed several large areas of replacement of muscle by fibrous tissue .
# Contesto della frase:  {'left', 'large', 'area', 'ventricle', 'base', 'heart', 'posterior', 'microscopically', 'muscle', 'tissue', 'replacement', 'fibrous'}
# Max Signature:  {'argument', 'stage', 'ulterior', 'mood', 'posterior', 'subsequent', 'time'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('later.s.01')
# Senso Target:  Lemma('posterior.a.01.posterior')
# ------------------------------
# Parola da disambiguare:  coats
# Frase in cui compare la parola:  This viewpoint is further supported by Verloop 's ( ' 48 ) demonstration of thickened bronchial artery and arteriolar muscular coats which are capable of acting as valves .
# Contesto della frase:  {'verloop', 'capable', 'thickened', 'viewpoint', 'demonstration', 'valve', 'artery', 'muscular', 'arteriolar', 'bronchial', 'support', 'coat'}
# Max Signature:  {'thin', 'second', 'paint', 'layer', 'cover', 'coat'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('coating.n.01')
# Senso Target:  Lemma('coating.n.01.coat')
# ------------------------------
# Parola da disambiguare:  occasion
# Frase in cui compare la parola:  There is no occasion to feel uneasy or disturbed about these people .
# Contesto della frase:  {'occasion', 'uneasy', 'people', 'feel', 'disturb'}
# Max Signature:  {'occasion', 'juncture', 'impulse', 'occur', 'leave', 'event', 'time', 'special', 'critical'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('juncture.n.01')
# Senso Target:  Lemma('occasion.n.03.occasion')
# ------------------------------
# Parola da disambiguare:  saluted
# Frase in cui compare la parola:  Palmer , golf 's leading money winner in 1960 , and Snead will be saluted as the winning team in the Canada Cup matches last June in Dublin .
# Contesto della frase:  {'golf', 'june', 'canada', 'match', 'snead', 'palmer', 'money', 'win', 'lead', 'cup', 'dublin', 'winner', 'salute', 'team'}
# Max Signature:  {'men', 'friendly', 'greet', 'work', 'day', 'meet', 'salute'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('salute.v.02')
# Senso Target:  Lemma('toast.v.02.salute')
# ------------------------------
# Parola da disambiguare:  chain
# Frase in cui compare la parola:  Physicochemical investigations of anionic surfactants , including the soaps , have shown that there is little polymerization or agglomeration of the chain anions below a certain region of concentration called the critical micelle concentration .
# Contesto della frase:  {'micelle', 'include', 'anion', 'call', 'investigation', 'polymerization', 'chain', 'concentration', 'agglomeration', 'region', 'surfactant', 'soap', 'critical', 'physicochemical', 'anionic'}
# Max Signature:  {'concatenation', 'circumstance', 'thing', 'chain', 'depend', 'series', 'link', 'complicated', 'command'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('chain.n.01')
# Senso Target:  Lemma('chain.n.02.chain')
# ------------------------------
# Parola da disambiguare:  care
# Frase in cui compare la parola:  He did not care .
# Contesto della frase:  {'care'}
# Max Signature:  {'car', 'care', 'require', 'attend', 'constant', 'provide', 'attention', 'work', 'treatment', 'medical'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('care.n.01')
# Senso Target:  Lemma('care.v.01.care')
# ------------------------------
# Parola da disambiguare:  aerial
# Frase in cui compare la parola:  More aerial and underground equipment was installed as well as office improvements to take care of the expanding business .
# Contesto della frase:  {'care', 'aerial', 'business', 'office', 'improvement', 'instal', 'expand', 'equipment', 'underground', 'well'}
# Max Signature:  {'car', 'root', 'aerial', 'photography', 'philodendron', 'particle', 'butterfly', 'exist', 'living', 'cable', 'warfare', 'creature', 'air', 'grow', 'operate', 'small'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('aerial.a.01')
# Senso Target:  aerial.s.00
# ------------------------------
# Parola da disambiguare:  adhesive
# Frase in cui compare la parola:  The latter adhesive was found to be much more satisfactory .
# Contesto della frase:  {'satisfactory', 'find', 'adhesive'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('adhesive_material.n.01')
# Senso Target:  Lemma('adhesive_material.n.01.adhesive')
# ------------------------------
# Parola da disambiguare:  2
# Frase in cui compare la parola:  The age of the moon was about 2 days .
# Contesto della frase:  {'moon', 'age', 'day'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('two.n.01')
# Senso Target:  Lemma('two.s.01.2')
# ------------------------------
# Parola da disambiguare:  set
# Frase in cui compare la parola:  `` This team set a precedent that could be valuable in the future '' , Benington pointed out .
# Contesto della frase:  {'set', 'benington', 'valuable', 'precedent', 'future', 'point', 'team'}
# Max Signature:  {'set', 'child', 'thing', 'emphasis', 'tray', 'scent', 'point', 'abstract', 'dog', 'location', 'place'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('put.v.01')
# Senso Target:  Lemma('set.v.04.set')
# ------------------------------
# Parola da disambiguare:  distribution
# Frase in cui compare la parola:  The meaning of this variation in distribution of the bronchial artery as found in the horse is not clear .
# Contesto della frase:  {'distribution', 'horse', 'artery', 'variation', 'find', 'bronchial', 'meaning', 'clear'}
# Max Signature:  {'worldwide', 'distribution', 'area', 'property', 'range', 'scatter', 'geographic', 'volume', 'complementary', 'spatial', 'nerve', 'fiber'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('distribution.n.02')
# Senso Target:  Lemma('distribution.n.02.distribution')
# ------------------------------
# Parola da disambiguare:  appearing
# Frase in cui compare la parola:  Physically , a movie is possible because a series of images is projected one at a time at such a speed that the eye `` remembers '' the one that has gone before even as it registers the one now appearing .
# Contesto della frase:  {'remember', 'appear', 'movie', 'project', 'physically', 'register', 'series', 'speed', 'time', 'image', 'eye'}
# Max Signature:  {'difficult', 'outward', 'aspect', 'people', 'impression', 'appear', 'sleep', 'eat', 'project', 'fishy', 'long', 'time', 'problem'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('look.v.02')
# Senso Target:  Lemma('appear.v.02.appear')
# ------------------------------
# Parola da disambiguare:  business
# Frase in cui compare la parola:  The Administration maintains a productive facilities inventory of small business industrial concerns that have voluntarily registered .
# Contesto della frase:  {'productive', 'inventory', 'business', 'facility', 'administration', 'maintain', 'register', 'concern', 'industrial', 'voluntarily', 'small'}
# Max Signature:  {'momandpop', 'concern', 'people', 'buy', 'business', 'small', 'enterprise', 'integrated', 'brother', 'industrial', 'racially', 'commercial', 'constitute'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('business.n.01')
# Senso Target:  Lemma('business.n.01.business_concern')
# ------------------------------
# Parola da disambiguare:  full
# Frase in cui compare la parola:  Participation for the educator in this case , however , would have to be raised to full and complete membership .
# Contesto della frase:  {'case', 'raise', 'complete', 'participation', 'educator', 'full', 'membership'}
# Max Signature:  {'town', 'entire', 'extent', 'complete', 'attention', 'devastate', 'earthquake', 'quantity', 'total', 'full', 'failure', 'constitute'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('entire.s.01')
# Senso Target:  Lemma('entire.s.01.full')
# ------------------------------
# Parola da disambiguare:  pupils
# Frase in cui compare la parola:  Undoubtedly you have read the case histories of some of his prize winning pupils ( every pupil has a physique title of some kind or other ) .
# Contesto della frase:  {'case', 'winning', 'pupil', 'title', 'undoubtedly', 'read', 'history', 'kind', 'physique', 'prize'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('student.n.01')
# Senso Target:  Lemma('student.n.01.pupil')
# ------------------------------
# Parola da disambiguare:  helped
# Frase in cui compare la parola:  `` Neither me nor my wife were helped by that chiropractor 's treatments '' .
# Contesto della frase:  {'chiropractor', 'treatment', 'help', 'wife'}
# Max Signature:  {'house', 'help', 'assistance', 'service', 'carry', 'table', 'earthquake'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('help.v.01')
# Senso Target:  Lemma('help.v.02.help')
# ------------------------------
# Parola da disambiguare:  claiming
# Frase in cui compare la parola:  Particularly when based upon a single dominant party , governments may respond to such a situation by claiming a monopoly of understanding about the national interest .
# Contesto della frase:  {'understand', 'government', 'national', 'base', 'respond', 'party', 'situation', 'monopoly', 'dominant', 'claim', 'interest', 'single'}
# Max Signature:  {'true', 'kill', 'assert', 'exist', 'burglar', 'claim', 'affirm'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('claim.v.01')
# Senso Target:  Lemma('claim.v.04.claim')
# ------------------------------
# Parola da disambiguare:  studied
# Frase in cui compare la parola:  The significance of these differences has not been studied nor has the existence of corresponding physiologic differences been determined .
# Contesto della frase:  {'existence', 'significance', 'correspond', 'study', 'difference', 'physiologic', 'determine'}
# Max Signature:  {'study', 'student', 'course', 'enrol', 'follow', 'institute', 'learn'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('study.v.02')
# Senso Target:  Lemma('analyze.v.01.study')
# ------------------------------
# Termini valutati:  51
# Termini valutati correttamente:  23
# Accuratezza:  0.46
#
# Esecuzioni:  10
# Lista delle accuratezze:  [0.48, 0.46, 0.56, 0.5, 0.54, 0.52, 0.58, 0.44, 0.5, 0.46]
# Accuratezza media:  0.504
