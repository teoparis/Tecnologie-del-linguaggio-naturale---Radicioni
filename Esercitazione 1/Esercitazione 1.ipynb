# %%
import re
import enum
import math
import random
import nltk
import csv
import numpy as np
import scipy as sp
from nltk.corpus import wordnet as wn
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import semcor
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from random import randrange
from collections import deque
from statistics import mean

# %% [markdown]
# FUNZIONI DI PREPROCESSING

# %%
#il pre-processing consiste nella tokenizzazione, lemmatizzazione,
#rimozione della punteggiatura e delle stopwords di una sentence
def pre_processing(sentence):
    return set(remove_stopwords(tokenize_sentence(remove_punctuation(sentence))))

#rimuove le stowords da una lista di parole
def remove_stopwords(words_list):
    stopwords_list = get_stopwords()
    return [value.lower() for value in words_list if value.lower() not in stopwords_list]

#Tokenizza la frase in input e ne affettua anche la lemmatizzazione della sue parole
def tokenize_sentence(sentence):
    words_list = []
    lmtzr = WordNetLemmatizer()
    for tag in nltk.pos_tag(word_tokenize(sentence)):
        if (tag[1][:2] == "NN"):
            words_list.append(lmtzr.lemmatize(tag[0], pos = wn.NOUN))
        elif (tag[1][:2] == "VB"):
             words_list.append(lmtzr.lemmatize(tag[0], pos = wn.VERB))
        elif (tag[1][:2] == "RB"):
             words_list.append(lmtzr.lemmatize(tag[0], pos = wn.ADV))
        elif (tag[1][:2] == "JJ"):
             words_list.append(lmtzr.lemmatize(tag[0], pos = wn.ADJ))
    return words_list

#Restituisce la l'insieme di stopwords dal file delle stopwords
def get_stopwords():
    stopwords = open("stop_words_FULL.txt", "r")
    stopwords_list = []
    for word in stopwords:
        stopwords_list.append(word.replace('\n', ''))
    stopwords.close()
    return stopwords_list

#Rimuove la punteggiatura da una sentence
#Restituisce la sentence senza punteggiature
def remove_punctuation(sentence):
    return re.sub(r'[^\w\s]','',sentence)

# %% [markdown]
# FUNZIONI UTILI PER L'ANALISI DEL TESTO

# %%
#Restituisce un sostantivo random presente nel dizionario associato ad una sentence
def get_random_noun(dictionary_tag):
    try:
        sentence_nouns = dictionary_tag['NN']
    except KeyError:
        return None #se non ci sono sostantivi
    noun =  random.choice(sentence_nouns)
    if len(wn.synsets(noun)) == 0:
        return None #se il sostantivo scelto non ha almeno un synset in wordnet
    return noun

#Restituisce una parola random presente nel dizionario associato ad una sentence
def get_random_word(dictionary_tag):
    keys = list(dictionary_tag.keys())
    if not keys:
        return None #se non ci sono parole "analizzabili" nel dizionario, aka se il dizionario è vuoto
    key = random.choice(keys)
    words_list = dictionary_tag[key]
    word = random.choice(words_list)
    if len(wn.synsets(word)) == 0:
        return None #se la parola scelta non ha almeno un synset in wordnet
    return word

#Verifica che una parola abbia un synset target associato
#Senza synset target associato è inutile confrontare l'output dell'algortimo di Lesk
def check_word_synset_target(word,sentence_sem):
    for w in sentence_sem:
        if (type(w) != list):
            if (w[0] == word):
                return True
    return False
    
#Crea un dizionario che ha come chiavi i tag presenti nella sentence e come valori liste di parole associate a quei tag
#e.g {NN: ['home','garden'], VB:['gone'], .....,}
#input: sentence_tag -> rappresenta le words della sentence con i relativi pos tag
#input: sentence_sem -> rappresenta le words della sentence con il relativo synset target associato
def get_dictionary_tag(sentence_tag,sentence_sem):
    dictionary_tag = dict()
    stopwords_list = get_stopwords()
    for word in sentence_tag:
         tag = word.label()
         word = " ".join(l for l in word)
         if check_word_synset_target(word, sentence_sem): #Non inserisco nel dizionario parole che non hanno un synset target
             w = word.lower()
             if w not in stopwords_list and tag: #Non inserisco nel dizionario stopwords o parole che non hanno un pos tag associato
                 if tag in dictionary_tag:
                     dictionary_tag[tag].append(word)
                 else:
                     dictionary_tag[tag] = [word]             
    return dictionary_tag

#Restituisce un indice randomico utile per l'ultimo esercizio
def get_random_index(index_evaluated, INDEXES_NUM):
    while True:
        index = randrange(INDEXES_NUM)
        if index not in index_evaluated:
            return index
    
#Restituisce il synset target per una parola in una sentence
def get_synset_target_for_word_in_sentence(noun,sentence):
     for word in sentence:
      if(type(word) != list):
          if (word[0] == noun):
              return str(word.label())

# %% [markdown]
# METRICHE DI SIMILARITA E ALGORITMI PER LA RICERCA

# %%
#Custom similarity functions
def wu_palmer_similarity(sense1, sense2):
    numerator = 2 * depth(lowest_common_subsumer(sense1,sense2))
    denominator = depth(sense1) + depth(sense2)
    return numerator/denominator

def leakcock_chodorow(sense1, sense2):
    numerator = (shortest_path(sense1, sense2) + 1)
    denominator = (2 * max_depth) + 1
    return -math.log(numerator/denominator)

def shortest_path_similarity(sense1, sense2):
    return ((2 * max_depth) - shortest_path(sense1, sense2))

#Wordnet similarity functions
def wn_wu_palmer_similarity(sense1, sense2):
    sim = sense1.wup_similarity(sense2)
    if sim: return sim
    else: return 0
    
def wn_leakcock_chodorow(sense1, sense2):
    try:
        sim = sense1.lch_similarity(sense2)
        if sim: return sim
        else: return 0
    except:
        return 0

#Restituisce la similarità tra due parole date in input
def similarity(word1, word2, similarity_function):
    max_sim = 0
    for s1 in wn.synsets(word1):
        for s2 in wn.synsets(word2):
           sim = similarity_function(s1,s2)
           if sim > max_sim:
               max_sim = sim
    return max_sim

#Restituisce la profondità di un senso in wordnet, cioè il massimo percorso dal senso alla radice        
def depth(sense):
    if not sense:
        return 0
    return max([len(path) for path in all_hypernym_paths(sense)])

#Restituisce tutti i percorsi di iperonimi di un senso di wordnet, la ricerca dei percosi viene effettuata in modo ricorsivo
def all_hypernym_paths(sense):
    paths = []
    hypernyms = sense.hypernyms()
    if len(hypernyms) == 0:
        paths = [[sense]]
    for hypernym in hypernyms:
        for ancestor_list in all_hypernym_paths(hypernym):
            ancestor_list.append(sense)
            paths.append(ancestor_list)
    return paths

#Massima profondità intesa come il percorso più lungo degli iperonimi di tutti i sensi presenti in wordnet
max_depth = max(max(len(hyp_path) for hyp_path in all_hypernym_paths(ss)) for ss in wn.all_synsets())

#Restituisce un dizionario di iperonimi del senso in input con la relativa profondità
def min_hypernyms_depth(sense):
    sense_depth_queue = deque([(sense, 0)]) #deque garantisce efficienza nell'inserire ed eliminare elementi sia a destra che a sinistra della coda
    sense_depth_dict = {}
    while sense_depth_queue:
        s, depth = sense_depth_queue.popleft()
        if s in sense_depth_dict:
            continue
        sense_depth_dict[s] = depth
        depth += 1
        sense_depth_queue.extend((hyperonym, depth) for hyperonym in s.hypernyms()) #li mette a destra della coda
    return sense_depth_dict

#restituisce il percorso più breve tra due sensi di wordnet
def shortest_path(sense1,sense2):
    if sense1 == sense2:
        return 0
    dict1 = min_hypernyms_depth(sense1)
    dict2 = min_hypernyms_depth(sense2)
    min_dist = (2 * max_depth) # distanza minima iniziale

    #per ogni senso del dizionario degli iperonimi di sense1 cerca di trovare il match con un senso del secondo dizionario.
    for ss, dist1 in dict1.items():
        dist2 = dict2.get(ss)
        if not dist2:
            dist2 = (2 * max_depth)
        min_dist = min(min_dist, dist1 + dist2) #somma dei due sensi matchati
    return (2 * max_depth) if math.isinf(min_dist) else min_dist

#Restituisce l'antenato comune più vicino di due sensi, cioè l'iperonimo comune più vicino ai due sensi. 
#SCELTA PROGETTUALE: Se ne ho più di uno prendo quello può essere il più profondo rispetto alla radice.
def lowest_common_subsumer(sense1, sense2):
    if sense1 == sense2: return sense1
    
    dict1 = min_hypernyms_depth(sense1)
    dict2 = min_hypernyms_depth(sense2)
    
    min_dist = (2 * max_depth)
    candidates = []
    for ss, dist1 in dict1.items():
        dist2 = dict2.get(ss) 
        if not dist2:
            dist2 = (2 * max_depth)
        else:
            if (dist1 + dist2) <= min_dist:
                min_dist = (dist1 + dist2)
                candidates.append(ss) 
    if candidates:
        deepest = candidates[0]
        for sense in candidates:
            if depth(sense) < depth(deepest):
                deepest = sense
        return deepest #restituisce il senso con profondità maggiore rispetto alla radice

#Classe enum con la quale specifichiamo il tipo di similarità utilizzata
class Similarity_Type(enum.Enum):
    wu_palmer_similarity = 1
    shortest_path = 2
    leakcock_chodorow = 3

# %% [markdown]
# Word sense disambiguation è un problema aperto dell'elaborazione del linguaggio naturale, che comprende il processo di identificazione del senso di una parola (cioè il significato) utilizzato in una determinata frase, quando la parola ha un numero di sensi distinti (polisemia).

# %%
#Algoritmo di Lesk
def lesk_algorithm(word, sentence, word_type):
    best_sense = wn.synsets(word)[0]
    max_overlap = 0
    max_signature = []
    print("Frase in cui compare la parola: ", sentence)
    context = pre_processing(sentence)
    
    #se il tipo di parola è un nome allora cerco solo tra i nomi in wordnet
    #altrimenti prendo tutti i synset associati a quel termine
    if word_type == 'NOUN':
        synsets = wn.synsets(word, pos=wn.NOUN)
    elif word_type == 'ALL':
        synsets = wn.synsets(word)
        
    for sense in synsets:
        signature = get_signature(sense)
        overlap = len(list(signature & context)) #overlap
        if overlap > max_overlap:
            max_overlap = overlap
            best_sense = sense
            max_signature = signature
            
    print("Contesto della frase: ", context)
    print("Max Signature: ", max_signature) #signature del senso con più overlap con il contesto della sentence
    return best_sense

#Signature di un senso di WordNet
def get_signature(sense):
    signature = set()
    for word in pre_processing(sense.definition()): #tokenizzo la definizione del synset
        signature.add(word)
    for example in sense.examples(): #tokenizzo ogni esempio del synset
        for word in pre_processing(example):
            signature.add(word)
    return signature #la signature conterrà tutte le parole presenti nella definizione del senso e negli esempi

# %% [markdown]
# CONSEGNA 1:
#
# L'esercitazione consiste nell'implementare tre misure di similarità basate su WordNet.
#
# Per ciascuna di tali misure di similarità, calcolare gli indici di
# correlazione di Spearman and gli indici di correlazione di Pearson
# fra i risultati ottenuti e quelli ‘target’ presenti nel file annotato.

# %%
def main():

    #scelta della metrica da utilizzare per il calcolo della similarità
    similarity_type = Similarity_Type.leakcock_chodorow
    #similarity_type = Similarity_Type.wu_palmer_similarity
    #similarity_type = Similarity_Type.shortest_path
    
    with open('WordSim353.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        assignments = []
        targets = []
        line_count = 0
        for row in csv_reader:
            if line_count > 0:
                print("Word1: ",row[0])
                print("Word2: ",row[1])
                sim = 0
                wn_sim = 0
                if similarity_type.value == 1:
                    sim = similarity(row[0], row[1], wu_palmer_similarity)
                    wn_sim = similarity(row[0], row[1], wn_wu_palmer_similarity)
                elif similarity_type.value == 2:
                    sim = similarity(row[0], row[1], shortest_path_similarity)
                elif similarity_type.value == 3:
                    sim = similarity(row[0], row[1], leakcock_chodorow)
                    wn_sim = similarity(row[0], row[1], wn_leakcock_chodorow)
                print("Type of similarity chosen: ", similarity_type.name)
                print("MyCustom Similarity: ",sim)
                print("WordNet Similarity: ",wn_sim)
                print("Human Similarity: ",row[2])
                assignments.append(sim)
                targets.append(float(row[2]))
                print("------------------------------")
            line_count = line_count + 1
            
    print("Pearson Correlation: ", np.corrcoef(assignments, targets))
    print("Spearman Correlation: ", sp.stats.spearmanr(assignments, targets))
main()
# Out:
# Word1:  love
# Word2:  sex
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  6.77
# ------------------------------
# Word1:  tiger
# Word2:  cat
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  7.35
# ------------------------------
# Word1:  tiger
# Word2:  tiger
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# WordNet Similarity:  3.6375861597263857
# Human Similarity:  10.00
# ------------------------------
# Word1:  book
# Word2:  paper
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.46
# ------------------------------
# Word1:  computer
# Word2:  keyboard
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.62
# ------------------------------
# Word1:  computer
# Word2:  internet
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  7.58
# ------------------------------
# Word1:  plane
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  5.77
# ------------------------------
# Word1:  train
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.31
# ------------------------------
# Word1:  telephone
# Word2:  communication
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  7.50
# ------------------------------
# Word1:  television
# Word2:  radio
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  6.77
# ------------------------------
# Word1:  media
# Word2:  radio
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.42
# ------------------------------
# Word1:  drug
# Word2:  abuse
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.6486586255873816
# Human Similarity:  6.85
# ------------------------------
# Word1:  bread
# Word2:  butter
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  6.19
# ------------------------------
# Word1:  cucumber
# Word2:  potato
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  5.92
# ------------------------------
# Word1:  doctor
# Word2:  nurse
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.00
# ------------------------------
# Word1:  professor
# Word2:  doctor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  6.62
# ------------------------------
# Word1:  student
# Word2:  professor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  6.81
# ------------------------------
# Word1:  smart
# Word2:  student
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  0.9985288301111273
# Human Similarity:  4.62
# ------------------------------
# Word1:  smart
# Word2:  stupid
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  0.9985288301111273
# Human Similarity:  5.81
# ------------------------------
# Word1:  company
# Word2:  stock
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  7.08
# ------------------------------
# Word1:  stock
# Word2:  market
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  8.08
# ------------------------------
# Word1:  stock
# Word2:  phone
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  1.62
# ------------------------------
# Word1:  stock
# Word2:  CD
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  1.31
# ------------------------------
# Word1:  stock
# Word2:  jaguar
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  0.92
# ------------------------------
# Word1:  stock
# Word2:  egg
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  1.81
# ------------------------------
# Word1:  fertility
# Word2:  egg
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  6.69
# ------------------------------
# Word1:  stock
# Word2:  live
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.8718021769015913
# Human Similarity:  3.73
# ------------------------------
# Word1:  stock
# Word2:  life
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  0.92
# ------------------------------
# Word1:  book
# Word2:  library
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.46
# ------------------------------
# Word1:  bank
# Word2:  money
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  8.12
# ------------------------------
# Word1:  wood
# Word2:  forest
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# WordNet Similarity:  3.6375861597263857
# Human Similarity:  7.73
# ------------------------------
# Word1:  money
# Word2:  cash
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  9.15
# ------------------------------
# Word1:  professor
# Word2:  cucumber
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  0.31
# ------------------------------
# Word1:  king
# Word2:  cabbage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  0.23
# ------------------------------
# Word1:  king
# Word2:  queen
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# WordNet Similarity:  3.6375861597263857
# Human Similarity:  8.58
# ------------------------------
# Word1:  king
# Word2:  rook
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  5.92
# ------------------------------
# Word1:  bishop
# Word2:  rabbi
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  6.69
# ------------------------------
# Word1:  Jerusalem
# Word2:  Israel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  8.46
# ------------------------------
# Word1:  Jerusalem
# Word2:  Palestinian
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  0.8649974374866046
# Human Similarity:  7.65
# ------------------------------
# Word1:  holy
# Word2:  sex
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  1.62
# ------------------------------
# Word1:  fuck
# Word2:  sex
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.538973871058276
# Human Similarity:  9.44
# ------------------------------
# Word1:  Maradona
# Word2:  football
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  0
# Human Similarity:  8.62
# ------------------------------
# Word1:  football
# Word2:  soccer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  9.03
# ------------------------------
# Word1:  football
# Word2:  basketball
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  6.81
# ------------------------------
# Word1:  football
# Word2:  tennis
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.63
# ------------------------------
# Word1:  tennis
# Word2:  racket
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  7.56
# ------------------------------
# Word1:  Arafat
# Word2:  peace
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  1.072636802264849
# Human Similarity:  6.73
# ------------------------------
# Word1:  Arafat
# Word2:  terror
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  1.845826690498331
# Human Similarity:  7.65
# ------------------------------
# Word1:  Arafat
# Word2:  Jackson
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  2.50
# ------------------------------
# Word1:  law
# Word2:  lawyer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  8.38
# ------------------------------
# Word1:  movie
# Word2:  star
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  7.38
# ------------------------------
# Word1:  movie
# Word2:  popcorn
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  0.9985288301111273
# Human Similarity:  6.19
# ------------------------------
# Word1:  movie
# Word2:  critic
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  6.73
# ------------------------------
# Word1:  movie
# Word2:  theater
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.92
# ------------------------------
# Word1:  physics
# Word2:  proton
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.0055218656020977
# WordNet Similarity:  0.9295359586241757
# Human Similarity:  8.12
# ------------------------------
# Word1:  physics
# Word2:  chemistry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.35
# ------------------------------
# Word1:  space
# Word2:  chemistry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  4.88
# ------------------------------
# Word1:  alcohol
# Word2:  chemistry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  5.54
# ------------------------------
# Word1:  vodka
# Word2:  gin
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.46
# ------------------------------
# Word1:  vodka
# Word2:  brandy
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.13
# ------------------------------
# Word1:  drink
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  3.04
# ------------------------------
# Word1:  drink
# Word2:  ear
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  1.31
# ------------------------------
# Word1:  drink
# Word2:  mouth
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  5.96
# ------------------------------
# Word1:  drink
# Word2:  eat
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.159484249353372
# Human Similarity:  6.87
# ------------------------------
# Word1:  baby
# Word2:  mother
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  7.85
# ------------------------------
# Word1:  drink
# Word2:  mother
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  2.65
# ------------------------------
# Word1:  car
# Word2:  automobile
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# WordNet Similarity:  3.6375861597263857
# Human Similarity:  8.94
# ------------------------------
# Word1:  gem
# Word2:  jewel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# WordNet Similarity:  3.6375861597263857
# Human Similarity:  8.96
# ------------------------------
# Word1:  journey
# Word2:  voyage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  9.29
# ------------------------------
# Word1:  boy
# Word2:  lad
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  8.83
# ------------------------------
# Word1:  coast
# Word2:  shore
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  9.10
# ------------------------------
# Word1:  asylum
# Word2:  madhouse
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  8.87
# ------------------------------
# Word1:  magician
# Word2:  wizard
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# WordNet Similarity:  3.6375861597263857
# Human Similarity:  9.02
# ------------------------------
# Word1:  midday
# Word2:  noon
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# WordNet Similarity:  3.6375861597263857
# Human Similarity:  9.29
# ------------------------------
# Word1:  furnace
# Word2:  stove
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  8.79
# ------------------------------
# Word1:  food
# Word2:  fruit
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  7.52
# ------------------------------
# Word1:  bird
# Word2:  cock
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  7.10
# ------------------------------
# Word1:  bird
# Word2:  crane
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.38
# ------------------------------
# Word1:  tool
# Word2:  implement
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  6.46
# ------------------------------
# Word1:  brother
# Word2:  monk
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  6.27
# ------------------------------
# Word1:  crane
# Word2:  implement
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  2.69
# ------------------------------
# Word1:  lad
# Word2:  brother
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  4.46
# ------------------------------
# Word1:  journey
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0.8232003088081431
# WordNet Similarity:  0.7472144018302211
# Human Similarity:  5.85
# ------------------------------
# Word1:  monk
# Word2:  oracle
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  5.00
# ------------------------------
# Word1:  cemetery
# Word2:  woodland
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  2.08
# ------------------------------
# Word1:  food
# Word2:  rooster
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0.9409833444645266
# WordNet Similarity:  0.8649974374866046
# Human Similarity:  4.42
# ------------------------------
# Word1:  coast
# Word2:  hill
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  4.38
# ------------------------------
# Word1:  forest
# Word2:  graveyard
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  1.85
# ------------------------------
# Word1:  shore
# Word2:  woodland
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  3.08
# ------------------------------
# Word1:  monk
# Word2:  slave
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  0.92
# ------------------------------
# Word1:  coast
# Word2:  forest
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  3.15
# ------------------------------
# Word1:  lad
# Word2:  wizard
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  0.92
# ------------------------------
# Word1:  chord
# Word2:  smile
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  0.54
# ------------------------------
# Word1:  glass
# Word2:  magician
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  2.08
# ------------------------------
# Word1:  noon
# Word2:  string
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  0.54
# ------------------------------
# Word1:  rooster
# Word2:  voyage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0.5355182363563622
# WordNet Similarity:  0.4595323293784402
# Human Similarity:  0.62
# ------------------------------
# Word1:  money
# Word2:  dollar
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  8.42
# ------------------------------
# Word1:  money
# Word2:  cash
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  9.08
# ------------------------------
# Word1:  money
# Word2:  currency
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  9.04
# ------------------------------
# Word1:  money
# Word2:  wealth
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  8.27
# ------------------------------
# Word1:  money
# Word2:  property
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.57
# ------------------------------
# Word1:  money
# Word2:  possession
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.29
# ------------------------------
# Word1:  money
# Word2:  bank
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  8.50
# ------------------------------
# Word1:  money
# Word2:  deposit
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.73
# ------------------------------
# Word1:  money
# Word2:  withdrawal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  6.88
# ------------------------------
# Word1:  money
# Word2:  laundering
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  5.65
# ------------------------------
# Word1:  money
# Word2:  operation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  3.31
# ------------------------------
# Word1:  tiger
# Word2:  jaguar
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.00
# ------------------------------
# Word1:  tiger
# Word2:  feline
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.00
# ------------------------------
# Word1:  tiger
# Word2:  carnivore
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.08
# ------------------------------
# Word1:  tiger
# Word2:  mammal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.85
# ------------------------------
# Word1:  tiger
# Word2:  animal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.00
# ------------------------------
# Word1:  tiger
# Word2:  organism
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.538973871058276
# Human Similarity:  4.77
# ------------------------------
# Word1:  tiger
# Word2:  fauna
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  5.62
# ------------------------------
# Word1:  tiger
# Word2:  zoo
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  5.87
# ------------------------------
# Word1:  psychology
# Word2:  psychiatry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  8.08
# ------------------------------
# Word1:  psychology
# Word2:  anxiety
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  7.00
# ------------------------------
# Word1:  psychology
# Word2:  fear
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  6.85
# ------------------------------
# Word1:  psychology
# Word2:  depression
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  7.42
# ------------------------------
# Word1:  psychology
# Word2:  clinic
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  0.9985288301111273
# Human Similarity:  6.58
# ------------------------------
# Word1:  psychology
# Word2:  doctor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  6.42
# ------------------------------
# Word1:  psychology
# Word2:  Freud
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  0.6418538861723948
# Human Similarity:  8.21
# ------------------------------
# Word1:  psychology
# Word2:  mind
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.69
# ------------------------------
# Word1:  psychology
# Word2:  health
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  7.23
# ------------------------------
# Word1:  psychology
# Word2:  science
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  6.71
# ------------------------------
# Word1:  psychology
# Word2:  discipline
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.538973871058276
# Human Similarity:  5.58
# ------------------------------
# Word1:  psychology
# Word2:  cognition
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.845826690498331
# Human Similarity:  7.48
# ------------------------------
# Word1:  planet
# Word2:  star
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.45
# ------------------------------
# Word1:  planet
# Word2:  constellation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  8.06
# ------------------------------
# Word1:  planet
# Word2:  moon
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  8.08
# ------------------------------
# Word1:  planet
# Word2:  sun
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  8.02
# ------------------------------
# Word1:  planet
# Word2:  galaxy
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  8.11
# ------------------------------
# Word1:  planet
# Word2:  space
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.92
# ------------------------------
# Word1:  planet
# Word2:  astronomer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  7.94
# ------------------------------
# Word1:  precedent
# Word2:  example
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  5.85
# ------------------------------
# Word1:  precedent
# Word2:  information
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.538973871058276
# Human Similarity:  3.85
# ------------------------------
# Word1:  precedent
# Word2:  cognition
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  2.81
# ------------------------------
# Word1:  precedent
# Word2:  law
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  6.65
# ------------------------------
# Word1:  precedent
# Word2:  collection
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.538973871058276
# Human Similarity:  2.50
# ------------------------------
# Word1:  precedent
# Word2:  group
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  1.77
# ------------------------------
# Word1:  precedent
# Word2:  antecedent
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.04
# ------------------------------
# Word1:  cup
# Word2:  coffee
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.58
# ------------------------------
# Word1:  cup
# Word2:  tableware
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.538973871058276
# Human Similarity:  6.85
# ------------------------------
# Word1:  cup
# Word2:  article
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  2.40
# ------------------------------
# Word1:  cup
# Word2:  artifact
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  2.92
# ------------------------------
# Word1:  cup
# Word2:  object
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.845826690498331
# Human Similarity:  3.69
# ------------------------------
# Word1:  cup
# Word2:  entity
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  1.845826690498331
# Human Similarity:  2.15
# ------------------------------
# Word1:  cup
# Word2:  drink
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  7.25
# ------------------------------
# Word1:  cup
# Word2:  food
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.845826690498331
# Human Similarity:  5.00
# ------------------------------
# Word1:  cup
# Word2:  substance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  1.92
# ------------------------------
# Word1:  cup
# Word2:  liquid
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.845826690498331
# Human Similarity:  5.90
# ------------------------------
# Word1:  jaguar
# Word2:  cat
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  7.42
# ------------------------------
# Word1:  jaguar
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0.8803587226480918
# WordNet Similarity:  0.8043728156701697
# Human Similarity:  7.27
# ------------------------------
# Word1:  energy
# Word2:  secretary
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  1.81
# ------------------------------
# Word1:  secretary
# Word2:  senate
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  0.9985288301111273
# Human Similarity:  5.06
# ------------------------------
# Word1:  energy
# Word2:  laboratory
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  5.09
# ------------------------------
# Word1:  computer
# Word2:  laboratory
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  6.78
# ------------------------------
# Word1:  weapon
# Word2:  secret
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  6.06
# ------------------------------
# Word1:  FBI
# Word2:  fingerprint
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  6.94
# ------------------------------
# Word1:  FBI
# Word2:  investigation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.0055218656020977
# WordNet Similarity:  0.9295359586241757
# Human Similarity:  8.31
# ------------------------------
# Word1:  investigation
# Word2:  effort
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  4.59
# ------------------------------
# Word1:  Mars
# Word2:  water
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  1.6486586255873816
# Human Similarity:  2.94
# ------------------------------
# Word1:  Mars
# Word2:  scientist
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  5.63
# ------------------------------
# Word1:  news
# Word2:  report
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  8.16
# ------------------------------
# Word1:  canyon
# Word2:  landscape
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  7.53
# ------------------------------
# Word1:  image
# Word2:  surface
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  4.56
# ------------------------------
# Word1:  discovery
# Word2:  space
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  6.34
# ------------------------------
# Word1:  water
# Word2:  seepage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  6.56
# ------------------------------
# Word1:  sign
# Word2:  recess
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.159484249353372
# Human Similarity:  2.38
# ------------------------------
# Word1:  Wednesday
# Word2:  news
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  2.22
# ------------------------------
# Word1:  mile
# Word2:  kilometer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  8.66
# ------------------------------
# Word1:  computer
# Word2:  news
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  4.47
# ------------------------------
# Word1:  territory
# Word2:  surface
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  5.34
# ------------------------------
# Word1:  atmosphere
# Word2:  landscape
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  3.69
# ------------------------------
# Word1:  president
# Word2:  medal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  3.00
# ------------------------------
# Word1:  war
# Word2:  troops
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  8.13
# ------------------------------
# Word1:  record
# Word2:  number
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  6.31
# ------------------------------
# Word1:  skin
# Word2:  eye
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.22
# ------------------------------
# Word1:  Japanese
# Word2:  American
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  6.50
# ------------------------------
# Word1:  theater
# Word2:  history
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  3.91
# ------------------------------
# Word1:  volunteer
# Word2:  motto
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  2.56
# ------------------------------
# Word1:  prejudice
# Word2:  recognition
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  3.00
# ------------------------------
# Word1:  decoration
# Word2:  valor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  5.63
# ------------------------------
# Word1:  century
# Word2:  year
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.59
# ------------------------------
# Word1:  century
# Word2:  nation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  3.16
# ------------------------------
# Word1:  delay
# Word2:  racism
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  1.19
# ------------------------------
# Word1:  delay
# Word2:  news
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  3.31
# ------------------------------
# Word1:  minister
# Word2:  party
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.63
# ------------------------------
# Word1:  peace
# Word2:  plan
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  4.75
# ------------------------------
# Word1:  minority
# Word2:  peace
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  3.69
# ------------------------------
# Word1:  attempt
# Word2:  peace
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  4.25
# ------------------------------
# Word1:  government
# Word2:  crisis
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  6.56
# ------------------------------
# Word1:  deployment
# Word2:  departure
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  4.25
# ------------------------------
# Word1:  deployment
# Word2:  withdrawal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  5.88
# ------------------------------
# Word1:  energy
# Word2:  crisis
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  5.94
# ------------------------------
# Word1:  announcement
# Word2:  news
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  7.56
# ------------------------------
# Word1:  announcement
# Word2:  effort
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  2.75
# ------------------------------
# Word1:  stroke
# Word2:  hospital
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  7.03
# ------------------------------
# Word1:  disability
# Word2:  death
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  5.47
# ------------------------------
# Word1:  victim
# Word2:  emergency
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  6.47
# ------------------------------
# Word1:  treatment
# Word2:  recovery
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.91
# ------------------------------
# Word1:  journal
# Word2:  association
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  4.97
# ------------------------------
# Word1:  doctor
# Word2:  personnel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  5.00
# ------------------------------
# Word1:  doctor
# Word2:  liability
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  5.19
# ------------------------------
# Word1:  liability
# Word2:  insurance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.03
# ------------------------------
# Word1:  school
# Word2:  center
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  3.44
# ------------------------------
# Word1:  reason
# Word2:  hypertension
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  2.31
# ------------------------------
# Word1:  reason
# Word2:  criterion
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  5.91
# ------------------------------
# Word1:  hundred
# Word2:  percent
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  7.38
# ------------------------------
# Word1:  Harvard
# Word2:  Yale
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.13
# ------------------------------
# Word1:  hospital
# Word2:  infrastructure
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  4.63
# ------------------------------
# Word1:  death
# Word2:  row
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  5.25
# ------------------------------
# Word1:  death
# Word2:  inmate
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  5.03
# ------------------------------
# Word1:  lawyer
# Word2:  evidence
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  6.69
# ------------------------------
# Word1:  life
# Word2:  death
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.88
# ------------------------------
# Word1:  life
# Word2:  term
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  4.50
# ------------------------------
# Word1:  word
# Word2:  similarity
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  4.75
# ------------------------------
# Word1:  board
# Word2:  recommendation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  4.47
# ------------------------------
# Word1:  governor
# Word2:  interview
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  0.9985288301111273
# Human Similarity:  3.25
# ------------------------------
# Word1:  OPEC
# Word2:  country
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  5.63
# ------------------------------
# Word1:  peace
# Word2:  atmosphere
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  3.69
# ------------------------------
# Word1:  peace
# Word2:  insurance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  2.94
# ------------------------------
# Word1:  territory
# Word2:  kilometer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  5.28
# ------------------------------
# Word1:  travel
# Word2:  activity
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  5.00
# ------------------------------
# Word1:  competition
# Word2:  price
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  6.44
# ------------------------------
# Word1:  consumer
# Word2:  confidence
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  4.13
# ------------------------------
# Word1:  consumer
# Word2:  energy
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  4.75
# ------------------------------
# Word1:  problem
# Word2:  airport
# ...
# WordNet Similarity:  0.9295359586241757
# Human Similarity:  5.97
# ------------------------------
# Word1:  game
# Word2:  victory
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.03
# ------------------------------
# Word1:  game
# Word2:  team
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  7.69
# ------------------------------
# Word1:  marathon
# Word2:  sprint
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  7.47
# ------------------------------
# Word1:  game
# Word2:  series
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  6.19
# ------------------------------
# Word1:  game
# Word2:  defeat
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  6.97
# ------------------------------
# Word1:  seven
# Word2:  series
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  3.56
# ------------------------------
# Word1:  seafood
# Word2:  sea
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  7.47
# ------------------------------
# Word1:  seafood
# Word2:  food
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  8.34
# ------------------------------
# Word1:  seafood
# Word2:  lobster
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.70
# ------------------------------
# Word1:  lobster
# Word2:  food
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.81
# ------------------------------
# Word1:  lobster
# Word2:  wine
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  5.70
# ------------------------------
# Word1:  food
# Word2:  preparation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  6.22
# ------------------------------
# Word1:  video
# Word2:  archive
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  6.34
# ------------------------------
# Word1:  start
# Word2:  year
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  4.06
# ------------------------------
# Word1:  start
# Word2:  match
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  1.8718021769015913
# Human Similarity:  4.47
# ------------------------------
# Word1:  game
# Word2:  round
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  5.97
# ------------------------------
# Word1:  boxing
# Word2:  round
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.61
# ------------------------------
# Word1:  championship
# Word2:  tournament
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.36
# ------------------------------
# Word1:  fighting
# Word2:  defeating
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  2.159484249353372
# Human Similarity:  7.41
# ------------------------------
# Word1:  line
# Word2:  insurance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  2.69
# ------------------------------
# Word1:  day
# Word2:  summer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  3.94
# ------------------------------
# Word1:  summer
# Word2:  drought
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.16
# ------------------------------
# Word1:  summer
# Word2:  nature
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  5.63
# ------------------------------
# Word1:  day
# Word2:  dawn
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.53
# ------------------------------
# Word1:  nature
# Word2:  environment
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  8.31
# ------------------------------
# Word1:  environment
# Word2:  ecology
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  8.81
# ------------------------------
# Word1:  nature
# Word2:  man
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  6.25
# ------------------------------
# Word1:  man
# Word2:  woman
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.30
# ------------------------------
# Word1:  man
# Word2:  governor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  5.25
# ------------------------------
# Word1:  murder
# Word2:  manslaughter
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.53
# ------------------------------
# Word1:  soap
# Word2:  opera
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  0.9985288301111273
# Human Similarity:  7.94
# ------------------------------
# Word1:  opera
# Word2:  performance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  6.88
# ------------------------------
# Word1:  life
# Word2:  lesson
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  5.94
# ------------------------------
# Word1:  focus
# Word2:  life
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  4.06
# ------------------------------
# Word1:  production
# Word2:  crew
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  6.25
# ------------------------------
# Word1:  television
# Word2:  film
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  7.72
# ------------------------------
# Word1:  lover
# Word2:  quarrel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  6.19
# ------------------------------
# Word1:  viewer
# Word2:  serial
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  2.97
# ------------------------------
# Word1:  possibility
# Word2:  girl
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  1.94
# ------------------------------
# Word1:  population
# Word2:  development
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  3.75
# ------------------------------
# Word1:  morality
# Word2:  importance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  3.31
# ------------------------------
# Word1:  morality
# Word2:  marriage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  3.69
# ------------------------------
# Word1:  Mexico
# Word2:  Brazil
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  7.44
# ------------------------------
# Word1:  gender
# Word2:  equality
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  6.41
# ------------------------------
# Word1:  change
# Word2:  attitude
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  5.44
# ------------------------------
# Word1:  family
# Word2:  planning
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  6.25
# ------------------------------
# Word1:  opera
# Word2:  industry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  2.63
# ------------------------------
# Word1:  sugar
# Word2:  approach
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.3121863889661687
# Human Similarity:  0.88
# ------------------------------
# Word1:  practice
# Word2:  institution
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  3.19
# ------------------------------
# Word1:  ministry
# Word2:  culture
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  4.69
# ------------------------------
# Word1:  problem
# Word2:  challenge
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.75
# ------------------------------
# Word1:  size
# Word2:  prominence
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  5.31
# ------------------------------
# Word1:  country
# Word2:  citizen
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  7.31
# ------------------------------
# Word1:  planet
# Word2:  people
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  5.75
# ------------------------------
# Word1:  development
# Word2:  issue
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  3.97
# ------------------------------
# Word1:  experience
# Word2:  music
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  3.47
# ------------------------------
# Word1:  music
# Word2:  project
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  3.63
# ------------------------------
# Word1:  glass
# Word2:  metal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  5.56
# ------------------------------
# Word1:  aluminum
# Word2:  metal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  7.83
# ------------------------------
# Word1:  chance
# Word2:  credibility
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  3.88
# ------------------------------
# Word1:  exhibit
# Word2:  memorabilia
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  5.31
# ------------------------------
# Word1:  concert
# Word2:  virtuoso
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  6.81
# ------------------------------
# Word1:  rock
# Word2:  jazz
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.59
# ------------------------------
# Word1:  museum
# Word2:  theater
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.19
# ------------------------------
# Word1:  observation
# Word2:  architecture
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  4.38
# ------------------------------
# Word1:  space
# Word2:  world
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  6.53
# ------------------------------
# Word1:  preservation
# Word2:  world
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  6.19
# ------------------------------
# Word1:  admission
# Word2:  ticket
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.69
# ------------------------------
# Word1:  shower
# Word2:  thunderstorm
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  6.31
# ------------------------------
# Word1:  shower
# Word2:  flood
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  1.6486586255873816
# Human Similarity:  6.03
# ------------------------------
# Word1:  weather
# Word2:  forecast
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  1.3121863889661687
# Human Similarity:  8.34
# ------------------------------
# Word1:  disaster
# Word2:  area
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  6.25
# ------------------------------
# Word1:  governor
# Word2:  office
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  6.34
# ------------------------------
# Word1:  architecture
# Word2:  century
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  3.78
# ------------------------------
# Pearson Correlation:  [[1.         0.26142012]
#  [0.26142012 1.        ]]
# Spearman Correlation:  SpearmanrResult(correlation=0.2651845536640065, pvalue=4.292887522518468e-07)

# %% [markdown]
# CONSEGNA 2.1:
#
# Estrarre 50 frasi dal corpus SemCor (corpus annotato con i synset di
# WN) e disambiguare (almeno) un sostantivo per frase.
#
# Calcolare
# l’accuratezza del sistema implementato sulla base dei sensi annotati in
# SemCor.

# %%
tokenizer = RegexpTokenizer(r'\w+')

INDEXES_NUM = 1000 #è il limite, partendo da 0, di sentence che possono essere testate relative al database SemCor
RANGE = 50 #è il numero di sentence che effettivamente verranno testate

sentences_tag = semcor.tagged_sents() #lista di liste. Ogni lista rappresenta una sentence e ad ogni parola della sentence è associato un pos tag
sentences = semcor.sents() #lista di liste di parole. Ogni lista rappresenta una sentence
sentences_sem = semcor.tagged_sents(tag = "sem") #lista di liste. Ogni lista rappresenta una sentence e ad ogni parola della sentence è associato un synset gold

def main():
    evaluated = 0 #termini valutati
    checked = 0 #termini valutati correttamente
    index_evaluated = set() #insieme degli indici già valutati
    while(evaluated <= RANGE):
        while True: #fino a quando non trova una word che ha almeno un senso in wordnet   
            index = get_random_index(index_evaluated, INDEXES_NUM)
            word = get_random_noun(get_dictionary_tag(sentences_tag[index],sentences_sem[index]))
            if word:
                break
        sentence = sentences[index]
        print("Parola da disambiguare: ",word)
        #all'algoritmo di lesk viene dato in input la word e l'insieme dei termini che formano la frase, uniti sottoforma di stringa
        best_sense = str(lesk_algorithm(word, ' '.join(word for word in sentence), word_type='NOUN'))
        print("Senso attribuito dall'algoritmo di Lesk: ",best_sense)
        target_lemma = get_synset_target_for_word_in_sentence(word,sentences_sem[index])
        print("Senso Target: ",target_lemma)
        best_sense_lemma = best_sense[8:len(best_sense)-2]
        if target_lemma:
            if best_sense_lemma in target_lemma:
             checked= checked + 1
        evaluated += 1
        print("------------------------------")
    
    print("Termini valutati: ", evaluated)
    print("Termini valutati correttamente: ", checked)
    print("Accuratezza: ", checked/RANGE)
    
main()
# Out:
# Parola da disambiguare:  residents
# Frase in cui compare la parola:  Nearly 18 per cent of West Berlin 's 2200000 residents are sixty-five or older , only 12.8 per cent are under fifteen .
# Contesto della frase:  {'fifteen', 'west', 'cent', 'sixtyfive', 'berlin', 'resident'}
# Max Signature:  {'hospital', 'patient', 'intern', 'special', 'training', 'clinical', 'physician', 'care', 'medical', 'receive', 'staff', 'supervision', 'hospitalized', 'resident', 'live'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('house_physician.n.01')
# Senso Target:  Lemma('resident.n.01.resident')
# ------------------------------
# Parola da disambiguare:  award
# Frase in cui compare la parola:  The most valuable player award was split three ways , among Glen Mankowski , Gordon Hartweger and Tom Kieffer .
# Contesto della frase:  {'tom', 'kieffer', 'glen', 'gordon', 'mankowski', 'valuable', 'hartweger', 'player', 'award', 'split'}
# Max Signature:  {'distinction', 'signify', 'approval', 'tangible', 'symbol', 'award', 'bravery'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('award.n.02')
# Senso Target:  Lemma('prize.n.01.award')
# ------------------------------
# Parola da disambiguare:  shoes
# Frase in cui compare la parola:  Stacked heels are also popular on dressy or tailored shoes .
# Contesto della frase:  {'dressy', 'stacked', 'tailor', 'popular', 'shoe', 'heel'}
# Max Signature:  {'flexible', 'heavy', 'sole', 'shape', 'foot', 'upper', 'footwear', 'fit', 'material', 'leather', 'ankle', 'plastic', 'heel'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('shoe.n.01')
# Senso Target:  Lemma('shoe.n.01.shoe')
# ------------------------------
# Parola da disambiguare:  discs
# Frase in cui compare la parola:  There 's more reading and instruction to be heard on discs than ever before , although the spoken rather than the sung word is as old as Thomas Alva Edison 's first experiment in recorded sound .
# Contesto della frase:  {'hear', 'alva', 'record', 'instruction', 'edison', 'experiment', 'word', 'spoken', 'thomas', 'sound', 'reading', 'sung', 'disc'}
# Max Signature:  {'phonograph', 'disk', 'needle', 'groove', 'track', 'music', 'rotate', 'sound', 'consist', 'record', 'continuous', 'reproduce'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('phonograph_record.n.01')
# Senso Target:  Lemma('phonograph_record.n.01.disc')
# ------------------------------
# Parola da disambiguare:  enemy
# Frase in cui compare la parola:  If this capacity had not failed them , they would see that their enemy has made a disastrous miscalculation .
# Contesto della frase:  {'enemy', 'capacity', 'fail', 'disastrous', 'miscalculation'}
# Max Signature:  {'enemy', 'attack', 'dawn', 'force', 'military', 'oppose'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('enemy.n.01')
# Senso Target:  Lemma('enemy.n.01.enemy')
# ------------------------------
# Parola da disambiguare:  association
# Frase in cui compare la parola:  Arnold sent for Joe Dey , the executive secretary of the golf association .
# Contesto della frase:  {'arnold', 'secretary', 'association', 'executive', 'dey', 'golf', 'joe', 'send'}
# Max Signature:  {'association', 'join', 'language', 'organization', 'formal', 'modern', 'group', 'people'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('association.n.01')
# Senso Target:  Lemma('association.n.01.association')
# ------------------------------
# Parola da disambiguare:  chance
# Frase in cui compare la parola:  It was ruled a difficult chance and a hit .
# Contesto della frase:  {'hit', 'rule', 'difficult', 'chance'}
# Max Signature:  {'washington', 'circumstance', 'combination', 'visit', 'holiday', 'possibility', 'favorable', 'opportunity', 'chance'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('opportunity.n.01')
# Senso Target:  Lemma('luck.n.02.chance')
# ------------------------------
# Parola da disambiguare:  organ
# Frase in cui compare la parola:  Mary Dobbs Tuttle was back at the organ .
# Contesto della frase:  {'dobbs', 'mary', 'tuttle', 'organ'}
# Max Signature:  {'commerce', 'agency', 'performance', 'specific', 'devote', 'bureau', 'instrument', 'department', 'census', 'organ', 'function', 'government'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('organ.n.02')
# Senso Target:  Lemma('electric_organ.n.01.organ')
# ------------------------------
# Parola da disambiguare:  kind
# Frase in cui compare la parola:  What is interesting is that his positive qualifications for the post were revealed only as a kind of tail to his candidacy .
# Contesto della frase:  {'reveal', 'post', 'kind', 'qualification', 'tail', 'candidacy', 'interest', 'positive'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('kind.n.01')
# Senso Target:  Lemma('kind.n.01.kind')
# ------------------------------
# Parola da disambiguare:  wife
# Frase in cui compare la parola:  It listed his wife 's age as 74 and place of birth as Opelika , Ala. .
# Contesto della frase:  {'ala', 'opelika', 'wife', 'age', 'birth', 'list', 'place'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('wife.n.01')
# Senso Target:  Lemma('wife.n.01.wife')
# ------------------------------
# Parola da disambiguare:  calls
# Frase in cui compare la parola:  So I started making some calls of my own .
# Contesto della frase:  {'start', 'call'}
# Max Signature:  {'hear', 'didnt', 'report', 'phone', 'ring', 'anonymous', 'london', 'telephone', 'call', 'place', 'connection'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('call.n.01')
# Senso Target:  Lemma('call.n.01.call')
# ------------------------------
# Parola da disambiguare:  conflict
# Frase in cui compare la parola:  But if you keep a calendar of events , as we do , you noticed a conflict .
# Contesto della frase:  {'event', 'notice', 'calendar', 'conflict'}
# Max Signature:  {'conflict', 'event', 'notice', 'meeting', 'incompatibility'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('conflict.n.05')
# Senso Target:  Lemma('conflict.n.05.conflict')
# ------------------------------
# Parola da disambiguare:  heels
# Frase in cui compare la parola:  Wine glass heels are to be found in both high and semi-heights .
# Contesto della frase:  {'semiheights', 'wine', 'high', 'find', 'glass', 'heel'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('heel.n.01')
# Senso Target:  Lemma('heel.n.01.heel')
# ------------------------------
# Parola da disambiguare:  conversions
# Frase in cui compare la parola:  Moritz was bothered during the first two games this year by a pulled muscle in the thigh of his right ( kicking ) leg and , as a result , several of his successful conversions have gone barely far enough .
# Contesto della frase:  {'thigh', 'bother', 'leg', 'game', 'result', 'moritz', 'kicking', 'successful', 'barely', 'conversion', 'muscle', 'year', 'pulled'}
# Max Signature:  {'event', 'result', 'transformation'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('conversion.n.01')
# Senso Target:  Lemma('conversion.n.03.conversion')
# ------------------------------
# Parola da disambiguare:  school
# Frase in cui compare la parola:  The TEA estimated there would be 182 scholastics to attend the day school in Dallas County , saving them from coming to Austin to live in the state deaf school .
# Contesto della frase:  {'estimate', 'school', 'scholastic', 'live', 'austin', 'day', 'tea', 'deaf', 'attend', 'dallas', 'county', 'save'}
# Max Signature:  {'didnt', 'school', 'single', 'walk', 'instruction', 'session', 'day', 'period', 'stay', 'time'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('school.n.05')
# Senso Target:  Lemma('school.n.01.school')
# ------------------------------
# Parola da disambiguare:  apparatus
# Frase in cui compare la parola:  Since the apparatus is new , it requires experimentation and changes in technique .
# Contesto della frase:  {'experimentation', 'require', 'change', 'technique', 'apparatus'}
# Max Signature:  {'function', 'work', 'body', 'breathing', 'perform', 'group', 'apparatus'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('apparatus.n.02')
# Senso Target:  Lemma('apparatus.n.01.apparatus')
# ------------------------------
# Parola da disambiguare:  walk
# Frase in cui compare la parola:  With one down in the eighth , Marv Throneberry drew a walk and stole second as Hyde fanned Tuttle .
# Contesto della frase:  {'draw', 'walk', 'throneberry', 'stole', 'second', 'hyde', 'marv', 'eighth', 'tuttle', 'fan'}
# Max Signature:  {'funny', 'manner', 'walk'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('walk.n.03')
# Senso Target:  Lemma('base_on_balls.n.01.walk')
# ------------------------------
# Parola da disambiguare:  day
# Frase in cui compare la parola:  Benington said , `` I 've never seen a player have a game as great as Mankowski did against Bradley that day '' .
# Contesto della frase:  {'game', 'mankowski', 'great', 'day', 'player', 'bradley', 've', 'benington'}
# Max Signature:  {'performance', 'rotation', 'leave', 'day', 'axis', 'complete', 'earth', 'passenger', 'time'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('day.n.01')
# Senso Target:  Lemma('day.n.03.day')
# ------------------------------
# Parola da disambiguare:  No.
# Frase in cui compare la parola:  With the speed and power of the body beautiful he saw before him , Ol ' Case wanted No. 7 to be not only the best homerun hitter , but also the best bunter , base-runner and outfielder .
# Contesto della frase:  {'best', 'bunter', 'case', 'body', 'baserunner', 'power', 'homerun', 'hitter', 'ol', 'speed', 'outfielder', 'beautiful'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('ordinal_number.n.01')
# Senso Target:  Lemma('ordinal_number.n.01.no.')
# ------------------------------
# Parola da disambiguare:  shape
# Frase in cui compare la parola:  Styles run the gamut from slender and tapered with elongated toes to a newer squared toe shape .
# Contesto della frase:  {'slender', 'square', 'shape', 'gamut', 'taper', 'elongated', 'newer', 'styles', 'toe'}
# Max Signature:  {'shape', 'barely', 'outline', 'attribute', 'spatial', 'define'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('shape.n.01')
# Senso Target:  Lemma('shape.n.01.shape')
# ------------------------------
# Parola da disambiguare:  record
# Frase in cui compare la parola:  Other lettermen from the team that compiled a 21 - 9 record and finished as runner-up in the National Invitation Tournament were : Art Hambric , Donnell Reid , Bill Nordmann , Dave Harris , Dave Luechtefeld and George Latinovich .
# Contesto della frase:  {'harris', 'luechtefeld', 'bill', 'invitation', 'reid', 'dave', 'compile', 'hambric', 'runnerup', 'latinovich', 'tournament', 'national', 'record', 'art', 'nordmann', 'team', 'george', 'letterman', 'finish', 'donnell'}
# Max Signature:  {'best', 'loss', 'versus', 'win', 'tie', 'league', 'record', 'team', 'number'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('record.n.03')
# Senso Target:  Lemma('record.n.03.record')
# ------------------------------
# Parola da disambiguare:  education
# Frase in cui compare la parola:  Mr. Bates shows us how this mutual education spreads its inevitable havoc .
# Contesto della frase:  {'inevitable', 'education', 'mutual', 'spread', 'bates', 'havoc'}
# Max Signature:  {'reward', 'education', 'seldom', 'educate', 'instruction', 'impart', 'knowledge', 'activity', 'formal', 'carefully', 'receive', 'skill', 'program', 'teaching', 'good', 'classroom', 'instruct'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('education.n.01')
# Senso Target:  Lemma('education.n.02.education')
# ------------------------------
# Parola da disambiguare:  reception
# Frase in cui compare la parola:  An exhibition of Evelyn Cibula 's paintings will open with a reception Nov. 5 at the Evanston Community center , 828 Davis st. .
# Contesto della frase:  {'painting', 'evanston', 'exhibition', 'open', 'center', 'reception', 'cibula', 'evelyn', 'nov', 'community', 'st', 'davis'}
# Max Signature:  {'expect', 'reception', 'greet', 'cold', 'receive', 'manner', 'superior'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('reception.n.01')
# Senso Target:  Lemma('reception.n.02.reception')
# ------------------------------
# Parola da disambiguare:  game
# Frase in cui compare la parola:  Both turned in top jobs for the second straight game .
# Contesto della frase:  {'straight', 'game', 'turn', 'second', 'job', 'top'}
# Max Signature:  {'winner', 'rule', 'game', 'determine', 'contest', 'play', 'people'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('game.n.01')
# Senso Target:  Lemma('game.n.02.game')
# ------------------------------
# Parola da disambiguare:  editor
# Frase in cui compare la parola:  In an effort to fortify himself against the unforeseen upsets sure to arise in the future , Herbert A. Leggett , banker editor of the Phoenix `` Arizona Progress '' , reflects upon a few of the depressing experiences of the feverish fifties .
# Contesto della frase:  {'depressing', 'effort', 'banker', 'editor', 'experience', 'fortify', 'progress', 'unforeseen', 'leggett', 'phoenix', 'arizona', 'reflect', 'feverish', 'herbert', 'upset', 'future', 'fifty'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('editor.n.01')
# Senso Target:  Lemma('editor.n.01.editor')
# ------------------------------
# Parola da disambiguare:  night
# Frase in cui compare la parola:  Larry Scherer last night pitched a no-hit game , said to be the first in Billiken baseball history , as the Blue and White beat Southeast Missouri State College , 5 - 1 , at Crystal City .
# Contesto della frase:  {'history', 'larry', 'blue', 'game', 'pitch', 'scherer', 'nohit', 'college', 'night', 'baseball', 'beat', 'city', 'missouri', 'southeast', 'white', 'billiken', 'crystal'}
# Max Signature:  {'night', 'sleep', 'period', 'spend', 'restless'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('night.n.03')
# Senso Target:  Lemma('night.n.01.night')
# ------------------------------
# Parola da disambiguare:  sacrilege
# Frase in cui compare la parola:  If such a paragon of perfection as Palmer could commit such a scoring sacrilege , there was hope left for all .
# Contesto della frase:  {'sacrilege', 'score', 'perfection', 'palmer', 'paragon', 'left', 'commit', 'hope'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('profanation.n.01')
# Senso Target:  Lemma('profanation.n.01.sacrilege')
# ------------------------------
# Parola da disambiguare:  year
# Frase in cui compare la parola:  The Pirates jumped off to an 11 - 3 start by May 1 last year , when the Redbirds as well as the Dodgers held them even over the season .
# Contesto della frase:  {'dodgers', 'hold', 'redbirds', 'season', 'start', 'pirates', 'year', 'jump', 'well'}
# Max Signature:  {'period', 'day', 'year', 'time'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('year.n.01')
# Senso Target:  Lemma('year.n.01.year')
# ------------------------------
# Parola da disambiguare:  offices
# Frase in cui compare la parola:  However , the jury said it believes `` these two offices should be combined to achieve greater efficiency and reduce the cost of administration '' .
# Contesto della frase:  {'combine', 'efficiency', 'reduce', 'achieve', 'administration', 'great', 'cost', 'jury', 'office'}
# Max Signature:  {'hold', 'official', 'president', 'candidate', 'great', 'advantage', 'power', 'year', 'government', 'office'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('office.n.04')
# Senso Target:  Lemma('agency.n.01.office')
# ------------------------------
# Parola da disambiguare:  degree
# Frase in cui compare la parola:  Dr. Clark holds an earned Doctor of Education degree from the University of Oklahoma .
# Contesto della frase:  {'hold', 'education', 'earned', 'university', 'degree', 'oklahoma', 'dr', 'doctor', 'clark'}
# Max Signature:  {'cum', 'earn', 'university', 'recipient', 'signifying', 'college', 'degree', 'princeton', 'laude', 'confer', 'award', 'complete', 'course', 'satisfactorily', 'study', 'summa'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('academic_degree.n.01')
# Senso Target:  Lemma('academic_degree.n.01.degree')
# ------------------------------
# Parola da disambiguare:  debate
# Frase in cui compare la parola:  Dallas may get to hear a debate on horse race parimutuels soon between Reps. V. E. Red Berry and Joe Ratcliff .
# Contesto della frase:  {'reps', 'hear', 'race', 'debate', 'parimutuel', 'ratcliff', 'horse', 'berry', 'red', 'joe', 'dallas'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('argument.n.03')
# Senso Target:  Lemma('debate.n.02.debate')
# ------------------------------
# Parola da disambiguare:  shoes
# Frase in cui compare la parola:  That is why it is important to invest in comfortable , airy types of shoes .
# Contesto della frase:  {'comfortable', 'type', 'invest', 'airy', 'shoe'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('place.n.06')
# Senso Target:  Lemma('shoe.n.01.shoe')
# ------------------------------
# Parola da disambiguare:  patients
# Frase in cui compare la parola:  Several dentists and patients with special dental problems have experimented with the device .
# Contesto della frase:  {'patient', 'device', 'dentist', 'special', 'problem', 'experiment', 'dental'}
# Max Signature:  {'emergency', 'require', 'patient', 'person', 'care', 'medical', 'rapidly', 'number', 'grow'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('patient.n.01')
# Senso Target:  Lemma('patient.n.01.patient')
# ------------------------------
# Parola da disambiguare:  summer
# Frase in cui compare la parola:  Designed for summer comfort are the shoes illustrated .
# Contesto della frase:  {'illustrate', 'comfort', 'summer', 'designed', 'shoe'}
# Max Signature:  {'northern', 'lazy', 'autumnal', 'hemisphere', 'season', 'shore', 'summer', 'equinox', 'spend', 'year', 'extend', 'solstice', 'warm'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('summer.n.01')
# Senso Target:  Lemma('summer.n.01.summer')
# ------------------------------
# Parola da disambiguare:  job
# Frase in cui compare la parola:  `` I think I can do a better job with the glove , now that I know the hitters around the league a little better '' , he said .
# Contesto della frase:  {'glove', 'league', 'good', 'hitter', 'job', 'well'}
# Max Signature:  {'estimate', 'repair', 'chore', 'engine', 'dollar', 'specific', 'require', 'loss', 'citys', 'high', 'task', 'hour', 'endless', 'classify', 'work', 'range', 'farmer', 'fee', 'duty', 'sample', 'morning', 'piece', 'job'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('job.n.02')
# Senso Target:  Lemma('job.n.02.job')
# ------------------------------
# Parola da disambiguare:  authority
# Frase in cui compare la parola:  Another enlarged authority of the Beaumont Navigation District .
# Contesto della frase:  {'district', 'beaumont', 'enlarged', 'authority', 'navigation'}
# Max Signature:  {'deputy', 'arrest', 'power', 'order', 'potency', 'decision', 'issue', 'place', 'authority', 'warrant', 'authorization'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('authority.n.01')
# Senso Target:  Lemma('authority.n.01.authority')
# ------------------------------
# Parola da disambiguare:  milestone
# Frase in cui compare la parola:  It was a real stimulant to a lot of guys I know who have moved past the 2 - score year milestone .
# Contesto della frase:  {'score', 'stimulant', 'lot', 'milestone', 'move', 'guy', 'year', 'real'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('milestone.n.01')
# Senso Target:  Lemma('milestone.n.01.milestone')
# ------------------------------
# Parola da disambiguare:  paragon
# Frase in cui compare la parola:  If such a paragon of perfection as Palmer could commit such a scoring sacrilege , there was hope left for all .
# Contesto della frase:  {'sacrilege', 'score', 'perfection', 'palmer', 'paragon', 'left', 'commit', 'hope'}
# Max Signature:  {'perfection', 'kind', 'equal', 'model', 'excellence'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('ideal.n.02')
# Senso Target:  Lemma('paragon.n.01.paragon')
# ------------------------------
# Parola da disambiguare:  team
# Frase in cui compare la parola:  We 'd be losing at halftime to a good team and Hartweger would say , ' Do n't worry , Coach - we 'll get 'em all right '' ' .
# Contesto della frase:  {'nt', 'lose', 'll', 'halftime', 'hartweger', 'coach', 'good', 'worry', 'team'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('team.n.01')
# Senso Target:  Lemma('team.n.01.team')
# ------------------------------
# Parola da disambiguare:  double-crosser
# Frase in cui compare la parola:  I told him what Liston had said and he said Liston was a double-crosser and said anything he ( Liston ) got was through a keyhole .
# Contesto della frase:  {'liston', 'keyhole', 'doublecrosser'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('double-crosser.n.01')
# Senso Target:  Lemma('double-crosser.n.01.double-crosser')
# ------------------------------
# Parola da disambiguare:  courses
# Frase in cui compare la parola:  College teachers in Texas are not required to have the Education courses .
# Contesto della frase:  {'require', 'education', 'college', 'teacher', 'texas', 'course'}
# Max Signature:  {'lesson', 'education', 'series', 'weaving', 'meeting', 'college', 'impart', 'unknown', 'flirting', 'course', 'basket', 'class'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('course.n.01')
# Senso Target:  Lemma('course.n.01.course')
# ------------------------------
# Parola da disambiguare:  tie
# Frase in cui compare la parola:  The victory was the first of the season for the Billikens after nine defeats and a tie .
# Contesto della frase:  {'billikens', 'defeat', 'season', 'victory', 'tie'}
# Max Signature:  {'stand', 'narrow', 'collar', 'front', 'necktie', 'tighten', 'wear', 'long', 'knot', 'men', 'neckwear', 'piece', 'tie', 'vest', 'material', 'mirror', 'consisting'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('necktie.n.01')
# Senso Target:  Lemma('tie.n.03.tie')
# ------------------------------
# Parola da disambiguare:  ball
# Frase in cui compare la parola:  `` Virdon has been blasting the ball .
# Contesto della frase:  {'virdon', 'ball', 'blast'}
# Max Signature:  {'travel', 'game', 'hit', 'serve', 'ball', 'mayor', 'corner', 'pocket', 'kick', 'mph', 'object', 'roll', 'throw', 'round'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('ball.n.01')
# Senso Target:  Lemma('ball.n.01.ball')
# ------------------------------
# Parola da disambiguare:  merits
# Frase in cui compare la parola:  Willie 's big day revived the running argument about the relative merits of Mays and Mickey Mantle .
# Contesto della frase:  {'big', 'relative', 'mickey', 'day', 'revive', 'merit', 'mantle', 'argument', 'mays', 'willie', 'running'}
# Max Signature:  {'work', 'great', 'quality', 'attribute', 'merit', 'admirable'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('merit.n.01')
# Senso Target:  Lemma('deservingness.n.01.merit')
# ------------------------------
# Parola da disambiguare:  reasons
# Frase in cui compare la parola:  Solly Hemus announced a switch in his starting pitcher , from Bob Gibson to Ernie Broglio , for several reasons :
# Contesto della frase:  {'gibson', 'bob', 'switch', 'hemus', 'pitcher', 'reason', 'start', 'broglio', 'solly', 'ernie'}
# Max Signature:  {'war', 'belief', 'action', 'motive', 'reason', 'declare', 'declaration', 'rational', 'ground'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('reason.n.01')
# Senso Target:  Lemma('reason.n.01.reason')
# ------------------------------
# Parola da disambiguare:  baseball
# Frase in cui compare la parola:  Nine of the league 's teams play in baseball parks and therefore face an early season conflict in dates .
# Contesto della frase:  {'conflict', 'park', 'baseball', 'season', 'early', 'league', 'face', 'play', 'team'}
# Max Signature:  {'empty', 'score', 'desire', 'game', 'school', 'lot', 'turn', 'high', 'baseball', 'area', 'ball', 'player', 'league', 'national', 'play', 'team', 'bat'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('baseball.n.01')
# Senso Target:  Lemma('baseball.n.01.baseball')
# ------------------------------
# Parola da disambiguare:  coach
# Frase in cui compare la parola:  `` This year , coach Royal told me if I 'd work on my place-kicking he thought he could use me '' , said Moritz .
# Contesto della frase:  {'work', 'moritz', 'placekicking', 'coach', 'royal', 'year'}
# Max Signature:  {'work', 'ride', 'carry', 'passenger', 'vehicle', 'public', 'bus', 'transport'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('bus.n.01')
# Senso Target:  Lemma('coach.n.01.coach')
# ------------------------------
# Parola da disambiguare:  records
# Frase in cui compare la parola:  If the record buyer 's tastes are somewhat eclectic or even the slightest bit esoteric , he will find them satisfied on educational records .
# Contesto della frase:  {'satisfy', 'buyer', 'educational', 'bit', 'slight', 'taste', 'eclectic', 'esoteric', 'record', 'find'}
# Max Signature:  {'serve', 'purchase', 'evidence', 'find', 'legal', 'record', 'transaction', 'document'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('record.n.07')
# Senso Target:  Lemma('phonograph_record.n.01.record')
# ------------------------------
# Parola da disambiguare:  year
# Frase in cui compare la parola:  The Yankee triumph made Ralph Houk only the third man to lead a team to both a pennant and a World Series victory in his first year as a manager .
# Contesto della frase:  {'team', 'pennant', 'series', 'manager', 'houk', 'yankee', 'man', 'victory', 'year', 'third', 'ralph', 'triumph', 'lead'}
# Max Signature:  {'period', 'day', 'year', 'time'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('year.n.01')
# Senso Target:  Lemma('year.n.01.year')
# ------------------------------
# Parola da disambiguare:  manager
# Frase in cui compare la parola:  Only Bucky Harris , the `` boy manager '' of Washington in 1924 , and Eddie Dyer of the St. Louis Cardinals in 1946 had accomplished the feat .
# Contesto della frase:  {'boy', 'washington', 'harris', 'manager', 'accomplish', 'louis', 'eddie', 'dyer', 'feat', 'st', 'bucky', 'cardinals'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('director.n.01')
# Senso Target:  Lemma('coach.n.01.manager')
# ------------------------------
# Parola da disambiguare:  bill
# Frase in cui compare la parola:  Cox argued that the bill is `` probably unconstitutional '' since , he said , it would impair contracts .
# Contesto della frase:  {'contract', 'bill', 'impair', 'cox', 'argue', 'unconstitutional'}
# Max Signature:  {'law', 'hold', 'bill', 'draft', 'statute', 'hearing', 'public'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('bill.n.01')
# Senso Target:  Lemma('bill.n.01.bill')
# ------------------------------
# Termini valutati:  51
# Termini valutati correttamente:  29
# Accuratezza:  0.58

# %% [markdown]
# CONSEGNA 2.2:
#
# Randomizzare la selezione delle 50 frasi e la selezione del termine da
# disambiguare, e restituire l’accuratezza media su (per esempio) 10
# esecuzioni del programma.

# %%
tokenizer = RegexpTokenizer(r'\w+')

EXECUTIONS = 10 #numero massimo di esecuzioni
INDEXES_NUM = 7000 #è il limite, partendo da 0, di sentence che possono essere testate relative al database SemCor
RANGE = 50 #è il numero di sentence che effettivamente verranno testate in ogni esecuzione        

sentences_tag = semcor.tagged_sents()
sentences = semcor.sents()
sentences_sem = semcor.tagged_sents(tag = "sem")

def main():
    accuracy_list = []
    for execution in range(1,EXECUTIONS + 1):
        evaluated = 0 #termini valutati
        checked = 0 #termini valutati correttamente
        index_evaluated = set() #insieme degli indici già valutati
        while(evaluated <= RANGE):
            while True: #fino a quando non trova una word che può essere presa in considerazione  
                index = get_random_index(index_evaluated, INDEXES_NUM)
                word = get_random_word(get_dictionary_tag(sentences_tag[index],sentences_sem[index]))
                if word:
                    break
            sentence = sentences[index]
            print("Parola da disambiguare: ",word)
            #all'algoritmo di lesk viene dato in input la word e l'insieme dei termini che formano la frase, uniti sottoforma di stringa
            best_sense = str(lesk_algorithm(word, ' '.join(word for word in sentence), word_type='ALL'))
            print("Senso attribuito dall'algoritmo di Lesk: ",best_sense)
            target_lemma = get_synset_target_for_word_in_sentence(word,sentences_sem[index])
            print("Senso Target: ",target_lemma)
            best_sense_lemma = best_sense[8:len(best_sense)-2]
            if target_lemma:
                if best_sense_lemma in target_lemma:
                 checked= checked + 1
            evaluated += 1
            print("------------------------------")
        
        print("Termini valutati: ", evaluated)
        print("Termini valutati correttamente: ", checked)
        accuracy = checked/RANGE
        print("Accuratezza: ", accuracy)
        accuracy_list.append(accuracy)
        
    print()
    print("Esecuzioni: ",EXECUTIONS)
    print("Lista delle accuratezze: ", accuracy_list)
    print("Accuratezza media: ",mean(accuracy_list))
    
main()
# Out:
# Parola da disambiguare:  releases
# Frase in cui compare la parola:  All of the releases , however , are recorded at a gratifyingly high level , with resultant masking of any surface noise .
# Contesto della frase:  {'gratifyingly', 'high', 'masking', 'surface', 'resultant', 'level', 'record', 'release', 'noise'}
# Max Signature:  {'symphony', 'orchestra', 'release', 'sale', 'london', 'film', 'showing', 'record', 'public', 'issue', 'merchandise'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('release.n.01')
# Senso Target:  Lemma('release.n.01.release')
# ------------------------------
# Parola da disambiguare:  sees
# Frase in cui compare la parola:  Not a circle , then , nor a straight line , but a spiral represents the shape of death as Irenaeus sees it ; for a spiral has motion as well as recurrence .
# Contesto della frase:  {'death', 'shape', 'straight', 'recurrence', 'circle', 'represent', 'irenaeus', 'well', 'motion', 'spiral'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('see.n.01')
# Senso Target:  Lemma('understand.v.02.see')
# ------------------------------
# Parola da disambiguare:  good
# Frase in cui compare la parola:  `` We 'll work hard Tuesday , Wednesday and Thursday '' , Meek said , `` and probably will have a good scrimmage Friday .
# Contesto della frase:  {'ll', 'friday', 'work', 'scrimmage', 'thursday', 'tuesday', 'hard', 'meek', 'good', 'wednesday'}
# Max Signature:  {'benefit', 'worry', 'good'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('good.n.01')
# Senso Target:  Lemma('good.a.01.good')
# ------------------------------
# Parola da disambiguare:  inner
# Frase in cui compare la parola:  Although the inner functions of religion are not of direct significance in social organization , they have important indirect consequences .
# Contesto della frase:  {'religion', 'social', 'consequence', 'organization', 'indirect', 'direct', 'inner', 'significance', 'function'}
# Max Signature:  {'center', 'organization', 'circle', 'inner', 'region', 'exclusive', 'government', 'influence'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('inner.s.05')
# Senso Target:  Lemma('inner.s.01.inner')
# ------------------------------
# Parola da disambiguare:  arrived
# Frase in cui compare la parola:  A half hour later the Vice President arrived .
# Contesto della frase:  {'president', 'half', 'arrive', 'hour', 'vice'}
# Max Signature:  {'didnt', 'reach', 'chicago', 'oclock', 'destination', 'arrive', 'midnight', 'movement', 'progress'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('arrive.v.01')
# Senso Target:  Lemma('arrive.v.01.arrive')
# ------------------------------
# Parola da disambiguare:  problem
# Frase in cui compare la parola:  Unfortunately , the purely synthetic problem is the rule .
# Contesto della frase:  {'synthetic', 'purely', 'rule', 'problem'}
# Max Signature:  {'urban', 'contact', 'congestion', 'smog', 'traffic', 'difficulty', 'problem', 'resolve', 'husband', 'job'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('problem.n.01')
# Senso Target:  Lemma('problem.n.01.problem')
# ------------------------------
# Parola da disambiguare:  total
# Frase in cui compare la parola:  In this instance , there was a dosage of 562 during the first two hours and a total dosage of 1980 for the four hour period , a four-fold increase .
# Contesto della frase:  {'fourfold', 'total', 'dosage', 'period', 'hour', 'increase', 'instance'}
# Max Signature:  {'rock', 'total', 'damage', 'repair', 'concert', 'son', 'car', 'point', 'guitar', 'star'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('total.v.03')
# Senso Target:  Lemma('sum.n.05.total')
# ------------------------------
# Parola da disambiguare:  8
# Frase in cui compare la parola:  Because of increasing anemia , triamcinolone , 8 mg. daily , was started on Feb. 23 , 1958 , and was continued until july , 1958 .
# Contesto della frase:  {'anemia', 'daily', 'continue', 'increase', 'triamcinolone', 'start', 'july', 'feb'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('eight.n.01')
# Senso Target:  Lemma('eight.s.01.8')
# ------------------------------
# Parola da disambiguare:  Agamemnon
# Frase in cui compare la parola:  We do not deny originality to the Agamemnon because Aeschylus found the tales of the house of Atreus among the folk lore of the Greeks .
# Contesto della frase:  {'house', 'originality', 'aeschylus', 'lore', 'folk', 'atreus', 'agamemnon', 'deny', 'greeks', 'tale', 'find'}
# Max Signature:  {'king', 'war', 'troy', 'trojan', 'greek', 'mythology', 'greeks', 'lead'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('agamemnon.n.01')
# Senso Target:  NE
# ------------------------------
# Parola da disambiguare:  long
# Frase in cui compare la parola:  An early film by a competitor of the Wizard of Menlo Park simply showed a long kiss performed by two actors of the contemporary stage .
# Contesto della frase:  {'contemporary', 'menlo', 'park', 'long', 'competitor', 'actor', 'stage', 'early', 'simply', 'kiss', 'film', 'perform', 'wizard'}
# Max Signature:  {'ago', 'game', 'long', 'speech', 'average', 'friendship', 'indicate', 'great', 'temporal', 'sense', 'boring', 'passage', 'hour', 'life', 'duration', 'time'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('long.a.01')
# Senso Target:  Lemma('long.a.01.long')
# ------------------------------
# Parola da disambiguare:  work
# Frase in cui compare la parola:  Certainly there would be less anxiety , fewer accidents ( it is the clumsy child who sustains the worst injuries ) , and higher scholastic averages , since alert children work better .
# Contesto della frase:  {'clumsy', 'injury', 'bad', 'work', 'child', 'scholastic', 'average', 'high', 'sustain', 'anxiety', 'alert', 'accident', 'well'}
# Max Signature:  {'expect', 'doesnt', 'desire', 'voting', 'idea', 'method', 'work', 'medicine', 'lot', 'practice', 'car', 'break', 'outcome', 'process', 'water', 'well', 'people'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('work.v.03')
# Senso Target:  work.v.00
# ------------------------------
# Parola da disambiguare:  levels
# Frase in cui compare la parola:  The significant things in it , at the higher religious levels , are the inner emotional , mental , and spiritual occurrences that fill the pressing human needs of self-preservation , self pacification , and self completion .
# Contesto della frase:  {'human', 'pacification', 'fill', 'high', 'emotional', 'occurrence', 'selfpreservation', 'pressing', 'inner', 'level', 'mental', 'completion', 'religious', 'spiritual', 'thing'}
# Max Signature:  {'intensity', 'require', 'position', 'high', 'degree', 'matter', 'scale', 'quality', 'moderate', 'grade', 'intelligence', 'care', 'level', 'amount'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('degree.n.01')
# Senso Target:  Lemma('grade.n.02.level')
# ------------------------------
# Parola da disambiguare:  individually
# Frase in cui compare la parola:  Folklore is individually created art that a homogeneous group of people preserve , vary and recreate through oral transmission .
# Contesto della frase:  {'recreate', 'preserve', 'oral', 'vary', 'people', 'transmission', 'folklore', 'group', 'art', 'create', 'individually', 'homogeneous'}
# Max Signature:  {'fact', 'singly', 'square', 'room', 'treat', 'apart', 'fine', 'point', 'individually'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('individually.r.01')
# Senso Target:  Lemma('individually.r.01.individually')
# ------------------------------
# Parola da disambiguare:  fact
# Frase in cui compare la parola:  Some clue to the character of London 's approach in these discs may be gained immediately from the fact that ten of the 12 titles include the word `` percussion '' or `` percussive '' .
# Contesto della frase:  {'fact', 'character', 'percussion', 'london', 'include', 'gain', 'word', 'title', 'percussive', 'disc', 'approach', 'ten', 'clue'}
# Max Signature:  {'fact', 'circumstance', 'event', 'case', 'exist', 'collect', 'piece', 'occur'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('fact.n.01')
# Senso Target:  Lemma('fact.n.01.fact')
# ------------------------------
# Parola da disambiguare:  today
# Frase in cui compare la parola:  Mr. H. is dead today because he followed this advice .
# Contesto della frase:  {'advice', 'today', 'follow', 'dead'}
# Max Signature:  {'age', 'today', 'computer', 'time'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('today.n.01')
# Senso Target:  Lemma('today.n.01.today')
# ------------------------------
# Parola da disambiguare:  objective
# Frase in cui compare la parola:  Yet it exists and has an objective reality which can be experienced and known .
# Contesto della frase:  {'reality', 'objective', 'exist', 'experience'}
# Max Signature:  {'objective', 'experience', 'event', 'kind', 'example', 'evidence', 'belong', 'actual', 'benefit', 'thing'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('objective.s.04')
# Senso Target:  Lemma('objective.a.01.objective')
# ------------------------------
# Parola da disambiguare:  Catholics
# Frase in cui compare la parola:  I have found myself saying with other foreigners here that English Catholics are good Catholics .
# Contesto della frase:  {'english', 'catholics', 'foreigner', 'good', 'find'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('catholic.n.01')
# Senso Target:  Lemma('catholic.n.01.Catholic')
# ------------------------------
# Parola da disambiguare:  scoring
# Frase in cui compare la parola:  The detailed rundown on the Kansas City scoring in the sixth went like this :
# Contesto della frase:  {'detailed', 'scoring', 'city', 'sixth', 'kansas', 'rundown'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('marking.n.03')
# Senso Target:  Lemma('score.v.01.score')
# ------------------------------
# Parola da disambiguare:  moon
# Frase in cui compare la parola:  The age of the moon was about 2 days .
# Contesto della frase:  {'age', 'moon', 'day'}
# Max Signature:  {'successive', 'moon', 'period', 'day'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('lunar_month.n.01')
# Senso Target:  Lemma('moon.n.01.Moon')
# ------------------------------
# Parola da disambiguare:  left
# Frase in cui compare la parola:  The parenchyma was slightly hyperemic in the apex of the left lung , and there were several firm , gray , fibrocalcific nodules measuring as large as 3 mm. .
# Contesto della frase:  {'hyperemic', 'firm', 'fibrocalcific', 'mm', 'apex', 'lung', 'gray', 'left', 'large', 'measure', 'nodule', 'parenchyma'}
# Max Signature:  {'side', 'stand', 'left', 'person', 'direction', 'north', 'east', 'face', 'object', 'location'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('left.n.01')
# Senso Target:  Lemma('left.a.01.left')
# ------------------------------
# Parola da disambiguare:  Cubist
# Frase in cui compare la parola:  Synthetic Cubism began with Picasso alone , late in 1913 or early in 1914 ; this was the point at which he finally took the lead in Cubist innovation away from Braque , never again to relinquish it .
# Contesto della frase:  {'cubism', 'innovation', 'finally', 'cubist', 'late', 'picasso', 'early', 'point', 'synthetic', 'relinquish', 'lead', 'braque'}
# Max Signature:  {'cubism', 'relate', 'cubist', 'characteristic', 'art'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('cubist.a.01')
# Senso Target:  Lemma('cubist.a.01.cubist')
# ------------------------------
# Parola da disambiguare:  fair
# Frase in cui compare la parola:  Fulton legislators `` work with city officials to pass enabling legislation that will permit the establishment of a fair and equitable '' pension plan for city employes .
# Contesto della frase:  {'enable', 'official', 'permit', 'pension', 'work', 'legislator', 'legislation', 'city', 'equitable', 'establishment', 'pass', 'fair', 'plan', 'employes', 'fulton'}
# Max Signature:  {'gathering', 'business', 'fair', 'promote', 'producer', 'book', 'trade'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('fair.n.02')
# Senso Target:  fair.a.00
# ------------------------------
# Parola da disambiguare:  ways
# Frase in cui compare la parola:  As it is , they consider that the North is now reaping the fruits of excess egalitarianism , that in spite of its high standard of living the `` American way '' has been proved inferior to the English and Scandinavian ways , although they disapprove of the socialistic features of the latter .
# Contesto della frase:  {'english', 'disapprove', 'fruit', 'egalitarianism', 'standard', 'spite', 'american', 'excess', 'consider', 'high', 'feature', 'north', 'inferior', 'socialistic', 'prove', 'reap', 'scandinavian', 'live'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('ways.n.01')
# Senso Target:  Lemma('way.n.05.way')
# ------------------------------
# Parola da disambiguare:  evaluating
# Frase in cui compare la parola:  In evaluating data on the concentration of TSH in blood , one must examine critically the bio-assay methods used to obtain them .
# Contesto della frase:  {'blood', 'method', 'evaluate', 'examine', 'critically', 'bioassay', 'tsh', 'data', 'concentration'}
# Max Signature:  {'estimate', 'professional', 'extent', 'risk', 'jewel', 'factor', 'nature', 'evaluate', 'family', 'quality', 'significance', 'ability', 'appraise', 'access'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('measure.v.04')
# Senso Target:  Lemma('measure.v.04.evaluate')
# ------------------------------
# Parola da disambiguare:  distilled
# Frase in cui compare la parola:  The mixture was then extracted with alkali and with water following which the carbon tetrachloride was distilled on a Vigreux column , a 25 % center cut being retained which was then degassed under vacuum in the presence of * * f .
# Contesto della frase:  {'alkali', 'distil', 'tetrachloride', 'retain', 'presence', 'center', 'vigreux', 'follow', 'carbon', 'cut', 'mixture', 'vacuum', 'water', 'column', 'degas', 'extract'}
# Max Signature:  {'fall', 'change', 'undergo', 'condensation', 'distill', 'acid', 'drop', 'gaseous', 'condenses', 'temperature', 'water', 'specific', 'liquid'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('condense.v.01')
# Senso Target:  Lemma('distill.v.02.distill')
# ------------------------------
# Parola da disambiguare:  treatments
# Frase in cui compare la parola:  Sarah Gross found that the treatments given her for a nervous ailment by the masseur were not helping her .
# Contesto della frase:  {'help', 'sarah', 'nervous', 'masseur', 'ailment', 'treatment', 'find', 'gross'}
# Max Signature:  {'justice', 'prisoner', 'sewage', 'equal', 'management', 'handling', 'treatment', 'water', 'system', 'criminal'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('treatment.n.02')
# Senso Target:  Lemma('treatment.n.01.treatment')
# ------------------------------
# Parola da disambiguare:  installed
# Frase in cui compare la parola:  More aerial and underground equipment was installed as well as office improvements to take care of the expanding business .
# Contesto della frase:  {'equipment', 'aerial', 'expand', 'underground', 'instal', 'improvement', 'care', 'business', 'well', 'office'}
# Max Signature:  {'president', 'position', 'instal', 'election', 'office'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('install.v.02')
# Senso Target:  Lemma('install.v.01.install')
# ------------------------------
# Parola da disambiguare:  understand
# Frase in cui compare la parola:  And further he must understand his obligation to the client to not only meet his physical necessities but also to enhance and improve his life and to enlarge the cultural horizon of our society .
# Contesto della frase:  {'society', 'client', 'obligation', 'improve', 'physical', 'understand', 'enlarge', 'horizon', 'enhance', 'life', 'necessity', 'cultural', 'meet'}
# Max Signature:  {'understand', 'nature', 'meaning', 'husband', 'comprehend'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('understand.v.01')
# Senso Target:  Lemma('understand.v.01.understand')
# ------------------------------
# Parola da disambiguare:  amount
# Frase in cui compare la parola:  The required amount of carbon tetrachloride was distilled into a series of reaction cells on a manifold on a vacuum line .
# Contesto della frase:  {'series', 'distil', 'tetrachloride', 'reaction', 'manifold', 'carbon', 'amount', 'cell', 'vacuum', 'required'}
# Max Signature:  {'cash', 'sum', 'quantity', 'large', 'amount', 'money', 'insufficient', 'borrow'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('sum.n.01')
# Senso Target:  Lemma('amount.n.02.amount')
# ------------------------------
# Parola da disambiguare:  large
# Frase in cui compare la parola:  The effect of drugs that act on the iodide concentrating mechanism can be counteracted by addition of relatively large amounts of iodine to the diet .
# Contesto della frase:  {'amount', 'iodide', 'large', 'iodine', 'counteract', 'diet', 'mechanism', 'addition', 'concentrate', 'drug'}
# Max Signature:  {'garment', 'large', 'size', 'person'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('large.n.01')
# Senso Target:  Lemma('large.a.01.large')
# ------------------------------
# Parola da disambiguare:  Projects
# Frase in cui compare la parola:  The program came out of the NBC Special Projects department , and was slotted in the Du Pont Show of the Week series .
# Contesto della frase:  {'du', 'series', 'week', 'projects', 'special', 'nbc', 'department', 'pont', 'program', 'slot'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('undertaking.n.01')
# Senso Target:  Lemma('undertaking.n.01.project')
# ------------------------------
# Parola da disambiguare:  unanimously
# Frase in cui compare la parola:  At the close of Davis ' speech the following preamble and resolutions were read by the president , and on the question of their adoption passed unanimously :
# Contesto della frase:  {'resolution', 'read', 'president', 'close', 'speech', 'question', 'preamble', 'pass', 'unanimously', 'adoption', 'davis'}
# Max Signature:  {'vote', 'dissent', 'bill', 'unanimously', 'senate', 'mind', 'approve'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('unanimously.r.01')
# Senso Target:  Lemma('unanimously.r.01.unanimously')
# ------------------------------
# Parola da disambiguare:  emptied
# Frase in cui compare la parola:  The Bordel and other places of prostitution were emptied .
# Contesto della frase:  {'empty', 'place', 'prostitution', 'bordel'}
# Max Signature:  {'empty', 'alarm', 'box', 'void', 'content', 'building'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('empty.v.01')
# Senso Target:  Lemma('empty.v.02.empty')
# ------------------------------
# Parola da disambiguare:  respiration
# Frase in cui compare la parola:  The intra nasal instillation of a fluid suspension of infectious agent in an anesthetized animal is far different from exposure , through natural respiration , to aerosolized organisms .
# Contesto della frase:  {'aerosolize', 'fluid', 'infectious', 'animal', 'instillation', 'natural', 'organism', 'suspension', 'nasal', 'exposure', 'intra', 'respiration', 'agent', 'anesthetized'}
# Max Signature:  {'tissue', 'blood', 'absorb', 'lung', 'produce', 'cell', 'energy', 'organism', 'molecule', 'dioxide', 'carbon', 'metabolic', 'process', 'place', 'release', 'organic', 'transport'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('respiration.n.01')
# Senso Target:  Lemma('respiration.n.01.respiration')
# ------------------------------
# Parola da disambiguare:  nation
# Frase in cui compare la parola:  President Kennedy has asked that we become a physically fit nation .
# Contesto della frase:  {'kennedy', 'president', 'nation', 'fit', 'physically'}
# Max Signature:  {'organize', 'single', 'president', 'country', 'politically', 'body', 'large', 'nation', 'elect', 'industrialized', 'capitol', 'manufacturer', 'land', 'student', 'african', 'people', 'government'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('state.n.04')
# Senso Target:  Lemma('state.n.04.nation')
# ------------------------------
# Parola da disambiguare:  American
# Frase in cui compare la parola:  The same thing is also evidenced by the extreme `` culture Protestantism '' so often observed to characterize the preaching and teaching of the American churches .
# Contesto della frase:  {'church', 'american', 'culture', 'protestantism', 'extreme', 'evidence', 'observe', 'characterize', 'teaching', 'thing', 'preaching'}
# Max Signature:  {'english', 'relate', 'dream', 'american', 'language', 'culture', 'people', 'united', 'citizen', 'america'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('american.a.01')
# Senso Target:  Lemma('american.a.01.American')
# ------------------------------
# Parola da disambiguare:  helpfully
# Frase in cui compare la parola:  Man has the experience of being helpfully allied with what he cannot fully understand ; he is a coordinate part of all of the mysterious energy and being and movement .
# Contesto della frase:  {'understand', 'experience', 'coordinate', 'movement', 'helpfully', 'fully', 'energy', 'man', 'ally', 'mysterious'}
# Max Signature:  {'helpful', 'subtitle', 'helpfully', 'convey', 'manner'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('helpfully.r.01')
# Senso Target:  Lemma('helpfully.r.01.helpfully')
# ------------------------------
# Parola da disambiguare:  diametrically
# Frase in cui compare la parola:  `` Since 1692 a great but superficial change has wiped out God 's beard and the Devil 's horns , but the world is still gripped between two diametrically opposed absolutes .
# Contesto della frase:  {'absolute', 'horn', 'change', 'diametrically', 'superficial', 'wipe', 'god', 'beard', 'great', 'oppose', 'grip', 'devil'}
# Max Signature:  {'opposite', 'witness', 'honest', 'foot', 'diametrically', 'event', 'fourth', 'evidence', 'apart', 'brush', 'false', 'account', 'prove', 'deliberately', 'differ', 'diameter'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('diametrically.r.01')
# Senso Target:  Lemma('diametrically.r.01.diametrically')
# ------------------------------
# Parola da disambiguare:  located
# Frase in cui compare la parola:  After being located for some years in the Village at the Equinox Pharmacy under the supervision of Mrs. Harry Mercier , it is presently located in the Hill and Dale Shop , Manchester Center .
# Contesto della frase:  {'locate', 'center', 'harry', 'dale', 'village', 'mercier', 'equinox', 'shop', 'pharmacy', 'year', 'presently', 'hill', 'manchester', 'supervision'}
# Max Signature:  {'midwest', 'locate', 'cousin', 'turn', 'search', 'examine', 'determine', 'discover', 'find', 'place', 'location'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('locate.v.01')
# Senso Target:  Lemma('located.s.01.located')
# ------------------------------
# Parola da disambiguare:  halted
# Frase in cui compare la parola:  He halted , and looked around .
# Contesto della frase:  {'halt'}
# Max Signature:  {'halt', 'engine', 'progress', 'press'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('halt.v.01')
# Senso Target:  Lemma('stop.v.01.halt')
# ------------------------------
# Parola da disambiguare:  stimulate
# Frase in cui compare la parola:  The overall effect was probably to stimulate more party activity in the communal elections than might have otherwise taken place .
# Contesto della frase:  {'activity', 'party', 'place', 'election', 'stimulate', 'communal'}
# Max Signature:  {'stimulant', 'imagination', 'play', 'book', 'stimulate'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('stimulate.v.01')
# Senso Target:  Lemma('stimulate.v.06.stimulate')
# ------------------------------
# Parola da disambiguare:  profoundly
# Frase in cui compare la parola:  ( 3 ) How can we be sure that his sense of touch was not profoundly disturbed by his head injury ?
# Contesto della frase:  {'injury', 'head', 'sense', 'disturb', 'touch', 'profoundly'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('profoundly.r.01')
# Senso Target:  Lemma('profoundly.r.01.profoundly')
# ------------------------------
# Parola da disambiguare:  directed
# Frase in cui compare la parola:  Most of the fire was directed by Cotten against Dallas and Sen. Parkhouse .
# Contesto della frase:  {'parkhouse', 'fire', 'sen', 'direct', 'dallas', 'cotten'}
# Max Signature:  {'command', 'child', 'homework', 'direct', 'authority'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('direct.v.01')
# Senso Target:  Lemma('aim.v.01.direct')
# ------------------------------
# Parola da disambiguare:  registration
# Frase in cui compare la parola:  Periodic bulletins of the accomplishment in each province made the registration process into a kind of competition among provincial officials .
# Contesto della frase:  {'periodic', 'official', 'competition', 'kind', 'province', 'bulletin', 'provincial', 'process', 'accomplishment', 'registration'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('registration.n.01')
# Senso Target:  Lemma('registration.n.01.registration')
# ------------------------------
# Parola da disambiguare:  game
# Frase in cui compare la parola:  Texas ' 545 - yard spree against Washington State gave the Longhorns a 3 - game total offense of 1512 yards ( 1065 rushing and 447 passing ) a new SWC high .
# Contesto della frase:  {'washington', 'game', 'rushing', 'total', 'high', 'spree', 'pass', 'offense', 'texas', 'swc', 'yard', 'longhorns'}
# Max Signature:  {'winner', 'rule', 'game', 'determine', 'contest', 'play', 'people'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('game.n.01')
# Senso Target:  Lemma('game.n.02.game')
# ------------------------------
# Parola da disambiguare:  capacity
# Frase in cui compare la parola:  Rachel , observing , would say , `` He has to rediscover his own capacity .
# Contesto della frase:  {'capacity', 'rediscover', 'rachel', 'observe'}
# Max Signature:  {'true', 'limited', 'runway', 'capacity', 'produce', 'capability', 'great', 'growth', 'altruism', 'perform', 'gift'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('capacity.n.01')
# Senso Target:  Lemma('capacity.n.01.capacity')
# ------------------------------
# Parola da disambiguare:  sensitive
# Frase in cui compare la parola:  In the United States , most of the sensors are calibrated by dropping small spheres on their sensitive surfaces .
# Contesto della frase:  {'calibrate', 'small', 'sensitive', 'drop', 'surface', 'united', 'sphere', 'sensor'}
# Max Signature:  {'physical', 'leaf', 'light', 'mimosa', 'sensitive', 'responsive', 'stimulus', 'touch', 'skin', 'voltmeter'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('sensitive.a.01')
# Senso Target:  Lemma('sensitive.a.01.sensitive')
# ------------------------------
# Parola da disambiguare:  observed
# Frase in cui compare la parola:  In the gas phase , with * * f of * * f and * * f of * * f , quantum yields of the order of * * f have been observed at 85 ` .
# Contesto della frase:  {'yield', 'gas', 'quantum', 'observe', 'phase', 'order'}
# Max Signature:  {'note', 'presentation', 'mention', 'day', 'observe', 'fine', 'sailing', 'time'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('note.v.01')
# Senso Target:  Lemma('detect.v.01.observe')
# ------------------------------
# Parola da disambiguare:  exercising
# Frase in cui compare la parola:  Most Europeans have been exercising newborn infants for centuries . )
# Contesto della frase:  {'exercise', 'europeans', 'newborn', 'infant', 'century'}
# Max Signature:  {'exercise', 'work', 'trainer', 'puzzle', 'hard', 'workout', 'infant', 'parent', 'muscle', 'mind', 'personal'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('exercise.v.03')
# Senso Target:  Lemma('exercise.v.03.exercise')
# ------------------------------
# Parola da disambiguare:  preposterous
# Frase in cui compare la parola:  Downtown Los Angeles is already two-thirds freeway , interchange , street , parking lot and garage - one of those preposterous `` if '' statistics has already come to pass .
# Contesto della frase:  {'preposterous', 'parking', 'freeway', 'statistic', 'street', 'lot', 'downtown', 'twothirds', 'pass', 'angeles', 'garage', 'los', 'interchange'}
# Max Signature:  {'dog', 'history', 'contribution', 'universal', 'question', 'laughable', 'eat', 'ridicule', 'answer', 'ludicrous', 'absurd', 'preposterous', 'idea', 'ridiculous', 'excuse', 'homework', 'small', 'attempt', 'nonsensical', 'cockeyed', 'incongruousinviting', 'mansion', 'dull', 'child', 'turn', 'cottage', 'conceited', 'assumption', 'interest', 'call'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('absurd.s.02')
# Senso Target:  Lemma('absurd.s.02.preposterous')
# ------------------------------
# Parola da disambiguare:  foundations
# Frase in cui compare la parola:  They had had to work on very simple foundations and had not dared to give rein to impulses .
# Contesto della frase:  {'simple', 'impulse', 'dare', 'work', 'rein', 'foundation'}
# Max Signature:  {'foundation', 'basis', 'objection', 'ground'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('foundation.n.01')
# Senso Target:  Lemma('foundation.n.01.foundation')
# ------------------------------
# Termini valutati:  51
# Termini valutati correttamente:  25
# Accuratezza:  0.5
# Parola da disambiguare:  idea
# Frase in cui compare la parola:  He had no idea where he was .
# Contesto della frase:  {'idea'}
# Max Signature:  {'enter', 'idea', 'main', 'cognition', 'good', 'mind', 'content', 'thing', 'thought'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('idea.n.01')
# Senso Target:  Lemma('idea.n.01.idea')
# ------------------------------
# Parola da disambiguare:  3
# Frase in cui compare la parola:  The 6 - foot 3 inch Hansen checked in close to 200 pounds , 15 pounds lighter than his reporting weight last spring .
# Contesto della frase:  {'hansen', 'close', 'foot', 'weight', 'lighter', 'check', 'inch', 'pound', 'reporting', 'spring'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('three.n.01')
# Senso Target:  Lemma('three.s.01.3')
# ------------------------------
# Parola da disambiguare:  ordinary
# Frase in cui compare la parola:  An ordinary hot bath or shower will do the same .
# Contesto della frase:  {'ordinary', 'bath', 'hot', 'shower'}
# Max Signature:  {'expect', 'commonplace', 'ordinary', 'condition', 'situation'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('ordinary.n.02')
# Senso Target:  Lemma('ordinary.a.01.ordinary')
# ------------------------------
# Parola da disambiguare:  walls
# Frase in cui compare la parola:  The autofluorescence from the walls of the xylem cells was particularly brilliant .
# Contesto della frase:  {'brilliant', 'wall', 'xylem', 'autofluorescence', 'cell'}
# Max Signature:  {'divide', 'partition', 'enclose', 'wall', 'small', 'cover', 'great', 'area', 'window', 'support', 'picture', 'thickness', 'south', 'length', 'structure', 'height', 'architectural'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('wall.n.01')
# Senso Target:  Lemma('wall.n.01.wall')
# ------------------------------
# Parola da disambiguare:  golf
# Frase in cui compare la parola:  For a serious young man who plays golf with a serious intensity , Palmer has such an inherent sense of humor that it relieves the strain and keeps his nerves from jangling like banjo strings .
# Contesto della frase:  {'intensity', 'string', 'inherent', 'relieve', 'palmer', 'jangle', 'serious', 'young', 'golf', 'sense', 'man', 'humor', 'strain', 'banjo', 'play', 'nerve'}
# Max Signature:  {'golf', 'play'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('golf.v.01')
# Senso Target:  Lemma('golf.n.01.golf')
# ------------------------------
# Parola da disambiguare:  fibrosis
# Frase in cui compare la parola:  There was no evidence of fibrosis .
# Contesto della frase:  {'fibrosis', 'evidence'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('fibrosis.n.01')
# Senso Target:  Lemma('fibrosis.n.01.fibrosis')
# ------------------------------
# Parola da disambiguare:  son
# Frase in cui compare la parola:  They have a son , William Berry Jr. , and a daughter , Mrs. J. M. Cheshire of Griffin .
# Contesto della frase:  {'daughter', 'jr', 'son', 'griffin', 'william', 'berry', 'cheshire'}
# Max Signature:  {'boy', 'human', 'famous', 'son', 'judge', 'offspring', 'male', 'tall'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('son.n.01')
# Senso Target:  Lemma('son.n.01.son')
# ------------------------------
# Parola da disambiguare:  leather
# Frase in cui compare la parola:  At right is a casual style in a crushed unlined white leather .
# Contesto della frase:  {'casual', 'crushed', 'unlined', 'white', 'leather', 'style'}
# Max Signature:  {'leather', 'whip', 'strap'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('leather.v.01')
# Senso Target:  Lemma('leather.n.01.leather')
# ------------------------------
# Parola da disambiguare:  change
# Frase in cui compare la parola:  Obviously , very slight changes in p do not change the probabilities much , and a slight lack of independence may not make an appreciable difference .
# Contesto della frase:  {'lack', 'change', 'independence', 'slight', 'difference', 'probability', 'appreciable'}
# Max Signature:  {'change', 'event', 'marriage', 'difference', 'attribute', 'relational'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('change.n.02')
# Senso Target:  Lemma('change.v.03.change')
# ------------------------------
# Parola da disambiguare:  Violet
# Frase in cui compare la parola:  When Papa went out to do God 's work , Stevie often accompanied him in the buggy , which was drawn by Violet , the new black mare .
# Contesto della frase:  {'draw', 'violet', 'work', 'stevie', 'mare', 'god', 'accompany', 'black', 'papa', 'buggy'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('violet.n.01')
# Senso Target:  NE
# ------------------------------
# Parola da disambiguare:  room
# Frase in cui compare la parola:  The stethoscope glinted silver in the darkening room .
# Contesto della frase:  {'glint', 'darkening', 'room', 'silver', 'stethoscope'}
# Max Signature:  {'ceiling', 'wall', 'enclose', 'room', 'small', 'nice', 'area', 'view', 'floor', 'building'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('room.n.01')
# Senso Target:  Lemma('room.n.01.room')
# ------------------------------
# Parola da disambiguare:  mucosa
# Frase in cui compare la parola:  The small intestine and colon contained approximately 300 cc. of foul-smelling , sanguineous material , and the mucosa throughout was hyperemic and mottled green brown .
# Contesto della frase:  {'hyperemic', 'brown', 'green', 'sanguineous', 'foulsmelling', 'small', 'mottle', 'intestine', 'material', 'colon', 'cc', 'mucosa'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('mucous_membrane.n.01')
# Senso Target:  Lemma('mucous_membrane.n.01.mucosa')
# ------------------------------
# Parola da disambiguare:  effort
# Frase in cui compare la parola:  In these rapidly changing societies there is also too little appreciation of the need for effort to achieve goals .
# Contesto della frase:  {'society', 'goal', 'effort', 'change', 'achieve', 'appreciation', 'rapidly'}
# Max Signature:  {'luck', 'effort', 'cover', 'accomplish', 'endeavor', 'activity', 'good', 'reading', 'conscientious', 'material', 'intend', 'earnest'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('attempt.n.01')
# Senso Target:  Lemma('attempt.n.01.effort')
# ------------------------------
# Parola da disambiguare:  future
# Frase in cui compare la parola:  Pelham pointed out that Georgia voters last November rejected a constitutional amendment to allow legislators to vote on pay raises for future Legislature sessions .
# Contesto della frase:  {'legislature', 'vote', 'allow', 'legislator', 'session', 'raise', 'amendment', 'pelham', 'voter', 'point', 'november', 'reject', 'georgia', 'constitutional', 'future', 'pay'}
# Max Signature:  {'action', 'verb', 'express', 'tense', 'future'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('future.n.02')
# Senso Target:  Lemma('future.a.01.future')
# ------------------------------
# Parola da disambiguare:  bitterly
# Frase in cui compare la parola:  And no doubt many people in states like the Carolinas and Georgia , which were among the most Tory in sentiment in the eighteenth century , bitterly regretted the revolt against the Crown .
# Contesto della frase:  {'sentiment', 'bitterly', 'regret', 'doubt', 'tory', 'eighteenth', 'georgia', 'revolt', 'crown', 'carolinas', 'people', 'century'}
# Max Signature:  {'bitterly', 'bitterness', 'manner', 'resentful', 'complain'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('bitterly.r.01')
# Senso Target:  Lemma('bitterly.r.01.bitterly')
# ------------------------------
# Parola da disambiguare:  Jupiter
# Frase in cui compare la parola:  Recent interferometer measurements ( Radhakrishnan and Roberts , 1960 ) have shown the 960 - Mc emission of Jupiter to be partially polarized and to originate in a region of larger diameter than the visible disk .
# Contesto della frase:  {'jupiter', 'roberts', 'measurement', 'polarize', 'disk', 'originate', 'emission', 'large', 'interferometer', 'mc', 'partially', 'region', 'visible', 'diameter', 'radhakrishnan'}
# Max Signature:  {'sky', 'sun', 'planet', 'satellite', 'night', 'large', 'bright', 'object'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('jupiter.n.01')
# Senso Target:  Lemma('jupiter.n.01.Jupiter')
# ------------------------------
# Parola da disambiguare:  Aeschylus
# Frase in cui compare la parola:  We do not deny originality to the Agamemnon because Aeschylus found the tales of the house of Atreus among the folk lore of the Greeks .
# Contesto della frase:  {'house', 'originality', 'aeschylus', 'lore', 'folk', 'atreus', 'agamemnon', 'deny', 'greeks', 'tale', 'find'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('aeschylus.n.01')
# Senso Target:  Lemma('aeschylus.n.01.Aeschylus')
# ------------------------------
# Parola da disambiguare:  bull
# Frase in cui compare la parola:  He 'll even bull head-on into the rules when he is sure he 's right .
# Contesto della frase:  {'ll', 'rule', 'bull', 'headon'}
# Max Signature:  {'bull', 'thickskinned', 'bruiser', 'heavyset', 'large', 'man', 'good', 'strong', 'ready'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('bull.n.02')
# Senso Target:  Lemma('bull.v.01.bull')
# ------------------------------
# Parola da disambiguare:  inappropriate
# Frase in cui compare la parola:  The Warren Telegraph stated that many of Rev. Trafton 's remarks were inappropriate and savored strongly of radicalism and fanaticism .
# Contesto della frase:  {'telegraph', 'savored', 'fanaticism', 'rev', 'trafton', 'warren', 'remark', 'radicalism', 'inappropriate'}
# Max Signature:  {'suitable', 'walk', 'shoe', 'pressure', 'sadness', 'occasion', 'inappropriate', 'noise', 'beach', 'time'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('inappropriate.a.01')
# Senso Target:  Lemma('inappropriate.a.01.inappropriate')
# ------------------------------
# Parola da disambiguare:  describe
# Frase in cui compare la parola:  The concept of apparent black-body temperature is used to describe the radiation received from the moon and the planets .
# Contesto della frase:  {'describe', 'apparent', 'concept', 'planet', 'radiation', 'blackbody', 'temperature', 'receive', 'moon'}
# Max Signature:  {'describe', 'discreet', 'representation', 'italian', 'typically', 'word', 'continental', 'manner', 'account', 'police'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('report.v.01')
# Senso Target:  Lemma('report.v.01.describe')
# ------------------------------
# Parola da disambiguare:  won
# Frase in cui compare la parola:  The September October term jury had been charged by Fulton Superior Court Judge Durwood Pye to investigate reports of possible `` irregularities '' in the hard-fought primary which was won by Mayor-nominate Ivan Allen Jr. .
# Contesto della frase:  {'pye', 'jr', 'hardfought', 'investigate', 'report', 'irregularity', 'ivan', 'fulton', 'primary', 'allen', 'durwood', 'jury', 'win', 'mayornominate', 'october', 'superior', 'term', 'charge', 'court', 'judge', 'september'}
# Max Signature:  {'winner', 'victorious', 'gold', 'game', 'competition', 'medal', 'win', 'skate', 'contest', 'team'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('win.v.01')
# Senso Target:  Lemma('win.v.01.win')
# ------------------------------
# Parola da disambiguare:  recognize
# Frase in cui compare la parola:  He could not recognize it ; he was absolutely unfamiliar with it because he had no visual memory at all .
# Contesto della frase:  {'absolutely', 'unfamiliar', 'visual', 'recognize', 'memory'}
# Max Signature:  {'true', 'god', 'claim', 'crown', 'throne', 'recognize', 'power', 'acknowledge', 'heir', 'prince', 'authority', 'accept'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('acknowledge.v.06')
# Senso Target:  Lemma('spot.v.02.recognize')
# ------------------------------
# Parola da disambiguare:  rays
# Frase in cui compare la parola:  The first slanting rays of the new day cannot yet dispel all the dark shadows which lie across the Aegean world ; but our evidence grows considerably in variety and shows more unmistakably some of the lines of change .
# Contesto della frase:  {'dispel', 'ray', 'change', 'lie', 'slanting', 'day', 'evidence', 'variety', 'dark', 'shadow', 'aegean', 'unmistakably', 'grow', 'considerably'}
# Max Signature:  {'sky', 'ray', 'emit', 'mile', 'tower', 'beam', 'laser'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('ray.v.01')
# Senso Target:  Lemma('beam.n.04.ray')
# ------------------------------
# Parola da disambiguare:  considerable
# Frase in cui compare la parola:  The mucosa of the jejunum and ileum showed similar changes , and in some areas the submucosa was edematous and contained considerable numbers of neutrophils .
# Contesto della frase:  {'ileum', 'change', 'area', 'submucosa', 'jejunum', 'neutrophil', 'edematous', 'considerable', 'number', 'mucosa'}
# Max Signature:  {'campaign', 'time', 'extent', 'quantity', 'degree', 'large', 'problem', 'spent', 'economy', 'considerable', 'amount', 'issue', 'number', 'trouble'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('considerable.a.01')
# Senso Target:  Lemma('considerable.a.01.considerable')
# ------------------------------
# Parola da disambiguare:  effective
# Frase in cui compare la parola:  Large numbers of potential builders have been investigated , but none have been found to be as effective as the polyphosphates over the relatively wide range of conditions met in practice .
# Contesto della frase:  {'investigate', 'effective', 'polyphosphate', 'range', 'condition', 'large', 'practice', 'wide', 'builder', 'find', 'potential', 'number', 'meet'}
# Max Signature:  {'effective', 'peace', 'produce', 'entrance', 'capable', 'bring', 'effectual', 'motor', 'result', 'efficacious', 'striking', 'rapid', 'lewismumford', 'longdistance', 'complaint', 'law', 'method', 'action', 'intended', 'step', 'aircooled', 'teaching', 'witchs', 'prove', 'transportation', 'broomstick'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('effective.a.01')
# Senso Target:  effective.s.3;1
# ------------------------------
# Parola da disambiguare:  militarily
# Frase in cui compare la parola:  Moreover , it should not be so fastidious in its growth requirements as to make production on a militarily significant scale improbable .
# Contesto della frase:  {'improbable', 'fastidious', 'production', 'scale', 'growth', 'requirement', 'militarily'}
# Max Signature:  {'military', 'militarily', 'scale', 'respect'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('militarily.r.01')
# Senso Target:  Lemma('militarily.r.01.militarily')
# ------------------------------
# Parola da disambiguare:  8
# Frase in cui compare la parola:  Lefty Wyman Carey , another Denver rookie , will be on the mound against veteran John Tsitouris at 8 o'clock Tuesday night .
# Contesto della frase:  {'carey', 'lefty', 'night', 'wyman', 'mound', 'tsitouris', 'tuesday', 'rookie', 'veteran', 'denver', 'oclock', 'john'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('eight.n.01')
# Senso Target:  Lemma('eight.s.01.8')
# ------------------------------
# Parola da disambiguare:  vacant
# Frase in cui compare la parola:  By 3 : 00 A.M. they reached his house and found it vacant .
# Contesto della frase:  {'find', 'house', 'reach', 'vacant'}
# Max Signature:  {'knowledge', 'void', 'vacant', 'mind', 'thought'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('vacant.s.01')
# Senso Target:  Lemma('vacant.s.01.vacant')
# ------------------------------
# Parola da disambiguare:  stiffened
# Frase in cui compare la parola:  John stiffened in anger .
# Contesto della frase:  {'stiffen', 'john', 'anger'}
# Max Signature:  {'enter', 'room', 'stiffer', 'stiff', 'bos', 'stiffen'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('stiffen.v.01')
# Senso Target:  Lemma('stiffen.v.01.stiffen')
# ------------------------------
# Parola da disambiguare:  entirely
# Frase in cui compare la parola:  He does n't think that potting them from a deck chair on the south side of the house with a quart glass of beer for sustenance is entirely sporting .
# Contesto della frase:  {'nt', 'chair', 'side', 'house', 'entirely', 'deck', 'beer', 'sustenance', 'pot', 'south', 'sport', 'quart', 'glass'}
# Max Signature:  {'expect', 'satisfy', 'totally', 'extent', 'informally', 'meal', 'idea', 'altogether', 'entirely', 'completely', 'fault', 'wrong', 'convinced', 'direction', 'entire', 'degree', 'full', 'wholly', 'complete', 'situation', 'approach'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('wholly.r.01')
# Senso Target:  Lemma('wholly.r.01.entirely')
# ------------------------------
# Parola da disambiguare:  public
# Frase in cui compare la parola:  Rep. Mac Barber of Commerce is asking the House in a privilege resolution to `` endorse increased federal support for public education , provided that such funds be received and expended '' as state funds .
# Contesto della frase:  {'commerce', 'house', 'resolution', 'increased', 'education', 'federal', 'fund', 'provide', 'expend', 'support', 'mac', 'receive', 'privilege', 'rep', 'public', 'barber', 'endorse'}
# Max Signature:  {'concern', 'performer', 'park', 'library', 'fund', 'scandal', 'garden', 'open', 'family', 'figure', 'private', 'good', 'member', 'royal', 'public', 'people'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('public.a.01')
# Senso Target:  Lemma('public.a.01.public')
# ------------------------------
# Parola da disambiguare:  top
# Frase in cui compare la parola:  Those who are too weak , should climb on the chair and , starting at the top of the chin , let themselves slowly down .
# Contesto della frase:  {'chair', 'slowly', 'weak', 'chin', 'start', 'climb', 'top'}
# Max Signature:  {'mower', 'upper', 'grass', 'cut', 'title', 'write', 'top'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('top.n.01')
# Senso Target:  Lemma('top.n.01.top')
# ------------------------------
# Parola da disambiguare:  collected
# Frase in cui compare la parola:  Statistically , the most significant data have been collected from the sensors on 1958 Alpha ( Explorer 1 , ) , 1958 Delta 2 ( Sputnik 3 , ) , and 1959 Eta ( Vanguard 3 , ) .
# Contesto della frase:  {'statistically', 'explorer', 'eta', 'collect', 'sputnik', 'vanguard', 'alpha', 'sensor', 'data', 'delta'}
# Max Signature:  {'fortune', 'wife', 'amass', 'lot', 'small', 'unfaithfulness', 'evidence', 'man', 'gather', 'thesis', 'roll', 'accumulate', 'data'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('roll_up.v.02')
# Senso Target:  Lemma('gather.v.01.collect')
# ------------------------------
# Parola da disambiguare:  scientific
# Frase in cui compare la parola:  But it has been during the last two centuries , during the scientific revolution , that our independence from the physical environment has made the most rapid strides .
# Contesto della frase:  {'physical', 'scientific', 'independence', 'environment', 'rapid', 'stride', 'revolution', 'century'}
# Max Signature:  {'relate', 'science', 'scientific', 'practice', 'journal'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('scientific.a.01')
# Senso Target:  Lemma('scientific.a.01.scientific')
# ------------------------------
# Parola da disambiguare:  distant
# Frase in cui compare la parola:  This suggests that the sampling period , particularly at the more distant locations , should have been increased .
# Contesto della frase:  {'distant', 'period', 'increase', 'sampling', 'location'}
# Max Signature:  {'traffic', 'distant', 'distance', 'village', 'telephone', 'separate', 'space', 'sound', 'call'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('distant.a.01')
# ...
# Senso attribuito dall'algoritmo di Lesk:  Synset('arm.n.02')
# Senso Target:  Lemma('arm.n.01.arm')
# ------------------------------
# Parola da disambiguare:  central
# Frase in cui compare la parola:  Nomia melanderi can be found in tremendous numbers in certain parts of the United States west of the Great Plains , for example , in Utah and central Washington .
# Contesto della frase:  {'utah', 'washington', 'central', 'nomia', 'west', 'great', 'example', 'melanderi', 'plains', 'tremendous', 'united', 'find', 'number'}
# Max Signature:  {'rule', 'computer', 'serve', 'central', 'argument', 'example', 'problem', 'industrial', 'cardinal', 'fundamental', 'essential', 'modern', 'structure', 'component'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('cardinal.s.01')
# Senso Target:  central.a.00
# ------------------------------
# Parola da disambiguare:  polynomial
# Frase in cui compare la parola:  Hence the minimal polynomial for * * f is * * f .
# Contesto della frase:  {'minimal', 'polynomial'}
# Max Signature:  {'character', 'expression', 'polynomial'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('polynomial.a.01')
# Senso Target:  Lemma('polynomial.n.01.polynomial')
# ------------------------------
# Parola da disambiguare:  unique
# Frase in cui compare la parola:  These operators D and N are unique and each is a polynomial in T .
# Contesto della frase:  {'operator', 'unique', 'polynomial'}
# Max Signature:  {'history', 'handling', 'unique', 'skill', 'counterpoint', 'distinctive', 'penetration', 'altogether', 'problem', 'unparalleled', 'athletic', 'bach', 'law', 'radically', 'breakdown', 'equal', 'craftsman', 'field', 'microbiology', 'theory', 'unequaled', 'ability'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('alone.s.04')
# Senso Target:  unique.s.00
# ------------------------------
# Parola da disambiguare:  effected
# Frase in cui compare la parola:  It urged that the next Legislature `` provide enabling funds and re-set the effective date so that an orderly implementation of the law may be effected '' .
# Contesto della frase:  {'legislature', 'effective', 'enable', 'law', 'orderly', 'fund', 'reset', 'provide', 'urge', 'implementation'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('effect.v.01')
# Senso Target:  Lemma('effect.v.01.effect')
# ------------------------------
# Parola da disambiguare:  shared
# Frase in cui compare la parola:  The value-system of a community or society is always correlated with , and to a degree dependent upon , a more or less shared system of religious beliefs and convictions .
# Contesto della frase:  {'society', 'religious', 'conviction', 'belief', 'degree', 'shared', 'valuesystem', 'community', 'dependent', 'correlate', 'system'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('share.v.01')
# Senso Target:  Lemma('shared.a.01.shared')
# ------------------------------
# Parola da disambiguare:  bronchioles
# Frase in cui compare la parola:  The most distal airways are similar to those found in type 1 , , being composed of numerous , apparently true terminal bronchioles and occasional , poorly developed respiratory bronchioles ( figs. 14 , 15 ) .
# Contesto della frase:  {'occasional', 'true', 'type', 'airway', 'bronchiole', 'numerous', 'developed', 'terminal', 'respiratory', 'distal', 'find', 'figs', 'compose'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('bronchiole.n.01')
# Senso Target:  Lemma('bronchiole.n.01.bronchiole')
# ------------------------------
# Parola da disambiguare:  provide
# Frase in cui compare la parola:  Records sound like records because they provide a different sort of experience than live music .
# Contesto della frase:  {'record', 'sort', 'experience', 'provide', 'music', 'sound', 'records', 'live'}
# Max Signature:  {'room', 'heater', 'provide', 'electrical'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('supply.v.01')
# Senso Target:  Lemma('supply.v.01.provide')
# ------------------------------
# Parola da disambiguare:  saved
# Frase in cui compare la parola:  The saline tubes were saved and used for the indirect Coombs test in the following manner .
# Contesto della frase:  {'tube', 'indirect', 'saline', 'test', 'manner', 'coombs', 'save'}
# Max Signature:  {'destruction', 'ruin', 'harm', 'save'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('salvage.v.01')
# Senso Target:  Lemma('save.v.05.save')
# ------------------------------
# Parola da disambiguare:  portrays
# Frase in cui compare la parola:  As Origen interprets the end of history on the basis of its beginning , so Irenaeus portrays the story of Adam on the basis of the story of Christ .
# Contesto della frase:  {'history', 'story', 'interpret', 'adam', 'irenaeus', 'origen', 'portray', 'basis', 'christ'}
# Max Signature:  {'selfish', 'actor', 'person', 'word', 'portray', 'book'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('portray.v.01')
# Senso Target:  Lemma('portray.v.01.portray')
# ------------------------------
# Parola da disambiguare:  felt
# Frase in cui compare la parola:  It was as though , in that instant , he had felt the flatness of collage as too constricting and had suddenly tried to escape all the way back - or forward - to literal three-dimensionality .
# Contesto della frase:  {'constrict', 'suddenly', 'collage', 'instant', 'forward', 'flatness', 'threedimensionality', 'felt', 'escape', 'literal'}
# Max Signature:  {'mat', 'felt', 'feltlike', 'wool'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('felt.v.01')
# Senso Target:  Lemma('find.v.05.feel')
# ------------------------------
# Parola da disambiguare:  symptomatic
# Frase in cui compare la parola:  The flood is not as great - only 700 a week according to one apparently conservative account - but it is symptomatic .
# Contesto della frase:  {'symptomatic', 'week', 'great', 'conservative', 'account', 'flood', 'accord'}
# Max Signature:  {'relate', 'symptom', 'disease', 'relief', 'classification', 'symptomatic', 'treatment', 'accord', 'affect'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('symptomatic.a.02')
# Senso Target:  Lemma('diagnostic.s.02.symptomatic')
# ------------------------------
# Parola da disambiguare:  resolution
# Frase in cui compare la parola:  A similar resolution passed in the Senate by a vote of 29 - 5 .
# Contesto della frase:  {'resolution', 'vote', 'pass', 'senate'}
# Max Signature:  {'vote', 'meeting', 'formal', 'agree', 'expression'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('resolution.n.01')
# Senso Target:  Lemma('resolution.n.01.resolution')
# ------------------------------
# Parola da disambiguare:  heat
# Frase in cui compare la parola:  The heat losses of the holder were to be reduced as far as possible and they should be such that an accurate heat balance can be made .
# Contesto della frase:  {'loss', 'reduce', 'balance', 'accurate', 'heat', 'holder'}
# Max Signature:  {'heat', 'presence'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('hotness.n.01')
# Senso Target:  Lemma('heat.n.01.heat')
# ------------------------------
# Parola da disambiguare:  orchestration
# Frase in cui compare la parola:  The Command technique invites you to listen to the depth of the orchestration .
# Contesto della frase:  {'command', 'technique', 'depth', 'listen', 'orchestration', 'invite'}
# Max Signature:  {'campaign', 'political', 'event', 'achieve', 'attempt', 'orchestration', 'arrangement', 'maximum', 'skillful'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('orchestration.n.03')
# Senso Target:  Lemma('orchestration.n.01.orchestration')
# ------------------------------
# Parola da disambiguare:  experience
# Frase in cui compare la parola:  Love is the crucial dilemma of experience for Mann 's heroes .
# Contesto della frase:  {'love', 'experience', 'mann', 'crucial', 'dilemma', 'hero'}
# Max Signature:  {'best', 'result', 'experience', 'event', 'knowledge', 'teacher', 'activity', 'man', 'skill', 'accumulation', 'direct', 'participation'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('experience.n.01')
# Senso Target:  Lemma('experience.n.02.experience')
# ------------------------------
# Parola da disambiguare:  trembled
# Frase in cui compare la parola:  The walls bulged , the floor trembled , the windowpanes rattled .
# Contesto della frase:  {'wall', 'windowpane', 'bulge', 'floor', 'rattle', 'tremble'}
# Max Signature:  {'jerk', 'move', 'sign', 'hand', 'document', 'tremble', 'sideways', 'involuntarily'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('tremble.v.01')
# Senso Target:  Lemma('tremble.v.01.tremble')
# ------------------------------
# Parola da disambiguare:  talked
# Frase in cui compare la parola:  He said he had never talked to Liston '' .
# Contesto della frase:  {'liston', 'talk'}
# Max Signature:  {'loud', 'exchange', 'talk', 'word', 'actions', 'business', 'thought'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('talk.v.01')
# Senso Target:  Lemma('talk.v.01.talk')
# ------------------------------
# Parola da disambiguare:  belly
# Frase in cui compare la parola:  They 'd cut their mothers ' belly open .
# Contesto della frase:  {'mother', 'cut', 'open', 'belly'}
# Max Signature:  {'deeply', 'bulge', 'sail', 'belly'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('belly.n.03')
# Senso Target:  Lemma('abdomen.n.01.belly')
# ------------------------------
# Parola da disambiguare:  Inspect
# Frase in cui compare la parola:  Inspect the site in the field during the time of the year when the area will be most heavily used for recreation .
# Contesto della frase:  {'site', 'field', 'area', 'inspect', 'heavily', 'recreation', 'year', 'time'}
# Max Signature:  {'carefully', 'inspect', 'father'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('inspect.v.01')
# Senso Target:  Lemma('inspect.v.01.inspect')
# ------------------------------
# Parola da disambiguare:  mate
# Frase in cui compare la parola:  The first worker bees do not mate or lay eggs ; males and mating females do not emerge until later in the season .
# Contesto della frase:  {'female', 'lay', 'worker', 'mate', 'season', 'emerge', 'bee', 'mat', 'male', 'eggs'}
# Max Signature:  {'love', 'hate', 'animal', 'mare', 'mate', 'leave', 'camel', 'partner', 'sexual'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('mate.n.03')
# Senso Target:  Lemma('copulate.v.01.mate')
# ------------------------------
# Parola da disambiguare:  liberals
# Frase in cui compare la parola:  I write about Northern liberals from considerable personal experience .
# Contesto della frase:  {'northern', 'liberal', 'experience', 'considerable', 'personal', 'write'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('liberal.n.01')
# Senso Target:  Lemma('liberal.n.01.liberal')
# ------------------------------
# Parola da disambiguare:  party
# Frase in cui compare la parola:  Although the government was probably prepared for elections by mid - 1958 , the first decision was no doubt made more difficult as party strife multiplied .
# Contesto della frase:  {'prepared', 'doubt', 'multiply', 'mid', 'difficult', 'strife', 'decision', 'party', 'election', 'government'}
# Max Signature:  {'party', 'organize', 'political', 'organization', 'gain', 'power', 'perot', 'level', 'third', 'national'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('party.n.01')
# Senso Target:  Lemma('party.n.01.party')
# ------------------------------
# Parola da disambiguare:  dramatic
# Frase in cui compare la parola:  The situation in which we find ourselves is brought out with dramatic force in Arthur Miller 's play The Crucible , which deals with the Salem witch trials .
# Contesto della frase:  {'dramatic', 'miller', 'deal', 'salem', 'force', 'arthur', 'play', 'crucible', 'bring', 'situation', 'find', 'trial', 'witch'}
# Max Signature:  {'appearance', 'thrilling', 'dramatic', 'northern', 'spectacular', 'pause', 'sensational', 'light', 'good', 'strike', 'display', 'sunset', 'sensation', 'play', 'create'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('dramatic.s.02')
# Senso Target:  Lemma('dramatic.a.01.dramatic')
# ------------------------------
# Parola da disambiguare:  top
# Frase in cui compare la parola:  Toying with her field in the early stages , Garden Fresh was asked for top speed only in the stretch by Jockey Philip Grimm and won by a length and a half in 1.24 3 - 5 for the 7 furlongs .
# Contesto della frase:  {'toying', 'jockey', 'garden', 'philip', 'stage', 'field', 'early', 'fresh', 'grimm', 'half', 'win', 'stretch', 'length', 'top', 'speed', 'furlong'}
# Max Signature:  {'pitcher', 'half', 'top', 'relief', 'visiting', 'inning', 'team', 'bat'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('top.n.04')
# Senso Target:  top.s.00
# ------------------------------
# Parola da disambiguare:  rode
# Frase in cui compare la parola:  He rode on and on .
# Contesto della frase:  {'ride'}
# Max Signature:  {'travel', 'animal', 'mare', 'horse', 'camel', 'young', 'ride', 'drive', 'motion', 'girl', 'sit', 'control'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('ride.v.01')
# Senso Target:  Lemma('ride.v.02.ride')
# ------------------------------
# Parola da disambiguare:  increased
# Frase in cui compare la parola:  When the temperature reached 32 ` F all protozoan activity ceased ; but as the temperature rose , the numbers of protozoa increased rapidly .
# Contesto della frase:  {'cease', 'protozoan', 'reach', 'rise', 'protozoa', 'activity', 'temperature', 'increase', 'rapidly', 'number'}
# Max Signature:  {'big', 'university', 'finally', 'salary', 'increase', 'admit', 'bos', 'student', 'number'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('increase.v.02')
# Senso Target:  Lemma('increase.v.01.increase')
# ------------------------------
# Parola da disambiguare:  feelings
# Frase in cui compare la parola:  If so , then it is clear that in saying the suffering was bad we are not expressing our feelings only .
# Contesto della frase:  {'bad', 'suffering', 'express', 'clear', 'feeling'}
# Max Signature:  {'relation', 'sensitivity', 'principle', 'emotional', 'moral', 'dignity', 'remark', 'hurt', 'feeling', 'personal'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('feelings.n.01')
# Senso Target:  Lemma('feeling.n.01.feeling')
# ------------------------------
# Parola da disambiguare:  open
# Frase in cui compare la parola:  He made the decision with his eyes open , or so he thought .
# Contesto della frase:  {'eye', 'open', 'decision'}
# Max Signature:  {'eye', 'mouth', 'open'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('open.a.05')
# Senso Target:  Lemma('open.a.05.open')
# ------------------------------
# Parola da disambiguare:  24
# Frase in cui compare la parola:  The sewage flow into the treatment plant was metered and continuously recorded on 24 - hr charts .
# Contesto della frase:  {'chart', 'record', 'meter', 'hr', 'sewage', 'plant', 'treatment', 'flow', 'continuously'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('twenty-four.n.01')
# Senso Target:  Lemma('twenty-four.s.01.24')
# ------------------------------
# Parola da disambiguare:  fled
# Frase in cui compare la parola:  When East Germans fled to the West by the thousands , paeans of joy rose from the throats of Western publicists .
# Contesto della frase:  {'throat', 'publicist', 'rise', 'flee', 'west', 'joy', 'east', 'western', 'paean', 'germans'}
# Max Signature:  {'throw', 'flee', 'gun'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('flee.v.01')
# Senso Target:  Lemma('flee.v.01.flee')
# ------------------------------
# Parola da disambiguare:  staff
# Frase in cui compare la parola:  The Eagles signed him for Shaw 's staff in 1959 .
# Contesto della frase:  {'sign', 'staff', 'eagles', 'shaw'}
# Max Signature:  {'hospital', 'nursing', 'decision', 'general', 'task', 'personnel', 'assist', 'routine', 'rely', 'carry', 'excellent', 'staff', 'assigned', 'superior'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('staff.n.01')
# Senso Target:  Lemma('staff.n.01.staff')
# ------------------------------
# Termini valutati:  51
# Termini valutati correttamente:  22
# Accuratezza:  0.44
#
# Esecuzioni:  10
# Lista delle accuratezze:  [0.5, 0.6, 0.44, 0.4, 0.6, 0.6, 0.44, 0.5, 0.44, 0.44]
# Accuratezza media:  0.496
