# %%
import re
import enum
import math
import random
import nltk
import csv
import numpy as np
import scipy as sp
from nltk.corpus import wordnet as wn
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import semcor
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from random import randrange
from collections import deque
from statistics import mean

# %% [markdown]
# FUNZIONI DI PREPROCESSING

# %%
#il pre-processing consiste nella tokenizzazione, lemmatizzazione,
#rimozione della punteggiatura e delle stopwords di una sentence
def pre_processing(sentence):
    return set(remove_stopwords(tokenize_sentence(remove_punctuation(sentence))))

#rimuove le stowords da una lista di parole
def remove_stopwords(words_list):
    stopwords_list = get_stopwords()
    return [value.lower() for value in words_list if value.lower() not in stopwords_list]

#Tokenizza la frase in input e ne affettua anche la lemmatizzazione della sue parole
def tokenize_sentence(sentence):
    words_list = []
    lmtzr = WordNetLemmatizer()
    for tag in nltk.pos_tag(word_tokenize(sentence)):
        if (tag[1][:2] == "NN"):
            words_list.append(lmtzr.lemmatize(tag[0], pos = wn.NOUN))
        elif (tag[1][:2] == "VB"):
             words_list.append(lmtzr.lemmatize(tag[0], pos = wn.VERB))
        elif (tag[1][:2] == "RB"):
             words_list.append(lmtzr.lemmatize(tag[0], pos = wn.ADV))
        elif (tag[1][:2] == "JJ"):
             words_list.append(lmtzr.lemmatize(tag[0], pos = wn.ADJ))
    return words_list

#Restituisce la l'insieme di stopwords dal file delle stopwords
def get_stopwords():
    stopwords = open("stop_words_FULL.txt", "r")
    stopwords_list = []
    for word in stopwords:
        stopwords_list.append(word.replace('\n', ''))
    stopwords.close()
    return stopwords_list

#Rimuove la punteggiatura da una sentence
#Restituisce la sentence senza punteggiature
def remove_punctuation(sentence):
    return re.sub(r'[^\w\s]','',sentence)

# %% [markdown]
# FUNZIONI UTILI PER L'ANALISI DEL TESTO

# %%
#Restituisce un sostantivo random presente nel dizionario associato ad una sentence
def get_random_noun(dictionary_tag):
    try:
        sentence_nouns = dictionary_tag['NN']
    except KeyError:
        return None #se non ci sono sostantivi
    noun =  random.choice(sentence_nouns)
    if len(wn.synsets(noun)) == 0:
        return None #se il sostantivo scelto non ha almeno un synset in wordnet
    return noun

#Restituisce una parola random presente nel dizionario associato ad una sentence
def get_random_word(dictionary_tag):
    keys = list(dictionary_tag.keys())
    if not keys:
        return None #se non ci sono parole "analizzabili" nel dizionario, aka se il dizionario è vuoto
    key = random.choice(keys)
    words_list = dictionary_tag[key]
    word = random.choice(words_list)
    if len(wn.synsets(word)) == 0:
        return None #se la parola scelta non ha almeno un synset in wordnet
    return word

#Verifica che una parola abbia un synset target associato
#Senza synset target associato è inutile confrontare l'output dell'algortimo di Lesk
def check_word_synset_target(word,sentence_sem):
    for w in sentence_sem:
        if (type(w) != list):
            if (w[0] == word):
                return True
    return False
    
#Crea un dizionario che ha come chiavi i tag presenti nella sentence
#e come valori liste di parole associate a quei tag
#e.g {NN: ['home','garden'], VB:['gone'], .....,}
#input: sentence_tag -> rappresenta le words della sentence con i relativi pos tag
#input: sentence_sem -> rappresenta le words della sentence con il relativo synset target associato
def get_dictionary_tag(sentence_tag,sentence_sem):
    dictionary_tag = dict()
    stopwords_list = get_stopwords()
    for word in sentence_tag:
         tag = word.label()
         word = " ".join(l for l in word)
         if check_word_synset_target(word, sentence_sem): #Non inserisco nel dizionario parole che non hanno un synset target
             w = word.lower()
             if w not in stopwords_list and tag: #Non inserisco nel dizionario stopwords o parole che non hanno un pos tag associato
                 if tag in dictionary_tag:
                     dictionary_tag[tag].append(word)
                 else:
                     dictionary_tag[tag] = [word]             
    return dictionary_tag

#Restituisce un indice randomico utile per l'ultimo esercizio
def get_random_index(index_evaluated, INDEXES_NUM):
    while True:
        index = randrange(INDEXES_NUM)
        if index not in index_evaluated:
            return index
    
#Restituisce il synset target per una parola in una sentence
def get_synset_target_for_word_in_sentence(noun,sentence):
     for word in sentence:
      if(type(word) != list):
          if (word[0] == noun):
              return str(word.label())

# %% [markdown]
# METRICHE DI SIMILARITA E ALGORITMI PER LA RICERCA

# %%
#Custom similarity functions
def wu_palmer_similarity(sense1, sense2):
    numerator = 2 * depth(lowest_common_subsumer(sense1,sense2))
    denominator = depth(sense1) + depth(sense2)
    return numerator/denominator

def leakcock_chodorow(sense1, sense2):
    numerator = (shortest_path(sense1, sense2) + 1)
    denominator = (2 * max_depth) + 1
    return -math.log(numerator/denominator)

def shortest_path_similarity(sense1, sense2):
    return ((2 * max_depth) - shortest_path(sense1, sense2))

#Wordnet similarity functions
def wn_wu_palmer_similarity(sense1, sense2):
    sim = sense1.wup_similarity(sense2)
    if sim: return sim
    else: return 0
    
def wn_leakcock_chodorow(sense1, sense2):
    try:
        sim = sense1.lch_similarity(sense2)
        if sim: return sim
        else: return 0
    except:
        return 0

#Restituisce la similarità tra due parole date in input
def similarity(word1, word2, similarity_function):
    max_sim = 0
    for s1 in wn.synsets(word1):
        for s2 in wn.synsets(word2):
           sim = similarity_function(s1,s2)
           if sim > max_sim:
               max_sim = sim
    return max_sim

#Restituisce la profondità di un senso in wordnet, cioè il massimo percorso dal senso alla radice        
def depth(sense):
    if not sense:
        return 0
    return max([len(path) for path in all_hypernym_paths(sense)])

#Restituisce tutti i percorsi di iperonimi di un senso di wordnet, la ricerca dei percosi viene effettuata in modo ricorsivo
def all_hypernym_paths(sense):
    paths = []
    hypernyms = sense.hypernyms()
    if len(hypernyms) == 0:
        paths = [[sense]]
    for hypernym in hypernyms:
        for ancestor_list in all_hypernym_paths(hypernym):
            ancestor_list.append(sense)
            paths.append(ancestor_list)
    return paths

#Massima profondità intesa come il percorso più lungo degli iperonimi di tutti i sensi presenti in wordnet
max_depth = max(max(len(hyp_path) for hyp_path in all_hypernym_paths(ss)) for ss in wn.all_synsets())

#Restituisce un dizionario di iperonimi del senso in input con la relativa profondità
def min_hypernyms_depth(sense):
    sense_depth_queue = deque([(sense, 0)]) #deque garantisce efficienza nell'inserire ed eliminare elementi sia a destra che a sinistra della coda
    sense_depth_dict = {}
    while sense_depth_queue:
        s, depth = sense_depth_queue.popleft()
        if s in sense_depth_dict:
            continue
        sense_depth_dict[s] = depth
        depth += 1
        sense_depth_queue.extend((hyperonym, depth) for hyperonym in s.hypernyms()) #li mette a destra della coda
    return sense_depth_dict

#restituisce il percorso più breve tra due sensi di wordnet
def shortest_path(sense1,sense2):
    if sense1 == sense2:
        return 0
    dict1 = min_hypernyms_depth(sense1)
    dict2 = min_hypernyms_depth(sense2)
    min_dist = (2 * max_depth) # distanza minima iniziale

    #per ogni senso del dizionario degli iperonimi di sense1 cerca di trovare il match con un senso del secondo dizionario.
    for ss, dist1 in dict1.items():
        dist2 = dict2.get(ss)
        if not dist2:
            dist2 = (2 * max_depth)
        min_dist = min(min_dist, dist1 + dist2) #somma dei due sensi matchati
    return (2 * max_depth) if math.isinf(min_dist) else min_dist

#Restituisce il lowest common ancestor di due sensi, cioè l'iperonimo comune più vicino ai due sensi. 
#Se ne ho più di uno prendo quello può essere il più profondo rispetto alla radice.
def lowest_common_subsumer(sense1, sense2):
    if sense1 == sense2: return sense1
    
    dict1 = min_hypernyms_depth(sense1)
    dict2 = min_hypernyms_depth(sense2)
    
    min_dist = (2 * max_depth)
    candidates = []
    for ss, dist1 in dict1.items():
        dist2 = dict2.get(ss) 
        if not dist2:
            dist2 = (2 * max_depth)
        else:
            if (dist1 + dist2) <= min_dist:
                min_dist = (dist1 + dist2)
                candidates.append(ss) 
    if candidates:
        deepest = candidates[0]
        for sense in candidates:
            if depth(sense) < depth(deepest):
                deepest = sense
        return deepest #restituisce il senso con profondità maggiore rispetto alla radice

#Classe enum con la quale specifichiamo il tipo di similarità utilizzata
class Similarity_Type(enum.Enum):
    wu_palmer_similarity = 1
    shortest_path = 2
    leakcock_chodorow = 3

# %% [markdown]
# Word sense disambiguation è un problema aperto dell'elaborazione del linguaggio naturale, che comprende il processo di identificazione del senso di una parola (cioè il significato) utilizzato in una determinata frase, quando la parola ha un numero di sensi distinti (polisemia).

# %%
#Algoritmo di Lesk
def lesk_algorithm(word, sentence, word_type):
    best_sense = wn.synsets(word)[0]
    max_overlap = 0
    max_signature = []
    print("Frase in cui compare la parola: ", sentence)
    context = pre_processing(sentence)
    
    #se il tipo di parola è un nome allora cerco solo tra i nomi in wordnet
    #altrimenti prendo tutti i synset associati a quel termine
    if word_type == 'NOUN':
        synsets = wn.synsets(word, pos=wn.NOUN)
    elif word_type == 'ALL':
        synsets = wn.synsets(word)
        
    for sense in synsets:
        signature = get_signature(sense)
        overlap = len(list(signature & context)) #overlap
        if overlap > max_overlap:
            max_overlap = overlap
            best_sense = sense
            max_signature = signature
            
    print("Contesto della frase: ", context)
    print("Max Signature: ", max_signature) #signature del senso con più overlap con il contesto della sentence
    return best_sense

#Signature di un senso di WordNet
def get_signature(sense):
    signature = set()
    for word in pre_processing(sense.definition()): #tokenizzo la definizione del synset
        signature.add(word)
    for example in sense.examples(): #tokenizzo ogni esempio del synset
        for word in pre_processing(example):
            signature.add(word)
    return signature #la signature conterrà tutte le parole presenti nella definizione del senso e negli esempi

# %% [markdown]
# CONSEGNA 1:
#
# L'esercitazione consiste nell'implementare tre misure di similarità basate su WordNet.
#
# Per ciascuna di tali misure di similarità, calcolare gli indici di
# correlazione di Spearman and gli indici di correlazione di Pearson
# fra i risultati ottenuti e quelli ‘target’ presenti nel file annotato.

# %%
def main():

    #scelta della metrica da utilizzare per il calcolo della similarità
    similarity_type = Similarity_Type.leakcock_chodorow
    #similarity_type = Similarity_Type.wu_palmer_similarity
    #similarity_type = Similarity_Type.shortest_path
    
    with open('WordSim353.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        assignments = []
        targets = []
        line_count = 0
        for row in csv_reader:
            if line_count > 0:
                print("Word1: ",row[0])
                print("Word2: ",row[1])
                sim = 0
                wn_sim = 0
                if similarity_type.value == 1:
                    sim = similarity(row[0], row[1], wu_palmer_similarity)
                    wn_sim = similarity(row[0], row[1], wn_wu_palmer_similarity)
                elif similarity_type.value == 2:
                    sim = similarity(row[0], row[1], shortest_path_similarity)
                elif similarity_type.value == 3:
                    sim = similarity(row[0], row[1], leakcock_chodorow)
                    wn_sim = similarity(row[0], row[1], wn_leakcock_chodorow)
                print("Type of similarity chosen: ", similarity_type.name)
                print("MyCustom Similarity: ",sim)
                print("WordNet Similarity: ",wn_sim)
                print("Human Similarity: ",row[2])
                assignments.append(sim)
                targets.append(float(row[2]))
                print("------------------------------")
            line_count = line_count + 1
            
    print("Pearson Correlation: ", np.corrcoef(assignments, targets))
    print("Spearman Correlation: ", sp.stats.spearmanr(assignments, targets))
main()
# Out:
# Word1:  love
# Word2:  sex
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  6.77
# ------------------------------
# Word1:  tiger
# Word2:  cat
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  7.35
# ------------------------------
# Word1:  tiger
# Word2:  tiger
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# WordNet Similarity:  3.6375861597263857
# Human Similarity:  10.00
# ------------------------------
# Word1:  book
# Word2:  paper
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.46
# ------------------------------
# Word1:  computer
# Word2:  keyboard
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.62
# ------------------------------
# Word1:  computer
# Word2:  internet
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  7.58
# ------------------------------
# Word1:  plane
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  5.77
# ------------------------------
# Word1:  train
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.31
# ------------------------------
# Word1:  telephone
# Word2:  communication
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  7.50
# ------------------------------
# Word1:  television
# Word2:  radio
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  6.77
# ------------------------------
# Word1:  media
# Word2:  radio
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.42
# ------------------------------
# Word1:  drug
# Word2:  abuse
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.6486586255873816
# Human Similarity:  6.85
# ------------------------------
# Word1:  bread
# Word2:  butter
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  6.19
# ------------------------------
# Word1:  cucumber
# Word2:  potato
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  5.92
# ------------------------------
# Word1:  doctor
# Word2:  nurse
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.00
# ------------------------------
# Word1:  professor
# Word2:  doctor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  6.62
# ------------------------------
# Word1:  student
# Word2:  professor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  6.81
# ------------------------------
# Word1:  smart
# Word2:  student
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  0.9985288301111273
# Human Similarity:  4.62
# ------------------------------
# Word1:  smart
# Word2:  stupid
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  0.9985288301111273
# Human Similarity:  5.81
# ------------------------------
# Word1:  company
# Word2:  stock
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  7.08
# ------------------------------
# Word1:  stock
# Word2:  market
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  8.08
# ------------------------------
# Word1:  stock
# Word2:  phone
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  1.62
# ------------------------------
# Word1:  stock
# Word2:  CD
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  1.31
# ------------------------------
# Word1:  stock
# Word2:  jaguar
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  0.92
# ------------------------------
# Word1:  stock
# Word2:  egg
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  1.81
# ------------------------------
# Word1:  fertility
# Word2:  egg
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  6.69
# ------------------------------
# Word1:  stock
# Word2:  live
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.8718021769015913
# Human Similarity:  3.73
# ------------------------------
# Word1:  stock
# Word2:  life
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  0.92
# ------------------------------
# Word1:  book
# Word2:  library
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.46
# ------------------------------
# Word1:  bank
# Word2:  money
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  8.12
# ------------------------------
# Word1:  wood
# Word2:  forest
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# WordNet Similarity:  3.6375861597263857
# Human Similarity:  7.73
# ------------------------------
# Word1:  money
# Word2:  cash
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  9.15
# ------------------------------
# Word1:  professor
# Word2:  cucumber
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  0.31
# ------------------------------
# Word1:  king
# Word2:  cabbage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  0.23
# ------------------------------
# Word1:  king
# Word2:  queen
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# WordNet Similarity:  3.6375861597263857
# Human Similarity:  8.58
# ------------------------------
# Word1:  king
# Word2:  rook
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  5.92
# ------------------------------
# Word1:  bishop
# Word2:  rabbi
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  6.69
# ------------------------------
# Word1:  Jerusalem
# Word2:  Israel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  8.46
# ------------------------------
# Word1:  Jerusalem
# Word2:  Palestinian
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  0.8649974374866046
# Human Similarity:  7.65
# ------------------------------
# Word1:  holy
# Word2:  sex
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  1.62
# ------------------------------
# Word1:  fuck
# Word2:  sex
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.538973871058276
# Human Similarity:  9.44
# ------------------------------
# Word1:  Maradona
# Word2:  football
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  0
# Human Similarity:  8.62
# ------------------------------
# Word1:  football
# Word2:  soccer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  9.03
# ------------------------------
# Word1:  football
# Word2:  basketball
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  6.81
# ------------------------------
# Word1:  football
# Word2:  tennis
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.63
# ------------------------------
# Word1:  tennis
# Word2:  racket
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  7.56
# ------------------------------
# Word1:  Arafat
# Word2:  peace
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  1.072636802264849
# Human Similarity:  6.73
# ------------------------------
# Word1:  Arafat
# Word2:  terror
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  1.845826690498331
# Human Similarity:  7.65
# ------------------------------
# Word1:  Arafat
# Word2:  Jackson
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  2.50
# ------------------------------
# Word1:  law
# Word2:  lawyer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  8.38
# ------------------------------
# Word1:  movie
# Word2:  star
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  7.38
# ------------------------------
# Word1:  movie
# Word2:  popcorn
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  0.9985288301111273
# Human Similarity:  6.19
# ------------------------------
# Word1:  movie
# Word2:  critic
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  6.73
# ------------------------------
# Word1:  movie
# Word2:  theater
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.92
# ------------------------------
# Word1:  physics
# Word2:  proton
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.0055218656020977
# WordNet Similarity:  0.9295359586241757
# Human Similarity:  8.12
# ------------------------------
# Word1:  physics
# Word2:  chemistry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.35
# ------------------------------
# Word1:  space
# Word2:  chemistry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  4.88
# ------------------------------
# Word1:  alcohol
# Word2:  chemistry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  5.54
# ------------------------------
# Word1:  vodka
# Word2:  gin
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.46
# ------------------------------
# Word1:  vodka
# Word2:  brandy
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.13
# ------------------------------
# Word1:  drink
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  3.04
# ------------------------------
# Word1:  drink
# Word2:  ear
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  1.31
# ------------------------------
# Word1:  drink
# Word2:  mouth
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  5.96
# ------------------------------
# Word1:  drink
# Word2:  eat
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.159484249353372
# Human Similarity:  6.87
# ------------------------------
# Word1:  baby
# Word2:  mother
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  7.85
# ------------------------------
# Word1:  drink
# Word2:  mother
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  2.65
# ------------------------------
# Word1:  car
# Word2:  automobile
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# WordNet Similarity:  3.6375861597263857
# Human Similarity:  8.94
# ------------------------------
# Word1:  gem
# Word2:  jewel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# WordNet Similarity:  3.6375861597263857
# Human Similarity:  8.96
# ------------------------------
# Word1:  journey
# Word2:  voyage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  9.29
# ------------------------------
# Word1:  boy
# Word2:  lad
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  8.83
# ------------------------------
# Word1:  coast
# Word2:  shore
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  9.10
# ------------------------------
# Word1:  asylum
# Word2:  madhouse
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  8.87
# ------------------------------
# Word1:  magician
# Word2:  wizard
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# WordNet Similarity:  3.6375861597263857
# Human Similarity:  9.02
# ------------------------------
# Word1:  midday
# Word2:  noon
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# WordNet Similarity:  3.6375861597263857
# Human Similarity:  9.29
# ------------------------------
# Word1:  furnace
# Word2:  stove
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  8.79
# ------------------------------
# Word1:  food
# Word2:  fruit
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  7.52
# ------------------------------
# Word1:  bird
# Word2:  cock
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  7.10
# ------------------------------
# Word1:  bird
# Word2:  crane
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.38
# ------------------------------
# Word1:  tool
# Word2:  implement
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  6.46
# ------------------------------
# Word1:  brother
# Word2:  monk
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  6.27
# ------------------------------
# Word1:  crane
# Word2:  implement
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  2.69
# ------------------------------
# Word1:  lad
# Word2:  brother
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  4.46
# ------------------------------
# Word1:  journey
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0.8232003088081431
# WordNet Similarity:  0.7472144018302211
# Human Similarity:  5.85
# ------------------------------
# Word1:  monk
# Word2:  oracle
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  5.00
# ------------------------------
# Word1:  cemetery
# Word2:  woodland
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  2.08
# ------------------------------
# Word1:  food
# Word2:  rooster
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0.9409833444645266
# WordNet Similarity:  0.8649974374866046
# Human Similarity:  4.42
# ------------------------------
# Word1:  coast
# Word2:  hill
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  4.38
# ------------------------------
# Word1:  forest
# Word2:  graveyard
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  1.85
# ------------------------------
# Word1:  shore
# Word2:  woodland
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  3.08
# ------------------------------
# Word1:  monk
# Word2:  slave
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  0.92
# ------------------------------
# Word1:  coast
# Word2:  forest
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  3.15
# ------------------------------
# Word1:  lad
# Word2:  wizard
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  0.92
# ------------------------------
# Word1:  chord
# Word2:  smile
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  0.54
# ------------------------------
# Word1:  glass
# Word2:  magician
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  2.08
# ------------------------------
# Word1:  noon
# Word2:  string
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  0.54
# ------------------------------
# Word1:  rooster
# Word2:  voyage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0.5355182363563622
# WordNet Similarity:  0.4595323293784402
# Human Similarity:  0.62
# ------------------------------
# Word1:  money
# Word2:  dollar
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  8.42
# ------------------------------
# Word1:  money
# Word2:  cash
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  9.08
# ------------------------------
# Word1:  money
# Word2:  currency
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  9.04
# ------------------------------
# Word1:  money
# Word2:  wealth
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  8.27
# ------------------------------
# Word1:  money
# Word2:  property
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.57
# ------------------------------
# Word1:  money
# Word2:  possession
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.29
# ------------------------------
# Word1:  money
# Word2:  bank
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  8.50
# ------------------------------
# Word1:  money
# Word2:  deposit
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.73
# ------------------------------
# Word1:  money
# Word2:  withdrawal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  6.88
# ------------------------------
# Word1:  money
# Word2:  laundering
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  5.65
# ------------------------------
# Word1:  money
# Word2:  operation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  3.31
# ------------------------------
# Word1:  tiger
# Word2:  jaguar
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.00
# ------------------------------
# Word1:  tiger
# Word2:  feline
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.00
# ------------------------------
# Word1:  tiger
# Word2:  carnivore
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.08
# ------------------------------
# Word1:  tiger
# Word2:  mammal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.85
# ------------------------------
# Word1:  tiger
# Word2:  animal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.00
# ------------------------------
# Word1:  tiger
# Word2:  organism
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.538973871058276
# Human Similarity:  4.77
# ------------------------------
# Word1:  tiger
# Word2:  fauna
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  5.62
# ------------------------------
# Word1:  tiger
# Word2:  zoo
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  5.87
# ------------------------------
# Word1:  psychology
# Word2:  psychiatry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  8.08
# ------------------------------
# Word1:  psychology
# Word2:  anxiety
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  7.00
# ------------------------------
# Word1:  psychology
# Word2:  fear
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  6.85
# ------------------------------
# Word1:  psychology
# Word2:  depression
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  7.42
# ------------------------------
# Word1:  psychology
# Word2:  clinic
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  0.9985288301111273
# Human Similarity:  6.58
# ------------------------------
# Word1:  psychology
# Word2:  doctor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  6.42
# ------------------------------
# Word1:  psychology
# Word2:  Freud
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  0.6418538861723948
# Human Similarity:  8.21
# ------------------------------
# Word1:  psychology
# Word2:  mind
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.69
# ------------------------------
# Word1:  psychology
# Word2:  health
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  7.23
# ------------------------------
# Word1:  psychology
# Word2:  science
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  6.71
# ------------------------------
# Word1:  psychology
# Word2:  discipline
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.538973871058276
# Human Similarity:  5.58
# ------------------------------
# Word1:  psychology
# Word2:  cognition
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.845826690498331
# Human Similarity:  7.48
# ------------------------------
# Word1:  planet
# Word2:  star
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.45
# ------------------------------
# Word1:  planet
# Word2:  constellation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  8.06
# ------------------------------
# Word1:  planet
# Word2:  moon
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  8.08
# ------------------------------
# Word1:  planet
# Word2:  sun
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  8.02
# ------------------------------
# Word1:  planet
# Word2:  galaxy
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  8.11
# ------------------------------
# Word1:  planet
# Word2:  space
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.92
# ------------------------------
# Word1:  planet
# Word2:  astronomer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  7.94
# ------------------------------
# Word1:  precedent
# Word2:  example
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  5.85
# ------------------------------
# Word1:  precedent
# Word2:  information
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.538973871058276
# Human Similarity:  3.85
# ------------------------------
# Word1:  precedent
# Word2:  cognition
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  2.81
# ------------------------------
# Word1:  precedent
# Word2:  law
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  6.65
# ------------------------------
# Word1:  precedent
# Word2:  collection
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.538973871058276
# Human Similarity:  2.50
# ------------------------------
# Word1:  precedent
# Word2:  group
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  1.77
# ------------------------------
# Word1:  precedent
# Word2:  antecedent
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.04
# ------------------------------
# Word1:  cup
# Word2:  coffee
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.58
# ------------------------------
# Word1:  cup
# Word2:  tableware
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.538973871058276
# Human Similarity:  6.85
# ------------------------------
# Word1:  cup
# Word2:  article
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  2.40
# ------------------------------
# Word1:  cup
# Word2:  artifact
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  2.92
# ------------------------------
# Word1:  cup
# Word2:  object
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.845826690498331
# Human Similarity:  3.69
# ------------------------------
# Word1:  cup
# Word2:  entity
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  1.845826690498331
# Human Similarity:  2.15
# ------------------------------
# Word1:  cup
# Word2:  drink
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  7.25
# ------------------------------
# Word1:  cup
# Word2:  food
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.845826690498331
# Human Similarity:  5.00
# ------------------------------
# Word1:  cup
# Word2:  substance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  1.92
# ------------------------------
# Word1:  cup
# Word2:  liquid
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.845826690498331
# Human Similarity:  5.90
# ------------------------------
# Word1:  jaguar
# Word2:  cat
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  7.42
# ------------------------------
# Word1:  jaguar
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0.8803587226480918
# WordNet Similarity:  0.8043728156701697
# Human Similarity:  7.27
# ------------------------------
# Word1:  energy
# Word2:  secretary
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  1.81
# ------------------------------
# Word1:  secretary
# Word2:  senate
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  0.9985288301111273
# Human Similarity:  5.06
# ------------------------------
# Word1:  energy
# Word2:  laboratory
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  5.09
# ------------------------------
# Word1:  computer
# Word2:  laboratory
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  6.78
# ------------------------------
# Word1:  weapon
# Word2:  secret
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  6.06
# ------------------------------
# Word1:  FBI
# Word2:  fingerprint
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  6.94
# ------------------------------
# Word1:  FBI
# Word2:  investigation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.0055218656020977
# WordNet Similarity:  0.9295359586241757
# Human Similarity:  8.31
# ------------------------------
# Word1:  investigation
# Word2:  effort
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  4.59
# ------------------------------
# Word1:  Mars
# Word2:  water
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  1.6486586255873816
# Human Similarity:  2.94
# ------------------------------
# Word1:  Mars
# Word2:  scientist
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  5.63
# ------------------------------
# Word1:  news
# Word2:  report
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  8.16
# ------------------------------
# Word1:  canyon
# Word2:  landscape
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  7.53
# ------------------------------
# Word1:  image
# Word2:  surface
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  4.56
# ------------------------------
# Word1:  discovery
# Word2:  space
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  6.34
# ------------------------------
# Word1:  water
# Word2:  seepage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  6.56
# ------------------------------
# Word1:  sign
# Word2:  recess
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.159484249353372
# Human Similarity:  2.38
# ------------------------------
# Word1:  Wednesday
# Word2:  news
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  2.22
# ------------------------------
# Word1:  mile
# Word2:  kilometer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  8.66
# ------------------------------
# Word1:  computer
# Word2:  news
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  4.47
# ------------------------------
# Word1:  territory
# Word2:  surface
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  5.34
# ------------------------------
# Word1:  atmosphere
# Word2:  landscape
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  3.69
# ------------------------------
# Word1:  president
# Word2:  medal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  3.00
# ------------------------------
# Word1:  war
# Word2:  troops
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  8.13
# ------------------------------
# Word1:  record
# Word2:  number
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  6.31
# ------------------------------
# Word1:  skin
# Word2:  eye
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.22
# ------------------------------
# Word1:  Japanese
# Word2:  American
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  6.50
# ------------------------------
# Word1:  theater
# Word2:  history
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  3.91
# ------------------------------
# Word1:  volunteer
# Word2:  motto
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  2.56
# ------------------------------
# Word1:  prejudice
# Word2:  recognition
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  3.00
# ------------------------------
# Word1:  decoration
# Word2:  valor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  5.63
# ------------------------------
# Word1:  century
# Word2:  year
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.59
# ------------------------------
# Word1:  century
# Word2:  nation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  3.16
# ------------------------------
# Word1:  delay
# Word2:  racism
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  1.19
# ------------------------------
# Word1:  delay
# Word2:  news
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  3.31
# ------------------------------
# Word1:  minister
# Word2:  party
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.63
# ------------------------------
# Word1:  peace
# Word2:  plan
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  4.75
# ------------------------------
# Word1:  minority
# Word2:  peace
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  3.69
# ------------------------------
# Word1:  attempt
# Word2:  peace
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  4.25
# ------------------------------
# Word1:  government
# Word2:  crisis
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  6.56
# ------------------------------
# Word1:  deployment
# Word2:  departure
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  4.25
# ------------------------------
# Word1:  deployment
# Word2:  withdrawal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  5.88
# ------------------------------
# Word1:  energy
# Word2:  crisis
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  5.94
# ------------------------------
# Word1:  announcement
# Word2:  news
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  7.56
# ------------------------------
# Word1:  announcement
# Word2:  effort
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  2.75
# ------------------------------
# Word1:  stroke
# Word2:  hospital
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  7.03
# ------------------------------
# Word1:  disability
# Word2:  death
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  5.47
# ------------------------------
# Word1:  victim
# Word2:  emergency
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  6.47
# ------------------------------
# Word1:  treatment
# Word2:  recovery
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.91
# ------------------------------
# Word1:  journal
# Word2:  association
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  4.97
# ------------------------------
# Word1:  doctor
# Word2:  personnel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  5.00
# ------------------------------
# Word1:  doctor
# Word2:  liability
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  5.19
# ------------------------------
# Word1:  liability
# Word2:  insurance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.03
# ------------------------------
# Word1:  school
# Word2:  center
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  3.44
# ------------------------------
# Word1:  reason
# Word2:  hypertension
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  2.31
# ------------------------------
# Word1:  reason
# Word2:  criterion
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  5.91
# ------------------------------
# Word1:  hundred
# Word2:  percent
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  7.38
# ------------------------------
# Word1:  Harvard
# Word2:  Yale
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.13
# ------------------------------
# Word1:  hospital
# Word2:  infrastructure
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  4.63
# ------------------------------
# Word1:  death
# Word2:  row
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  5.25
# ------------------------------
# Word1:  death
# Word2:  inmate
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  5.03
# ------------------------------
# Word1:  lawyer
# Word2:  evidence
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  6.69
# ------------------------------
# Word1:  life
# Word2:  death
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.88
# ------------------------------
# Word1:  life
# Word2:  term
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  4.50
# ------------------------------
# Word1:  word
# Word2:  similarity
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  4.75
# ------------------------------
# Word1:  board
# Word2:  recommendation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  4.47
# ------------------------------
# Word1:  governor
# Word2:  interview
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  0.9985288301111273
# Human Similarity:  3.25
# ------------------------------
# Word1:  OPEC
# Word2:  country
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  5.63
# ------------------------------
# Word1:  peace
# Word2:  atmosphere
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  3.69
# ------------------------------
# Word1:  peace
# Word2:  insurance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  2.94
# ------------------------------
# Word1:  territory
# Word2:  kilometer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  5.28
# ------------------------------
# Word1:  travel
# Word2:  activity
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  5.00
# ------------------------------
# Word1:  competition
# Word2:  price
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  6.44
# ------------------------------
# Word1:  consumer
# Word2:  confidence
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  4.13
# ------------------------------
# Word1:  consumer
# Word2:  energy
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  4.75
# ------------------------------
# Word1:  problem
# Word2:  airport
# ...
# WordNet Similarity:  0.9295359586241757
# Human Similarity:  5.97
# ------------------------------
# Word1:  game
# Word2:  victory
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.03
# ------------------------------
# Word1:  game
# Word2:  team
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  7.69
# ------------------------------
# Word1:  marathon
# Word2:  sprint
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  7.47
# ------------------------------
# Word1:  game
# Word2:  series
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  6.19
# ------------------------------
# Word1:  game
# Word2:  defeat
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  6.97
# ------------------------------
# Word1:  seven
# Word2:  series
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  3.56
# ------------------------------
# Word1:  seafood
# Word2:  sea
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  7.47
# ------------------------------
# Word1:  seafood
# Word2:  food
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  8.34
# ------------------------------
# Word1:  seafood
# Word2:  lobster
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.70
# ------------------------------
# Word1:  lobster
# Word2:  food
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.81
# ------------------------------
# Word1:  lobster
# Word2:  wine
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  5.70
# ------------------------------
# Word1:  food
# Word2:  preparation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  6.22
# ------------------------------
# Word1:  video
# Word2:  archive
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  6.34
# ------------------------------
# Word1:  start
# Word2:  year
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  4.06
# ------------------------------
# Word1:  start
# Word2:  match
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  1.8718021769015913
# Human Similarity:  4.47
# ------------------------------
# Word1:  game
# Word2:  round
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  5.97
# ------------------------------
# Word1:  boxing
# Word2:  round
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.61
# ------------------------------
# Word1:  championship
# Word2:  tournament
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.36
# ------------------------------
# Word1:  fighting
# Word2:  defeating
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  2.159484249353372
# Human Similarity:  7.41
# ------------------------------
# Word1:  line
# Word2:  insurance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  2.69
# ------------------------------
# Word1:  day
# Word2:  summer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  3.94
# ------------------------------
# Word1:  summer
# Word2:  drought
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.16
# ------------------------------
# Word1:  summer
# Word2:  nature
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  5.63
# ------------------------------
# Word1:  day
# Word2:  dawn
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.53
# ------------------------------
# Word1:  nature
# Word2:  environment
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  8.31
# ------------------------------
# Word1:  environment
# Word2:  ecology
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  8.81
# ------------------------------
# Word1:  nature
# Word2:  man
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  6.25
# ------------------------------
# Word1:  man
# Word2:  woman
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.30
# ------------------------------
# Word1:  man
# Word2:  governor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  5.25
# ------------------------------
# Word1:  murder
# Word2:  manslaughter
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.53
# ------------------------------
# Word1:  soap
# Word2:  opera
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  0.9985288301111273
# Human Similarity:  7.94
# ------------------------------
# Word1:  opera
# Word2:  performance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  6.88
# ------------------------------
# Word1:  life
# Word2:  lesson
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  5.94
# ------------------------------
# Word1:  focus
# Word2:  life
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  4.06
# ------------------------------
# Word1:  production
# Word2:  crew
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  6.25
# ------------------------------
# Word1:  television
# Word2:  film
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  7.72
# ------------------------------
# Word1:  lover
# Word2:  quarrel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  6.19
# ------------------------------
# Word1:  viewer
# Word2:  serial
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  2.97
# ------------------------------
# Word1:  possibility
# Word2:  girl
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  1.94
# ------------------------------
# Word1:  population
# Word2:  development
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  3.75
# ------------------------------
# Word1:  morality
# Word2:  importance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  3.31
# ------------------------------
# Word1:  morality
# Word2:  marriage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  3.69
# ------------------------------
# Word1:  Mexico
# Word2:  Brazil
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  7.44
# ------------------------------
# Word1:  gender
# Word2:  equality
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  6.41
# ------------------------------
# Word1:  change
# Word2:  attitude
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  5.44
# ------------------------------
# Word1:  family
# Word2:  planning
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  6.25
# ------------------------------
# Word1:  opera
# Word2:  industry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  2.63
# ------------------------------
# Word1:  sugar
# Word2:  approach
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.3121863889661687
# Human Similarity:  0.88
# ------------------------------
# Word1:  practice
# Word2:  institution
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  3.19
# ------------------------------
# Word1:  ministry
# Word2:  culture
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  4.69
# ------------------------------
# Word1:  problem
# Word2:  challenge
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.75
# ------------------------------
# Word1:  size
# Word2:  prominence
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  5.31
# ------------------------------
# Word1:  country
# Word2:  citizen
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  7.31
# ------------------------------
# Word1:  planet
# Word2:  people
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  5.75
# ------------------------------
# Word1:  development
# Word2:  issue
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  3.97
# ------------------------------
# Word1:  experience
# Word2:  music
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  3.47
# ------------------------------
# Word1:  music
# Word2:  project
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  3.63
# ------------------------------
# Word1:  glass
# Word2:  metal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  5.56
# ------------------------------
# Word1:  aluminum
# Word2:  metal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  7.83
# ------------------------------
# Word1:  chance
# Word2:  credibility
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  3.88
# ------------------------------
# Word1:  exhibit
# Word2:  memorabilia
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  5.31
# ------------------------------
# Word1:  concert
# Word2:  virtuoso
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  6.81
# ------------------------------
# Word1:  rock
# Word2:  jazz
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.59
# ------------------------------
# Word1:  museum
# Word2:  theater
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.19
# ------------------------------
# Word1:  observation
# Word2:  architecture
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  4.38
# ------------------------------
# Word1:  space
# Word2:  world
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  6.53
# ------------------------------
# Word1:  preservation
# Word2:  world
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  6.19
# ------------------------------
# Word1:  admission
# Word2:  ticket
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.69
# ------------------------------
# Word1:  shower
# Word2:  thunderstorm
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  6.31
# ------------------------------
# Word1:  shower
# Word2:  flood
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  1.6486586255873816
# Human Similarity:  6.03
# ------------------------------
# Word1:  weather
# Word2:  forecast
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  1.3121863889661687
# Human Similarity:  8.34
# ------------------------------
# Word1:  disaster
# Word2:  area
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  6.25
# ------------------------------
# Word1:  governor
# Word2:  office
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  6.34
# ------------------------------
# Word1:  architecture
# Word2:  century
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  3.78
# ------------------------------
# Pearson Correlation:  [[1.         0.26142012]
#  [0.26142012 1.        ]]
# Spearman Correlation:  SpearmanrResult(correlation=0.2651845536640065, pvalue=4.292887522518468e-07)

# %% [markdown]
# CONSEGNA 2.1:
#
# Estrarre 50 frasi dal corpus SemCor (corpus annotato con i synset di
# WN) e disambiguare (almeno) un sostantivo per frase.
#
# Calcolare
# l’accuratezza del sistema implementato sulla base dei sensi annotati in
# SemCor.

# %%
tokenizer = RegexpTokenizer(r'\w+')

INDEXES_NUM = 1000 #è il limite, partendo da 0, di sentence che possono essere testate relative al database SemCor
RANGE = 50 #è il numero di sentence che effettivamente verranno testate

sentences_tag = semcor.tagged_sents() #lista di liste. Ogni lista rappresenta una sentence e ad ogni parola della sentence è associato un pos tag
sentences = semcor.sents() #lista di liste di parole. Ogni lista rappresenta una sentence
sentences_sem = semcor.tagged_sents(tag = "sem") #lista di liste. Ogni lista rappresenta una sentence e ad ogni parola della sentence è associato un synset gold

def main():
    evaluated = 0 #termini valutati
    checked = 0 #termini valutati correttamente
    index_evaluated = set() #insieme degli indici già valutati
    while(evaluated <= RANGE):
        while True: #fino a quando non trova una word che ha almeno un senso in wordnet   
            index = get_random_index(index_evaluated, INDEXES_NUM)
            word = get_random_noun(get_dictionary_tag(sentences_tag[index],sentences_sem[index]))
            if word:
                break
        sentence = sentences[index]
        print("Parola da disambiguare: ",word)
        #all'algoritmo di lesk viene dato in input la word e l'insieme dei termini che formano la frase, uniti sottoforma di stringa
        best_sense = str(lesk_algorithm(word, ' '.join(word for word in sentence), word_type='NOUN'))
        print("Senso attribuito dall'algoritmo di Lesk: ",best_sense)
        target_lemma = get_synset_target_for_word_in_sentence(word,sentences_sem[index])
        print("Senso Target: ",target_lemma)
        best_sense_lemma = best_sense[8:len(best_sense)-2]
        if target_lemma:
            if best_sense_lemma in target_lemma:
             checked= checked + 1
        evaluated += 1
        print("------------------------------")
    
    print("Termini valutati: ", evaluated)
    print("Termini valutati correttamente: ", checked)
    print("Accuratezza: ", checked/RANGE)
    
main()
# Out:
# Parola da disambiguare:  suggestion
# Frase in cui compare la parola:  Just the barest suggestion of a heel is found on teenage pumps .
# Contesto della frase:  {'heel', 'pump', 'teenage', 'bare', 'suggestion', 'find'}
# Max Signature:  {'idea', 'suggestion', 'picnic'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('suggestion.n.01')
# Senso Target:  Lemma('trace.n.01.suggestion')
# ------------------------------
# Parola da disambiguare:  horror
# Frase in cui compare la parola:  It 's a horror .
# Contesto della frase:  {'horror'}
# Max Signature:  {'painting', 'horror', 'beautiful', 'inspire', 'horrible', 'find'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('horror.n.02')
# Senso Target:  Lemma('horror.n.02.horror')
# ------------------------------
# Parola da disambiguare:  season
# Frase in cui compare la parola:  An injury forced Skorich to quit after the 1948 season .
# Contesto della frase:  {'force', 'quit', 'season', 'skorich', 'injury'}
# Max Signature:  {'ballet', 'celebrate', 'field', 'mark', 'season', 'forward', 'activity', 'company', 'year', 'period', 'event', 'special', 'avocado'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('season.n.01')
# Senso Target:  Lemma('season.n.01.season')
# ------------------------------
# Parola da disambiguare:  situation
# Frase in cui compare la parola:  There are two more Sunday afternoons when the situation will arise .
# Contesto della frase:  {'afternoon', 'sunday', 'situation'}
# Max Signature:  {'social', 'combination', 'droosevelt', 'time', 'situation', 'fresh', 'franklin', 'international', 'true', 'eternal', 'thing', 'meaning', 'circumstance', 'wonder', 'truth', 'affair', 'general', 'dangerous'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('situation.n.01')
# Senso Target:  Lemma('situation.n.01.situation')
# ------------------------------
# Parola da disambiguare:  Daddy
# Frase in cui compare la parola:  If Daddy 's books are out of bounds his own picture books are not .
# Contesto della frase:  {'book', 'bound', 'daddy', 'picture'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('dad.n.01')
# Senso Target:  Lemma('dad.n.01.daddy')
# ------------------------------
# Parola da disambiguare:  majors
# Frase in cui compare la parola:  The Continental League never got off the ground , but after two years it forced the existing majors to expand .
# Contesto della frase:  {'force', 'ground', 'continental', 'major', 'expand', 'league', 'year', 'exist'}
# Max Signature:  {'sport', 'baseball', 'league'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('major_league.n.01')
# Senso Target:  Lemma('major_league.n.01.majors')
# ------------------------------
# Parola da disambiguare:  accessories
# Frase in cui compare la parola:  The girls , very fetching in their uniforms , are shown firing rockets from a launcher mounted on a dump truck ; they are also trained with carbines , automatic weapons , pistols , rifles and other such ladies ' accessories .
# Contesto della frase:  {'uniform', 'rocket', 'automatic', 'fire', 'launcher', 'carbine', 'rifle', 'lady', 'pistol', 'accessory', 'weapon', 'dump', 'train', 'truck', 'girl', 'fetch', 'mount'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('accessory.n.01')
# Senso Target:  Lemma('accessory.n.01.accessory')
# ------------------------------
# Parola da disambiguare:  opener
# Frase in cui compare la parola:  Rice has not played since injuring a knee in the opener with Maryland .
# Contesto della frase:  {'injure', 'knee', 'maryland', 'rice', 'opener', 'play'}
# Max Signature:  {'series', 'season', 'yankees', 'chopin', 'opener', 'game', 'event', 'play'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('opener.n.01')
# Senso Target:  Lemma('opener.n.01.opener')
# ------------------------------
# Parola da disambiguare:  families
# Frase in cui compare la parola:  Whole families are moving and removal firms are booked for months ahead .
# Contesto della frase:  {'firm', 'ahead', 'book', 'move', 'family', 'removal', 'month'}
# Max Signature:  {'social', 'wait', 'virginia', 'asleep', 'unit', 'household', 'move', 'good', 'christian', 'family', 'people', 'teacher', 'house', 'live'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('family.n.01')
# Senso Target:  Lemma('family.n.01.family')
# ------------------------------
# Parola da disambiguare:  Restoration
# Frase in cui compare la parola:  And in England , after the Restoration , the body of Cromwell was disinterred and hanged at Tyburn .
# Contesto della frase:  {'cromwell', 'disinter', 'hang', 'tyburn', 'restoration', 'body', 'england'}
# Max Signature:  {'ii', 'reign', 'charles', 'england'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('restoration.n.01')
# Senso Target:  Lemma('restoration.n.01.Restoration')
# ------------------------------
# Parola da disambiguare:  peace
# Frase in cui compare la parola:  He is a Buddhist , which means that to him peace and the sanctity of human life are not only religious dogma , but a profound and unshakable Weltanschauung .
# Contesto della frase:  {'weltanschauung', 'life', 'human', 'religious', 'dogma', 'peace', 'sanctity', 'unshakable', 'profound', 'buddhist'}
# Max Signature:  {'harmonious', 'dispute', 'roommate', 'relation', 'freedom', 'peace', 'live'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('peace.n.02')
# Senso Target:  Lemma('peace.n.01.peace')
# ------------------------------
# Parola da disambiguare:  short
# Frase in cui compare la parola:  Jackie Brandt singled deep into the hole at short to start the rally .
# Contesto della frase:  {'jackie', 'rally', 'start', 'deep', 'brandt', 'single', 'short', 'hole'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('short.n.01')
# Senso Target:  Lemma('short.n.01.short')
# ------------------------------
# Parola da disambiguare:  Nation
# Frase in cui compare la parola:  The materials for compromise are at hand : The Nation , Walter Lippmann and other sober commentators ( see Alan Clark on p. 367 ) have spelled them out again and again .
# Contesto della frase:  {'lippmann', 'sober', 'material', 'clark', 'commentator', 'nation', 'compromise', 'spell', 'alan', 'walter', 'hand'}
# Max Signature:  {'land', 'large', 'elect', 'president', 'student', 'country', 'capitol', 'single', 'politically', 'organize', 'manufacturer', 'industrialized', 'nation', 'body', 'people', 'government', 'african'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('state.n.04')
# Senso Target:  NE
# ------------------------------
# Parola da disambiguare:  ballast
# Frase in cui compare la parola:  If his mother loves him , he clings to that love as a ballast .
# Contesto della frase:  {'love', 'ballast', 'cling', 'mother'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('ballast.n.01')
# Senso Target:  Lemma('ballast.n.01.ballast')
# ------------------------------
# Parola da disambiguare:  Denver
# Frase in cui compare la parola:  `` We always like to keep the ball as much as we can against Denver because they have such an explosive attack '' , explained Stram .
# Contesto della frase:  {'stram', 'denver', 'ball', 'explosive', 'explain', 'attack'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('denver.n.01')
# Senso Target:  Lemma('denver.n.01.Denver')
# ------------------------------
# Parola da disambiguare:  election
# Frase in cui compare la parola:  Davis received 1119 votes in Saturday 's election , and Bush got 402 .
# Contesto della frase:  {'bush', 'davis', 'election', 'receive', 'saturday', 'vote'}
# Max Signature:  {'select', 'office', 'political', 'winner', 'election', 'result', 'tonight', 'position', 'vote'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('election.n.01')
# Senso Target:  Lemma('election.n.01.election')
# ------------------------------
# Parola da disambiguare:  straws
# Frase in cui compare la parola:  Do n't overlook the straws this year .
# Contesto della frase:  {'straw', 'year', 'overlook'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('straw.n.01')
# Senso Target:  Lemma('straw.n.01.straw')
# ------------------------------
# Parola da disambiguare:  runs
# Frase in cui compare la parola:  The Birds got five hits and all three of their runs off Kunkel before Hartman took over in the top of the fourth .
# Contesto della frase:  {'fourth', 'hartman', 'top', 'kunkel', 'hit', 'birds'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('run.n.01')
# Senso Target:  Lemma('run.n.01.run')
# ------------------------------
# Parola da disambiguare:  March
# Frase in cui compare la parola:  He went into the Army in March , 1957 , and returned two years later .
# Contesto della frase:  {'army', 'march', 'return', 'year'}
# Max Signature:  {'regular', 'sound', 'walk', 'step', 'kind', 'procession', 'march', 'long', 'hear'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('march.n.02')
# Senso Target:  Lemma('march.n.01.March')
# ------------------------------
# Parola da disambiguare:  kid
# Frase in cui compare la parola:  Stengel probably preached too much in the early days when the kid wanted to pop his bubble gum and sow his oats .
# Contesto della frase:  {'bubble', 'stengel', 'early', 'kid', 'pop', 'gum', 'preach', 'oat', 'day', 'sow'}
# Max Signature:  {'tiddler', 'child', 'sex', 'write', 'book', 'british', 'kid', 'term', 'person', 'young', 'youngster'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('child.n.01')
# Senso Target:  Lemma('child.n.01.kid')
# ------------------------------
# Parola da disambiguare:  degree
# Frase in cui compare la parola:  Despite the 45 - degree weather the game was clicked off in 1 : 48 , thanks to only three bases on balls and some good infield play .
# Contesto della frase:  {'base', 'infield', 'good', 'ball', 'degree', 'game', 'play', 'click'}
# Max Signature:  {'scale', 'spite', 'temperature', 'unit', 'game', 'play'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('degree.n.06')
# Senso Target:  Lemma('degree.n.06.degree')
# ------------------------------
# Parola da disambiguare:  shape
# Frase in cui compare la parola:  Styles run the gamut from slender and tapered with elongated toes to a newer squared toe shape .
# Contesto della frase:  {'taper', 'newer', 'toe', 'elongated', 'gamut', 'slender', 'square', 'styles', 'shape'}
# Max Signature:  {'define', 'attribute', 'outline', 'barely', 'spatial', 'shape'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('shape.n.01')
# Senso Target:  Lemma('shape.n.01.shape')
# ------------------------------
# Parola da disambiguare:  teachers
# Frase in cui compare la parola:  College teachers in Texas are not required to have the Education courses .
# Contesto della frase:  {'course', 'education', 'college', 'texas', 'teacher', 'require'}
# Max Signature:  {'teach', 'experience', 'book', 'demand', 'teacher', 'personified', 'abstraction'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('teacher.n.02')
# Senso Target:  Lemma('teacher.n.01.teacher')
# ------------------------------
# Parola da disambiguare:  Thursday
# Frase in cui compare la parola:  Senators unanimously approved Thursday the bill of Sen. George Parkhouse of Dallas authorizing establishment of day schools for the deaf in Dallas and the four other largest counties .
# Contesto della frase:  {'county', 'unanimously', 'large', 'authorize', 'bill', 'thursday', 'sen', 'senators', 'school', 'approve', 'establishment', 'dallas', 'parkhouse', 'george', 'day', 'deaf'}
# Max Signature:  {'fourth', 'working', 'day', 'week'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('thursday.n.01')
# Senso Target:  Lemma('thursday.n.01.Thursday')
# ------------------------------
# Parola da disambiguare:  mob
# Frase in cui compare la parola:  A British writer , Richard Haestier , in a book , Dead Men Tell Tales , recalls that in the turmoil preceding French Revolution the body of Henry /4 , , who had died nearly 180 years earlier , was torn to pieces by a mob .
# Contesto della frase:  {'turmoil', 'revolution', 'french', 'tales', 'dead', 'henry', 'year', 'writer', 'piece', 'mob', 'richard', 'body', 'earlier', 'british', 'book', 'precede', 'tear', 'men', 'haestier', 'recall', 'die'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('mob.n.01')
# Senso Target:  Lemma('mob.n.01.mob')
# ------------------------------
# Parola da disambiguare:  booking
# Frase in cui compare la parola:  Then why not the juicy booking Hurok had held for us ?
# Contesto della frase:  {'hold', 'hurok', 'book', 'juicy'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('engagement.n.05')
# Senso Target:  Lemma('engagement.n.05.booking')
# ------------------------------
# Parola da disambiguare:  man
# Frase in cui compare la parola:  `` I know when my reflexes are gone and I'm not going to be any 25th man on the ball club '' .
# Contesto della frase:  {'man', 'club', 'ball', 'reflex'}
# Max Signature:  {'man', 'word', 'human', 'generic', 'refer'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('man.n.03')
# Senso Target:  Lemma('man.n.01.man')
# ------------------------------
# Parola da disambiguare:  man
# Frase in cui compare la parola:  The Yankee triumph made Ralph Houk only the third man to lead a team to both a pennant and a World Series victory in his first year as a manager .
# Contesto della frase:  {'man', 'victory', 'pennant', 'houk', 'series', 'third', 'year', 'lead', 'triumph', 'ralph', 'manager', 'team', 'yankee'}
# Max Signature:  {'man', 'word', 'human', 'generic', 'refer'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('man.n.03')
# Senso Target:  Lemma('man.n.01.man')
# ------------------------------
# Parola da disambiguare:  year
# Frase in cui compare la parola:  Ryne Duren and Roland Sheldon , a rookie righthander who posted a 15 - 1 record last year for the Yanks ' Auburn ( N.Y. ) farm club of the Class - D New York-Pennsylvania League , are the probable rival pitchers .
# Contesto della frase:  {'record', 'class', 'ny', 'league', 'duren', 'rookie', 'righthander', 'sheldon', 'probable', 'post', 'ryne', 'rival', 'auburn', 'year', 'farm', 'pitcher', 'club', 'yorkpennsylvania', 'yanks', 'roland'}
# Max Signature:  {'class', 'high', 'student', 'year', 'body', 'graduate', 'hoehandle'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('class.n.06')
# Senso Target:  Lemma('year.n.01.year')
# ------------------------------
# Parola da disambiguare:  night
# Frase in cui compare la parola:  Larry Scherer last night pitched a no-hit game , said to be the first in Billiken baseball history , as the Blue and White beat Southeast Missouri State College , 5 - 1 , at Crystal City .
# Contesto della frase:  {'blue', 'billiken', 'nohit', 'southeast', 'college', 'beat', 'pitch', 'night', 'baseball', 'history', 'missouri', 'city', 'crystal', 'scherer', 'game', 'larry', 'white'}
# Max Signature:  {'sleep', 'night', 'spend', 'period', 'restless'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('night.n.03')
# Senso Target:  Lemma('night.n.01.night')
# ------------------------------
# Parola da disambiguare:  magazine
# Frase in cui compare la parola:  Ritchie walked up to him at the magazine stand .
# Contesto della frase:  {'ritchie', 'magazine', 'walk', 'stand'}
# Max Signature:  {'publication', 'story', 'start', 'picture', 'money', 'periodic', 'article', 'purchase', 'magazine', 'year', 'break', 'interest', 'subscribe'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('magazine.n.01')
# Senso Target:  Lemma('magazine.n.01.magazine')
# ------------------------------
# Parola da disambiguare:  weather
# Frase in cui compare la parola:  `` We 'll have the problem of baseball at one end and weather at the other '' .
# Contesto della frase:  {'ll', 'problem', 'baseball', 'weather'}
# Max Signature:  {'play', 'condition', 'atmosphere', 'cloud', 'yesterday', 'temperature', 'atmospheric', 'exception', 'comprise', 'good', 'hop', 'term', 'snow', 'wind', 'weather', 'day', 'rainy', 'precipitation'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('weather.n.01')
# Senso Target:  Lemma('weather.n.01.weather')
# ------------------------------
# Parola da disambiguare:  time
# Frase in cui compare la parola:  It was the first time we 've been ahead this season ( when John Richey kicked what proved to be the winning field goal ) '' .
# Contesto della frase:  {'richey', 'ahead', 'goal', 'time', 'field', 'season', 'kick', 'winning', 'john', 've', 'prove'}
# Max Signature:  {'succeed', 'time', 'call', 'single', 'ten', 'clip', 'instance', 'occasion', 'event'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('time.n.01')
# Senso Target:  Lemma('time.n.01.time')
# ------------------------------
# Parola da disambiguare:  question
# Frase in cui compare la parola:  `` But I believe if people were better informed on this question , most of them would oppose it also .
# Contesto della frase:  {'good', 'question', 'people', 'oppose', 'inform'}
# Max Signature:  {'question', 'inquiry', 'instance', 'training'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('question.n.01')
# Senso Target:  Lemma('question.n.02.question')
# ------------------------------
# Parola da disambiguare:  day
# Frase in cui compare la parola:  Schley County Rep. B. D. Pelham will offer a resolution Monday in the House to rescind the body 's action of Friday in voting itself a $ 10 per day increase in expense allowances .
# Contesto della frase:  {'county', 'offer', 'monday', 'resolution', 'friday', 'allowance', 'expense', 'rescind', 'pelham', 'body', 'action', 'increase', 'schley', 'house', 'day', 'rep', 'vote'}
# Max Signature:  {'complete', 'time', 'leave', 'axis', 'earth', 'passenger', 'rotation', 'day', 'performance'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('day.n.01')
# Senso Target:  Lemma('day.n.01.day')
# ------------------------------
# Parola da disambiguare:  Wingback
# Frase in cui compare la parola:  Wingback Jack Collins injured a knee in the Washington State game but insists he 'll be ready for Oklahoma .
# Contesto della frase:  {'injure', 'jack', 'ready', 'collins', 'knee', 'oklahoma', 'insist', 'washington', 'll', 'game', 'wingback'}
# Max Signature:  {'person', 'wingback', 'play', 'football'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('wingback.n.01')
# Senso Target:  Lemma('wingback.n.01.wingback')
# ------------------------------
# Parola da disambiguare:  scope
# Frase in cui compare la parola:  Perhaps the lesson we should take from these pages is that the welfare state in England still allows wild scope for all kinds of rugged eccentrics .
# Contesto della frase:  {'kind', 'eccentric', 'allow', 'rugged', 'welfare', 'lesson', 'england', 'wild', 'scope'}
# Max Signature:  {'investigation', 'area', 'political', 'compass', 'human', 'law', 'supersonic', 'control', 'voice', 'article', 'legislation', 'great', 'operate', 'jet', 'ambit', 'reach', 'power', 'scope', 'range', 'piano', 'municipal', 'orbit'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('scope.n.01')
# Senso Target:  Lemma('scope.n.01.scope')
# ------------------------------
# Parola da disambiguare:  games
# Frase in cui compare la parola:  In their first three games , the Longhorns have had the ball 41 times and scored 16 times , or 40 per cent their total passing yardage in three games , 447 on 30 completions in 56 attempts , is only 22 yards short of their total passing yardage in 1959 , when they made 469 on 37 completions in 86 tries .
# Contesto della frase:  {'attempt', 'time', 'yardage', 'passing', 'yard', 'longhorns', 'short', 'ball', 'completion', 'score', 'game', 'total', 'cent'}
# Max Signature:  {'word', 'empty', 'amusement', 'painting', 'time', 'life', 'game', 'fun', 'pastime', 'play', 'fill'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('game.n.03')
# Senso Target:  Lemma('game.n.02.game')
# ------------------------------
# Parola da disambiguare:  tournament
# Frase in cui compare la parola:  So he picked up a stroke with the provisional ball and won the tournament by the margin of that stroke .
# Contesto della frase:  {'pick', 'stroke', 'tournament', 'ball', 'provisional', 'win', 'margin'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('tournament.n.01')
# Senso Target:  Lemma('tournament.n.01.tournament')
# ------------------------------
# Parola da disambiguare:  housewife
# Frase in cui compare la parola:  Mrs. Grace Butcher , of nearby Chardon , a 27 - year old housewife who has two children , finished in 2.21.6 .
# Contesto della frase:  {'nearby', 'child', 'butcher', 'grace', 'chardon', 'housewife', 'finish', 'year'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('housewife.n.01')
# Senso Target:  Lemma('housewife.n.01.housewife')
# ------------------------------
# Parola da disambiguare:  France
# Frase in cui compare la parola:  Mongi Slim of Tunisia and Frederick Boland of Ireland were early favorites in the running , but France did n't like the former and the Soviet Union would have none of the latter .
# Contesto della frase:  {'tunisia', 'slim', 'ireland', 'frederick', 'union', 'soviet', 'france', 'early', 'boland', 'running', 'favorite', 'mongi', 'nt'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('france.n.01')
# Senso Target:  Lemma('france.n.01.France')
# ------------------------------
# Parola da disambiguare:  people
# Frase in cui compare la parola:  `` But I believe if people were better informed on this question , most of them would oppose it also .
# Contesto della frase:  {'good', 'question', 'people', 'oppose', 'inform'}
# Max Signature:  {'child', 'group', 'audience', 'collectively', 'human', 'woman', 'men', 'plural', 'people'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('people.n.01')
# Senso Target:  Lemma('people.n.01.people')
# ------------------------------
# Parola da disambiguare:  management
# Frase in cui compare la parola:  Regarding Atlanta 's new million dollar airport , the jury recommended `` that when the new management takes charge Jan. 1 the airport be operated in a manner that will eliminate political influences '' .
# Contesto della frase:  {'jury', 'atlanta', 'eliminate', 'political', 'dollar', 'recommend', 'jan', 'airport', 'management', 'operate', 'charge', 'manner', 'influence'}
# Max Signature:  {'function', 'direction', 'manage', 'economy', 'government', 'management', 'program'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('management.n.01')
# Senso Target:  Lemma('management.n.02.management')
# ------------------------------
# Parola da disambiguare:  speeches
# Frase in cui compare la parola:  Thanks to Spoken Arts Records , history buffs may hear Lincoln 's `` most memorable speeches and letters '' in a two disc set , interpreted by Lincoln authority and lecturer Roy P. Basler .
# Contesto della frase:  {'speech', 'roy', 'records', 'lecturer', 'buff', 'letter', 'set', 'spoken', 'history', 'authority', 'interpret', 'memorable', 'arts', 'disc', 'hear', 'basler', 'lincoln'}
# Max Signature:  {'speech', 'utter', 'spoken', 'merry', 'hear'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('speech.n.03')
# Senso Target:  Lemma('address.n.03.speech')
# ------------------------------
# Parola da disambiguare:  series
# Frase in cui compare la parola:  With Mickey Mantle and Yogi Berra both out of action due to injuries , the American League champs still mounted a 15 - hit attack against a parade of eight Cincinnati pitchers , the most ever used by one team in a series game .
# Contesto della frase:  {'game', 'series', 'injuries', 'mickey', 'pitchers', 'parade', 'berra', 'yogi', 'league', 'mantle', 'cincinnati', 'action', 'hit', 'champ', 'attack', 'team', 'american', 'mount'}
# Max Signature:  {'play', 'series', 'team', 'sweep', 'sport', 'visiting', 'contest', 'successively'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('series.n.04')
# Senso Target:  Lemma('series.n.04.series')
# ------------------------------
# Parola da disambiguare:  enamel
# Frase in cui compare la parola:  The bristles are soft enough to massage the gums and not scratch the enamel .
# Contesto della frase:  {'scratch', 'bristle', 'enamel', 'gum', 'soft', 'massage'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('enamel.n.01')
# Senso Target:  Lemma('enamel.n.01.enamel')
# ------------------------------
# Parola da disambiguare:  temptations
# Frase in cui compare la parola:  Remove temptations .
# Contesto della frase:  {'temptation', 'remove'}
# Max Signature:  {'temptation', 'desire', 'avoid', 'felt', 'weaken', 'power'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('temptation.n.02')
# Senso Target:  Lemma('temptation.n.01.temptation')
# ------------------------------
# Parola da disambiguare:  irregularities
# Frase in cui compare la parola:  Many local citizens feared that there would be irregularities at the polls , and Williams got himself a permit to carry a gun and promised an orderly election .
# Contesto della frase:  {'fear', 'poll', 'carry', 'williams', 'election', 'orderly', 'gun', 'local', 'irregularity', 'citizen', 'promise', 'permit'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('abnormality.n.04')
# Senso Target:  Lemma('abnormality.n.04.irregularity')
# ------------------------------
# Parola da disambiguare:  runners
# Frase in cui compare la parola:  Then Robinson slammed a long double to left center to score both runners .
# Contesto della frase:  {'slam', 'double', 'runner', 'leave', 'center', 'score', 'long', 'robinson'}
# Max Signature:  {'runner', 'message', 'send', 'person', 'document', 'employ', 'contract', 'deliver'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('runner.n.03')
# Senso Target:  Lemma('base_runner.n.01.runner')
# ------------------------------
# Parola da disambiguare:  mother
# Frase in cui compare la parola:  What can a mother do then to prevent misbehavior ?
# Contesto della frase:  {'misbehavior', 'prevent', 'mother'}
# Max Signature:  {'child', 'birth', 'woman', 'mother', 'term', 'address'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('mother.n.01')
# Senso Target:  Lemma('mother.n.01.mother')
# ------------------------------
# Parola da disambiguare:  management
# Frase in cui compare la parola:  The last couple of years the Bears management got the business from the `` Living Room Athletic Club '' when games were cut off .
# Contesto della frase:  {'game', 'club', 'bears', 'business', 'cut', 'athletic', 'management', 'year', 'living', 'couple', 'room'}
# Max Signature:  {'function', 'direction', 'manage', 'economy', 'government', 'management', 'program'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('management.n.01')
# Senso Target:  Lemma('management.n.02.management')
# ------------------------------
# Termini valutati:  51
# Termini valutati correttamente:  35
# Accuratezza:  0.7

# %% [markdown]
# CONSEGNA 2.2:
#
# Randomizzare la selezione delle 50 frasi e la selezione del termine da
# disambiguare, e restituire l’accuratezza media su (per esempio) 10
# esecuzioni del programma.

# %%
tokenizer = RegexpTokenizer(r'\w+')

EXECUTIONS = 10 #numero massimo di esecuzioni
INDEXES_NUM = 7000 #è il limite, partendo da 0, di sentence che possono essere testate relative al database SemCor
RANGE = 50 #è il numero di sentence che effettivamente verranno testate in ogni esecuzione        

sentences_tag = semcor.tagged_sents()
sentences = semcor.sents()
sentences_sem = semcor.tagged_sents(tag = "sem")

def main():
    accuracy_list = []
    for execution in range(1,EXECUTIONS + 1):
        evaluated = 0 #termini valutati
        checked = 0 #termini valutati correttamente
        index_evaluated = set() #insieme degli indici già valutati
        while(evaluated <= RANGE):
            while True: #fino a quando non trova una word che può essere presa in considerazione  
                index = get_random_index(index_evaluated, INDEXES_NUM)
                word = get_random_word(get_dictionary_tag(sentences_tag[index],sentences_sem[index]))
                if word:
                    break
            sentence = sentences[index]
            print("Parola da disambiguare: ",word)
            #all'algoritmo di lesk viene dato in input la word e l'insieme dei termini che formano la frase, uniti sottoforma di stringa
            best_sense = str(lesk_algorithm(word, ' '.join(word for word in sentence), word_type='ALL'))
            print("Senso attribuito dall'algoritmo di Lesk: ",best_sense)
            target_lemma = get_synset_target_for_word_in_sentence(word,sentences_sem[index])
            print("Senso Target: ",target_lemma)
            best_sense_lemma = best_sense[8:len(best_sense)-2]
            if target_lemma:
                if best_sense_lemma in target_lemma:
                 checked= checked + 1
            evaluated += 1
            print("------------------------------")
        
        print("Termini valutati: ", evaluated)
        print("Termini valutati correttamente: ", checked)
        accuracy = checked/RANGE
        print("Accuratezza: ", accuracy)
        accuracy_list.append(accuracy)
        
    print()
    print("Esecuzioni: ",EXECUTIONS)
    print("Lista delle accuratezze: ", accuracy_list)
    print("Accuratezza media: ",mean(accuracy_list))
    
main()
# Out:
# Parola da disambiguare:  occurs
# Frase in cui compare la parola:  And this occurs now , at the refrain of Jacoby 's song - at the point , in fact , of the name `` Lizzy '' - ; a modulation described as `` almost a stroke of genius '' .
# Contesto della frase:  {'point', 'describe', 'occur', 'fact', 'stroke', 'genius', 'jacoby', 'lizzy', 'modulation', 'refrain', 'song'}
# Max Signature:  {'pass', 'occur', 'incidence', 'happen', 'place', 'meeting'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('happen.v.01')
# Senso Target:  occur.v.00
# ------------------------------
# Parola da disambiguare:  good
# Frase in cui compare la parola:  Working in a vacuum of minimal information can result only in show pieces that look good in exhibitions and catalogs and may please the public relations department but have little to do with the essence of interior design .
# Contesto della frase:  {'essence', 'piece', 'working', 'minimal', 'result', 'good', 'relation', 'department', 'interior', 'design', 'exhibition', 'vacuum', 'catalog', 'public'}
# Max Signature:  {'thing', 'result', 'favorably', 'good', 'wasnt', 'stay', 'well', 'alls'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('good.s.13')
# Senso Target:  Lemma('good.a.01.good')
# ------------------------------
# Parola da disambiguare:  weak
# Frase in cui compare la parola:  Those who are too weak , should climb on the chair and , starting at the top of the chin , let themselves slowly down .
# Contesto della frase:  {'climb', 'chin', 'chair', 'start', 'top', 'weak', 'slowly'}
# Max Signature:  {'physical', 'weak', 'pillar', 'strength'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('weak.a.01')
# Senso Target:  Lemma('weak.a.01.weak')
# ------------------------------
# Parola da disambiguare:  physiological
# Frase in cui compare la parola:  An important observation of Pavlov served as a guide post to achieve such a reversibility by physiological means .
# Contesto della frase:  {'observation', 'guide', 'physiological', 'reversibility', 'post', 'serve', 'achieve', 'pavlov'}
# Max Signature:  {'pavlovs', 'physiological', 'study', 'biological', 'physiology', 'relate', 'theory', 'psychology'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('physiological.a.01')
# Senso Target:  Lemma('physiological.a.01.physiological')
# ------------------------------
# Parola da disambiguare:  symptomatic
# Frase in cui compare la parola:  The flood is not as great - only 700 a week according to one apparently conservative account - but it is symptomatic .
# Contesto della frase:  {'conservative', 'symptomatic', 'accord', 'week', 'account', 'great', 'flood'}
# Max Signature:  {'treatment', 'symptomatic', 'accord', 'disease', 'relate', 'relief', 'classification', 'symptom', 'affect'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('symptomatic.a.02')
# Senso Target:  Lemma('diagnostic.s.02.symptomatic')
# ------------------------------
# Parola da disambiguare:  induced
# Frase in cui compare la parola:  Similar effects can be induced reflexly via the baroreceptor reflexes in man and animals .
# Contesto della frase:  {'man', 'reflex', 'animal', 'reflexly', 'baroreceptor', 'induce'}
# Max Signature:  {'crisis', 'induce'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('induce.v.01')
# Senso Target:  Lemma('induce.v.03.induce')
# ------------------------------
# Parola da disambiguare:  pores
# Frase in cui compare la parola:  No , other than cleaning out the pores and making the sweat glands work harder .
# Contesto della frase:  {'sweat', 'work', 'clean', 'pore', 'glands', 'harder'}
# Max Signature:  {'leaf', 'epidermal', 'stem', 'pass', 'vapor', 'water', 'minute', 'pore', 'gas'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('stoma.n.01')
# Senso Target:  Lemma('pore.n.02.pore')
# ------------------------------
# Parola da disambiguare:  horse
# Frase in cui compare la parola:  One might also wonder if monkeys are capable of developing bronchiolitis as we know it in man or the horse .
# Contesto della frase:  {'man', 'develop', 'bronchiolitis', 'capable', 'monkey', 'wonder', 'horse'}
# Max Signature:  {'horseback', 'fight', 'lead', 'train', 'attack', 'horse', 'troop'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('cavalry.n.01')
# Senso Target:  Lemma('horse.n.01.horse')
# ------------------------------
# Parola da disambiguare:  features
# Frase in cui compare la parola:  The same is true of areas which at first look good because of a few existing recreation features but may actually be poor areas to develop for general public use .
# Contesto della frase:  {'develop', 'area', 'poor', 'recreation', 'true', 'good', 'exist', 'general', 'public', 'feature'}
# Max Signature:  {'road', 'generosity', 'attribute', 'best', 'characteristic', 'aspect', 'map', 'prominent', 'feature'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('feature.n.01')
# Senso Target:  Lemma('feature.n.01.feature')
# ------------------------------
# Parola da disambiguare:  lower-class
# Frase in cui compare la parola:  Until internal combustion became cheap , he had to be near a railroad siding and a trolley line or an existing large community of lower-class homes .
# Contesto della frase:  {'internal', 'lowerclass', 'large', 'siding', 'trolley', 'railroad', 'community', 'cheap', 'exist', 'combustion'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('lower-class.a.01')
# Senso Target:  Lemma('lower-class.a.01.lower-class')
# ------------------------------
# Parola da disambiguare:  liveliness
# Frase in cui compare la parola:  Not satisfied with various unofficial checks on the liveliness of baseballs currently in use , the major leagues have ordered their own tests , which are in progress at Massachusetts Institute of Technology .
# Contesto della frase:  {'massachusetts', 'major', 'liveliness', 'unofficial', 'test', 'institute', 'satisfy', 'league', 'currently', 'order', 'progress', 'technology', 'baseball', 'check'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('liveliness.n.01')
# Senso Target:  Lemma('liveliness.n.01.liveliness')
# ------------------------------
# Parola da disambiguare:  indicated
# Frase in cui compare la parola:  This is , of course , a similar type of behavior to that indicated by birefringence studies .
# Contesto della frase:  {'course', 'study', 'type', 'birefringence', 'indicate', 'behavior'}
# Max Signature:  {'undervalue', 'point', 'signal', 'severe', 'economic', 'serious', 'illness', 'neurosis', 'indicator', 'euro', 'indicate', 'behavior', 'symptom'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('bespeak.v.01')
# Senso Target:  Lemma('indicate.v.02.indicate')
# ------------------------------
# Parola da disambiguare:  decrease
# Frase in cui compare la parola:  She can decrease the number of temptations .
# Contesto della frase:  {'number', 'decrease', 'temptation'}
# Max Signature:  {'temperature', 'downward', 'fever', 'dropoff', 'sale', 'decrease', 'change', 'subside', 'sharp'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('decrease.n.01')
# Senso Target:  Lemma('decrease.v.01.decrease')
# ------------------------------
# Parola da disambiguare:  acquire
# Frase in cui compare la parola:  He had to acquire everything he was going to get in four years .
# Contesto della frase:  {'acquire', 'year'}
# Max Signature:  {'painting', 'acquire', 'uncle', 'abstract', 'permission', 'work', 'lot', 'result', 'possession', 'concrete', 'pet', 'day'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('get.v.01')
# Senso Target:  Lemma('get.v.01.acquire')
# ------------------------------
# Parola da disambiguare:  aerobic
# Frase in cui compare la parola:  It was possible to maintain aerobic conditions in the pond by regular additions of sodium nitrate until the temperature decreased and the algae population changed from blue-green to green algae .
# Contesto della frase:  {'maintain', 'condition', 'regular', 'addition', 'sodium', 'aerobic', 'temperature', 'green', 'pond', 'population', 'nitrate', 'change', 'decrease', 'algae', 'bluegreen'}
# Max Signature:  {'aerobic', 'fermentation', 'oxygen', 'air', 'free', 'depend'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('aerobic.a.01')
# Senso Target:  Lemma('aerobic.a.01.aerobic')
# ------------------------------
# Parola da disambiguare:  returning
# Frase in cui compare la parola:  He saw no life , but still stood there for a time peering at the unlovely hills , his gaze continually returning to Papa-san .
# Contesto della frase:  {'return', 'papasan', 'time', 'life', 'stand', 'unlovely', 'hill', 'peer', 'gaze', 'continually'}
# Max Signature:  {'return', 'condition', 'land', 'professor', 'dean', 'serve', 'activity', 'place', 'native', 'position', 'teach'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('return.v.01')
# Senso Target:  Lemma('return.v.01.return')
# ------------------------------
# Parola da disambiguare:  gristmill
# Frase in cui compare la parola:  The first mention of an electric plant in Manchester seems to be one installed in Reuben Colvin 's and Houghton 's gristmill on the West Branch in Factory Point .
# Contesto della frase:  {'branch', 'point', 'mention', 'plant', 'manchester', 'houghton', 'reuben', 'electric', 'colvin', 'factory', 'gristmill', 'west', 'instal'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('gristmill.n.01')
# Senso Target:  Lemma('gristmill.n.01.gristmill')
# ------------------------------
# Parola da disambiguare:  garter
# Frase in cui compare la parola:  Laurence M . Klauber put length at maturity at two thirds the ultimate length for some rattlesnakes , and Charles C . Carpenter 's data on Michigan garter and ribbon snakes ( Thamnophis ) show that the smallest gravid females are more than half as long as the biggest adults .
# Contesto della frase:  {'klauber', 'female', 'third', 'maturity', 'length', 'small', 'ultimate', 'thamnophis', 'snake', 'charles', 'half', 'gravid', 'laurence', 'garter', 'ribbon', 'rattlesnake', 'big', 'michigan', 'data', 'adult', 'long', 'carpenter'}
# Max Signature:  {'fasten', 'garter'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('garter.v.01')
# Senso Target:  Lemma('garter_snake.n.01.garter_snake')
# ------------------------------
# Parola da disambiguare:  destruction
# Frase in cui compare la parola:  In this connection it should be capable of being disseminated without excessive destruction .
# Contesto della frase:  {'capable', 'excessive', 'disseminate', 'destruction', 'connection'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('destruction.n.01')
# Senso Target:  Lemma('destruction.n.01.destruction')
# ------------------------------
# Parola da disambiguare:  largest
# Frase in cui compare la parola:  The Catholics had the largest cemetery , near the Neversink River where Main Street ran south ; Stevie whistled when he passed these alien grounds .
# Contesto della frase:  {'pass', 'large', 'ground', 'river', 'neversink', 'south', 'whistle', 'stevie', 'alien', 'main', 'street', 'catholics', 'cemetery'}
# Max Signature:  {'expenditure', 'area', 'city', 'size', 'barn', 'set', 'quantity', 'business', 'big', 'newspaper', 'extent', 'number', 'average', 'magnitude', 'large', 'group', 'family', 'sum', 'scientist'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('large.a.01')
# Senso Target:  largest.s.00
# ------------------------------
# Parola da disambiguare:  sounds
# Frase in cui compare la parola:  The penalty for this is noticeable in the big , bold , brilliant , but brassy piano sounds in Melody and Percussion for Two Pianos ( SP 44007 ) .
# Contesto della frase:  {'sound', 'noticeable', 'percussion', 'big', 'sp', 'melody', 'piano', 'brilliant', 'pianos', 'penalty', 'bold', 'brassy'}
# Max Signature:  {'sound', 'roof', 'produce', 'beautiful', 'auditory', 'rain', 'music'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('sound.n.01')
# Senso Target:  Lemma('sound.n.03.sound')
# ------------------------------
# Parola da disambiguare:  3
# Frase in cui compare la parola:  The proteins were extracted with 3 volumes of * * f in * * f to give a nearly neutral extract and precipitated by 80 % saturation with * * f .
# Contesto della frase:  {'precipitate', 'neutral', 'extract', 'volume', 'saturation', 'protein'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('three.n.01')
# Senso Target:  Lemma('three.s.01.3')
# ------------------------------
# Parola da disambiguare:  material
# Frase in cui compare la parola:  Dirt , which is here defined as particulate material which is usually inorganic and is very often extremely finely divided so as to exhibit colloidal properties .
# Contesto della frase:  {'divide', 'particulate', 'define', 'finely', 'colloidal', 'exhibit', 'dirt', 'material', 'inorganic', 'property', 'extremely'}
# Max Signature:  {'physical', 'coal', 'wheat', 'makeup', 'hard', 'black', 'material', 'bread', 'tangible', 'stuff', 'object', 'substance'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('material.n.01')
# Senso Target:  Lemma('material.n.01.material')
# ------------------------------
# Parola da disambiguare:  binomial
# Frase in cui compare la parola:  On the other hand , even when the binomial model does not describe well the physical phenomenon being studied , the binomial model may still be used as a baseline for comparative purposes ; that is , we may discuss the phenomenon in terms of its departures from the binomial model .
# Contesto della frase:  {'physical', 'baseline', 'describe', 'purpose', 'study', 'discuss', 'binomial', 'well', 'comparative', 'term', 'phenomenon', 'departure', 'hand', 'model'}
# Max Signature:  {'expression', 'consist', 'relate', 'binomial', 'term'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('binomial.a.01')
# Senso Target:  Lemma('binomial.a.01.binomial')
# ------------------------------
# Parola da disambiguare:  holder
# Frase in cui compare la parola:  Another anode holder used in the experiments is shown in figure 3 .
# Contesto della frase:  {'anode', 'holder', 'figure', 'experiment'}
# Max Signature:  {'hold', 'device', 'holder', 'cigarette', 'towel', 'umbrella'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('holder.n.01')
# Senso Target:  Lemma('holder.n.01.holder')
# ------------------------------
# Parola da disambiguare:  high
# Frase in cui compare la parola:  Similarly , the American Cancer Society ( ACS ) , the Arthritis and Rheumatism Foundation , and the BBB have each stated lately that medical quackery is at a new high .
# Contesto della frase:  {'high', 'cancer', 'bbb', 'foundation', 'arthritis', 'rheumatism', 'medical', 'society', 'acs', 'quackery', 'american'}
# Max Signature:  {'high', 'temperature', 'lofty', 'alltime', 'reach', 'degree', 'position', 'summer', 'level'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('high.n.01')
# Senso Target:  Lemma('high.n.01.high')
# ------------------------------
# Parola da disambiguare:  appear
# Frase in cui compare la parola:  The gross details of the structure appear reasonable .
# Contesto della frase:  {'appear', 'detail', 'structure', 'reasonable', 'gross'}
# Max Signature:  {'sleep', 'appear', 'project', 'fishy', 'time', 'eat', 'impression', 'difficult', 'outward', 'people', 'long', 'aspect', 'problem'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('look.v.02')
# Senso Target:  Lemma('look.v.02.appear')
# ------------------------------
# Parola da disambiguare:  peripheral
# Frase in cui compare la parola:  And in the economy of the book it is not peripheral but central .
# Contesto della frase:  {'book', 'peripheral', 'economy', 'central'}
# Max Signature:  {'peripheral', 'key', 'energy', 'relate', 'economy', 'issue', 'interest', 'central'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('peripheral.s.02')
# Senso Target:  Lemma('peripheral.a.01.peripheral')
# ------------------------------
# Parola da disambiguare:  good
# Frase in cui compare la parola:  For my seedbed I use good garden soil with a little sand added to encourage rooting .
# Contesto della frase:  {'garden', 'sand', 'seedbed', 'good', 'root', 'add', 'soil', 'encourage'}
# Max Signature:  {'good', 'worry', 'benefit'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('good.n.01')
# Senso Target:  Lemma('good.a.01.good')
# ------------------------------
# Parola da disambiguare:  torso
# Frase in cui compare la parola:  So with four complete Push-Pull Super-Sets No. 1 , four of No. 2 , four of No. 3 and four to six sets of the Incline Bench Press , you can see that Henri de Courcy has had a terrific mass building , muscle shaping , torso defining workout that cannot be improved upon .
# Contesto della frase:  {'muscle', 'complete', 'mass', 'define', 'supersets', 'set', 'terrific', 'torso', 'pushpull', 'henri', 'building', 'improve', 'courcy', 'incline', 'bench', 'press', 'shape'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('torso.n.01')
# Senso Target:  Lemma('torso.n.01.torso')
# ------------------------------
# Parola da disambiguare:  money
# Frase in cui compare la parola:  But it is our health - more precious than all the money in the world - that these modern witch doctors with their fake therapeutic gadgets are gambling away .
# Contesto della frase:  {'gadget', 'money', 'health', 'modern', 'doctor', 'precious', 'gamble', 'witch', 'therapeutic', 'fake'}
# Max Signature:  {'tender', 'owe', 'function', 'money', 'medium', 'collect', 'common', 'legal', 'exchange'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('money.n.01')
# Senso Target:  Lemma('money.n.01.money')
# ------------------------------
# Parola da disambiguare:  comprise
# Frase in cui compare la parola:  True terminal bronchioles comprise the most frequent form taken by the distal airways in types 1 , and 3 , , although small numbers of poorly developed respiratory bronchioles are present .
# Contesto della frase:  {'develop', 'bronchiole', 'distal', 'comprise', 'respiratory', 'true', 'frequent', 'type', 'form', 'terminal', 'small', 'airway', 'number'}
# Max Signature:  {'backdrop', 'comprise', 'money', 'income', 'year', 'army', 'performance', 'child', 'stone', 'chorus', 'wall', 'form', 'constitute', 'compose', 'entire', 'belonging', 'men', 'represent', 'sum'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('constitute.v.01')
# Senso Target:  Lemma('consist.v.04.comprise')
# ------------------------------
# Parola da disambiguare:  positivist
# Frase in cui compare la parola:  Consider what follows from the positivist view .
# Contesto della frase:  {'positivist', 'follow', 'view', 'consider'}
# Max Signature:  {'philosophy', 'thinker', 'positive', 'positivism', 'relate', 'positivist', 'doctrine'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('positivist.a.01')
# Senso Target:  Lemma('positivist.n.01.positivist')
# ------------------------------
# Parola da disambiguare:  provide
# Frase in cui compare la parola:  He told the committee the measure would merely provide means of enforcing the escheat law which has been on the books `` since Texas was a republic '' .
# Contesto della frase:  {'enforce', 'measure', 'escheat', 'book', 'law', 'provide', 'texas', 'committee', 'republic'}
# Max Signature:  {'measure', 'preparation', 'provide', 'passenger', 'ship', 'proper', 'cruise', 'care'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('provide.v.07')
# Senso Target:  Lemma('supply.v.01.provide')
# ------------------------------
# Parola da disambiguare:  committed
# Frase in cui compare la parola:  Why had not this success come to him before he had plunged into his Discourse , and before he had committed himself to a life of austerity and denial ?
# Contesto della frase:  {'life', 'denial', 'commit', 'plunge', 'discourse', 'austerity', 'success'}
# Max Signature:  {'god', 'life', 'specific', 'work', 'entirely', 'activity', 'talent', 'good', 'commit', 'person', 'church', 'consecrate'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('give.v.18')
# Senso Target:  Lemma('give.v.18.commit')
# ------------------------------
# Parola da disambiguare:  propagandists
# Frase in cui compare la parola:  But there are also the commercial propagandists and the analysts - one dominated by money , the other by nineteenth century German scholarship .
# Contesto della frase:  {'money', 'german', 'propagandist', 'commercial', 'dominate', 'scholarship', 'analyst', 'nineteenth', 'century'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('propagandist.n.01')
# Senso Target:  Lemma('propagandist.n.01.propagandist')
# ------------------------------
# Parola da disambiguare:  variables
# Frase in cui compare la parola:  No correlation between these variables and the irreproducibility of the results was found .
# Contesto della frase:  {'irreproducibility', 'variable', 'result', 'correlation', 'find'}
# Max Signature:  {'vary', 'subject', 'consider', 'weather', 'variation', 'variable'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('variable.n.01')
# Senso Target:  Lemma('variable.n.02.variable')
# ------------------------------
# Parola da disambiguare:  unhappy
# Frase in cui compare la parola:  The only one who would have him was his cripple , the strange unhappy woman who became his wife .
# Contesto della frase:  {'unhappy', 'wife', 'cripple', 'woman', 'strange'}
# Max Signature:  {'unhappy', 'experience', 'sad', 'discontent', 'time', 'mark', 'sorrow', 'raise', 'news', 'lapse', 'argument', 'school', 'sadness', 'silence', 'departure'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('unhappy.a.01')
# Senso Target:  Lemma('unhappy.a.01.unhappy')
# ------------------------------
# Parola da disambiguare:  interesting
# Frase in cui compare la parola:  But he is more interesting than the others , the ones who come from the highroad to watch him , more interesting than Life considered as a cyclist .
# Contesto della frase:  {'life', 'interesting', 'highroad', 'watch', 'consider', 'cyclist'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('interest.v.01')
# Senso Target:  Lemma('interesting.a.01.interesting')
# ------------------------------
# Parola da disambiguare:  function
# Frase in cui compare la parola:  Heat of condensation ( work function ) plus kinetic energy of the electrons impinging on the anode .
# Contesto della frase:  {'function', 'condensation', 'energy', 'work', 'electron', 'impinge', 'heat', 'anode', 'kinetic'}
# Max Signature:  {'element', 'range', 'function', 'mathematical', 'set', 'associate', 'relation', 'mathematics', 'domain'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('function.n.01')
# Senso Target:  Lemma('function.n.01.function')
# ------------------------------
# Parola da disambiguare:  London
# Frase in cui compare la parola:  There is Karl Marx , of course , buried in London .
# Contesto della frase:  {'course', 'marx', 'london', 'karl', 'bury'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('london.n.01')
# Senso Target:  Lemma('london.n.01.London')
# ------------------------------
# Parola da disambiguare:  fired
# Frase in cui compare la parola:  We knew the enemy was subdued , because a flare was fired as the signal .
# Contesto della frase:  {'signal', 'fire', 'subdue', 'flare', 'enemy'}
# Max Signature:  {'weapon', 'start', 'fire'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('open_fire.v.01')
# Senso Target:  Lemma('fire.v.02.fire')
# ------------------------------
# Parola da disambiguare:  special
# Frase in cui compare la parola:  His bel canto style gave the performance a special distinction .
# Contesto della frase:  {'distinction', 'bel', 'performance', 'style', 'special', 'canto'}
# Max Signature:  {'reduced', 'price', 'chop', 'offering', 'pork', 'temporary', 'advertising', 'special', 'feature'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('special.n.01')
# Senso Target:  Lemma('particular.s.01.special')
# ------------------------------
# Parola da disambiguare:  Tanks
# Frase in cui compare la parola:  Tanks lined up at the border will be no more helpful .
# Contesto della frase:  {'border', 'helpful', 'tanks'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('tank.n.01')
# Senso Target:  Lemma('tank.n.01.tank')
# ------------------------------
# Parola da disambiguare:  hands
# Frase in cui compare la parola:  Start on hands and feet .
# Contesto della frase:  {'foot', 'start', 'hand'}
# Max Signature:  {'discipline', 'child', 'fate', 'president', 'power', 'divorce', 'case', 'guardianship', 'custody', 'mother', 'award', 'house', 'guest', 'care', 'hand'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('hands.n.01')
# Senso Target:  Lemma('hand.n.01.hand')
# ------------------------------
# Parola da disambiguare:  unresponsive
# Frase in cui compare la parola:  Most attempts to develop any sympathy for Brown and his actions found an unresponsive audience in Rhode Island .
# Contesto della frase:  {'attempt', 'develop', 'brown', 'audience', 'unresponsive', 'rhode', 'action', 'island', 'sympathy', 'find'}
# Max Signature:  {'indifferent', 'aloof', 'unresponsive', 'advance', 'passionate'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('unresponsive.s.02')
# Senso Target:  Lemma('unresponsive.a.01.unresponsive')
# ------------------------------
# Parola da disambiguare:  dot
# Frase in cui compare la parola:  The `` dot '' on his arrow indicates early Onset and the `` tip '' indicates relatively later Completion .
# Contesto della frase:  {'onset', 'dot', 'late', 'early', 'indicate', 'completion', 'arrow'}
# Max Signature:  {'point', 'circular', 'dot', 'draw', 'small', 'row', 'shape'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('point.n.09')
# Senso Target:  Lemma('point.n.09.dot')
# ------------------------------
# Parola da disambiguare:  American
# Frase in cui compare la parola:  An electric toothbrush ( Broxodent ) may soon take its place next to the electric razor in the American bathroom .
# Contesto della frase:  {'razor', 'bathroom', 'toothbrush', 'electric', 'place', 'broxodent', 'american'}
# Max Signature:  {'country', 'central', 'inhabitant', 'native', 'north', 'american', 'south'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('american.n.03')
# Senso Target:  Lemma('american.a.01.American')
# ------------------------------
# Parola da disambiguare:  provide
# Frase in cui compare la parola:  Its folklore and legend , usually disguised as history , are allowed to account for group actions , to provide a focal point for group loyalty , and to become a cohesive force for national identification .
# Contesto della frase:  {'force', 'cohesive', 'folklore', 'point', 'group', 'history', 'legend', 'loyalty', 'provide', 'account', 'action', 'national', 'allow', 'identification', 'focal', 'disguise'}
# Max Signature:  {'remain', 'attainable', 'time', 'conclusion', 'possibility', 'leave', 'trip', 'lot', 'allow', 'leeway', 'procedure', 'evidence', 'opportunity', 'provide', 'mistake', 'room', 'permit', 'improvement'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('leave.v.06')
# Senso Target:  Lemma('supply.v.01.provide')
# ------------------------------
# Parola da disambiguare:  turned
# Frase in cui compare la parola:  Thus , stealthily they advanced upstream ; then they turned to the right , climbed the embankment , and walked into the valley again .
# Contesto della frase:  {'climb', 'walk', 'upstream', 'advance', 'embankment', 'stealthily', 'valley', 'turn'}
# Max Signature:  {'fell', 'walk', 'shoulder', 'wrestler', 'twist', 'sprain', 'wrench', 'hiker', 'ankle', 'suddenly', 'day', 'turn'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('twist.v.10')
# Senso Target:  Lemma('turn.v.01.turn')
# ------------------------------
# Parola da disambiguare:  correspondingly
# Frase in cui compare la parola:  In the presence of a low iodine intake , thyroglobulin labelled in vivo with * * f is found to contain more mono-iodotyrosine than normal , the amounts of di-iodotyrosine and iodothyronines being correspondingly reduced .
# Contesto della frase:  {'presence', 'normal', 'iodothyronine', 'reduce', 'monoiodotyrosine', 'amount', 'low', 'diiodotyrosine', 'label', 'thyroglobulin', 'correspondingly', 'iodine', 'intake', 'vivo', 'find'}
# Max Signature:  {'corresponding', 'temperature', 'correspondingly', 'decrease', 'manner'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('correspondingly.r.01')
# Senso Target:  Lemma('correspondingly.r.01.correspondingly')
# ------------------------------
# Termini valutati:  51
# Termini valutati correttamente:  25
# Accuratezza:  0.5
# Parola da disambiguare:  algae
# Frase in cui compare la parola:  Microscopic examination of the effluent showed that minimum BOD occurred when the algae began to decrease with cold weather .
# Contesto della frase:  {'minimum', 'occur', 'effluent', 'bod', 'microscopic', 'cold', 'algae', 'decrease', 'weather', 'examination'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('alga.n.01')
# Senso Target:  Lemma('alga.n.01.algae')
# ------------------------------
# Parola da disambiguare:  left
# Frase in cui compare la parola:  The house has been swept so clean that contemporary man has been left with no means , or at best with wholly inadequate means , for dealing with his experience of spirit .
# Contesto della frase:  {'man', 'experience', 'spirit', 'wholly', 'leave', 'sweep', 'clean', 'contemporary', 'best', 'deal', 'house', 'inadequate'}
# Max Signature:  {'piece', 'ground', 'leave', 'flied', 'outfield', 'catcher', 'batter'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('left_field.n.01')
# Senso Target:  Lemma('leave.v.03.leave')
# ------------------------------
# Parola da disambiguare:  titer
# Frase in cui compare la parola:  One contained complete antibody and had a titer of 1 : 512 in saline .
# Contesto della frase:  {'complete', 'titer', 'saline', 'antibody'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('titer.n.01')
# Senso Target:  Lemma('titer.n.01.titer')
# ------------------------------
# Parola da disambiguare:  erratically
# Frase in cui compare la parola:  The men in power are committed in principle to modernization , but economic and social changes are proceeding only erratically .
# Contesto della frase:  {'social', 'erratically', 'economic', 'men', 'commit', 'modernization', 'change', 'proceed', 'principle', 'power'}
# Max Signature:  {'erratically', 'erratic', 'economic', 'unpredictable', 'change', 'proceed', 'manner'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('erratically.r.01')
# Senso Target:  Lemma('erratically.r.01.erratically')
# ------------------------------
# Parola da disambiguare:  pulled
# Frase in cui compare la parola:  A tape of cellulose acetate is pulled between the blocks and the tape pulls the fluid or paste with it between the parallel faces of the blocks .
# Contesto della frase:  {'pull', 'acetate', 'block', 'parallel', 'face', 'paste', 'fluid', 'tape', 'cellulose'}
# Max Signature:  {'pull', 'swing', 'carry', 'face', 'direction', 'ball', 'player', 'hit'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('pull.v.13')
# Senso Target:  Lemma('pull.v.01.pull')
# ------------------------------
# Parola da disambiguare:  completely
# Frase in cui compare la parola:  His standards are , of course , completely foreign to those of the analyst .
# Contesto della frase:  {'course', 'completely', 'foreign', 'standard', 'analyst'}
# Max Signature:  {'expect', 'situation', 'wholly', 'convinced', 'full', 'complete', 'wrong', 'satisfy', 'direction', 'totally', 'meal', 'completely', 'extent', 'informally', 'altogether', 'approach', 'fault', 'entire', 'entirely', 'idea', 'degree'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('wholly.r.01')
# Senso Target:  Lemma('wholly.r.01.completely')
# ------------------------------
# Parola da disambiguare:  animal
# Frase in cui compare la parola:  The name thyroid-stimulating hormone ( TSH ) has been given to a substance found in the anterior pituitary gland of all species of animal so far tested for its presence .
# Contesto della frase:  {'presence', 'thyroidstimulating', 'tsh', 'test', 'animal', 'anterior', 'hormone', 'specie', 'gland', 'pituitary', 'substance', 'find'}
# Max Signature:  {'desire', 'delight', 'mark', 'knowledge', 'eat', 'pleasure', 'animal', 'sensual', 'appetite', 'instinct', 'passion', 'body', 'fleshly', 'vice', 'carnal', 'music'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('animal.s.01')
# Senso Target:  Lemma('animal.n.01.animal')
# ------------------------------
# Parola da disambiguare:  duller
# Frase in cui compare la parola:  The males are much duller .
# Contesto della frase:  {'duller', 'male'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('dull.a.01')
# Senso Target:  Lemma('dull.s.05.dull')
# ------------------------------
# Parola da disambiguare:  tingling
# Frase in cui compare la parola:  He was tingling within .
# Contesto della frase:  {'tingle'}
# Max Signature:  {'tingle', 'stinging', 'sensation'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('tingle.v.01')
# Senso Target:  Lemma('tingle.v.01.tingle')
# ------------------------------
# Parola da disambiguare:  data
# Frase in cui compare la parola:  Its value was * * f from the above data .
# Contesto della frase:  {'data'}
# Max Signature:  {'data', 'fact', 'conclusion', 'draw', 'statistical', 'collection'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('data.n.01')
# Senso Target:  Lemma('data.n.01.data')
# ------------------------------
# Parola da disambiguare:  conducts
# Frase in cui compare la parola:  Rudolf Kempe conducts .
# Contesto della frase:  {'conduct', 'rudolf', 'kempe'}
# Max Signature:  {'conduct', 'course', 'direct', 'manage', 'control', 'business'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('conduct.v.01')
# Senso Target:  Lemma('conduct.v.02.conduct')
# ------------------------------
# Parola da disambiguare:  presented
# Frase in cui compare la parola:  Yet even here many a problem is presented ; as in a recent design competition with a floor plan and the simple command - `` design a luxury apartment '' ; no description of the client or his cultural level , no assertion of geographical area or local social necessities - simply `` a luxury apartment '' .
# Contesto della frase:  {'area', 'simply', 'problem', 'level', 'competition', 'social', 'simple', 'necessity', 'geographical', 'description', 'cultural', 'plan', 'floor', 'command', 'luxury', 'design', 'client', 'local', 'assertion', 'apartment'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('show.v.01')
# Senso Target:  Lemma('show.v.01.present')
# ------------------------------
# Parola da disambiguare:  worry
# Frase in cui compare la parola:  But as long as you can have treatment from my machine you have nothing to worry about .
# Contesto della frase:  {'long', 'machine', 'treatment', 'worry'}
# Max Signature:  {'york', 'major', 'unhappiness', 'concern', 'source', 'constant', 'anxiety', 'traffic', 'worry'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('concern.n.04')
# Senso Target:  Lemma('worry.v.01.worry')
# ------------------------------
# Parola da disambiguare:  rehabilitations
# Frase in cui compare la parola:  Besides , he can hardly avoid musing on the instability of death which , what with exhumations and rehabilitations , seems to match that of life .
# Contesto della frase:  {'exhumation', 'life', 'match', 'muse', 'avoid', 'instability', 'death', 'rehabilitation'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('rehabilitation.n.01')
# Senso Target:  Lemma('reclamation.n.01.rehabilitation')
# ------------------------------
# Parola da disambiguare:  naturally
# Frase in cui compare la parola:  This follows naturally since frontage on an ocean , stream , or lake provides scenic values and opportunities for the very popular recreation activities of bathing , fishing , boating , and other water sports .
# Contesto della frase:  {'scenic', 'ocean', 'frontage', 'lake', 'boating', 'bath', 'popular', 'recreation', 'water', 'activity', 'naturally', 'follow', 'provide', 'opportunity', 'sport', 'fish', 'stream'}
# Max Signature:  {'expect', 'bill', 'lawyer', 'huge', 'naturally', 'send'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('naturally.r.01')
# Senso Target:  Lemma('naturally.r.01.naturally')
# ------------------------------
# Parola da disambiguare:  mistaking
# Frase in cui compare la parola:  There was no mistaking that scream .
# Contesto della frase:  {'scream', 'mistaking'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('misinterpretation.n.01')
# Senso Target:  Lemma('misinterpretation.n.01.mistaking')
# ------------------------------
# Parola da disambiguare:  parody
# Frase in cui compare la parola:  Piepsam is grotesque , a disturbing parody ; his end is ridiculous and trivial .
# Contesto della frase:  {'grotesque', 'parody', 'disturb', 'ridiculous', 'piepsam', 'trivial'}
# Max Signature:  {'student', 'spoof', 'parody', 'teacher'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('spoof.v.01')
# Senso Target:  Lemma('parody.n.01.parody')
# ------------------------------
# Parola da disambiguare:  essential
# Frase in cui compare la parola:  Consultation with architects , clients , real estate men , fabric houses and furniture companies is essential to the proper development of class problems just as in actual work .
# Contesto della frase:  {'class', 'furniture', 'real', 'development', 'work', 'house', 'problem', 'men', 'fabric', 'client', 'estate', 'company', 'actual', 'architect', 'essential', 'proper', 'consultation'}
# Max Signature:  {'shelter', 'buy', 'condition', 'fodder', 'life', 'fuel', 'favorable', 'requisite', 'water', 'allow', 'food', 'necessity', 'good', 'farmer', 'place', 'essential', 'indispensable', 'requirement'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('necessity.n.02')
# Senso Target:  Lemma('essential.s.01.essential')
# ------------------------------
# Parola da disambiguare:  operator
# Frase in cui compare la parola:  Now * * f is a diagonalizable operator which is also nilpotent .
# Contesto della frase:  {'diagonalizable', 'operator', 'nilpotent'}
# Max Signature:  {'operator', 'machine', 'apparatus', 'switchboard', 'operate', 'agent'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('operator.n.02')
# Senso Target:  Lemma('operator.n.01.operator')
# ------------------------------
# Parola da disambiguare:  alligatored
# Frase in cui compare la parola:  the wood was old , the paint alligatored .
# Contesto della frase:  {'wood', 'alligator', 'paint'}
# Max Signature:  {'acquire', 'alligator', 'varnish', 'application', 'paint', 'appearance', 'weather', 'hide', 'improper', 'crack'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('alligator.v.01')
# Senso Target:  Lemma('alligatored.s.01.alligatored')
# ------------------------------
# Parola da disambiguare:  reception
# Frase in cui compare la parola:  Even Joan Sutherland may not have anticipated the tremendous reception she received from the Metropolitan Opera audience attending her debut as Lucia in Donizetti 's `` Lucia di Lammermoor '' Sunday night .
# Contesto della frase:  {'opera', 'tremendous', 'donizetti', 'debut', 'sunday', 'audience', 'receive', 'joan', 'metropolitan', 'lucia', 'lammermoor', 'attend', 'night', 'anticipate', 'reception', 'sutherland'}
# Max Signature:  {'expect', 'cold', 'greet', 'receive', 'reception', 'manner', 'superior'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('reception.n.01')
# Senso Target:  Lemma('reception.n.01.reception')
# ------------------------------
# Parola da disambiguare:  column
# Frase in cui compare la parola:  Fractions from the column which were to be subjected to analytical ultracentrifugation were concentrated by negative pressure dialysis and dialyzed for 16 hr in the cold against at least 500 volumes of phosphate buffered saline , pH 7.2 , ionic strength 0.154 .
# Contesto della frase:  {'phosphate', 'dialysis', 'ph', 'volume', 'fractions', 'pressure', 'dialyze', 'concentrate', 'subject', 'ultracentrifugation', 'saline', 'ionic', 'column', 'analytical', 'negative', 'buffer', 'cold', 'strength', 'hr'}
# Max Signature:  {'divide', 'devote', 'newspaper', 'subject', 'column', 'text', 'vertically', 'bookkeeper'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('column.n.08')
# Senso Target:  Lemma('column.n.04.column')
# ------------------------------
# Parola da disambiguare:  physical
# Frase in cui compare la parola:  Ask any group of ballerinas to do ten push-ups or three chin-ups and the results , considering the amount of physical training they have had , will be very disappointing .
# Contesto della frase:  {'pushup', 'physical', 'ballerina', 'group', 'amount', 'ten', 'disappointing', 'result', 'training', 'consider', 'chinups'}
# Max Signature:  {'involve', 'physical', 'spirit', 'suffering', 'body', 'appearance', 'sloppy', 'exercise', 'mind', 'distinguish'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('physical.a.01')
# Senso Target:  Lemma('physical.a.01.physical')
# ------------------------------
# Parola da disambiguare:  charity
# Frase in cui compare la parola:  The writers ' Gold Tee Award will go to John McAuliffe of Plainfield , N. J. , and Palm Beach , Fla. , for his sponsorship of charity tournaments .
# Contesto della frase:  {'writer', 'tee', 'beach', 'mcauliffe', 'palm', 'fla', 'charity', 'award', 'john', 'plainfield', 'gold', 'tournament', 'sponsorship'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('charity.n.01')
# Senso Target:  Lemma('charity.n.01.charity')
# ------------------------------
# Parola da disambiguare:  basking
# Frase in cui compare la parola:  Port Jervis , basking in the foothills , was the city of God .
# Contesto della frase:  {'god', 'foothill', 'city', 'jervis', 'basking', 'port'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('enjoy.v.01')
# Senso Target:  Lemma('bask.v.02.bask')
# ------------------------------
# Parola da disambiguare:  number
# Frase in cui compare la parola:  Thus we do not score the number of bull's-eyes , and the random variable is not the number of successes .
# Contesto della frase:  {'random', 'bullseyes', 'score', 'success', 'number', 'variable'}
# Max Signature:  {'indefinite', 'chore', 'unit', 'parameter', 'figure', 'possess', 'property', 'small', 'quantity', 'number', 'sum', 'individual', 'total'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('number.n.01')
# Senso Target:  Lemma('number.n.01.number')
# ------------------------------
# Parola da disambiguare:  awarded
# Frase in cui compare la parola:  ( Small wonder a Spokane jury awarded the husband $ 35823 for his wife 's death . )
# Contesto della frase:  {'wife', 'jury', 'husband', 'wonder', 'small', 'award', 'spokane', 'death'}
# Max Signature:  {'merit', 'basis', 'jury', 'funds', 'plaintiff', 'grant', 'kick', 'free', 'dollar', 'researcher', 'award', 'qualified', 'team', 'referee', 'judged'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('award.v.02')
# Senso Target:  Lemma('award.v.02.award')
# ------------------------------
# Parola da disambiguare:  cast
# Frase in cui compare la parola:  Since the hero , a sterling and upright fellow , is a rich Brown senior , while two Yalies are cast as virtual rapists , I suppose I should disqualify myself from sitting in judgment on `` Where the Boys are '' , but I shall do nothing of the sort .
# Contesto della frase:  {'suppose', 'rapist', 'sort', 'virtual', 'brown', 'rich', 'sterling', 'hero', 'judgment', 'senior', 'upright', 'sit', 'disqualify', 'fellow', 'boys', 'yalies', 'cast'}
# Max Signature:  {'cast', 'distinctive', 'pottery', 'thing', 'region', 'form', 'find'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('cast.n.03')
# Senso Target:  Lemma('cast.v.03.cast')
# ------------------------------
# Parola da disambiguare:  upper
# Frase in cui compare la parola:  Accordingly , maturity level ratings by means of the upper portion and lower portion of the Chart , respectively , should be somewhat similar since Skeletal Age assessments are dependent upon Onsets during infancy and upon Completions during adolescence .
# Contesto della frase:  {'infancy', 'skeletal', 'assessment', 'rating', 'low', 'chart', 'dependent', 'maturity', 'completions', 'portion', 'upper', 'onsets', 'adolescence', 'level', 'age'}
# Max Signature:  {'story', 'picture', 'higher', 'bunk', 'center', 'place', 'upper', 'position'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('upper.s.02')
# Senso Target:  upper.s.01
# ------------------------------
# Parola da disambiguare:  suppose
# Frase in cui compare la parola:  But suppose that a week later we revert to the incident in thought and make our statement again .
# Contesto della frase:  {'suppose', 'incident', 'week', 'thought', 'revert', 'statement'}
# Max Signature:  {'suppose', 'imagine', 'expect', 'guess', 'money', 'kitchen', 'stand', 'angry', 'bad', 'lot', 'novel', 'didnt', 'find', 'earn'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('think.v.02')
# Senso Target:  Lemma('speculate.v.01.suppose')
# ------------------------------
# Parola da disambiguare:  periodic
# Frase in cui compare la parola:  The jury did not elaborate , but it added that `` there should be periodic surveillance of the pricing practices of the concessionaires for the purpose of keeping the prices reasonable '' .
# Contesto della frase:  {'elaborate', 'purpose', 'jury', 'price', 'periodic', 'pricing', 'concessionaire', 'surveillance', 'reasonable', 'practice', 'add'}
# Max Signature:  {'regular', 'interval', 'periodic', 'seventeenyear', 'happen', 'locust', 'appearance', 'recur'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('periodic.a.01')
# Senso Target:  Lemma('periodic.a.01.periodic')
# ------------------------------
# Parola da disambiguare:  change
# Frase in cui compare la parola:  This cooling does not change the avocado in any way , it just delays the natural softening of the fruit until a grove like temperature ( room temperature ) is restored .
# Contesto della frase:  {'grove', 'softening', 'temperature', 'natural', 'delay', 'cooling', 'restore', 'change', 'fruit', 'room', 'avocado'}
# Max Signature:  {'pass', 'visit', 'occur', 'storm', 'neighborhood', 'year', 'modification', 'sale', 'ago', 'change', 'undergone', 'increase', 'intend', 'phase', 'event', 'worse'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('change.n.01')
# Senso Target:  Lemma('change.v.01.change')
# ------------------------------
# Parola da disambiguare:  varying
# Frase in cui compare la parola:  Changes of intensity on the cell were achieved by use of a wire screen and by varying the distance of the light source from the cell .
# Contesto della frase:  {'vary', 'screen', 'intensity', 'light', 'cell', 'source', 'achieve', 'changes', 'distance', 'wire'}
# Max Signature:  {'vary', 'subject', 'change', 'mood', 'weather', 'depend', 'prices', 'variable'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('vary.v.03')
# Senso Target:  Lemma('change.v.03.vary')
# ------------------------------
# Parola da disambiguare:  small
# Frase in cui compare la parola:  Proposed property sales of general interest to small business concerns are publicized through SBA regional news releases , and by `` flyers '' directed to the small business concerns .
# Contesto della frase:  {'direct', 'concern', 'proposed', 'business', 'regional', 'news', 'sba', 'flyer', 'sale', 'property', 'small', 'publicize', 'release', 'interest', 'general'}
# Max Signature:  {'size', 'modest', 'plan', 'limit', 'smallscale', 'pocketsize', 'country', 'circulation', 'newspaper', 'small', 'business', 'scope'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('minor.s.10')
# Senso Target:  Lemma('small.a.01.small')
# ------------------------------
# Parola da disambiguare:  typified
# Frase in cui compare la parola:  Greasy soils , which are typified by hydrocarbons and fats ( esters of glycerol with long chain organic acids ) .
# Contesto della frase:  {'acid', 'ester', 'greasy', 'hydrocarbon', 'chain', 'organic', 'fat', 'glycerol', 'typify', 'long', 'soil'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('typify.v.01')
# Senso Target:  Lemma('typify.v.01.typify')
# ------------------------------
# Parola da disambiguare:  set
# Frase in cui compare la parola:  Kerr , who set the world record earlier this month in New York with a clocking of 1.09.3 , wiped out Mills 's early pace and beat the young Big 10 quarter-mile king by 5 yards .
# Contesto della frase:  {'record', 'york', 'clocking', 'mills', 'set', 'big', 'king', 'yard', 'early', 'wipe', 'pace', 'earlier', 'quartermile', 'beat', 'young', 'month', 'kerr'}
# Max Signature:  {'radio', 'signal', 'transmit', 'set', 'tv', 'battery', 'early', 'storage', 'electronic', 'receive', 'equipment'}
# ...
# ------------------------------
# Parola da disambiguare:  Sundays
# Frase in cui compare la parola:  By 1871 L. C. Orvis , manager of the `` Western Union Telegraph Company '' , expressed willingness to send emergency telegrams on Sundays from his Village drugstore .
# Contesto della frase:  {'willingness', 'drugstore', 'union', 'telegraph', 'express', 'emergency', 'western', 'company', 'send', 'orvis', 'manager', 'telegram', 'village', 'sundays'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('sunday.n.01')
# Senso Target:  Lemma('sunday.n.01.Sunday')
# ------------------------------
# Parola da disambiguare:  effective
# Frase in cui compare la parola:  Often it is recognized that all the details of the pattern may not be essential to the outcome but , because the pattern was empirically determined and not developed through theoretical understanding , one is never quite certain which behavior elements are effective , and the whole pattern becomes ritualized .
# Contesto della frase:  {'element', 'pattern', 'determine', 'develop', 'understand', 'ritualize', 'outcome', 'detail', 'empirically', 'effective', 'behavior', 'essential', 'theoretical', 'recognize'}
# Max Signature:  {'expenditure', 'fact', 'real', 'work', 'decline', 'demand', 'confuse', 'effective', 'quantity', 'equipment', 'exist', 'theoretical', 'increased'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('effective.s.05')
# Senso Target:  Lemma('effective.s.03.effective')
# ------------------------------
# Parola da disambiguare:  polynomials
# Frase in cui compare la parola:  Since * * f are distinct prime polynomials , the polynomials * * f are relatively prime ( Theorem 8 , Chapter 4 ) .
# Contesto della frase:  {'polynomial', 'chapter', 'distinct', 'theorem', 'prime'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('polynomial.n.01')
# Senso Target:  Lemma('polynomial.n.01.polynomial')
# ------------------------------
# Parola da disambiguare:  precarious
# Frase in cui compare la parola:  During this precarious period of development the mother should continue to influence the growth of the child 's conscience .
# Contesto della frase:  {'precarious', 'continue', 'child', 'mother', 'conscience', 'period', 'development', 'growth', 'influence'}
# Max Signature:  {'precarious', 'afford', 'reassurance', 'ease', 'truce'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('precarious.s.01')
# Senso Target:  Lemma('precarious.s.01.precarious')
# ------------------------------
# Parola da disambiguare:  topical
# Frase in cui compare la parola:  In experiments with topical application of strychnine on the cerebral cortex , the transmission of impulses from the cortex to the hypothalamus was demonstrated .
# Contesto della frase:  {'strychnine', 'topical', 'application', 'cortex', 'hypothalamus', 'transmission', 'impulse', 'demonstrate', 'cerebral', 'experiment'}
# Max Signature:  {'surface', 'drug', 'topical', 'application', 'pertain', 'anesthesia', 'body', 'local'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('topical.s.01')
# Senso Target:  Lemma('topical.s.01.topical')
# ------------------------------
# Parola da disambiguare:  astonishing
# Frase in cui compare la parola:  They can even be rather grand , like Edward Land 's monument to the astonishing success of Polaroid .
# Contesto della frase:  {'land', 'astonishing', 'polaroid', 'edward', 'grand', 'success', 'monument'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('amaze.v.01')
# Senso Target:  Lemma('amazing.s.01.astonishing')
# ------------------------------
# Parola da disambiguare:  follicular
# Frase in cui compare la parola:  At the present time we do not know by what biochemical mechanism TSH acts on the thyroid , but for bio-assay of the hormone there are a number of properties by which its activity may be estimated , including release of iodine from the thyroid , increase in thyroid weight , increase in mean height of the follicular cells and increase in the thyroidal uptake of * * f .
# Contesto della frase:  {'include', 'cell', 'release', 'bioassay', 'thyroidal', 'tsh', 'time', 'mechanism', 'biochemical', 'height', 'uptake', 'iodine', 'weight', 'number', 'hormone', 'activity', 'property', 'thyroid', 'increase', 'follicular', 'estimate'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('follicular.a.01')
# Senso Target:  Lemma('follicular.a.01.follicular')
# ------------------------------
# Parola da disambiguare:  hot
# Frase in cui compare la parola:  An ordinary hot bath or shower will do the same .
# Contesto della frase:  {'bath', 'ordinary', 'hot', 'shower'}
# Max Signature:  {'physical', 'high', 'hot', 'temperature', 'sensation', 'desirable', 'august', 'forehead', 'water', 'tire', 'stuffy', 'stove', 'heat', 'room', 'day', 'feeling', 'burning'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('hot.a.01')
# Senso Target:  Lemma('hot.a.01.hot')
# ------------------------------
# Parola da disambiguare:  frightful
# Frase in cui compare la parola:  It is this modulation which reveals to Jacoby his own frightful abjection and , simultaneously , his wife 's infidelity .
# Contesto della frase:  {'wife', 'simultaneously', 'frightful', 'jacoby', 'infidelity', 'modulation', 'reveal', 'abjection'}
# Max Signature:  {'atrocious', 'word', 'crime', 'horrify', 'picture', 'frightful', 'horror', 'automobile', 'alarm', 'wound', 'accident', 'ugly', 'war', 'horrible', 'churchill', 'decapitation', 'provoke', 'winston'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('atrocious.s.03')
# Senso Target:  Lemma('atrocious.s.03.frightful')
# ------------------------------
# Parola da disambiguare:  infinite
# Frase in cui compare la parola:  that the dream was a reality on the infinite progressions of universal , gradient frequencies , across which the modern professor and the priest of ancient Nippur met ?
# Contesto della frase:  {'professor', 'meet', 'gradient', 'infinite', 'progression', 'reality', 'frequency', 'priest', 'dream', 'modern', 'nippur', 'universal', 'ancient'}
# Max Signature:  {'expanse', 'space', 'infinite', 'test', 'region', 'locate', 'ability', 'unlimited', 'object', 'boundless'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('space.n.01')
# Senso Target:  Lemma('infinite.a.01.infinite')
# ------------------------------
# Parola da disambiguare:  esthetic
# Frase in cui compare la parola:  This would , naturally , lengthen their courses far beyond the largely esthetic demands of interior designer 's training .
# Contesto della frase:  {'course', 'designer', 'esthetic', 'demand', 'naturally', 'interior', 'training', 'lengthen'}
# Max Signature:  {'minimalism', 'philosophical', 'esthetic', 'theory', 'beautiful', 'despise', 'philosophy'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('aesthetic.n.01')
# Senso Target:  Lemma('aesthetic.a.02.esthetic')
# ------------------------------
# Parola da disambiguare:  firms
# Frase in cui compare la parola:  SBA serves also as a clearing house for information on products and processes particularly adaptable for exploitation by small firms .
# Contesto della frase:  {'firm', 'clearing', 'exploitation', 'serve', 'sba', 'process', 'product', 'small', 'house', 'adaptable'}
# Max Signature:  {'member', 'organization', 'work', 'establishment', 'operate', 'house', 'business', 'brokerage'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('firm.n.01')
# Senso Target:  Lemma('firm.n.01.firm')
# ------------------------------
# Parola da disambiguare:  3
# Frase in cui compare la parola:  The surfaces were coarsely and finely granular and punctuated by clear , fluid filled cysts measuring up to 3 cm. in diameter .
# Contesto della frase:  {'surface', 'finely', 'measure', 'cm', 'cyst', 'clear', 'granular', 'diameter', 'punctuate', 'fluid', 'coarsely', 'fill'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('three.n.01')
# Senso Target:  Lemma('three.s.01.3')
# ------------------------------
# Parola da disambiguare:  philosophy
# Frase in cui compare la parola:  The Bourbon economic philosophy , moreover , is not very different from that of Northern conservatives .
# Contesto della frase:  {'conservative', 'economic', 'northern', 'philosophy', 'bourbon'}
# Max Signature:  {'selfindulgence', 'situation', 'father', 'belief', 'deal', 'philosophy', 'live', 'personal', 'childrearing'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('philosophy.n.03')
# Senso Target:  Lemma('doctrine.n.01.philosophy')
# ------------------------------
# Parola da disambiguare:  memberships
# Frase in cui compare la parola:  These groups have varied widely from mere families , primitive , totemic groups , and small modern cults and sects , to the memberships of great denominations , and great , widely dispersed world religions .
# Contesto della frase:  {'vary', 'totemic', 'primitive', 'group', 'mere', 'denomination', 'religion', 'great', 'small', 'family', 'modern', 'sect', 'disperse', 'membership', 'cult'}
# Max Signature:  {'rank', 'member', 'group', 'poll', 'organization', 'unemployed', 'dissension', 'join', 'body', 'membership', 'find'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('membership.n.01')
# Senso Target:  Lemma('membership.n.01.membership')
# ------------------------------
# Parola da disambiguare:  suitable
# Frase in cui compare la parola:  Biological agents are , moreover , suitable for delivery through enemy sabotage which imposes many problems in defense .
# Contesto della frase:  {'sabotage', 'impose', 'biological', 'defense', 'suitable', 'problem', 'enemy', 'delivery', 'agent'}
# Max Signature:  {'fit', 'duty', 'time', 'flippancy', 'appropriate', 'meant', 'occasion', 'adapt', 'tractor', 'heavy', 'suitable'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('suitable.s.01')
# Senso Target:  suitable.s.00
# ------------------------------
# Parola da disambiguare:  whistled
# Frase in cui compare la parola:  The Catholics had the largest cemetery , near the Neversink River where Main Street ran south ; Stevie whistled when he passed these alien grounds .
# Contesto della frase:  {'pass', 'large', 'ground', 'river', 'neversink', 'south', 'whistle', 'stevie', 'alien', 'main', 'street', 'catholics', 'cemetery'}
# Max Signature:  {'sound', 'snore', 'whistle', 'lay', 'whistling'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('whistle.v.01')
# Senso Target:  Lemma('whistle.v.05.whistle')
# ------------------------------
# Parola da disambiguare:  case
# Frase in cui compare la parola:  On the positivist theory , everything I sought to express by calling it evil in the first case is still present in the second .
# Contesto della frase:  {'express', 'call', 'theory', 'evil', 'case', 'second', 'positivist', 'seek'}
# Max Signature:  {'example', 'occur', 'yesterday', 'occurrence', 'bad', 'case', 'famous', 'judgment', 'instance', 'smiths'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('case.n.01')
# Senso Target:  Lemma('case.n.01.case')
# ------------------------------
# Parola da disambiguare:  orchestra
# Frase in cui compare la parola:  Those would be reserved for the orchestra 's great nights when the soloist can surpass himself .
# Contesto della frase:  {'surpass', 'reserve', 'orchestra', 'night', 'great', 'soloist'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('orchestra.n.01')
# Senso Target:  Lemma('orchestra.n.01.orchestra')
# ------------------------------
# Parola da disambiguare:  heavy
# Frase in cui compare la parola:  But for purely definition purposes - used in conjunction with your regular Squatting , Leg Curling , Leg Extensor programs - a heavy weight is not needed .
# Contesto della frase:  {'purpose', 'leg', 'regular', 'conjunction', 'extensor', 'weight', 'purely', 'definition', 'squatting', 'program', 'heavy', 'curling'}
# Max Signature:  {'physical', 'furniture', 'load', 'heavy', 'comparatively', 'density', 'great', 'mahogany', 'weight', 'lead', 'metal'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('heavy.a.01')
# Senso Target:  Lemma('heavy.a.01.heavy')
# ------------------------------
# Parola da disambiguare:  began
# Frase in cui compare la parola:  He began his coaching career at Pittsburgh Central Catholic High School in 1949 .
# Contesto della frase:  {'high', 'school', 'coach', 'pittsburgh', 'career', 'central', 'catholic'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('get_down.v.07')
# Senso Target:  Lemma('get_down.v.07.begin')
# ------------------------------
# Parola da disambiguare:  Microscopically
# Frase in cui compare la parola:  Microscopically , both kidneys showed many small cortical scars in which there was glomerular and interstitial fibrosis , tubular atrophy , and an infiltration of lymphocytes and plasma cells .
# Contesto della frase:  {'plasma', 'atrophy', 'infiltration', 'fibrosis', 'glomerular', 'scar', 'cell', 'kidney', 'small', 'interstitial', 'tubular', 'cortical', 'lymphocyte', 'microscopically'}
# Max Signature:  {'seed', 'examine', 'microscope', 'blood', 'small', 'visible', 'microscopically'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('microscopically.r.01')
# Senso Target:  Lemma('microscopically.r.01.microscopically')
# ------------------------------
# Parola da disambiguare:  satellites
# Frase in cui compare la parola:  Direct information has been obtained from rockets and satellites equipped with impact sensors .
# Contesto della frase:  {'rocket', 'impact', 'direct', 'sensor', 'equip', 'satellite'}
# Max Signature:  {'disseminate', 'broadcast', 'satellite'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('satellite.v.01')
# Senso Target:  Lemma('satellite.n.01.satellite')
# ------------------------------
# Parola da disambiguare:  alchemy
# Frase in cui compare la parola:  There was in the Brahms none of the mysterious and marvelous alchemy by which a great conductor can bring soloist , orchestra and music to ultimate fusion .
# Contesto della frase:  {'fusion', 'conductor', 'alchemy', 'bring', 'brahms', 'orchestra', 'marvelous', 'great', 'ultimate', 'mysterious', 'music', 'soloist'}
# Max Signature:  {'bring', 'alchemy', 'relate', 'wrong', 'chemistry', 'hat', 'mysterious', 'individual'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('chemistry.n.03')
# Senso Target:  alchemy.n.00
# ------------------------------
# Parola da disambiguare:  quack
# Frase in cui compare la parola:  As a result , she consulted medical authorities and learned that the devices her quack `` doctor '' was using were phony .
# Contesto della frase:  {'phony', 'authority', 'device', 'result', 'doctor', 'medical', 'quack', 'learn', 'consult'}
# Max Signature:  {'quack', 'medical', 'charlatan'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('quack.v.02')
# Senso Target:  Lemma('quack.s.01.quack')
# ------------------------------
# Parola da disambiguare:  slow-moving
# Frase in cui compare la parola:  Cousin Joshua and some others felt that we should march toward Lexington and take up new positions ahead of the slow-moving British column , but another group maintained that we should stick to this spot and this section of road .
# Contesto della frase:  {'maintain', 'road', 'ahead', 'group', 'joshua', 'lexington', 'spot', 'british', 'stick', 'cousin', 'felt', 'column', 'march', 'position', 'slowmoving'}
# Max Signature:  {'slowmoving', 'car', 'move', 'slowly'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('slow-moving.s.01')
# Senso Target:  Lemma('slow-moving.s.01.slow-moving')
# ------------------------------
# Parola da disambiguare:  oxygen
# Frase in cui compare la parola:  The slippage of the drive belts caused the aerator to slow down and reduce oxygen transfer as well as the mixing of the raw sewage .
# Contesto della frase:  {'reduce', 'transfer', 'raw', 'slow', 'belt', 'oxygen', 'sewage', 'well', 'aerator', 'drive', 'slippage', 'mixing'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('oxygen.n.01')
# Senso Target:  Lemma('oxygen.n.01.oxygen')
# ------------------------------
# Termini valutati:  51
# Termini valutati correttamente:  28
# Accuratezza:  0.56
#
# Esecuzioni:  10
# Lista delle accuratezze:  [0.5, 0.48, 0.46, 0.48, 0.54, 0.62, 0.56, 0.4, 0.5, 0.56]
# Accuratezza media:  0.51
