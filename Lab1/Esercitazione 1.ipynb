# %%
import re
import enum
import math
import random
import nltk
import csv
import numpy as np
import scipy as sp
from nltk.corpus import wordnet as wn
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import semcor
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from random import randrange
from collections import deque
from statistics import mean

# %% [markdown]
# FUNZIONI DI PREPROCESSING

# %%
#il pre-processing consiste nella tokenizzazione, lemmatizzazione,
#rimozione della punteggiatura e delle stopwords di una sentence
def pre_processing(sentence):
    return set(remove_stopwords(tokenize_sentence(remove_punctuation(sentence))))

#rimuove le stowords da una lista di parole
def remove_stopwords(words_list):
    stopwords_list = get_stopwords()
    return [value.lower() for value in words_list if value.lower() not in stopwords_list]

#Tokenizza la frase in input e ne affettua anche la lemmatizzazione della sue parole
def tokenize_sentence(sentence):
    words_list = []
    lmtzr = WordNetLemmatizer()
    for tag in nltk.pos_tag(word_tokenize(sentence)):
        if (tag[1][:2] == "NN"):
            words_list.append(lmtzr.lemmatize(tag[0], pos = wn.NOUN))
        elif (tag[1][:2] == "VB"):
             words_list.append(lmtzr.lemmatize(tag[0], pos = wn.VERB))
        elif (tag[1][:2] == "RB"):
             words_list.append(lmtzr.lemmatize(tag[0], pos = wn.ADV))
        elif (tag[1][:2] == "JJ"):
             words_list.append(lmtzr.lemmatize(tag[0], pos = wn.ADJ))
    return words_list

#Restituisce la l'insieme di stopwords dal file delle stopwords
def get_stopwords():
    stopwords = open("stop_words_FULL.txt", "r")
    stopwords_list = []
    for word in stopwords:
        stopwords_list.append(word.replace('\n', ''))
    stopwords.close()
    return stopwords_list

#Rimuove la punteggiatura da una sentence
#Restituisce la sentence senza punteggiature
def remove_punctuation(sentence):
    return re.sub(r'[^\w\s]','',sentence)

# %% [markdown]
# FUNZIONI UTILI PER L'ANALISI DEL TESTO

# %%
#Restituisce un sostantivo random presente nel dizionario associato ad una sentence
def get_random_noun(dictionary_tag):
    try:
        sentence_nouns = dictionary_tag['NN']
    except KeyError:
        return None #se non ci sono sostantivi
    noun =  random.choice(sentence_nouns)
    if len(wn.synsets(noun)) == 0:
        return None #se il sostantivo scelto non ha almeno un synset in wordnet
    return noun

#Restituisce una parola random presente nel dizionario associato ad una sentence
def get_random_word(dictionary_tag):
    keys = list(dictionary_tag.keys())
    if not keys:
        return None #se non ci sono parole "analizzabili" nel dizionario, aka se il dizionario è vuoto
    key = random.choice(keys)
    words_list = dictionary_tag[key]
    word = random.choice(words_list)
    if len(wn.synsets(word)) == 0:
        return None #se la parola scelta non ha almeno un synset in wordnet
    return word

#Verifica che una parola abbia un synset target associato
#Senza synset target associato è inutile confrontare l'output dell'algortimo di Lesk
def check_word_synset_target(word,sentence_sem):
    for w in sentence_sem:
        if (type(w) != list):
            if (w[0] == word):
                return True
    return False
    
#Crea un dizionario che ha come chiavi i tag presenti nella sentence
#e come valori liste di parole associate a quei tag
#e.g {NN: ['home','garden'], VB:['gone'], .....,}
#input: sentence_tag -> rappresenta le words della sentence con i relativi pos tag
#input: sentence_sem -> rappresenta le words della sentence con il relativo synset target associato
def get_dictionary_tag(sentence_tag,sentence_sem):
    dictionary_tag = dict()
    stopwords_list = get_stopwords()
    for word in sentence_tag:
         tag = word.label()
         word = " ".join(l for l in word)
         if check_word_synset_target(word, sentence_sem): #Non inserisco nel dizionario parole che non hanno un synset target
             w = word.lower()
             if w not in stopwords_list and tag: #Non inserisco nel dizionario stopwords o parole che non hanno un pos tag associato
                 if tag in dictionary_tag:
                     dictionary_tag[tag].append(word)
                 else:
                     dictionary_tag[tag] = [word]             
    return dictionary_tag

#Restituisce un indice randomico utile per l'ultimo esercizio
def get_random_index(index_evaluated, INDEXES_NUM):
    while True:
        index = randrange(INDEXES_NUM)
        if index not in index_evaluated:
            return index
    
#Restituisce il synset target per una parola in una sentence
def get_synset_target_for_word_in_sentence(noun,sentence):
     for word in sentence:
      if(type(word) != list):
          if (word[0] == noun):
              return str(word.label())

# %% [markdown]
# METRICHE DI SIMILARITA E ALGORITMI PER LA RICERCA

# %%
#Custom similarity functions
def wu_palmer_similarity(sense1, sense2):
    numerator = 2 * depth(lowest_common_subsumer(sense1,sense2))
    denominator = depth(sense1) + depth(sense2)
    return numerator/denominator

def leakcock_chodorow(sense1, sense2):
    numerator = (shortest_path(sense1, sense2) + 1)
    denominator = (2 * max_depth) + 1
    return -math.log(numerator/denominator)

def shortest_path_similarity(sense1, sense2):
    return ((2 * max_depth) - shortest_path(sense1, sense2))

#Wordnet similarity functions
def wn_wu_palmer_similarity(sense1, sense2):
    sim = sense1.wup_similarity(sense2)
    if sim: return sim
    else: return 0
    
def wn_leakcock_chodorow(sense1, sense2):
    try:
        sim = sense1.lch_similarity(sense2)
        if sim: return sim
        else: return 0
    except:
        return 0

#Restituisce la similarità tra due parole date in input
def similarity(word1, word2, similarity_function):
    max_sim = 0
    for s1 in wn.synsets(word1):
        for s2 in wn.synsets(word2):
           sim = similarity_function(s1,s2)
           if sim > max_sim:
               max_sim = sim
    return max_sim

#Restituisce la profondità di un senso in wordnet, cioè il massimo percorso dal senso alla radice        
def depth(sense):
    if not sense:
        return 0
    return max([len(path) for path in all_hypernym_paths(sense)])

#Restituisce tutti i percorsi di iperonimi di un senso di wordnet, la ricerca dei percosi viene effettuata in modo ricorsivo
def all_hypernym_paths(sense):
    paths = []
    hypernyms = sense.hypernyms()
    if len(hypernyms) == 0:
        paths = [[sense]]
    for hypernym in hypernyms:
        for ancestor_list in all_hypernym_paths(hypernym):
            ancestor_list.append(sense)
            paths.append(ancestor_list)
    return paths

#Massima profondità intesa come il percorso più lungo degli iperonimi di tutti i sensi presenti in wordnet
max_depth = max(max(len(hyp_path) for hyp_path in all_hypernym_paths(ss)) for ss in wn.all_synsets())

#Restituisce un dizionario di iperonimi del senso in input con la relativa profondità
def min_hypernyms_depth(sense):
    sense_depth_queue = deque([(sense, 0)]) #deque garantisce efficienza nell'inserire ed eliminare elementi sia a destra che a sinistra della coda
    sense_depth_dict = {}
    while sense_depth_queue:
        s, depth = sense_depth_queue.popleft()
        if s in sense_depth_dict:
            continue
        sense_depth_dict[s] = depth
        depth += 1
        sense_depth_queue.extend((hyperonym, depth) for hyperonym in s.hypernyms()) #li mette a destra della coda
    return sense_depth_dict

#restituisce il percorso più breve tra due sensi di wordnet
def shortest_path(sense1,sense2):
    if sense1 == sense2:
        return 0
    dict1 = min_hypernyms_depth(sense1)
    dict2 = min_hypernyms_depth(sense2)
    min_dist = (2 * max_depth) # distanza minima iniziale

    #per ogni senso del dizionario degli iperonimi di sense1 cerca di trovare il match con un senso del secondo dizionario.
    for ss, dist1 in dict1.items():
        dist2 = dict2.get(ss)
        if not dist2:
            dist2 = (2 * max_depth)
        min_dist = min(min_dist, dist1 + dist2) #somma dei due sensi matchati
    return (2 * max_depth) if math.isinf(min_dist) else min_dist

#Restituisce il lowest common ancestor di due sensi, cioè l'iperonimo comune più vicino ai due sensi. 
#Se ne ho più di uno prendo quello può essere il più profondo rispetto alla radice.
def lowest_common_subsumer(sense1, sense2):
    if sense1 == sense2: return sense1
    
    dict1 = min_hypernyms_depth(sense1)
    dict2 = min_hypernyms_depth(sense2)
    
    min_dist = (2 * max_depth)
    candidates = []
    for ss, dist1 in dict1.items():
        dist2 = dict2.get(ss) 
        if not dist2:
            dist2 = (2 * max_depth)
        else:
            if (dist1 + dist2) <= min_dist:
                min_dist = (dist1 + dist2)
                candidates.append(ss) 
    if candidates:
        deepest = candidates[0]
        for sense in candidates:
            if depth(sense) < depth(deepest):
                deepest = sense
        return deepest #restituisce il senso con profondità maggiore rispetto alla radice

#Classe enum con la quale specifichiamo il tipo di similarità utilizzata
class Similarity_Type(enum.Enum):
    wu_palmer_similarity = 1
    shortest_path = 2
    leakcock_chodorow = 3

# %% [markdown]
# Word sense disambiguation è un problema aperto dell'elaborazione del linguaggio naturale, che comprende il processo di identificazione del senso di una parola (cioè il significato) utilizzato in una determinata frase, quando la parola ha un numero di sensi distinti (polisemia).

# %%
#Algoritmo di Lesk
def lesk_algorithm(word, sentence, word_type):
    best_sense = wn.synsets(word)[0]
    max_overlap = 0
    max_signature = []
    print("Frase in cui compare la parola: ", sentence)
    context = pre_processing(sentence)
    
    #se il tipo di parola è un nome allora cerco solo tra i nomi in wordnet
    #altrimenti prendo tutti i synset associati a quel termine
    if word_type == 'NOUN':
        synsets = wn.synsets(word, pos=wn.NOUN)
    elif word_type == 'ALL':
        synsets = wn.synsets(word)
        
    for sense in synsets:
        signature = get_signature(sense)
        overlap = len(list(signature & context)) #overlap
        if overlap > max_overlap:
            max_overlap = overlap
            best_sense = sense
            max_signature = signature
            
    print("Contesto della frase: ", context)
    print("Max Signature: ", max_signature) #signature del senso con più overlap con il contesto della sentence
    return best_sense

#Signature di un senso di WordNet
def get_signature(sense):
    signature = set()
    for word in pre_processing(sense.definition()): #tokenizzo la definizione del synset
        signature.add(word)
    for example in sense.examples(): #tokenizzo ogni esempio del synset
        for word in pre_processing(example):
            signature.add(word)
    return signature #la signature conterrà tutte le parole presenti nella definizione del senso e negli esempi

# %% [markdown]
# CONSEGNA 1:
#
# L'esercitazione consiste nell'implementare tre misure di similarità basate su WordNet.
#
# Per ciascuna di tali misure di similarità, calcolare gli indici di
# correlazione di Spearman and gli indici di correlazione di Pearson
# fra i risultati ottenuti e quelli ‘target’ presenti nel file annotato.

# %%
def main():

    #scelta della metrica da utilizzare per il calcolo della similarità
    similarity_type = Similarity_Type.leakcock_chodorow
    #similarity_type = Similarity_Type.wu_palmer_similarity
    #similarity_type = Similarity_Type.shortest_path
    
    with open('WordSim353.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        assignments = []
        targets = []
        line_count = 0
        for row in csv_reader:
            if line_count > 0:
                print("Word1: ",row[0])
                print("Word2: ",row[1])
                sim = 0
                wn_sim = 0
                if similarity_type.value == 1:
                    sim = similarity(row[0], row[1], wu_palmer_similarity)
                    wn_sim = similarity(row[0], row[1], wn_wu_palmer_similarity)
                elif similarity_type.value == 2:
                    sim = similarity(row[0], row[1], shortest_path_similarity)
                elif similarity_type.value == 3:
                    sim = similarity(row[0], row[1], leakcock_chodorow)
                    wn_sim = similarity(row[0], row[1], wn_leakcock_chodorow)
                print("Type of similarity chosen: ", similarity_type.name)
                print("MyCustom Similarity: ",sim)
                print("WordNet Similarity: ",wn_sim)
                print("Human Similarity: ",row[2])
                assignments.append(sim)
                targets.append(float(row[2]))
                print("------------------------------")
            line_count = line_count + 1
            
    print("Pearson Correlation: ", np.corrcoef(assignments, targets))
    print("Spearman Correlation: ", sp.stats.spearmanr(assignments, targets))
main()
# Out:
# Word1:  love
# Word2:  sex
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  6.77
# ------------------------------
# Word1:  tiger
# Word2:  cat
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  7.35
# ------------------------------
# Word1:  tiger
# Word2:  tiger
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# WordNet Similarity:  3.6375861597263857
# Human Similarity:  10.00
# ------------------------------
# Word1:  book
# Word2:  paper
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.46
# ------------------------------
# Word1:  computer
# Word2:  keyboard
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.62
# ------------------------------
# Word1:  computer
# Word2:  internet
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  7.58
# ------------------------------
# Word1:  plane
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  5.77
# ------------------------------
# Word1:  train
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.31
# ------------------------------
# Word1:  telephone
# Word2:  communication
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  7.50
# ------------------------------
# Word1:  television
# Word2:  radio
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  6.77
# ------------------------------
# Word1:  media
# Word2:  radio
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.42
# ------------------------------
# Word1:  drug
# Word2:  abuse
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.6486586255873816
# Human Similarity:  6.85
# ------------------------------
# Word1:  bread
# Word2:  butter
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  6.19
# ------------------------------
# Word1:  cucumber
# Word2:  potato
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  5.92
# ------------------------------
# Word1:  doctor
# Word2:  nurse
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.00
# ------------------------------
# Word1:  professor
# Word2:  doctor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  6.62
# ------------------------------
# Word1:  student
# Word2:  professor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  6.81
# ------------------------------
# Word1:  smart
# Word2:  student
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  0.9985288301111273
# Human Similarity:  4.62
# ------------------------------
# Word1:  smart
# Word2:  stupid
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  0.9985288301111273
# Human Similarity:  5.81
# ------------------------------
# Word1:  company
# Word2:  stock
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  7.08
# ------------------------------
# Word1:  stock
# Word2:  market
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  8.08
# ------------------------------
# Word1:  stock
# Word2:  phone
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  1.62
# ------------------------------
# Word1:  stock
# Word2:  CD
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  1.31
# ------------------------------
# Word1:  stock
# Word2:  jaguar
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  0.92
# ------------------------------
# Word1:  stock
# Word2:  egg
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  1.81
# ------------------------------
# Word1:  fertility
# Word2:  egg
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  6.69
# ------------------------------
# Word1:  stock
# Word2:  live
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.8718021769015913
# Human Similarity:  3.73
# ------------------------------
# Word1:  stock
# Word2:  life
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  0.92
# ------------------------------
# Word1:  book
# Word2:  library
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.46
# ------------------------------
# Word1:  bank
# Word2:  money
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  8.12
# ------------------------------
# Word1:  wood
# Word2:  forest
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# WordNet Similarity:  3.6375861597263857
# Human Similarity:  7.73
# ------------------------------
# Word1:  money
# Word2:  cash
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  9.15
# ------------------------------
# Word1:  professor
# Word2:  cucumber
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  0.31
# ------------------------------
# Word1:  king
# Word2:  cabbage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  0.23
# ------------------------------
# Word1:  king
# Word2:  queen
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# WordNet Similarity:  3.6375861597263857
# Human Similarity:  8.58
# ------------------------------
# Word1:  king
# Word2:  rook
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  5.92
# ------------------------------
# Word1:  bishop
# Word2:  rabbi
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  6.69
# ------------------------------
# Word1:  Jerusalem
# Word2:  Israel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  8.46
# ------------------------------
# Word1:  Jerusalem
# Word2:  Palestinian
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  0.8649974374866046
# Human Similarity:  7.65
# ------------------------------
# Word1:  holy
# Word2:  sex
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  1.62
# ------------------------------
# Word1:  fuck
# Word2:  sex
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.538973871058276
# Human Similarity:  9.44
# ------------------------------
# Word1:  Maradona
# Word2:  football
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  0
# Human Similarity:  8.62
# ------------------------------
# Word1:  football
# Word2:  soccer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  9.03
# ------------------------------
# Word1:  football
# Word2:  basketball
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  6.81
# ------------------------------
# Word1:  football
# Word2:  tennis
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.63
# ------------------------------
# Word1:  tennis
# Word2:  racket
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  7.56
# ------------------------------
# Word1:  Arafat
# Word2:  peace
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  1.072636802264849
# Human Similarity:  6.73
# ------------------------------
# Word1:  Arafat
# Word2:  terror
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  1.845826690498331
# Human Similarity:  7.65
# ------------------------------
# Word1:  Arafat
# Word2:  Jackson
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  2.50
# ------------------------------
# Word1:  law
# Word2:  lawyer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  8.38
# ------------------------------
# Word1:  movie
# Word2:  star
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  7.38
# ------------------------------
# Word1:  movie
# Word2:  popcorn
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  0.9985288301111273
# Human Similarity:  6.19
# ------------------------------
# Word1:  movie
# Word2:  critic
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  6.73
# ------------------------------
# Word1:  movie
# Word2:  theater
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.92
# ------------------------------
# Word1:  physics
# Word2:  proton
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.0055218656020977
# WordNet Similarity:  0.9295359586241757
# Human Similarity:  8.12
# ------------------------------
# Word1:  physics
# Word2:  chemistry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.35
# ------------------------------
# Word1:  space
# Word2:  chemistry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  4.88
# ------------------------------
# Word1:  alcohol
# Word2:  chemistry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  5.54
# ------------------------------
# Word1:  vodka
# Word2:  gin
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.46
# ------------------------------
# Word1:  vodka
# Word2:  brandy
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.13
# ------------------------------
# Word1:  drink
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  3.04
# ------------------------------
# Word1:  drink
# Word2:  ear
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  1.31
# ------------------------------
# Word1:  drink
# Word2:  mouth
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  5.96
# ------------------------------
# Word1:  drink
# Word2:  eat
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.159484249353372
# Human Similarity:  6.87
# ------------------------------
# Word1:  baby
# Word2:  mother
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  7.85
# ------------------------------
# Word1:  drink
# Word2:  mother
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  2.65
# ------------------------------
# Word1:  car
# Word2:  automobile
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# WordNet Similarity:  3.6375861597263857
# Human Similarity:  8.94
# ------------------------------
# Word1:  gem
# Word2:  jewel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# WordNet Similarity:  3.6375861597263857
# Human Similarity:  8.96
# ------------------------------
# Word1:  journey
# Word2:  voyage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  9.29
# ------------------------------
# Word1:  boy
# Word2:  lad
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  8.83
# ------------------------------
# Word1:  coast
# Word2:  shore
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  9.10
# ------------------------------
# Word1:  asylum
# Word2:  madhouse
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  8.87
# ------------------------------
# Word1:  magician
# Word2:  wizard
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# WordNet Similarity:  3.6375861597263857
# Human Similarity:  9.02
# ------------------------------
# Word1:  midday
# Word2:  noon
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.713572066704308
# WordNet Similarity:  3.6375861597263857
# Human Similarity:  9.29
# ------------------------------
# Word1:  furnace
# Word2:  stove
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  8.79
# ------------------------------
# Word1:  food
# Word2:  fruit
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  7.52
# ------------------------------
# Word1:  bird
# Word2:  cock
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  7.10
# ------------------------------
# Word1:  bird
# Word2:  crane
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.38
# ------------------------------
# Word1:  tool
# Word2:  implement
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  6.46
# ------------------------------
# Word1:  brother
# Word2:  monk
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  6.27
# ------------------------------
# Word1:  crane
# Word2:  implement
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  2.69
# ------------------------------
# Word1:  lad
# Word2:  brother
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  4.46
# ------------------------------
# Word1:  journey
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0.8232003088081431
# WordNet Similarity:  0.7472144018302211
# Human Similarity:  5.85
# ------------------------------
# Word1:  monk
# Word2:  oracle
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  5.00
# ------------------------------
# Word1:  cemetery
# Word2:  woodland
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  2.08
# ------------------------------
# Word1:  food
# Word2:  rooster
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0.9409833444645266
# WordNet Similarity:  0.8649974374866046
# Human Similarity:  4.42
# ------------------------------
# Word1:  coast
# Word2:  hill
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  4.38
# ------------------------------
# Word1:  forest
# Word2:  graveyard
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  1.85
# ------------------------------
# Word1:  shore
# Word2:  woodland
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  3.08
# ------------------------------
# Word1:  monk
# Word2:  slave
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  0.92
# ------------------------------
# Word1:  coast
# Word2:  forest
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  3.15
# ------------------------------
# Word1:  lad
# Word2:  wizard
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  0.92
# ------------------------------
# Word1:  chord
# Word2:  smile
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  0.54
# ------------------------------
# Word1:  glass
# Word2:  magician
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  2.08
# ------------------------------
# Word1:  noon
# Word2:  string
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  0.54
# ------------------------------
# Word1:  rooster
# Word2:  voyage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0.5355182363563622
# WordNet Similarity:  0.4595323293784402
# Human Similarity:  0.62
# ------------------------------
# Word1:  money
# Word2:  dollar
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  8.42
# ------------------------------
# Word1:  money
# Word2:  cash
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  9.08
# ------------------------------
# Word1:  money
# Word2:  currency
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  9.04
# ------------------------------
# Word1:  money
# Word2:  wealth
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  8.27
# ------------------------------
# Word1:  money
# Word2:  property
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.57
# ------------------------------
# Word1:  money
# Word2:  possession
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.29
# ------------------------------
# Word1:  money
# Word2:  bank
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  8.50
# ------------------------------
# Word1:  money
# Word2:  deposit
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.73
# ------------------------------
# Word1:  money
# Word2:  withdrawal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  6.88
# ------------------------------
# Word1:  money
# Word2:  laundering
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  5.65
# ------------------------------
# Word1:  money
# Word2:  operation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  3.31
# ------------------------------
# Word1:  tiger
# Word2:  jaguar
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.00
# ------------------------------
# Word1:  tiger
# Word2:  feline
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.00
# ------------------------------
# Word1:  tiger
# Word2:  carnivore
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.08
# ------------------------------
# Word1:  tiger
# Word2:  mammal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.85
# ------------------------------
# Word1:  tiger
# Word2:  animal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.00
# ------------------------------
# Word1:  tiger
# Word2:  organism
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.538973871058276
# Human Similarity:  4.77
# ------------------------------
# Word1:  tiger
# Word2:  fauna
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  5.62
# ------------------------------
# Word1:  tiger
# Word2:  zoo
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  5.87
# ------------------------------
# Word1:  psychology
# Word2:  psychiatry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  8.08
# ------------------------------
# Word1:  psychology
# Word2:  anxiety
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  7.00
# ------------------------------
# Word1:  psychology
# Word2:  fear
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  6.85
# ------------------------------
# Word1:  psychology
# Word2:  depression
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  7.42
# ------------------------------
# Word1:  psychology
# Word2:  clinic
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  0.9985288301111273
# Human Similarity:  6.58
# ------------------------------
# Word1:  psychology
# Word2:  doctor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  6.42
# ------------------------------
# Word1:  psychology
# Word2:  Freud
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  0.6418538861723948
# Human Similarity:  8.21
# ------------------------------
# Word1:  psychology
# Word2:  mind
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.69
# ------------------------------
# Word1:  psychology
# Word2:  health
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  7.23
# ------------------------------
# Word1:  psychology
# Word2:  science
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  6.71
# ------------------------------
# Word1:  psychology
# Word2:  discipline
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.538973871058276
# Human Similarity:  5.58
# ------------------------------
# Word1:  psychology
# Word2:  cognition
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.845826690498331
# Human Similarity:  7.48
# ------------------------------
# Word1:  planet
# Word2:  star
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.45
# ------------------------------
# Word1:  planet
# Word2:  constellation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  8.06
# ------------------------------
# Word1:  planet
# Word2:  moon
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  8.08
# ------------------------------
# Word1:  planet
# Word2:  sun
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  8.02
# ------------------------------
# Word1:  planet
# Word2:  galaxy
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  8.11
# ------------------------------
# Word1:  planet
# Word2:  space
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.92
# ------------------------------
# Word1:  planet
# Word2:  astronomer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  7.94
# ------------------------------
# Word1:  precedent
# Word2:  example
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  5.85
# ------------------------------
# Word1:  precedent
# Word2:  information
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.538973871058276
# Human Similarity:  3.85
# ------------------------------
# Word1:  precedent
# Word2:  cognition
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  2.81
# ------------------------------
# Word1:  precedent
# Word2:  law
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  6.65
# ------------------------------
# Word1:  precedent
# Word2:  collection
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.538973871058276
# Human Similarity:  2.50
# ------------------------------
# Word1:  precedent
# Word2:  group
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  1.77
# ------------------------------
# Word1:  precedent
# Word2:  antecedent
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.04
# ------------------------------
# Word1:  cup
# Word2:  coffee
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.58
# ------------------------------
# Word1:  cup
# Word2:  tableware
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.538973871058276
# Human Similarity:  6.85
# ------------------------------
# Word1:  cup
# Word2:  article
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  2.40
# ------------------------------
# Word1:  cup
# Word2:  artifact
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  2.92
# ------------------------------
# Word1:  cup
# Word2:  object
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.845826690498331
# Human Similarity:  3.69
# ------------------------------
# Word1:  cup
# Word2:  entity
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  1.845826690498331
# Human Similarity:  2.15
# ------------------------------
# Word1:  cup
# Word2:  drink
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  7.25
# ------------------------------
# Word1:  cup
# Word2:  food
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.845826690498331
# Human Similarity:  5.00
# ------------------------------
# Word1:  cup
# Word2:  substance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  1.92
# ------------------------------
# Word1:  cup
# Word2:  liquid
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.845826690498331
# Human Similarity:  5.90
# ------------------------------
# Word1:  jaguar
# Word2:  cat
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  7.42
# ------------------------------
# Word1:  jaguar
# Word2:  car
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0.8803587226480918
# WordNet Similarity:  0.8043728156701697
# Human Similarity:  7.27
# ------------------------------
# Word1:  energy
# Word2:  secretary
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  1.81
# ------------------------------
# Word1:  secretary
# Word2:  senate
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  0.9985288301111273
# Human Similarity:  5.06
# ------------------------------
# Word1:  energy
# Word2:  laboratory
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  5.09
# ------------------------------
# Word1:  computer
# Word2:  laboratory
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  6.78
# ------------------------------
# Word1:  weapon
# Word2:  secret
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  6.06
# ------------------------------
# Word1:  FBI
# Word2:  fingerprint
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  6.94
# ------------------------------
# Word1:  FBI
# Word2:  investigation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.0055218656020977
# WordNet Similarity:  0.9295359586241757
# Human Similarity:  8.31
# ------------------------------
# Word1:  investigation
# Word2:  effort
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  4.59
# ------------------------------
# Word1:  Mars
# Word2:  water
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  1.6486586255873816
# Human Similarity:  2.94
# ------------------------------
# Word1:  Mars
# Word2:  scientist
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  5.63
# ------------------------------
# Word1:  news
# Word2:  report
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  8.16
# ------------------------------
# Word1:  canyon
# Word2:  landscape
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  7.53
# ------------------------------
# Word1:  image
# Word2:  surface
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  4.56
# ------------------------------
# Word1:  discovery
# Word2:  space
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  6.34
# ------------------------------
# Word1:  water
# Word2:  seepage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  6.56
# ------------------------------
# Word1:  sign
# Word2:  recess
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.159484249353372
# Human Similarity:  2.38
# ------------------------------
# Word1:  Wednesday
# Word2:  news
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  2.22
# ------------------------------
# Word1:  mile
# Word2:  kilometer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  8.66
# ------------------------------
# Word1:  computer
# Word2:  news
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  4.47
# ------------------------------
# Word1:  territory
# Word2:  surface
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  5.34
# ------------------------------
# Word1:  atmosphere
# Word2:  landscape
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  3.69
# ------------------------------
# Word1:  president
# Word2:  medal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  3.00
# ------------------------------
# Word1:  war
# Word2:  troops
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  8.13
# ------------------------------
# Word1:  record
# Word2:  number
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  6.31
# ------------------------------
# Word1:  skin
# Word2:  eye
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.22
# ------------------------------
# Word1:  Japanese
# Word2:  American
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  6.50
# ------------------------------
# Word1:  theater
# Word2:  history
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  3.91
# ------------------------------
# Word1:  volunteer
# Word2:  motto
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  2.56
# ------------------------------
# Word1:  prejudice
# Word2:  recognition
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  3.00
# ------------------------------
# Word1:  decoration
# Word2:  valor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  5.63
# ------------------------------
# Word1:  century
# Word2:  year
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.59
# ------------------------------
# Word1:  century
# Word2:  nation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  3.16
# ------------------------------
# Word1:  delay
# Word2:  racism
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  1.19
# ------------------------------
# Word1:  delay
# Word2:  news
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  3.31
# ------------------------------
# Word1:  minister
# Word2:  party
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.63
# ------------------------------
# Word1:  peace
# Word2:  plan
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  4.75
# ------------------------------
# Word1:  minority
# Word2:  peace
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  3.69
# ------------------------------
# Word1:  attempt
# Word2:  peace
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  4.25
# ------------------------------
# Word1:  government
# Word2:  crisis
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  6.56
# ------------------------------
# Word1:  deployment
# Word2:  departure
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  4.25
# ------------------------------
# Word1:  deployment
# Word2:  withdrawal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  5.88
# ------------------------------
# Word1:  energy
# Word2:  crisis
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  5.94
# ------------------------------
# Word1:  announcement
# Word2:  news
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  7.56
# ------------------------------
# Word1:  announcement
# Word2:  effort
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  2.75
# ------------------------------
# Word1:  stroke
# Word2:  hospital
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  7.03
# ------------------------------
# Word1:  disability
# Word2:  death
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  5.47
# ------------------------------
# Word1:  victim
# Word2:  emergency
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  6.47
# ------------------------------
# Word1:  treatment
# Word2:  recovery
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.91
# ------------------------------
# Word1:  journal
# Word2:  association
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  4.97
# ------------------------------
# Word1:  doctor
# Word2:  personnel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  5.00
# ------------------------------
# Word1:  doctor
# Word2:  liability
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  5.19
# ------------------------------
# Word1:  liability
# Word2:  insurance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.03
# ------------------------------
# Word1:  school
# Word2:  center
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  3.44
# ------------------------------
# Word1:  reason
# Word2:  hypertension
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  2.31
# ------------------------------
# Word1:  reason
# Word2:  criterion
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  5.91
# ------------------------------
# Word1:  hundred
# Word2:  percent
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  7.38
# ------------------------------
# Word1:  Harvard
# Word2:  Yale
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.13
# ------------------------------
# Word1:  hospital
# Word2:  infrastructure
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  4.63
# ------------------------------
# Word1:  death
# Word2:  row
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  5.25
# ------------------------------
# Word1:  death
# Word2:  inmate
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  5.03
# ------------------------------
# Word1:  lawyer
# Word2:  evidence
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  6.69
# ------------------------------
# Word1:  life
# Word2:  death
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.88
# ------------------------------
# Word1:  life
# Word2:  term
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  4.50
# ------------------------------
# Word1:  word
# Word2:  similarity
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  4.75
# ------------------------------
# Word1:  board
# Word2:  recommendation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  4.47
# ------------------------------
# Word1:  governor
# Word2:  interview
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  0.9985288301111273
# Human Similarity:  3.25
# ------------------------------
# Word1:  OPEC
# Word2:  country
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  5.63
# ------------------------------
# Word1:  peace
# Word2:  atmosphere
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  3.69
# ------------------------------
# Word1:  peace
# Word2:  insurance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  2.94
# ------------------------------
# Word1:  territory
# Word2:  kilometer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  5.28
# ------------------------------
# Word1:  travel
# Word2:  activity
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  5.00
# ------------------------------
# Word1:  competition
# Word2:  price
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  6.44
# ------------------------------
# Word1:  consumer
# Word2:  confidence
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.2286654169163076
# WordNet Similarity:  1.1526795099383855
# Human Similarity:  4.13
# ------------------------------
# Word1:  consumer
# Word2:  energy
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  4.75
# ------------------------------
# Word1:  problem
# Word2:  airport
# ...
# WordNet Similarity:  0.9295359586241757
# Human Similarity:  5.97
# ------------------------------
# Word1:  game
# Word2:  victory
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.03
# ------------------------------
# Word1:  game
# Word2:  team
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  7.69
# ------------------------------
# Word1:  marathon
# Word2:  sprint
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  7.47
# ------------------------------
# Word1:  game
# Word2:  series
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  6.19
# ------------------------------
# Word1:  game
# Word2:  defeat
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  6.97
# ------------------------------
# Word1:  seven
# Word2:  series
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  3.56
# ------------------------------
# Word1:  seafood
# Word2:  sea
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  7.47
# ------------------------------
# Word1:  seafood
# Word2:  food
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  8.34
# ------------------------------
# Word1:  seafood
# Word2:  lobster
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.70
# ------------------------------
# Word1:  lobster
# Word2:  food
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.81
# ------------------------------
# Word1:  lobster
# Word2:  wine
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  5.70
# ------------------------------
# Word1:  food
# Word2:  preparation
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  6.22
# ------------------------------
# Word1:  video
# Word2:  archive
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  6.34
# ------------------------------
# Word1:  start
# Word2:  year
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  4.06
# ------------------------------
# Word1:  start
# Word2:  match
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  1.8718021769015913
# Human Similarity:  4.47
# ------------------------------
# Word1:  game
# Word2:  round
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  5.97
# ------------------------------
# Word1:  boxing
# Word2:  round
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.61
# ------------------------------
# Word1:  championship
# Word2:  tournament
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.36
# ------------------------------
# Word1:  fighting
# Word2:  defeating
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  2.159484249353372
# Human Similarity:  7.41
# ------------------------------
# Word1:  line
# Word2:  insurance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  2.69
# ------------------------------
# Word1:  day
# Word2:  summer
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  3.94
# ------------------------------
# Word1:  summer
# Word2:  drought
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  7.16
# ------------------------------
# Word1:  summer
# Word2:  nature
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  5.63
# ------------------------------
# Word1:  day
# Word2:  dawn
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.53
# ------------------------------
# Word1:  nature
# Word2:  environment
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  8.31
# ------------------------------
# Word1:  environment
# Word2:  ecology
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  3.0204248861443626
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  8.81
# ------------------------------
# Word1:  nature
# Word2:  man
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  6.25
# ------------------------------
# Word1:  man
# Word2:  woman
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.30
# ------------------------------
# Word1:  man
# Word2:  governor
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  5.25
# ------------------------------
# Word1:  murder
# Word2:  manslaughter
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  8.53
# ------------------------------
# Word1:  soap
# Word2:  opera
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  0.9985288301111273
# Human Similarity:  7.94
# ------------------------------
# Word1:  opera
# Word2:  performance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  6.88
# ------------------------------
# Word1:  life
# Word2:  lesson
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  5.94
# ------------------------------
# Word1:  focus
# Word2:  life
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  4.06
# ------------------------------
# Word1:  production
# Word2:  crew
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  6.25
# ------------------------------
# Word1:  television
# Word2:  film
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  7.72
# ------------------------------
# Word1:  lover
# Word2:  quarrel
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  6.19
# ------------------------------
# Word1:  viewer
# Word2:  serial
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  2.97
# ------------------------------
# Word1:  possibility
# Word2:  girl
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  1.94
# ------------------------------
# Word1:  population
# Word2:  development
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  3.75
# ------------------------------
# Word1:  morality
# Word2:  importance
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  3.31
# ------------------------------
# Word1:  morality
# Word2:  marriage
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  3.69
# ------------------------------
# Word1:  Mexico
# Word2:  Brazil
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  0
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  7.44
# ------------------------------
# Word1:  gender
# Word2:  equality
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  6.41
# ------------------------------
# Word1:  change
# Word2:  attitude
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  5.44
# ------------------------------
# Word1:  family
# Word2:  planning
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  6.25
# ------------------------------
# Word1:  opera
# Word2:  industry
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.2396908869280152
# Human Similarity:  2.63
# ------------------------------
# Word1:  sugar
# Word2:  approach
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.3156767939059373
# WordNet Similarity:  1.3121863889661687
# Human Similarity:  0.88
# ------------------------------
# Word1:  practice
# Word2:  institution
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  3.19
# ------------------------------
# Word1:  ministry
# Word2:  culture
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.6341305250244718
# WordNet Similarity:  1.55814461804655
# Human Similarity:  4.69
# ------------------------------
# Word1:  problem
# Word2:  challenge
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  6.75
# ------------------------------
# Word1:  size
# Word2:  prominence
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  5.31
# ------------------------------
# Word1:  country
# Word2:  citizen
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  7.31
# ------------------------------
# Word1:  planet
# Word2:  people
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  5.75
# ------------------------------
# Word1:  development
# Word2:  issue
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  3.97
# ------------------------------
# Word1:  experience
# Word2:  music
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  3.47
# ------------------------------
# Word1:  music
# Word2:  project
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.2512917986064953
# Human Similarity:  3.63
# ------------------------------
# Word1:  glass
# Word2:  metal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  5.56
# ------------------------------
# Word1:  aluminum
# Word2:  metal
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.327277705584417
# WordNet Similarity:  2.9444389791664407
# Human Similarity:  7.83
# ------------------------------
# Word1:  chance
# Word2:  credibility
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  3.88
# ------------------------------
# Word1:  exhibit
# Word2:  memorabilia
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  5.31
# ------------------------------
# Word1:  concert
# Word2:  virtuoso
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.148622709242771
# WordNet Similarity:  1.072636802264849
# Human Similarity:  6.81
# ------------------------------
# Word1:  rock
# Word2:  jazz
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.6149597780361984
# WordNet Similarity:  2.538973871058276
# Human Similarity:  7.59
# ------------------------------
# Word1:  museum
# Word2:  theater
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.19
# ------------------------------
# Word1:  observation
# Word2:  architecture
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.9218125974762528
# WordNet Similarity:  1.845826690498331
# Human Similarity:  4.38
# ------------------------------
# Word1:  space
# Word2:  world
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  2.0281482472922856
# Human Similarity:  6.53
# ------------------------------
# Word1:  preservation
# Word2:  world
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  6.19
# ------------------------------
# Word1:  admission
# Word2:  ticket
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  7.69
# ------------------------------
# Word1:  shower
# Word2:  thunderstorm
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.7676619176489945
# WordNet Similarity:  1.6916760106710724
# Human Similarity:  6.31
# ------------------------------
# Word1:  shower
# Word2:  flood
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  2.1041341542702074
# WordNet Similarity:  1.6486586255873816
# Human Similarity:  6.03
# ------------------------------
# Word1:  weather
# Word2:  forecast
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.074514737089049
# WordNet Similarity:  1.3121863889661687
# Human Similarity:  8.34
# ------------------------------
# Word1:  disaster
# Word2:  area
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.5163474893680884
# WordNet Similarity:  1.4403615823901665
# Human Similarity:  6.25
# ------------------------------
# Word1:  governor
# Word2:  office
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  6.34
# ------------------------------
# Word1:  architecture
# Word2:  century
# Type of similarity chosen:  leakcock_chodorow
# MyCustom Similarity:  1.410986973710262
# WordNet Similarity:  1.3350010667323402
# Human Similarity:  3.78
# ------------------------------
# Pearson Correlation:  [[1.         0.26142012]
#  [0.26142012 1.        ]]
# Spearman Correlation:  SpearmanrResult(correlation=0.2651845536640065, pvalue=4.292887522518468e-07)

# %% [markdown]
# CONSEGNA 2.1:
#
# Estrarre 50 frasi dal corpus SemCor (corpus annotato con i synset di
# WN) e disambiguare (almeno) un sostantivo per frase.
#
# Calcolare
# l’accuratezza del sistema implementato sulla base dei sensi annotati in
# SemCor.

# %%
tokenizer = RegexpTokenizer(r'\w+')

INDEXES_NUM = 1000 #è il limite, partendo da 0, di sentence che possono essere testate relative al database SemCor
RANGE = 50 #è il numero di sentence che effettivamente verranno testate

sentences_tag = semcor.tagged_sents() #lista di liste. Ogni lista rappresenta una sentence e ad ogni parola della sentence è associato un pos tag
sentences = semcor.sents() #lista di liste di parole. Ogni lista rappresenta una sentence
sentences_sem = semcor.tagged_sents(tag = "sem") #lista di liste. Ogni lista rappresenta una sentence e ad ogni parola della sentence è associato un synset gold

def main():
    evaluated = 0 #termini valutati
    checked = 0 #termini valutati correttamente
    index_evaluated = set() #insieme degli indici già valutati
    while(evaluated <= RANGE):
        while True: #fino a quando non trova una word che ha almeno un senso in wordnet   
            index = get_random_index(index_evaluated, INDEXES_NUM)
            word = get_random_noun(get_dictionary_tag(sentences_tag[index],sentences_sem[index]))
            if word:
                break
        sentence = sentences[index]
        print("Parola da disambiguare: ",word)
        #all'algoritmo di lesk viene dato in input la word e l'insieme dei termini che formano la frase, uniti sottoforma di stringa
        best_sense = str(lesk_algorithm(word, ' '.join(word for word in sentence), word_type='NOUN'))
        print("Senso attribuito dall'algoritmo di Lesk: ",best_sense)
        target_lemma = get_synset_target_for_word_in_sentence(word,sentences_sem[index])
        print("Senso Target: ",target_lemma)
        best_sense_lemma = best_sense[8:len(best_sense)-2]
        if target_lemma:
            if best_sense_lemma in target_lemma:
             checked= checked + 1
        evaluated += 1
        print("------------------------------")
    
    print("Termini valutati: ", evaluated)
    print("Termini valutati correttamente: ", checked)
    print("Accuratezza: ", checked/RANGE)
    
main()
# Out:
# Parola da disambiguare:  dozen
# Frase in cui compare la parola:  Palmer 's dozen were honestly earned .
# Contesto della frase:  {'dozen', 'palmer', 'honestly', 'earn'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('twelve.n.01')
# Senso Target:  Lemma('twelve.n.01.dozen')
# ------------------------------
# Parola da disambiguare:  customers
# Frase in cui compare la parola:  Dewey Lawrence , a Tyler lawyer representing the Texas Bankers Association , sounded the opposition keynote when he said it would force banks to violate their contractual obligations with depositors and undermine the confidence of bank customers .
# Contesto della frase:  {'obligation', 'contractual', 'customer', 'undermine', 'bankers', 'dewey', 'bank', 'depositor', 'represent', 'opposition', 'lawyer', 'violate', 'association', 'lawrence', 'force', 'texas', 'confidence', 'tyler', 'keynote', 'sound'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('customer.n.01')
# Senso Target:  Lemma('customer.n.01.customer')
# ------------------------------
# Parola da disambiguare:  lettermen
# Frase in cui compare la parola:  Other lettermen from the team that compiled a 21 - 9 record and finished as runner-up in the National Invitation Tournament were : Art Hambric , Donnell Reid , Bill Nordmann , Dave Harris , Dave Luechtefeld and George Latinovich .
# Contesto della frase:  {'tournament', 'dave', 'donnell', 'nordmann', 'national', 'record', 'bill', 'compile', 'runnerup', 'letterman', 'hambric', 'finish', 'art', 'reid', 'invitation', 'harris', 'team', 'latinovich', 'george', 'luechtefeld'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('letterman.n.01')
# Senso Target:  Lemma('letterman.n.01.letterman')
# ------------------------------
# Parola da disambiguare:  circles
# Frase in cui compare la parola:  He just shot at the board and then drew circles around the holes to form a bull's-eye .
# Contesto della frase:  {'bullseye', 'board', 'shot', 'draw', 'hole', 'form', 'circle'}
# Max Signature:  {'constant', 'generate', 'distance', 'ax', 'equal', 'curve', 'move', 'circumference', 'calculate', 'length', 'ellipse', 'plane', 'point', 'circle'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('circle.n.01')
# Senso Target:  Lemma('circle.n.01.circle')
# ------------------------------
# Parola da disambiguare:  family
# Frase in cui compare la parola:  The report called racial discrimination in employment `` one of the most serious causes of family breakdown , desertion , and ADC dependency '' .
# Contesto della frase:  {'report', 'family', 'call', 'racial', 'desertion', 'adc', 'employment', 'serious', 'breakdown', 'discrimination', 'dependency'}
# Max Signature:  {'household', 'family', 'wait', 'unit', 'social', 'move', 'good', 'asleep', 'christian', 'people', 'virginia', 'teacher', 'house', 'live'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('family.n.01')
# Senso Target:  Lemma('family.n.01.family')
# ------------------------------
# Parola da disambiguare:  children
# Frase in cui compare la parola:  State and federal legislation against racial discrimination in employment was called for yesterday in a report of a `` blue ribbon '' citizens committee on the aid to dependent children program .
# Contesto della frase:  {'program', 'report', 'dependent', 'committee', 'call', 'racial', 'blue', 'citizen', 'child', 'legislation', 'ribbon', 'federal', 'aid', 'employment', 'discrimination', 'yesterday'}
# Max Signature:  {'term', 'sex', 'tiddler', 'young', 'write', 'kid', 'child', 'youngster', 'person', 'british', 'book'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('child.n.01')
# Senso Target:  Lemma('child.n.02.child')
# ------------------------------
# Parola da disambiguare:  mother
# Frase in cui compare la parola:  He senses his mother 's disapproval .
# Contesto della frase:  {'sense', 'mother', 'disapproval'}
# Max Signature:  {'term', 'mother', 'birth', 'woman', 'child', 'address'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('mother.n.01')
# Senso Target:  Lemma('mother.n.01.mother')
# ------------------------------
# Parola da disambiguare:  Tanks
# Frase in cui compare la parola:  Tanks lined up at the border will be no more helpful .
# Contesto della frase:  {'helpful', 'border', 'tanks'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('tank.n.01')
# Senso Target:  Lemma('tank.n.01.tank')
# ------------------------------
# Parola da disambiguare:  teams
# Frase in cui compare la parola:  The owners would like each club in the fourteen team league to play a home and home series with teams in its division , plus two games against teams in the other division .
# Contesto della frase:  {'league', 'play', 'club', 'team', 'division', 'game', 'owner', 'fourteen', 'series'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('team.n.01')
# Senso Target:  Lemma('team.n.01.team')
# ------------------------------
# Parola da disambiguare:  year
# Frase in cui compare la parola:  The Pirates jumped off to an 11 - 3 start by May 1 last year , when the Redbirds as well as the Dodgers held them even over the season .
# Contesto della frase:  {'pirates', 'jump', 'start', 'year', 'redbirds', 'season', 'well', 'dodgers', 'hold'}
# Max Signature:  {'time', 'day', 'period', 'year'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('year.n.01')
# Senso Target:  Lemma('year.n.01.year')
# ------------------------------
# Parola da disambiguare:  Friday
# Frase in cui compare la parola:  The resolution , which Barber tossed into the House hopper Friday , will be formally read Monday .
# Contesto della frase:  {'hopper', 'read', 'resolution', 'house', 'formally', 'barber', 'toss', 'monday', 'friday'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('friday.n.01')
# Senso Target:  Lemma('friday.n.01.Friday')
# ------------------------------
# Parola da disambiguare:  styles
# Frase in cui compare la parola:  In the casual field straws feature wedge heels of cork or carved wood in a variety of styles .
# Contesto della frase:  {'feature', 'cork', 'field', 'casual', 'carve', 'wedge', 'wood', 'variety', 'straws', 'style', 'heel'}
# Max Signature:  {'mode', 'fashion', 'existence', 'nomadic', 'characteristic', 'lonely', 'style', 'manner', 'york', 'life', 'happen', 'rapid', 'dignified', 'talk', 'abrasive'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('manner.n.01')
# Senso Target:  Lemma('style.n.03.style')
# ------------------------------
# Parola da disambiguare:  hearing
# Frase in cui compare la parola:  Daniel personally led the fight for the measure , which he had watered down considerably since its rejection by two previous Legislatures , in a public hearing before the House Committee on Revenue and Taxation .
# Contesto della frase:  {'revenue', 'fight', 'rejection', 'committee', 'house', 'measure', 'taxation', 'previous', 'hearing', 'daniel', 'public', 'water', 'considerably', 'lead', 'personally', 'legislatures'}
# Max Signature:  {'investigative', 'session', 'committee', 'call', 'witness', 'grand', 'chicago', 'hearing', 'jury', 'hold', 'testimony'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('hearing.n.05')
# Senso Target:  Lemma('hearing.n.01.hearing')
# ------------------------------
# Parola da disambiguare:  discontinuity
# Frase in cui compare la parola:  `` Only a discontinuity can end it '' , Professor Morrison writes .
# Contesto della frase:  {'discontinuity', 'professor', 'morrison', 'write'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('discontinuity.n.01')
# Senso Target:  Lemma('discontinuity.n.01.discontinuity')
# ------------------------------
# Parola da disambiguare:  West
# Frase in cui compare la parola:  The weekly loss is partly counterbalanced by 500 arrivals each week from West Germany , but the hard truth , says Crossman , is that `` The closing off of East Berlin without interference from the West and with the use only of East German , as distinct from Russian , troops was a major Communist victory , which dealt West Berlin a deadly , possibly a fatal , blow .
# Contesto della frase:  {'counterbalance', 'german', 'hard', 'west', 'troop', 'fatal', 'crossman', 'week', 'deadly', 'distinct', 'major', 'berlin', 'loss', 'arrival', 'weekly', 'truth', 'interference', 'victory', 'east', 'russian', 'blow', 'closing', 'communist', 'partly', 'deal', 'germany'}
# Max Signature:  {'lie', 'west', 'united', 'region', 'mississippi', 'river'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('west.n.03')
# Senso Target:  Lemma('west.n.01.West')
# ------------------------------
# Parola da disambiguare:  players
# Frase in cui compare la parola:  `` Several times I found the players pepping me up , where it usually is the coach who is supposed to deliver the fight talk .
# Contesto della frase:  {'time', 'find', 'fight', 'coach', 'deliver', 'suppose', 'player', 'pepping', 'talk'}
# Max Signature:  {'set', 'deal', 'business', 'major', 'participant', 'player', 'corporation'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('player.n.05')
# Senso Target:  Lemma('player.n.01.player')
# ------------------------------
# Parola da disambiguare:  high
# Frase in cui compare la parola:  Hansen , who slugged the 1960 Oriole high of 22 homers and drove in 86 runs on a .255 freshman average , completes the Birds ' spring squad at 49 players .
# Contesto della frase:  {'complete', 'drive', 'birds', 'oriole', 'average', 'spring', 'slug', 'hansen', 'squad', 'freshman', 'player', 'high', 'homer'}
# Max Signature:  {'reach', 'degree', 'lofty', 'position', 'temperature', 'alltime', 'high', 'summer', 'level'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('high.n.01')
# Senso Target:  Lemma('high.n.01.high')
# ------------------------------
# Parola da disambiguare:  petition
# Frase in cui compare la parola:  Henry L. Bowden was listed on the petition as the mayor 's attorney .
# Contesto della frase:  {'attorney', 'bowden', 'petition', 'henry', 'mayor', 'list'}
# Max Signature:  {'deity', 'reverent', 'petition'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('prayer.n.02')
# Senso Target:  Lemma('request.n.01.petition')
# ------------------------------
# Parola da disambiguare:  estimate
# Frase in cui compare la parola:  Daniel termed `` extremely conservative '' his estimate that it would produce 17 million dollars to help erase an anticipated deficit of 63 million dollars at the end of the current fiscal year next Aug. 31 .
# Contesto della frase:  {'conservative', 'term', 'current', 'produce', 'dollar', 'aug', 'deficit', 'erase', 'extremely', 'estimate', 'year', 'anticipated', 'daniel', 'help', 'fiscal'}
# Max Signature:  {'quantity', 'calculation', 'rough', 'degree', 'approximate', 'estimate', 'long', 'cost', 'idea', 'worth'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('estimate.n.01')
# Senso Target:  Lemma('estimate.n.01.estimate')
# ------------------------------
# Parola da disambiguare:  letters
# Frase in cui compare la parola:  Thanks to Spoken Arts Records , history buffs may hear Lincoln 's `` most memorable speeches and letters '' in a two disc set , interpreted by Lincoln authority and lecturer Roy P. Basler .
# Contesto della frase:  {'history', 'lincoln', 'memorable', 'letter', 'set', 'lecturer', 'hear', 'spoken', 'speech', 'arts', 'buff', 'records', 'disc', 'interpret', 'basler', 'authority', 'roy'}
# Max Signature:  {'represent', 'grandmother', 'letter', 'character', 'speech', 'conventional', 'alphabet', 'teach'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('letter.n.02')
# Senso Target:  Lemma('letter.n.01.letter')
# ------------------------------
# Parola da disambiguare:  behavior
# Frase in cui compare la parola:  He won't submit to his natural desires all the time , and it 's Mother 's love that is responsible for his good behavior .
# Contesto della frase:  {'time', 'desire', 'mother', 'submit', 'wont', 'good', 'responsible', 'behavior', 'natural', 'love'}
# Max Signature:  {'substance', 'small', 'study', 'particle', 'reaction', 'action', 'circumstance', 'behavior', 'machine', 'experiment'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('behavior.n.02')
# Senso Target:  Lemma('behavior.n.01.behavior')
# ------------------------------
# Parola da disambiguare:  shoes
# Frase in cui compare la parola:  Designed for summer comfort are the shoes illustrated .
# Contesto della frase:  {'shoe', 'designed', 'illustrate', 'comfort', 'summer'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('place.n.06')
# Senso Target:  Lemma('shoe.n.01.shoe')
# ------------------------------
# Parola da disambiguare:  halfback
# Frase in cui compare la parola:  `` He timed it just right and broke through there before the boy ( halfback Terry Isaacson ) had time to turn around .
# Contesto della frase:  {'time', 'halfback', 'boy', 'break', 'isaacson', 'terry', 'turn'}
# Max Signature:  {'play', 'halfback', 'football', 'offensive', 'position'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('halfback.n.01')
# Senso Target:  Lemma('halfback.n.01.halfback')
# ------------------------------
# Parola da disambiguare:  baseball
# Frase in cui compare la parola:  Larry Scherer last night pitched a no-hit game , said to be the first in Billiken baseball history , as the Blue and White beat Southeast Missouri State College , 5 - 1 , at Crystal City .
# Contesto della frase:  {'nohit', 'history', 'southeast', 'missouri', 'larry', 'blue', 'white', 'city', 'baseball', 'college', 'billiken', 'beat', 'crystal', 'night', 'pitch', 'game', 'scherer'}
# Max Signature:  {'play', 'score', 'league', 'area', 'high', 'desire', 'national', 'empty', 'team', 'ball', 'game', 'baseball', 'player', 'bat', 'lot', 'school', 'turn'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('baseball.n.01')
# Senso Target:  Lemma('baseball.n.01.baseball')
# ------------------------------
# Parola da disambiguare:  league
# Frase in cui compare la parola:  Rabb , the former Louisiana State field general , came off the bench for his debut with the Bills Sunday and directed his new team to a 22 - 12 upset victory over the Houston Oilers , defending league champions .
# Contesto della frase:  {'direct', 'league', 'houston', 'bench', 'champion', 'field', 'bills', 'louisiana', 'upset', 'team', 'victory', 'defend', 'rabb', 'oilers', 'general', 'debut', 'sunday'}
# Max Signature:  {'organize', 'match', 'member', 'association', 'sport', 'team'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('league.n.01')
# Senso Target:  Lemma('league.n.01.league')
# ------------------------------
# Parola da disambiguare:  automobile
# Frase in cui compare la parola:  Implementation of Georgia 's automobile title law was also recommended by the outgoing jury .
# Contesto della frase:  {'recommend', 'automobile', 'implementation', 'title', 'law', 'jury', 'georgia', 'outgoing'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('car.n.01')
# Senso Target:  Lemma('car.n.01.automobile')
# ------------------------------
# Parola da disambiguare:  plays
# Frase in cui compare la parola:  A Texas halfback who does n't even know the team 's plays , Eldon Moritz , ranks fourth in Southwest Conference scoring after three games .
# Contesto della frase:  {'play', 'scoring', 'halfback', 'eldon', 'moritz', 'team', 'conference', 'fourth', 'texas', 'southwest', 'game', 'rank', 'nt'}
# Max Signature:  {'play', 'coach', 'draw', 'sport', 'team', 'action', 'preset', 'plan'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('play.n.03')
# Senso Target:  Lemma('play.n.03.play')
# ------------------------------
# Parola da disambiguare:  air
# Frase in cui compare la parola:  He conjures herds of deer , and wild birds crowding the air .
# Contesto della frase:  {'conjure', 'air', 'bird', 'herd', 'deer', 'crowd', 'wild'}
# Max Signature:  {'pollution', 'window', 'air', 'stuff', 'consist', 'require', 'mixture', 'breathe', 'wind', 'fresh', 'open', 'gas', 'smell', 'chemical', 'oxygen'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('air.n.01')
# Senso Target:  Lemma('air.n.02.air')
# ------------------------------
# Parola da disambiguare:  running
# Frase in cui compare la parola:  `` We 'll let him do a lot of running this week , but I do n't know if he 'll be able to play '' .
# Contesto della frase:  {'play', 'week', 'll', 'lot', 'nt'}
# Max Signature:  {'play', 'american', 'attempt', 'defensive', 'football', 'opposing', 'coach', 'great', 'team', 'ball', 'brace', 'emphasis', 'player', 'carry'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('run.n.05')
# Senso Target:  Lemma('run.n.07.running')
# ------------------------------
# Parola da disambiguare:  stocks
# Frase in cui compare la parola:  The other bill , by Sen. A. M. Aikin Jr. of Paris , would relieve real estate brokers , who pay their own annual licensing fee , from the $ 12 annual occupation license on brokers in such as stocks and bonds .
# Contesto della frase:  {'broker', 'aikin', 'bill', 'estate', 'sen', 'jr', 'annual', 'licensing', 'fee', 'real', 'license', 'relieve', 'bond', 'occupation', 'paris', 'pay', 'stock'}
# Max Signature:  {'raise', 'control', 'issue', 'share', 'stock', 'holder', 'ownership', 'equity', 'company', 'entitle', 'capital', 'corporation', 'interest'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('stock.n.01')
# Senso Target:  Lemma('stock.n.01.stock')
# ------------------------------
# Parola da disambiguare:  afternoon
# Frase in cui compare la parola:  If the Orioles are to break their losing streak within the next two days , it will have to be at the expense of the American League champion New York Yankees , who come in here tomorrow for a night game and a single test Sunday afternoon .
# Contesto della frase:  {'american', 'league', 'streak', 'test', 'orioles', 'yankees', 'champion', 'afternoon', 'game', 'break', 'york', 'losing', 'expense', 'day', 'single', 'sunday', 'tomorrow', 'night'}
# Max Signature:  {'spend', 'park', 'quiet', 'noon', 'day', 'afternoon', 'evening'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('afternoon.n.01')
# Senso Target:  Lemma('afternoon.n.01.afternoon')
# ------------------------------
# Parola da disambiguare:  frustrations
# Frase in cui compare la parola:  And it also stayed the hands of thousands of brooding incompetents who were meditating the abandonment of a sport whose frustrations were driving them to despair .
# Contesto della frase:  {'hand', 'incompetent', 'frustration', 'stay', 'drive', 'despair', 'sport', 'abandonment', 'meditate', 'brood'}
# Max Signature:  {'feeling', 'constant', 'frustration', 'annoyance', 'complaint', 'main', 'source', 'hinder', 'criticize'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('frustration.n.03')
# Senso Target:  Lemma('frustration.n.01.frustration')
# ------------------------------
# Parola da disambiguare:  jury
# Frase in cui compare la parola:  On other matters , the jury recommended that :
# Contesto della frase:  {'jury', 'recommend', 'matter'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('jury.n.01')
# Senso Target:  Lemma('jury.n.01.jury')
# ------------------------------
# Parola da disambiguare:  place-kicking
# Frase in cui compare la parola:  A 208 - pound , 6 - foot 1 - inch senior from Stamford , Moritz practices nothing but place-kicking .
# Contesto della frase:  {'placekicking', 'inch', 'pound', 'stamford', 'moritz', 'senior', 'foot', 'practice'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('place_kick.n.01')
# Senso Target:  Lemma('place_kick.n.01.place-kicking')
# ------------------------------
# Parola da disambiguare:  ventures
# Frase in cui compare la parola:  One of those capital-gains ventures , in fact , has saddled him with Gore Court .
# Contesto della frase:  {'court', 'venture', 'saddle', 'fact', 'capitalgains', 'gore'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('venture.n.01')
# Senso Target:  Lemma('speculation.n.03.venture')
# ------------------------------
# Parola da disambiguare:  yard
# Frase in cui compare la parola:  On the narrow fairway of a 508 - yard hole , Arnold whipped into his second shot .
# Contesto della frase:  {'arnold', 'hole', 'fairway', 'narrow', 'yard', 'shot', 'second', 'whip'}
# Max Signature:  {'small', 'land', 'enclosed', 'yard', 'building', 'house'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('yard.n.02')
# Senso Target:  Lemma('yard.n.01.yard')
# ------------------------------
# Parola da disambiguare:  inning
# Frase in cui compare la parola:  Nischwitz fanned six and walked only Charley Hinton in the third inning .
# Contesto della frase:  {'inning', 'walk', 'nischwitz', 'hinton', 'fan', 'charley', 'third'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('inning.n.01')
# Senso Target:  Lemma('inning.n.01.inning')
# ------------------------------
# Parola da disambiguare:  ways
# Frase in cui compare la parola:  From the standpoint of the army of duffers , however , this was easily the most heartening exhibition they had had since Ben Hogan fell upon evil ways during his heyday and scored an 11 in the Texas open .
# Contesto della frase:  {'score', 'duffer', 'standpoint', 'easily', 'evil', 'fell', 'heartening', 'hogan', 'ben', 'heyday', 'army', 'texas', 'open', 'exhibition'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('ways.n.01')
# Senso Target:  Lemma('way.n.05.way')
# ------------------------------
# Parola da disambiguare:  pounds
# Frase in cui compare la parola:  The 6 - foot 3 inch Hansen checked in close to 200 pounds , 15 pounds lighter than his reporting weight last spring .
# Contesto della frase:  {'close', 'inch', 'pound', 'lighter', 'reporting', 'spring', 'hansen', 'check', 'foot', 'weight'}
# Max Signature:  {'hallway', 'pound', 'repeat', 'sudden', 'deliver', 'guard', 'pounding', 'heavy', 'blow', 'catch', 'hammer', 'foot', 'fist'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('hammer.n.08')
# Senso Target:  Lemma('pound.n.01.pound')
# ------------------------------
# Parola da disambiguare:  list
# Frase in cui compare la parola:  Despite the recession , Pittsburgh came into town with this imposing list of averages : Smoky Burgess .455 , Gino Cimoli .389 , Bill Virdon .340 , Bob Clemente and Dick Groat , each .323 , Dick Stuart .306 , Don Hoak .280 and Bob Skinner .267 .
# Contesto della frase:  {'stuart', 'gino', 'don', 'virdon', 'groat', 'town', 'dick', 'skinner', 'bill', 'impose', 'burgess', 'average', 'smoky', 'recession', 'list', 'pittsburgh', 'bob', 'hoak', 'clemente', 'cimoli'}
# Max Signature:  {'inclination', 'ship', 'surface', 'walk', 'starboard', 'possess', 'develop', 'heavy', 'list', 'property', 'depart', 'pronounced', 'vertical', 'tower', 'tilt'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('tilt.n.04')
# Senso Target:  Lemma('list.n.01.list')
# ------------------------------
# Parola da disambiguare:  ball
# Frase in cui compare la parola:  The principal tactic in controlling the ball was giving it to Abner Haynes , the flashy halfback .
# Contesto della frase:  {'abner', 'flashy', 'haynes', 'halfback', 'control', 'ball', 'tactic', 'principal'}
# Max Signature:  {'pocket', 'hit', 'round', 'mph', 'roll', 'mayor', 'corner', 'object', 'ball', 'serve', 'kick', 'travel', 'game', 'throw'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('ball.n.01')
# Senso Target:  Lemma('ball.n.01.ball')
# ------------------------------
# Parola da disambiguare:  drive
# Frase in cui compare la parola:  Momentarily the Reds were back in the ball game , trailing only 6 - 3 , but the drive fizzled when John Edwards fouled out with men on second and third and two out .
# Contesto della frase:  {'john', 'fizzle', 'drive', 'edwards', 'foul', 'trail', 'ball', 'momentarily', 'reds', 'game', 'men', 'second', 'third'}
# Max Signature:  {'driver', 'bound', 'tee', 'hit', 'drive', 'slice', 'ball', 'golf'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('drive.n.06')
# Senso Target:  Lemma('campaign.n.02.drive')
# ------------------------------
# Parola da disambiguare:  thing
# Frase in cui compare la parola:  And of course Larkin has just the thing they want .
# Contesto della frase:  {'larkin', 'thing', 'course'}
# Max Signature:  {'situation', 'special', 'thing', 'remarkable'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('thing.n.01')
# Senso Target:  Lemma('thing.n.04.thing')
# ------------------------------
# Parola da disambiguare:  season
# Frase in cui compare la parola:  An injury forced Skorich to quit after the 1948 season .
# Contesto della frase:  {'skorich', 'injury', 'quit', 'force', 'season'}
# Max Signature:  {'period', 'field', 'celebrate', 'event', 'avocado', 'year', 'special', 'mark', 'ballet', 'season', 'company', 'forward', 'activity'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('season.n.01')
# Senso Target:  Lemma('season.n.01.season')
# ------------------------------
# Parola da disambiguare:  gifts
# Frase in cui compare la parola:  Money for its construction will be sought later on but in the meantime the State Hospital board can accept gifts and donations of a site .
# Contesto della frase:  {'accept', 'seek', 'site', 'donation', 'board', 'gift', 'hospital', 'construction', 'money'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('gift.n.01')
# Senso Target:  Lemma('gift.n.01.gift')
# ------------------------------
# Parola da disambiguare:  bill
# Frase in cui compare la parola:  There was no debate as the Senate passed the bill on to the House .
# Contesto della frase:  {'senate', 'pass', 'bill', 'house', 'debate'}
# Max Signature:  {'statute', 'bill', 'draft', 'hearing', 'law', 'hold', 'public'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('bill.n.01')
# Senso Target:  Lemma('bill.n.01.bill')
# ------------------------------
# Parola da disambiguare:  minutes
# Frase in cui compare la parola:  The Union Pacific Railroad streamliner , City of San Francisco , stopped in Ogden , Utah , for a few minutes .
# Contesto della frase:  {'ogden', 'francisco', 'utah', 'streamliner', 'city', 'union', 'san', 'minute', 'pacific', 'railroad'}
# Max Signature:  {'time', 'unit', 'equal', 'minute', 'mile', 'hour', 'second'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('minute.n.01')
# Senso Target:  Lemma('minute.n.01.minute')
# ------------------------------
# Parola da disambiguare:  yarder
# Frase in cui compare la parola:  It happened on the twelfth hole , a 155 - yarder .
# Contesto della frase:  {'twelfth', 'happen', 'yarder', 'hole'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('yarder.n.01')
# Senso Target:  yarder.n.00
# ------------------------------
# Parola da disambiguare:  airport
# Frase in cui compare la parola:  Regarding Atlanta 's new million dollar airport , the jury recommended `` that when the new management takes charge Jan. 1 the airport be operated in a manner that will eliminate political influences '' .
# Contesto della frase:  {'airport', 'recommend', 'dollar', 'political', 'charge', 'atlanta', 'management', 'manner', 'influence', 'jury', 'eliminate', 'jan', 'operate'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('airport.n.01')
# Senso Target:  Lemma('airport.n.01.airport')
# ------------------------------
# Parola da disambiguare:  staff
# Frase in cui compare la parola:  The Eagles signed him for Shaw 's staff in 1959 .
# Contesto della frase:  {'staff', 'sign', 'eagles', 'shaw'}
# Max Signature:  {'general', 'task', 'decision', 'excellent', 'routine', 'personnel', 'superior', 'hospital', 'nursing', 'assist', 'assigned', 'carry', 'staff', 'rely'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('staff.n.01')
# Senso Target:  Lemma('staff.n.01.staff')
# ------------------------------
# Parola da disambiguare:  residents
# Frase in cui compare la parola:  Nearly 18 per cent of West Berlin 's 2200000 residents are sixty-five or older , only 12.8 per cent are under fifteen .
# Contesto della frase:  {'cent', 'sixtyfive', 'west', 'berlin', 'fifteen', 'resident'}
# Max Signature:  {'physician', 'patient', 'clinical', 'hospitalized', 'care', 'medical', 'hospital', 'live', 'special', 'training', 'receive', 'staff', 'resident', 'intern', 'supervision'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('house_physician.n.01')
# Senso Target:  Lemma('resident.n.01.resident')
# ------------------------------
# Termini valutati:  51
# Termini valutati correttamente:  30
# Accuratezza:  0.6

# %% [markdown]
# CONSEGNA 2.2:
#
# Randomizzare la selezione delle 50 frasi e la selezione del termine da
# disambiguare, e restituire l’accuratezza media su (per esempio) 10
# esecuzioni del programma.

# %%
tokenizer = RegexpTokenizer(r'\w+')

EXECUTIONS = 10 #numero massimo di esecuzioni
INDEXES_NUM = 7000 #è il limite, partendo da 0, di sentence che possono essere testate relative al database SemCor
RANGE = 50 #è il numero di sentence che effettivamente verranno testate in ogni esecuzione        

sentences_tag = semcor.tagged_sents()
sentences = semcor.sents()
sentences_sem = semcor.tagged_sents(tag = "sem")

def main():
    accuracy_list = []
    for execution in range(1,EXECUTIONS + 1):
        evaluated = 0 #termini valutati
        checked = 0 #termini valutati correttamente
        index_evaluated = set() #insieme degli indici già valutati
        while(evaluated <= RANGE):
            while True: #fino a quando non trova una word che può essere presa in considerazione  
                index = get_random_index(index_evaluated, INDEXES_NUM)
                word = get_random_word(get_dictionary_tag(sentences_tag[index],sentences_sem[index]))
                if word:
                    break
            sentence = sentences[index]
            print("Parola da disambiguare: ",word)
            #all'algoritmo di lesk viene dato in input la word e l'insieme dei termini che formano la frase, uniti sottoforma di stringa
            best_sense = str(lesk_algorithm(word, ' '.join(word for word in sentence), word_type='ALL'))
            print("Senso attribuito dall'algoritmo di Lesk: ",best_sense)
            target_lemma = get_synset_target_for_word_in_sentence(word,sentences_sem[index])
            print("Senso Target: ",target_lemma)
            best_sense_lemma = best_sense[8:len(best_sense)-2]
            if target_lemma:
                if best_sense_lemma in target_lemma:
                 checked= checked + 1
            evaluated += 1
            print("------------------------------")
        
        print("Termini valutati: ", evaluated)
        print("Termini valutati correttamente: ", checked)
        accuracy = checked/RANGE
        print("Accuratezza: ", accuracy)
        accuracy_list.append(accuracy)
        
    print()
    print("Esecuzioni: ",EXECUTIONS)
    print("Lista delle accuratezze: ", accuracy_list)
    print("Accuratezza media: ",mean(accuracy_list))
    
main()
# Out:
# Parola da disambiguare:  clinical
# Frase in cui compare la parola:  These are few and seemingly disjointed data , but they illustrate the important fact that fundamental alterations in conditioned reactions occur in a variety of states in which the hypothalamic balance has been altered by physiological experimentation , pharmacological action , or clinical processes .
# Contesto della frase:  {'fundamental', 'clinical', 'illustrate', 'balance', 'disjoint', 'physiological', 'alteration', 'seemingly', 'action', 'variety', 'conditioned', 'fact', 'pharmacological', 'data', 'experimentation', 'occur', 'reaction', 'hypothalamic', 'alter', 'process'}
# Max Signature:  {'direct', 'patient', 'conduct', 'observation', 'clinic', 'study', 'clinical', 'depend', 'case', 'relate'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('clinical.a.01')
# Senso Target:  Lemma('clinical.a.01.clinical')
# ------------------------------
# Parola da disambiguare:  gospel
# Frase in cui compare la parola:  This is not to say that the only explanation of the present infatuation with Norman Vincent Peale 's `` cult of reassurance '' or the other types of a purely cultural Christianity is the ever-present need for a demythologized gospel .
# Contesto della frase:  {'type', 'christianity', 'explanation', 'cult', 'demythologized', 'gospel', 'norman', 'vincent', 'reassurance', 'everpresent', 'peale', 'infatuation', 'cultural', 'purely'}
# Max Signature:  {'unquestionable', 'gospel', 'truth', 'word'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('gospel.n.02')
# Senso Target:  Lemma('gospel.n.01.Gospel')
# ------------------------------
# Parola da disambiguare:  brains
# Frase in cui compare la parola:  I did n't offer any advice , but I certainly did not want to go back to where the officer lay with his brains dashed out .
# Contesto della frase:  {'brain', 'lay', 'offer', 'dash', 'officer', 'advice', 'nt'}
# Max Signature:  {'brain', 'ability', 'plenty', 'mental', 'sense', 'common'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('brain.n.02')
# Senso Target:  Lemma('brain.n.01.brain')
# ------------------------------
# Parola da disambiguare:  paste
# Frase in cui compare la parola:  There is a small well in the top in which the fluid or paste to be tested is placed .
# Contesto della frase:  {'place', 'small', 'test', 'fluid', 'well', 'paste', 'top'}
# Max Signature:  {'text', 'sentence', 'sign', 'wall', 'paste', 'attach', 'cut', 'join', 'glue'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('glue.v.01')
# Senso Target:  Lemma('paste.n.01.paste')
# ------------------------------
# Parola da disambiguare:  speaker
# Frase in cui compare la parola:  The next speaker was George T. Day .
# Contesto della frase:  {'george', 'speaker', 'day'}
# Max Signature:  {'language', 'commencement', 'maxim', 'express', 'speech', 'deliver', 'speaker', 'utterer', 'public', 'garrulous', 'talk'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('speaker.n.01')
# Senso Target:  Lemma('speaker.n.01.speaker')
# ------------------------------
# Parola da disambiguare:  fear
# Frase in cui compare la parola:  Small wonder , then , that we fear .
# Contesto della frase:  {'fear', 'wonder', 'small'}
# Max Signature:  {'age', 'feeling', 'reaction', 'care', 'fear', 'hush', 'public', 'anxious'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('concern.n.02')
# Senso Target:  Lemma('fear.v.01.fear')
# ------------------------------
# Parola da disambiguare:  washing
# Frase in cui compare la parola:  The purpose of washing is , obviously , to remove soils which are arbitrarily classed in the four major categories given below :
# Contesto della frase:  {'class', 'wash', 'arbitrarily', 'remove', 'soil', 'major', 'category', 'purpose'}
# Max Signature:  {'nurse', 'wash', 'soap', 'coat', 'cleaning', 'agent', 'blood', 'window', 'remove', 'stain', 'application', 'manage', 'dirt', 'spot', 'water', 'liquid'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('wash.v.09')
# Senso Target:  Lemma('wash.n.02.washing')
# ------------------------------
# Parola da disambiguare:  Call
# Frase in cui compare la parola:  Yet how might he know the Call when it came ?
# Contesto della frase:  {'call'}
# Max Signature:  {'place', 'report', 'connection', 'phone', 'hear', 'call', 'ring', 'telephone', 'anonymous', 'london', 'didnt'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('call.n.01')
# Senso Target:  Lemma('call.n.02.Call')
# ------------------------------
# Parola da disambiguare:  work
# Frase in cui compare la parola:  The opposition to this point of view has its staunchest support in the work of Miller ( ' 50 ) .
# Contesto della frase:  {'opposition', 'work', 'staunch', 'view', 'miller', 'support', 'point'}
# Max Signature:  {'direct', 'work', 'check', 'point', 'activity'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('work.n.01')
# Senso Target:  Lemma('work.n.02.work')
# ------------------------------
# Parola da disambiguare:  institutionalized
# Frase in cui compare la parola:  She suffered a nervous breakdown and had to be institutionalized .
# Contesto della frase:  {'suffer', 'nervous', 'breakdown', 'institutionalize'}
# Max Signature:  {'place', 'officially', 'juvenile', 'specialized', 'rehabilitate', 'institutionalize', 'commit', 'hope', 'delinquent', 'institution'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('institutionalized.a.01')
# Senso Target:  Lemma('commit.v.03.institutionalize')
# ------------------------------
# Parola da disambiguare:  Hand
# Frase in cui compare la parola:  The lower portion necessitates only films of Hand .
# Contesto della frase:  {'hand', 'film', 'necessitate', 'portion', 'low'}
# Max Signature:  {'extremity', 'hand', 'mitt', 'limb', 'prehensile', 'superior', 'extend', 'surgeon'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('hand.n.01')
# Senso Target:  Lemma('hand.n.01.hand')
# ------------------------------
# Parola da disambiguare:  spread
# Frase in cui compare la parola:  Measurements at 3.15 cm were obtained on 11 days spread over the interval May 3 to June 19 , 1956 , using the 50 - foot reflector at the U.S. Naval Research Laboratory in Washington .
# Contesto della frase:  {'june', 'reflector', 'laboratory', 'cm', 'measurements', 'naval', 'interval', 'spread', 'washington', 'day', 'foot'}
# Max Signature:  {'income', 'gap', 'outgo', 'conspicuous', 'figure', 'spread', 'cost', 'borrowing', 'lending', 'disparity', 'difference'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('gap.n.01')
# Senso Target:  Lemma('spread.v.01.spread')
# ------------------------------
# Parola da disambiguare:  listener
# Frase in cui compare la parola:  The home listener is overpowered , all right , but the experience is a far from pleasant one .
# Contesto della frase:  {'overpower', 'listener', 'pleasant', 'experience'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('hearer.n.01')
# Senso Target:  Lemma('hearer.n.01.listener')
# ------------------------------
# Parola da disambiguare:  southpaw
# Frase in cui compare la parola:  But there surely can be no doubt about the slender southpaw belonging with the all time great lefthanders in the game 's history .
# Contesto della frase:  {'belong', 'time', 'history', 'slender', 'doubt', 'southpaw', 'great', 'lefthander', 'surely', 'game'}
# Max Signature:  {'hand', 'pitcher', 'southpaw', 'left', 'great', 'skill', 'person'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('left-hander.n.02')
# Senso Target:  Lemma('left-handed_pitcher.n.01.southpaw')
# ------------------------------
# Parola da disambiguare:  Russia
# Frase in cui compare la parola:  Splendid , too , is the performance of Yuri Tolubeyev , one of Russia 's leading comedians , as Sancho Panza , the fat , grotesque `` squire '' .
# Contesto della frase:  {'tolubeyev', 'splendid', 'panza', 'comedian', 'russia', 'grotesque', 'sancho', 'squire', 'lead', 'yuri', 'fat', 'performance'}
# Max Signature:  {'officially', 'northern', 'ukraine', 'eastern', 'communist', 'soviet', 'dissolve', 'europe', 'republic', 'asia', 'country', 'russia', 'socialist', 'establish', 'include', 'byelorussia', 'december'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('soviet_union.n.01')
# Senso Target:  Lemma('soviet_union.n.01.Russia')
# ------------------------------
# Parola da disambiguare:  centers
# Frase in cui compare la parola:  Although the standard deviation values on which spread of the lines are based are relatively larger for those centers which begin to ossify early ( Table 1 ) , there are considerable differences in this value between centers having the closely timed Onsets .
# Contesto della frase:  {'early', 'center', 'closely', 'ossify', 'large', 'spread', 'table', 'deviation', 'onsets', 'timed', 'base', 'difference', 'considerable', 'standard'}
# Max Signature:  {'area', 'center', 'eye', 'struggle', 'large', 'central', 'storm', 'region', 'heart', 'town', 'forward'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('center.n.01')
# Senso Target:  Lemma('center.n.01.center')
# ------------------------------
# Parola da disambiguare:  feelings
# Frase in cui compare la parola:  Furthermore , he 's something of a scoundrel , an artist whose mind and feelings are all finger-tips .
# Contesto della frase:  {'artist', 'feeling', 'scoundrel', 'fingertip', 'mind'}
# Max Signature:  {'feeling', 'hurt', 'remark', 'sensitivity', 'emotional', 'principle', 'dignity', 'moral', 'personal', 'relation'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('feelings.n.01')
# Senso Target:  Lemma('feeling.n.01.feeling')
# ------------------------------
# Parola da disambiguare:  probe
# Frase in cui compare la parola:  Observations of the radio emission of a planet which has an extensive atmosphere will probe the atmosphere to a greater extent than those using shorter wave lengths and should in some cases give otherwise unobtainable information about the characteristics of the solid surface .
# Contesto della frase:  {'atmosphere', 'radio', 'unobtainable', 'surface', 'extensive', 'characteristic', 'great', 'short', 'wave', 'emission', 'solid', 'planet', 'length', 'case', 'extent', 'probe', 'observations'}
# Max Signature:  {'questionable', 'congressional', 'probe', 'unfamiliar', 'scandal', 'activity', 'inquiry'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('probe.n.01')
# Senso Target:  Lemma('probe.v.01.probe')
# ------------------------------
# Parola da disambiguare:  sense
# Frase in cui compare la parola:  The capacity of intellectuals and members of the new professional classes to contribute creatively to national development is likely to be destroyed by a constraining sense of inferiority toward both their own political class and their colleagues and professional counterparts in the West .
# Contesto della frase:  {'development', 'national', 'member', 'creatively', 'west', 'capacity', 'constrain', 'inferiority', 'counterpart', 'colleague', 'contribute', 'intellectual', 'sense', 'destroy', 'class', 'professional', 'political'}
# Max Signature:  {'awareness', 'happiness', 'conscious', 'sense', 'danger', 'general', 'security'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('sense.n.01')
# Senso Target:  sense.n.00
# ------------------------------
# Parola da disambiguare:  invented
# Frase in cui compare la parola:  He had a mean , unbroken sheer bastard in his outfit , and someone invented the name Trig for him .
# Contesto della frase:  {'trig', 'invent', 'sheer', 'bastard', 'outfit', 'unbroken'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('invent.v.01')
# Senso Target:  Lemma('invent.v.01.invent')
# ------------------------------
# Parola da disambiguare:  fall
# Frase in cui compare la parola:  Irenaeus does not claim pre-existence for the human soul ; therefore there is no need for him , as there is for Origen , to identify existence itself with the fall .
# Contesto della frase:  {'claim', 'existence', 'human', 'origen', 'preexistence', 'identify', 'irenaeus', 'fall', 'soul'}
# Max Signature:  {'fall', 'season', 'tree', 'leaf'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('fall.n.01')
# Senso Target:  Lemma('fall.n.03.Fall')
# ------------------------------
# Parola da disambiguare:  life
# Frase in cui compare la parola:  Another reason gymnastic study is valuable is that it can be started very early in life .
# Contesto della frase:  {'early', 'study', 'reason', 'start', 'valuable', 'gymnastic', 'life'}
# Max Signature:  {'real', 'city', 'social', 'characteristic', 'living', 'life', 'mode'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('life.n.01')
# Senso Target:  Lemma('life.n.03.life')
# ------------------------------
# Parola da disambiguare:  practice
# Frase in cui compare la parola:  He did this by the charming practice of buying up used electric blankets for $ 5 to $ 10 from survivors of patients who had died , reconditioning them , and selling them at $ 185 each .
# Contesto della frase:  {'patient', 'buy', 'die', 'survivor', 'sell', 'blanket', 'electric', 'practice', 'charming', 'recondition'}
# Max Signature:  {'customary', 'raise', 'pattern', 'operation', 'annual', 'change', 'behavior', 'dietary', 'practice'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('practice.n.01')
# Senso Target:  Lemma('practice.n.04.practice')
# ------------------------------
# Parola da disambiguare:  period
# Frase in cui compare la parola:  While it must be said that these same Protestants have built some new churches during this period , and that religious population shifts have emptied churches , a principal reason for this phenomenon of redundancy is that fewer Protestants are going to church .
# Contesto della frase:  {'population', 'period', 'protestants', 'reason', 'church', 'empty', 'religious', 'shift', 'principal', 'phenomenon', 'build', 'redundancy'}
# Max Signature:  {'time', 'period', 'blue', 'year', 'recovery', 'hasten', 'picassos', 'amount'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('time_period.n.01')
# Senso Target:  Lemma('time_period.n.01.period')
# ------------------------------
# Parola da disambiguare:  received
# Frase in cui compare la parola:  Skorich received a three year contract at a salary believed to be between $ 20000 and $ 25000 a year .
# Contesto della frase:  {'skorich', 'contract', 'salary', 'year', 'receive'}
# Max Signature:  {'prison', 'punishment', 'year', 'receive', 'retribution'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('get.v.25')
# Senso Target:  Lemma('receive.v.01.receive')
# ------------------------------
# Parola da disambiguare:  observed
# Frase in cui compare la parola:  At times , clumps of 10 to 15 closely packed nuclei were also observed .
# Contesto della frase:  {'nucleus', 'time', 'closely', 'packed', 'observe', 'clump'}
# Max Signature:  {'time', 'fine', 'mention', 'note', 'observe', 'sailing', 'day', 'presentation'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('note.v.01')
# Senso Target:  Lemma('detect.v.01.observe')
# ------------------------------
# Parola da disambiguare:  family
# Frase in cui compare la parola:  Parents should be informed about this system and encouraged to do the same with the whole family at home .
# Contesto della frase:  {'system', 'inform', 'family', 'encourage', 'parents'}
# Max Signature:  {'household', 'family', 'wait', 'unit', 'social', 'move', 'good', 'asleep', 'christian', 'people', 'virginia', 'teacher', 'house', 'live'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('family.n.01')
# Senso Target:  Lemma('family.n.02.family')
# ------------------------------
# Parola da disambiguare:  hate
# Frase in cui compare la parola:  The word also made him feel hate , sincere hate , for those so labeled .
# Contesto della frase:  {'hate', 'label', 'sincere', 'feel', 'word'}
# Max Signature:  {'aversion', 'dislike', 'politician', 'hate', 'mexican', 'food', 'detest', 'feel', 'antipathy', 'intensely'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('hate.v.01')
# Senso Target:  Lemma('hate.n.01.hate')
# ------------------------------
# Parola da disambiguare:  observed
# Frase in cui compare la parola:  In the relatively short time since these early observations , Venus has been observed at additional wave lengths in the range from 0.8 to 10.2 cm , and Jupiter has been observed over the wave-length range from 3.03 to 68 cm .
# Contesto della frase:  {'early', 'time', 'observation', 'cm', 'short', 'wave', 'length', 'range', 'observe', 'jupiter', 'venus', 'additional', 'wavelength'}
# Max Signature:  {'time', 'fine', 'mention', 'note', 'observe', 'sailing', 'day', 'presentation'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('note.v.01')
# Senso Target:  Lemma('detect.v.01.observe')
# ------------------------------
# Parola da disambiguare:  dreaming
# Frase in cui compare la parola:  What if it came when he was playing , or was asleep and dreaming ?
# Contesto della frase:  {'play', 'asleep', 'dream'}
# Max Signature:  {'thought', 'dream', 'imaginative', 'reality', 'awake', 'indulge', 'live'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('dream.n.02')
# Senso Target:  Lemma('dream.v.02.dream')
# ------------------------------
# Parola da disambiguare:  changes
# Frase in cui compare la parola:  Since the apparatus is new , it requires experimentation and changes in technique .
# Contesto della frase:  {'technique', 'experimentation', 'require', 'apparatus', 'change'}
# Max Signature:  {'worse', 'phase', 'intend', 'occur', 'pass', 'visit', 'event', 'storm', 'year', 'undergone', 'increase', 'change', 'ago', 'neighborhood', 'modification', 'sale'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('change.n.01')
# Senso Target:  Lemma('change.n.03.change')
# ------------------------------
# Parola da disambiguare:  refuses
# Frase in cui compare la parola:  The largest of these organizations at present denies to the full time educator any vote on the conduct and standards of the group and , indeed , refuses him even the right to attach the customary initials after his name in the college catalog .
# Contesto della frase:  {'time', 'conduct', 'customary', 'group', 'vote', 'large', 'refuse', 'full', 'catalog', 'educator', 'initial', 'college', 'denies', 'attach', 'organization', 'standard'}
# Max Signature:  {'group', 'decline', 'unwillingness', 'hike', 'join'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('refuse.v.01')
# Senso Target:  Lemma('deny.v.04.refuse')
# ------------------------------
# Parola da disambiguare:  completed
# Frase in cui compare la parola:  Now when Henri has completed four complete Push-Pull Super-Sets No. 1 , the professor allows him about a five minute rest period before starting him on four complete Push-Pull Super-Sets No. 2 .
# Contesto della frase:  {'henri', 'complete', 'period', 'pushpull', 'start', 'professor', 'allow', 'minute', 'rest', 'supersets'}
# Max Signature:  {'bring', 'masters', 'complete', 'dish', 'degree', 'race', 'runner', 'finish', 'requirement', 'hour', 'fast'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('complete.v.01')
# Senso Target:  Lemma('complete.v.01.complete')
# ------------------------------
# Parola da disambiguare:  consistency
# Frase in cui compare la parola:  The improvement was most noticeable in the greater consistency among reaction cells prepared as a group on the same manifold .
# Contesto della frase:  {'noticeable', 'group', 'manifold', 'reaction', 'prepare', 'great', 'improvement', 'cell', 'consistency'}
# Max Signature:  {'wool', 'rayon', 'bake', 'dough', 'shape', 'ready', 'property', 'hold', 'retain', 'body', 'consistency'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('consistency.n.01')
# Senso Target:  Lemma('consistency.n.02.consistency')
# ------------------------------
# Parola da disambiguare:  tail
# Frase in cui compare la parola:  What is interesting is that his positive qualifications for the post were revealed only as a kind of tail to his candidacy .
# Contesto della frase:  {'positive', 'candidacy', 'post', 'tail', 'reveal', 'kind', 'qualification', 'interest'}
# Max Signature:  {'time', 'crisisridden', 'fag', 'century', 'tail', 'storm'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('fag_end.n.01')
# Senso Target:  Lemma('fag_end.n.01.tail')
# ------------------------------
# Parola da disambiguare:  worse
# Frase in cui compare la parola:  Professionally a lawyer , that is to say associated with dignity , reserve , discipline , with much that is essentially middle-class , he is compelled by an impossible love to exhibit himself dressed up , disguised - that is , paradoxically , revealed - as a child , and , worse , as a whore masquerading as a child .
# Contesto della frase:  {'dress', 'exhibit', 'dignity', 'associate', 'essentially', 'paradoxically', 'compel', 'reveal', 'impossible', 'whore', 'love', 'lawyer', 'discipline', 'child', 'masquerading', 'worse', 'professionally', 'reserve', 'disguised', 'middleclass'}
# Max Signature:  {'worse', 'exam', 'ill', 'second', 'desirable', 'manner', 'successful', 'comparative', 'effective'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('worse.r.01')
# Senso Target:  Lemma('worse.a.01.worse')
# ------------------------------
# Parola da disambiguare:  strained
# Frase in cui compare la parola:  They strained forward .
# Contesto della frase:  {'forward', 'strain'}
# Max Signature:  {'hear', 'ear', 'effort', 'energy', 'exert', 'strain'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('strive.v.02')
# Senso Target:  Lemma('strain.v.03.strain')
# ------------------------------
# Parola da disambiguare:  special
# Frase in cui compare la parola:  The bill is designed to provide special schooling for more deaf students in the scholastic age at a reduced cost to the state .
# Contesto della frase:  {'age', 'provide', 'bill', 'student', 'scholastic', 'special', 'cost', 'deaf', 'reduced', 'design', 'school'}
# Max Signature:  {'price', 'feature', 'offering', 'temporary', 'chop', 'special', 'pork', 'advertising', 'reduced'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('special.n.01')
# Senso Target:  Lemma('special.s.02.special')
# ------------------------------
# Parola da disambiguare:  Direct
# Frase in cui compare la parola:  Direct proportionality of the rate to the incident intensity has also been assumed in obtaining the value in the last column for the fourth sample of series /2 , where the light intensity was reduced by use of a screen .
# Contesto della frase:  {'direct', 'intensity', 'screen', 'light', 'incident', 'sample', 'column', 'reduce', 'proportionality', 'fourth', 'rate', 'assume', 'series'}
# Max Signature:  {'direct', 'homework', 'child', 'command', 'authority'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('direct.v.01')
# Senso Target:  Lemma('direct.a.01.direct')
# ------------------------------
# Parola da disambiguare:  financially
# Frase in cui compare la parola:  The large land areas required for oxidation ponds made this type of treatment financially unattractive to the developer .
# Contesto della frase:  {'area', 'treatment', 'type', 'financially', 'land', 'large', 'require', 'unattractive', 'oxidation', 'developer', 'pond'}
# Max Signature:  {'financially', 'view', 'unattractive', 'point', 'financial'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('financially.r.01')
# Senso Target:  Lemma('financially.r.01.financially')
# ------------------------------
# Parola da disambiguare:  engaged
# Frase in cui compare la parola:  The electoral procedure prevented the ready identification of party affiliation , but all vitally interested parties , including the government itself , were busily engaged in determining the party identifications of all successful candidates the month following the elections .
# Contesto della frase:  {'government', 'candidate', 'engage', 'vitally', 'procedure', 'affiliation', 'include', 'party', 'election', 'determine', 'interested', 'ready', 'identification', 'successful', 'prevent', 'month', 'follow', 'electoral', 'busily'}
# Max Signature:  {'activity', 'discussion', 'participate', 'pursue', 'engage', 'carry', 'involve'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('prosecute.v.03')
# Senso Target:  Lemma('prosecute.v.03.engage')
# ------------------------------
# Parola da disambiguare:  writes
# Frase in cui compare la parola:  writes : Does numbness in the left hand at night , which awakens the person , indicate brain tumor ?
# Contesto della frase:  {'hand', 'brain', 'indicate', 'person', 'tumor', 'left', 'writes', 'night', 'awaken', 'numbness'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('write.v.01')
# Senso Target:  Lemma('write.v.05.write')
# ------------------------------
# Parola da disambiguare:  hastened
# Frase in cui compare la parola:  The evidence shows that fake therapeutic machines , substituted for valid medical cures , have hastened the deaths of thousands .
# Contesto della frase:  {'fake', 'medical', 'hasten', 'cure', 'therapeutic', 'valid', 'machine', 'evidence', 'death', 'substitute'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('rush.v.04')
# Senso Target:  Lemma('induce.v.03.hasten')
# ------------------------------
# Parola da disambiguare:  sized
# Frase in cui compare la parola:  In criticism of the latter 's views , his conclusions were based upon dog lung injection studies in which all of the vascular channels were first filled with a solution under pressure and then were injected with various sized colored particles designed to stop at the arteriolar level .
# Contesto della frase:  {'inject', 'study', 'fill', 'base', 'pressure', 'particle', 'lung', 'injection', 'arteriolar', 'size', 'solution', 'design', 'dog', 'conclusion', 'view', 'channel', 'colored', 'criticism', 'vascular', 'level'}
# Max Signature:  {'substance', 'porous', 'stiffen', 'size', 'glutinous', 'material', 'cover', 'glaze'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('size.v.01')
# Senso Target:  Lemma('sized.a.01.sized')
# ------------------------------
# Parola da disambiguare:  Increasing
# Frase in cui compare la parola:  Increasing threats on his life finally convinced Cook that he should leave New Mexico .
# Contesto della frase:  {'cook', 'convince', 'finally', 'life', 'increasing', 'mexico', 'threat', 'leave'}
# Max Signature:  {'bos', 'admit', 'number', 'salary', 'student', 'increase', 'university', 'finally', 'big'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('increase.v.02')
# Senso Target:  Lemma('increasing.a.01.increasing')
# ------------------------------
# Parola da disambiguare:  today
# Frase in cui compare la parola:  Skorich began his new job auspiciously today .
# Contesto della frase:  {'auspiciously', 'today', 'skorich', 'job'}
# Max Signature:  {'time', 'today', 'age', 'computer'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('today.n.01')
# Senso Target:  Lemma('today.n.02.today')
# ------------------------------
# Parola da disambiguare:  school
# Frase in cui compare la parola:  Scotty did not go back to school .
# Contesto della frase:  {'scotty', 'school'}
# Max Signature:  {'educational', 'school', 'institution'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('school.n.01')
# Senso Target:  Lemma('school.n.02.school')
# ------------------------------
# Parola da disambiguare:  Weekly
# Frase in cui compare la parola:  Weekly samples would make any changes more readily discernible than daily samples .
# Contesto della frase:  {'weekly', 'discernible', 'sample', 'change', 'daily'}
# Max Signature:  {'weekly', 'occur', 'visit', 'paper', 'day'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('weekly.s.01')
# Senso Target:  weekly.a.00
# ------------------------------
# Parola da disambiguare:  calculated
# Frase in cui compare la parola:  De Jager ( 1955 ) has calculated the times required for these particles to reach the atmosphere under the influence of the Poynting-Robertson effect , which in this case causes the orbits to become more and more eccentric without changing the semi major axis .
# Contesto della frase:  {'atmosphere', 'time', 'poyntingrobertson', 'reach', 'eccentric', 'particle', 'require', 'orbit', 'jager', 'semi', 'major', 'de', 'change', 'influence', 'case', 'axis', 'calculate'}
# Max Signature:  {'confidence', 'time', 'family', 'faith', 'count', 'depend', 'crisis', 'bet', 'support', 'help', 'friend'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('count.v.08')
# Senso Target:  Lemma('calculate.v.01.calculate')
# ------------------------------
# Parola da disambiguare:  lower
# Frase in cui compare la parola:  The lower portion provides a rating at any stage between infancy and adulthood .
# Contesto della frase:  {'provide', 'rating', 'infancy', 'portion', 'stage', 'low', 'adulthood'}
# Max Signature:  {'set', 'rating', 'expectation', 'low'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('lower.v.02')
# Senso Target:  lower.s.00
# ------------------------------
# Parola da disambiguare:  detected
# Frase in cui compare la parola:  This was particularly noticeable in group A and group B sera , in which cases activity in Regions 1 and 2 was usually not detectable without prior concentration and occasionally could not be detected at all .
# Contesto della frase:  {'prior', 'noticeable', 'group', 'detect', 'concentration', 'case', 'regions', 'detectable', 'activity', 'serum', 'occasionally'}
# Max Signature:  {'presence', 'find', 'discover', 'existence', 'detect', 'fact', 'drinking', 'determine', 'paint', 'trace', 'water', 'high', 'lead', 'level'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('detect.v.01')
# Senso Target:  Lemma('detect.v.01.detect')
# ------------------------------
# Termini valutati:  51
# Termini valutati correttamente:  13
# Accuratezza:  0.26
# Parola da disambiguare:  spirit
# Frase in cui compare la parola:  One characteristic of the spirit in community is its givenness .
# Contesto della frase:  {'givenness', 'community', 'characteristic', 'spirit'}
# Max Signature:  {'opinion', 'pleasure', 'emotion', 'depend', 'regard', 'emotional', 'dejection', 'rise', 'spirit', 'good', 'person'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('emotional_state.n.01')
# Senso Target:  spirit.n.1;2
# ------------------------------
# Parola da disambiguare:  brought
# Frase in cui compare la parola:  The commotion had brought her into the wings .
# Contesto della frase:  {'commotion', 'wing', 'bring'}
# Max Signature:  {'bring', 'letter', 'bos', 'box', 'main', 'point', 'room'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('bring.v.01')
# Senso Target:  Lemma('bring.v.01.bring')
# ------------------------------
# Parola da disambiguare:  toes
# Frase in cui compare la parola:  Keep the legs straight and the toes pointed .
# Contesto della frase:  {'toe', 'legs', 'point', 'straight'}
# Max Signature:  {'toe', 'footwear', 'cover', 'provide'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('toe.n.02')
# Senso Target:  Lemma('toe.n.01.toe')
# ------------------------------
# Parola da disambiguare:  50
# Frase in cui compare la parola:  The figures in the next-to-last column are derived with the assumption of 50 per cent shielding by the Earth ; hence , these figures apply immediately above the Earth 's atmosphere .
# Contesto della frase:  {'atmosphere', 'apply', 'cent', 'column', 'derive', 'shielding', 'figure', 'earth', 'assumption', 'nexttolast'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('fifty.n.01')
# Senso Target:  Lemma('fifty.s.01.50')
# ------------------------------
# Parola da disambiguare:  individual
# Frase in cui compare la parola:  The numbers of successes on the five individual shots are , then , 0 , 0 , 1 , 0 , 1 .
# Contesto della frase:  {'success', 'individual', 'shot', 'number'}
# Max Signature:  {'thing', 'characteristic', 'drop', 'rain', 'individual', 'mark', 'person', 'single'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('individual.a.01')
# Senso Target:  Lemma('individual.a.01.individual')
# ------------------------------
# Parola da disambiguare:  loan
# Frase in cui compare la parola:  The bill would increase from $ 5000000 to $ 15000000 the maximum loan the state could make to a local water project .
# Contesto della frase:  {'project', 'local', 'maximum', 'loan', 'bill', 'increase', 'water'}
# Max Signature:  {'time', 'lend', 'loan', 'temporarily', 'limited', 'car', 'money'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('lend.v.02')
# Senso Target:  Lemma('loan.n.01.loan')
# ------------------------------
# Parola da disambiguare:  explains
# Frase in cui compare la parola:  London explains that the very distinct directional effect in the Phase 4 series is due in large part to their novel methods of microphoning and recording the music on a number of separate tape channels .
# Contesto della frase:  {'microphoning', 'phase', 'novel', 'series', 'number', 'separate', 'record', 'large', 'channel', 'distinct', 'london', 'directional', 'method', 'tape', 'music', 'explain'}
# Max Signature:  {'comprehensible', 'plain', 'student', 'physic', 'law', 'explain'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('explain.v.01')
# Senso Target:  Lemma('explain.v.01.explain')
# ------------------------------
# Parola da disambiguare:  25
# Frase in cui compare la parola:  For further information , contact the Bank for Cooperatives serving the region , or the Farm Credit Administration , Research and Information Division , Washington 25 , D.C. .
# Contesto della frase:  {'administration', 'contact', 'dc', 'region', 'serve', 'division', 'bank', 'washington', 'farm', 'cooperatives', 'credit'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('twenty-five.n.01')
# Senso Target:  Lemma('twenty-five.s.01.25')
# ------------------------------
# Parola da disambiguare:  sentiment
# Frase in cui compare la parola:  And no doubt many people in states like the Carolinas and Georgia , which were among the most Tory in sentiment in the eighteenth century , bitterly regretted the revolt against the Crown .
# Contesto della frase:  {'sentiment', 'revolt', 'doubt', 'century', 'bitterly', 'people', 'eighteenth', 'crown', 'regret', 'tory', 'carolinas', 'georgia'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('sentiment.n.01')
# Senso Target:  Lemma('opinion.n.01.sentiment')
# ------------------------------
# Parola da disambiguare:  lousy
# Frase in cui compare la parola:  No epidemic was initiated nor was one expected because the population in City A was not lousy .
# Contesto della frase:  {'expect', 'population', 'epidemic', 'city', 'lousy', 'initiate'}
# Max Signature:  {'play', 'bad', 'stinking', 'lousy'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('icky.s.01')
# Senso Target:  Lemma('lousy.s.02.lousy')
# ------------------------------
# Parola da disambiguare:  racists
# Frase in cui compare la parola:  The two main charges levelled against the Bourbons by liberals is that they are racists and social reactionaries .
# Contesto della frase:  {'racist', 'charge', 'main', 'social', 'liberal', 'reactionary', 'bourbons', 'level'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('racist.n.01')
# Senso Target:  Lemma('racist.n.01.racist')
# ------------------------------
# Parola da disambiguare:  serious
# Frase in cui compare la parola:  More believed that a man could be both serious and gay .
# Contesto della frase:  {'serious', 'gay', 'man'}
# Max Signature:  {'play', 'history', 'joking', 'attempt', 'ski', 'young', 'learn', 'triviality', 'matter', 'student', 'concern', 'work', 'serious', 'dont', 'man'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('serious.a.01')
# Senso Target:  Lemma('serious.a.01.serious')
# ------------------------------
# Parola da disambiguare:  remain
# Frase in cui compare la parola:  However , many herpetologists remain skeptical and would prefer a tentative maximum of about 30 feet .
# Contesto della frase:  {'tentative', 'prefer', 'remain', 'maximum', 'skeptical', 'herpetologist', 'foot'}
# Max Signature:  {'week', 'assure', 'dry', 'dress', 'attempt', 'stay', 'repeat', 'remain', 'unmoved', 'tear', 'weather', 'continue', 'bad', 'rest', 'wet'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('stay.v.01')
# Senso Target:  Lemma('stay.v.01.remain')
# ------------------------------
# Parola da disambiguare:  medication
# Frase in cui compare la parola:  This medication was continued until February , 1958 .
# Contesto della frase:  {'continue', 'february', 'medication'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('medicine.n.02')
# Senso Target:  Lemma('medicine.n.02.medication')
# ------------------------------
# Parola da disambiguare:  Western
# Frase in cui compare la parola:  Or the city can be a graveyard monument to Western intransigence , if that is what the West wants .
# Contesto della frase:  {'west', 'intransigence', 'city', 'graveyard', 'monument', 'western'}
# Max Signature:  {'oriental', 'eastern', 'west', 'characteristic', 'oppose', 'relate', 'western'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('western.a.01')
# Senso Target:  Lemma('western.a.01.western')
# ------------------------------
# Parola da disambiguare:  advertising
# Frase in cui compare la parola:  The Vice President said , `` If you hear of any names that would fix me cheap in return for advertising they decorated the Vice President 's home , let me know .
# Contesto della frase:  {'advertising', 'return', 'hear', 'cheap', 'decorate', 'president', 'vice'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('ad.n.01')
# Senso Target:  Lemma('ad.n.01.advertising')
# ------------------------------
# Parola da disambiguare:  shot
# Frase in cui compare la parola:  Mills shot out in front and kept the lead through two thirds of the race .
# Contesto della frase:  {'front', 'shoot', 'race', 'third', 'lead', 'mills'}
# Max Signature:  {'respect', 'poor', 'ability', 'crack', 'shoot', 'person', 'shot', 'shooter'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('shot.n.05')
# Senso Target:  Lemma('tear.v.03.shoot')
# ------------------------------
# Parola da disambiguare:  dance
# Frase in cui compare la parola:  Our athletes are only just beginning to learn that they must study dance .
# Contesto della frase:  {'athlete', 'study', 'dance', 'learn'}
# Max Signature:  {'assemble', 'party', 'people', 'dance'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('dance.n.02')
# Senso Target:  Lemma('dance.n.01.dance')
# ------------------------------
# Parola da disambiguare:  gas
# Frase in cui compare la parola:  This arrangement had the purpose to prevent heated gas to reach the thermocouple by natural convection .
# Contesto della frase:  {'prevent', 'reach', 'thermocouple', 'convection', 'gas', 'natural', 'arrangement', 'purpose', 'heat'}
# Max Signature:  {'alimentary', 'gas', 'canal', 'excessive'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('flatulence.n.01')
# Senso Target:  Lemma('gas.n.02.gas')
# ------------------------------
# Parola da disambiguare:  historical
# Frase in cui compare la parola:  To be the Savior and the Lord , Jesus Christ has to be a historical individual with a biography all his own ; he dare not be a cosmic aeon that swoops to earth for a while but never identifies itself with man 's history .
# Contesto della frase:  {'history', 'lord', 'christ', 'dare', 'savior', 'biography', 'aeon', 'jesus', 'historical', 'individual', 'cosmic', 'earth', 'swoop', 'identifies', 'man'}
# Max Signature:  {'history', 'study', 'perspective', 'historical', 'relate', 'scholar'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('historical.a.01')
# Senso Target:  Lemma('historical.s.02.historical')
# ------------------------------
# Parola da disambiguare:  Finally
# Frase in cui compare la parola:  Finally , a balance must be effected among project finance , utilization of agricultural surpluses , and general balance of payments support .
# Contesto della frase:  {'project', 'utilization', 'finance', 'surplus', 'agricultural', 'balance', 'support', 'finally', 'general', 'payment'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('finally.r.01')
# Senso Target:  Lemma('finally.r.01.finally')
# ------------------------------
# Parola da disambiguare:  maids
# Frase in cui compare la parola:  One of the leading members of the Amen corner was cook ; there were two or three colored maids employed there .
# Contesto della frase:  {'cook', 'employ', 'member', 'corner', 'amen', 'colored', 'lead', 'maid'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('maid.n.01')
# Senso Target:  Lemma('maid.n.01.maid')
# ------------------------------
# Parola da disambiguare:  command
# Frase in cui compare la parola:  And He laid down for him certain conditions : so that , if he kept the command of God , then he would always remain as he was , that is , immortal ; but if he did not , he would become mortal , melting into earth , whence his frame had been taken '' .
# Contesto della frase:  {'lay', 'immortal', 'god', 'mortal', 'melt', 'remain', 'condition', 'earth', 'frame', 'command'}
# Max Signature:  {'command', 'authority', 'admiral', 'power'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('command.n.03')
# Senso Target:  Lemma('command.n.01.command')
# ------------------------------
# Parola da disambiguare:  submitted
# Frase in cui compare la parola:  No figures were submitted with the report and no action was taken on it by the town .
# Contesto della frase:  {'report', 'submit', 'figure', 'action', 'town'}
# Max Signature:  {'court', 'lawyer', 'consideration', 'submit', 'judgment', 'refer', 'material'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('submit.v.01')
# Senso Target:  Lemma('submit.v.01.submit')
# ------------------------------
# Parola da disambiguare:  study
# Frase in cui compare la parola:  `` How long did you study ?
# Contesto della frase:  {'long', 'study'}
# Max Signature:  {'apply', 'work', 'language', 'read', 'subject', 'learn', 'master', 'require', 'study', 'school', 'interior', 'graduate', 'offer', 'understand', 'mind', 'lot', 'second', 'design'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('study.n.02')
# Senso Target:  Lemma('study.v.06.study')
# ------------------------------
# Parola da disambiguare:  direct
# Frase in cui compare la parola:  Results from this approach amply confirm the direct observations :
# Contesto della frase:  {'direct', 'observation', 'confirm', 'approach', 'amply'}
# Max Signature:  {'direct', 'language', 'question', 'response', 'straightforward', 'action', 'manner', 'behavior', 'approach'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('direct.a.03')
# Senso Target:  Lemma('direct.a.01.direct')
# ------------------------------
# Parola da disambiguare:  water
# Frase in cui compare la parola:  Figure the cost of providing water to the use areas .
# Contesto della frase:  {'area', 'provide', 'figure', 'cost', 'water'}
# Max Signature:  {'supply', 'provide', 'source', 'facility', 'purification', 'town', 'water', 'cut', 'debate'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('water_system.n.02')
# Senso Target:  Lemma('water.n.01.water')
# ------------------------------
# Parola da disambiguare:  interested
# Frase in cui compare la parola:  Jane sat receptive and interested .
# Contesto della frase:  {'sit', 'receptive', 'jane', 'interested'}
# Max Signature:  {'fascination', 'family', 'spectator', 'hear', 'telephone', 'curiosity', 'interested', 'sport', 'concern', 'audience', 'interest'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('interested.a.01')
# Senso Target:  Lemma('interested.a.01.interested')
# ------------------------------
# Parola da disambiguare:  high
# Frase in cui compare la parola:  The high heat fluxes existing at the electrode surfaces of electric arcs necessitate extensive cooling to prevent electrode ablation .
# Contesto della frase:  {'arc', 'exist', 'prevent', 'flux', 'ablation', 'surface', 'necessitate', 'extensive', 'electrode', 'electric', 'cooling', 'high', 'heat'}
# Max Signature:  {'reach', 'degree', 'lofty', 'position', 'temperature', 'alltime', 'high', 'summer', 'level'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('high.n.01')
# Senso Target:  Lemma('high.a.01.high')
# ------------------------------
# Parola da disambiguare:  satisfactory
# Frase in cui compare la parola:  This was working by the end of August and giving satisfactory service .
# Contesto della frase:  {'work', 'august', 'satisfactory', 'service'}
# Max Signature:  {'grade', 'condition', 'satisfaction', 'satisfactory', 'living'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('satisfactory.a.01')
# Senso Target:  Lemma('satisfactory.a.01.satisfactory')
# ------------------------------
# Parola da disambiguare:  derive
# Frase in cui compare la parola:  To derive Utopian communism from the Jerusalem Christian community of the apostolic age or from its medieval successors in spirit , the monastic communities , is with an appropriate shift of adjectives , misleading in the same way as to derive it from Plato 's Republic :
# Contesto della frase:  {'age', 'monastic', 'utopian', 'communism', 'jerusalem', 'mislead', 'adjective', 'derive', 'medieval', 'spirit', 'apostolic', 'plato', 'appropriate', 'christian', 'shift', 'republic', 'community', 'successor'}
# Max Signature:  {'derive', 'pleasure', 'garden'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('derive.v.02')
# Senso Target:  Lemma('deduce.v.01.derive')
# ------------------------------
# Parola da disambiguare:  called
# Frase in cui compare la parola:  Bumblebees can thus suffer severely from the onslaughts of Psithyrus , the `` cuckoo bumblebee '' as it is called in some European countries .
# Contesto della frase:  {'bumblebee', 'severely', 'call', 'suffer', 'cuckoo', 'onslaught', 'psithyrus', 'country', 'european', 'bumblebees'}
# Max Signature:  {'ascribe', 'call', 'ungrateful', 'child', 'bastard', 'common', 'quality', 'reflect', 'noun', 'lazy'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('call.v.02')
# Senso Target:  called.s.00
# ------------------------------
# Parola da disambiguare:  higher
# Frase in cui compare la parola:  The higher heat transfer rates at the anode compared with those at the cathode can be explained by the physical phenomena occurring in free burning arcs .
# Contesto della frase:  {'arc', 'phenomenon', 'transfer', 'free', 'cathode', 'occur', 'burning', 'compare', 'physical', 'rate', 'high', 'anode', 'heat', 'explain'}
# Max Signature:  {'advance', 'finance', 'complexity', 'mathematics', 'elaboration', 'high'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('higher.s.01')
# Senso Target:  Lemma('high.a.01.high')
# ------------------------------
# Parola da disambiguare:  argue
# Frase in cui compare la parola:  They argue further ( and somewhat contradictorily ) that our knowledge and resources in preventive medicine would make it possible to control such an outbreak of disease .
# Contesto della frase:  {'contradictorily', 'preventive', 'control', 'knowledge', 'outbreak', 'argue', 'resource', 'medicine', 'disease'}
# Max Signature:  {'result', 'indicate', 'claim', 'argue', 'work', 'evidence'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('argue.v.03')
# Senso Target:  Lemma('argue.v.02.argue')
# ------------------------------
# Parola da disambiguare:  fits
# Frase in cui compare la parola:  This idea , which occurs in both Tatian and Cyprian , fits especially well into the scheme of Irenaeus ' theology ; for it prepares the way for the passage from life through death to life that is achieved in Christ .
# Contesto della frase:  {'achieve', 'scheme', 'tatian', 'christ', 'occur', 'prepare', 'passage', 'life', 'well', 'irenaeus', 'idea', 'death', 'theology', 'cyprian', 'fit'}
# Max Signature:  {'temper', 'scene', 'tantrum', 'display', 'bad', 'throw', 'fit'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('fit.n.01')
# Senso Target:  Lemma('suit.v.01.fit')
# ------------------------------
# Parola da disambiguare:  close
# Frase in cui compare la parola:  That after all his years of effort to become a composer , he should now , now when he was still stoutly replying to the critics of his Discourse on the Arts and Sciences , be so close to a success in music and have to reject it .
# Contesto della frase:  {'sciences', 'stoutly', 'critic', 'close', 'reject', 'effort', 'success', 'arts', 'year', 'reply', 'music', 'discourse', 'composer'}
# Max Signature:  {'time', 'bomb', 'close', 'hit', 'degree', 'call', 'thing', 'equal', 'tear', 'success', 'future', 'distant', 'circumstance', 'space', 'neighbor', 'approach'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('near.a.01')
# Senso Target:  Lemma('close.a.01.close')
# ------------------------------
# Parola da disambiguare:  dependence
# ...
# Senso Target:  Lemma('strange.s.02.strange')
# ------------------------------
# Parola da disambiguare:  precious
# Frase in cui compare la parola:  The long settled areas of states like Virginia and South Carolina developed the ante-bellum culture to its richest flowering , and there the memory is more precious , and the consciousness of loss the greater .
# Contesto della frase:  {'area', 'flowering', 'consciousness', 'culture', 'carolina', 'precious', 'great', 'develop', 'memory', 'south', 'long', 'antebellum', 'virginia', 'loss', 'rich', 'settled'}
# Max Signature:  {'intrinsic', 'precious', 'nature', 'great', 'memory', 'hold', 'esteem', 'quality', 'admirable', 'friend'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('valued.s.02')
# Senso Target:  Lemma('cherished.s.01.precious')
# ------------------------------
# Parola da disambiguare:  anticipation
# Frase in cui compare la parola:  He glowed with anticipation about what would happen to the culprits when they caught them .
# Contesto della frase:  {'anticipation', 'culprit', 'catch', 'happen', 'glow'}
# Max Signature:  {'expect', 'norm', 'anticipation', 'expectancy', 'basis', 'development', 'indicator'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('anticipation.n.02')
# Senso Target:  Lemma('anticipation.n.01.anticipation')
# ------------------------------
# Parola da disambiguare:  total
# Frase in cui compare la parola:  Their sum is X , the total number of successes , which in this experiment has the value * * f .
# Contesto della frase:  {'sum', 'number', 'success', 'total', 'experiment'}
# Max Signature:  {'quantity', 'group', 'number', 'addition'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('sum.n.02')
# Senso Target:  Lemma('entire.s.01.total')
# ------------------------------
# Parola da disambiguare:  negative
# Frase in cui compare la parola:  The x-ray data did not permit Douglass to determine uniquely the space group , but a negative test for piezoelectricity led him to assume a center of symmetry .
# Contesto della frase:  {'center', 'permit', 'douglass', 'test', 'group', 'uniquely', 'determine', 'symmetry', 'negative', 'space', 'xray', 'assume', 'lead', 'data', 'piezoelectricity'}
# Max Signature:  {'indicate', 'presence', 'test', 'condition', 'specific', 'negative', 'hiv', 'disease', 'microorganism'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('negative.a.04')
# Senso Target:  Lemma('negative.a.02.negative')
# ------------------------------
# Parola da disambiguare:  scavenger
# Frase in cui compare la parola:  Furthermore , the exchange would not be expected to be sensitive to trace amounts of impurities because it would not be apt to be a chain reaction since the activation energy for abstraction of chlorine by a chlorine atom would be expected to be too high ; also it would be expected that * * f would compete very effectively with any impurities as a scavenger for * * f radicals .
# Contesto della frase:  {'expect', 'activation', 'apt', 'scavenger', 'exchange', 'trace', 'chain', 'abstraction', 'impurity', 'high', 'atom', 'chlorine', 'effectively', 'energy', 'amount', 'reaction', 'radical', 'compete', 'sensitive'}
# Max Signature:  {'agent', 'mixture', 'impurity', 'counteract', 'chemical', 'add'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('scavenger.n.01')
# Senso Target:  Lemma('scavenger.n.01.scavenger')
# ------------------------------
# Parola da disambiguare:  unfolding
# Frase in cui compare la parola:  Each high note had the crowd in ecstasy so that it stopped the show midway in the `` Mad Scene '' , but the real reason was a realization of the extraordinary performance unfolding at the moment .
# Contesto della frase:  {'mad', 'realization', 'scene', 'reason', 'unfolding', 'midway', 'extraordinary', 'crowd', 'moment', 'real', 'high', 'note', 'performance'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('unfolding.n.01')
# Senso Target:  Lemma('blossom.v.02.unfold')
# ------------------------------
# Parola da disambiguare:  thought
# Frase in cui compare la parola:  Both shudder at the thought of proceeding too far beyond the sewage system and the electric light lines .
# Contesto della frase:  {'system', 'proceed', 'thought', 'light', 'shudder', 'electric', 'sewage'}
# Max Signature:  {'thought', 'main', 'thing', 'cognition', 'good', 'content', 'mind', 'idea', 'enter'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('idea.n.01')
# Senso Target:  Lemma('idea.n.01.thought')
# ------------------------------
# Parola da disambiguare:  exploitation
# Frase in cui compare la parola:  It is the exploitation of the inherent potential of infectious disease agents by scientific research and development , resulting in the production of BW weapons systems .
# Contesto della frase:  {'scientific', 'result', 'potential', 'system', 'disease', 'agent', 'production', 'inherent', 'exploitation', 'weapon', 'bw', 'development', 'infectious'}
# Max Signature:  {'area', 'land', 'copper', 'exploitation', 'alaskan', 'productive', 'resource', 'water', 'development', 'profitable', 'deposit'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('exploitation.n.01')
# Senso Target:  Lemma('exploitation.n.02.exploitation')
# ------------------------------
# Parola da disambiguare:  blend
# Frase in cui compare la parola:  One of the script 's big problems was how to blend pictures and music of the past with live performances by musicians of today .
# Contesto della frase:  {'musician', 'today', 'live', 'picture', 'blend', 'problem', 'big', 'music', 'script', 'performance'}
# Max Signature:  {'motor', 'hotel', 'smog', 'combine', 'smoke', 'wellknown', 'blend', 'meaning', 'word', 'brunch', 'form', 'portmanteau', 'join', 'motel', 'fog'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('blend.n.02')
# Senso Target:  Lemma('blend.v.01.blend')
# ------------------------------
# Parola da disambiguare:  acknowledges
# Frase in cui compare la parola:  We find it in Plato 's republic , and in Utopia More acknowledges his debt to that book .
# Contesto della frase:  {'find', 'utopia', 'debt', 'republic', 'plato', 'acknowledge', 'book'}
# Max Signature:  {'truth', 'admit', 'existence', 'error', 'reality', 'true', 'forget', 'declare', 'acknowledge'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('admit.v.01')
# Senso Target:  acknowledge.v.00
# ------------------------------
# Parola da disambiguare:  set
# Frase in cui compare la parola:  Receiving no answer , they set the fire .
# Contesto della frase:  {'fire', 'set', 'receiving', 'answer'}
# Max Signature:  {'set', 'apply', 'start', 'fire', 'building'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('set.v.13')
# Senso Target:  Lemma('set_ablaze.v.01.set_on_fire')
# ------------------------------
# Parola da disambiguare:  third
# Frase in cui compare la parola:  The Dallas Texans were back home Monday with their third victory in four American Football League starts - a 19 - 12 triumph over the Denver Broncos - but their visit will be a short one .
# Contesto della frase:  {'league', 'dallas', 'football', 'visit', 'victory', 'short', 'start', 'denver', 'triumph', 'american', 'third', 'monday', 'broncos', 'texans'}
# Max Signature:  {'motor', 'gear', 'box', 'vehicle', 'ratio', 'start', 'low', 'third', 'forward', 'shouldnt'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('third_gear.n.01')
# Senso Target:  Lemma('third.s.01.third')
# ------------------------------
# Parola da disambiguare:  fifty
# Frase in cui compare la parola:  To the west of this road was another low bluff , forty or fifty feet high , covered with scrub oak and other brush .
# Contesto della frase:  {'scrub', 'cover', 'road', 'west', 'fifty', 'oak', 'low', 'brush', 'high', 'forty', 'foot', 'bluff'}
# Max Signature:  {'forty'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('fifty.s.01')
# Senso Target:  Lemma('fifty.s.01.fifty')
# ------------------------------
# Parola da disambiguare:  specific
# Frase in cui compare la parola:  One gram of cotton has been found to have a specific surface area of * * f .
# Contesto della frase:  {'area', 'find', 'surface', 'specific', 'cotton', 'gram'}
# Max Signature:  {'quinine', 'mitigating', 'specific', 'malaria', 'medicine', 'disease'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('specific.n.02')
# Senso Target:  Lemma('specific.s.02.specific')
# ------------------------------
# Parola da disambiguare:  continuously
# Frase in cui compare la parola:  This region which had a higher temperature than the rest of the anode surface changed size and location continuously .
# Contesto della frase:  {'location', 'surface', 'region', 'size', 'change', 'temperature', 'continuously', 'high', 'anode', 'rest'}
# Max Signature:  {'point', 'continuously', 'function', 'differentiable'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('continuously.r.01')
# Senso Target:  Lemma('continuously.r.01.continuously')
# ------------------------------
# Parola da disambiguare:  adventure
# Frase in cui compare la parola:  As long as audiences came to see the movement , there seemed little reason to adventure further .
# Contesto della frase:  {'reason', 'movement', 'long', 'adventure', 'audience'}
# Max Signature:  []
# Senso attribuito dall'algoritmo di Lesk:  Synset('adventure.n.01')
# Senso Target:  Lemma('gamble.v.01.adventure')
# ------------------------------
# Parola da disambiguare:  determination
# Frase in cui compare la parola:  There have been few measurements specifically for the determination of the polarization of planetary radiation .
# Contesto della frase:  {'planetary', 'measurement', 'determination', 'polarization', 'radiation'}
# Max Signature:  {'calculation', 'determine', 'structure', 'molecular', 'determination', 'property'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('determination.n.01')
# Senso Target:  Lemma('determination.n.01.determination')
# ------------------------------
# Parola da disambiguare:  calculated
# Frase in cui compare la parola:  De Jager ( 1955 ) has calculated the times required for these particles to reach the atmosphere under the influence of the Poynting-Robertson effect , which in this case causes the orbits to become more and more eccentric without changing the semi major axis .
# Contesto della frase:  {'atmosphere', 'time', 'poyntingrobertson', 'reach', 'eccentric', 'particle', 'require', 'orbit', 'jager', 'semi', 'major', 'de', 'change', 'influence', 'case', 'axis', 'calculate'}
# Max Signature:  {'confidence', 'time', 'family', 'faith', 'count', 'depend', 'crisis', 'bet', 'support', 'help', 'friend'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('count.v.08')
# Senso Target:  Lemma('calculate.v.01.calculate')
# ------------------------------
# Parola da disambiguare:  moments
# Frase in cui compare la parola:  The music drove them off , or away , and he was free to walk on air in a very few moments , humming and jiving within , beating the rhythm within .
# Contesto della frase:  {'air', 'free', 'drive', 'walk', 'moment', 'hum', 'jive', 'beat', 'music', 'rhythm'}
# Max Signature:  {'time', 'arrive', 'moment', 'point', 'party'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('moment.n.01')
# Senso Target:  Lemma('moment.n.01.moment')
# ------------------------------
# Parola da disambiguare:  evokes
# Frase in cui compare la parola:  Only one other contemporary of More 's evokes so immediate and direct a response , and only one other contemporary work - Niccolo Machiavelli and The Prince .
# Contesto della frase:  {'direct', 'response', 'evokes', 'prince', 'work', 'machiavelli', 'niccolo', 'contemporary'}
# Max Signature:  {'feeling', 'raise', 'emotion', 'sympathy', 'call', 'response', 'evoke', 'arouse', 'pity', 'smile'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('arouse.v.01')
# Senso Target:  Lemma('arouse.v.01.evoke')
# ------------------------------
# Parola da disambiguare:  speak
# Frase in cui compare la parola:  They did not speak much .
# Contesto della frase:  {'speak'}
# Max Signature:  {'talk', 'language', 'strange', 'wont', 'speak', 'prisoner', 'dialect', 'baby'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('speak.v.03')
# Senso Target:  Lemma('talk.v.01.speak')
# ------------------------------
# Parola da disambiguare:  time
# Frase in cui compare la parola:  This time as a musician .
# Contesto della frase:  {'musician', 'time'}
# Max Signature:  {'time', 'succeed', 'call', 'ten', 'occasion', 'event', 'instance', 'clip', 'single'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('time.n.01')
# Senso Target:  Lemma('time.n.01.time')
# ------------------------------
# Parola da disambiguare:  intelligent
# Frase in cui compare la parola:  Though it was a great relief when the big brains on these shows turned out to be frauds and phonies , it did irreparable damage to the ego of the editor and many another intelligent , well-informed American .
# Contesto della frase:  {'brain', 'american', 'relief', 'damage', 'intelligent', 'great', 'frauds', 'ego', 'wellinformed', 'big', 'phony', 'irreparable', 'editor', 'turn'}
# Max Signature:  {'thought', 'question', 'universe', 'reason', 'degree', 'capacity', 'intelligent', 'life', 'high'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('intelligent.a.01')
# Senso Target:  Lemma('intelligent.a.01.intelligent')
# ------------------------------
# Parola da disambiguare:  intensively
# Frase in cui compare la parola:  The biological and physical properties of infectious particles have been studied intensively during the past fifteen years .
# Contesto della frase:  {'study', 'particle', 'physical', 'year', 'intensively', 'biological', 'fifteen', 'property', 'infectious'}
# Max Signature:  {'study', 'snake', 'intensively', 'intensive', 'manner'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('intensively.r.01')
# Senso Target:  Lemma('intensively.r.01.intensively')
# ------------------------------
# Parola da disambiguare:  combining
# Frase in cui compare la parola:  They are segregated businesses , combining again on one site the factory and the office , drawing their work force from segregated communities .
# Contesto della frase:  {'site', 'draw', 'business', 'combine', 'factory', 'force', 'office', 'community', 'work', 'segregated'}
# Max Signature:  {'combine', 'action', 'force', 'common', 'purpose', 'join'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('combine.v.05')
# Senso Target:  Lemma('compound.v.02.combine')
# ------------------------------
# Parola da disambiguare:  vogue
# Frase in cui compare la parola:  These were the years when people flocked to Manchester not only to play golf , which had come into vogue , but also to witness the Ekwanok Country Club tournaments .
# Contesto della frase:  {'play', 'manchester', 'witness', 'tournament', 'club', 'vogue', 'year', 'people', 'golf', 'flock', 'ekwanok', 'country'}
# Max Signature:  {'time', 'current', 'follow', 'vogue', 'popular', 'trend', 'leather', 'late', 'style', 'taste'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('vogue.n.01')
# Senso Target:  Lemma('vogue.n.01.vogue')
# ------------------------------
# Parola da disambiguare:  unpleasant
# Frase in cui compare la parola:  Above all , we should seek to encourage the leaders of these societies to accept the unpleasant fact that they are responsible for their fates .
# Contesto della frase:  {'society', 'unpleasant', 'seek', 'encourage', 'fact', 'leader', 'responsible', 'fate', 'accept'}
# Max Signature:  {'unpleasant', 'sens', 'feeling', 'repercussion', 'personality', 'disagreeable', 'odor', 'mind'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('unpleasant.a.01')
# Senso Target:  Lemma('unpleasant.a.01.unpleasant')
# ------------------------------
# Parola da disambiguare:  making
# Frase in cui compare la parola:  So I started making some calls of my own .
# Contesto della frase:  {'start', 'call'}
# Max Signature:  {'decision', 'perform', 'phone', 'advance', 'call', 'move', 'carry'}
# Senso attribuito dall'algoritmo di Lesk:  Synset('make.v.16')
# Senso Target:  Lemma('make.v.01.make')
# ------------------------------
# Termini valutati:  51
# Termini valutati correttamente:  28
# Accuratezza:  0.56
#
# Esecuzioni:  10
# Lista delle accuratezze:  [0.26, 0.44, 0.5, 0.44, 0.46, 0.5, 0.52, 0.56, 0.56, 0.56]
# Accuratezza media:  0.48000000000000004
